# %%
import xml.etree.ElementTree as ET
from difflib import SequenceMatcher, get_close_matches

def parse_mesh_descriptors(xml_path):
    """Parse the MeSH XML and return a list of descriptors."""
    tree = ET.parse(xml_path)
    root = tree.getroot()
    descriptors = []
    for dr in root.findall('DescriptorRecord'):
        ui_el   = dr.find('DescriptorUI')
        name_el = dr.find('DescriptorName/String')
        if ui_el is None or name_el is None:
            continue
        ui   = ui_el.text
        name = name_el.text
        tree_nums = [tn.text for tn in dr.findall('TreeNumberList/TreeNumber') if tn.text]
        descriptors.append({'ui':ui, 'name':name, 'tree_numbers':tree_nums})
    return descriptors

MESH_XML = 'desc2025.xml'
descriptors = parse_mesh_descriptors(MESH_XML)
print(f"Parsed {len(descriptors)} descriptors")
# Out:
# Parsed 30956 descriptors

# %%
import xml.etree.ElementTree as ET

def parse_mesh_descriptors(xml_path):
    """
    Parse the MeSH XML and return a list of dicts:
      { 'ui': DescriptorUI,
        'name': DescriptorName,
        'tree_numbers': [treeNum1, treeNum2, ...]
      }
    """
    tree = ET.parse(xml_path)
    root = tree.getroot()
    descriptors = []
    for dr in root.findall('DescriptorRecord'):
        ui_el = dr.find('DescriptorUI')
        name_el = dr.find('DescriptorName/String')
        if ui_el is None or name_el is None:
            continue
        ui = ui_el.text
        name = name_el.text
        tree_numbers = [tn.text for tn in dr.findall('TreeNumberList/TreeNumber') if tn.text]
        descriptors.append({
            'ui': ui,
            'name': name,
            'tree_numbers': tree_numbers
        })
    return descriptors

def get_bacteria_taxonomy(xml_path):
    """
    From the full MeSH descriptors file, extract all descriptors
    under the 'Bacteria' branch (tree number B03).
    Returns a dict: { tree_number: { 'ui': ..., 'name': ... }, ... }
    """
    descriptors = parse_mesh_descriptors(xml_path)

    bacteria_prefix = None
    for d in descriptors:
        if d['name'] == 'Bacteria':
            bacteria_prefix = d['tree_numbers'][0]
            break

    if not bacteria_prefix:
        raise RuntimeError("Couldn't find a descriptor named 'Bacteria' in the file.")

    taxonomy = {}
    for d in descriptors:
        for tn in d['tree_numbers']:
            if tn == bacteria_prefix or tn.startswith(bacteria_prefix + '.'):
                taxonomy[tn] = {
                    'ui': d['ui'],
                    'name': d['name']
                }
                break

    return taxonomy

if __name__ == '__main__':
    xml_file = 'desc2025.xml'
    bacteria_tax = get_bacteria_taxonomy(xml_file)

# %%
from difflib import SequenceMatcher

def find_mesh_match(input_name, name_index, n=5, cutoff=0.6):
    """
    Return matches for input_name among the MeSH bacterial names.
    Exact matches come first with score=1.0.
    Then fuzzy matches (score computed via SequenceMatcher.ratio).
    """
    key = input_name.lower()
    results = []
    if key in name_index:
        for tree_num, ui, name in name_index[key]:
            results.append((name, ui, tree_num, 1.0))
        return results

    all_names = list(name_index.keys())
    
    close = get_close_matches(key, all_names, n=n, cutoff=cutoff)
    for cname in close:
        score = SequenceMatcher(None, key, cname).ratio()
        for tree_num, ui, name in name_index[cname]:
            results.append((name, ui, tree_num, score))
    results.sort(key=lambda x: x[3], reverse=True)
    return results

def build_name_index(taxonomy):
    """
    Build a dict: lower-case name -> list of (tree#, ui, canonical name)
    """
    idx = {}
    for tree_num, info in taxonomy.items():
        key = info['name'].lower()
        idx.setdefault(key, []).append((tree_num, info['ui'], info['name']))
    return idx

name_index = build_name_index(bacteria_tax)
print(f"Indexed {len(name_index)} bacterial names")
# Out:
# Indexed 859 bacterial names

# %%
import xml.etree.ElementTree as ET

def load_mesh_definitions(xml_path: str) -> dict:
    """
    Parse the MeSH XML and return a dict mapping DescriptorUI → ScopeNote text.
    """
    defs = {}
    tree = ET.parse(xml_path)
    root = tree.getroot()
    for dr in root.findall('DescriptorRecord'):
        ui = dr.findtext('DescriptorUI')
        # ScopeNote can appear directly or under ScopeNoteList/ScopeNote
        sn = dr.findtext('ScopeNote') or dr.findtext('ScopeNoteList/ScopeNote')
        if ui and sn:
            defs[ui] = sn.strip()
    return defs

# load once at module top
MESH_XML = 'desc2025.xml'
mesh_definitions = load_mesh_definitions(MESH_XML)

def get_mesh_description(uri: str, mesh_defs: dict) -> str | None:
    """
    Given a full MeSH URI like "https://.../ui", return its ScopeNote definition if present.
    """
    ui = uri.rsplit('/', 1)[-1]
    return mesh_defs.get(ui)

# %%
import re, json, numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

def load_taxonomy_tree(path):
    row_re = re.compile(r"^\s*(.*?)\s+\[([^\]]+)\]\s*$")
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = row_re.match(ln)
            if m:
                label, tid = m.groups()
                depth      = len(ln) - len(ln.lstrip())
                rows.append((label, tid, depth))
    return rows

TAX_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\bacteria_tree1.txt"
rows     = load_taxonomy_tree(TAX_FILE)

exact_ix  = defaultdict(list)
for lbl, tid, depth in rows:
    exact_ix[lbl.lower()].append((lbl, tid, depth))

labels_only  = [r[0] for r in rows]
vec          = TfidfVectorizer(stop_words="english")
mat          = vec.fit_transform(labels_only)

def top_cosine(term, k=5, thr=0.75):
    v   = vec.transform([term])
    sc  = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr: break
        lbl, tid, d = rows[i]
        out.append((lbl, tid, d, sc[i]))
    return out

abbr_re = re.compile(r"^([A-Z])\.\s+([A-Za-z_-]+)$")

def preprocess(term):
    term = term.replace('_', ' ')
    term = term.strip()
    return " ".join(lemmatizer.lemmatize(w) for w in term.split())

def genus_abbrev_lookup(term):
    m = abbr_re.match(term)
    if not m:
        return []
    initial, species = m.groups()
    species = species.lower()
    hits = []
    for lbl, tid, d in rows:
        if lbl.lower().endswith(' ' + species) and lbl[0].upper() == initial:
            hits.append((lbl, tid, d, 1.00))
    return hits

# %% [markdown]
# <h1>INGEST BACTERIA</h1>

# %%
import os
import re
import unicodedata
import json
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint
from rdflib.namespace import DCTERMS

# -----------------------------------------------------------------------------
# 1. Setup paths and namespaces
# -----------------------------------------------------------------------------
path = str(Path(os.path.abspath(os.getcwd())).absolute())
json_file = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\data\train_platinum\train_platinum.json"
gold_file = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\data\train_gold\train_gold.json"
dev_file = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\data\dev\dev.json"

tokenized_file = os.path.join(path, "tokenized_sentences_with_entitiesv2.json")
tokenized_gold_file = os.path.join(path, "tokenized_sentences_with_entitiesgoldv2.json")
tokenized_dev = os.path.join(path,"tokenized_sentences_with_entitiesdev.json")
save_path = os.path.join(path, "rdf")
os.makedirs(save_path, exist_ok=True)

GUTBRAIN = Namespace("https://w3id.org/hereditary/ontology/gutbrain/resource/")
GUTPROP = Namespace("https://w3id.org/hereditary/ontology/gutbrain/schema/")
GUTBRAINMENTION = Namespace("https://w3id.org/hereditary/ontology/gutbrain/resource/mention/")
GUTBRAINSENTENCE = Namespace("https://w3id.org/hereditary/ontology/gutbrain/resource/sentence/")
GUTBRAINABSTRACT = Namespace("https://w3id.org/hereditary/ontology/gutbrain/resource/abstract/")
GUTBRAINTITLE = Namespace("https://w3id.org/hereditary/ontology/gutbrain/resource/title/")
GUTBRAINPAPER = Namespace("https://w3id.org/hereditary/ontology/gutbrain/resource/paper/")

PAPER_CLASS       = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Paper")
MENTION_CLASS     = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Mention")
PAPER_ABSTRACT    = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/PaperAbstract")
PAPER_TITLE       = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/PaperTitle")
PAPER_COLLECTION  = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/PaperCollection")
PROJECT           = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Project")
SAMPLE            = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Sample")
SENTENCE          = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Sentence")

# -----------------------------------------------------------------------------
# 2. Load the JSON paper data
# -----------------------------------------------------------------------------
with open(json_file, "r", encoding="utf-8") as f:
    data = json.load(f)

with open(gold_file, "r", encoding="utf-8") as f:
    data_gold = json.load(f)

with open(dev_file, "r", encoding="utf-8") as f:
    data_dev = json.load(f)
# -----------------------------------------------------------------------------
# 3. Mapping dictionaries (keys must be in Title case)
# -----------------------------------------------------------------------------
label_mapping = {
    "Anatomical Location":   URIRef("https://w3id.org/brainteaser/ontology/schema/AnatomicalSite"),
    "Animal":                URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Animal"),
    "Biomedical Technique":  URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/BiomedicalTechnique"),
    "Bacteria":              URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Species"),
    "Chemical":              URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Chemical"),
    "Dietary Supplement":    URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/DietarySupplement"),
    "DDF":                   URIRef("https://w3id.org/brainteaser/ontology/schema/DiseaseDisorderOrFinding"),
    "Drug":                  URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Drug"),
    "Food":                  URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Food"),
    "Gene":                  URIRef("https://w3id.org/brainteaser/ontology/schema/Gene"),
    "Human":                 URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Human"),
    "Microbiome":            URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Microbiome"),
    "Statistical Technique": URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/StatisticalTechnique")
}
concept_scheme_mapping = {
    "Anatomical Location":   URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/AnatomicSite"),
    "Animal":                URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Animal"),
    "Human":                 URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Human"),
    "Drug":                  URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Drug"),
    "Gene":                  URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Gene"),
    "Dietary Supplement":    URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/DietarySupplement"),
    "DDF":                   URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/DiseaseDisorderOrFinding"),
    "Metabolite":            URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Metabolite"),
    "Bacteria":               URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Bacteria"),
    "Food":                  URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Food"),
    "Chemical":              URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Chemical"),
    "Biomedical Technique":  URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/BiomedicalTechnique"),
    "Microbiome":            URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Microbiome"),
    "Statistical Technique": URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/StatisticalTechnique")
}
tokenized_mentions = {}

BACTERIA_CLASS = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Species")
FAMILY_CLASS = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Family")
OBO_BASE = "http://purl.obolibrary.org/obo/"
MESH_BASE = "https://www.ncbi.nlm.nih.gov/mesh/"
BACTERIA_CONCEPT_SCHEME = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Bacteria")

g = Graph()
g.bind("gutbrain", GUTBRAIN)
g.bind("rdfs", RDFS)
g.bind("xsd", XSD)
g.bind("skos", SKOS)
g.bind("owl", OWL)
g.bind("gutprop", GUTPROP)

# %%
from funcutils import get_ncit_description, get_chebi_description, get_omit_description, get_foodon_description, NCBI_BASE, HEREDITARY_BASE, UMLS_BASES, foodon_file, ncit_file, omit_file, chebi_file, hash_term_sha256
from groqutils import get_llm_definition
from umlsutils import get_umls_definition

g.add((SKOS.inScheme, RDF.type, OWL.ObjectProperty))
g.add((SKOS.broaderTransitive, RDF.type, OWL.ObjectProperty))

g.add((GUTPROP.partOf, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.partOf, RDFS.label, Literal("partOf", datatype=XSD.string)))
g.add((GUTPROP.hasTitle, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.hasTitle, RDFS.label, Literal("hasTitle", datatype=XSD.string)))
g.add((GUTPROP.hasAbstract, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.hasAbstract, RDFS.label, Literal("hasAbstract", datatype=XSD.string)))

g.add((GUTPROP.containedIn, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.containedIn, RDFS.label, Literal("containedIn", datatype=XSD.string)))
g.add((GUTBRAIN.contains, RDF.type, OWL.ObjectProperty))
g.add((GUTBRAIN.contains, RDFS.label, Literal("contains", datatype=XSD.string)))
g.add((GUTPROP.composedOf, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.composedOf, RDFS.label, Literal("composedOf", datatype=XSD.string)))

g.add((GUTPROP.locatedIn, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.locatedIn, RDFS.label, Literal("locatedIn", datatype=XSD.string)))

g.add((GUTPROP.paperId, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.paperId, RDFS.label, Literal("paperId", datatype=XSD.string)))
g.add((GUTPROP.paperAnnotator, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.paperAnnotator, RDFS.label, Literal("paperAnnotator", datatype=XSD.string)))
g.add((GUTPROP.paperYear, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.paperYear, RDFS.label, Literal("paperYear", datatype=XSD.string)))
g.add((GUTPROP.paperJournal, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.paperJournal, RDFS.label, Literal("paperJournal", datatype=XSD.string)))
g.add((GUTPROP.paperAuthor, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.paperAuthor, RDFS.label, Literal("paperAuthor", datatype=XSD.string)))
g.add((GUTPROP.numberOfRunsFound, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.numberOfRunsFound, RDFS.label, Literal("numberOfRunsFound", datatype=XSD.string)))
g.add((GUTPROP.NCBITaxonID, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.NCBITaxonID, RDFS.label, Literal("NCBITaxonID", datatype=XSD.string)))
g.add((GUTPROP.sdRelativeAbundance, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.sdRelativeAbundance, RDFS.label, Literal("sdRelativeAbundance", datatype=XSD.string)))
g.add((GUTPROP.medianRelativeAbundance, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.medianRelativeAbundance, RDFS.label, Literal("medianRelativeAbundance", datatype=XSD.string)))
g.add((GUTPROP.meanRelativeAbundance, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.meanRelativeAbundance, RDFS.label, Literal("meanRelativeAbundance", datatype=XSD.string)))
g.add((GUTPROP.scientificName, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.scientificName, RDFS.label, Literal("scientificName", datatype=XSD.string)))
g.add((GUTPROP.hasMentionText, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.hasMentionText, RDFS.label, Literal("hasMentionText", datatype=XSD.string)))
g.add((GUTPROP.hasSentenceText, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.hasSentenceText, RDFS.label, Literal("hasSentenceText", datatype=XSD.string)))
g.add((GUTPROP.hasTitleText, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.hasTitleText, RDFS.label, Literal("hasTitleText", datatype=XSD.string)))
g.add((GUTPROP.hasAbstractText, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.hasAbstractText, RDFS.label, Literal("hasAbstractText", datatype=XSD.string)))
g.add((GUTPROP.taggedAs, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.taggedAs, RDFS.label, Literal("taggedAs", datatype=XSD.string)))

for scheme_uri in set(concept_scheme_mapping.values()):
    keys = [k for k, v in concept_scheme_mapping.items() if v == scheme_uri]
    label_text = ", ".join(k.title() for k in keys) + " Concept Scheme"
    g.add((scheme_uri, RDF.type, SKOS.ConceptScheme))
    g.add((scheme_uri, RDFS.label, Literal(label_text, datatype=XSD.string)))

is_train_platinum = "train_platinum" in os.path.basename(json_file)
is_train_gold = "train_gold" in os.path.basename(gold_file)
is_dev = "dev" in os.path.basename(dev_file)

if is_train_gold:
    gold_collection_uri = URIRef(GUTBRAIN["goldCollection"])
    label_text = "goldCollection"
    g.add((gold_collection_uri, RDF.type, PAPER_COLLECTION))
    g.add((gold_collection_uri, RDFS.label, Literal(label_text, datatype=XSD.string)))
    
if is_train_platinum:
    platinum_collection_uri = URIRef(GUTBRAIN["platinumCollection"])
    label_text = "platinumCollection"
    g.add((platinum_collection_uri, RDF.type, PAPER_COLLECTION))
    g.add((platinum_collection_uri, RDFS.label, Literal(label_text, datatype=XSD.string)))

if is_dev:
    dev_collection_uri = URIRef(GUTBRAIN["devCollection"])
    label_text = "devCollection"
    g.add((dev_collection_uri, RDF.type, PAPER_COLLECTION))
    g.add((dev_collection_uri, RDFS.label, Literal(label_text, datatype=XSD.string)))

def create_uri_fragment(text):
    cleaned = re.sub(r'<[^>]*>', '', text)
    cleaned = normalize_text(cleaned)
    cleaned = re.sub(r'[^\w\u0370-\u03FF-]', '_', cleaned)
    return cleaned

def to_camel_case(s):
    s = re.sub(r'[^\w\s]', '', s)
    parts = re.split(r'\s+', s.strip())
    if not parts:
        return ""
    return parts[0].lower() + ''.join(word.title() for word in parts[1:])

def normalize_text(text):
    return unicodedata.normalize('NFC', text)

def normalize_to_ascii(s: str) -> str:
    nfkd = unicodedata.normalize('NFKD', s)
    ascii_bytes = nfkd.encode('ascii', 'ignore')
    return ascii_bytes.decode('ascii')

def singularize(term):
    if term.endswith("ies"):
        return term[:-3] + "y"
    elif term.endswith("s") and not term.endswith("ss"):
        return term[:-1]
    return term

def choose_definition(uri_str: str, term_raw: str) -> str:
    # 1) NCIT
    raw_ncit = None
    if uri_str.startswith(NCBI_BASE) and "NCIT_" in uri_str:
        ncit_id = uri_str.rsplit("/",1)[-1].split("_",1)[1]
        try:
            raw_ncit = get_ncit_description(ncit_id, ncit_file)
        except KeyError:
            pass

    # 2) ChEBI
    raw_chebi = None
    if not raw_ncit:
        try:
            raw_chebi = get_chebi_description(uri_str, chebi_file)
        except KeyError:
            pass

    # 3) OMIT
    raw_omit = None
    if not raw_ncit and not raw_chebi:
        try:
            raw_omit = get_omit_description(uri_str, omit_file)
        except KeyError:
            pass

    # 4) FOODON
    raw_foodon = None
    if not raw_ncit and not raw_chebi and not raw_omit:
        try:
            raw_foodon = get_foodon_description(uri_str, foodon_file)
        except KeyError:
            pass

    # 5) MeSH
    raw_mesh = None
    if not raw_ncit and not raw_chebi and not raw_omit and not raw_foodon:
        raw_mesh = get_mesh_description(uri_str, mesh_definitions)

    # 6) LLM fallback
    if raw_ncit:
        m = re.search(r'—\s*(.*?)\s*—', raw_ncit)
        text = m.group(1).strip() if m else raw_ncit.strip()
        return f"{text} [Definition Source: NCIT]"
    elif raw_chebi:
        return f"{raw_chebi.strip()} [Definition Source: ChEBI]"
    elif raw_omit:
        return f"{raw_omit.strip()} [Definition Source: OMIT]"
    elif raw_foodon:
        return f"{raw_foodon.strip()} [Definition Source: FOODON]"
    elif raw_mesh:
        return f"{raw_mesh.strip()} [Definition Source: MeSH]"
    else:
        llm_def = get_llm_definition(term_raw)
        return f"{llm_def} [Definition Source: llama3-8b-8192]"

manual_created = {}
created = {}

manual_created = {
    "family_ruminococcaceae": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C2584567"),
    "methanobrevibacter": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0995874"),
    "rikenellaceae" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1080664"),
    "firmicutes": URIRef("https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes"),
    "toxoplasma_gondii" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0040557"),
    "microorganism": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0445623"),
    "psychobiotics": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/species/Psychobiotics"),
    "probiotics": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0525033"),
    "mucus-associated_species": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/species/Mucus-AssociatedSpecies"),
    "short-chain_fatty_acid_producing_bacteria": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/species/Short-ChainFattyAcidProducingBacteria"),
    "acute_chronic_insomnia-related_signature_bacteria": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/species/AcuteChronicInsomniaRelatedSignatureBacteria"),
    "flavonifractor": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C2959924"),
    "agathobacter_rectalis" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0317478"),
    "coliform_bacteria": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0314760"),
    "bifidobacterium" : URIRef("http://purl.obolibrary.org/obo/NCBITaxon_1678"),
    "lactobacillus" : URIRef("http://purl.obolibrary.org/obo/NCBITaxon_1578"),
    "flavonifractor" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C2959924"),
    "phylum_synergistetes" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C2309303"),
    "leptospiraceae" : URIRef("https://www.ncbi.nlm.nih.gov/mesh/D016953"),
    "prevotella" : URIRef("https://www.ncbi.nlm.nih.gov/mesh/D018720"),
    "clostridium" : URIRef("https://www.ncbi.nlm.nih.gov/mesh/D003013"),
    "ruminococcus" : URIRef("https://www.ncbi.nlm.nih.gov/mesh/D045857"),
    "clostridium_sporogenes": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0315079"),
    "corynebacterium": URIRef("http://purl.obolibrary.org/obo/NCBITaxon_1716"),
    "enterobacteriaceae": URIRef("http://purl.obolibrary.org/obo/NCBITaxon_543"),
    "erwinia_amylovora": URIRef("http://purl.obolibrary.org/obo/NCBITaxon_552"),
    "holdemanella_biformis" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0317519"),
    "mollicutes": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C3179193"),
    "alistipes": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1490417"),
    "class_lentisphaerae": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1495786"),
    "dubosiella": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4473044"),
    "intestinal_microorganism" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/species/IntestinalMicroorganism"),
    "hek293_cells": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C2936239"),
    "opportunistic_pathogen": URIRef("http://purl.obolibrary.org/obo/IDO_0000654"),
    "microorganism": URIRef("http://purl.obolibrary.org/obo/NCIT_C14329"),
    "candida_albicans": URIRef("http://purl.obolibrary.org/obo/OMIT_0003515"),
    "scutellaria_baicalensis": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1025331"),
    "bacterial_mutant": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/species/BacterialMutant"),
    "multidrug-resistant_bacteria":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4076168"),
    "catabacteriaceae": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1902775"),
    "anaerofustis": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1500236"),
    "pathogenic_organism": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0450254"),
  }

created = dict(manual_created)

regex_map = [
    (r"lactobacillus_plantarum_ccfm8661","acinetobacter_plantarum"),
    (r"\bcristensenellaceae\b","catabacteriaceae"),
    (r"\bphylum_firmicute\w*\b","firmicutes"),
    (r"\bproinflammatory_spec\w*\b","bacteria"),
    (r"\bshort-chain_fatty_acid_producing-bacteria\b","short-chain_fatty_acid_producing_bacteria"),
    (r"\bbacterial_symbiont_specw*\b","bacteria"),
    (r"\bharmful_pathogenic_organism\b","pathogenic_organism"),
    (r"turicibacter_spp_","turicibacter"),
    (r"p__copri","prevotella_copri"),
    (r"v__dispar","veillonella_dispar"),
    (r"\bsfb\b","segmented_filamentous_bacteria"),
    (r"\blentisphaerae\b","class_lentisphaerae"),
    (r"\bintestinimona\w*\b","intestinimonas"),
    (r"\bmultiple_b__subtilis_strain\w*\b","bacillus_subtilis_strain_dy"),
    (r"\bcommensal_gut_bacteria\b","bacteria"),
    (r"\bgut_bacterial_population\b","bacteria"),
    (r"\biga-coated_and_-uncoated_bacteria\b","bacteria"),
    (r"\banaerofusti\w*\b","anaerofustis"),
    (r"c__albican\w*\b","candida_albicans"),
    (r"\bcommensal_fungus_candida_albican\w*\b","candida_albicans"),
    (r"\bhek293_cell\w*\b","hek293_cells"),
    (r"\banaerotruncu\w*\b","anaerotruncus"),
    (r"\bgenus_frisingicoccu\w*\b","frisingicoccus"),
    (r"\bscutellaria_baicalensi\w*\b","scutellaria_baicalensis"),
    (r"\bbeneficial_gut_bacteria\b","intestinal_microorganism"),
    (r"\bintestinal_microorganism\w*\b","intestinal_microorganism"),
    (r"\bcandida_albican\w*\b","candida_albicans"),
    (r"\bopportunistic_pathogen\w*\b","opportunistic_pathogen"),
    (r"\bucg005\b","family_ruminococcaceae"),
    (r"\bhost_microorganism","microorganism"),
    (r"\bbacteria_responsible_for_secondary_bile_acid_synthesi\w*\b","bacteria"),
    (r"commensal_and_pathogenic_bacteria", "bacteria"),
    (r"\bhuman_gut_microbe\w*\b","intestinal_microorganism"),
    (r"\bgut_microbe\w*\b","intestinal_microorganism"),
    (r"\bdubosiella_spp_\b","dubosiella"),
    (r"\bantimicrobial_adjuvant_re-sensitising_multidrug-resistant_gram-negative_bacteria\b","uncultured_gram-negative_bacterium"),
    (r"\bfirmicute\w*\b","firmicutes"),
    (r"live_and_inactivated_lactobacillus_plantarum_ccfm8661","acinetobacter_plantarum"),
    (r"live_l__plantarum_ccfm8661","acinetobacter_plantarum"),
    (r"inactivated_l__plantarum_ccfm8661","acinetobacter_plantarum"),
    (r"\bgenus_eubacterium\b","eubacterium"),
    (r"\beubacterium_biforme\b","holdemanella_biformis"),
    (r"\bprevotella_specie\w*\b","prevotella"),
    (r"\be__amylovora_1189\b","erwinia_amylovora"),
    (r"\bhuman_intestinal_bacteroides_spp_\b","bacteroides"),
    (r"anaerostipe","anaerostipes"),
    (r"\bc__sporogene\w*\b","clostridium_sporogenes"),
    (r"\bmultidrug_resistant_bacteria","multidrug-resistant_bacteria"),
    (r"\boral_lactobacillu\w*\b","lactobacillus"),
    (r"\blactococcu\w*\b","lactococcus"),
    (r"\bbacterial_symbiont_specy\b","bacteria"),
    (r"\bcorynebacteria\w*\b","corynebacterium"),
    (r"lactobacillus_reuteri_atg-f4","limosilactobacillus_reuteri"),
    (r"lachnospiraceae_incertae_sedi","leptospiraceae"),
    (r"\bl_plantarum_ccfm8661\b","acinetobacter_plantarum"),
    (r"ruminococcaceae","family_ruminococcaceae"),
    (r"\bl__brevis_p30021\b","lactobacillus_brevis"),
    (r"\bl\b","lactobacillus"),
    (r"\benterobacteriaceae_bacteria\b","enterobacteriaceae"),
    (r"plantarum p-80","acinetobacter_plantarum"),
    (r"bacteroidaceae_and_porphyromonadaceae_families","bacteroidaceae"),
    (r"rikencellaceae","rikenellaceae"),
    (r"biffdobacterium","bifidobacterium"),
    (r"bifidobacterium","bifidobacterium"),
    (r"bacteroidaceae_and_porphyromonadaceae_family","bacteroidaceae"),
    (r"lactobacillus_plantarum_r1012","acinetobacter_plantarum"),
    (r"maternal_vaginal_microbes","bacteria"),
    (r"maternal_vaginal_microbiome","microbacterium"),
    (r"ruminococcaceae_incertae_sedis","family_ruminococcaceae"),
    (r"microorganisms","microorganism"),
    (r"hypnotic_psychobiotic_strain","psychobiotics"),
    (r"psychobiotic_strain","psychobiotics"),
    (r"ps150","limosilactobacillus_fermentum"),
    (r"\bl_fermentum_strain\b","limosilactobacillus_fermentum"),
    (r"gr1009","limosilactobacillus_fermentum"),
    (r"heat-killed_ps150","limosilactobacillus_fermentum"),
    (r"cancer-related_bacteria","bacteria"),
    (r"short-chain_fatty_acid__scfa_-producing_bacteria","short-chain_fatty_acid_producing_bacteria"),
    (r"clostridiuminnocuumgroup","clostridium_innocuum_group"),
    (r"gut_flavonifractor_genus","flavonifractor"),
    (r"gut_christensenellaceae_family","christensenellaceae"),
    (r"ucg009","family_ruminococcaceae"),
    (r"eubacterium_rectale","agathobacter_rectalis"),
    (r"coliform_genera","coliform_bacteria"),
    (r"bifidobacteria", "bifidobacterium"),
    (r"\bscutellaria_baicalensi\w*\b","scutellaria_baicalensis"),
    (r"\bparabacteroide\w*\b","bacteroide"),
    (r"\blactobacillu","lactobacillus"),
    (r"\bbacteroide\w*\b","bacteroide"),
    (r"\bgut_bacteria\b","bacteria"),
    (r"\bbacteroidete\w*\b","bacteroidete"),
    (r"oral_bacteria\b", "bacteria"),
    (r"maternal_vaginal_microbe","microorganism"),
    (r"l__fermentum_strain","limosilactobacillus_fermentum"),
    (r"synergistete","phylum_synergistetes"),
    (r"gut_flavonifractor_genu","flavonifractor"),
    (r"\blactobacillacea\b","lactobacillaceae"),
    (r"\bstreptococcu\w*\b","streptococcus"),
    (r"\bruminococcu\w*\b","ruminococcus"),
    (r"\bec_ruminococcus_torques\b","ruminococcus"),
    (r"\bruminococcus\b","ruminococcus"),
    (r"\bcoprococcu\w*\b", "micrococcus"),
    (r"butyrate-producing_bacteria","butyrate-producing_bacterium"),
    (r"\bclostridium_sp__br31\b", "clostridium"),
    (r"\bmegamona\b","comamonas"),
    (r"\bcoproccu\w*\b","micrococcus"),
    (r"\bf4\b","bacillus_sp._f4-1"),
    (r"\bhaemophilu\w*\b","haemophilus"),
    (r"\bintestinal_bacteria\b","bacteria"),
    (r"\bactinobacteriota\b","actinobacteria"),
    (r"\bacetate-producing_bacteria\b","actinobacteria"),
    (r"\bverrucomicrobia\b","verrucomicrobia_bacterium_b-1-8"),
    (r"\bdrug-sensitive_bacterial_specie\w*\b","bacteria"),
    (r"\bacterial_mutant\w*\b","bacterial_mutant"),
    (r"\bclostridium_sporogene\w*","clostridium_sporogenes"),
    (r"\binflammation-related_bacteria\b","bacteria"),
    (r"\bdrug-sensitive_bacterial_specy\b","bacteria"),
    (r"\bgut_bacterium_c__sporogene\b","clostridium_sporogenes"),
    
]
mesh_descs   = parse_mesh_descriptors(MESH_XML)

for term_raw, uri in manual_created.items():
    uri_str = str(uri)

    # NCIT definitions
    if uri_str.startswith(NCBI_BASE) and "NCIT_" in uri_str:
        ncit_id = uri_str.rsplit("_", 1)[-1]
        desc = get_ncit_description(ncit_id, ncit_file)
        m = re.search(r'—\s*(.*?)\s*—', desc)
        if m:
            desc = m.group(1).strip()
            comment = f"{desc} [Definition Source: NCIT]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # UMLS definitions
    elif uri_str.startswith(UMLS_BASES):
        cui = uri_str.rsplit("/", 1)[-1]
        defn = get_umls_definition(cui)
        if defn:
            comment = f"{defn.strip()} [Definition Source: UMLS]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # MeSH definitions via your mesh_index
    elif uri_str.startswith(MESH_BASE):
        ui     = uri_str.rsplit("/",1)[-1]
        hits   = [d['name'] for d in mesh_descs if d['ui']==ui]
        if hits:
            comment = f"{hits[0]} [Definition Source: MeSH]"
        elif term_raw == "patients":
            comment = "Patients with various diseases. [Definition Source: GUTBRAIN]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    elif uri_str.startswith(HEREDITARY_BASE):
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"
    else:
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    g.add((uri,
           RDFS.comment,
           Literal(comment, datatype=XSD.string)))
    
CREATOR = "Samuel Piron"

for uri in manual_created.values():
    uri_str = str(uri)

    if uri_str.startswith(UMLS_BASES):
        g.add((uri,
               RDFS.comment,
               Literal("UMLS Match", datatype=XSD.string)))
    elif "NCIT" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("NCIT Match", datatype=XSD.string)))
    elif "OMIT" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("OMIT Match", datatype=XSD.string)))
    elif "NCBITaxon" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("NCBITaxon Match", datatype=XSD.string)))
    elif "CHEBI" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("CHEBI Match", datatype=XSD.string)))
    elif "GO" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("GO Match", datatype=XSD.string)))
    elif "genome" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("KEGG Match", datatype=XSD.string)))
    elif "mesh" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("MESH Match", datatype=XSD.string)))
    elif "PCO" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("PCO Match", datatype=XSD.string)))
    else:
        g.add((uri,
               DCTERMS.creator,
               Literal(CREATOR, datatype=XSD.string)))

created["bacteria"] = URIRef(f"{OBO_BASE}NCBITaxon_2")
g.add((created["bacteria"], RDF.type, FAMILY_CLASS))
g.add((created["bacteria"], RDF.type, SKOS.Concept))
g.add((created["bacteria"], RDFS.label, Literal("Bacteria", datatype=XSD.string)))
g.add((created["bacteria"], SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))

# -----------------------------------------------------------------------------
# 5. Process each paper (each key in the JSON represents a paper)
# -----------------------------------------------------------------------------
for paper_id, paper_data in data.items():
    paper_uri = URIRef(GUTBRAINPAPER[f"{paper_id}"])
    g.add((paper_uri, RDFS.label, Literal(f"paper_{paper_id}", datatype=XSD.string)))
    g.add((paper_uri, RDF.type, PAPER_CLASS))
    
    if is_train_platinum:
        g.add((paper_uri, GUTPROP.partOf, platinum_collection_uri))
        g.add((platinum_collection_uri, GUTBRAIN.contains, paper_uri))
    
    metadata = paper_data.get("metadata", {})
    full_title = metadata.get("title", None)
    full_abstract = metadata.get("abstract", None)
    try:
        paper_id_val = int(paper_id)
    except ValueError:
        paper_id_val = paper_id
    paper_annotator = metadata.get("annotator", None)
    paper_year = metadata.get("year", None)
    paper_journal = metadata.get("journal", None)
    paper_author = metadata.get("author", None)
    
    g.add((paper_uri, GUTPROP.paperId, Literal(paper_id_val, datatype=XSD.integer)))
    if paper_annotator is not None:
        g.add((paper_uri, GUTPROP.paperAnnotator, Literal(paper_annotator, datatype=XSD.string)))
    if paper_year is not None:
        g.add((paper_uri, GUTPROP.paperYear, Literal(paper_year, datatype=XSD.gYear)))
    if paper_journal is not None:
        g.add((paper_uri, GUTPROP.paperJournal, Literal(paper_journal, datatype=XSD.string)))
    if paper_author is not None:
        g.add((paper_uri, GUTPROP.paperAuthor, Literal(paper_author, datatype=XSD.string)))
    
    title_texts = []
    abstract_texts = []
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        label_title = raw_label
        
        if label_title == "bacteria":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                g.add((entity_uri, SKOS.broaderTransitive, created["bacteria"]))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                g.add((entity_uri, SKOS.broaderTransitive, created["bacteria"]))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue
                
            hits = genus_abbrev_lookup(term)
            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            if hits:
                for l,t,d,s in hits: 
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f} (abbr)")
                    entity_uri = URIRef(f"{OBO_BASE}{t}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(l.title(), datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                    g.add((entity_uri, SKOS.broaderTransitive, created["bacteria"]))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "mesh" in uri_str:
                        comment = "MESH Match"
                    elif "ncbitaxon" in uri_str:
                        comment = "NCBITaxon Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    continue

            elif ex:
                for label_name, taxon_id, depth in ex:
                    print(f"  • {label_name:40s} ID={taxon_id:15s} depth={depth:<2d} (exact)")
                    entity_uri = URIRef(f"{OBO_BASE}{taxon_id}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(label_name.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                    g.add((entity_uri, SKOS.broaderTransitive, created["bacteria"]))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "mesh" in uri_str:
                        comment = "MESH Match"
                    elif "ncbitaxon" in uri_str:
                        comment = "NCBITaxon Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for l,t,d,s in cos[:1]:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f}")
                    name_uri = URIRef(f"{OBO_BASE}{t}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, BACTERIA_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(l.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                    g.add((name_uri, SKOS.broaderTransitive, created["bacteria"]))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "mesh" in uri_str:
                        comment = "MESH Match"
                    elif "ncbitaxon" in uri_str:
                        comment = "NCBITaxon Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
            elif term_raw not in created: 
                matches = find_mesh_match(term, name_index)
                if matches: 
                    for name, ui, tree, score in matches[:1]: 
                        print(f"  • {name:30s} UI={ui:8s} Tree={tree:12s}  scoreMESH={score:.2f}")
                        name_uri = URIRef(f"{MESH_BASE}{ui}")
                        created[term_raw] = name_uri
                        g.add((name_uri, RDF.type, BACTERIA_CLASS))
                        g.add((name_uri, RDF.type, SKOS.Concept))
                        if (name_uri, RDFS.label, None) not in g:
                            g.add((name_uri,
                            RDFS.label,
                            Literal(name.title(), datatype=XSD.string)))
                        g.add((name_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                        g.add((name_uri, SKOS.broaderTransitive, created["bacteria"]))
                        uri_str = str(name_uri).lower()

                        if "stato_" in uri_str:
                            comment = "STATO Match"
                        elif "ncbitaxon_" in uri_str:
                            comment = "NCBITaxon Match"
                        elif "obi_" in uri_str:
                            comment = "OBI Match"
                        elif "umls" in uri_str:
                            comment = "UMLS Match"
                        elif "mesh" in uri_str:
                            comment = "MESH Match"
                        elif "ncbitaxon" in uri_str:
                            comment = "NCBITaxon Match"
                        else:
                            comment = CREATOR 
                        g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                        uri_str = str(name_uri)
                        definition = choose_definition(uri_str, term_raw)
                        existing_defs = [
                            c for c in g.objects(name_uri, RDFS.comment)
                            if "[Definition Source:" in str(c)
                        ]
                        if not existing_defs:
                            g.add((name_uri,
                                RDFS.comment,
                                Literal(definition, datatype=XSD.string)))
                        mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                        g.add((mention_uri, RDF.type, MENTION_CLASS))
                        g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                        g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                        g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title, datatype=XSD.string)))
                        g.add((name_uri, GUTPROP.containedIn, mention_uri))
                        tokenized_mentions[term_raw] = mention_uri
                        continue
                else:
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title, datatype=XSD.string)))
                    g.add((created["bacteria"], GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print("no match")
                    continue
        else:
            pass

    g.remove((created["bacteria"], RDF.type, BACTERIA_CLASS))
    
    location_lower = entity.get("location", "").strip().lower()
    text_span = entity.get("text_span", "").strip()
    canonical = create_uri_fragment(text_span)
    cleaned_text_span = normalize_to_ascii(canonical)
    if location_lower == "title":
        title_texts.append(cleaned_text_span)
    elif location_lower == "abstract":
        abstract_texts.append(cleaned_text_span)
    
    if full_title is None and title_texts:
        full_title = " ".join(title_texts)
    if full_abstract is None and abstract_texts:
        full_abstract = " ".join(abstract_texts)
    
    if full_title:
        title_uri = URIRef(GUTBRAINTITLE[f"{paper_id}"])
        g.add((title_uri, RDFS.label, Literal(f"title_{paper_id}", datatype=XSD.string)))
        g.add((title_uri, RDF.type, PAPER_TITLE))
        g.add((title_uri, GUTPROP.hasTitleText, Literal(full_title, datatype=XSD.string)))
        g.add((paper_uri, GUTPROP.hasTitle, title_uri))
    
    if full_abstract:
        abstract_uri = URIRef(GUTBRAINABSTRACT[f"{paper_id}"])
        g.add((abstract_uri, RDFS.label, Literal(f"abstract_{paper_id}", datatype=XSD.string)))
        g.add((abstract_uri, RDF.type, PAPER_ABSTRACT))
        g.add((abstract_uri, GUTPROP.hasAbstractText, Literal(full_abstract, datatype=XSD.string)))
        g.add((paper_uri, GUTPROP.hasAbstract, abstract_uri))

print("entering in data gold")

for paper_id, paper_data in data_gold.items():
    paper_uri = URIRef(GUTBRAINPAPER[f"{paper_id}"])
    g.add((paper_uri, RDFS.label, Literal(f"paper_{paper_id}", datatype=XSD.string)))
    g.add((paper_uri, RDF.type, PAPER_CLASS))
    
    if is_train_gold:
        g.add((paper_uri, GUTPROP.partOf, gold_collection_uri))
        g.add((gold_collection_uri, GUTBRAIN.contains, paper_uri))
    
    metadata = paper_data.get("metadata", {})
    full_title = metadata.get("title", None)
    full_abstract = metadata.get("abstract", None)
    try:
        paper_id_val = int(paper_id)
    except ValueError:
        paper_id_val = paper_id
    paper_annotator = metadata.get("annotator", None)
    paper_year = metadata.get("year", None)
    paper_journal = metadata.get("journal", None)
    paper_author = metadata.get("author", None)
    
    g.add((paper_uri, GUTPROP.paperId, Literal(paper_id_val, datatype=XSD.integer)))
    if paper_annotator is not None:
        g.add((paper_uri, GUTPROP.paperAnnotator, Literal(paper_annotator, datatype=XSD.string)))
    if paper_year is not None:
        g.add((paper_uri, GUTPROP.paperYear, Literal(paper_year, datatype=XSD.gYear)))
    if paper_journal is not None:
        g.add((paper_uri, GUTPROP.paperJournal, Literal(paper_journal, datatype=XSD.string)))
    if paper_author is not None:
        g.add((paper_uri, GUTPROP.paperAuthor, Literal(paper_author, datatype=XSD.string)))
    
    title_texts = []
    abstract_texts = []
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        label_title = raw_label
        
        if label_title == "bacteria":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                g.add((entity_uri, SKOS.broaderTransitive, created["bacteria"]))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                g.add((entity_uri, SKOS.broaderTransitive, created["bacteria"]))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue
                
            hits = genus_abbrev_lookup(term)
            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            if hits:
                for l,t,d,s in hits: 
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f} (abbr)")
                    entity_uri = URIRef(f"{OBO_BASE}{t}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(l.title(), datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                    g.add((entity_uri, SKOS.broaderTransitive, created["bacteria"]))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "mesh" in uri_str:
                        comment = "MESH Match"
                    elif "ncbitaxon" in uri_str:
                        comment = "NCBITaxon Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    continue

            elif ex:
                for label_name, taxon_id, depth in ex:
                    print(f"  • {label_name:40s} ID={taxon_id:15s} depth={depth:<2d} (exact)")
                    entity_uri = URIRef(f"{OBO_BASE}{taxon_id}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(label_name.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                    g.add((entity_uri, SKOS.broaderTransitive, created["bacteria"]))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "mesh" in uri_str:
                        comment = "MESH Match"
                    elif "ncbitaxon" in uri_str:
                        comment = "NCBITaxon Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for l,t,d,s in cos[:1]:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f}")
                    name_uri = URIRef(f"{OBO_BASE}{t}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, BACTERIA_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(l.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                    g.add((name_uri, SKOS.broaderTransitive, created["bacteria"]))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "mesh" in uri_str:
                        comment = "MESH Match"
                    elif "ncbitaxon" in uri_str:
                        comment = "NCBITaxon Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
            elif term_raw not in created: 
                matches = find_mesh_match(term, name_index)
                if matches: 
                    for name, ui, tree, score in matches[:1]: 
                        print(f"  • {name:30s} UI={ui:8s} Tree={tree:12s}  scoreMESH={score:.2f}")
                        name_uri = URIRef(f"{MESH_BASE}{ui}")
                        created[term_raw] = name_uri
                        g.add((name_uri, RDF.type, BACTERIA_CLASS))
                        g.add((name_uri, RDF.type, SKOS.Concept))
                        if (name_uri, RDFS.label, None) not in g:
                            g.add((name_uri,
                            RDFS.label,
                            Literal(name.title(), datatype=XSD.string)))
                        g.add((name_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                        g.add((name_uri, SKOS.broaderTransitive, created["bacteria"]))
                        uri_str = str(name_uri).lower()

                        if "stato_" in uri_str:
                            comment = "STATO Match"
                        elif "ncbitaxon_" in uri_str:
                            comment = "NCBITaxon Match"
                        elif "obi_" in uri_str:
                            comment = "OBI Match"
                        elif "umls" in uri_str:
                            comment = "UMLS Match"
                        elif "mesh" in uri_str:
                            comment = "MESH Match"
                        elif "ncbitaxon" in uri_str:
                            comment = "NCBITaxon Match"
                        else:
                            comment = CREATOR 
                        g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                        uri_str = str(name_uri)
                        definition = choose_definition(uri_str, term_raw)
                        existing_defs = [
                            c for c in g.objects(name_uri, RDFS.comment)
                            if "[Definition Source:" in str(c)
                        ]
                        if not existing_defs:
                            g.add((name_uri,
                                RDFS.comment,
                                Literal(definition, datatype=XSD.string)))
                        mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                        g.add((mention_uri, RDF.type, MENTION_CLASS))
                        g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                        g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                        g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title, datatype=XSD.string)))
                        g.add((name_uri, GUTPROP.containedIn, mention_uri))
                        tokenized_mentions[term_raw] = mention_uri
                        continue
                else:
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title, datatype=XSD.string)))
                    g.add((created["bacteria"], GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print("no match")
                    continue
        else:
            pass
    
    

    g.remove((created["bacteria"], RDF.type, BACTERIA_CLASS))
    
    location_lower = entity.get("location", "").strip().lower()
    text_span = entity.get("text_span", "").strip()
    canonical = create_uri_fragment(text_span)
    cleaned_text_span = normalize_to_ascii(canonical)
    if location_lower == "title":
        title_texts.append(cleaned_text_span)
    elif location_lower == "abstract":
        abstract_texts.append(cleaned_text_span)
    
    if full_title is None and title_texts:
        full_title = " ".join(title_texts)
    if full_abstract is None and abstract_texts:
        full_abstract = " ".join(abstract_texts)
    
    if full_title:
        title_uri = URIRef(GUTBRAINTITLE[f"{paper_id}"])
        g.add((title_uri, RDFS.label, Literal(f"title_{paper_id}", datatype=XSD.string)))
        g.add((title_uri, RDF.type, PAPER_TITLE))
        g.add((title_uri, GUTPROP.hasTitleText, Literal(full_title, datatype=XSD.string)))
        g.add((paper_uri, GUTPROP.hasTitle, title_uri))
    
    if full_abstract:
        abstract_uri = URIRef(GUTBRAINABSTRACT[f"{paper_id}"])
        g.add((abstract_uri, RDFS.label, Literal(f"abstract_{paper_id}", datatype=XSD.string)))
        g.add((abstract_uri, RDF.type, PAPER_ABSTRACT))
        g.add((abstract_uri, GUTPROP.hasAbstractText, Literal(full_abstract, datatype=XSD.string)))
        g.add((paper_uri, GUTPROP.hasAbstract, abstract_uri))

print("entering dev collection")

for paper_id, paper_data in data_dev.items():
    paper_uri = URIRef(GUTBRAINPAPER[f"{paper_id}"])
    g.add((paper_uri, RDFS.label, Literal(f"paper_{paper_id}", datatype=XSD.string)))
    g.add((paper_uri, RDF.type, PAPER_CLASS))
    
    if is_dev:
        g.add((paper_uri, GUTPROP.partOf, dev_collection_uri))
        g.add((dev_collection_uri, GUTBRAIN.contains, paper_uri))
    
    metadata = paper_data.get("metadata", {})
    full_title = metadata.get("title", None)
    full_abstract = metadata.get("abstract", None)
    try:
        paper_id_val = int(paper_id)
    except ValueError:
        paper_id_val = paper_id
    paper_annotator = metadata.get("annotator", None)
    paper_year = metadata.get("year", None)
    paper_journal = metadata.get("journal", None)
    paper_author = metadata.get("author", None)
    
    g.add((paper_uri, GUTPROP.paperId, Literal(paper_id_val, datatype=XSD.integer)))
    if paper_annotator is not None:
        g.add((paper_uri, GUTPROP.paperAnnotator, Literal(paper_annotator, datatype=XSD.string)))
    if paper_year is not None:
        g.add((paper_uri, GUTPROP.paperYear, Literal(paper_year, datatype=XSD.gYear)))
    if paper_journal is not None:
        g.add((paper_uri, GUTPROP.paperJournal, Literal(paper_journal, datatype=XSD.string)))
    if paper_author is not None:
        g.add((paper_uri, GUTPROP.paperAuthor, Literal(paper_author, datatype=XSD.string)))
    
    title_texts = []
    abstract_texts = []
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        label_title = raw_label
        
        if label_title == "bacteria":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                g.add((entity_uri, SKOS.broaderTransitive, created["bacteria"]))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                g.add((entity_uri, SKOS.broaderTransitive, created["bacteria"]))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue
                
            hits = genus_abbrev_lookup(term)
            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            if hits:
                for l,t,d,s in hits: 
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f} (abbr)")
                    entity_uri = URIRef(f"{OBO_BASE}{t}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(l.title(), datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                    g.add((entity_uri, SKOS.broaderTransitive, created["bacteria"]))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "mesh" in uri_str:
                        comment = "MESH Match"
                    elif "ncbitaxon" in uri_str:
                        comment = "NCBITaxon Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    continue

            elif ex:
                for label_name, taxon_id, depth in ex:
                    print(f"  • {label_name:40s} ID={taxon_id:15s} depth={depth:<2d} (exact)")
                    entity_uri = URIRef(f"{OBO_BASE}{taxon_id}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(label_name.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                    g.add((entity_uri, SKOS.broaderTransitive, created["bacteria"]))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "mesh" in uri_str:
                        comment = "MESH Match"
                    elif "ncbitaxon" in uri_str:
                        comment = "NCBITaxon Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for l,t,d,s in cos[:1]:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f}")
                    name_uri = URIRef(f"{OBO_BASE}{t}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, BACTERIA_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(l.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                    g.add((name_uri, SKOS.broaderTransitive, created["bacteria"]))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "mesh" in uri_str:
                        comment = "MESH Match"
                    elif "ncbitaxon" in uri_str:
                        comment = "NCBITaxon Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
            elif term_raw not in created: 
                matches = find_mesh_match(term, name_index)
                if matches: 
                    for name, ui, tree, score in matches[:1]: 
                        print(f"  • {name:30s} UI={ui:8s} Tree={tree:12s}  scoreMESH={score:.2f}")
                        name_uri = URIRef(f"{MESH_BASE}{ui}")
                        created[term_raw] = name_uri
                        g.add((name_uri, RDF.type, BACTERIA_CLASS))
                        g.add((name_uri, RDF.type, SKOS.Concept))
                        if (name_uri, RDFS.label, None) not in g:
                            g.add((name_uri,
                            RDFS.label,
                            Literal(name.title(), datatype=XSD.string)))
                        g.add((name_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                        g.add((name_uri, SKOS.broaderTransitive, created["bacteria"]))
                        uri_str = str(name_uri).lower()

                        if "stato_" in uri_str:
                            comment = "STATO Match"
                        elif "ncbitaxon_" in uri_str:
                            comment = "NCBITaxon Match"
                        elif "obi_" in uri_str:
                            comment = "OBI Match"
                        elif "umls" in uri_str:
                            comment = "UMLS Match"
                        elif "mesh" in uri_str:
                            comment = "MESH Match"
                        elif "ncbitaxon" in uri_str:
                            comment = "NCBITaxon Match"
                        else:
                            comment = CREATOR 
                        g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                        uri_str = str(name_uri)
                        definition = choose_definition(uri_str, term_raw)
                        existing_defs = [
                            c for c in g.objects(name_uri, RDFS.comment)
                            if "[Definition Source:" in str(c)
                        ]
                        if not existing_defs:
                            g.add((name_uri,
                                RDFS.comment,
                                Literal(definition, datatype=XSD.string)))
                        mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                        g.add((mention_uri, RDF.type, MENTION_CLASS))
                        g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                        g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                        g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title, datatype=XSD.string)))
                        g.add((name_uri, GUTPROP.containedIn, mention_uri))
                        tokenized_mentions[term_raw] = mention_uri
                        continue
                else:
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title, datatype=XSD.string)))
                    g.add((created["bacteria"], GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print("no match")
                    continue
        else:
            pass
    
    

    g.remove((created["bacteria"], RDF.type, BACTERIA_CLASS))
    
    location_lower = entity.get("location", "").strip().lower()
    text_span = entity.get("text_span", "").strip()
    canonical = create_uri_fragment(text_span)
    cleaned_text_span = normalize_to_ascii(canonical)
    if location_lower == "title":
        title_texts.append(cleaned_text_span)
    elif location_lower == "abstract":
        abstract_texts.append(cleaned_text_span)
    
    if full_title is None and title_texts:
        full_title = " ".join(title_texts)
    if full_abstract is None and abstract_texts:
        full_abstract = " ".join(abstract_texts)
    
    if full_title:
        title_uri = URIRef(GUTBRAINTITLE[f"{paper_id}"])
        g.add((title_uri, RDFS.label, Literal(f"title_{paper_id}", datatype=XSD.string)))
        g.add((title_uri, RDF.type, PAPER_TITLE))
        g.add((title_uri, GUTPROP.hasTitleText, Literal(full_title, datatype=XSD.string)))
        g.add((paper_uri, GUTPROP.hasTitle, title_uri))
    
    if full_abstract:
        abstract_uri = URIRef(GUTBRAINABSTRACT[f"{paper_id}"])
        g.add((abstract_uri, RDFS.label, Literal(f"abstract_{paper_id}", datatype=XSD.string)))
        g.add((abstract_uri, RDF.type, PAPER_ABSTRACT))
        g.add((abstract_uri, GUTPROP.hasAbstractText, Literal(full_abstract, datatype=XSD.string)))
        g.add((paper_uri, GUTPROP.hasAbstract, abstract_uri))


with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "bacteria":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_gold_file, "r", encoding="utf-8") as f_sent:
    tokenized_gold_data = json.load(f_sent)

for entry in tokenized_gold_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "bacteria":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_dev, "r", encoding="utf-8") as f_sent:
    tokenized_dev_data = json.load(f_sent)

for entry in tokenized_dev_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "bacteria":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

output_file = os.path.join(save_path, "gutbrain_entities.ttl")
ttl_output = g.serialize(format="turtle")
with open(output_file, "w", encoding="utf-8") as f_out:
    f_out.write(ttl_output)

print(f"The RDF graph has been saved in {output_file}")
# Out:
# Query: veillonella
# lookup term: veillonella
#   • Veillonella                              ID=NCBITaxon_29465 depth=12 (exact)
# Query: roseburia
# lookup term: roseburia
#   • Roseburia                                ID=NCBITaxon_841   depth=12 (exact)
# Query: christensenellaceae r-7 group
# lookup term: christensenellaceae_r-7_group
#   • Christensenellaceae                      ID=NCBITaxon_990719 depth=10 score=0.87
# Query: subdoligranulum
# lookup term: subdoligranulum
#   • Subdoligranulum                          ID=NCBITaxon_292632 depth=12 (exact)
# Query: oscillibacter
# lookup term: oscillibacter
#   • Oscillibacter                            ID=NCBITaxon_459786 depth=12 (exact)
# Query: ucg-005
# lookup term: ucg-005
#   • Ruminococcaceae bacterium UCG-005        ID=NCBITaxon_3068309 depth=14 score=0.87
# actinobacteria
# Query: actinobacteria
# lookup term: actinobacteria
#   • Actinobacteria bacterium HGW-Actinobacteria-9 ID=NCBITaxon_2013654 depth=8  score=0.87
# actinobacteria
# Query: actinobacteria
# lookup term: actinobacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2013654
#
#
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
#
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# acinetobacter_plantarum
# Query: acinetobacter plantarum
# lookup term: acinetobacter_plantarum
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 (exact)
# acinetobacter_plantarum
# Query: acinetobacter plantarum
# lookup term: acinetobacter_plantarum
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 (exact)
# acinetobacter_plantarum
# Query: acinetobacter plantarum
# lookup term: acinetobacter_plantarum
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 (exact)
# acinetobacter_plantarum
# Query: acinetobacter plantarum
# lookup term: acinetobacter_plantarum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
#
# acinetobacter_plantarum
# Query: acinetobacter plantarum
# lookup term: acinetobacter_plantarum
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 (exact)
# acinetobacter_plantarum
# Query: acinetobacter plantarum
# lookup term: acinetobacter_plantarum
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 (exact)
# Query: staphylococcu
# lookup term: staphylococcu
#   • Staphylococcus                 UI=D013210  Tree=B03.300.390.400.800.750  scoreMESH=0.96
# Query: l plantarum ccfm8661
# lookup term: l__plantarum_ccfm8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
# Query: lactobacillaceae
# lookup term: lactobacillaceae
#   • Lactobacillaceae                         ID=NCBITaxon_33958 depth=10 (exact)
# Query: lachnospiraceae
# lookup term: lachnospiraceae
#   • Lachnospiraceae                          ID=NCBITaxon_186803 depth=10 (exact)
# Query: lachnospiraceae
# lookup term: lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_186803
#
#
# family_ruminococcaceae
# Query: family ruminococcaceae
# lookup term: family_ruminococcaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2584567
#
# Query: levilactobacillus brevi
# lookup term: levilactobacillus_brevi
#   • Levilactobacillus brevis       UI=D052196  Tree=B03.353.750.450.639  scoreMESH=0.98
# Query: lactiplantibacillus plantarum
# lookup term: lactiplantibacillus_plantarum
#   • Lactiplantibacillus plantarum            ID=NCBITaxon_1590  depth=14 (exact)
# Query: lacticaseibacillus paracasei
# lookup term: lacticaseibacillus_paracasei
#   • Lacticaseibacillus paracasei             ID=NCBITaxon_1597  depth=14 (exact)
# Query: ligilactobacillus salivariu
# lookup term: ligilactobacillus_salivariu
#   • Ligilactobacillus                        ID=NCBITaxon_2767887 depth=12 score=1.00
# streptococcus
# Query: streptococcus
# lookup term: streptococcus
#   • Streptococcus                            ID=NCBITaxon_1301  depth=12 (exact)
# lactobacillus_brevis
# Query: lactobacillus brevis
# lookup term: lactobacillus_brevis
#   • Levilactobacillus brevis       UI=D052196  Tree=B03.353.750.450.639  scoreMESH=0.91
# Query: l plantarum p30025
# lookup term: l__plantarum_p30025
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
# Query: veillonellaceae
# lookup term: veillonellaceae
#   • Veillonellaceae                          ID=NCBITaxon_31977 depth=10 (exact)
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   • Bacteroides                    UI=D001439  Tree=B03.440.080.094.152  scoreMESH=0.95
# Query: proteobacteria
# lookup term: proteobacteria
#   • Proteobacteria                 UI=D020560  Tree=B03.660       scoreMESH=1.00
# Query: succinivibrio
# lookup term: succinivibrio
#   • Succinivibrio                            ID=NCBITaxon_83770 depth=12 (exact)
# Query: megasphaera
# lookup term: megasphaera
#   • Megasphaera                              ID=NCBITaxon_906   depth=12 (exact)
# Query: collinsella
# lookup term: collinsella
#   • Collinsella                              ID=NCBITaxon_102106 depth=12 (exact)
# Query: clostridium
# lookup term: clostridium
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D003013
#
#
# Query: klebsiella
# lookup term: klebsiella
#   • Klebsiella                               ID=NCBITaxon_570   depth=14 (exact)
# Query: methanobrevibacter
# lookup term: methanobrevibacter
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0995874
#
#
# Query: blautia
# lookup term: blautia
#   • Blautia                                  ID=NCBITaxon_572511 depth=12 (exact)
# micrococcus
# Query: micrococcus
# lookup term: micrococcus
#   • Micrococcus                              ID=NCBITaxon_1269  depth=12 (exact)
# Query: roseburia
# lookup term: roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_841
#
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# Query: plantarum p-8
# lookup term: plantarum_p-8
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: fecalibacterium prausnitzii
# lookup term: fecalibacterium_prausnitzii
#   • Faecalibacterium prausnitzii             ID=NCBITaxon_853   depth=14 score=0.79
# Query: roseburia faeci
# lookup term: roseburia_faeci
#   • Roseburia                                ID=NCBITaxon_841   depth=12 score=1.00
# Query: fusicatenibacter saccharivoran
# lookup term: fusicatenibacter_saccharivoran
#   • Fusicatenibacter                         ID=NCBITaxon_1407607 depth=12 score=1.00
# bacteroidaceae
# Query: bacteroidaceae
# lookup term: bacteroidaceae
#   • Bacteroidaceae                           ID=NCBITaxon_815   depth=14 (exact)
# rikenellaceae
# Query: rikenellaceae
# lookup term: rikenellaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1080664
#
# Query: s24-7
# lookup term: s24-7
#   • bacterium S24                            ID=NCBITaxon_1315627 depth=4  score=0.97
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
#
# lactococcus
# Query: lactococcus
# lookup term: lactococcus
#   • Lactococcus                              ID=NCBITaxon_1357  depth=12 (exact)
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
#
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# acinetobacter_plantarum
# Query: acinetobacter plantarum
# lookup term: acinetobacter_plantarum
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 (exact)
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# Query: escherichia coli
# lookup term: escherichia_coli
#   • Escherichia coli                         ID=NCBITaxon_562   depth=14 (exact)
# Query: enterobacter cloaca
# lookup term: enterobacter_cloacae
#   • Enterobacter                             ID=NCBITaxon_547   depth=12 score=1.00
# microorganism
# Query: microorganism
# lookup term: microorganism
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14329
#
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
#
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
#
# Query: verrucomicrobiaceae
# lookup term: verrucomicrobiaceae
#   • Verrucomicrobiaceae                      ID=NCBITaxon_203557 depth=12 (exact)
# Query: akkermansia
# lookup term: akkermansia
#   • Akkermansia                              ID=NCBITaxon_239934 depth=14 (exact)
# Query: faecalibacterium
# lookup term: faecalibacterium
#   • Faecalibacterium                         ID=NCBITaxon_216851 depth=12 (exact)
# micrococcus
# Query: micrococcus
# lookup term: micrococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1269
#
#
# Query: blautia
# lookup term: blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
#
# Query: prevotella
# lookup term: prevotella
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D018720
#
#
# Query: prevotellaceae
# lookup term: prevotellaceae
#   • Prevotellaceae                           ID=NCBITaxon_171552 depth=14 (exact)
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   • Bacteroides                    UI=D001439  Tree=B03.440.080.094.152  scoreMESH=0.95
# Query: proteobacteria
# lookup term: proteobacteria
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D020560
#
#
# Query: helicobacter pylorus
# lookup term: helicobacter_pylori
#   • Helicobacter                             ID=NCBITaxon_209   depth=12 score=1.00
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# Query: actinobacteria
# lookup term: actinobacteria
#   • Actinobacteria bacterium HGW-Actinobacteria-9 ID=NCBITaxon_2013654 depth=8  score=0.87
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# Query: microbe
# lookup term: microbe
#   • Microbacterium                 UI=D000083822 Tree=B03.510.024.775  scoreMESH=0.67
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# Query: coliform
# lookup term: coliform
#   • coliform bacterium S1/7                  ID=NCBITaxon_464824 depth=4  score=0.78
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# Query: toxoplasma gondii
# lookup term: toxoplasma_gondii
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0040557
#
#
# Query: lachnospiraceae family
# lookup term: lachnospiraceae_family
#   • Leptospiraceae                 UI=D016953  Tree=B03.440.400.425.475  scoreMESH=0.61
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
#
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
#
# Query: akkermansia
# lookup term: akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_239934
#
# Query: desulfovibrio
# lookup term: desulfovibrio
#   • Desulfovibrio                            ID=NCBITaxon_872   depth=12 (exact)
# Query: klebsiella
# lookup term: klebsiella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_570
#
#
# Query: akkermansia
# lookup term: akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_239934
#
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# Query: gaba-producing bacteria
# lookup term: gaba-producing_bacteria
#   • Sulfur-Reducing Bacteria       UI=D016999  Tree=B03.900       scoreMESH=0.72
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# Query: odoribacter
# lookup term: odoribacter
#   • Odoribacter                              ID=NCBITaxon_283168 depth=16 (exact)
# Query: oscillibacter
# lookup term: oscillibacter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_459786
#
#
# Query: blautia
# lookup term: blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
#
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: clostridium
# lookup term: clostridium
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D003013
#
#
# Query: lachnospiraceae nk4a136 group
# lookup term: lachnospiraceae_nk4a136_group
#   • Lachnospiraceae bacterium NK4A136        ID=NCBITaxon_877420 depth=14 score=0.90
# Query: subdoligranulum
# lookup term: subdoligranulum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_292632
#
#
# Query: faecalibacterium prausnitzii
# lookup term: faecalibacterium_prausnitzii
#   • Faecalibacterium prausnitzii             ID=NCBITaxon_853   depth=14 (exact)
# Query: corynebacterium
# lookup term: corynebacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1716
#
#
# family_ruminococcaceae
# Query: family ruminococcaceae
# lookup term: family_ruminococcaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2584567
#
# Query: fusobacterium
# lookup term: fusobacterium
#   • Fusobacterium                            ID=NCBITaxon_848   depth=12 (exact)
# Query: corynebacterium
# lookup term: corynebacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1716
#
#
# family_ruminococcaceae
# Query: family ruminococcaceae
# lookup term: family_ruminococcaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2584567
#
# Query: microorganism
# lookup term: microorganism
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14329
#
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# verrucomicrobia_bacterium_b-1-8
# Query: verrucomicrobia bacterium b-1-8
# lookup term: verrucomicrobia_bacterium_b-1-8
#   • Verrucomicrobia bacterium B-1-8          ID=NCBITaxon_747582 depth=10 (exact)
# Query: mucispirillum
# lookup term: mucispirillum
#   • Mucispirillum                            ID=NCBITaxon_248038 depth=12 (exact)
# Query: porphyromona
# lookup term: porphyromona
#   • Porphyromonas                  UI=D017861  Tree=B03.440.080.094.625  scoreMESH=0.96
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   • Bacteroides                    UI=D001439  Tree=B03.440.080.094.152  scoreMESH=0.95
# Query: prevotella
# lookup term: prevotella
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D018720
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# verrucomicrobia_bacterium_b-1-8
# Query: verrucomicrobia bacterium b-1-8
# lookup term: verrucomicrobia_bacterium_b-1-8
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_747582
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   • Limosilactobacillus fermentum            ID=NCBITaxon_1613  depth=14 (exact)
# psychobiotics
# Query: psychobiotics
# lookup term: psychobiotics
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/species/Psychobiotics
#
# Query: psychobiotic
# lookup term: psychobiotic
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/species/Psychobiotics
#
#
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
#
# psychobiotics
# Query: psychobiotics
# lookup term: psychobiotics
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/species/Psychobiotics
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   • Limosilactobacillus fermentum            ID=NCBITaxon_1613  depth=14 (exact)
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   • Limosilactobacillus fermentum            ID=NCBITaxon_1613  depth=14 (exact)
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   • Limosilactobacillus fermentum            ID=NCBITaxon_1613  depth=14 (exact)
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   • Limosilactobacillus fermentum            ID=NCBITaxon_1613  depth=14 (exact)
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# limosilactobacillus_fermentum
# Query: limosilactobacillus fermentum
# lookup term: limosilactobacillus_fermentum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1613
#
#
# Query: ec ruminococcus torque
# lookup term: ec_ruminococcus_torque
#   • Ruminococcus                   UI=D045857  Tree=B03.353.625.806  scoreMESH=0.71
# micrococcus
# Query: micrococcus
# lookup term: micrococcus
#   • Micrococcus                              ID=NCBITaxon_1269  depth=12 (exact)
# Query: megasphaera elsdenii
# lookup term: megasphaera_elsdenii
#   • Megasphaera elsdenii                     ID=NCBITaxon_907   depth=14 (exact)
# Query: acidaminococcus intestini
# lookup term: acidaminococcus_intestini
#   • Acidaminococcus intestini                ID=NCBITaxon_187327 depth=14 (exact)
# Query: barnesiella viscericola
# lookup term: barnesiella_viscericola
#   • Barnesiella viscericola                  ID=NCBITaxon_397865 depth=18 (exact)
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   • Bacteroides                    UI=D001439  Tree=B03.440.080.094.152  scoreMESH=0.95
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# Query: mucus-associated specy
# lookup term: mucus-associated_specy
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/species/Mucus-AssociatedSpecies
#
#
# Query: desulfovibrionaceae
# lookup term: desulfovibrionaceae
#   • Desulfovibrionaceae                      ID=NCBITaxon_194924 depth=10 (exact)
# Query: enterobacteriaceae
# lookup term: enterobacteriaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_543
#
#
# Query: turicibacter
# lookup term: turicibacter
#   • Turicibacter                             ID=NCBITaxon_191303 depth=12 (exact)
# micrococcus
# Query: micrococcus
# lookup term: micrococcus
#   • Micrococcus                              ID=NCBITaxon_1269  depth=12 (exact)
# Query: lachnospiraceae fcs020 group
# lookup term: lachnospiraceae_fcs020_group
#   • bacterium FCS020                         ID=NCBITaxon_1451755 depth=4  score=0.78
# Query: eggerthellaceae
# lookup term: eggerthellaceae
#   • Eggerthellaceae                          ID=NCBITaxon_1643826 depth=10 (exact)
# Query: turicibacter
# lookup term: turicibacter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_191303
#
#
# micrococcus
# Query: micrococcus
# lookup term: micrococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1269
#
#
# Query: eggerthellaceae
# lookup term: eggerthellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1643826
#
#
# clostridium
# Query: clostridium
# lookup term: clostridium
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D003013
#
# Query: turicibacter
# lookup term: turicibacter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_191303
#
#
# micrococcus
# Query: micrococcus
# lookup term: micrococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1269
#
#
# Query: eggerthellaceae
# lookup term: eggerthellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1643826
#
#
# clostridium
# Query: clostridium
# lookup term: clostridium
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D003013
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# Query: actinobacteria
# lookup term: actinobacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2013654
#
#
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# lactobacillaceae
# Query: lactobacillaceae
# lookup term: lactobacillaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_33958
#
# Query: enterobacteriaceae
# lookup term: enterobacteriaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_543
#
#
# Query: lachnospiraceae
# lookup term: lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_186803
#
#
# Query: odoribacter
# lookup term: odoribacter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_283168
#
#
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# Query: helicobacter
# lookup term: helicobacter
#   • Helicobacter                             ID=NCBITaxon_209   depth=12 (exact)
# lactococcus
# Query: lactococcus
# lookup term: lactococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1357
#
#
# Query: alloprevotella
# lookup term: alloprevotella
#   • Alloprevotella                           ID=NCBITaxon_1283313 depth=16 (exact)
# Query: imbalance-inducing bacteria
# lookup term: imbalance-inducing_bacteria
#   • Sulfur-Reducing Bacteria       UI=D016999  Tree=B03.900       scoreMESH=0.67
# Query: escherichia-shigella
# lookup term: escherichia-shigella
#   • Escherichia/Shigella sp.                 ID=NCBITaxon_1940338 depth=14 score=0.99
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# butyrate-producing_bacterium
# Query: butyrate-producing bacterium
# lookup term: butyrate-producing_bacterium
#   • butyrate-producing bacterium             ID=NCBITaxon_2811711 depth=4  (exact)
# family_ruminococcaceae
# Query: family ruminococcaceae
# lookup term: family_ruminococcaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2584567
#
# limosilactobacillus_reuteri
# Query: limosilactobacillus reuteri
# lookup term: limosilactobacillus_reuteri
#   • Limosilactobacillus reuteri              ID=NCBITaxon_1598  depth=14 (exact)
# limosilactobacillus_reuteri
# Query: limosilactobacillus reuteri
# lookup term: limosilactobacillus_reuteri
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1598
#
#
# bacillus_sp._f4-1
# Query: bacillus sp. f4-1
# lookup term: bacillus_sp._f4-1
#   • Bacillus sp. F4-1                        ID=NCBITaxon_489169 depth=16 (exact)
# bacillus_sp._f4-1
# Query: bacillus sp. f4-1
# lookup term: bacillus_sp._f4-1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_489169
#
#
# bacillus_sp._f4-1
# Query: bacillus sp. f4-1
# lookup term: bacillus_sp._f4-1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_489169
#
#
# bacillus_sp._f4-1
# Query: bacillus sp. f4-1
# lookup term: bacillus_sp._f4-1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_489169
#
#
# Query: short-chain fatty acid producing bacteria
# lookup term: short-chain_fatty_acid_producing_bacteria
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/species/Short-ChainFattyAcidProducingBacteria
#
#
# Query: gut-resident bacteria
# lookup term: gut-resident_bacteria
#   • Sulfur-Reducing Bacteria       UI=D016999  Tree=B03.900       scoreMESH=0.67
# Query: dysregulated bacteria
# lookup term: dysregulated_bacteria
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  score=1.00
# Query: fusobacterium nucleatum
# lookup term: fusobacterium_nucleatum
#   • Fusobacterium nucleatum                  ID=NCBITaxon_851   depth=14 (exact)
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: actinobacteria
# lookup term: actinobacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2013654
#
#
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# Query: lachnospiraceae
# lookup term: lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_186803
#
#
# Query: faecalibacterium
# lookup term: faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_216851
#
#
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# short-chain_fatty_acid_producing_bacteria
# Query: short-chain fatty acid producing bacteria
# lookup term: short-chain_fatty_acid_producing_bacteria
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/species/Short-ChainFattyAcidProducingBacteria
#
# Query: lachnospira
# lookup term: lachnospira
#   • Lachnospira                              ID=NCBITaxon_28050 depth=12 (exact)
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# Query: faecalibacterium
# lookup term: faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_216851
#
#
# Query: blautia
# lookup term: blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
#
# Query: acute chronic insomnia-related signature bacteria
# lookup term: acute_chronic_insomnia-related_signature_bacteria
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/species/AcuteChronicInsomniaRelatedSignatureBacteria
#
#
# Query: negativicute
# lookup term: negativicute
#   • Tenericutes                    UI=D008973  Tree=B03.440.860   scoreMESH=0.61
# clostridium_innocuum_group
# Query: clostridium innocuum group
# lookup term: clostridium_innocuum_group
#   • [Clostridium] innocuum                   ID=NCBITaxon_1522  depth=14 score=0.90
# Query: dorea
# lookup term: dorea
#   • Dorea                                    ID=NCBITaxon_189330 depth=12 (exact)
# Query: lachnoclostridium
# lookup term: lachnoclostridium
#   • Lachnoclostridium                        ID=NCBITaxon_1506553 depth=12 (exact)
# Query: prevotella7
# lookup term: prevotella7
#   • Prevotella                     UI=D018720  Tree=B03.440.080.094.640  scoreMESH=0.95
# Query: selenomonadalesare
# lookup term: selenomonadalesare
#   • Selenomonas                    UI=D020357  Tree=B03.440.425.410.800.877  scoreMESH=0.76
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
#
# Query: blautia
# lookup term: blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
#
# Query: prevotella
# lookup term: prevotella
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D018720
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# comamonas
# Query: comamonas
# lookup term: comamonas
#   • Comamonas                                ID=NCBITaxon_283   depth=12 (exact)
# Query: faecalibacterium
# lookup term: faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_216851
#
#
# phylum_synergistetes
# Query: phylum synergistetes
# lookup term: phylum_synergistetes
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2309303
#
# Query: proteobacteria
# lookup term: proteobacteria
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D020560
#
#
# Query: olidextribacter
# lookup term: olidextribacter
#   • Liberibacter                   UI=D000086202 Tree=B03.660.050.662.347  scoreMESH=0.81
# Query: intestinibacter
# lookup term: intestinibacter
#   • Intestinibacter                          ID=NCBITaxon_1505657 depth=12 (exact)
# Query: kineothrix
# lookup term: kineothrix
#   • Kineothrix                               ID=NCBITaxon_2163168 depth=12 (exact)
# Query: agathobaculum
# lookup term: agathobaculum
#   • Agathobaculum                            ID=NCBITaxon_2048137 depth=12 (exact)
# Query: roseburia
# lookup term: roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_841
#
#
# Query: prevotella specy
# lookup term: prevotella_specy
#   • Prevotella sp. 2-4                       ID=NCBITaxon_1486939 depth=20 score=0.98
# actinobacteria
# Query: actinobacteria
# lookup term: actinobacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2013654
#
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
#
# Query: verrucomicrobiota
# lookup term: verrucomicrobiota
#   • Verrucomicrobiota                        ID=NCBITaxon_74201 depth=6  (exact)
# Query: akkermansia
# lookup term: akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_239934
#
#
# Query: enterococcu
# lookup term: enterococcu
#   • Enterococcus                   UI=D016983  Tree=B03.353.750.250.250  scoreMESH=0.96
# Query: hungatella
# lookup term: hungatella
#   • Hungatella                               ID=NCBITaxon_1649459 depth=12 (exact)
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
#
# Query: oscillospira
# lookup term: oscillospira
#   • Oscillospira                             ID=NCBITaxon_119852 depth=12 (exact)
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# family_ruminococcaceae
# Query: family ruminococcaceae
# lookup term: family_ruminococcaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2584567
#
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# Query: proteobacteria
# lookup term: proteobacteria
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D020560
#
#
# Query: lachnospiraceae
# lookup term: lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_186803
#
#
# Query: blautia
# lookup term: blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
#
# micrococcus
# Query: micrococcus
# lookup term: micrococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1269
#
#
# Query: roseburia
# lookup term: roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_841
#
#
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# Query: verrucomicrobiota
# lookup term: verrucomicrobiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_74201
#
#
# Query: akkermansia
# lookup term: akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_239934
#
#
# Query: akkermansia muciniphila
# lookup term: akkermansia_muciniphila
#   • Akkermansia muciniphila                  ID=NCBITaxon_239935 depth=16 (exact)
# Query: verrucomicrobiaceae
# lookup term: verrucomicrobiaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_203557
#
#
# Query: verrucomicrobiota
# lookup term: verrucomicrobiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_74201
#
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
#
# Query: roseburia
# lookup term: roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_841
#
#
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# Query: lactobacillaceae
# lookup term: lactobacillaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_33958
#
#
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# Query: barnesiellaceae
# lookup term: barnesiellaceae
#   • Barnesiellaceae                          ID=NCBITaxon_2005519 depth=14 (exact)
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
#
# actinobacteria
# Query: actinobacteria
# lookup term: actinobacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2013654
#
# Query: bilophila wadsworthia
# lookup term: bilophila_wadsworthia
#   • Bilophila wadsworthia                    ID=NCBITaxon_35833 depth=14 (exact)
# Query: thermodesulfobacteriota
# lookup term: thermodesulfobacteriota
#   • Thermodesulfobacteriota                  ID=NCBITaxon_200940 depth=4  (exact)
# Query: prevotella
# lookup term: prevotella
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D018720
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# Query: verrucomicrobiota
# lookup term: verrucomicrobiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_74201
#
#
# Query: akkermansia
# lookup term: akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_239934
#
#
# bifidobacterium
# Query: bifidobacterium
# lookup term: bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: coriobacteriaceae
# lookup term: coriobacteriaceae
#   • Coriobacteriaceae                        ID=NCBITaxon_84107 depth=10 (exact)
# actinobacteria
# Query: actinobacteria
# lookup term: actinobacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2013654
#
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# Query: christensenellaceae
# lookup term: christensenellaceae
#   • Christensenellaceae                      ID=NCBITaxon_990719 depth=10 (exact)
# Query: lactobacillaceae
# lookup term: lactobacillaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_33958
#
#
# Query: enterococcaceae
# lookup term: enterococcaceae
#   • Enterococcaceae                          ID=NCBITaxon_81852 depth=10 (exact)
# Query: enterococcu
# lookup term: enterococcu
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D016983
#
#
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# lactococcus
# Query: lactococcus
# lookup term: lactococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1357
#
#
# Query: oscillospira
# lookup term: oscillospira
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_119852
#
#
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# Query: proteobacteria
# lookup term: proteobacteria
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D020560
#
#
# Query: enterobacteriaceae
# lookup term: enterobacteriaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_543
#
#
# Query: citrobacter
# lookup term: citrobacter
#   • Citrobacter                              ID=NCBITaxon_544   depth=12 (exact)
# Query: klebsiella
# lookup term: klebsiella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_570
#
#
# Query: salmonella
# lookup term: salmonella
#   • Salmonella                               ID=NCBITaxon_590   depth=12 (exact)
# Query: shigella
# lookup term: shigella
#   • Shigella                                 ID=NCBITaxon_620   depth=12 (exact)
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# Query: lachnospiraceae
# lookup term: lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_186803
#
#
# Query: roseburia
# lookup term: roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_841
#
#
# ruminococcus
# Query: ruminococcus
# lookup term: ruminococcus
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D045857
#
#
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# Query: muribaculaceae
# lookup term: muribaculaceae
#   • Muribaculaceae                           ID=NCBITaxon_2005473 depth=14 (exact)
# Query: faecalibaculum
# lookup term: faecalibaculum
#   • Faecalibaculum                           ID=NCBITaxon_1729679 depth=12 (exact)
# Query: flavonifractor
# lookup term: flavonifractor
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2959924
#
#
# Query: christensenellaceae
# lookup term: christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_990719
#
#
# flavonifractor
# Query: flavonifractor
# lookup term: flavonifractor
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2959924
#
# christensenellaceae
# Query: christensenellaceae
# lookup term: christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_990719
#
# Query: flavonifractor
# lookup term: flavonifractor
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2959924
#
#
# Query: christensenellaceae
# lookup term: christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_990719
#
#
# Query: flavonifractor
# lookup term: flavonifractor
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2959924
#
#
# Query: christensenellaceae
# lookup term: christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_990719
#
#
# Query: christensenellaceae
# lookup term: christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_990719
#
#
# Query: flavonifractor
# lookup term: flavonifractor
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2959924
#
#
# Query: christensenellaceae
# lookup term: christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_990719
#
#
# Query: flavonifractor
# lookup term: flavonifractor
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2959924
#
#
# Query: christensenellaceae
# lookup term: christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_990719
#
#
# Query: flavonifractor
# lookup term: flavonifractor
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2959924
#
#
# family_ruminococcaceae
# Query: family ruminococcaceae
# lookup term: family_ruminococcaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2584567
#
# family_ruminococcaceae
# Query: family ruminococcaceae
# lookup term: family_ruminococcaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2584567
#
# Query: genus subdoligranulum
# lookup term: genus_subdoligranulum
#   • Subdoligranulum                          ID=NCBITaxon_292632 depth=12 score=0.86
# family_ruminococcaceae
# Query: family ruminococcaceae
# lookup term: family_ruminococcaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2584567
#
#
# Query: genus coprococcus2
# lookup term: genus_coprococcus2
#   • Enterococcus                   UI=D016983  Tree=B03.353.750.250.250  scoreMESH=0.67
# Query: genus eggerthella
# lookup term: genus_eggerthella
#   • Eggerthella                              ID=NCBITaxon_84111 depth=12 score=0.85
# eubacterium
# Query: eubacterium
# lookup term: eubacterium
#   • Eubacterium                              ID=NCBITaxon_1730  depth=12 (exact)
# Query: xylanophilum group
# lookup term: xylanophilum_group
#   • Eubacterium xylanophilum                 ID=NCBITaxon_39497 depth=14 score=0.79
# Query: predominant bacteria
# lookup term: predominant_bacteria
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  score=1.00
# family_ruminococcaceae
# Query: family ruminococcaceae
# lookup term: family_ruminococcaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2584567
#
# family_ruminococcaceae
# Query: family ruminococcaceae
# lookup term: family_ruminococcaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2584567
#
# family_ruminococcaceae
# Query: family ruminococcaceae
# lookup term: family_ruminococcaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2584567
#
# family_ruminococcaceae
# Query: family ruminococcaceae
# lookup term: family_ruminococcaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2584567
#
# family_ruminococcaceae
# Query: family ruminococcaceae
# lookup term: family_ruminococcaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2584567
#
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# Query: lachnoclostridium
# lookup term: lachnoclostridium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1506553
#
#
# Query: lachnostridium
# lookup term: lachnostridium
#   • Clostridium                    UI=D003013  Tree=B03.300.390.400.200  scoreMESH=0.80
# Query: lachnoclostridium
# lookup term: lachnoclostridium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1506553
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# anaerostipes
# Query: anaerostipes
# lookup term: anaerostipes
#   • Anaerostipes                             ID=NCBITaxon_207244 depth=12 (exact)
# ruminococcus
# Query: ruminococcus
# lookup term: ruminococcus
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D045857
#
# Query: blautia
# lookup term: blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
#
# Query: akkermansia muciniphila
# lookup term: akkermansia_muciniphila
# ...
# lookup term: prevotellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_171552
#
#
# Query: lachnospiraceae
# lookup term: lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_186803
#
#
# Query: erysipelotrichaceae
# lookup term: erysipelotrichaceae
#   • Erysipelotrichaceae                      ID=NCBITaxon_128827 depth=10 (exact)
# Query: faecalibacterium
# lookup term: faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_216851
#
#
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
#
# candida_albicans
# Query: candida albicans
# lookup term: candida_albicans
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0003515
#
# candida_albicans
# Query: candida albicans
# lookup term: candida_albicans
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0003515
#
#
# candida_albicans
# Query: candida albicans
# lookup term: candida_albicans
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0003515
#
# intestinal_microorganism
# Query: intestinal microorganism
# lookup term: intestinal_microorganism
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/species/IntestinalMicroorganism
#
# Query: clostridia ucg 014
# lookup term: clostridia_ucg_014
#   • Clostridium                    UI=D003013  Tree=B03.300.390.400.200  scoreMESH=0.69
# catabacteriaceae
# Query: catabacteriaceae
# lookup term: catabacteriaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1902775
#
# Query: oscillospiraceae
# lookup term: oscillospiraceae
#   • Oscillospiraceae                         ID=NCBITaxon_216572 depth=10 (exact)
# Query: lachinospiracea
# lookup term: lachinospiracea
#   • Leptospiraceae                 UI=D016953  Tree=B03.440.400.425.475  scoreMESH=0.69
# Query: coriobacteriaceae
# lookup term: coriobacteriaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_84107
#
#
# Query: faecalibacterium
# lookup term: faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_216851
#
#
# Query: fusicatenibacter
# lookup term: fusicatenibacter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1407607
#
#
# Query: roseburia
# lookup term: roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_841
#
#
# Query: blautia
# lookup term: blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
#
# Query: akkermansia
# lookup term: akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_239934
#
#
# Query: dialister
# lookup term: dialister
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# Query: lachnospiraceae nk4a136
# lookup term: lachnospiraceae_nk4a136
#   • Lachnospiraceae bacterium NK4A136        ID=NCBITaxon_877420 depth=14 score=0.98
# Query: clostridia ucg 014
# lookup term: clostridia_ucg_014
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D003013
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
#
# Query: proteobacteria
# lookup term: proteobacteria
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D020560
#
#
# Query: 7-dehydroxylating bacteria
# lookup term: 7-dehydroxylating_bacteria
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  score=1.00
# Query: proteobacteria
# lookup term: proteobacteria
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D020560
#
#
# Query: prevotella
# lookup term: prevotella
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D018720
#
#
# Query: prevotellaceae
# lookup term: prevotellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_171552
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# Query: lachnospiraceae
# lookup term: lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_186803
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# Query: prevotella
# lookup term: prevotella
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D018720
#
#
# Query: lachnospiraceae
# lookup term: lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_186803
#
#
# Query: aerotolerant bacteria
# lookup term: aerotolerant_bacteria
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  score=1.00
# Query: aerotolerant bacteria
# lookup term: aerotolerant_bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
#
# Query: aerotolerant bacteria
# lookup term: aerotolerant_bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
#
# Query: aerotolerant bacteria
# lookup term: aerotolerant_bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
#
# firmicutes
# Query: firmicutes
# lookup term: firmicutes
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/?term=firmicutes
#
# Query: phylum actinobacteria
# lookup term: phyla_actinobacteria
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   scoreMESH=0.80
# verrucomicrobia_bacterium_b-1-8
# Query: verrucomicrobia bacterium b-1-8
# lookup term: verrucomicrobia_bacterium_b-1-8
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_747582
#
#
# Query: genus roseburia
# lookup term: genus_roseburia
#   • Roseburia                                ID=NCBITaxon_841   depth=12 score=0.84
# intestinimonas
# Query: intestinimonas
# lookup term: intestinimonas
#   • Intestinimonas                           ID=NCBITaxon_1392389 depth=12 (exact)
# anaerotruncus
# Query: anaerotruncus
# lookup term: anaerotruncus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_244127
#
#
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# Query: blautia
# lookup term: blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
#
# Query: blautia
# lookup term: blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
#
# Query: blautia
# lookup term: blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
#
# Query: blautia
# lookup term: blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
#
# Query: blautia
# lookup term: blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
#
# Query: blautia
# lookup term: blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
#
# Query: psychobiotic
# lookup term: psychobiotic
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/species/Psychobiotics
#
#
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# Query: psychobiotic
# lookup term: psychobiotic
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/species/Psychobiotics
#
#
# Query: psychobiotic
# lookup term: psychobiotic
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/species/Psychobiotics
#
#
# verrucomicrobia_bacterium_b-1-8
# Query: verrucomicrobia bacterium b-1-8
# lookup term: verrucomicrobia_bacterium_b-1-8
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_747582
#
#
# Query: fibrobactere
# lookup term: fibrobactere
#   • Fibrobacteres                  UI=D061306  Tree=B03.440.305   scoreMESH=0.96
# verrucomicrobia_bacterium_b-1-8
# Query: verrucomicrobia bacterium b-1-8
# lookup term: verrucomicrobia_bacterium_b-1-8
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_747582
#
#
# Query: fibrobactere
# lookup term: fibrobactere
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D061306
#
#
# Query: deinococcus-thermu
# lookup term: deinococcus-thermu
#   • Deinococcus                              ID=NCBITaxon_1298  depth=12 score=1.00
# Query: pro-inflammatory bacteria
# lookup term: pro-inflammatory_bacteria
#   • bacterium pro-3                          ID=NCBITaxon_1552762 depth=4  score=0.81
# Query: kineothrix alysoide
# lookup term: kineothrix_alysoide
#   • Kineothrix                               ID=NCBITaxon_2163168 depth=12 score=1.00
# butyrate-producing_bacterium
# Query: butyrate-producing bacterium
# lookup term: butyrate-producing_bacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2811711
#
#
# entering dev collection
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# Query: ectopic colonization bacteria
# lookup term: ectopic_colonization_bacteria
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  score=1.00
# Query: bacteria in the gut microbiome
# lookup term: bacteria_in_the_gut_microbiome
#   • Bacteria, Anaerobic            UI=D001421  Tree=B03.130       scoreMESH=0.61
# Query: changing gut bacteria
# lookup term: changing_gut_bacteria
#   • Cyanobacteria                  UI=D000458  Tree=B03.280       scoreMESH=0.65
# Query: lactobacillale
# lookup term: lactobacillale
#   • Lactobacillales                UI=D056546  Tree=B03.353.750   scoreMESH=0.97
# Query: lactobacillaceae
# lookup term: lactobacillaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_33958
#
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
#
# Query: clostridium cluster iii
# lookup term: clostridium_cluster_iii
#   • Clostridium kluyveri           UI=D047010  Tree=B03.300.390.400.200.493  scoreMESH=0.79
# anaerofustis
# Query: anaerofustis
# lookup term: anaerofustis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1500236
#
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
#
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# pathogenic_organism
# Query: pathogenic organism
# lookup term: pathogenic_organism
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0450254
#
# Query: proteobacteria
# lookup term: proteobacteria
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D020560
#
#
# Query: faecalibacterium
# lookup term: faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_216851
#
#
# Query: proteobacteria
# lookup term: proteobacteria
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D020560
#
#
# Query: faecalibacterium
# lookup term: faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_216851
#
#
# Query: genus faecalicatena
# lookup term: genus_faecalicatena
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2005359
#
#
# Query: genus faecalicatena
# lookup term: genus_faecalicatena
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2005359
#
#
# Query: genus faecalicatena
# lookup term: genus_faecalicatena
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2005359
#
#
# Query: prevotella
# lookup term: prevotella
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D018720
#
#
# Query: alistipe
# lookup term: alistipe
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1490417
#
#
# Query: akkermansia
# lookup term: akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_239934
#
#
# ruminococcus
# Query: ruminococcus
# lookup term: ruminococcus
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D045857
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# family_ruminococcaceae
# Query: family ruminococcaceae
# lookup term: family_ruminococcaceae
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2584567
#
# Query: clostridiaceae
# lookup term: clostridiaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_31979
#
#
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# Query: enterobacteriaceae
# lookup term: enterobacteriaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_543
#
#
# Query: desulfovibrio
# lookup term: desulfovibrio
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_872
#
#
# short-chain_fatty_acid_producing_bacteria
# Query: short-chain fatty acid producing bacteria
# lookup term: short-chain_fatty_acid_producing_bacteria
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/species/Short-ChainFattyAcidProducingBacteria
#
# Query: faecalibacterium
# lookup term: faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_216851
#
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
#
# Query: alistipe
# lookup term: alistipe
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1490417
#
#
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# Query: alistipe
# lookup term: alistipe
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1490417
#
#
# Query: rikenella
# lookup term: rikenella
#   • Rikenella                                ID=NCBITaxon_28138 depth=16 (exact)
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
#
# Query: bacterial group
# lookup term: bacterial_group
#   • Bacteria                       UI=D001419  Tree=B03           scoreMESH=0.70
# bacteria
# Query: bacteria
# lookup term: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# Query: erysipelotrichaceae family
# lookup term: erysipelotrichaceae_family
#   • Erysipelotrichaceae                      ID=NCBITaxon_128827 depth=10 score=0.76
# Query: allobaculum genu
# lookup term: allobaculum_genu
#   • Allobaculum                              ID=NCBITaxon_174708 depth=12 score=1.00
# Query: erysipelotrichale
# lookup term: erysipelotrichale
#   • Erysipelothrix                 UI=D004888  Tree=B03.353.688   scoreMESH=0.77
# Query: bacteroidale
# lookup term: bacteroidale
#   • Bacteroides                    UI=D001439  Tree=B03.440.080.094.152  scoreMESH=0.87
# Query: clostridiale
# lookup term: clostridiale
#   • Clostridiales                  UI=D000068016 Tree=B03.353.625   scoreMESH=0.96
# Query: oscillospira
# lookup term: oscillospira
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_119852
#
#
# bacteroide
# Query: bacteroide
# lookup term: bacteroide
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001439
#
#
# Query: prevotella
# lookup term: prevotella
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D018720
#
#
# ruminococcus
# Query: ruminococcus
# lookup term: ruminococcus
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D045857
#
#
# Query: faecalibacterium
# lookup term: faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_216851
#
#
# Query: prevotella 9
# lookup term: prevotella_9
#   • Prevotella sp. 2-4                       ID=NCBITaxon_1486939 depth=20 score=0.98
# Query: faecalibacterium
# lookup term: faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_216851
#
#
# The RDF graph has been saved in c:\Users\samue\OneDrive\Desktop\ThesisPiron\rdf\gutbrain_entities.ttl

# %% [markdown]
# <h1>INGEST CHEMICAL</h1>

# %%
import re
import json
import numpy as np
import requests
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from rdflib.namespace import DCTERMS
from umlsutils import best_umls_match, search_umls, get_umls_definition
from groqutils import get_llm_definition
from funcutils import get_ncit_description, get_chebi_description, get_omit_description, get_foodon_description, NCBI_BASE, HEREDITARY_BASE, UMLS_BASES, foodon_file, ncit_file, omit_file, chebi_file, hash_term_sha256

CHEBI_BASE = "http://purl.obolibrary.org/obo/"
CHEMICAL_CLASS = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Chemical")
CHEMICAL_CONCEPT_SCHEME = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Chemical")
UBERON_URI = URIRef("http://purl.obolibrary.org/obo/UBERON_0002097")

def load_ncbitaxon_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = CHEBI_BASE + term_id
            rows.append((label, uri))
    return rows
    
def load_chebi_labels(path):
    rows = []
    with open(path, encoding="utf-8") as fh:
        next(fh) 
        for ln in fh:
            uri, label = ln.rstrip("\n").split("\t", 1)
            rows.append((label, uri))
    return rows

CHEBI_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\chebi_labels.txt"
NCBITAXON_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncit_full_taxonomy.txt"
chebi_rows = load_chebi_labels(CHEBI_LABELS_FILE)
ncbi_rows = load_ncbitaxon_labels(NCBITAXON_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in chebi_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

exact_ix1 = defaultdict(list)
for lbl, uri in ncbi_rows:
    exact_ix1[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in chebi_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

labels_only1 = [preprocess(lbl) for lbl, _ in ncbi_rows]
vec1 = TfidfVectorizer(stop_words="english")
mat1 = vec1.fit_transform(labels_only1)

def top_cosine(term, k=5, thr=0.75):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = chebi_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

def top_cosine_ncbitaxon(term, k=5, thr=0.75):
    v  = vec1.transform([term])
    sc = cosine_similarity(v, mat1).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = ncbi_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

greek_map = {
    'α': 'alpha',  'Α': 'alpha',
    'β': 'beta',   'Β': 'beta',
    'γ': 'gamma',  'Γ': 'gamma',
    'δ': 'delta',  'Δ': 'delta',
    'ε': 'epsilon','Ε': 'epsilon',
    'ζ': 'zeta',   'Ζ': 'zeta',
    'η': 'eta',    'Η': 'eta',
    'θ': 'theta',  'Θ': 'theta',
    'ι': 'iota',   'Ι': 'iota',
    'κ': 'kappa',  'Κ': 'kappa',
    'λ': 'lambda', 'Λ': 'lambda',
    'μ': 'mu',     'Μ': 'mu',
    'ν': 'nu',     'Ν': 'nu',
    'ξ': 'xi',     'Ξ': 'xi',
    'ο': 'omicron','Ο': 'omicron',
    'π': 'pi',     'Π': 'pi',
    'ρ': 'rho',    'Ρ': 'rho',
    'σ': 'sigma',  'Σ': 'sigma',
    'τ': 'tau',    'Τ': 'tau',
    'υ': 'upsilon','Υ': 'upsilon',
    'φ': 'phi',    'Φ': 'phi',
    'χ': 'chi',    'Χ': 'chi',
    'ψ': 'psi',    'Ψ': 'psi',
    'ω': 'omega',  'Ω': 'omega',
}

def preprocess(term):
    for greek_char, name in greek_map.items():
        if greek_char in term:
            term = term.replace(greek_char, name)
    term = term.replace('_', ' ')
    term = term.strip()
    return " ".join(lemmatizer.lemmatize(w) for w in term.split())

manual_created = {}
created = {}

manual_created = {
    "serum_hormone": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/SerumHormone"),
    "melanosome" : URIRef("http://purl.obolibrary.org/obo/GO_0042470"),
    "glutamate" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0220839"),
    "phosphoribosylanthranilate_isomerase" : URIRef("https://www.genome.jp/dbget-bin/www_bget?ko:K01817"),
    "aspartate_aminotransferase" : URIRef("https://www.genome.jp/dbget-bin/www_bget?ko:K11358"),
    "3-deoxy-7-phosphoheptulonate_synthase" : URIRef("https://www.genome.jp/dbget-bin/www_bget?ko:K01626"),
    "tryptophanase": URIRef("https://www.genome.jp/dbget-bin/www_bget?K01667"),
    "rhepo" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/Rhepo"),
    "dna_methylation" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0376452"),
    "enteric_glial_cells_network" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/EntericGlialCellsNetwork"),
    "choline_metabolite" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4329663"),
    "oxygen": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0030054"),
    "gut_iga_level" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/GutIgaLevel"),
    "me": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/Me"),
    "toll-like_receptors" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0670896"),
    "fatty_acid" : URIRef("http://purl.obolibrary.org/obo/NCIT_C492"),
    "neurotransmitter" : URIRef("http://purl.obolibrary.org/obo/NCIT_C687"),
    "lipid" : URIRef("http://purl.obolibrary.org/obo/NCIT_C616"),
    "isorhamnetin" : URIRef("http://purl.obolibrary.org/obo/CHEBI_6052"),
    "serotonin" : URIRef("http://purl.obolibrary.org/obo/CHEBI_28790"),
    "nutrient" : URIRef("http://purl.obolibrary.org/obo/NCIT_C1814"),
    "atp" : URIRef("http://purl.obolibrary.org/obo/CHEBI_15422"),
    "iron" : URIRef("http://purl.obolibrary.org/obo/NCIT_C598"),
    "lactic_acid": URIRef("http://purl.obolibrary.org/obo/CHEBI_42111"),
    "microbially-derived_neurotransmitters" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/MicrobiallyDerivedNeurotransmitters"),
    "starch" : URIRef("http://purl.obolibrary.org/obo/NCIT_C68488"),
    "derived_metabolite": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/DerivedMetabolite"),
    "sialyl_alpha2_6_lactose": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/SialylAlpha26Lactose"),
    "group_iii_metabotropic_glutamate_receptor_activity" : URIRef("http://purl.obolibrary.org/obo/GO_0001642"),
    "histone_deacetylase" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0019643"),
    "3-(3-hydroxyphenyl)propionic_acid_glucuronide": URIRef("http://purl.obolibrary.org/obo/FOBI_08679"),
    "g-protein-coupled_receptors" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0682972"),
    "beta-casomorphin-7": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0053401"),
    "opioid_peptide": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0205753"),
    "glutamate_metabolite": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/GlutamateMetabolite"),
    "cd4_regulatory": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/Cd4Regulatory"),
    "21-desoxycortisol": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/21Desoxycortisol"),
    "dead_cell": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/DeadCell"),
    "neurochemical" :  URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/Neurochemical"),
    "microbiome-borne_curli": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/MicrobiomeBorneCurli"),
}

created = dict(manual_created)

regex_map = [
    (r"simple_sugar","monosaccharide"),
    (r"\benteric_neuron\w*\b","enteric_ganglion_neuron"),
    (r"\bsystemic_cytokines_and_chemokine\w*\b","cytokine"),
    (r"\bsyn\b","synaptic_cast_protein,_human"),
    (r"\bmr16-1\b","anti-il-6_monoclonal_antibody"),
    (r"\b-amino-3-hydroxy-5-methyl-4-isoxazolepropionic_acid_receptor_1\b","gria1_protein,_human"),
    (r"\bneurochemical\w*\b","neurochemicals"),
    (r"\b-valerolactone\w*\b","gamma-valerolactone"),
    (r"\bcognition-relevant_signaling_molecule\w*\b","signaling_molecules"),
    (r"neuropeptide_y_system","neuropeptide_y"),
    (r"cerebral_neuropeptide_y_system","neuropeptide_y"),
    (r"\bhost-derived_soluble_factor\w*\b","cytokine"),
    (r"\bgut_microbial-derived_metabolite\w*\b","derived_metabolite"),
    (r"\bmicrobial-derived_metabolite\w*\b","derived_metabolite"),
    (r"\boligomerization_domain-like_receptor\w*\b","nlr_proteins"),
    (r"\bnlr\w*\b","nlr_proteins"),
    (r"tumour_necrosis_factor-","tumor_necrosis_factor-alpha"),
    (r"cd4__regulatory_t","cd4_regulatory"),
    (r"circulating_cxcl1","cxcl1_protein,_human"),
    (r"\bglutamate_metabolite\w*\b","glutamate_metabolite"),
    (r"\b6_sl\w*\b","sialyl_alpha2_6_lactose"),
    (r"\bmetabotropic_glutamate_receptors","receptors,_metabotropic_glutamate"),
    (r"\bmglu\b","receptors,_metabotropic_glutamate"),
    (r"\bmetabotropic_glutamate_receptor\w*\b","receptors,_metabotropic_glutamate"),
    (r"\bg_protein-coupled_receptors\b","g-protein-coupled_receptors"),
    (r"\bgroup_iii_mglu_receptors\w*\b","group_iii_metabotropic_glutamate_receptor_activity"),
    (r"group_iii_mglu","group_iii_metabotropic_glutamate_receptor_activity"),
    (r"\bmglu8","metabotropic_glutamate_receptor_8"),
    (r"\bhistone_deacetylase\w*\b","histone_deacetylase"),
    (r"\bhdac\w*\b","histone_deacetylase"),
    (r"\bgpcrs\b", "g_protein-coupled_receptors"),
    (r"\bfa3rs\b", "receptor"),
    (r"\bsals\b","salsolinol"),
    (r"\bhucb-derived_plasma\b","plasma_derivative"),
    (r"\bsmadcam-1\b","mucosal_addressin_cell_adhesion_molecule_1"),
    (r"\blbp\b","lipopolysaccharide-binding_protein"),
    (r"\bi-fabp","intestinal_fatty_acid_binding_protein,_xenopus"),
    (r"\bintestinal_fatty_acid_binding_protein\b","intestinal_fatty_acid_binding_protein,_xenopus"),
    (r"plasma_il-18","interleukin-18"),
    (r"hippocampal_il6_and_tnfa","interleukin-6"),
    (r"il-18bpa","interleukin-18"),
    (r"\bsmadcam-1\b","soluble_vascular_cell_adhesion_molecule_1"),
    (r"\bccl25\b","chemokine"),
    (r"human_glucose-dependent_insulinotropic_polypeptide","gastric_inhibitory_polypeptide_receptor"),
    (r"inner_and_outer_membrane_efflux_pump_factor_proteins","proteins"),
    (r"\bacrb\b","acrb_protein,_e_coli"),
    (r"\btolc\b","tolc_protein,_e_coli"),
    (r"protein-bound_n-_carboxymethyl_lysine","2-n,n-bis(carboxymethyl)lysine"),
    (r"\bcml\b","2-n,n-bis(carboxymethyl)lysine"),
    (r"\bcel\b","n(6)-(1-carboxyethyl)lysine"),
    (r"n-_1-carboxyethyl_lysine","n(6)-(1-carboxyethyl)lysine"),
    (r"n-_5-hydro-5-methyl-4-imidazolon-2-yl_-ornithine","ndelta-(5-hydro-5-methyl-4-imidazolon-2-yl)ornithine"),
    (r"\bmg-h1\b","ndelta-(5-hydro-5-methyl-4-imidazolon-2-yl)ornithine"),
    (r"3-_3-hydroxyphenyl_propionic_acid","3-(3-hydroxyphenyl)propionic_acid_glucuronide"),
    (r"\bdietary_polyphenol\w*\b","dietary_polyphenol"),
    (r"insoluble_-syn","snca_protein,_mouse"),
    (r"\balpha-synuclein__-syn__protein\b","snca_protein,_mouse"),
    (r"\b-syn\b","snca_protein,_mouse"),
    (r"\b-syn_protein\b","snca_protein,_mouse"),
    (r"\bpark7\b","park7_protein,_human"),
    (r"faecal_scfa","short_chain_fatty_acid"),
    (r"designer_receptors_exclusively_activated_by_designer_drugs","receptor"),
    (r"dreadds","receptor"),
    (r"gpcrs","g-protein-coupled_receptors"),
    (r"synthetic_ligands","c3_synthetic_ncam-ligand"),
    (r"dreadd_agonist_21", "agonist"),
    (r"compound_21__c21","agonist"),
    (r"kyn","kynurenine"),
    (r"\bido\b","plasma_indoleamine-2_3-dioxygenase"),
    (r"microbiota-derived_metabolites","metabolite"),
    (r"bacterial_amyloid_proteins","amyloid_proteins"),
    (r"endogenous_nd-related_proteins","envelope_protein,_endogenous_retrovirus-3"),
    (r"bacterial_and_human_amyloid_proteins","amyloid_proteins"),
    (r"csga","amyloid_proteins"),
    (r"csga_protein","amyloid_proteins"),
    (r"hydrophobic_and_secondary_bile_acids","bile_acid"),
    (r"microbially_derived_toxic_bile_acids","bile_acid"),
    (r"non-nutrient_bioactive_compounds","phytochemicals"),
    (r"\bphytochemical\w*\b","phytochemicals"),
    (r"microbial_toxin","toxin"),
    (r"microbial_toxin_-n-methylamino-l-alanine","toxin"),
    (r"\basyn\b","snca_protein,_mouse"),
    (r"gut-microbiome-derived_metabolites","metabolites"),
    (r"\b4ep\b","4-ethylphenol"),
    (r"\bbioactive_polyphenol\w*\b","polyphenol"),
    (r"lactic-acid","lactic_acid"),
    (r"sfa","saturated_fatty_acid"),
    (r"\ba1_beta-casein\w*\b","casein"),
    (r"\bmacro-_and_micro-nutrient\w*\b","nutrient"),
    (r"fat_and_sugar_content", "monosaccharide"),
    (r"il-6", "interleukin_6"),
    (r"melanosomes", "melanosome"),
    (r"stress-related_hormones", "hormone"),
    (r"inflammation-related_cytokines", "cytokine"),
    (r"neuroactive_compound","compound"),
    (r"gaba","gamma-aminobutyric_acid"),
    (r"plant-origin_and_microbially-formed_neuroactive_compounds", "compound"),
    (r"inflammatory_compounds","compound"),
    (r"different_hormones","hormones"),
    (r"serum_ba_precursor_7-hydroxy-4-cholesten-3-one","7_alpha-hydroxy-4-cholesten-3-one"),
    (r"\bbas\b","bile_acid"),
    (r"\bba\b","bile_acid"),
    (r"essential_minerals","minerals"),
    (r"\bpm\b","particulate_matter"),
    (r"\bcrp\b","c-reactive_protein"),
    (r"\bcu\b","copper"),
    (r"\bdead_cell\w*\b","dead_cell"),
    (r"urban_particulate_matter","particulate_matter"),
    (r"urban_pm","particulate_matter"),
    (r"pm_solution","particulate_matter"),
    (r"sterile_pbs_solution","phosphate_buffered_saline"),
    (r"endocannabinoidome","endocannabinoids"),
    (r"fatty_acid_amide_hydrolase__faah__inhibitor_urb597","urb_597"),
    (r"microbial_metabolites", "metabolite"),
    (r"\bscfa\w*\b","short_chain_fatty_acid"),
    (r"microbial_neuroactive_metabolites", "metabolite"),
    (r"dextran_sodium_sulphate", "dextran_sulfate_sodium"),
    (r"dss", "dextran_sulfate_sodium"),
    (r"lps", "lipopolysaccharide"),
    (r"\beya1\b","eya-1_protein,_c_elegans"),
    (r"circulating_lipocalin-2", "lipocalin-2"),
    (r"\bserotonin\w*\b","serotonin"),
    (r"xpjyf", "xingpijieyu_formula"),
    (r"gfap","glial_fibrillary_acidic_protein"),
    (r"2-dg","2-deoxy-d-glucose"),
    (r"\bresistant_starch\w*\b","starch"),
    (r"g1p","glucose-1-phosphate"),
    (r"glucose1pmetab-pwy","glucose-1-phosphate_metabolism"),
    (r"associated_synaptic_proteins","synaptic_cast_protein,_human"),
    (r"helicobacter_pylori-related_inflammatory_mediators","mediators"),
    (r"bovine_milk_casein","bovine_milk_plasma"),
    (r"food_antigens","antigens"),
    (r"inflammatory_cytokines","cytokines"),
    (r"plasma_and_brain_cytokines","cytokines"),
    (r"interleukin__il_-1","interleukin-1"),
    (r"7_nachr","nachr_alpha9"),
    (r"prebiotic_phytochemicals","phytochemical"),
    (r"microbiota-derived_-aminobutyric_acid","aminobutyric_acids"),
    (r"gut_microbiota-mediated_vitamin_b6","vitamin_b6"),
    (r"milk_derived_opioid_peptides","opioid_peptide"),
    (r"\bbcm-7\b","beta-casomorphin-7"),
    (r"pro-excitatory_and_inhibitory_neurotransmitters","neurotransmitter_receptor"),
    (r"aromatic_aminotransferase","aromatic_amino_acid_aminotransferase"),
    (r"non-ketamine_nmdar-related_compounds","nmdar"),
    (r"\bil-1\b","interleukin-1"),
    (r"host-derived_soluble_factors","cytokines"),
    (r"\bpea\b","palmitoylethanolamide"),
    (r"\ba\b","amyloid_beta-peptides"),
    (r"\bil-2\b","interleukin-2"),
    (r"\bil-4\b","interleukin-4"),
    (r"\btce\b","trichloroethylene"),
    (r"\bgm-csf\b","csf_39300/gm-csf"),
    (r"\bifn\b","interferons"),
    (r"\bTNF\w*\b","tnf_protein,_human"),
    (r"eps","exopolysaccharide"),
    (r"\bchemokine_ccl25\b","ccl25_protein,_human"),
    (r"c-eps","exopolysaccharide"),
    (r"blood_erythrocytes_and_lymphocytes","erythrocytes"),
    (r"k01817","phosphoribosylanthranilate_isomerase"),
    (r"k11358","aspartate_aminotransferase"),
    (r"k01626","3-deoxy-7-phosphoheptulonate_synthase"),
    (r"k01667","tryptophanase"),
    (r"\bfe\b", "iron"),
    (r"5-ht", "serotonin"),
    (r"intestinal_gut_enteric_neuropeptides", "neuropeptides"),
    (r"vagal_and_spinal_afferent_neurons", "afferent_neuron"),
    (r"dietary_microbial_metabolites", "metabolite"),
    (r"vitamins", "vitamin"),
    (r"gut_2-keto-glutaramic_acid","glutaramic_acid"),
    (r"\bgastrointestinal_peptide\w*\b","receptors,_gastrointestinal_hormone"),
    (r"\bmicrobiome-derived_metabolite\w*\b","metabolites"),
    (r"krebs_cycle_intermediates","krebs_henseleit_cycle"),
    (r"reactive_oxygen_species", "oxygen"),
    (r"napes","n-acylphosphatidyl_ethanolamines"),
    (r"pro-inflammatory_cytokines","cytokines"),
    (r"php","porphyra_haitanensis_polysaccharide"),
    (r"high-dose_php","porphyra_haitanensis_polysaccharide"),
    (r"\blphp\b","porphyra_haitanensis_polysaccharide"),
    (r"\bhphp\b","porphyra_haitanensis_polysaccharide"),
    (r"cd36","fatty_acid_transporter_interactions"),
    (r"\bacacb\b","fatty_acid_oxidation"),
    (r"\bTriglyceride\w*\b","triglyceride"),
    (r"microbial_metabolites","metabolite"),
    (r"5-hydroxytryptamine","serotonin"),
    (r"ldl-c","ldl_cholesterol_lipoproteins"),
    (r"tcd","total_cholesterol_lipoproteins"),
    (r"tg","tg_protein,_human"),
    (r"mcp-1","monocyte_chemoattractant_protein_1"),
    (r"\bgut_microbiota-associated_epitopes\w*\b","epitopes"),
    (r"mes","epitopes"),
    (r"\bage\w*\b","glycation_end_products,_advanced"),
    (r"central_nervous_system__cns__antigens","antigens"),
    (r"gut_microbiome-modified_polyphenolic_compounds","polyphenol"),
    (r"\b-syn\b","snca_protein,_mouse"),
    (r"\b3_4-dihba\b","3-_3-hydroxyphenyl_propionic_acid"),
    (r"3-hppa","3-(3-hydroxyphenyl)propionic_acid_glucuronide"),
    (r"gja1","gap_junction_alpha-1"),
    (r"paired_box_protein_pax-3","paired_box_protein_3"),
    (r"eyes_absent_homolog_1_isoform_4","eya1_protein,_human"),
    (r"central_monoamine_neurotransmitters","monoamine_neurotransmitters"),
    (r"amino_acid_transmitters","monoamine_neurotransmitters"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))derived_neurotransmitter(?:(?=$)|(?=[^A-Za-z0-9]))","neurotransmitter"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))lipid(?:(?=$)|(?=[^A-Za-z0-9]))","lipid"),
    (r"\bcirculating_lipid\w*\b","lipid"),
    (r"\blipid\w*\b","lipid"),
    (r"\bh2s\b","hydrogen_sulfide"),
    (r"\bintestinal_metabolite\w*\b","metabolite"),
    (r"bdnf","brain-derived_neurotrophic_factor"),
    (r"toll-like_receptor_4","toll-like_receptor_4"),
    (r"toll-like_receptor_2","toll-like_receptor_2"),
    (r"gap43","growth_associated_protein_43"),
    (r"\bfa3r\b","ffar3_protein,_mouse"),
    (r"microbial_tryptophan","tryptophan"),
    (r"tlr4", "toll-like_receptor_4"),
    (r"bioactive_polyphenols","polyphenols"),
    (r"\bhuman_microbiome-associated_functional_amyloid\w*\b","amyloid"),
    (r"hba1c","glycated_hemoglobin_a1c"),
    (r"zo-1","zonula_occludens-1_protein"),
    (r"tlr2","toll-like_receptor_2"),
    (r"tight_junction_proteins","tight_junction_protein_1"),
    (r"gut_microbiota-derived_metabolites","metabolites"),
    (r"sv2c","sv2c_protein,_rat"),
    (r"\bindole\w*\b","indole"),
    (r"gut_iga_levels","gut_iga_level"),
    (r"\blipopolysaccharide\w*\b","lipopolysaccharide"),
    (r"tight_junction_protein","tight_junction_protein_1"),
    (r"\bmelanin\w*\b","melanin"),
    (r"\bneurotransmitter\w*\b","neurotransmitter"),
    (r"\bskin_triglyceride\w*\b","triglyceride"),
    (r"\btc\b","cholesterol"),
    (r"\beyes_absent_homolog_1_isoform_4\b","eya-1_protein,_c_elegans"),

]
for term_raw, uri in manual_created.items():
    uri_str = str(uri)

    # NCIT definitions
    if uri_str.startswith(NCBI_BASE) and "NCIT_" in uri_str:
        ncit_id = uri_str.rsplit("_", 1)[-1]
        desc = get_ncit_description(ncit_id, ncit_file)
        m = re.search(r'—\s*(.*?)\s*—', desc)
        if m:
            desc = m.group(1).strip()
            comment = f"{desc} [Definition Source: NCIT]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # UMLS definitions
    elif uri_str.startswith(UMLS_BASES):
        cui = uri_str.rsplit("/", 1)[-1]
        defn = get_umls_definition(cui)
        if defn:
            comment = f"{defn.strip()} [Definition Source: UMLS]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # MeSH definitions via your mesh_index
    elif uri_str.startswith(MESH_BASE):
        ui     = uri_str.rsplit("/",1)[-1]
        hits   = [d['name'] for d in mesh_descs if d['ui']==ui]
        if hits:
            comment = f"{hits[0]} [Definition Source: MeSH]"
        elif term_raw == "patients":
            comment = "Patients with various diseases. [Definition Source: GUTBRAIN]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    elif uri_str.startswith(HEREDITARY_BASE):
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"
    else:
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    g.add((uri,
           RDFS.comment,
           Literal(comment, datatype=XSD.string)))
    
CREATOR = "Samuel Piron"

mesh_descs   = parse_mesh_descriptors(MESH_XML)
mesh_defs   = load_mesh_definitions(MESH_XML)

for uri in manual_created.values():
    uri_str = str(uri)

    if uri_str.startswith(UMLS_BASES):
        # only a UMLS‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("UMLS Match", datatype=XSD.string)))
    elif "NCIT" in uri_str:
        # only a NCIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("NCIT Match", datatype=XSD.string)))
    elif "OMIT" in uri_str:
        # only a OMIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("OMIT Match", datatype=XSD.string)))
    elif "NCBITaxon" in uri_str:
        # only a NCBITaxon‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("NCBITaxon Match", datatype=XSD.string)))
    elif "CHEBI" in uri_str:
        # only a CHEBI‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("CHEBI Match", datatype=XSD.string)))
    elif "GO" in uri_str:
        # only a FOODON‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("GO Match", datatype=XSD.string)))
    elif "genome" in uri_str:
        # only a KO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("KEGG Match", datatype=XSD.string)))
    elif "mesh" in uri_str:
        # only a MESH‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("MESH Match", datatype=XSD.string)))
    elif "PCO" in uri_str:
        # only a XCO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("PCO Match", datatype=XSD.string)))
    else:
        # everything else still gets a creator
        g.add((uri,
               DCTERMS.creator,
               Literal(CREATOR, datatype=XSD.string)))
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "chemical":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            #lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    #print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, CHEMICAL_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, CHEMICAL_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine_ncbitaxon(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, CHEMICAL_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    
                    s = lbl.strip()
                    s = s.replace("′", "'")    # U+2032 prime → ASCII apostrophe
                    s = s.replace("’", "'")    # U+2019 right single quote → ASCII apostrophe
                    for dash in ["–", "—", "-", "−"]:   # en-dash, em-dash, non-breaking hyphen, minus
                        s = s.replace(dash, "-")

                    if re.fullmatch(r"(?i)pax3['’]", s):
                        label_str = "Pax3"

                    elif re.fullmatch(r"\(S\)\-Lactate", s):
                        label_str = "Lactate"

                    elif re.fullmatch(r"2,3\-Saturated Fatty Acid\(1\-\)", s):
                        label_str = "Saturated Fatty Acid"

                    elif re.fullmatch(r"2,4\-D Choline", s):
                        label_str = "2,4-D Choline"

                    elif s.lower().startswith("adenosine 3'-diphosphate"):
                        label_str = "Adenosine 3-Diphosphate, 5-Triphosphate"

                    elif re.fullmatch(r"5\-Hydroxytryptamine\(1\-\)", s):
                        label_str = "5-Hydroxytryptamine"
                    else:
                        label_str = lbl.title()

                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(label_str, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))

                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                    g.add((entity_uri, RDFS.comment, Literal("CHEBI Match", datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, CHEMICAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    s = lbl.strip()
                    s = s.replace("′", "'")    # U+2032 prime → ASCII apostrophe
                    s = s.replace("’", "'")    # U+2019 right single quote → ASCII apostrophe
                    for dash in ["–", "—", "-", "−"]:   # en-dash, em-dash, non-breaking hyphen, minus
                        s = s.replace(dash, "-")

                    if re.fullmatch(r"(?i)pax3['’]", s):
                        label_str = "Pax3"

                    elif re.fullmatch(r"\(R\)\-Lactic Acid", s):
                        label_str = "Lactic Acid"

                    elif re.fullmatch(r"\(S\)\-Lactate", s):
                        label_str = "Lactate"

                    elif re.fullmatch(r"2,3\-Saturated Fatty Acid\(1\-\)", s):
                        label_str = "Saturated Fatty Acid"

                    elif re.fullmatch(r"2,4\-D Choline", s):
                        label_str = "2,4-D Choline"

                    elif re.fullmatch(r"5'\-D\[Tc\]\-3'", s):
                        label_str = "5-DTc-3"

                    elif s.lower().startswith("adenosine 3'-diphosphate"):
                        label_str = "Adenosine 3-Diphosphate, 5-Triphosphate"

                    elif re.fullmatch(r"5\-Hydroxytryptamine\(1\-\)", s):
                        label_str = "5-Hydroxytryptamine"

                    elif re.match(r"Iron", s):
                        label_str = "Iron"                     
                    else:
                    
                        label_str = lbl.title()
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(label_str, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    g.add((name_uri, RDFS.comment, Literal("CHEBI Match", datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, CHEMICAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    g.add((name_uri, RDFS.comment, Literal("NCIT Match", datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                api_term = lookup_key.replace("_", " ")
                umls_hits = search_umls(api_term)
                if umls_hits:
                    cui, name, score, definition = best_umls_match(api_term, umls_hits)
                    if name in created:
                        entity_uri = created[term_raw]
                    else:
                        entity_uri = URIRef(f"https://uts.nlm.nih.gov/uts/umls/concept/{cui}")
                        created[term_raw] = entity_uri

                    g.add((entity_uri, RDF.type,      CHEMICAL_CLASS))
                    g.add((entity_uri, RDF.type,      SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(name.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                    if definition:
                        comment_str = f"{definition.strip()} [Definition Source: UMLS]"
                    else:
                        llm_def = get_llm_definition(term_raw)
                        comment_str = f"{llm_def} [Definition Source: llama3-8b-8192]"
                    g.add((entity_uri, RDFS.comment, Literal("UMLS Match", datatype=XSD.string)))
            
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,        MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,      Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn,    mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print(f"  • UMLS CUI={cui}  Name={name!r}  sim={score:.2f}")
                    continue
                    
                else: 
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,      MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,    Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    tokenized_mentions[term_raw] = mention_uri
                    print("no matches locally or in UMLS")
        else:
            pass

for paper_id, paper_data in data_gold.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "chemical":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, CHEMICAL_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, CHEMICAL_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine_ncbitaxon(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, CHEMICAL_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    
                    s = lbl.strip()
                    s = s.replace("′", "'")    # U+2032 prime → ASCII apostrophe
                    s = s.replace("’", "'")    # U+2019 right single quote → ASCII apostrophe
                    for dash in ["–", "—", "-", "−"]:   # en-dash, em-dash, non-breaking hyphen, minus
                        s = s.replace(dash, "-")

                    if re.fullmatch(r"(?i)pax3['’]", s):
                        label_str = "Pax3"

                    elif re.fullmatch(r"\(S\)\-Lactate", s):
                        label_str = "Lactate"

                    elif re.fullmatch(r"2,3\-Saturated Fatty Acid\(1\-\)", s):
                        label_str = "Saturated Fatty Acid"

                    elif re.fullmatch(r"2,4\-D Choline", s):
                        label_str = "2,4-D Choline"

                    elif s.lower().startswith("adenosine 3'-diphosphate"):
                        label_str = "Adenosine 3-Diphosphate, 5-Triphosphate"

                    elif re.fullmatch(r"5\-Hydroxytryptamine\(1\-\)", s):
                        label_str = "5-Hydroxytryptamine"
                    else:
                        label_str = lbl.title()

                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(label_str, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))

                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                    g.add((entity_uri, RDFS.comment, Literal("CHEBI Match", datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, CHEMICAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    s = lbl.strip()
                    s = s.replace("′", "'")    # U+2032 prime → ASCII apostrophe
                    s = s.replace("’", "'")    # U+2019 right single quote → ASCII apostrophe
                    for dash in ["–", "—", "-", "−"]:   # en-dash, em-dash, non-breaking hyphen, minus
                        s = s.replace(dash, "-")

                    if re.fullmatch(r"(?i)pax3['’]", s):
                        label_str = "Pax3"

                    elif re.fullmatch(r"\(R\)\-Lactic Acid", s):
                        label_str = "Lactic Acid"

                    elif re.fullmatch(r"\(S\)\-Lactate", s):
                        label_str = "Lactate"

                    elif re.fullmatch(r"2,3\-Saturated Fatty Acid\(1\-\)", s):
                        label_str = "Saturated Fatty Acid"

                    elif re.fullmatch(r"2,4\-D Choline", s):
                        label_str = "2,4-D Choline"

                    elif re.fullmatch(r"5'\-D\[Tc\]\-3'", s):
                        label_str = "5-DTc-3"

                    elif s.lower().startswith("adenosine 3'-diphosphate"):
                        label_str = "Adenosine 3-Diphosphate, 5-Triphosphate"

                    elif re.fullmatch(r"5\-Hydroxytryptamine\(1\-\)", s):
                        label_str = "5-Hydroxytryptamine"

                    elif re.match(r"Iron", s):
                        label_str = "Iron"                     
                    else:
                    
                        label_str = lbl.title()
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(label_str, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    g.add((name_uri, RDFS.comment, Literal("CHEBI Match", datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, CHEMICAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    g.add((name_uri, RDFS.comment, Literal("NCIT Match", datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                api_term = lookup_key.replace("_", " ")
                umls_hits = search_umls(api_term)
                if umls_hits:
                    cui, name, score, definition = best_umls_match(api_term, umls_hits)
                    if name in created:
                        entity_uri = created[term_raw]
                    else:
                        entity_uri = URIRef(f"https://uts.nlm.nih.gov/uts/umls/concept/{cui}")
                        created[term_raw] = entity_uri

                    g.add((entity_uri, RDF.type,      CHEMICAL_CLASS))
                    g.add((entity_uri, RDF.type,      SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(name.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                    if definition:
                        comment_str = f"{definition.strip()} [Definition Source: UMLS]"
                    else:
                        llm_def = get_llm_definition(term_raw)
                        comment_str = f"{llm_def} [Definition Source: llama3-8b-8192]"
                    g.add((entity_uri, RDFS.comment, Literal("UMLS Match", datatype=XSD.string)))
            
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,        MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,      Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn,    mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print(f"  • UMLS CUI={cui}  Name={name!r}  sim={score:.2f}")
                    continue
                    
                else: 
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,      MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,    Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    tokenized_mentions[term_raw] = mention_uri
                    print("no matches locally or in UMLS")
        else:
            pass

for paper_id, paper_data in data_dev.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "chemical":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, CHEMICAL_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, CHEMICAL_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine_ncbitaxon(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, CHEMICAL_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    
                    s = lbl.strip()
                    s = s.replace("′", "'")    # U+2032 prime → ASCII apostrophe
                    s = s.replace("’", "'")    # U+2019 right single quote → ASCII apostrophe
                    for dash in ["–", "—", "-", "−"]:   # en-dash, em-dash, non-breaking hyphen, minus
                        s = s.replace(dash, "-")

                    if re.fullmatch(r"(?i)pax3['’]", s):
                        label_str = "Pax3"

                    elif re.fullmatch(r"\(S\)\-Lactate", s):
                        label_str = "Lactate"

                    elif re.fullmatch(r"2,3\-Saturated Fatty Acid\(1\-\)", s):
                        label_str = "Saturated Fatty Acid"

                    elif re.fullmatch(r"2,4\-D Choline", s):
                        label_str = "2,4-D Choline"

                    elif s.lower().startswith("adenosine 3'-diphosphate"):
                        label_str = "Adenosine 3-Diphosphate, 5-Triphosphate"

                    elif re.fullmatch(r"5\-Hydroxytryptamine\(1\-\)", s):
                        label_str = "5-Hydroxytryptamine"
                    else:
                        label_str = lbl.title()

                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(label_str, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))

                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                    g.add((entity_uri, RDFS.comment, Literal("CHEBI Match", datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, CHEMICAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    s = lbl.strip()
                    s = s.replace("′", "'")    # U+2032 prime → ASCII apostrophe
                    s = s.replace("’", "'")    # U+2019 right single quote → ASCII apostrophe
                    for dash in ["–", "—", "-", "−"]:   # en-dash, em-dash, non-breaking hyphen, minus
                        s = s.replace(dash, "-")

                    if re.fullmatch(r"(?i)pax3['’]", s):
                        label_str = "Pax3"

                    elif re.fullmatch(r"\(R\)\-Lactic Acid", s):
                        label_str = "Lactic Acid"

                    elif re.fullmatch(r"\(S\)\-Lactate", s):
                        label_str = "Lactate"

                    elif re.fullmatch(r"2,3\-Saturated Fatty Acid\(1\-\)", s):
                        label_str = "Saturated Fatty Acid"

                    elif re.fullmatch(r"2,4\-D Choline", s):
                        label_str = "2,4-D Choline"

                    elif re.fullmatch(r"5'\-D\[Tc\]\-3'", s):
                        label_str = "5-DTc-3"

                    elif s.lower().startswith("adenosine 3'-diphosphate"):
                        label_str = "Adenosine 3-Diphosphate, 5-Triphosphate"

                    elif re.fullmatch(r"5\-Hydroxytryptamine\(1\-\)", s):
                        label_str = "5-Hydroxytryptamine"

                    elif re.match(r"Iron", s):
                        label_str = "Iron"                     
                    else:
                    
                        label_str = lbl.title()
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(label_str, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    g.add((name_uri, RDFS.comment, Literal("CHEBI Match", datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, CHEMICAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    g.add((name_uri, RDFS.comment, Literal("NCIT Match", datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                api_term = lookup_key.replace("_", " ")
                umls_hits = search_umls(api_term)
                if umls_hits:
                    cui, name, score, definition = best_umls_match(api_term, umls_hits)
                    if name in created:
                        entity_uri = created[term_raw]
                    else:
                        entity_uri = URIRef(f"https://uts.nlm.nih.gov/uts/umls/concept/{cui}")
                        created[term_raw] = entity_uri

                    g.add((entity_uri, RDF.type,      CHEMICAL_CLASS))
                    g.add((entity_uri, RDF.type,      SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(name.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                    if definition:
                        comment_str = f"{definition.strip()} [Definition Source: UMLS]"
                    else:
                        llm_def = get_llm_definition(term_raw)
                        comment_str = f"{llm_def} [Definition Source: llama3-8b-8192]"
                    g.add((entity_uri, RDFS.comment, Literal("UMLS Match", datatype=XSD.string)))
            
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,        MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,      Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn,    mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print(f"  • UMLS CUI={cui}  Name={name!r}  sim={score:.2f}")
                    continue
                    
                else: 
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,      MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,    Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    tokenized_mentions[term_raw] = mention_uri
                    print("no matches locally or in UMLS")
        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "chemical":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_gold_file, "r", encoding="utf-8") as f_sent:
    tokenized_gold_data = json.load(f_sent)

for entry in tokenized_gold_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "chemical":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_dev, "r", encoding="utf-8") as f_sent:
    tokenized_dev_data = json.load(f_sent)

for entry in tokenized_dev_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "chemical":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))
# Out:
# Query: monosaccharide
# lookup term: monosaccharide
#   • monosaccharide                           URI=http://purl.obolibrary.org/obo/CHEBI_35381
# Query: saturated fatty acid
# lookup term: saturated_fatty_acid
#   • saturated fatty acid                     URI=http://purl.obolibrary.org/obo/CHEBI_26607
# Query: monounsaturated fatty acid
# lookup term: monounsaturated_fatty_acids
#   • monounsaturated fatty acid               URI=http://purl.obolibrary.org/obo/CHEBI_25413
# Query: metabolite acetate
# lookup term: metabolite_acetate
#   • metabolite                               URI=http://purl.obolibrary.org/obo/CHEBI_25212 score=0.81
#
# Query: monosaccharide
# lookup term: monosaccharide
#   • monosaccharide                           URI=http://purl.obolibrary.org/obo/CHEBI_35381
# Query: amyloid beta-peptides
# lookup term: amyloid_beta-peptides
#   • amyloid-beta                             URI=http://purl.obolibrary.org/obo/CHEBI_64645 score=1.00
#
# Query: interleukin 6
# lookup term: interleukin_6
#   • interleukins                             URI=http://purl.obolibrary.org/obo/CHEBI_52998 score=1.00
#
# Query: il-17
# lookup term: il-17
#   • UMLS CUI=C1623218  Name='IL-17 activity'  sim=0.72
# Query: serum hormone
# lookup term: serum_hormone
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/SerumHormone
#
#
# Query: insulin
# lookup term: insulin
#   • insulin                                  URI=http://purl.obolibrary.org/obo/CHEBI_145810
# Query: testosterone
# lookup term: testosterone
#   • testosterone                             URI=http://purl.obolibrary.org/obo/CHEBI_17347
# Query: skin lipid
# lookup term: skin_lipids
#   • Lipid                                    URI=http://purl.obolibrary.org/obo/NCIT_C616 score=0.82
#
# Query: triglyceride
# lookup term: triglyceride
#   • triglyceride                             URI=http://purl.obolibrary.org/obo/CHEBI_17855
# Query: non-esterified free fatty acid
# lookup term: non-esterified_free_fatty_acids
#   • Free Non-esterified Fatty Acids Measurement URI=http://purl.obolibrary.org/obo/NCIT_C80181 score=0.79
#
# Query: triglyceride
# lookup term: triglyceride
#   • triglyceride                             URI=http://purl.obolibrary.org/obo/CHEBI_17855
# Query: hormone
# lookup term: hormones
#   • hormone                                  URI=http://purl.obolibrary.org/obo/CHEBI_24621
# Query: skin lipid
# lookup term: skin_lipids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C616
#
#
# Query: melanin
# lookup term: melanin
#   • Melanin                                  URI=http://purl.obolibrary.org/obo/CHEBI_89634
# Query: melanin
# lookup term: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_89634
#
#
# Query: oxygen
# lookup term: oxygen
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0030054
#
# Query: melanin
# lookup term: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_89634
#
#
# Query: melanin
# lookup term: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_89634
#
#
# Query: melanin
# lookup term: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_89634
#
#
# Query: neuromelanin
# lookup term: neuromelanin
#   • UMLS CUI=C0068608  Name='neuromelanin'  sim=1.00
# Query: herpesvirus
# lookup term: herpesvirus
#   • Herpesvirus                              URI=http://purl.obolibrary.org/obo/NCIT_C14217 score=1.00
#
# Query: melanosome
# lookup term: melanosome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/GO_0042470
#
# Query: herpesvirus
# lookup term: herpesvirus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14217
#
#
# Query: melanin
# lookup term: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_89634
#
#
# Query: atp
# lookup term: atp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_15422
#
#
# Query: melanin
# lookup term: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_89634
#
#
# Query: atp
# lookup term: atp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_15422
#
#
# Query: atp
# lookup term: atp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_15422
#
#
# Query: melanin
# lookup term: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_89634
#
#
# Query: melanin
# lookup term: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_89634
#
#
# Query: flavonoid
# lookup term: flavonoids
#   • flavonoid                                URI=http://purl.obolibrary.org/obo/CHEBI_47916
# Query: isorhamnetin
# lookup term: isorhamnetin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_6052
#
#
# Query: quercetin
# lookup term: quercetin
#   • quercetin                                URI=http://purl.obolibrary.org/obo/CHEBI_16243
# Query: kaempferol
# lookup term: kaempferol
#   • kaempferol                               URI=http://purl.obolibrary.org/obo/CHEBI_28499
# Query: neurotrophins
# lookup term: neurotrophins
#   • Recombinant Neurotrophins                URI=http://purl.obolibrary.org/obo/NCIT_C1396 score=0.85
#
# Query: neurotransmitter
# lookup term: neurotransmitter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C687
#
# Query: hormone
# lookup term: hormone
#   • hormone                                  URI=http://purl.obolibrary.org/obo/CHEBI_24621
# Query: cytokine
# lookup term: cytokine
#   • Cytokine                                 URI=http://purl.obolibrary.org/obo/NCIT_C20464 score=1.00
#
# Query: compound
# lookup term: compound
#   • Compound D                               URI=http://purl.obolibrary.org/obo/CHEBI_228264 score=1.00
#
# Query: compound
# lookup term: compound
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_228264
#
#
# Query: compound
# lookup term: compound
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_228264
#
#
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   • gamma-aminobutyric acid                  URI=http://purl.obolibrary.org/obo/CHEBI_16865
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: serotonin
# lookup term: serotonin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28790
#
#
# Query: melatonin
# lookup term: melatonin
#   • melatonin                                URI=http://purl.obolibrary.org/obo/CHEBI_16796
# Query: kynurenine
# lookup term: kynurenine
#   • kynurenine                               URI=http://purl.obolibrary.org/obo/CHEBI_28683
# Query: kynurenine
# lookup term: kynurenine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28683
#
# Query: dopamine
# lookup term: dopamine
#   • dopamine                                 URI=http://purl.obolibrary.org/obo/CHEBI_18243
# Query: norepinephrine
# lookup term: norepinephrine
#   • Norepinephrine sulfate                   URI=http://purl.obolibrary.org/obo/CHEBI_90022 score=0.89
#
# Query: histamine
# lookup term: histamine
#   • histamine                                URI=http://purl.obolibrary.org/obo/CHEBI_18295
# Query: tryptamine
# lookup term: tryptamine
#   • tryptamine                               URI=http://purl.obolibrary.org/obo/CHEBI_16765
# Query: tyramine
# lookup term: tyramine
#   • tyramine                                 URI=http://purl.obolibrary.org/obo/CHEBI_15760
# Query: -phenylethylamine
# lookup term: -phenylethylamine
#   • 1-phenylethylamine                       URI=http://purl.obolibrary.org/obo/CHEBI_670 score=1.00
#
# Query: compound
# lookup term: compound
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_228264
#
#
# Query: compound
# lookup term: compound
#   • Compound D                               URI=http://purl.obolibrary.org/obo/CHEBI_228264 score=1.00
#
# Query: compound
# lookup term: compound
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_228264
#
#
# Query: compound
# lookup term: compound
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_228264
#
#
# Query: metabolite
# lookup term: metabolite
#   • metabolite                               URI=http://purl.obolibrary.org/obo/CHEBI_25212
# Query: compound
# lookup term: compound
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_228264
#
#
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: compound
# lookup term: compound
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_228264
#
#
# Query: -aminobutyric acid
# lookup term: -aminobutyric_acid
#   • L-3-Aminobutyric acid                    URI=http://purl.obolibrary.org/obo/CHEBI_229980 score=1.00
#
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: acetylcholine
# lookup term: acetylcholine
#   • acetylcholine                            URI=http://purl.obolibrary.org/obo/CHEBI_15355
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: acetylcholine
# lookup term: acetylcholine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_15355
#
#
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acids
#   • short-chain fatty acid                   URI=http://purl.obolibrary.org/obo/CHEBI_26666 score=1.00
#
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acid
#   • short-chain fatty acid                   URI=http://purl.obolibrary.org/obo/CHEBI_26666 score=1.00
#
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: acetylcholine
# lookup term: acetylcholine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_15355
#
#
# Query: glutamate
# lookup term: glutamate
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0220839
#
#
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acids
#   • short-chain fatty acid                   URI=http://purl.obolibrary.org/obo/CHEBI_26666
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: vitamin b6
# lookup term: vitamin_b6
#   • vitamin B6                               URI=http://purl.obolibrary.org/obo/CHEBI_27306
# Query: fatty acid
# lookup term: fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C492
#
#
# Query: metabolite
# lookup term: metabolite
#   • metabolite                               URI=http://purl.obolibrary.org/obo/CHEBI_25212
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
#
# Query: arachidonic acid
# lookup term: arachidonic_acid
#   • arachidonic acid                         URI=http://purl.obolibrary.org/obo/CHEBI_15843
# Query: sphingomyelin
# lookup term: sphingomyelin
#   • sphingomyelin                            URI=http://purl.obolibrary.org/obo/CHEBI_64583
# Query: dextran sulfate sodium
# lookup term: dextran_sulfate_sodium
#   • dextran sulfate sodium                   URI=http://purl.obolibrary.org/obo/CHEBI_191875
# Query: dextran sulfate sodium
# lookup term: dextran_sulfate_sodium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_191875
#
#
# Query: dextran sulfate sodium
# lookup term: dextran_sulfate_sodium
#   • dextran sulfate sodium                   URI=http://purl.obolibrary.org/obo/CHEBI_191875
# Query: lipopolysaccharide
# lookup term: lipopolysaccharide
#   • lipopolysaccharide                       URI=http://purl.obolibrary.org/obo/CHEBI_16412
# Query: lipopolysaccharide
# lookup term: lipopolysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16412
#
# Query: dextran sulfate sodium
# lookup term: dextran_sulfate_sodium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_191875
#
#
# Query: dextran sulfate sodium
# lookup term: dextran_sulfate_sodium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_191875
#
#
# Query: dextran sulfate sodium
# lookup term: dextran_sulfate_sodium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_191875
#
#
# Query: lipopolysaccharide
# lookup term: lipopolysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16412
#
# Query: paraquat
# lookup term: paraquat
#   • paraquat                                 URI=http://purl.obolibrary.org/obo/CHEBI_34905
# Query: lipocalin-2
# lookup term: lipocalin-2
#   • Lipocalin-2 Measurement                  URI=http://purl.obolibrary.org/obo/NCIT_C106539 score=0.92
#
# Query: interleukin 6
# lookup term: interleukin_6
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_52998
#
#
# Query: dextran sulfate sodium
# lookup term: dextran_sulfate_sodium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_191875
#
#
# Query: xingpijieyu formula
# lookup term: xingpijieyu_formula
#   • Chemical Formula                         URI=http://purl.obolibrary.org/obo/NCIT_C48808 score=0.76
#
# Query: xingpijieyu formula
# lookup term: xingpijieyu_formula
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C48808
#
#
# Query: xingpijieyu formula
# lookup term: xingpijieyu_formula
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C48808
#
# Query: xingpijieyu formula
# lookup term: xingpijieyu_formula
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C48808
#
# Query: serum cytokine
# lookup term: serum_cytokines
#   • Cytokine                                 URI=http://purl.obolibrary.org/obo/NCIT_C20464 score=0.76
#
# Query: glial fibrillary acidic protein
# lookup term: glial_fibrillary_acidic_protein
#   • Glial Fibrillary Acidic Protein          URI=http://purl.obolibrary.org/obo/NCIT_C68804 score=1.00
#
# Query: glial fibrillary acidic protein
# lookup term: glial_fibrillary_acidic_protein
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C68804
#
# Query: xingpijieyu formula
# lookup term: xingpijieyu_formula
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C48808
#
# Query: lipopolysaccharide
# lookup term: lipopolysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16412
#
#
# Query: lipopolysaccharide
# lookup term: lipopolysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16412
#
# Query: cytokine
# lookup term: cytokines
#   • Cytokine                                 URI=http://purl.obolibrary.org/obo/NCIT_C20464 score=1.00
#
# Query: 2-deoxy-d-glucose
# lookup term: 2-deoxy-d-glucose
#   • 2-deoxy-D-glucose                        URI=http://purl.obolibrary.org/obo/CHEBI_15866
# Query: 2-deoxy-d-glucose
# lookup term: 2-deoxy-d-glucose
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_15866
#
# Query: adenosine triphosphate
# lookup term: adenosine_triphosphate
#   • adenosine 3'-diphosphate,5'-triphosphate(6-) URI=http://purl.obolibrary.org/obo/CHEBI_145540 score=0.86
#
# Query: atp
# lookup term: atp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_15422
#
#
# Query: glucose-1-phosphate
# lookup term: glucose-1-phosphate
#   • D-glucose 6-phosphate                    URI=http://purl.obolibrary.org/obo/CHEBI_14314 score=1.00
#
# Query: glucose-1-phosphate
# lookup term: glucose-1-phosphate
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_14314
#
# Query: xingpijieyu formula
# lookup term: xingpijieyu_formula
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C48808
#
# Query: glucose-1-phosphate metabolism
# lookup term: glucose-1-phosphate_metabolism
#   • D-glucose 6-phosphate                    URI=http://purl.obolibrary.org/obo/CHEBI_14314 score=1.00
#
# Query: xingpijieyu formula
# lookup term: xingpijieyu_formula
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C48808
#
# Query: xingpijieyu formula
# lookup term: xingpijieyu_formula
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C48808
#
# Query: atp
# lookup term: atp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_15422
#
#
# Query: glucose-1-phosphate
# lookup term: glucose-1-phosphate
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_14314
#
#
# Query: xingpijieyu formula
# lookup term: xingpijieyu_formula
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C48808
#
# Query: interferon-
# lookup term: interferon-
#   • interferon                               URI=http://purl.obolibrary.org/obo/CHEBI_52999 score=1.00
#
# Query: tumor necrosis factor-
# lookup term: tumor_necrosis_factor-
#   • Recombinant Tumor Necrosis Factor-alpha (human) URI=http://purl.obolibrary.org/obo/CHEBI_197440 score=0.77
#
# Query: indole
# lookup term: indole
#   • indole                                   URI=http://purl.obolibrary.org/obo/CHEBI_35581
# Query: maltotriose
# lookup term: maltotriose
#   • maltotriose                              URI=http://purl.obolibrary.org/obo/CHEBI_61993
# Query: isomaltose
# lookup term: isomaltose
#   • isomaltose                               URI=http://purl.obolibrary.org/obo/CHEBI_28189
# Query: anandamide
# lookup term: anandamide
#   • anandamide                               URI=http://purl.obolibrary.org/obo/CHEBI_2700
# Query: synaptic cast protein, human
# lookup term: synaptic_cast_protein,_human
#   • UMLS CUI=C1144501  Name='synaptic CAST protein, human'  sim=1.00
# Query: growth associated protein 43
# lookup term: growth_associated_protein_43
#   • UMLS CUI=C0068563  Name='Growth Associated Protein 43'  sim=1.00
# Query: sv2c protein, rat
# lookup term: sv2c_protein,_rat
#   • Rat Protein                              URI=http://purl.obolibrary.org/obo/NCIT_C26534 score=1.00
#
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acid
#   • short-chain fatty acid                   URI=http://purl.obolibrary.org/obo/CHEBI_26666
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: claudin-2
# lookup term: claudin-2
#   • Claudin-7                                URI=http://purl.obolibrary.org/obo/NCIT_C201780 score=1.00
#
# Query: epinephrine
# lookup term: epinephrine
#   • Epinephrine sulfate                      URI=http://purl.obolibrary.org/obo/CHEBI_89878 score=0.88
#
# Query: norepinephrine
# lookup term: norepinephrine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_90022
#
#
# Query: mediator
# lookup term: mediators
#   • Mediator                                 URI=http://purl.obolibrary.org/obo/NCIT_C61426 score=1.00
#
# Query: defensins
# lookup term: defensins
#   • Defensins                                URI=http://purl.obolibrary.org/obo/NCIT_C1063 score=1.00
#
# Query: vitamin d
# lookup term: vitamin_d
#   • vitamin D                                URI=http://purl.obolibrary.org/obo/CHEBI_27300
# Query: tryptophan
# lookup term: tryptophan
#   • tryptophan                               URI=http://purl.obolibrary.org/obo/CHEBI_27897
# Query: wheat gluten
# lookup term: wheat_gluten
#   • Wheat Gluten                             URI=http://purl.obolibrary.org/obo/NCIT_C84242 score=1.00
#
# Query: bovine milk plasma
# lookup term: bovine_milk_plasma
#   • UMLS CUI=C5873086  Name='Bovine Milk Plasma'  sim=1.00
# Query: antigen
# lookup term: antigens
#   • antigen                                  URI=http://purl.obolibrary.org/obo/CHEBI_59132
# Query: complement c1q
# lookup term: complement_c1q
#   • Complement C1q Measurement               URI=http://purl.obolibrary.org/obo/NCIT_C186029 score=0.94
#
# Query: serum metabolome
# lookup term: serum_metabolome
#   • Serum                                    URI=http://purl.obolibrary.org/obo/NCIT_C13325 score=1.00
#
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
#
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acid
#   • short-chain fatty acid                   URI=http://purl.obolibrary.org/obo/CHEBI_26666 score=1.00
#
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: tight junction protein 1
# lookup term: tight_junction_protein_1
#   • Tight Junction                           URI=http://purl.obolibrary.org/obo/NCIT_C13333 score=0.94
#
# Query: zonula occludens-1 protein
# lookup term: zonula_occludens-1_protein
#   • C-Protein                                URI=http://purl.obolibrary.org/obo/CHEBI_3254 score=1.00
#
# Query: claudin
# lookup term: claudin
#   • Claudin-7                                URI=http://purl.obolibrary.org/obo/NCIT_C201780 score=1.00
#
# Query: occludin
# lookup term: occludin
#   • UMLS CUI=C0250400  Name='occludin'  sim=1.00
# Query: cytokine
# lookup term: cytokines
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C20464
#
# Query: interleukin-1
# lookup term: interleukin-1
#   • interleukins                             URI=http://purl.obolibrary.org/obo/CHEBI_52998 score=1.00
#
# Query: interleukin 6
# lookup term: interleukin_6
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_52998
#
#
# Query: butyrate
# lookup term: butyrate
#   • butyrate                                 URI=http://purl.obolibrary.org/obo/CHEBI_17968
# Query: trichloroethylene
# lookup term: trichloroethylene
#   • Trichloroethylene                        URI=http://purl.obolibrary.org/obo/NCIT_C44459 score=1.00
#
# Query: pesticide
# lookup term: pesticides
#   • pesticide                                URI=http://purl.obolibrary.org/obo/CHEBI_25944
# Query: metal
# lookup term: metals
#   • metal sulfate                            URI=http://purl.obolibrary.org/obo/CHEBI_51336 score=0.84
#
# Query: organic solvent
# lookup term: organic_solvents
#   • solvent                                  URI=http://purl.obolibrary.org/obo/CHEBI_46787 score=0.79
#
# Query: trichloroethylene
# lookup term: trichloroethylene
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C44459
#
#
# Query: trichloroethylene
# lookup term: trichloroethylene
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C44459
#
# Query: trichloroethylene
# lookup term: trichloroethylene
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C44459
#
# Query: trichloroethylene
# lookup term: trichloroethylene
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C44459
#
# Query: trichloroethylene
# lookup term: trichloroethylene
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C44459
#
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: lactic acid
# lookup term: lactic_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_42111
#
# Query: interleukin-1
# lookup term: interleukin-1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_52998
#
#
# Query: interleukin-2
# lookup term: interleukin-2
#   • interleukins                             URI=http://purl.obolibrary.org/obo/CHEBI_52998 score=1.00
#
# Query: interleukin-4
# lookup term: interleukin-4
#   • interleukins                             URI=http://purl.obolibrary.org/obo/CHEBI_52998 score=1.00
#
# Query: interleukin 6
# lookup term: interleukin_6
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_52998
#
#
# Query: il-13
# lookup term: il-13
#   • UMLS CUI=C0214743  Name='Interleukin-13'  sim=0.32
# Query: il-18
# lookup term: il-18
#   • UMLS CUI=C0383327  Name='Interleukin-18'  sim=0.32
# Query: csf 39300/gm-csf
# lookup term: csf_39300/gm-csf
#   • GM-CSF Receptor                          URI=http://purl.obolibrary.org/obo/NCIT_C38991 score=0.86
#
# Query: interferon
# lookup term: interferons
#   • interferon                               URI=http://purl.obolibrary.org/obo/CHEBI_52999
# Query: tnf protein, human
# lookup term: tnf_protein,_human
#   • UMLS CUI=C1448177  Name='TNF protein, human'  sim=1.00
# Query: interferon
# lookup term: interferons
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_52999
#
#
# Query: tnf protein, human
# lookup term: tnf_protein,_human
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1448177
#
#
# Query: tnf protein, human
# lookup term: tnf_protein,_human
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1448177
#
#
# Query: interferon
# lookup term: interferons
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_52999
#
#
# Query: tnf protein, human
# lookup term: tnf_protein,_human
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1448177
#
#
# Query: interferon
# lookup term: interferons
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_52999
#
#
# Query: exopolysaccharide
# lookup term: exopolysaccharide
#   • exopolysaccharide                        URI=http://purl.obolibrary.org/obo/CHEBI_72813
# Query: exopolysaccharide
# lookup term: exopolysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_72813
#
#
# Query: exopolysaccharide
# lookup term: exopolysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_72813
#
# Query: exopolysaccharide
# lookup term: exopolysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_72813
#
# Query: exopolysaccharide
# lookup term: exopolysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_72813
#
# Query: exopolysaccharide
# lookup term: exopolysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_72813
#
# Query: exopolysaccharide
# lookup term: exopolysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_72813
#
# Query: exopolysaccharide
# lookup term: exopolysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_72813
#
# Query: hydrogen sulfide
# lookup term: hydrogen_sulfide
#   • hydrogen sulfide                         URI=http://purl.obolibrary.org/obo/CHEBI_16136
# Query: hydrogen sulfide
# lookup term: hydrogen_sulfide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16136
#
#
# Query: hydrogen sulfide
# lookup term: hydrogen_sulfide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16136
#
# Query: hydrogen sulfide
# lookup term: hydrogen_sulfide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16136
#
# Query: hydrogen sulfide
# lookup term: hydrogen_sulfide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16136
#
# Query: hydrogen sulfide
# lookup term: hydrogen_sulfide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16136
#
# Query: cytochrome c protein
# lookup term: cytochrome_c_protein
#   • cytochrome f                             URI=http://purl.obolibrary.org/obo/CHEBI_38556 score=0.77
#
# Query: oxygen
# lookup term: oxygen
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0030054
#
# Query: alpha-synuclein oligomers
# lookup term: alpha-synuclein_oligomers
#   • N(alpha),N(alpha),N(alpha)-trimethyl-L-histidine URI=http://purl.obolibrary.org/obo/CHEBI_15781 score=0.80
#
# Query: alpha-synuclein protein
# lookup term: alpha-synuclein_protein
#   • Protein C                                URI=http://purl.obolibrary.org/obo/CHEBI_82131 score=0.88
#
# Query: hydrogen sulfide
# lookup term: hydrogen_sulfide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16136
#
# Query: erythrocyte
# lookup term: erythrocytes
#   • Erythrocyte                              URI=http://purl.obolibrary.org/obo/NCIT_C12521 score=1.00
#
# Query: metabolite
# lookup term: metabolite
#   • metabolite                               URI=http://purl.obolibrary.org/obo/CHEBI_25212
# Query: trp
# lookup term: trp
#   • Trp-P-1                                  URI=http://purl.obolibrary.org/obo/CHEBI_82376 score=1.00
#
# Query: phosphoribosylanthranilate isomerase
# lookup term: phosphoribosylanthranilate_isomerase
#   → Reusing existing URI: https://www.genome.jp/dbget-bin/www_bget?ko:K01817
#
# Query: aspartate aminotransferase
# lookup term: aspartate_aminotransferase
#   → Reusing existing URI: https://www.genome.jp/dbget-bin/www_bget?ko:K11358
#
# Query: 3-deoxy-7-phosphoheptulonate synthase
# lookup term: 3-deoxy-7-phosphoheptulonate_synthase
#   → Reusing existing URI: https://www.genome.jp/dbget-bin/www_bget?ko:K01626
#
# Query: tryptophanase
# lookup term: tryptophanase
#   → Reusing existing URI: https://www.genome.jp/dbget-bin/www_bget?K01667
#
# Query: 3-deoxy-7-phosphoheptulonate synthase
# lookup term: 3-deoxy-7-phosphoheptulonate_synthase
#   → Reusing existing URI: https://www.genome.jp/dbget-bin/www_bget?ko:K01626
#
# Query: iron
# lookup term: iron
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C598
#
# Query: rhepo
# lookup term: rhepo
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/Rhepo
#
#
# Query: iron
# lookup term: iron
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C598
#
# Query: rhepo
# lookup term: rhepo
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/Rhepo
#
#
# Query: iron
# lookup term: iron
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C598
#
# Query: rhepo
# lookup term: rhepo
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/Rhepo
#
#
# Query: rhepo
# lookup term: rhepo
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/Rhepo
#
#
# Query: iron
# lookup term: iron
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C598
#
# Query: serotonin
# lookup term: serotonin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28790
#
#
# Query: serotonin
# lookup term: serotonin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28790
#
# Query: serotonin
# lookup term: serotonin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28790
#
# Query: long-chain fatty acid
# lookup term: long-chain_fatty_acids
#   • long-chain fatty acid                    URI=http://purl.obolibrary.org/obo/CHEBI_15904
# Query: bile acid
# lookup term: bile_acids
#   • bile acid                                URI=http://purl.obolibrary.org/obo/CHEBI_3098
# Query: starch
# lookup term: starch
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C68488
#
# Query: -glucuronidase
# lookup term: -glucuronidase
#   • Glucuronidase Inhibitor                  URI=http://purl.obolibrary.org/obo/NCIT_C1017 score=0.88
#
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: bile acid
# lookup term: bile_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_3098
#
#
# Query: dna methylation
# lookup term: dna_methylation
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0376452
#
#
# Query: enteric glial cell network
# lookup term: enteric_glial_cells_network
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/EntericGlialCellsNetwork
#
#
# Query: neuropeptides
# lookup term: neuropeptides
#   • UMLS CUI=C0027895  Name='Neuropeptides'  sim=1.00
# Query: afferent neuron
# lookup term: afferent_neuron
#   • Visceral Afferent Neuron                 URI=http://purl.obolibrary.org/obo/NCIT_C33877 score=0.86
#
# Query: gut hormone
# lookup term: gut_hormones
#   • UMLS CUI=C0684155  Name='gut hormone'  sim=0.34
# Query: cytokine
# lookup term: cytokines
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C20464
#
#
# Query: microbially-derived neurotransmitter
# lookup term: microbially-derived_neurotransmitters
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/MicrobiallyDerivedNeurotransmitters
#
#
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: metabolite
# lookup term: metabolite
#   • metabolite                               URI=http://purl.obolibrary.org/obo/CHEBI_25212
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: indole
# lookup term: indole
#   • indole                                   URI=http://purl.obolibrary.org/obo/CHEBI_35581
# Query: bile acid
# lookup term: bile_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_3098
#
#
# Query: choline metabolite
# lookup term: choline_metabolites
#   • 2,4-D choline                            URI=http://purl.obolibrary.org/obo/CHEBI_145558 score=0.76
#
# Query: lactate
# lookup term: lactate
#   • lactate                                  URI=http://purl.obolibrary.org/obo/CHEBI_24996
# Query: vitamin
# lookup term: vitamin
#   • vitamin D                                URI=http://purl.obolibrary.org/obo/CHEBI_27300 score=1.00
#
# Query: atp
# lookup term: atp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_15422
#
#
# Query: adp
# lookup term: adp
#   • ADP                                      URI=http://purl.obolibrary.org/obo/CHEBI_16761
# Query: krebs henseleit cycle
# lookup term: krebs_henseleit_cycle
#   • UMLS CUI=C0599588  Name='Krebs Henseleit cycle'  sim=1.00
# Query: oxygen
# lookup term: oxygen
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0030054
#
#
# Query: oxygen
# lookup term: oxygen
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0030054
#
# Query: ro
# lookup term: ros
#   • Anti-Ro Antibody                         URI=http://purl.obolibrary.org/obo/NCIT_C121322 score=0.81
#
# Query: n-acylphosphatidyl ethanolamines
# lookup term: n-acylphosphatidyl_ethanolamines
#   • ethanolamines                            URI=http://purl.obolibrary.org/obo/CHEBI_23981 score=1.00
#
# Query: n-acylphosphatidyl ethanolamines
# lookup term: n-acylphosphatidyl_ethanolamines
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_23981
#
# Query: lipid
# lookup term: lipid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C616
#
# Query: n-acyl-phosphatidylethanolamines
# lookup term: n-acyl-phosphatidylethanolamines
#   • N-acyl-amino acid                        URI=http://purl.obolibrary.org/obo/CHEBI_51569 score=0.79
#
# Query: n-acylphosphatidyl ethanolamines
# lookup term: n-acylphosphatidyl_ethanolamines
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_23981
#
# Query: n-acylphosphatidyl ethanolamines
# lookup term: n-acylphosphatidyl_ethanolamines
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_23981
#
# Query: n-acylphosphatidyl ethanolamines
# lookup term: n-acylphosphatidyl_ethanolamines
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_23981
#
# Query: n-acylphosphatidyl ethanolamines
# lookup term: n-acylphosphatidyl_ethanolamines
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_23981
#
# Query: n-acylphosphatidyl ethanolamines
# lookup term: n-acylphosphatidyl_ethanolamines
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_23981
#
# Query: lipid
# lookup term: lipid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C616
#
# Query: cytokine
# lookup term: cytokines
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C20464
#
# Query: tight junction protein 1
# lookup term: tight_junction_protein_1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C13333
#
#
# Query: porphyra haitanensis polysaccharide
# lookup term: porphyra_haitanensis_polysaccharides
#   • Polysaccharide                           URI=http://purl.obolibrary.org/obo/NCIT_C28179 score=1.00
#
# Query: lipid
# lookup term: lipid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C616
#
# Query: porphyra haitanensis polysaccharide
# lookup term: porphyra_haitanensis_polysaccharide
#   • Polysaccharide                           URI=http://purl.obolibrary.org/obo/NCIT_C28179 score=1.00
#
# Query: porphyra haitanensis polysaccharide
# lookup term: porphyra_haitanensis_polysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C28179
#
# Query: blood lipid
# lookup term: blood_lipids
#   • Lipid                                    URI=http://purl.obolibrary.org/obo/NCIT_C616 score=0.81
#
# Query: porphyra haitanensis polysaccharide
# lookup term: porphyra_haitanensis_polysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C28179
#
# Query: serum total cholesterol
# lookup term: serum_total_cholesterol
#   • Serum Total Cholesterol Measurement      URI=http://purl.obolibrary.org/obo/NCIT_C61032 score=0.94
#
# Query: triglyceride
# lookup term: triglyceride
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_17855
#
#
# Query: low-density lipoprotein cholesterol
# lookup term: low-density_lipoprotein_cholesterol
#   • low-density lipoprotein cholesterol      URI=http://purl.obolibrary.org/obo/CHEBI_47774
# Query: porphyra haitanensis polysaccharide
# lookup term: porphyra_haitanensis_polysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C28179
#
# Query: butyric acid
# lookup term: butyric_acid
#   • butyric acid                             URI=http://purl.obolibrary.org/obo/CHEBI_30772
# Query: porphyra haitanensis polysaccharide
# lookup term: porphyra_haitanensis_polysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C28179
#
# Query: porphyra haitanensis polysaccharide
# lookup term: porphyra_haitanensis_polysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C28179
#
# Query: porphyra haitanensis polysaccharide
# lookup term: porphyra_haitanensis_polysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C28179
#
# Query: porphyra haitanensis polysaccharide
# lookup term: porphyra_haitanensis_polysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C28179
#
# Query: phosphatidylcholine metabolite
# lookup term: phosphatidylcholine_metabolites
#   • metabolite                               URI=http://purl.obolibrary.org/obo/CHEBI_25212 score=0.77
#
# Query: porphyra haitanensis polysaccharide
# lookup term: porphyra_haitanensis_polysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C28179
#
# Query: triglyceride
# lookup term: triglyceride
#   • triglyceride                             URI=http://purl.obolibrary.org/obo/CHEBI_17855
# Query: fatty acid transporter interaction
# lookup term: fatty_acid_transporter_interactions
#   • UMLS CUI=C3668481  Name='Fatty Acid Transporter Interactions'  sim=1.00
# Query: fatty acid oxidation
# lookup term: fatty_acid_oxidation
#   • fatty acid oxidation inhibitor           URI=http://purl.obolibrary.org/obo/CHEBI_133190 score=0.90
#
# Query: porphyra haitanensis polysaccharide
# lookup term: porphyra_haitanensis_polysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C28179
#
# Query: metabolite
# lookup term: metabolite
#   • metabolite                               URI=http://purl.obolibrary.org/obo/CHEBI_25212
# Query: metabolite
# lookup term: metabolite
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25212
#
#
# Query: microflora metabolite
# lookup term: microflora_metabolites
#   • metabolite                               URI=http://purl.obolibrary.org/obo/CHEBI_25212 score=1.00
#
# Query: metabolite
# lookup term: metabolite
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25212
#
#
# Query: 3-dehydrocarnitine
# lookup term: 3-dehydrocarnitine
#   • 3-dehydrocarnitine                       URI=http://purl.obolibrary.org/obo/CHEBI_57885
# Query: epiandrosterone sulfate
# lookup term: epiandrosterone_sulfate
#   • epiandrosterone sulfate                  URI=http://purl.obolibrary.org/obo/CHEBI_83040
# Query: leucine
# lookup term: leucine
#   • leucine                                  URI=http://purl.obolibrary.org/obo/CHEBI_25017
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: kynurenine
# lookup term: kynurenine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28683
#
#
# Query: norepinephrine
# lookup term: norepinephrine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_90022
#
#
# Query: glutamate
# lookup term: glutamate
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0220839
#
#
# Query: tryptophan
# lookup term: tryptophan
#   • tryptophan                               URI=http://purl.obolibrary.org/obo/CHEBI_27897
# Query: dopamine
# lookup term: dopamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_18243
#
#
# Query: epinephrine
# lookup term: epinephrine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_89878
#
#
# Query: -aminobutyric acid
# lookup term: -aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_229980
#
#
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: gamma-aminobutyric acid
# lookup term: gamma-aminobutyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: cholesterol
# lookup term: cholesterol
#   • cholesterol                              URI=http://purl.obolibrary.org/obo/CHEBI_16113
# Query: serotonin
# lookup term: serotonin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28790
#
# Query: serotonin
# lookup term: serotonin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28790
#
# Query: serotonin
# lookup term: serotonin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28790
#
# Query: ldl cholesterol lipoprotein
# lookup term: ldl_cholesterol_lipoproteins
#   • lipoprotein cholesterol                  URI=http://purl.obolibrary.org/obo/CHEBI_50404 score=0.75
#
# Query: cholesterol
# lookup term: cholesterol
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16113
#
# Query: tg protein, human
# lookup term: tg_protein,_human
#   • UMLS CUI=C5196781  Name='TG protein, human'  sim=1.00
# Query: interleukin-1
# lookup term: interleukin-1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_52998
#
#
# Query: monocyte chemoattractant protein 1
# lookup term: monocyte_chemoattractant_protein_1
#   • Monocyte Chemoattractant Protein-1       URI=http://purl.obolibrary.org/obo/NCIT_C20482 score=1.00
#
# Query: il-17a
# lookup term: il-17a
#   • UMLS CUI=C1705947  Name='Interleukin-17A'  sim=0.38
# Query: monocyte chemoattractant protein 1
# lookup term: monocyte_chemoattractant_protein_1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C20482
#
#
# Query: serotonin
# lookup term: serotonin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28790
#
# Query: monocyte chemoattractant protein 1
# lookup term: monocyte_chemoattractant_protein_1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C20482
#
#
# Query: il-17a
# lookup term: il-17a
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1705947
#
#
# Query: serotonin
# lookup term: serotonin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28790
#
# Query: nutraceuticals
# lookup term: nutraceuticals
#   • UMLS CUI=C1518478  Name='Nutraceuticals'  sim=1.00
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: trimethylamine n-oxide
# lookup term: trimethylamine_n-oxide
#   • trimethylamine N-oxide                   URI=http://purl.obolibrary.org/obo/CHEBI_15724
# Query: epitope
# lookup term: epitopes
#   • epitope                                  URI=http://purl.obolibrary.org/obo/CHEBI_53000
# Query: potentially immunogenic epitope
# lookup term: potentially_immunogenic_epitopes
#   • epitope                                  URI=http://purl.obolibrary.org/obo/CHEBI_53000 score=1.00
#
# Query: epitope
# lookup term: epitopes
#   • epitope                                  URI=http://purl.obolibrary.org/obo/CHEBI_53000
# Query: potentially immunogenic epitope
# lookup term: potentially_immunogenic_epitopes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_53000
#
#
# Query: epitope
# lookup term: epitopes
#   • epitope                                  URI=http://purl.obolibrary.org/obo/CHEBI_53000
# Query: epitope
# lookup term: epitopes
#   • epitope                                  URI=http://purl.obolibrary.org/obo/CHEBI_53000
# Query: epitope
# lookup term: epitopes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_53000
#
#
# Query: epitope
# lookup term: epitopes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_53000
#
#
# Query: gut iga level
# lookup term: gut_iga_level
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/GutIgaLevel
#
#
# Query: epitope
# lookup term: epitopes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_53000
#
#
# Query: epitope
# lookup term: epitopes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_53000
#
#
# Query: epitope
# lookup term: epitopes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_53000
#
#
# Query: peptide
# lookup term: peptides
#   • peptide                                  URI=http://purl.obolibrary.org/obo/CHEBI_16670
# Query: epitope
# lookup term: epitopes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_53000
#
#
# Query: gap junction alpha-1
# lookup term: gap_junction_alpha-1
#   • Gap Junction Alpha-1 Protein             URI=http://purl.obolibrary.org/obo/NCIT_C115172 score=0.95
#
# Query: gap junction alpha-1
# lookup term: gap_junction_alpha-1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C115172
#
# Query: paired box protein 3
# lookup term: paired_box_protein_3
#   • Paired Box Protein Pax-8                 URI=http://purl.obolibrary.org/obo/NCIT_C97690 score=0.80
#
# Query: pax3
# lookup term: pax3
#   • PAX3'                                    URI=http://purl.obolibrary.org/obo/CHEBI_209474 score=1.00
#
# Query: eya1 protein, human
# lookup term: eya1_protein,_human
#   • EYA1 Gene                                URI=http://purl.obolibrary.org/obo/NCIT_C75390 score=0.78
#
# Query: eya-1 protein, c elegans
# lookup term: eya-1_protein,_c_elegans
#   • UMLS CUI=C1667359  Name='eya-1 protein, C elegans'  sim=1.00
# Query: me
# lookup term: me
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/Me
#
#
# Query: listeriolysin o peptide
# lookup term: listeriolysin_o_peptide
#   • peptide                                  URI=http://purl.obolibrary.org/obo/CHEBI_16670 score=1.00
#
# Query: epitope
# lookup term: epitopes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_53000
#
#
# Query: gut iga level
# lookup term: gut_iga_level
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/GutIgaLevel
#
# Query: epitope
# lookup term: epitopes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_53000
#
#
# Query: epitope
# lookup term: epitopes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_53000
#
#
# Query: epitope
# lookup term: epitopes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_53000
#
#
# Query: monoamine neurotransmitter
# lookup term: monoamine_neurotransmitters
#   • UMLS CUI=C0815020  Name='monoamine neurotransmitters'  sim=1.00
# Query: monoamine neurotransmitter
# lookup term: monoamine_neurotransmitters
#   • UMLS CUI=C0815020  Name='monoamine neurotransmitters'  sim=1.00
# Query: monosaccharide glucose
# ...
#
# Query: norepinephrine
# lookup term: norepinephrine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_90022
#
#
# Query: ne
# lookup term: ne
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_172425
#
#
# Query: serotonin
# lookup term: serotonin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28790
#
#
# Query: serotonin
# lookup term: serotonin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28790
#
# Query: histamine
# lookup term: histamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_18295
#
#
# Query: neuron
# lookup term: neurons
#   • Neuron                                   URI=http://purl.obolibrary.org/obo/NCIT_C12623 score=1.00
#
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: acetic acid
# lookup term: acetic_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_15366
#
#
# Query: propionic acid
# lookup term: propionic_acid
#   • propionic acid                           URI=http://purl.obolibrary.org/obo/CHEBI_30768
# Query: lactic acid
# lookup term: lactic_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_42111
#
#
# Query: lactic acid
# lookup term: lactic_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_42111
#
#
# Query: metabolite
# lookup term: metabolite
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25212
#
#
# Query: neurochemical
# lookup term: neurochemicals
# no matches locally or in UMLS
# Query: flavonoid
# lookup term: flavonoids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_47916
#
#
# Query: flavonoid metabolite
# lookup term: flavonoid_metabolites
#   • flavonoid                                URI=http://purl.obolibrary.org/obo/CHEBI_47916 score=0.79
#
# Query: flavonoid
# lookup term: flavonoids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_47916
#
#
# Query: pharmacologically active compound
# lookup term: pharmacologically_active_compounds
#   • Compound D                               URI=http://purl.obolibrary.org/obo/CHEBI_228264 score=1.00
#
# Query: bioactive flavonoid metabolite
# lookup term: bioactive_flavonoid_metabolites
#   • flavonoid                                URI=http://purl.obolibrary.org/obo/CHEBI_47916 score=0.79
#
# Query: intact flavonoid
# lookup term: intact_flavonoid
#   • flavonoid                                URI=http://purl.obolibrary.org/obo/CHEBI_47916 score=1.00
#
# Query: dietary flavonoid component
# lookup term: dietary_flavonoid_components
#   • Dietary Flavonoid                        URI=http://purl.obolibrary.org/obo/NCIT_C70554 score=0.87
#
# Query: therapeutic metabolite
# lookup term: therapeutic_metabolites
#   • metabolite                               URI=http://purl.obolibrary.org/obo/CHEBI_25212 score=1.00
#
# Query: native flavonoid
# lookup term: native_flavonoids
#   • Flavonoid                                URI=http://purl.obolibrary.org/obo/NCIT_C1745 score=0.79
#
# Query: flavonoid
# lookup term: flavonoids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_47916
#
#
# Query: native flavonoid
# lookup term: native_flavonoids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C1745
#
#
# Query: microbiome-generated flavonoid metabolite
# lookup term: microbiome-generated_flavonoid_metabolites
#   • flavonoid                                URI=http://purl.obolibrary.org/obo/CHEBI_47916 score=0.79
#
# Query: protocatechuic acid
# lookup term: protocatechuic_acid
#   • Protocatechuic acid 3-glucoside          URI=http://purl.obolibrary.org/obo/CHEBI_167537 score=0.89
#
# Query: urolithins
# lookup term: urolithins
#   • UMLS CUI=C3827687  Name='Urolithin'  sim=0.00
# Query: -valerolactones
# lookup term: -valerolactones
# no matches locally or in UMLS
# Query: native flavonoid
# lookup term: native_flavonoid
#   • Flavonoid                                URI=http://purl.obolibrary.org/obo/NCIT_C1745 score=0.79
#
# Query: flavonoid metabolite
# lookup term: flavonoid_metabolites
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_47916
#
#
# Query: short-chain fatty acid butyrate
# lookup term: short-chain_fatty_acid_butyrate
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: cytokine
# lookup term: cytokines
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C20464
#
#
# Query: albumin
# lookup term: albumin
#   • albumin type                             URI=http://purl.obolibrary.org/obo/CHEBI_166964 score=0.80
#
# Query: cytokine
# lookup term: cytokines
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C20464
#
# Query: cytokine
# lookup term: cytokines
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C20464
#
# Query: mptp
# lookup term: mptp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_233275
#
#
# Query: 1-methyl-4-phenyl-1 2 3 6-tetrahydropyridine
# lookup term: 1-methyl-4-phenyl-1_2_3_6-tetrahydropyridine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_17963
#
#
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: mptp
# lookup term: mptp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_233275
#
#
# Query: mptp
# lookup term: mptp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_233275
#
#
# Query: mptp
# lookup term: mptp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_233275
#
#
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: propionic acid
# lookup term: propionic_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_30768
#
#
# Query: alpha-synuclein
# lookup term: alpha-synuclein
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_15781
#
#
# Query: short fatty acid
# lookup term: short_fatty_acids
#   • short-chain fatty acid                   URI=http://purl.obolibrary.org/obo/CHEBI_26666 score=0.85
#
# Query: circulating metabolite
# lookup term: circulating_metabolites
#   • metabolite                               URI=http://purl.obolibrary.org/obo/CHEBI_25212 score=1.00
#
# Query: neuronal signaling molecule
# lookup term: neuronal_signaling_molecules
#   • Signaling Molecule                       URI=http://purl.obolibrary.org/obo/NCIT_C1929 score=0.77
#
# Query: cognition-relevant signaling molecule
# lookup term: cognition-relevant_signaling_molecules
# no matches locally or in UMLS
# Query: brain-derived neurotrophic factor
# lookup term: brain-derived_neurotrophic_factor
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C20445
#
#
# Query: n-methyl-d-aspartate receptor subunit 2b
# lookup term: n-methyl-d-aspartate_receptor_subunit_2b
#   • N-Methyl-D-Aspartate Receptor            URI=http://purl.obolibrary.org/obo/NCIT_C118457 score=0.78
#
# Query: serotonin
# lookup term: serotonin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28790
#
# Query: neuropeptide y system
# lookup term: neuropeptide_y_system
#   • neuropeptide S                           URI=http://purl.obolibrary.org/obo/CHEBI_53461 score=1.00
#
# Query: circulating metabolite
# lookup term: circulating_metabolites
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25212
#
#
# Query: cerebral neuropeptide y system
# lookup term: cerebral_neuropeptide_y_system
#   • neuropeptide S                           URI=http://purl.obolibrary.org/obo/CHEBI_53461 score=1.00
#
# Query: mineralocorticoid and n-methyl-d-aspartate receptor
# lookup term: mineralocorticoid_and_n-methyl-d-aspartate_receptors
#   • N-Methyl-D-Aspartate Receptor            URI=http://purl.obolibrary.org/obo/NCIT_C118457 score=0.80
#
# Query: alpha-synuclein -syn protein
# lookup term: alpha-synuclein__-syn__protein
# no matches locally or in UMLS
# Query: -syn
# lookup term: -syn
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C43684
#
#
# Query: -syn protein
# lookup term: -syn_protein
#   • FULL_SYN                                 URI=http://purl.obolibrary.org/obo/NCIT_C43684 score=0.93
#
# Query: protein
# lookup term: proteins
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_36080
#
#
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: gut metabolite
# lookup term: gut_metabolites
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_82933
#
#
# Query: dj-1
# lookup term: dj-1
#   • Protein DJ-1                             URI=http://purl.obolibrary.org/obo/NCIT_C104716 score=0.92
#
# Query: park7
# lookup term: park7
#   • PARK7 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C104714 score=0.95
#
# Query: dj-1
# lookup term: dj-1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C104716
#
#
# Query: dj-1
# lookup term: dj-1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C104716
#
#
# Query: dj-1
# lookup term: dj-1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C104716
#
#
# Query: dj-1
# lookup term: dj-1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C104716
#
#
# Query: fecal calprotectin
# lookup term: fecal_calprotectin
#   • Calprotectin                             URI=http://purl.obolibrary.org/obo/NCIT_C105971 score=0.77
#
# Query: monocyte chemoattractant protein 1
# lookup term: monocyte_chemoattractant_protein_1
#   • Monocyte Chemoattractant Protein-1       URI=http://purl.obolibrary.org/obo/NCIT_C20482 score=1.00
#
# Query: malonate
# lookup term: malonate
#   • malonate(1-)                             URI=http://purl.obolibrary.org/obo/CHEBI_30795 score=1.00
#
# Query: dj-1
# lookup term: dj-1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C104716
#
#
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: lactic acid
# lookup term: lactic_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_42111
#
#
# Query: lactic acid
# lookup term: lactic_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_42111
#
#
# Query: faecal short chain fatty acid
# lookup term: faecal_short_chain_fatty_acids
#   • short-chain fatty acid                   URI=http://purl.obolibrary.org/obo/CHEBI_26666 score=1.00
#
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: faecal scfa
# lookup term: faecal_scfa
# no matches locally or in UMLS
# Query: valerate
# lookup term: valerate
#   • valerate                                 URI=http://purl.obolibrary.org/obo/CHEBI_31011
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acids
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: short chain fatty acid
# lookup term: short_chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
#
# Query: faecal butyric acid
# lookup term: faecal_butyric_acid
#   • butyric acid                             URI=http://purl.obolibrary.org/obo/CHEBI_30772 score=1.00
#
# Query: butyric acid
# lookup term: butyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_30772
#
#
# Query: butyric acid
# lookup term: butyric_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_30772
#
#
# Query: leptin
# lookup term: leptin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_81571
#
#
# Query: ghrelin
# lookup term: ghrelin
#   • ghrelin                                  URI=http://purl.obolibrary.org/obo/CHEBI_75431
# Query: microbiome-borne curli
# lookup term: microbiome-borne_curli
# no matches locally or in UMLS
# Query: enteric neuron
# lookup term: enteric_neurons
# no matches locally or in UMLS
# Query: toxin
# lookup term: toxins
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_27026
#
#
# Query: bacterial curli
# lookup term: bacterial_curli
#   • bacterial metabolite                     URI=http://purl.obolibrary.org/obo/CHEBI_76969 score=0.80
#
# Query: protein
# lookup term: protein
#   • protein                                  URI=http://purl.obolibrary.org/obo/CHEBI_36080
# Query: syn
# lookup term: syn
#   • FULL_SYN                                 URI=http://purl.obolibrary.org/obo/NCIT_C43684 score=1.00
#
# Query: bacterial curli
# lookup term: bacterial_curli
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_76969
#
#
# Query: serotonergic
# lookup term: serotonergic
#   • serotonergic agonist                     URI=http://purl.obolibrary.org/obo/CHEBI_35941 score=0.81
#
# Query: dopaminergic
# lookup term: dopaminergic
#   • dopaminergic agent                       URI=http://purl.obolibrary.org/obo/CHEBI_48560 score=0.83
#
# Query: noradrenergic
# lookup term: noradrenergic
#   • UMLS CUI=C0599861  Name='noradrenergic'  sim=1.00
# Query: neuron
# lookup term: neurons
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12623
#
#
# Query: interleukin-6 receptor
# lookup term: interleukin-6_receptor
#   • interleukins                             URI=http://purl.obolibrary.org/obo/CHEBI_52998 score=0.84
#
# Query: interleukin 6
# lookup term: interleukin_6
#   • interleukins                             URI=http://purl.obolibrary.org/obo/CHEBI_52998 score=1.00
#
# Query: mr16-1
# lookup term: mr16-1
# no matches locally or in UMLS
# Query: mr16-1
# lookup term: mr16-1
# no matches locally or in UMLS
# Query: mr16-1
# lookup term: mr16-1
# no matches locally or in UMLS
# Query: mr16-1
# lookup term: mr16-1
# no matches locally or in UMLS
# Query: synaptic protein
# lookup term: synaptic_proteins
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_3254
#
#
# Query: postsynaptic density protein 95
# lookup term: postsynaptic_density_protein_95
#   • UMLS CUI=C4318444  Name='Disks Large Homolog 4 Protein'  sim=0.14
# Query: -amino-3-hydroxy-5-methyl-4-isoxazolepropionic acid receptor 1
# lookup term: -amino-3-hydroxy-5-methyl-4-isoxazolepropionic_acid_receptor_1
# no matches locally or in UMLS
# Query: mr16-1
# lookup term: mr16-1
# no matches locally or in UMLS
# Query: interleukin 6
# lookup term: interleukin_6
#   • interleukins                             URI=http://purl.obolibrary.org/obo/CHEBI_52998 score=1.00
#
# Query: interleukin 6
# lookup term: interleukin_6
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_52998
#
#
# Query: rat caecal and hippocampal metabolome
# lookup term: rat_caecal_and_hippocampal_metabolome
#   • rat metabolite                           URI=http://purl.obolibrary.org/obo/CHEBI_86264 score=0.82
#
# Query: toll-like receptor 4
# lookup term: toll-like_receptor_4
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_77161
#
# Query: plasma metabolite
# lookup term: plasma_metabolites
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25212
#
#
# Query: saline
# lookup term: saline
#   • Saline                                   URI=http://purl.obolibrary.org/obo/NCIT_C821 score=1.00
#
# Query: plasma metabolite
# lookup term: plasma_metabolites
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25212
#
#
# Query: cytokine chemokines
# lookup term: cytokines_chemokines
#   • Cytokine                                 URI=http://purl.obolibrary.org/obo/NCIT_C20464 score=1.00
#
# Query: cytokine chemokines
# lookup term: cytokines_chemokines
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C20464
#
#
# Query: systemic cytokine and chemokines
# lookup term: systemic_cytokines_and_chemokines
# no matches locally or in UMLS

# %% [markdown]
# <h1>INGEST FOOD</h1>

# %%
import os
import re
import unicodedata
import json
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint
from rdflib.namespace import DCTERMS
from groqutils import get_llm_definition
from umlsutils import search_umls, best_umls_match, get_umls_definition
from funcutils import get_ncit_description, get_chebi_description, get_omit_description, NCBI_BASE, HEREDITARY_BASE, UMLS_BASES, foodon_file, ncit_file, omit_file, chebi_file, hash_term_sha256, get_foodon_description

FOODON_BASE = "http://purl.obolibrary.org/obo/"
NCIT_BASE = "http://purl.obolibrary.org/obo/"
FOOD_CLASS = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Food")
FOOD_CONCEPT_SCHEME = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Food")

TAX1_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\food_tree.txt"
TAX2_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\foodon_terms.txt"

def load_taxonomy_tree(path):
    row_re = re.compile(r"^\s*(.*?)\s+\[([^\]]+)\]\s*$")
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = row_re.match(ln)
            if m:
                label, tid = m.groups()
                depth = len(ln) - len(ln.lstrip())
                rows.append((label, tid, depth))
    return rows

rows1 = load_taxonomy_tree(TAX1_FILE)
rows2 = load_taxonomy_tree(TAX2_FILE)

exact1 = defaultdict(list)
for lbl, tid, depth in rows1:
    exact1[lbl.lower()].append((lbl, tid, depth))

exact2 = defaultdict(list)
for lbl, tid, depth in rows2:
    exact2[lbl.lower()].append((lbl, tid, depth))

labels1 = [lbl for lbl,_,_ in rows1]
vec1    = TfidfVectorizer(stop_words="english")
mat1    = vec1.fit_transform(labels1)

labels2 = [lbl for lbl,_,_ in rows2]
vec2    = TfidfVectorizer(stop_words="english")
mat2    = vec2.fit_transform(labels2)

def top_cosine(rows, vec, mat, labels, term, k=5, thr=0.75):
    v   = vec.transform([term])
    sc  = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, tid, depth = rows[i]
        out.append((lbl, tid, depth, sc[i]))
    return out

manual_created = {}
created = {}

manual_created = {
    "whole_grain_cereals" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4046096"),
    "thymus_vulgaris" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0697238"),
    "origanum_vulgare" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0946715"),
    "low-caloric_diet" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C2930544"),
    "egg_food_product" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0013710"),
    "oregano_spice" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0453263"),
    "milk,_human" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0026140"),
    "specimen_type_-_breast_milk" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1556060"),
    "phoenix_dactylifera": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0599067"),
    "age-diet": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/food/AgeDiet"),
    "vegan_food": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0453867"),
    "bovine_milk_plasma": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5873086"),
    "high-cholesterol_diet": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/food/HighColesterolDiet"),
    "normal_diet": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/food/NormalDiet"),
    "fiber" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0225326"),
    "nuts": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0028723"),
    "diet,_mediterranean": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1138412"),
    "diet": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0012155"),
    "meal": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1998602"),
    "low_carbohydrate_high_fat_diets": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5447757"),
}

created = dict(manual_created)

regex_map = [
    (r"dietary_fiber", "high-fiber_diet"),
    (r"diet\w*\b","diet"),
    (r"\bmd\b","meat"),
    (r"\bnnss\b","nonnutritive_sweeteners"),
    (r"\blchf\b","low_carbohydrate_high_fat_diet"),
    (r"\bvegan_diet\w*\b","vegan_food"),
    (r"\bpre-prepared_convenience_meal\w*\b","meal"),
    (r"\bhighly_processed__poor_quality_food\w*\b","food"),
    (r"nutrient-rich_diet","high-fiber_diet"),
    (r"multi-component_diet","diet"),
    (r"mediterranean_diet","diet,_mediterranean"),
    (r"\bhigh-cholesterol_diet\w*\b","high-cholesterol_diet"),
    (r"\bnut\w*\b","nuts"),
    (r"bovine_milk","bovine_milk_plasma"),
    (r"\bfibre\w*\b","fiber"),
    (r"\bvd\b","vegan_food"),
    (r"\bvegan__vd_\b","vegan_food"),
    (r"fermented_foods", "food"),
    (r"animal_to_vegetal_food", "food"),
    (r"breastmilk","specimen_type_-_breast_milk"),
    (r"eggs","egg_food_product"),
    (r"vegetables","vegetable"),
    (r"6_sl-deficient_milk","milk,_human"),
    (r"maternal_milk","milk,_human"),
    (r"standard_chow__n___10__or_a_baked_chow_high_age-diet","chow_chow"),
    (r"standard_chow","chow_chow"),
    (r"\bwheat_germ\w*\b", "wheat_germ"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))oregano(?:(?=$)|(?=[^A-Za-z0-9]))", "oregano_spice"),
]
CREATOR = "Samuel Piron"

mesh_descs   = parse_mesh_descriptors(MESH_XML)

for uri in manual_created.values():
    uri_str = str(uri)

    if uri_str.startswith(UMLS_BASES):
        # only a UMLS‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("UMLS Match", datatype=XSD.string)))
    elif "NCIT" in uri_str:
        # only a NCIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("NCIT Match", datatype=XSD.string)))
    elif "OMIT" in uri_str:
        # only a OMIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("OMIT Match", datatype=XSD.string)))
    elif "NCBITaxon" in uri_str:
        # only a NCBITaxon‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("NCBITaxon Match", datatype=XSD.string)))
    elif "CHEBI" in uri_str:
        # only a CHEBI‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("CHEBI Match", datatype=XSD.string)))
    elif "FOODON" in uri_str:
        # only a FOODON‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("FOODON Match", datatype=XSD.string)))
    elif "mesh" in uri_str:
        # only a MESH‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("MESH Match", datatype=XSD.string)))
    elif "PCO" in uri_str:
        # only a XCO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("PCO Match", datatype=XSD.string)))
    else:
        # everything else still gets a creator
        g.add((uri,
               DCTERMS.creator,
               Literal(CREATOR, datatype=XSD.string)))

for term_raw, uri in manual_created.items():
    uri_str = str(uri)

    # NCIT definitions
    if uri_str.startswith(NCBI_BASE) and "NCIT_" in uri_str:
        ncit_id = uri_str.rsplit("_", 1)[-1]
        desc = get_ncit_description(ncit_id, ncit_file)
        m = re.search(r'—\s*(.*?)\s*—', desc)
        if m:
            desc = m.group(1).strip()
            comment = f"{desc} [Definition Source: NCIT]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # UMLS definitions
    elif uri_str.startswith(UMLS_BASES):
        cui = uri_str.rsplit("/", 1)[-1]
        defn = get_umls_definition(cui)
        if defn:
            comment = f"{defn.strip()} [Definition Source: UMLS]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # MeSH definitions via your mesh_index
    elif uri_str.startswith(MESH_BASE):
        ui     = uri_str.rsplit("/",1)[-1]
        hits   = [d['name'] for d in mesh_descs if d['ui']==ui]
        if hits:
            comment = f"{hits[0]} [Definition Source: MeSH]"
        elif term_raw == "patients":
            comment = "Patients with various diseases. [Definition Source: GUTBRAIN]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    elif uri_str.startswith(HEREDITARY_BASE):
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"
    else:
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    g.add((uri,
           RDFS.comment,
           Literal(comment, datatype=XSD.string)))

for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "food":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            #lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, FOOD_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, FOOD_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex1 = exact1.get(term.lower(), [])
            cos1 = top_cosine(rows1, vec1, mat1, labels1, term, k=5, thr=0.75)
            cos2 = top_cosine(rows2, vec2, mat2, labels2, term, k=5, thr=0.75)
            if ex1:
                for l,t,d in ex1:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score=1.00 (TAX1 exact)")
                    entity_uri = URIRef(f"{NCIT_BASE}{t}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, FOOD_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(l.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                    g.add((entity_uri, RDFS.comment, Literal("NCIT Match", datatype=XSD.string)))
                    raw_desc = get_ncit_description(t, ncit_file)
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos1:
                for l,t,d,s in cos1[:1]:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f} (TAX1 cosine)")
                    name_uri = URIRef(f"{NCIT_BASE}{t}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, FOOD_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(l.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                    g.add((name_uri, RDFS.comment, Literal("NCIT Match", datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                continue

            elif cos2:
                for l,t,d,s in cos2[:1]:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f} (TAX2 cosine)")
                    name_uri = URIRef(f"{FOODON_BASE}{t}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, FOOD_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(l.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                    uri_str    = str(name_uri)
                    # pick off only the ID portion
                    fragment   = uri_str.rsplit("/", 1)[-1]
                    definition = choose_definition(fragment, term_raw)

                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((
                            name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)
                        ))
                    g.add((name_uri, RDFS.comment, Literal("FOODON Match", datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

for paper_id, paper_data in data_gold.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "food":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            #lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, FOOD_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, FOOD_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex1 = exact1.get(term.lower(), [])
            cos1 = top_cosine(rows1, vec1, mat1, labels1, term, k=5, thr=0.75)
            cos2 = top_cosine(rows2, vec2, mat2, labels2, term, k=5, thr=0.75)
            if ex1:
                for l,t,d in ex1:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score=1.00 (TAX1 exact)")
                    entity_uri = URIRef(f"{NCIT_BASE}{t}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, FOOD_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(l.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                    g.add((entity_uri, RDFS.comment, Literal("NCIT Match", datatype=XSD.string)))
                    raw_desc = get_ncit_description(t, ncit_file)
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos1:
                for l,t,d,s in cos1[:1]:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f} (TAX1 cosine)")
                    name_uri = URIRef(f"{NCIT_BASE}{t}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, FOOD_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(l.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                    g.add((name_uri, RDFS.comment, Literal("NCIT Match", datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                continue

            elif cos2:
                for l,t,d,s in cos2[:1]:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f} (TAX2 cosine)")
                    name_uri = URIRef(f"{FOODON_BASE}{t}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, FOOD_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(l.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                    uri_str    = str(name_uri)
                    # pick off only the ID portion
                    fragment   = uri_str.rsplit("/", 1)[-1]
                    definition = choose_definition(fragment, term_raw)

                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((
                            name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)
                        ))
                    g.add((name_uri, RDFS.comment, Literal("FOODON Match", datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

print("entering dev")

for paper_id, paper_data in data_dev.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "food":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            #lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, FOOD_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, FOOD_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex1 = exact1.get(term.lower(), [])
            cos1 = top_cosine(rows1, vec1, mat1, labels1, term, k=5, thr=0.75)
            cos2 = top_cosine(rows2, vec2, mat2, labels2, term, k=5, thr=0.75)
            if ex1:
                for l,t,d in ex1:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score=1.00 (TAX1 exact)")
                    entity_uri = URIRef(f"{NCIT_BASE}{t}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, FOOD_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(l.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                    g.add((entity_uri, RDFS.comment, Literal("NCIT Match", datatype=XSD.string)))
                    raw_desc = get_ncit_description(t, ncit_file)
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos1:
                for l,t,d,s in cos1[:1]:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f} (TAX1 cosine)")
                    name_uri = URIRef(f"{NCIT_BASE}{t}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, FOOD_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(l.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                    g.add((name_uri, RDFS.comment, Literal("NCIT Match", datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                continue

            elif cos2:
                for l,t,d,s in cos2[:1]:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f} (TAX2 cosine)")
                    name_uri = URIRef(f"{FOODON_BASE}{t}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, FOOD_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(l.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                    uri_str    = str(name_uri)
                    # pick off only the ID portion
                    fragment   = uri_str.rsplit("/", 1)[-1]
                    definition = choose_definition(fragment, term_raw)

                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((
                            name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)
                        ))
                    g.add((name_uri, RDFS.comment, Literal("FOODON Match", datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "food":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_food_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_gold_file, "r", encoding="utf-8") as f_sent:
    tokenized_gold_data = json.load(f_sent)

for entry in tokenized_gold_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "food":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_food_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_dev, "r", encoding="utf-8") as f_sent:
    tokenized_dev_data = json.load(f_sent)

for entry in tokenized_dev_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "food":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_food_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

output_file = os.path.join(save_path, "gutbrain_entities.ttl")
ttl_output = g.serialize(format="turtle")
with open(output_file, "w", encoding="utf-8") as f_out:
    f_out.write(ttl_output)

print(f"The RDF graph has been saved in {output_file}")
# Out:
# vegetable
# Query: vegetable
# lookup term: vegetable
#   • Vegetable                                ID=NCIT_C178192    depth=4  score=1.00 (TAX1 exact)
# Query: whole grain cereal
# lookup term: whole_grain_cereals
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4046096
#
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# wheat_germ
# Query: wheat germ
# lookup term: wheat_germ
#   • wheat germ                               ID=FOODON_03301595 depth=0  score=1.00 (TAX2 cosine)
# wheat_germ
# Query: wheat germ
# lookup term: wheat_germ
#   → Reusing existing URI: http://purl.obolibrary.org/obo/FOODON_03301595
#
# high-fiber_diet
# Query: high-fiber diet
# lookup term: high-fiber_diet
#   • high fiber food                          ID=FOODON_03510048 depth=0  score=0.76 (TAX2 cosine)
# Query: thyme
# lookup term: thyme
#   • thyme plant                              ID=FOODON_03411199 depth=0  score=0.90 (TAX2 cosine)
# Query: thymus vulgaris
# lookup term: thymus_vulgaris
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0697238
#
#
# oregano_spice
# Query: oregano spice
# lookup term: oregano_spice
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0453263
#
# Query: origanum vulgare
# lookup term: origanum_vulgare
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0946715
#
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2930544
#
#
# food
# Query: food
# lookup term: food
#   • Food                                     ID=NCIT_C62695     depth=0  score=1.00 (TAX1 exact)
# Query: poultry meat
# lookup term: poultry_meat
#   • poultry meat product                     ID=FOODON_03315174 depth=0  score=0.89 (TAX2 cosine)
# Query: meat
# lookup term: meat
#   • Meat                                     ID=NCIT_C126482    depth=2  score=1.00 (TAX1 exact)
# egg_food_product
# Query: egg food product
# lookup term: egg_food_product
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0013710
#
# Query: pork
# lookup term: pork
#   • Pork                                     ID=NCIT_C71958     depth=4  score=1.00 (TAX1 exact)
# specimen_type_-_breast_milk
# Query: specimen type - breast milk
# lookup term: specimen_type_-_breast_milk
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1556060
#
# milk,_human
# Query: milk, human
# lookup term: milk,_human
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0026140
#
# milk,_human
# Query: milk, human
# lookup term: milk,_human
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0026140
#
# Query: phoenix dactylifera
# lookup term: phoenix_dactylifera
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0599067
#
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# Query: baked chow
# lookup term: baked_chow
#   • chow chow                                ID=FOODON_03303376 depth=0  score=0.77 (TAX2 cosine)
# chow_chow
# Query: chow chow
# lookup term: chow_chow
#   • chow chow                                ID=FOODON_03303376 depth=0  score=1.00 (TAX2 cosine)
# Query: baked chow
# lookup term: baked_chow
#   → Reusing existing URI: http://purl.obolibrary.org/obo/FOODON_03303376
#
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/food/AgeDiet
#
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# vegan_food
# Query: vegan food
# lookup term: vegan_food
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0453867
#
# Query: meat-rich md
# lookup term: meat-rich__md_
#   • Meat                                     ID=NCIT_C126482    depth=2  score=1.00 (TAX1 cosine)
#
# vegan_food
# Query: vegan food
# lookup term: vegan_food
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0453867
#
# meat
# Query: meat
# lookup term: meat
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C126482
#
# vegan_food
# Query: vegan food
# lookup term: vegan_food
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0453867
#
# meat
# Query: meat
# lookup term: meat
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C126482
#
# meat
# Query: meat
# lookup term: meat
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C126482
#
# vegan_food
# Query: vegan food
# lookup term: vegan_food
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0453867
#
# nuts
# Query: nut
# lookup term: nuts
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0028723
#
# meal
# Query: meal
# lookup term: meal
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1998602
#
# food
# Query: food
# lookup term: food
#   • Food                                     ID=NCIT_C62695     depth=0  score=1.00 (TAX1 exact)
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# nuts
# Query: nut
# lookup term: nuts
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0028723
#
# Query: plant food
# lookup term: plant_foods
#   • plant food product                       ID=FOODON_00001015 depth=0  score=0.81 (TAX2 cosine)
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# meat
# Query: meat
# lookup term: meat
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C126482
#
# Query: fruit
# lookup term: fruits
#   • Fruit                                    ID=NCIT_C71972     depth=4  score=1.00 (TAX1 exact)
# Query: legume
# lookup term: legumes
#   • legume                                   ID=FOODON_03310646 depth=0  score=1.00 (TAX2 cosine)
# vegetable
# Query: vegetable
# lookup term: vegetable
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C178192
#
#
# Query: olive oil
# lookup term: olive_oil
#   • Olive Oil                                ID=NCIT_C1175      depth=4  score=1.00 (TAX1 exact)
# Query: herb
# lookup term: herbs
#   • piece(s) of herb                         ID=FOODON_00004546 depth=0  score=0.88 (TAX2 cosine)
# Query: spice
# lookup term: spices
#   • spice                                    ID=FOODON_03306052 depth=0  score=1.00 (TAX2 cosine)
# meat
# Query: meat
# lookup term: meat
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C126482
#
# meat
# Query: meat
# lookup term: meat
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C126482
#
# meat
# Query: meat
# lookup term: meat
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C126482
#
# meat
# Query: meat
# lookup term: meat
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C126482
#
# bovine_milk_plasma
# Query: bovine milk plasma
# lookup term: bovine_milk_plasma
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5873086
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/food/HighColesterolDiet
#
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/food/HighColesterolDiet
#
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/food/NormalDiet
#
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/food/HighColesterolDiet
#
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# Query: fruit
# lookup term: fruits
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C71972
#
#
# vegetable
# Query: vegetable
# lookup term: vegetable
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C178192
#
#
# nuts
# Query: nut
# lookup term: nuts
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0028723
#
#
# Query: herb
# lookup term: herbs
#   → Reusing existing URI: http://purl.obolibrary.org/obo/FOODON_00004546
#
#
# Query: spice
# lookup term: spices
#   → Reusing existing URI: http://purl.obolibrary.org/obo/FOODON_03306052
#
#
# Query: legume
# lookup term: legumes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/FOODON_03310646
#
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
#
# Query: grain
# lookup term: grains
#   • Whole Grain                              ID=NCIT_C178197    depth=2  score=1.00 (TAX1 cosine)
#
# fiber
# Query: fiber
# lookup term: fiber
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0225326
#
# food
# Query: food
# lookup term: food
#   • Food                                     ID=NCIT_C62695     depth=0  score=1.00 (TAX1 exact)
# Query: fish
# lookup term: fish
#   • fish                                     ID=FOODON_03411222 depth=0  score=1.00 (TAX2 cosine)
# entering dev
# Query: food item
# lookup term: food_items
#   • Food                                     ID=NCIT_C62695     depth=0  score=1.00 (TAX1 cosine)
#
# Query: unpasteurised milk
# lookup term: unpasteurised_milk
#   • Whole Milk                               ID=NCIT_C188111    depth=8  score=1.00 (TAX1 cosine)
#
# Query: unpasteurised dairy product
# lookup term: unpasteurised_dairy_products
#   • Dairy Product                            ID=NCIT_C413       depth=2  score=1.00 (TAX1 cosine)
#
# Query: unpasteurised dairy
# lookup term: unpasteurised_dairy
#   • Dairy Milk                               ID=NCIT_C178184    depth=6  score=0.77 (TAX1 cosine)
#
# Query: unpasteurised milk
# lookup term: unpasteurised_milk
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C188111
#
#
# Query: dairy product
# lookup term: dairy_products
#   • Dairy Product                            ID=NCIT_C413       depth=2  score=1.00 (TAX1 exact)
# Query: unpasteurised milk
# lookup term: unpasteurised_milk
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C188111
#
#
# Query: dairy product
# lookup term: dairy_products
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C413
#
#
# Query: unpasteurised milk
# lookup term: unpasteurised_milk
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C188111
#
#
# Query: dairy product
# lookup term: dairy_products
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C413
#
#
# Query: nonnutritive sweetener
# lookup term: nonnutritive_sweeteners
#   • sweetener (nonnutritive)                 ID=FOODON_03315027 depth=0  score=1.00 (TAX2 cosine)
# Query: nonnutritive sweetener
# lookup term: nonnutritive_sweeteners
#   → Reusing existing URI: http://purl.obolibrary.org/obo/FOODON_03315027
#
#
# Query: nnss
# lookup term: nnss
# no matches
# Query: nnss
# lookup term: nnss
# no matches
# Query: nnss
# lookup term: nnss
# no matches
# Query: nnss
# lookup term: nnss
# no matches
# Query: nnss
# lookup term: nnss
# no matches
# Query: starch
# lookup term: starch
#   • obsolete: starch                         ID=FOODON_03420203 depth=0  score=0.90 (TAX2 cosine)
# Query: nnss
# lookup term: nnss
# no matches
# Query: nnss
# lookup term: nnss
# no matches
# Query: nnss
# lookup term: nnss
# no matches
# Query: nnss
# lookup term: nnss
# no matches
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# diet
# Query: diet
# lookup term: diet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0012155
#
# Query: lchf
# lookup term: lchf
# no matches
# Query: lchf
# lookup term: lchf
# no matches
# The RDF graph has been saved in c:\Users\samue\OneDrive\Desktop\ThesisPiron\rdf\gutbrain_entities.ttl

# %% [markdown]
# <h1>INGEST HUMAN</h1>

# %%
import os
import requests
import re
import unicodedata
import json
from pathlib import Path
from collections import defaultdict
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from rdflib.namespace import DCTERMS
from groqutils import get_llm_definition
from umlsutils import search_umls, best_umls_match, get_umls_definition
from funcutils import get_ncit_description, get_chebi_description, get_omit_description, NCBI_BASE, HEREDITARY_BASE, UMLS_BASES, foodon_file, ncit_file, omit_file, chebi_file, hash_term_sha256

NCBI_BASE             = "http://purl.obolibrary.org/obo/"
MESH_BASE             = "https://www.ncbi.nlm.nih.gov/mesh/"
HUMAN_CLASS           = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Human")
HUMAN_CONCEPT_SCHEME  = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Human")

GUTBRAINMENTION = Namespace("https://w3id.org/hereditary/ontology/gutbrain/resource/mention/")

def load_ddf_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = NCBI_BASE + term_id
            rows.append((label, uri))
    return rows

def parse_mesh_descriptors(xml_path):
    descs = []
    tree  = ET.parse(xml_path)
    root  = tree.getroot()
    for dr in root.findall('DescriptorRecord'):
        ui   = dr.findtext('DescriptorUI')
        name = dr.findtext('DescriptorName/String')
        tns  = [tn.text for tn in dr.findall('TreeNumberList/TreeNumber') if tn.text]
        if ui and name:
            descs.append({'ui':ui,'name':name,'tree_numbers':tns})
    return descs

def build_name_index(descriptors):
    idx = defaultdict(list)
    for d in descriptors:
        if not d['tree_numbers']: continue
        tn = d['tree_numbers'][0]
        idx[d['name'].lower()].append((tn, d['ui'], d['name']))
    return idx

MESH_XML     = 'desc2025.xml'
mesh_descs   = parse_mesh_descriptors(MESH_XML)
mesh_index   = build_name_index(mesh_descs)

mesh_items   = [(tn,ui,name) for vs in mesh_index.values() for tn,ui,name in vs]
mesh_labels  = [name for (_,_,name) in mesh_items]
mesh_uids    = [ui   for (_,ui,_)   in mesh_items]

mesh_vec     = TfidfVectorizer(stop_words="english").fit(mesh_labels)
mesh_mat     = mesh_vec.transform(mesh_labels)

def load_taxonomy_tree(path):
    row_re = re.compile(r"^\s*(.*?)\s+\[([^\]]+)\]\s*$")
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = row_re.match(ln)
            if m:
                label, tid = m.groups()
                depth      = len(ln) - len(ln.lstrip())
                rows.append((label, tid, depth))
    return rows

TAX_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\patients_output.txt"
rows     = load_taxonomy_tree(TAX_FILE)

exact_ix  = defaultdict(list)
for lbl, tid, depth in rows:
    exact_ix[lbl.lower()].append((lbl, tid, depth))

labels_only  = [r[0] for r in rows]
vec          = TfidfVectorizer(stop_words="english")
mat          = vec.fit_transform(labels_only)

def top_cosine(term, k=5, thr=0.75):
    v   = vec.transform([term])
    sc  = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr: break
        lbl, tid, d = rows[i]
        out.append((lbl, tid, d, sc[i]))
    return out

manual_created = {}
created = {}

manual_created = {
    "patients": URIRef("https://www.ncbi.nlm.nih.gov/mesh/68010361"),
    "parkinson_disease_patients":URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients"),
    "alzheimer_disease_patient": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/AlzheimerDiseasePatients"),
    "depressed_patients":URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/DepressedPatients"),
    "major_depressive_disorder_patients" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/MajorDepressiveDisorderPatients"),
    "alcohol_overconsumption_group":URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/AlcoholOverconsumptionGroup"),
    "non-smoking_patients":URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/NonSmokingPatients"),
    "patients_with_schizophrenia":URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/PatientsWithSchizophrenia"),
    "human_subjects":URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/HumanSubjects"),
    "crew_members":URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/CrewMembers"),
    "ibs-d_patients" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/IbsDPatients"),
    "bipolar_patients" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/BipolarPatients"),
    "hunter-gatherers": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/HunterGathers"),
    "obese_westerners": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/ObeseWesterners"),
    "asd_patients": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/AsdPatients"),
    "donor_group": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/DonorGroup"),
    "adenocarcinoma_patients" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/AdenocarcinomaPatients"),
    "experiment_group": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/ExperimentGroup"),
    "insomnia_disorder_group": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/InsomniaDisorderGroup"),
    "liver_cirrhosis_patients": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/LiverCirrhosisPatients"),
    "epileptic_patients": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/EpilepticPatients"),
    "chronic_restraint_stress_group": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/ChronicRestraintStressGroup"),
    "pediatric_chronic_intestinal_pseudo-obstruction_patients": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/PediatricChronicIntestinalPseudoObstructionPatients"),
    "people_with_hiv": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/PeopleWithHiv"),
    "multiple_sclerosis_patients": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/human/MultipleSclerosisPatients"),
}

created = dict(manual_created)

regex_map = [
    (r"bariatric_patients", "patients"),
    (r"\bibs_patient\w*\b","ibs-d_patients"),
    (r"\bagile__fit_hunter_gatherer\w*\b","hunter-gatherers"),
    (r"\bef-risk_and_non-risk_groups\b","control_groups"),
    (r"\bfep_patient\w*\b","patients"),
    (r"eerrisk_children","children"),
    (r"\basd_group\w*\b","asd_patients"),
    (r"\bfep-patient\w*\b","patients"),
    (r"\bvolunteer_twin\w*\b","people"),
    (r"\bnon-oncological_patient\w*\b","patients"),
    (r"age-matched_children","children"),
    (r"td_group","control_groups"),
    (r"\basd_and_td_group\w*\b","control_groups"),
    (r"\bunited_states__us__military_veteran\w*\b","military_veterans"),
    (r"\bus_veteran\w*\b","military_veterans"),
    (r"\bchinese_and_korean_immigrant\w*\b","immigrant_(person)"),
    (r"\bchinese_and_korean_american_immigrant\w*\b","immigrant_(person)"),
    (r"\btreated_and_treatment-naive_patient\w*\b","patients"),
    (r"\btreatment-resistant_depressed_patient\w*\b","depressed_patients"),
    (r"\bpatient_group\w*\b","control_groups"),
    (r"\bnarcolepsy_type_1_and_idiopathic_hypersomnia_group\w*\b","control_groups"),
    (r"\bnon-depressed_general_population\w*\b","population"),
    (r"\bgp\b","population"),
    (r"\bgp_cohort\b","population"),
    (r"mdd_cohort","major_depressive_disorder_patients"),
    (r"\bstudy_population\w*\b","population"),
    (r"\batypical_parkinsonism_cohort\w*\b","parkinson_disease_patients"),
    (r"aging_population","elderly_(population_group)"),
    (r"human_population","population"),
    (r"\bpipo_patient\w*\b","pediatric_chronic_intestinal_pseudo-obstruction_patients"),
    (r"\bnon-ldsd_patient\w*\b","patients"),
    (r"\bldsd_patient\w*\b","depressed_patients"),
    (r"\bibs_cohort\w*\b","ibs-d_patients"),
    (r"\bibs_participant\w*\b","ibs-d_patients"),
    (r"\bhealthy_korean_adult\w*\b","adults"),
    (r"\bparticipants_in_the_prevotella_dominant_group\b","participants"),
    (r"\bparticipants_in_the_bacteroides_group\b","participants"),
    (r"\bplwh\b","people_with_hiv"),
    (r"\bepileptic_patient\w*\b","epileptic_patients"),
    (r"\binactive_adult\w*\b","adults"),
    (r"newborn_child","children"),
    (r"\b_expectant__mother\w*\b","mothers"),
    (r"\bwomen_during_pregnancy_and_postpartum\b","women"),
    (r"saline___crs_group","chronic_restraint_stress_group"),
    (r"arketamine___crs_group","chronic_restraint_stress_group"),
    (r"female_people","people"),
    (r"\bdiagnosed_patient\b","patients"),
    (r"\bclinically_diagnosed_human_population\w*\b","population"),
    (r"men_and_women_over_40_years_old","human"),
    (r"\bobese_patient\w*\b","patients"),
    (r"\bmultiple_sclerosis_patient\w*\b",""),
    (r"\bdepressed_patient\w*\b","depressed_patients"),
    (r"\bdepression_patient\w*\b","depressed_patients"),
    (r"control","control_groups"),
    (r"\bhealthy__omnivore__normal-weight_participant\w*\b","participants"),
    (r"\bibd_patient\w*\b","ibs-d_patients"),
    (r"\bpd_case\w*\b","parkinson_disease_patients"),
    (r"\bidiopathic_rapid_eye_movement_sleep_behavior_disorder_patient\w*\b","patients"),
    (r"\bhuman_host\w*\b","human"),
    (r"\bmother-infant_dyad\w*\b","mother"),
    (r"\bhealthy_control_group\w*\b","control_groups"),
    (r"chronic_insomnia_disorder_group","insomnia_disorder_group"),
    (r"school-aged_children","children"),
    (r"\bmajor_depressive_disorder__mdd__patient\w*\b","major_depressive_disorder_patients"),
    (r"\bmdd_case\w*\b","major_depressive_disorder_patients"),
    (r"\bdrug-naive__dn_scz__and_risperidone-treated_scz_patient\w*\b","patients_with_schizophrenia"),
    (r"risp_scz","patients_with_schizophrenia"),
    (r"dn_scz","patients_with_schizophrenia"),
    (r"\bscz_patient\w*\b","patients_with_schizophrenia"),
    (r"\bdn\b","patients_with_schizophrenia"),
    (r"\brisp\b","patients_with_schizophrenia"),
    (r"\bliver_cirrhosis_patient\w*\b","liver_cirrhosis_patients"),
    (r"chinese_group","people"),
    (r"asian__chinese_people","people"),
    (r"\bprimary_sjogren_s_syndrome-mediated_dry_eye_patient\w*\b","patients"),
    (r"\bfunctional_constipation_patient\w*\b","patients"),
    (r"\bexperimental_and_control_group\w*\b","control_groups"),
    (r"\bcfc_patient\w*\b","patients"),
    (r"\bagile__fit_hunter_gatherer\w*\b","hunter-gatherers"),
    (r"happiest_people","people"),
    (r"spanish_population","population"),
    (r"spanish_cohort","population"),
    (r"healthy_age_groups","elderly_(population_group)"),
    (r"\belderly_patient\w*\b","elderly_(population_group)"),
    (r"\bparkinson_s_disease_and_multiple_sclerosis_patient\w*\b","parkinson_disease_patients"),
    (r"\bclinical_population\w*\b","population"),
    (r"children_aged_3-4","children"),
    (r"bef-risk_and_non-risk_group\w*\b","control_groups"),
    (r"children_with_eer-risk","children"),
    (r"elderly_population","elderly_(population_group)"),
    (r"\bcommunity-dwelling_older_adult\w*\b","adult"),
    (r"\byoung_adult\w*\b","adult"),
    (r"\bcommunity_dwelling_participant\w*\b","participants"),
    (r"\b2_5-month-old_infant\w*\b","infants"),
    (r"\byoung_infant\w*\b","infant"),
    (r"\byoung_patient\w*\b","patients"),
    (r"adult_human","elderly_(population_group)"),
    (r"\bchinese_depressed_patient\w*\b","depressed_patients"),
    (r"healthy_donor_group","donor_group"),
    (r"\bdiagnosed_patient\w*\b","patients"),
    (r"\bbd_patient\w*\b","bipolar_patients"),
    (r"non-smoking_healthy_controls","humans"),
    (r"controls", "humans"),
    (r"healthy_controls", "humans"),
    (r"schizophrenia_patients", "patients"),
    (r"health_controls", "humans"),
    (r"schizophrenia_cohort", "cohort"),
    (r"control_cohort", "cohort"),
    (r"stressed_adults", "adult"),
    (r"placebo_group", "people"),
    (r"probiotic group", "people"),
    (r"parkinson_s_disease__pd__patients", "parkinson_disease_patients"),
    (r"pd_patients", "parkinson_disease_patients"),
    (r"individuals","individual"),
    (r"comorbid_patients", "patients"),
    (r"mother-infant_pairs","humans"),
    (r"vaginally_delivered_infants", "infants"),
    (r"vaginally_delivered__fully_breastfed_infants", "infants"),
    (r"world_s_population", "population"),
    (r"hcs", "humans"),
    (r"child_and_adolescent_population__0-18_years_old_", "population"),
    (r"youth", "adolescent"),
    (r"asd_and_healthy_controls", "humans"),
    (r"child_and_adolescent_populations", "population"),
    (r"type_2_diabetes_patients", "patients"),
    (r"homeless_individuals", "individual"),
    (r"individual_patients", "patients"),
    (r"hospitalized_older_adults", "elderly_(population_group)"),
    (r"hospitalized_acutely_ill_older_adults", "elderly_(population_group)"),
    (r"geriatric_patients", "elderly_(population_group)"),
    (r"inpatients", "patients"),
    (r"gender-matched_controls", "humans"),
    (r"pcos_patients", "patients"),
    (r"depressed_women", "women"),
    (r"\bc_group\b", "control_groups"),
    (r"pcos-dp", "patients"),
    (r"hc__mdd__and_pcos_groups", "patients"),
    (r"typically_developing__td__children", "children"),
    (r"td_children", "children"),
    (r"asd_children", "children"),
    (r"mdd_patients", "patients"),
    (r"mdd_group", "population"),
    (r"nvp-1704_group", "population"),
    (r"edf_group", "population"),
    (r"d_and_edf_groups","p_group"),
    (r"reproductive-aged_women","women"),
    (r"pd_and_healthy_controls","parkinson_disease_patients"),
    (r"insomnia_patients","patients"),
    (r"acute_insomnia_patients","patients"),
    (r"chronic_insomnia_patients","patients"),
    (r"tibetan_buddhist_monks","monks"),
    (r"neighbouring_residents","residents"),
    (r"control_subjects","human_subjects"),
    (r"controls", "control_groups"),
    (r"participants_aged_18-40_years","participants"),
    (r"people_with_pd","parkinson_disease_patients"),
    (r"pd_cohort","cohort"),
    (r"southern_hemisphere_pd_population","parkinson_disease_patients"),
    (r"parkinson_s_disease_patients","parkinson_disease_patients"),
    (r"female_pd_patients","parkinson_disease_patients"),
    (r"occidental_patients","patients"),
    (r"non-pd_controls","control_groups"),
    (r"acute_patients","patients"),
    (r"remission_patients","patients"),
    (r"unaffected first-degree relatives","relatives"),
    (r"unaffected_relatives","relatives"),
    (r"controls","control_groups"),
    (r"vvs_children","children"),
    (r"matched_ontrols","control_groups"),
    (r"\bcrs_group\w*\b","chronic_restraint_stress_group"),
    (r"vvs_cases","humans"),
    (r"vvs_patients","patients"),
    (r"\bibs\b","irritable_bowel_syndrome"),
    (r"\bibs-d_patient\w*\b","ibs-d_patients"),
    (r"gut_microbial_composition_of_patients","patients"),
    (r"taiwanese_patients","patients"),
    (r"major_depressive_episode_patients","patients"),
    (r"asd_children","children"),
    (r"typically_developing__td__children","children"),
    (r"td_children","children"),
    (r"criteria-acute_group__patients_with_acute_schizophrenia_","patients_with_schizophrenia"),
    (r"remission_group__patients_with_schizophrenia_in_remission_","patients_with_schizophrenia"),
    (r"control_group__healthy_controls_","control_groups"),
    (r"remission_and_control_groups","control_groups"),
    (r"crew_members","crew_members"),
    (r"older_subjects","elderly_(population_group)"),
    (r"at-risk_groups","control_groups"),
    (r"healthy_persons","persons"),
    (r"generation_over_75","elderly_(population_group)"),
    (r"younger_generations","adolescent"),
    (r"younger_generation","adolescent"),
    (r"egyptian_patients","patients"),
    (r"healthy_subjects","human_subjects"),
    (r"breast_cancer_survivors","cancer_survivors"),
    (r"healthy_population","population"),
    (r"control__c__group", "control_groups"),
    (r"subjects","human_subjects"),
    (r"probiotic_group","control_groups"),
    (r"individual_patient","patients"),
    (r"acute_group","patients"),
    (r"unaffected_first-degree_relatives","relatives"),
    (r"healthy_people","people"),
    (r"\bresident\w*\b","resident_(person)"),
    (r"\bar_and_td_patient\w*\b","patients"),
    (r"\bmale_patient\w*\b","male"),
    (r"\bhc\b","control_groups"),
    (r"\bobese_adult\w*\b","adults"),
    (r"\bdepressed_population\b","depressed_patients"),
    (r"\bsz_patient\w*\b","patients_with_schizophrenia"),
    (r"\bpd_patient_cohort\w*\b","parkinson_disease_patients"),
    (r"\bchildren_within_three_of_these_cluster\w*\b","children"),
    (r"\b14-year-old\w*\b","adolescent"),
    (r"alzheimer_s_patients","alzheimer_disease_patient"),
    (r"\bdonor_patient\w*\b","patients"),
    (r"\bhealthy_adult\w*\b","adult"),
    (r"mentally_healthy_women","women"),
    (r"\bgeriatric_population\w*\b","elderly_(population_group)"),
    (r"\bindividual_patient\w*\b","patients"),
    (r"\bpwp\b","parkinson_disease_patients"),
    (r"\byoung_children\b","children"),
]

CREATOR = "Samuel Piron"

UMLS_BASES = "https://uts.nlm.nih.gov/uts/umls/concept/"
HEREDITARY_BASE = "https://w3id.org/hereditary/ontology/gutbrain/resource/"

for uri in manual_created.values():
    uri_str = str(uri)

    if uri_str.startswith(UMLS_BASES):
        g.add((uri,
               RDFS.comment,
               Literal("UMLS Match", datatype=XSD.string)))
    elif "NCIT" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("NCIT Match", datatype=XSD.string)))
    elif "OMIT" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("OMIT Match", datatype=XSD.string)))
    elif "NCBITaxon" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("NCBITaxon Match", datatype=XSD.string)))
    elif "CHEBI" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("CHEBI Match", datatype=XSD.string)))
    elif "FOODON" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("FOODON Match", datatype=XSD.string)))
    elif "mesh" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("MESH Match", datatype=XSD.string)))
    elif "PCO" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("PCO Match", datatype=XSD.string)))
    else:
        g.add((uri,
               DCTERMS.creator,
               Literal(CREATOR, datatype=XSD.string)))

for term_raw, uri in manual_created.items():
    if (uri, RDFS.label, None) not in g:
        pretty = term_raw.replace("_", " ").title()
        g.add((uri,
               RDFS.label,
               Literal(pretty, datatype=XSD.string)))

for term_raw, uri in manual_created.items():
    uri_str = str(uri)

    # NCIT definitions
    if uri_str.startswith(NCBI_BASE) and "NCIT_" in uri_str:
        ncit_id = uri_str.rsplit("_", 1)[-1]
        desc = get_ncit_description(ncit_id, ncit_file)
        m = re.search(r'—\s*(.*?)\s*—', desc)
        if m:
            desc = m.group(1).strip()
            comment = f"{desc} [Definition Source: NCIT]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # UMLS definitions
    elif uri_str.startswith(UMLS_BASES):
        cui = uri_str.rsplit("/", 1)[-1]
        defn = get_umls_definition(cui)
        if defn:
            comment = f"{defn.strip()} [Definition Source: UMLS]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # MeSH definitions via your mesh_index
    elif uri_str.startswith(MESH_BASE):
        ui     = uri_str.rsplit("/",1)[-1]
        hits   = [d['name'] for d in mesh_descs if d['ui']==ui]
        if hits:
            comment = f"{hits[0]} [Definition Source: MeSH]"
        elif term_raw == "patients":
            comment = "Patients with various diseases. [Definition Source: GUTBRAIN]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    elif uri_str.startswith(HEREDITARY_BASE):
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"
    else:
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    g.add((uri,
           RDFS.comment,
           Literal(comment, datatype=XSD.string)))
    
IBSD_URI = URIRef(
    "https://w3id.org/hereditary/ontology/gutbrain/resource/human/IbsDPatients"
)
ADOLESCENT_URI = URIRef("https://www.ncbi.nlm.nih.gov/mesh/D000293")
ADULT_URI = URIRef("https://www.ncbi.nlm.nih.gov/mesh/D000328")
CHILD_URI = URIRef("https://www.ncbi.nlm.nih.gov/mesh/D002648")
INFANT_URI = URIRef("https://www.ncbi.nlm.nih.gov/mesh/D007223")
MEN_URI = URIRef("https://www.ncbi.nlm.nih.gov/mesh/D008571")
POPULATION_URI = URIRef("https://www.ncbi.nlm.nih.gov/mesh/D011153")
YOUNG_ADULTS = URIRef("https://www.ncbi.nlm.nih.gov/mesh/D055815")  
    
for paper_id, paper_data in data.items():
    entities = paper_data.get("entities", [])
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        if raw_label == "human":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    if lookup_key == "residents":
                        lookup_key = "resident"
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, HUMAN_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    if entity_uri == IBSD_URI:
                        g.add((entity_uri, RDFS.label, Literal("IBS-D Patients", datatype=XSD.string)))
                    elif entity_uri == ADOLESCENT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Adolescent", datatype=XSD.string)))
                    elif entity_uri == ADULT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Adult", datatype=XSD.string)))
                    elif entity_uri == CHILD_URI:
                        g.add((entity_uri, RDFS.label, Literal("Child", datatype=XSD.string)))
                    elif entity_uri == INFANT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Infant", datatype=XSD.string)))
                    elif entity_uri == MEN_URI:
                        g.add((entity_uri, RDFS.label, Literal("Men", datatype=XSD.string)))
                    elif entity_uri == POPULATION_URI:
                        g.add((entity_uri, RDFS.label, Literal("Population", datatype=XSD.string)))
                    else:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, HUMAN_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    if entity_uri == IBSD_URI:
                        g.add((entity_uri, RDFS.label, Literal("IBS-D Patients", datatype=XSD.string)))
                    elif entity_uri == ADOLESCENT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Adolescent", datatype=XSD.string)))
                    elif entity_uri == ADULT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Adult", datatype=XSD.string)))
                    elif entity_uri == CHILD_URI:
                        g.add((entity_uri, RDFS.label, Literal("Child", datatype=XSD.string)))
                    elif entity_uri == INFANT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Infant", datatype=XSD.string)))
                    elif entity_uri == MEN_URI:
                        g.add((entity_uri, RDFS.label, Literal("Men", datatype=XSD.string)))
                    elif entity_uri == POPULATION_URI:
                        g.add((entity_uri, RDFS.label, Literal("Population", datatype=XSD.string)))
                    else:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            mesh_ex = mesh_index.get(term, [])
            cos = top_cosine(term)
            if mesh_ex:
                for t,u,n in mesh_ex:
                    print(f"  • {t:40s} ID={u:15s} depth={n:40s} score=1.00 (TAX1 exact)")
                    entity_uri = URIRef(f"{MESH_BASE}{u}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, HUMAN_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        if entity_uri == IBSD_URI:
                            g.add((entity_uri, RDFS.label, Literal("IBS-D Patients", datatype=XSD.string)))
                        elif entity_uri == ADOLESCENT_URI:
                            g.add((entity_uri, RDFS.label, Literal("Adolescent", datatype=XSD.string)))
                        elif entity_uri == ADULT_URI:
                            g.add((entity_uri, RDFS.label, Literal("Adult", datatype=XSD.string)))
                        elif entity_uri == CHILD_URI:
                            g.add((entity_uri, RDFS.label, Literal("Child", datatype=XSD.string)))
                        elif entity_uri == INFANT_URI:
                            g.add((entity_uri, RDFS.label, Literal("Infant", datatype=XSD.string)))
                        elif entity_uri == MEN_URI:
                            g.add((entity_uri, RDFS.label, Literal("Men", datatype=XSD.string)))
                        elif entity_uri == POPULATION_URI:
                            g.add((entity_uri, RDFS.label, Literal("Population", datatype=XSD.string)))
                        else:
                            g.add((entity_uri,
                                RDFS.label,
                                Literal(t.title(), datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    g.add((entity_uri, RDFS.comment, Literal("MeSH Match", datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for name, ui, depth, score in cos[:1]:
                    print(f"  • {name:40s} ID={ui:15s} depth={depth:<2d} score={score:.2f} (Patients cosine)")
                    name_uri = URIRef(f"{MESH_BASE}{ui}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, HUMAN_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        if name_uri == IBSD_URI:
                            g.add((name_uri, RDFS.label, Literal("IBS-D Patients", datatype=XSD.string)))
                        elif name_uri == ADOLESCENT_URI:
                            g.add((name_uri, RDFS.label, Literal("Adolescent", datatype=XSD.string)))
                        elif name_uri == ADULT_URI:
                            g.add((name_uri, RDFS.label, Literal("Adult", datatype=XSD.string)))
                        elif name_uri == CHILD_URI:
                            g.add((name_uri, RDFS.label, Literal("Child", datatype=XSD.string)))
                        elif name_uri == INFANT_URI:
                            g.add((name_uri, RDFS.label, Literal("Infant", datatype=XSD.string)))
                        elif name_uri == MEN_URI:
                            g.add((name_uri, RDFS.label, Literal("Men", datatype=XSD.string)))
                        elif name_uri == POPULATION_URI:
                            g.add((name_uri, RDFS.label, Literal("Population", datatype=XSD.string)))
                        else:
                            g.add((name_uri,
                                RDFS.label,
                                Literal(name.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    g.add((name_uri, RDFS.comment, Literal("MeSH Match", datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    continue
            else:
                api_term = lookup_key.replace("_", " ")
                umls_hits = search_umls(api_term)
                if umls_hits:
                    cui, name, score, definition = best_umls_match(api_term, umls_hits)
                    if name in created:
                        entity_uri = created[term_raw]
                    else:
                        entity_uri = URIRef(f"https://uts.nlm.nih.gov/uts/umls/concept/{cui}")
                        created[term_raw] = entity_uri

                    g.add((entity_uri, RDF.type,      HUMAN_CLASS))
                    g.add((entity_uri, RDF.type,      SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(name.title(), datatype=XSD.string)))

                    g.add((entity_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                    g.add((entity_uri, RDFS.comment, Literal("UMLS Match", datatype=XSD.string)))
                    if definition:
                        comment_str = f"{definition.strip()} [Definition Source: UMLS]"
                    else:
                        llm_def = get_llm_definition(term_raw)
                        comment_str = f"{llm_def} [Definition Source: llama3-8b-8192]"

                    g.add((entity_uri,
                        RDFS.comment,
                        Literal(comment_str, datatype=XSD.string)))
            
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,        MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,      Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn,    mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print(f"  • UMLS CUI={cui}  Name={name!r}  sim={score:.2f}")
                    continue
                    
                else: 
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,      MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,    Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    tokenized_mentions[term_raw] = mention_uri
                    print("no matches locally or in UMLS")

        else:
            pass

print("entering gold")

for paper_id, paper_data in data_gold.items():
    entities = paper_data.get("entities", [])
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        if raw_label == "human":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    if lookup_key == "residents":
                        lookup_key = "resident"
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, HUMAN_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    if entity_uri == IBSD_URI:
                        g.add((entity_uri, RDFS.label, Literal("IBS-D Patients", datatype=XSD.string)))
                    elif entity_uri == ADOLESCENT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Adolescent", datatype=XSD.string)))
                    elif entity_uri == ADULT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Adult", datatype=XSD.string)))
                    elif entity_uri == CHILD_URI:
                        g.add((entity_uri, RDFS.label, Literal("Child", datatype=XSD.string)))
                    elif entity_uri == INFANT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Infant", datatype=XSD.string)))
                    elif entity_uri == MEN_URI:
                        g.add((entity_uri, RDFS.label, Literal("Men", datatype=XSD.string)))
                    elif entity_uri == POPULATION_URI:
                        g.add((entity_uri, RDFS.label, Literal("Population", datatype=XSD.string)))
                    else:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, HUMAN_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    if entity_uri == IBSD_URI:
                        g.add((entity_uri, RDFS.label, Literal("IBS-D Patients", datatype=XSD.string)))
                    elif entity_uri == ADOLESCENT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Adolescent", datatype=XSD.string)))
                    elif entity_uri == ADULT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Adult", datatype=XSD.string)))
                    elif entity_uri == CHILD_URI:
                        g.add((entity_uri, RDFS.label, Literal("Child", datatype=XSD.string)))
                    elif entity_uri == INFANT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Infant", datatype=XSD.string)))
                    elif entity_uri == MEN_URI:
                        g.add((entity_uri, RDFS.label, Literal("Men", datatype=XSD.string)))
                    elif entity_uri == POPULATION_URI:
                        g.add((entity_uri, RDFS.label, Literal("Population", datatype=XSD.string)))
                    else:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            mesh_ex = mesh_index.get(term, [])
            cos = top_cosine(term)
            if mesh_ex:
                for t,u,n in mesh_ex:
                    print(f"  • {t:40s} ID={u:15s} depth={n:40s} score=1.00 (TAX1 exact)")
                    entity_uri = URIRef(f"{MESH_BASE}{u}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, HUMAN_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        if entity_uri == IBSD_URI:
                            g.add((entity_uri, RDFS.label, Literal("IBS-D Patients", datatype=XSD.string)))
                        elif entity_uri == ADOLESCENT_URI:
                            g.add((entity_uri, RDFS.label, Literal("Adolescent", datatype=XSD.string)))
                        elif entity_uri == ADULT_URI:
                            g.add((entity_uri, RDFS.label, Literal("Adult", datatype=XSD.string)))
                        elif entity_uri == CHILD_URI:
                            g.add((entity_uri, RDFS.label, Literal("Child", datatype=XSD.string)))
                        elif entity_uri == INFANT_URI:
                            g.add((entity_uri, RDFS.label, Literal("Infant", datatype=XSD.string)))
                        elif entity_uri == MEN_URI:
                            g.add((entity_uri, RDFS.label, Literal("Men", datatype=XSD.string)))
                        elif entity_uri == POPULATION_URI:
                            g.add((entity_uri, RDFS.label, Literal("Population", datatype=XSD.string)))
                        else:
                            g.add((entity_uri,
                                RDFS.label,
                                Literal(t.title(), datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    g.add((entity_uri, RDFS.comment, Literal("MeSH Match", datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for name, ui, depth, score in cos[:1]:
                    print(f"  • {name:40s} ID={ui:15s} depth={depth:<2d} score={score:.2f} (Patients cosine)")
                    name_uri = URIRef(f"{MESH_BASE}{ui}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, HUMAN_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        if name_uri == IBSD_URI:
                            g.add((name_uri, RDFS.label, Literal("IBS-D Patients", datatype=XSD.string)))
                        elif name_uri == ADOLESCENT_URI:
                            g.add((name_uri, RDFS.label, Literal("Adolescent", datatype=XSD.string)))
                        elif name_uri == ADULT_URI:
                            g.add((name_uri, RDFS.label, Literal("Adult", datatype=XSD.string)))
                        elif name_uri == CHILD_URI:
                            g.add((name_uri, RDFS.label, Literal("Child", datatype=XSD.string)))
                        elif name_uri == INFANT_URI:
                            g.add((name_uri, RDFS.label, Literal("Infant", datatype=XSD.string)))
                        elif name_uri == MEN_URI:
                            g.add((name_uri, RDFS.label, Literal("Men", datatype=XSD.string)))
                        elif name_uri == POPULATION_URI:
                            g.add((name_uri, RDFS.label, Literal("Population", datatype=XSD.string)))
                        else:
                            g.add((name_uri,
                                RDFS.label,
                                Literal(name.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    g.add((name_uri, RDFS.comment, Literal("MeSH Match", datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    continue
            else:
                api_term = lookup_key.replace("_", " ")
                umls_hits = search_umls(api_term)
                if umls_hits:
                    cui, name, score, definition = best_umls_match(api_term, umls_hits)
                    if name in created:
                        entity_uri = created[term_raw]
                    else:
                        entity_uri = URIRef(f"https://uts.nlm.nih.gov/uts/umls/concept/{cui}")
                        created[term_raw] = entity_uri

                    g.add((entity_uri, RDF.type,      HUMAN_CLASS))
                    g.add((entity_uri, RDF.type,      SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(name.title(), datatype=XSD.string)))

                    g.add((entity_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                    g.add((entity_uri, RDFS.comment, Literal("UMLS Match", datatype=XSD.string)))
                    if definition:
                        comment_str = f"{definition.strip()} [Definition Source: UMLS]"
                    else:
                        llm_def = get_llm_definition(term_raw)
                        comment_str = f"{llm_def} [Definition Source: llama3-8b-8192]"

                    g.add((entity_uri,
                        RDFS.comment,
                        Literal(comment_str, datatype=XSD.string)))
            
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,        MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,      Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn,    mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print(f"  • UMLS CUI={cui}  Name={name!r}  sim={score:.2f}")
                    continue
                    
                else: 
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,      MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,    Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    tokenized_mentions[term_raw] = mention_uri
                    print("no matches locally or in UMLS")

        else:
            pass
        
print("entering dev")

for paper_id, paper_data in data_dev.items():
    entities = paper_data.get("entities", [])
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        if raw_label == "human":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    if lookup_key == "residents":
                        lookup_key = "resident"
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, HUMAN_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    if entity_uri == IBSD_URI:
                        g.add((entity_uri, RDFS.label, Literal("IBS-D Patients", datatype=XSD.string)))
                    elif entity_uri == ADOLESCENT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Adolescent", datatype=XSD.string)))
                    elif entity_uri == ADULT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Adult", datatype=XSD.string)))
                    elif entity_uri == CHILD_URI:
                        g.add((entity_uri, RDFS.label, Literal("Child", datatype=XSD.string)))
                    elif entity_uri == INFANT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Infant", datatype=XSD.string)))
                    elif entity_uri == MEN_URI:
                        g.add((entity_uri, RDFS.label, Literal("Men", datatype=XSD.string)))
                    elif entity_uri == POPULATION_URI:
                        g.add((entity_uri, RDFS.label, Literal("Population", datatype=XSD.string)))
                    else:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, HUMAN_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    if entity_uri == IBSD_URI:
                        g.add((entity_uri, RDFS.label, Literal("IBS-D Patients", datatype=XSD.string)))
                    elif entity_uri == ADOLESCENT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Adolescent", datatype=XSD.string)))
                    elif entity_uri == ADULT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Adult", datatype=XSD.string)))
                    elif entity_uri == CHILD_URI:
                        g.add((entity_uri, RDFS.label, Literal("Child", datatype=XSD.string)))
                    elif entity_uri == INFANT_URI:
                        g.add((entity_uri, RDFS.label, Literal("Infant", datatype=XSD.string)))
                    elif entity_uri == MEN_URI:
                        g.add((entity_uri, RDFS.label, Literal("Men", datatype=XSD.string)))
                    elif entity_uri == POPULATION_URI:
                        g.add((entity_uri, RDFS.label, Literal("Population", datatype=XSD.string)))
                    else:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            mesh_ex = mesh_index.get(term, [])
            cos = top_cosine(term)
            if mesh_ex:
                for t,u,n in mesh_ex:
                    print(f"  • {t:40s} ID={u:15s} depth={n:40s} score=1.00 (TAX1 exact)")
                    entity_uri = URIRef(f"{MESH_BASE}{u}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, HUMAN_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        if entity_uri == IBSD_URI:
                            g.add((entity_uri, RDFS.label, Literal("IBS-D Patients", datatype=XSD.string)))
                        elif entity_uri == ADOLESCENT_URI:
                            g.add((entity_uri, RDFS.label, Literal("Adolescent", datatype=XSD.string)))
                        elif entity_uri == ADULT_URI:
                            g.add((entity_uri, RDFS.label, Literal("Adult", datatype=XSD.string)))
                        elif entity_uri == CHILD_URI:
                            g.add((entity_uri, RDFS.label, Literal("Child", datatype=XSD.string)))
                        elif entity_uri == INFANT_URI:
                            g.add((entity_uri, RDFS.label, Literal("Infant", datatype=XSD.string)))
                        elif entity_uri == MEN_URI:
                            g.add((entity_uri, RDFS.label, Literal("Men", datatype=XSD.string)))
                        elif entity_uri == POPULATION_URI:
                            g.add((entity_uri, RDFS.label, Literal("Population", datatype=XSD.string)))
                        else:
                            g.add((entity_uri,
                                RDFS.label,
                                Literal(t.title(), datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    g.add((entity_uri, RDFS.comment, Literal("MeSH Match", datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for name, ui, depth, score in cos[:1]:
                    print(f"  • {name:40s} ID={ui:15s} depth={depth:<2d} score={score:.2f} (Patients cosine)")
                    name_uri = URIRef(f"{MESH_BASE}{ui}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, HUMAN_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        if name_uri == IBSD_URI:
                            g.add((name_uri, RDFS.label, Literal("IBS-D Patients", datatype=XSD.string)))
                        elif name_uri == ADOLESCENT_URI:
                            g.add((name_uri, RDFS.label, Literal("Adolescent", datatype=XSD.string)))
                        elif name_uri == ADULT_URI:
                            g.add((name_uri, RDFS.label, Literal("Adult", datatype=XSD.string)))
                        elif name_uri == CHILD_URI:
                            g.add((name_uri, RDFS.label, Literal("Child", datatype=XSD.string)))
                        elif name_uri == INFANT_URI:
                            g.add((name_uri, RDFS.label, Literal("Infant", datatype=XSD.string)))
                        elif name_uri == MEN_URI:
                            g.add((name_uri, RDFS.label, Literal("Men", datatype=XSD.string)))
                        elif name_uri == POPULATION_URI:
                            g.add((name_uri, RDFS.label, Literal("Population", datatype=XSD.string)))
                        else:
                            g.add((name_uri,
                                RDFS.label,
                                Literal(name.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    g.add((name_uri, RDFS.comment, Literal("MeSH Match", datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    continue
            else:
                api_term = lookup_key.replace("_", " ")
                umls_hits = search_umls(api_term)
                if umls_hits:
                    cui, name, score, definition = best_umls_match(api_term, umls_hits)
                    if name in created:
                        entity_uri = created[term_raw]
                    else:
                        entity_uri = URIRef(f"https://uts.nlm.nih.gov/uts/umls/concept/{cui}")
                        created[term_raw] = entity_uri

                    g.add((entity_uri, RDF.type,      HUMAN_CLASS))
                    g.add((entity_uri, RDF.type,      SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(name.title(), datatype=XSD.string)))

                    g.add((entity_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                    g.add((entity_uri, RDFS.comment, Literal("UMLS Match", datatype=XSD.string)))
                    if definition:
                        comment_str = f"{definition.strip()} [Definition Source: UMLS]"
                    else:
                        llm_def = get_llm_definition(term_raw)
                        comment_str = f"{llm_def} [Definition Source: llama3-8b-8192]"

                    g.add((entity_uri,
                        RDFS.comment,
                        Literal(comment_str, datatype=XSD.string)))
            
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,        MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,      Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn,    mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print(f"  • UMLS CUI={cui}  Name={name!r}  sim={score:.2f}")
                    continue
                    
                else: 
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,      MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,    Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    tokenized_mentions[term_raw] = mention_uri
                    print("no matches locally or in UMLS")

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "human":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[cleaned_text_span])
            tokenized_mentions[cleaned_text_span] = mention_uri
            print(cleaned_text_span)
            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_human_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_gold_file, "r", encoding="utf-8") as f_sent:
    tokenized_gold_data = json.load(f_sent)

for entry in tokenized_gold_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "human":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_human_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_dev, "r", encoding="utf-8") as f_sent:
    tokenized_dev_data = json.load(f_sent)

for entry in tokenized_dev_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "human":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_human_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

output_file = os.path.join(save_path, "gutbrain_entities.ttl")
ttl_output = g.serialize(format="turtle")
with open(output_file, "w", encoding="utf-8") as f_out:
    f_out.write(ttl_output)

print(f"The RDF graph has been saved in {output_file}")
# Out:
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: people
# lookup term: people
#   • UMLS CUI=C0027361  Name='Persons'  sim=0.00
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   • UMLS CUI=C0009932  Name='Control Groups'  sim=1.00
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   • UMLS CUI=C0009932  Name='Control Groups'  sim=1.00
# Query: human
# lookup term: humans
#   • UMLS CUI=C1300203  Name='Genus Homo'  sim=0.00
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: female
# lookup term: females
#   • UMLS CUI=C0086287  Name='Females'  sim=1.00
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
#
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# control_groups
# Query: control group
# lookup term: control_groups
#   • UMLS CUI=C0009932  Name='Control Groups'  sim=1.00
# cohort
# Query: cohort
# lookup term: cohort
#   • UMLS CUI=C0599755  Name='Cohort'  sim=1.00
# control_groups
# Query: control group
# lookup term: control_groups
#   • UMLS CUI=C0009932  Name='Control Groups'  sim=1.00
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# adult
# Query: adult
# lookup term: adult
#   • M01.060.116                              ID=D000328         depth=Adult                                    score=1.00 (TAX1 exact)
# people
# Query: people
# lookup term: people
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
# control_groups
# Query: control group
# lookup term: control_groups
#   • UMLS CUI=C0009932  Name='Control Groups'  sim=1.00
# people
# Query: people
# lookup term: people
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# adult
# Query: adult
# lookup term: adult
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D000328
#
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
#
# individual
# Query: individual
# lookup term: individual
#   • UMLS CUI=C0237401  Name='Individual'  sim=1.00
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
#
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
#
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
#
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
#
# individual
# Query: individual
# lookup term: individual
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0237401
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# irritable_bowel_syndrome
# Query: irritable bowel syndrome
# lookup term: irritable_bowel_syndrome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/IbsDPatients
#
#
# depressed_patients
# Query: depressed patient
# lookup term: depressed_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/DepressedPatients
#
# humans
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
# Query: mother
# lookup term: mother
#   • UMLS CUI=C1546508  Name='Relationship - Mother'  sim=0.51
# infants
# Query: infant
# lookup term: infants
#   • M01.060.703                              ID=D007223         depth=Infant                                   score=1.00 (TAX1 exact)
# infants
# Query: infant
# lookup term: infants
#   • M01.060.703                              ID=D007223         depth=Infant                                   score=1.00 (TAX1 exact)
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# population
# Query: population
# lookup term: population
#   • N01.600                                  ID=D011153         depth=Population                               score=1.00 (TAX1 exact)
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# humans
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
# humans
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
# humans
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# individual
# Query: individual
# lookup term: individual
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0237401
#
#
# Query: offspring
# lookup term: offspring
#   • UMLS CUI=C0680063  Name='Offspring'  sim=1.00
# Query: child
# lookup term: child
#   • M01.060.406                              ID=D002648         depth=Child                                    score=1.00 (TAX1 exact)
# Query: woman
# lookup term: women
#   • UMLS CUI=C0043210  Name='Woman'  sim=0.00
# Query: woman
# lookup term: women
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0043210
#
#
# Query: child
# lookup term: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: child
# lookup term: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: woman
# lookup term: women
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0043210
#
#
# Query: child
# lookup term: children
#   • M01.060.406                              ID=D002648         depth=Child                                    score=1.00 (TAX1 exact)
# Query: woman
# lookup term: women
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0043210
#
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: adolescent
# lookup term: adolescents
#   • M01.060.057                              ID=D000293         depth=Adolescent                               score=1.00 (TAX1 exact)
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: adolescent
# lookup term: adolescents
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D000293
#
#
# Query: pediatric population
# lookup term: pediatric_population
#   • UMLS CUI=C5547365  Name='Pediatric population'  sim=1.00
# population
# Query: population
# lookup term: population
#   • N01.600                                  ID=D011153         depth=Population                               score=1.00 (TAX1 exact)
# adolescent
# Query: adolescent
# lookup term: adolescent
#   • M01.060.057                              ID=D000293         depth=Adolescent                               score=1.00 (TAX1 exact)
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   • UMLS CUI=C0009932  Name='Control Groups'  sim=1.00
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: adolescent
# lookup term: adolescents
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D000293
#
#
# population
# Query: population
# lookup term: population
#   • N01.600                                  ID=D011153         depth=Population                               score=1.00 (TAX1 exact)
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: participant
# lookup term: participants
#   • UMLS CUI=C0679646  Name='Participant'  sim=0.00
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: military veteran
# lookup term: military_veterans
#   • UMLS CUI=C0237945  Name='Military Veterans'  sim=1.00
# individual
# Query: individual
# lookup term: individual
#   • UMLS CUI=C0237401  Name='Individual'  sim=1.00
# Query: veteran
# lookup term: veterans
#   • UMLS CUI=C0042610  Name='Veterans'  sim=1.00
# individual
# Query: individual
# lookup term: individual
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0237401
#
#
# Query: veteran
# lookup term: veterans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042610
#
#
# Query: veteran
# lookup term: veterans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042610
#
#
# Query: veteran
# lookup term: veterans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042610
#
#
# Query: veteran
# lookup term: veterans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042610
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# individual
# Query: individual
# lookup term: individual
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0237401
#
#
# Query: person
# lookup term: persons
#   • UMLS CUI=C0027361  Name='Persons'  sim=1.00
# individual
# Query: individual
# lookup term: individual
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0237401
#
#
# elderly_(population_group)
# Query: elderly (population group)
# lookup term: elderly_(population_group)
#   • UMLS CUI=C0001792  Name='Elderly (population group)'  sim=1.00
# elderly_(population_group)
# Query: elderly (population group)
# lookup term: elderly_(population_group)
#   • UMLS CUI=C0001792  Name='Elderly (population group)'  sim=1.00
# elderly_(population_group)
# Query: elderly (population group)
# lookup term: elderly_(population_group)
#   • UMLS CUI=C0001792  Name='Elderly (population group)'  sim=1.00
# elderly_(population_group)
# Query: elderly (population group)
# lookup term: elderly_(population_group)
#   • UMLS CUI=C0001792  Name='Elderly (population group)'  sim=1.00
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: older adult
# lookup term: older_adults
#   • UMLS CUI=C0001792  Name='Elderly (population group)'  sim=0.00
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# Query: female
# lookup term: females
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0086287
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   • UMLS CUI=C0009932  Name='Control Groups'  sim=1.00
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: population
# lookup term: population
#   • N01.600                                  ID=D011153         depth=Population                               score=1.00 (TAX1 exact)
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# women
# Query: woman
# lookup term: women
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0043210
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# women
# Query: woman
# lookup term: women
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0043210
#
# control_groups
# Query: control group
# lookup term: control_groups
#   • UMLS CUI=C0009932  Name='Control Groups'  sim=1.00
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: major depressive disorder patient
# lookup term: major_depressive_disorder_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/MajorDepressiveDisorderPatients
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# humans
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# humans
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# population
# Query: population
# lookup term: population
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D011153
#
# population
# Query: population
# lookup term: population
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D011153
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# humans
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
# adult
# Query: adult
# lookup term: adult
#   • M01.060.116                              ID=D000328         depth=Adult                                    score=1.00 (TAX1 exact)
# adult
# Query: adult
# lookup term: adult
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D000328
#
#
# population
# Query: population
# lookup term: population
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D011153
#
# people
# Query: people
# lookup term: people
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
# population
# Query: population
# lookup term: population
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D011153
#
# Query: p group
# lookup term: p_group
#   • UMLS CUI=C1959644  Name='P group'  sim=1.00
# population
# Query: population
# lookup term: population
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D011153
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# individual
# Query: individual
# lookup term: individual
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0237401
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# individual
# Query: individual
# lookup term: individual
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0237401
#
#
# Query: woman
# lookup term: women
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0043210
#
#
# women
# Query: woman
# lookup term: women
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0043210
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: alcohol overconsumption group
# lookup term: alcohol_overconsumption_group
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/AlcoholOverconsumptionGroup
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   • UMLS CUI=C0009932  Name='Control Groups'  sim=1.00
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# humans
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# humans
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
# humans
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# monks
# Query: monk
# lookup term: monks
#   • UMLS CUI=C0682252  Name='Monks'  sim=1.00
# resident
# Query: resident
# lookup term: resident
#   • UMLS CUI=C2347958  Name='Resident (person)'  sim=0.43
# Query: monk
# lookup term: monks
#   • UMLS CUI=C0682252  Name='Monks'  sim=1.00
# control_groups
# Query: control group
# lookup term: control_groups
#   • UMLS CUI=C0009932  Name='Control Groups'  sim=1.00
# Query: monk
# lookup term: monks
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0682252
#
#
# Query: female
# lookup term: females
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0086287
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: female
# lookup term: females
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0086287
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
#
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
#
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
#
# participants
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# control_groups
# Query: control group
# lookup term: control_groups
#   • UMLS CUI=C0009932  Name='Control Groups'  sim=1.00
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# cohort
# Query: cohort
# lookup term: cohort
#   • UMLS CUI=C0599755  Name='Cohort'  sim=1.00
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# human_subjects
# Query: human subject
# lookup term: human_subjects
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/HumanSubjects
#
#
# individual
# Query: individual
# lookup term: individual
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0237401
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# Query: population
# lookup term: populations
#   • N01.600                                  ID=D011153         depth=Population                               score=1.00 (TAX1 exact)
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# people
# Query: people
# lookup term: people
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
# Query: woman
# lookup term: women
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0043210
#
#
# Query: men
# lookup term: men
#   • M01.390                                  ID=D008571         depth=Men                                      score=1.00 (TAX1 exact)
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# relatives
# Query: relative
# lookup term: relatives
#   • UMLS CUI=C0080103  Name='Relative (related person)'  sim=0.00
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: smoker
# lookup term: smokers
#   • UMLS CUI=C0337664  Name='Smoker'  sim=0.00
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: smoker
# lookup term: smokers
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0337664
#
#
# Query: non-smoking patient
# lookup term: non-smoking_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/NonSmokingPatients
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# Query: smoker
# lookup term: smokers
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0337664
#
#
# relatives
# Query: relative
# lookup term: relatives
#   • UMLS CUI=C0080103  Name='Relative (related person)'  sim=0.00
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# humans
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: patient with schizophrenia
# lookup term: patients_with_schizophrenia
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/PatientsWithSchizophrenia
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: male
# lookup term: males
#   • UMLS CUI=C0086582  Name='Males'  sim=1.00
# Query: female
# lookup term: females
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0086287
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# children
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
#
# patients_with_schizophrenia
# Query: patient with schizophrenia
# lookup term: patients_with_schizophrenia
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/PatientsWithSchizophrenia
#
# patients_with_schizophrenia
# Query: patient with schizophrenia
# lookup term: patients_with_schizophrenia
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/PatientsWithSchizophrenia
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: people
# lookup term: people
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
#
# crew_members
# Query: crew member
# lookup term: crew_members
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/CrewMembers
#
#
# elderly_(population_group)
# Query: elderly (population group)
# lookup term: elderly_(population_group)
#   • UMLS CUI=C0001792  Name='Elderly (population group)'  sim=1.00
# elderly_(population_group)
# Query: elderly (population group)
# lookup term: elderly_(population_group)
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0001792
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
#
# persons
# Query: person
# lookup term: persons
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
# persons
# Query: person
# lookup term: persons
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
# Query: woman
# lookup term: women
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0043210
#
#
# Query: men
# lookup term: men
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D008571
#
#
# Query: people
# lookup term: people
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
#
# Query: people
# lookup term: people
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
#
# individual
# Query: individual
# lookup term: individual
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0237401
#
#
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
#
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
#
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# people
# Query: people
# lookup term: people
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
# elderly_(population_group)
# Query: elderly (population group)
# lookup term: elderly_(population_group)
#   • UMLS CUI=C0001792  Name='Elderly (population group)'  sim=1.00
# adolescent
# Query: adolescent
# lookup term: adolescent
#   • M01.060.057                              ID=D000293         depth=Adolescent                               score=1.00 (TAX1 exact)
# adolescent
# Query: adolescent
# lookup term: adolescent
#   • M01.060.057                              ID=D000293         depth=Adolescent                               score=1.00 (TAX1 exact)
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# human_subjects
# Query: human subject
# lookup term: human_subjects
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/HumanSubjects
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# control_groups
# Query: control group
# lookup term: control_groups
# ...
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# adults
# Query: adult
# lookup term: adults
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D000328
#
# participants
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
# participants
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
# adult
# Query: adult
# lookup term: adult
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D000328
#
#
# Query: person
# lookup term: persons
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
#
# people_with_hiv
# Query: people with hiv
# lookup term: people_with_hiv
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/PeopleWithHiv
#
# Query: adult
# lookup term: adults
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D000328
#
#
# people_with_hiv
# Query: people with hiv
# lookup term: people_with_hiv
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/PeopleWithHiv
#
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
#
# people_with_hiv
# Query: people with hiv
# lookup term: people_with_hiv
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/PeopleWithHiv
#
# people_with_hiv
# Query: people with hiv
# lookup term: people_with_hiv
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/PeopleWithHiv
#
# people_with_hiv
# Query: people with hiv
# lookup term: people_with_hiv
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/PeopleWithHiv
#
# population
# Query: population
# lookup term: population
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D011153
#
# human
# Query: human
# lookup term: human
#   • UMLS CUI=C0086418  Name='Homo sapiens'  sim=0.00
# human_subjects
# Query: human subject
# lookup term: human_subjects
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/HumanSubjects
#
# individual
# Query: individual
# lookup term: individual
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0237401
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# individual
# Query: individual
# lookup term: individual
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0237401
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# depressed_patients
# Query: depressed patient
# lookup term: depressed_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/DepressedPatients
#
# population
# Query: population
# lookup term: population
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D011153
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
#
# Query:
# lookup term:
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/MultipleSclerosisPatients
#
#
# people
# Query: people
# lookup term: people
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
# Query: female
# lookup term: females
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0086287
#
#
# individual
# Query: individual
# lookup term: individual
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0237401
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# individual
# Query: individual
# lookup term: individual
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0237401
#
#
# Query: ar and td patient
# lookup term: ar_and_td_patients
# no matches locally or in UMLS
# Query: male patient
# lookup term: male_patients
#   • UMLS CUI=C0150904  Name='patient is male'  sim=0.34
# Query: person
# lookup term: persons
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: hc
# lookup term: hc
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0202056
#
#
# Query: person
# lookup term: persons
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
#
# Query: person
# lookup term: persons
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
#
# Query: hc
# lookup term: hc
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0202056
#
#
# Query: person
# lookup term: persons
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027361
#
#
# Query: hc
# lookup term: hc
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0202056
#
#
# adult
# Query: adult
# lookup term: adult
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D000328
#
#
# individual
# Query: individual
# lookup term: individual
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0237401
#
#
# elderly_(population_group)
# Query: elderly (population group)
# lookup term: elderly_(population_group)
#   • UMLS CUI=C0001792  Name='Elderly (population group)'  sim=1.00
# individual
# Query: individual
# lookup term: individual
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0237401
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: men
# lookup term: men
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D008571
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# Query: men
# lookup term: men
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D008571
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: hc
# lookup term: hc
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0202056
#
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: hc
# lookup term: hc
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0202056
#
#
# parkinson_disease_patients
# Query: parkinson disease patient
# lookup term: parkinson_disease_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/ParkinsonDiseasePatients
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
#
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
#
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
#
# human_subjects
# Query: human subject
# lookup term: human_subjects
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/HumanSubjects
#
# human_subjects
# Query: human subject
# lookup term: human_subjects
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/HumanSubjects
#
# Query: men
# lookup term: men
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D008571
#
#
# Query: woman
# lookup term: women
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0043210
#
#
# Query: obese adult
# lookup term: obese_adults
# no matches locally or in UMLS
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# population
# Query: population
# lookup term: population
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D011153
#
# Query: depressed population
# lookup term: depressed_population
# no matches locally or in UMLS
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# depressed_patients
# Query: depressed patient
# lookup term: depressed_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/DepressedPatients
#
#
# patients
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
# population
# Query: population
# lookup term: population
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D011153
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# population
# Query: population
# lookup term: population
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D011153
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# population
# Query: population
# lookup term: population
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D011153
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# Query: participant
# lookup term: participants
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0679646
#
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# depressed_patients
# Query: depressed patient
# lookup term: depressed_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/DepressedPatients
#
#
# Query: sz patient
# lookup term: sz_patients
# no matches locally or in UMLS
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# human_subjects
# Query: human subject
# lookup term: human_subjects
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/HumanSubjects
#
# depressed_patients
# Query: depressed patient
# lookup term: depressed_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/DepressedPatients
#
#
# Query: affected patient
# lookup term: affected_patients
#   • UMLS CUI=C0522476  Name='Patient affected'  sim=0.34
# Query: pd patient cohort
# lookup term: pd_patient_cohorts
# no matches locally or in UMLS
# Query: child
# lookup term: children
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
#
# Query: child within three of these cluster
# lookup term: children_within_three_of_these_clusters
# no matches locally or in UMLS
# Query: 14-year-olds
# lookup term: 14-year-olds
# no matches locally or in UMLS
# Query: alzheimer s patient
# lookup term: alzheimer_s_patients
# no matches locally or in UMLS
# Query: alzheimer s patient
# lookup term: alzheimer_s_patients
# no matches locally or in UMLS
# Query: alzheimer s patient
# lookup term: alzheimer_s_patients
# no matches locally or in UMLS
# control_groups
# Query: control group
# lookup term: control_groups
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009932
#
# Query: donor patient
# lookup term: donor_patients
# no matches locally or in UMLS
# Query: living human
# lookup term: living_humans
# no matches locally or in UMLS
# Query: alzheimer s patient
# lookup term: alzheimer_s_patients
# no matches locally or in UMLS
# Query: human
# lookup term: humans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1300203
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# depressed_patients
# Query: depressed patient
# lookup term: depressed_patients
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/human/DepressedPatients
#
#
# Query: patient
# lookup term: patients
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68010361
#
#
# The RDF graph has been saved in c:\Users\samue\OneDrive\Desktop\ThesisPiron\rdf\gutbrain_entities.ttl

# %% [markdown]
# <h1>INGEST DRUG</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint
from rdflib.namespace import DCTERMS
from groqutils import get_llm_definition
from funcutils import get_ncit_description, get_chebi_description, get_omit_description, NCBI_BASE, HEREDITARY_BASE, UMLS_BASES, foodon_file, ncit_file, omit_file, chebi_file, hash_term_sha256

DRUG_BASE = "http://purl.obolibrary.org/obo/"
DRUG_CLASS = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Drug")
DRUG_CONCEPT_SCHEME = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Drug")


def load_chebi_labels(path):
    rows = []
    with open(path, encoding="utf-8") as fh:
        next(fh) 
        for ln in fh:
            uri, label = ln.rstrip("\n").split("\t", 1)
            rows.append((label, uri))
    return rows

CHEBI_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\chebi_labels.txt"
chebi_rows = load_chebi_labels(CHEBI_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in chebi_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

labels_only = [lbl for lbl, _ in chebi_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

def top_cosine(term, k=5, thr=0.75):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = chebi_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

greek_map = {
    'α': 'alpha',  'Α': 'alpha',
    'β': 'beta',   'Β': 'beta',
    'γ': 'gamma',  'Γ': 'gamma',
    'δ': 'delta',  'Δ': 'delta',
    'ε': 'epsilon','Ε': 'epsilon',
    'ζ': 'zeta',   'Ζ': 'zeta',
    'η': 'eta',    'Η': 'eta',
    'θ': 'theta',  'Θ': 'theta',
    'ι': 'iota',   'Ι': 'iota',
    'κ': 'kappa',  'Κ': 'kappa',
    'λ': 'lambda', 'Λ': 'lambda',
    'μ': 'mu',     'Μ': 'mu',
    'ν': 'nu',     'Ν': 'nu',
    'ξ': 'xi',     'Ξ': 'xi',
    'ο': 'omicron','Ο': 'omicron',
    'π': 'pi',     'Π': 'pi',
    'ρ': 'rho',    'Ρ': 'rho',
    'σ': 'sigma',  'Σ': 'sigma',
    'τ': 'tau',    'Τ': 'tau',
    'υ': 'upsilon','Υ': 'upsilon',
    'φ': 'phi',    'Φ': 'phi',
    'χ': 'chi',    'Χ': 'chi',
    'ψ': 'psi',    'Ψ': 'psi',
    'ω': 'omega',  'Ω': 'omega',
}

def preprocess(term):
    for greek_char, name in greek_map.items():
        if greek_char in term:
            term = term.replace(greek_char, name)
    term = term.replace('_', ' ')
    term = term.strip()
    return term.lower()

manual_created = {}
created = {}

manual_created = {
    "antibiotic" : URIRef("http://purl.obolibrary.org/obo/NCIT_C258"),
    "antibiotic_growth_promotant" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/drug/AntibioticGrowthPromotant"),
    "vancomycin" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0042313"),
    "placebo_oral_tablet" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1249327"),
    "ct-26": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/drug/Ct26"),
    "rhepo" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/Rhepo"),
    "cuprizone": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0010460"),
    "anti-anxiety_agents": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0040616"),
    "gv-971":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5435122"),
    "arketamine": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5940914"),
    "esketamine": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C2825616"),
    "enantiomer": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0599473"),
    "levodopa": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0023570"),
    "citalopram": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0008845"),
    "adrenergic_beta-antagonists": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0001645"),
    "pharmacologic_substance": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1254351"),
    "anti-infective_combinations": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C2194218"),
    "pharmaceutical_preparations": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0013227"),
    "plx5622": URIRef("http://purl.obolibrary.org/obo/CHEBI_230497"),
    "selective_serotonin_reuptake_inhibitors":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0360105"),
    "antidepressive_agents": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0003289"),
    "cbt-101": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4725914"),
    "vaccines":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0042210"),
}

created = dict(manual_created)

regex_map = [
    (r"agp", "antibiotic_growth_promotant"),
    (r"bactericidal_antibiotic","antibiotic"),
    (r"\bvaccine\w*\b","vaccines"),
    (r"selective_serotonin_reuptake_inhibitor__ssri__citalopram","citalopram"),
    (r"antidepressant_treatment","antidepressive_agents"),
    (r"escitalopram_treatment","escitalopram"),
    (r"\bcbt\b","cbt-101"),
    (r"anti-infective_medication","anti-infective_combinations"),
    (r"\bcit\b","citalopram"),
    (r"ssris_treatment","selective_serotonin_reuptake_inhibitors")
    (r"residual_levodopa_medication","levodopa"),
    (r"levodopa_medication","levodopa"),
    (r"broad-spectrum_antibiotic","antibiotic"),
    (r"serotonin_and_norepinephrine_reuptake_inhibitor_antidepressant","antidepressant"),
    (r"prescription_medication","pharmaceutical_preparations"),
    (r"beta-blocker","adrenergic_beta-antagonists"),
    (r"\b_s_-ketamine\b","esketamine"),
    (r"diabete_ medication","pharmaceutical_preparations"),
    (r"psychiatric_pharmacological_agent","pharmacologic_substance"),
    (r"ketamine_enantiomer","enantiomer"),
    (r"non-absorbable_antibiotic_vancomycin","vancomycin"),
    (r"placebo_tablet", "placebo_oral_tablet"),
    (r"placebo", "placebo_oral_tablet"),
    (r"cpz", "cuprizone"),
    (r"anti-anxiety_drug","anti-anxiety_agents"),
    (r"diabetes_medication","pharmacologic_substance"),
    (r"antidepressant_pmx","antidepressant"),
    (r"\bbhb\b","beta-hydroxy_butyrate"),
    (r"\bnovel_antibiotic\b","antibiotic"),
    (r"antibiotic_treatment","antibiotic"),
    (r"\bdex\b","dexamethasone"),
    (r"colony_stimulating_factor_1_receptor_inhibitor_plx5622","plx5622"),
    (r"antibiotic_cocktail","antibiotic"),
    (r"antibiofilm_agent","agent"),
]
CREATOR = "Samuel Piron"

UMLS_BASES = "https://uts.nlm.nih.gov/uts/umls/concept/"

for uri in manual_created.values():
    uri_str = str(uri)

    if uri_str.startswith(UMLS_BASES):
        g.add((uri,
               RDFS.comment,
               Literal("UMLS Match", datatype=XSD.string)))
    elif "NCIT" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("NCIT Match", datatype=XSD.string)))
    elif "OMIT" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("OMIT Match", datatype=XSD.string)))
    elif "NCBITaxon" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("NCBITaxon Match", datatype=XSD.string)))
    elif "CHEBI" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("CHEBI Match", datatype=XSD.string)))
    elif "FOODON" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("FOODON Match", datatype=XSD.string)))
    elif "mesh" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("MESH Match", datatype=XSD.string)))
    elif "PCO" in uri_str:
        g.add((uri,
               RDFS.comment,
               Literal("PCO Match", datatype=XSD.string)))
    else:
        g.add((uri,
               DCTERMS.creator,
               Literal(CREATOR, datatype=XSD.string)))

for term_raw, uri in manual_created.items():
    uri_str = str(uri)

    if uri_str.startswith(NCBI_BASE) and "NCIT_" in uri_str:
        ncit_id = uri_str.rsplit("_", 1)[-1]
        desc = get_ncit_description(ncit_id, ncit_file)
        m = re.search(r'—\s*(.*?)\s*—', desc)
        if m:
            desc = m.group(1).strip()
            comment = f"{desc} [Definition Source: NCIT]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    elif uri_str.startswith(UMLS_BASES):
        cui = uri_str.rsplit("/", 1)[-1]
        defn = get_umls_definition(cui)
        if defn:
            comment = f"{defn.strip()} [Definition Source: UMLS]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    elif uri_str.startswith(HEREDITARY_BASE):
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"
    else:
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    g.add((uri,
           RDFS.comment,
           Literal(comment, datatype=XSD.string)))

for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "drug":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, DRUG_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DRUG_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, DRUG_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DRUG_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, DRUG_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, DRUG_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    elif "ohmi" in uri_str:
                        comment = "OHMI Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 

            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DRUG_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DRUG_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    elif "ohmi" in uri_str:
                        comment = "OHMI Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no match")
                continue

        else:
            pass

print("entering gold")

for paper_id, paper_data in data_gold.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "drug":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, DRUG_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DRUG_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, DRUG_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DRUG_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, DRUG_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, DRUG_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    elif "ohmi" in uri_str:
                        comment = "OHMI Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 

            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DRUG_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DRUG_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    elif "ohmi" in uri_str:
                        comment = "OHMI Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no match")
                continue

        else:
            pass

print("entering dev")

for paper_id, paper_data in data_dev.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "drug":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, DRUG_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DRUG_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, DRUG_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DRUG_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, DRUG_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, DRUG_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    elif "ohmi" in uri_str:
                        comment = "OHMI Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 

            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DRUG_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DRUG_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    elif "ohmi" in uri_str:
                        comment = "OHMI Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no match")
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "drug":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_gold_file, "r", encoding="utf-8") as f_sent:
    tokenized_gold_data = json.load(f_sent)

for entry in tokenized_gold_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "drug":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_dev, "r", encoding="utf-8") as f_sent:
    tokenized_dev_data = json.load(f_sent)

for entry in tokenized_dev_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "drug":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))
# Out:
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: antibiotic growth promotant
# lookup term: antibiotic_growth_promotant
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/drug/AntibioticGrowthPromotant
#
# antibiotic_growth_promotant
# Query: antibiotic growth promotant
# lookup term: antibiotic_growth_promotant
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/drug/AntibioticGrowthPromotant
#
# antibiotic_growth_promotant
# Query: antibiotic growth promotant
# lookup term: antibiotic_growth_promotant
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/drug/AntibioticGrowthPromotant
#
# antibiotic_growth_promotant
# Query: antibiotic growth promotant
# lookup term: antibiotic_growth_promotant
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/drug/AntibioticGrowthPromotant
#
# antibiotic_growth_promotant
# Query: antibiotic growth promotant
# lookup term: antibiotic_growth_promotant
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/drug/AntibioticGrowthPromotant
#
# antibiotic_growth_promotant
# Query: antibiotic growth promotant
# lookup term: antibiotic_growth_promotant
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/drug/AntibioticGrowthPromotant
#
# antibiotic_growth_promotant
# Query: antibiotic growth promotant
# lookup term: antibiotic_growth_promotant
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/drug/AntibioticGrowthPromotant
#
# antibiotic_growth_promotant
# Query: antibiotic growth promotant
# lookup term: antibiotic_growth_promotant
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/drug/AntibioticGrowthPromotant
#
# antibiotic_growth_promotant
# Query: antibiotic growth promotant
# lookup term: antibiotic_growth_promotant
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/drug/AntibioticGrowthPromotant
#
# vancomycin
# Query: vancomycin
# lookup term: vancomycin
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042313
#
# Query: olanzapine
# lookup term: olanzapine
#   • olanzapine                               URI=http://purl.obolibrary.org/obo/CHEBI_7735
# Query: olanzapine
# lookup term: olanzapine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_7735
#
#
# Query: olanzapine
# lookup term: olanzapine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_7735
#
#
# Query: olanzapine
# lookup term: olanzapine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_7735
#
#
# placebo_oral_tablet
# Query: placebo oral tablet
# lookup term: placebo_oral_tablet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1249327
#
# placebo_oral_tablet
# Query: placebo oral tablet
# lookup term: placebo_oral_tablet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1249327
#
# placebo_oral_tablet
# Query: placebo oral tablet
# lookup term: placebo_oral_tablet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1249327
#
# placebo_oral_tablet
# Query: placebo oral tablet
# lookup term: placebo_oral_tablet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1249327
#
# Query: olanzapine
# lookup term: olanzapine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_7735
#
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
#
# Query: antidepressant
# lookup term: antidepressant
#   • antidepressant                           URI=http://purl.obolibrary.org/obo/CHEBI_35469
# Query: escitalopram
# lookup term: escitalopram
#   • escitalopram                             URI=http://purl.obolibrary.org/obo/CHEBI_36791
# Query: escitalopram
# lookup term: escitalopram
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_36791
#
#
# Query: ct-26
# lookup term: ct-26
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/drug/Ct26
#
#
# Query: oxaliplatin
# lookup term: oxaliplatin
#   • oxaliplatin                              URI=http://purl.obolibrary.org/obo/CHEBI_31941
# Query: rhepo
# lookup term: rhepo
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/chemical/Rhepo
#
#
# Query: cuprizone
# lookup term: cuprizone
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0010460
#
#
# cuprizone
# Query: cuprizone
# lookup term: cuprizone
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0010460
#
# cuprizone
# Query: cuprizone
# lookup term: cuprizone
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0010460
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: csf1r inhibitor
# lookup term: csf1r_inhibitor
#   • inhibitor                                URI=http://purl.obolibrary.org/obo/CHEBI_35222 score=1.00
#
# Query: antidepressant
# lookup term: antidepressant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35469
#
#
# Query: antidepressant medication
# lookup term: antidepressant_medication
#   • antidepressant                           URI=http://purl.obolibrary.org/obo/CHEBI_35469 score=1.00
#
# Query: antidepressant
# lookup term: antidepressant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35469
#
#
# Query: antidepressant
# lookup term: antidepressant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35469
#
#
# Query: antidepressant
# lookup term: antidepressant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35469
#
#
# Query: antidepressant
# lookup term: antidepressant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35469
#
#
# antidepressant
# Query: antidepressant
# lookup term: antidepressant
#   • antidepressant                           URI=http://purl.obolibrary.org/obo/CHEBI_35469
# Query: antidepressant
# lookup term: antidepressant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35469
#
#
# Query: antidepressant
# lookup term: antidepressant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35469
#
#
# Query: psychotropic medication
# lookup term: psychotropic_medication
#   • psychotropic drug                        URI=http://purl.obolibrary.org/obo/CHEBI_35471 score=0.82
#
# Query: drug
# lookup term: drug
#   • drug                                     URI=http://purl.obolibrary.org/obo/CHEBI_23888
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: antidepressant
# lookup term: antidepressant
#   • antidepressant                           URI=http://purl.obolibrary.org/obo/CHEBI_35469
# anti-anxiety_agents
# Query: anti-anxiety agents
# lookup term: anti-anxiety_agents
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0040616
#
# placebo_oral_tablet
# Query: placebo oral tablet
# lookup term: placebo_oral_tablet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1249327
#
# Query: beta-hydroxy butyrate
# lookup term: beta-hydroxy_butyrate
#   • butyrate                                 URI=http://purl.obolibrary.org/obo/CHEBI_17968 score=0.84
#
# beta-hydroxy_butyrate
# Query: beta-hydroxy butyrate
# lookup term: beta-hydroxy_butyrate
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_17968
#
# Query: ar 420626
# lookup term: ar_420626
#   • AR-42                                    URI=http://purl.obolibrary.org/obo/CHEBI_188197 score=0.76
#
# beta-hydroxy_butyrate
# Query: beta-hydroxy butyrate
# lookup term: beta-hydroxy_butyrate
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_17968
#
# Query: l-3 4-dihydroxyphenylalanine  l-dopa
# lookup term: l-3_4-dihydroxyphenylalanine__l-dopa_
#   • D-dopa                                   URI=http://purl.obolibrary.org/obo/CHEBI_49169 score=1.00
#
# antibiotic
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# antibiotic
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: dexamethasone
# lookup term: dexamethasone
#   • dexamethasone                            URI=http://purl.obolibrary.org/obo/CHEBI_41879
# dexamethasone
# Query: dexamethasone
# lookup term: dexamethasone
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_41879
#
# placebo_oral_tablet
# Query: placebo oral tablet
# lookup term: placebo_oral_tablet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1249327
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# antibiotic
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# antibiotic
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: over-the-counter laxative
# lookup term: over-the-counter_laxative
#   • laxative                                 URI=http://purl.obolibrary.org/obo/CHEBI_50503 score=1.00
#
# Query: guanylate cyclase c agonist
# lookup term: guanylate_cyclase_c_agonist
#   • guanylate cyclase 2C agonist             URI=http://purl.obolibrary.org/obo/CHEBI_68553 score=0.86
#
# Query: selective 5-hyroxytryptamine 4 receptor agonist
# lookup term: selective_5-hyroxytryptamine_4_receptor_agonist
#   • prostaglandin receptor agonist           URI=http://purl.obolibrary.org/obo/CHEBI_66900 score=0.83
#
# Query: dreadd ligand
# lookup term: dreadd_ligand
#   • ligand                                   URI=http://purl.obolibrary.org/obo/CHEBI_52214 score=1.00
#
# Query: dreadd ligand
# lookup term: dreadd_ligand
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_52214
#
#
# Query: dreadd ligand
# lookup term: dreadd_ligand
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_52214
#
#
# Query: baicalin
# lookup term: baicalin
#   • baicalin                                 URI=http://purl.obolibrary.org/obo/CHEBI_2981
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# agent
# Query: agent
# lookup term: agent
#   • pro-agent                                URI=http://purl.obolibrary.org/obo/CHEBI_136859 score=0.81
#
# Query: fda-approved drug
# lookup term: fda-approved_drug
#   • drug                                     URI=http://purl.obolibrary.org/obo/CHEBI_23888 score=1.00
#
# Query: gv-971
# lookup term: gv-971
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5435122
#
#
# Query: sodium oligomannate
# lookup term: sodium_oligomannate
#   • sodium(1+)                               URI=http://purl.obolibrary.org/obo/CHEBI_29101 score=1.00
#
# placebo_oral_tablet
# Query: placebo oral tablet
# lookup term: placebo_oral_tablet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1249327
#
# Query: drug
# lookup term: drug
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_23888
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: antidepressant
# lookup term: antidepressant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35469
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: antiepileptic drug
# lookup term: antiepileptic_drug
#   • drug                                     URI=http://purl.obolibrary.org/obo/CHEBI_23888 score=1.00
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: r -ketamine
# lookup term: _r_-ketamine
#   • (R)-ketamine                             URI=http://purl.obolibrary.org/obo/CHEBI_580604 score=1.00
#
# Query: r -ketamine
# lookup term: _r_-ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_580604
#
#
# esketamine
# Query: esketamine
# lookup term: esketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2825616
#
# enantiomer
# Query: enantiomer
# lookup term: enantiomer
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0599473
#
# enantiomer
# Query: enantiomer
# lookup term: enantiomer
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0599473
#
# enantiomer
# Query: enantiomer
# lookup term: enantiomer
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0599473
#
# enantiomer
# Query: enantiomer
# lookup term: enantiomer
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0599473
#
# Query: r -ketamine
# lookup term: _r_-ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_580604
#
#
# esketamine
# Query: esketamine
# lookup term: esketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2825616
#
# enantiomer
# Query: enantiomer
# lookup term: enantiomer
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0599473
#
# Query: r -ketamine
# lookup term: _r_-ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_580604
#
#
# esketamine
# Query: esketamine
# lookup term: esketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2825616
#
# Query: ketamine
# lookup term: ketamine
#   • ketamine                                 URI=http://purl.obolibrary.org/obo/CHEBI_6121
# Query: r -ketamine
# lookup term: _r_-ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_580604
#
#
# Query: antidepressant
# lookup term: antidepressant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35469
#
#
# Query: antidepressant
# lookup term: antidepressant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35469
#
#
# Query: levodopa
# lookup term: levodopa
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0023570
#
#
# Query: anti-infective medication
# lookup term: anti-infective_medication
# no match
# placebo_oral_tablet
# Query: placebo oral tablet
# lookup term: placebo_oral_tablet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1249327
#
# Query: pharmacological intervention
# lookup term: pharmacological_intervention
#   • pharmacological role                     URI=http://purl.obolibrary.org/obo/CHEBI_52210 score=0.76
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# citalopram
# Query: citalopram
# lookup term: citalopram
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0008845
#
# citalopram
# Query: citalopram
# lookup term: citalopram
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0008845
#
# citalopram
# Query: citalopram
# lookup term: citalopram
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0008845
#
# Query: psychiatric drug
# lookup term: psychiatric_drug
#   • drug                                     URI=http://purl.obolibrary.org/obo/CHEBI_23888 score=1.00
#
# Query: psychotropic medication
# lookup term: psychotropic_medication
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35471
#
#
# Query: psychotropic medication
# lookup term: psychotropic_medication
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35471
#
#
# levodopa
# Query: levodopa
# lookup term: levodopa
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0023570
#
# Query: levodopa
# lookup term: levodopa
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0023570
#
#
# Query: levodopa
# lookup term: levodopa
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0023570
#
#
# levodopa
# Query: levodopa
# lookup term: levodopa
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0023570
#
# Query: levodopa
# lookup term: levodopa
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0023570
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: r s -ketamine
# lookup term: _r_s_-ketamine
#   • (R)-ketamine                             URI=http://purl.obolibrary.org/obo/CHEBI_580604 score=1.00
#
# Query: r s -ketamine
# lookup term: _r_s_-ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_580604
#
#
# Query: r -ketamine
# lookup term: _r_-ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_580604
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# esketamine
# Query: esketamine
# lookup term: esketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2825616
#
# Query: esketamine
# lookup term: esketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2825616
#
#
# Query: esketamine
# lookup term: esketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2825616
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: esketamine
# lookup term: esketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2825616
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: r s -ketamine
# lookup term: _r_s_-ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_580604
#
#
# Query: r s -ketamine
# lookup term: _r_s_-ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_580604
#
#
# Query: r s -ketamine
# lookup term: _r_s_-ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_580604
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# antibiotic
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# placebo_oral_tablet
# Query: placebo oral tablet
# lookup term: placebo_oral_tablet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1249327
#
# placebo_oral_tablet
# Query: placebo oral tablet
# lookup term: placebo_oral_tablet
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1249327
#
# medicine
# Query: medicine
# lookup term: medicine
# no match
# adrenergic_beta-antagonists
# Query: adrenergic beta-antagonists
# lookup term: adrenergic_beta-antagonists
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0001645
#
# antidepressant
# Query: antidepressant
# lookup term: antidepressant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35469
#
# Query: diabetes medication
# lookup term: diabetes_medication
# no match
# Query: proton pump inhibitor
# lookup term: proton_pump_inhibitor
#   • proton                                   URI=http://purl.obolibrary.org/obo/CHEBI_24636 score=0.88
#
# antibiotic
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: abx
# lookup term: abx
#   • (-)-ABX-K                                URI=http://purl.obolibrary.org/obo/CHEBI_221253 score=1.00
#
# pharmacologic_substance
# Query: pharmacologic substance
# lookup term: pharmacologic_substance
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1254351
#
# Query: psychiatric drug
# lookup term: psychiatric_drug
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_23888
#
#
# Query: oxytocin administration
# lookup term: oxytocin_administration
#   • oxytocin                                 URI=http://purl.obolibrary.org/obo/CHEBI_7872 score=1.00
#
# Query: oxytocin
# lookup term: oxytocin
#   • oxytocin                                 URI=http://purl.obolibrary.org/obo/CHEBI_7872
# Query: citalopram
# lookup term: citalopram
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0008845
#
#
# Query: psychiatric drug
# lookup term: psychiatric_drug
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_23888
#
#
# Query: ketamine
# lookup term: ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_6121
#
#
# Query: ketamine
# lookup term: ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_6121
#
#
# Query: ketamine
# lookup term: ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_6121
#
#
# Query: ketamine
# lookup term: ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_6121
#
#
# Query: ketamine
# lookup term: ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_6121
#
#
# Query: ketamine
# lookup term: ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_6121
#
#
# Query: ketamine
# lookup term: ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_6121
#
#
# Query: ketamine
# lookup term: ketamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_6121
#
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: psychotropic
# lookup term: psychotropic
#   • psychotropic drug                        URI=http://purl.obolibrary.org/obo/CHEBI_35471 score=0.82
#
# Query: psychotropic medication
# lookup term: psychotropic_medication
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35471
#
# Query: antidepressant
# lookup term: antidepressant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35469
#
#
# antibiotic
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# antibiotic
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: ampicillin
# lookup term: ampicillin
#   • ampicillin                               URI=http://purl.obolibrary.org/obo/CHEBI_28971
# Query: bacitracin
# lookup term: bacitracin
#   • bacitracin                               URI=http://purl.obolibrary.org/obo/CHEBI_28669
# Query: meropenem
# lookup term: meropenem
#   • meropenem                                URI=http://purl.obolibrary.org/obo/CHEBI_43968
# Query: neomycin
# lookup term: neomycin
#   • neomycin                                 URI=http://purl.obolibrary.org/obo/CHEBI_7507
# Query: vancomycin
# lookup term: vancomycin
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042313
#
#
# Query: ampicillin
# lookup term: ampicillin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28971
#
#
# Query: broad range antibiotic
# lookup term: broad_range_antibiotic
#   • piperidine antibiotic                    URI=http://purl.obolibrary.org/obo/CHEBI_49318 score=0.79
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: ampicillin
# lookup term: ampicillin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_28971
#
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: psychotropic medication
# lookup term: psychotropic_medication
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35471
#
# antibiotic
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# antibiotic
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: colony stimulating factor 1 receptor inhibitor plx5622
# lookup term: colony_stimulating_factor_1_receptor_inhibitor_plx5622
# no match
# Query: plx5622
# lookup term: plx5622
#   • PLX5622                                  URI=http://purl.obolibrary.org/obo/CHEBI_230497
# Query: plx5622
# lookup term: plx5622
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_230497
#
#
# Query: plx5622
# lookup term: plx5622
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_230497
#
#
# Query: plx5622
# lookup term: plx5622
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_230497
#
#
# Query: plx5622
# lookup term: plx5622
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_230497
#
#
# Query: plx5622
# lookup term: plx5622
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_230497
#
#
# Query: plx5622
# lookup term: plx5622
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_230497
#
#
# Query: csf1r inhibitor
# lookup term: csf1r_inhibitor
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35222
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: ssris treatment
# lookup term: ssris_treatment
# no match
# Query: antidepressant treatment
# lookup term: antidepressant_treatment
# no match
# Query: escitalopram
# lookup term: escitalopram
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_36791
#
#
# Query: escitalopram treatment
# lookup term: escitalopram_treatment
# no match
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: neuropsychiatric drug
# lookup term: neuropsychiatric_drug
#   • drug                                     URI=http://purl.obolibrary.org/obo/CHEBI_23888 score=1.00
#
# Query: antibiotic
# lookup term: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C258
#
# Query: antidepressant
# lookup term: antidepressant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_35469
#
#
# Query: anti-inflammatory agent
# lookup term: anti-inflammatory_agent
#   • anti-inflammatory agent                  URI=http://purl.obolibrary.org/obo/CHEBI_67079
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: arketamine
# lookup term: arketamine
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940914
#
#
# Query: minocycline
# lookup term: minocycline
#   • minocycline                              URI=http://purl.obolibrary.org/obo/CHEBI_50694
# Query: minocycline
# lookup term: minocycline
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_50694
#
#
# Query: minocycline
# lookup term: minocycline
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_50694
#
#
# Query: minocycline s antibiotic
# lookup term: minocycline_s_antibiotic
#   • minocycline(1-)                          URI=http://purl.obolibrary.org/obo/CHEBI_71337 score=0.79
#
# Query: minocycline
# lookup term: minocycline
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_50694
#
#
# Query: minocycline
# lookup term: minocycline
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_50694
#
#
# Query: minocycline
# lookup term: minocycline
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_50694
#
#
# Query: minocycline
# lookup term: minocycline
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_50694
#
#
# Query: minocycline
# lookup term: minocycline
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_50694
#
#
# Query: minocycline
# lookup term: minocycline
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_50694
#
#
# Query: monoaminergic antidepressant
# lookup term: monoaminergic_antidepressant
#   • antidepressant                           URI=http://purl.obolibrary.org/obo/CHEBI_35469 score=1.00
#
# Query: benzodiazepine
# lookup term: benzodiazepine
#   • benzodiazepine                           URI=http://purl.obolibrary.org/obo/CHEBI_22720
# Query: cbt
# lookup term: cbt
# no match
# Query: bactericidal antibiotic
# lookup term: bactericidal_antibiotic
#   • piperidine antibiotic                    URI=http://purl.obolibrary.org/obo/CHEBI_49318 score=0.79
#
# Query: vaccine
# lookup term: vaccine
# no match

# %% [markdown]
# <h1>INGEST MICROBIOME</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint
from rdflib.namespace import DCTERMS
from groqutils import get_llm_definition
from funcutils import get_ncit_description, get_chebi_description, get_omit_description, NCBI_BASE, HEREDITARY_BASE, UMLS_BASES, foodon_file, ncit_file, omit_file, chebi_file, hash_term_sha256

MICROBIOME_BASE = "http://purl.obolibrary.org/obo/"
MICROBIOME_CLASS = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Microbiome")
MICROBIOME_CONCEPT_SCHEME = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Microbiome")

def load_ohmi_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*\[([A-Za-z0-9_]+)\]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = MICROBIOME_BASE + term_id
            rows.append((label, uri))
    return rows

OHMI_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\OHMI_full_taxonomy.txt"
ohmi_rows = load_ohmi_labels(OHMI_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in ohmi_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in ohmi_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

def top_cosine(term, k=5, thr=0.75):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = ohmi_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

def preprocess(term):
    term = term.replace('_', ' ')
    term = term.strip()
    return term.lower()

manual_created = {}
created = {}

manual_created = {
    "poultry_gut_microbiome": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/PoultryGutMicrobiome"),
    "intestinal_microbiome" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome"),
    "gut_microbial_ecosystem" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/GutMicrobialEcosystem"),
    "gut_metagenome" : URIRef("http://purl.obolibrary.org/obo/NCBITaxon_749906"),
    "feces_metagenome" : URIRef("http://purl.obolibrary.org/obo/NCBITaxon_1861841"),
    "microbial_community" : URIRef("http://purl.obolibrary.org/obo/PCO_1000004"),
    "intestinal_flora" : URIRef("http://purl.obolibrary.org/obo/NCIT_C93019"),
    "microorganism" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0445623"),
    "gut_microbial": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/GutMicrobial"),
    "pharmacomicrobiomics" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/Pharmacomicrobiomics"),
    "colon_microbiota": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C3510360"),
    "interventions_regulating_intestinal_flora" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/InterventionsRegulatingIntestinalFlora"),
    "pathobiont": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/Pathobiont"),
    "brain_microbiota": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/BrainMicrobiota"),
    "iga-biome": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IgaBiome"),
    "dormant_blood_microbiome": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/DormantBloodMicrobiome"),
}

created = dict(manual_created)

regex_map = [

    (r"chicken_gut_microbiome", "poultry_gut_microbiome"),
    (r"\bblood_microbiome","dormant_blood_microbiome"),
    (r"fecal_microbiota","microbiota"),
    (r"human_intestinal_microbiota","intestinal_microbiome"),
    (r"gut_microbial_composition","intestinal_microbiome"),
    (r"gut_microbiota_composition","intestinal_microbiome"),
    (r"inflammation-associated_gut_microbiota","intestinal_microbiome"),
    (r"control_diet_microbiota","microbiota"),
    (r"gastrointestinal__gi__microbiota","microbiota"),
    (r"\bgut\b","intestinal_microbiome"),
    (r"intestine_microbiota","intestinal_flora"),
    (r"\bmam\b","microbiota"),
    (r"\bbrainbiota\b","brain_microbiota"),
    (r"specific_mam_associated_to_underlying_pathology","microbiota"),
    (r"gut_microbiota_community","microbial_community"),
    (r"fecal_microbiome","feces_metagenome"),
    (r"intestinal_microbiota","intestinal_microbiome"),
    (r"gut_microbial_community","microbial_community"),
    (r"fecal_metagenome","feces_metagenome"),
    (r"canine_intestinal_microbiota","intestinal_microbiome"),
    (r"gastrointestinal_tract_microbiome","microbiome_in_human_gastrointestinal_system"),
    (r"irif","interventions_regulating_intestinal_flora"),
    (r"gut_microorganism","microorganism"),
    (r"microbiome_population","microbiome"),
    (r"gut_flora","intestinal_flora"),
    (r"gm","microbiome"),
    (r"cecal_microbiota","microbiota"),
    (r"intestinal_microbe","microbiome"),
    (r"inflammatory_microbes_and_gene","microbiota"),
    (r"pro-inflammatory_bacteria__genes_and_pathway","microbiome"),
    (r"anti-inflammatory_bacteria__genes_and_pathway","microbiome"),
    (r"positive_mood-related_gut_microbiota","microbiota"),
    (r"small_bowel_microbiome","microbiome"),
    (r"small_intestinal_microbiome", "intestinal_microbiome")
]
CREATOR = "Samuel Piron"

UMLS_BASES = "https://uts.nlm.nih.gov/uts/umls/concept/"
#MESH_BASE = "https://meshb.nlm.nih.gov/record/ui?ui="

for uri in manual_created.values():
    uri_str = str(uri)

    if uri_str.startswith(UMLS_BASES):
        # only a UMLS‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("UMLS Match", datatype=XSD.string)))
    elif "NCIT" in uri_str:
        # only a NCIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("NCIT Match", datatype=XSD.string)))
    elif "OMIT" in uri_str:
        # only a OMIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("OMIT Match", datatype=XSD.string)))
    elif "NCBITaxon" in uri_str:
        # only a NCBITaxon‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("NCBITaxon Match", datatype=XSD.string)))
    elif "CHEBI" in uri_str:
        # only a CHEBI‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("CHEBI Match", datatype=XSD.string)))
    elif "FOODON" in uri_str:
        # only a FOODON‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("FOODON Match", datatype=XSD.string)))
    elif "mesh" in uri_str:
        # only a MESH‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("MESH Match", datatype=XSD.string)))
    elif "PCO" in uri_str:
        # only a XCO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("PCO Match", datatype=XSD.string)))
    else:
        # everything else still gets a creator
        g.add((uri,
               DCTERMS.creator,
               Literal(CREATOR, datatype=XSD.string)))
        
for term_raw, uri in manual_created.items():
    uri_str = str(uri)

    # NCIT definitions
    if uri_str.startswith(NCBI_BASE) and "NCIT_" in uri_str:
        ncit_id = uri_str.rsplit("_", 1)[-1]
        desc = get_ncit_description(ncit_id, ncit_file)
        m = re.search(r'—\s*(.*?)\s*—', desc)
        if m:
            desc = m.group(1).strip()
            comment = f"{desc} [Definition Source: NCIT]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # UMLS definitions
    elif uri_str.startswith(UMLS_BASES):
        cui = uri_str.rsplit("/", 1)[-1]
        defn = get_umls_definition(cui)
        if defn:
            comment = f"{defn.strip()} [Definition Source: UMLS]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # MeSH definitions via your mesh_index
    elif uri_str.startswith(MESH_BASE):
        ui     = uri_str.rsplit("/",1)[-1]
        hits   = [d['name'] for d in mesh_descs if d['ui']==ui]
        if hits:
            comment = f"{hits[0]} [Definition Source: MeSH]"
        elif term_raw == "patients":
            comment = "Patients with various diseases. [Definition Source: GUTBRAIN]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    elif uri_str.startswith(HEREDITARY_BASE):
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"
    else:
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    g.add((uri,
           RDFS.comment,
           Literal(comment, datatype=XSD.string)))
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "microbiome":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, MICROBIOME_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, MICROBIOME_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, MICROBIOME_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, MICROBIOME_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, MICROBIOME_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, MICROBIOME_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    elif "ohmi" in uri_str:
                        comment = "OHMI Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, MICROBIOME_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, MICROBIOME_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    elif "ohmi" in uri_str:
                        comment = "OHMI Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

print("entering gold")

for paper_id, paper_data in data_gold.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "microbiome":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, MICROBIOME_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, MICROBIOME_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, MICROBIOME_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, MICROBIOME_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, MICROBIOME_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, MICROBIOME_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    elif "ohmi" in uri_str:
                        comment = "OHMI Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, MICROBIOME_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, MICROBIOME_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    elif "ohmi" in uri_str:
                        comment = "OHMI Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

print("entering dev")

for paper_id, paper_data in data_dev.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "microbiome":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, MICROBIOME_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, MICROBIOME_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, MICROBIOME_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, MICROBIOME_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, MICROBIOME_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, MICROBIOME_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    elif "ohmi" in uri_str:
                        comment = "OHMI Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, MICROBIOME_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, MICROBIOME_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    elif "ohmi" in uri_str:
                        comment = "OHMI Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

created["bacteria"] = URIRef("http://purl.obolibrary.org/obo/NCBITaxon_2")
g.remove((created["bacteria"], RDF.type, MICROBIOME_CLASS))
g.remove((created["bacteria"], SKOS.inScheme, MICROBIOME_CONCEPT_SCHEME))

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "microbiome":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_gold_file, "r", encoding="utf-8") as f_sent:
    tokenized_gold_data = json.load(f_sent)

for entry in tokenized_gold_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "microbiome":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_dev, "r", encoding="utf-8") as f_sent:
    tokenized_dev_data = json.load(f_sent)

for entry in tokenized_dev_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "microbiome":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))
# Out:
# Query: gut microbiota
# lookup term: gut_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# poultry_gut_microbiome
# Query: poultry gut microbiome
# lookup term: poultry_gut_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/PoultryGutMicrobiome
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   • human gut microbiome                     URI=http://purl.obolibrary.org/obo/OHMI_0000020 score=0.91
#
# Query: poultry gut microbiome
# lookup term: poultry_gut_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/PoultryGutMicrobiome
#
#
# poultry_gut_microbiome
# Query: poultry gut microbiome
# lookup term: poultry_gut_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/PoultryGutMicrobiome
#
# Query: oral and gut microbiota
# lookup term: oral_and_gut_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.82
#
# Query: gut and oral microbiota
# lookup term: gut_and_oral_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.82
#
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
#
# Query: oral and gut microbiota
# lookup term: oral_and_gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: oral and gut microbiota
# lookup term: oral_and_gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: host microbiome
# lookup term: host_microbiome
#   • host-microbiome interaction              URI=http://purl.obolibrary.org/obo/OHMI_0000001 score=0.85
#
# Query: microbiota
# lookup term: microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: host microbiota
# lookup term: host_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.77
#
# Query: host microbiota
# lookup term: host_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: individual s gut microbiota
# lookup term: individual_s_gut_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: individual s specific gut microbiota
# lookup term: individual_s_specific_gut_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbial ecosystem
# lookup term: gut_microbial_ecosystem
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/GutMicrobialEcosystem
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: maternal prenatal gut microbiota
# lookup term: maternal_prenatal_gut_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: maternal gut microbiota
# lookup term: maternal_gut_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: prenatal faecal microbiota
# lookup term: prenatal_faecal_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: faecal microbiota
# lookup term: faecal_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: maternal faecal microbiota
# lookup term: maternal_faecal_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: maternal faecal microbiota
# lookup term: maternal_faecal_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: maternal prenatal gut microbiota
# lookup term: maternal_prenatal_gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: prenatal gut microbiota
# lookup term: prenatal_gut_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: human microbiota
# lookup term: human_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.96
#
# Query: probiotic-exposed microbiota
# lookup term: probiotic-exposed_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: gut microbe
# lookup term: gut_microbe
#   • microbe                                  URI=http://purl.obolibrary.org/obo/OHMI_0000460 score=0.96
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# microbiota
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# Query: gut metagenome
# lookup term: gut_metagenome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_749906
#
# feces_metagenome
# Query: feces metagenome
# lookup term: feces_metagenome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1861841
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# feces_metagenome
# Query: feces metagenome
# lookup term: feces_metagenome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1861841
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: human microbiome
# lookup term: human_microbiome
#   • human microbiome                         URI=http://purl.obolibrary.org/obo/OHMI_0000002
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: human gut microbiome
# lookup term: human_gut_microbiome
#   • human gut microbiome                     URI=http://purl.obolibrary.org/obo/OHMI_0000020
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# microbiota
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# microbial_community
# Query: microbial community
# lookup term: microbial_community
#   → Reusing existing URI: http://purl.obolibrary.org/obo/PCO_1000004
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# Query: depression gut microbiota
# lookup term: depression_gut_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: maternal vaginal microbiota
# lookup term: maternal_vaginal_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: microbiota of neonatal gut and nose
# lookup term: microbiota_of_neonatal_gut_and_nose
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: infant microbiota
# lookup term: infant_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: maternal microbiota
# lookup term: maternal_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: microbiota of infant gut and nose
# lookup term: microbiota_of_infant_gut_and_nose
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: maternal vaginal microbiota
# lookup term: maternal_vaginal_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: infant faecal microbiota
# lookup term: infant_faecal_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: maternal rectal microbiota
# lookup term: maternal_rectal_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: infant microbiota
# lookup term: infant_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: infant s nasal and gut microbiota
# lookup term: infant_s_nasal_and_gut_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: infant stool microbiota
# lookup term: infant_stool_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: maternal rectal microbiota
# lookup term: maternal_rectal_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: infant stool microbiota
# lookup term: infant_stool_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: microbiota of infant
# lookup term: microbiota_of_infant
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: infant gut microbiota
# lookup term: infant_gut_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: infant microbiota
# lookup term: infant_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: infant microbiota
# lookup term: infant_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: maternal microbiota
# lookup term: maternal_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: infant gut and nasal microbiota
# lookup term: infant_gut_and_nasal_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: colonic microbiome
# lookup term: colonic_microbiome
#   • microbiome                               URI=http://purl.obolibrary.org/obo/OHMI_0000003 score=1.00
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: altered gut microbiota
# lookup term: altered_gut_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: dysbiotic gut microbiota
# lookup term: dysbiotic_gut_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: non-commensal gut microbiome
# lookup term: non-commensal_gut_microbiome
#   • human gut microbiome                     URI=http://purl.obolibrary.org/obo/OHMI_0000020 score=0.91
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gastrointestinal microbiome
# lookup term: gastrointestinal_microbiome
#   • microbiome in human gastrointestinal system URI=http://purl.obolibrary.org/obo/OHMI_0000016 score=0.97
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: intestinal flora
# lookup term: intestinal_flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C93019
#
#
# Query: intestinal flora
# lookup term: intestinal_flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C93019
#
#
# Query: intestinal flora
# lookup term: intestinal_flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C93019
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: maternal gut microbiota
# lookup term: maternal_gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbe
# lookup term: gut_microbe
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000460
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# microbiome_in_human_gastrointestinal_system
# Query: microbiome in human gastrointestinal system
# lookup term: microbiome_in_human_gastrointestinal_system
#   • microbiome in human gastrointestinal system URI=http://purl.obolibrary.org/obo/OHMI_0000016
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: human microbiota
# lookup term: human_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: human microbiota
# lookup term: human_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# microbiota
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# microbiota
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# microbiota
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# microbiota
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# Query: intestinal flora
# lookup term: intestinal_flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C93019
#
#
# interventions_regulating_intestinal_flora
# Query: interventions regulating intestinal flora
# lookup term: interventions_regulating_intestinal_flora
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/InterventionsRegulatingIntestinalFlora
#
# interventions_regulating_intestinal_flora
# Query: interventions regulating intestinal flora
# lookup term: interventions_regulating_intestinal_flora
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/InterventionsRegulatingIntestinalFlora
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# Query: human gut microbiome
# lookup term: human_gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# microbiota
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: duodenal microbiome
# lookup term: duodenal_microbiome
#   • microbiome                               URI=http://purl.obolibrary.org/obo/OHMI_0000003 score=1.00
#
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: human gut microbiome
# lookup term: human_gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# microorganism
# Query: microorganism
# lookup term: microorganism
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0445623
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# microbiome
# Query: microbiome
# lookup term: microbiome
#   • microbiome                               URI=http://purl.obolibrary.org/obo/OHMI_0000003
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# intestinal_flora
# Query: intestinal flora
# lookup term: intestinal_flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C93019
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: intestinal flora
# lookup term: intestinal_flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C93019
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# microbiome
# Query: microbiome
# lookup term: microbiome
#   • microbiome                               URI=http://purl.obolibrary.org/obo/OHMI_0000003
# Query: intestinal flora
# lookup term: intestinal_flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C93019
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: faecal microbiota
# lookup term: faecal_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: intestinal flora
# lookup term: intestinal_flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C93019
#
#
# Query: faecal microbiota
# lookup term: faecal_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: oral and gut microbiota
# lookup term: oral_and_gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut and oral microbiota
# lookup term: gut_and_oral_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbial
# lookup term: gut_microbial
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/GutMicrobial
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: pharmacomicrobiomic
# lookup term: pharmacomicrobiomic
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/Pharmacomicrobiomics
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: host microbiota
# lookup term: host_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# microbiota
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# microbiome
# Query: microbiome
# lookup term: microbiome
#   • microbiome                               URI=http://purl.obolibrary.org/obo/OHMI_0000003
# Query: intestinal microflora
# lookup term: intestinal_microflora
#   • intestinal cancer                        URI=http://purl.obolibrary.org/obo/DOID_10155 score=0.93
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: human gut microbiota
# lookup term: human_gut_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.91
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbe
# lookup term: gut_microbe
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000460
#
#
# Query: colonic microbiota
# lookup term: colonic_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# microbiota
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# microbiome
# Query: microbiome
# lookup term: microbiome
#   • microbiome                               URI=http://purl.obolibrary.org/obo/OHMI_0000003
# microbiome
# Query: microbiome
# lookup term: microbiome
#   • microbiome                               URI=http://purl.obolibrary.org/obo/OHMI_0000003
# microbiota
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# microbiome
# Query: microbiome
# lookup term: microbiome
#   • microbiome                               URI=http://purl.obolibrary.org/obo/OHMI_0000003
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: intestinal barrier
# lookup term: intestinal_barrier
#   • intestinal cancer                        URI=http://purl.obolibrary.org/obo/DOID_10155 score=0.93
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: colon microbiota
# lookup term: colon_microbiota
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3510360
#
#
# Query: colon microbiota
# lookup term: colon_microbiota
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3510360
#
#
# Query: colon microbiota
# lookup term: colon_microbiota
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3510360
#
#
# Query: colon microbiota
# lookup term: colon_microbiota
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3510360
#
#
# microbiota
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# microbiota
# Query: microbiota
# lookup term: microbiota
# ...
#
# entering dev
# Query: brainbiota
# lookup term: brainbiota
# no matches
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: brain microbiota
# lookup term: brain_microbiota
# no matches
# Query: brainbiota
# lookup term: brainbiota
# no matches
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: brainbiota
# lookup term: brainbiota
# no matches
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: iga-biome
# lookup term: iga-biome
#   • biome                                    URI=http://purl.obolibrary.org/obo/ENVO_00000428 score=1.00
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: oral and gut microbiota
# lookup term: oral_and_gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: oral and gut microbiota
# lookup term: oral_and_gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: oral microbiota
# lookup term: oral_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.85
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# Query: oral and gut microbiota
# lookup term: oral_and_gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: oral microbiota
# lookup term: oral_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: oral microbiota
# lookup term: oral_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# Query: oral and gut microbiota
# lookup term: oral_and_gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: oral microbiota
# lookup term: oral_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: oral-gut microbiota
# lookup term: oral-gut_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.82
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut  commensal  microbiome
# lookup term: gut__commensal__microbiome
#   • human gut microbiome                     URI=http://purl.obolibrary.org/obo/OHMI_0000020 score=0.91
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# intestinal_flora
# Query: intestinal flora
# lookup term: intestinal_flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C93019
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: human gut microbiome
# lookup term: human_gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: faecal microbiota
# lookup term: faecal_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: faecal microbiota
# lookup term: faecal_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: faecal microbiota
# lookup term: faecal_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: intestinal flora
# lookup term: intestinal_flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C93019
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: intestinal flora
# lookup term: intestinal_flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C93019
#
#
# Query: human gut microbiota
# lookup term: human_gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# intestinal_microbiome
# Query: intestinal microbiome
# lookup term: intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/microbiome/IntestinalMicrobiome
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: alzheimer s patient gut microbiota
# lookup term: alzheimer_s_patient_gut_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.75
#
# Query: faecal microbiota
# lookup term: faecal_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: sd microbiota
# lookup term: sd_microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: sd microbiota
# lookup term: sd_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: microbiota
# lookup term: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: gut microbiota
# lookup term: gut_microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
#
# Query: dormant blood microbiome
# lookup term: dormant_blood_microbiome
# no matches
# Query: blood microbiome
# lookup term: blood_microbiome
# no matches
# Query: gut microbiome
# lookup term: gut_microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020

# %% [markdown]
# <h1>INGEST STATISTICAL TECHNIQUE</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint
from rdflib.namespace import DCTERMS
from groqutils import get_llm_definition
from funcutils import get_ncit_description, get_chebi_description, get_omit_description, NCBI_BASE, HEREDITARY_BASE, UMLS_BASES, foodon_file, ncit_file, omit_file, chebi_file, hash_term_sha256

STATISTICALTECHNIQUE_BASE = "http://purl.obolibrary.org/obo/"
STATISTICALTECHNIQUE_CLASS = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/StatisticalTechnique")
STATISTICALTECHNIQUE_CONCEPT_SCHEME = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/StatisticalTechnique")

def load_statistical_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = STATISTICALTECHNIQUE_BASE + term_id
            rows.append((label, uri))
    return rows

STATISTICAL_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\stato_full_taxonomy.txt"
STATO_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\subtree_C19044.txt"
stat_rows = load_statistical_labels(STATISTICAL_LABELS_FILE)
stat1_rows = load_statistical_labels(STATO_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in stat_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

exact_ix1 = defaultdict(list)
for lbl, uri in stat1_rows:
    exact_ix1[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in stat_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

labels1_only = [preprocess(lbl) for lbl, _ in stat1_rows]
vec1 = TfidfVectorizer(stop_words="english")
mat1 = vec1.fit_transform(labels1_only)

def top_cosine(term, k=5, thr=0.75):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = stat_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

def top_cosine1(term, k=5, thr=0.75):
    v   = vec1.transform([term])
    sc  = cosine_similarity(v, mat1).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = stat1_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

manual_created = {}
created = {}

manual_created = {
    "random-effects_meta-analyses" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/RandomEffectsMetaAnalyses"),
    "receiver_operating_characteristic_curve_analysis" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/ReceiverOperatingCharacteristicCurveAnalysis"),
    "chao1_index" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/Chao1Index"),
    "shannon_diversity_index" : URIRef("http://purl.obolibrary.org/obo/PCO_0000062"),
    "inverse_simpson_diversity_index" : URIRef("http://purl.obolibrary.org/obo/PCO_0000064"),
    "bray_curtis_dissimilarity" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/BrayCurtisDissimilarity"),
    "cochrane_risk_of_bias" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/CochraneRiskOfBias"),
    "mr_analysis" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/MrAnalysis"),
    "linear_discriminant_analysis": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5940528"),
    "two-stage_cluster_random_sampling" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C2348830"),
    "inverse_variance_weighted_mr_analysis": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/InverseVarianceWeightedMrAnalysis"),
    "multivariable_mr_analysis" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0026777"),
    "q_test" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0809418"),
    "sensitivity_analysis": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/SensitivityAnalysis"),
    "linear_discriminant_analysis": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5940528"),
    "logistic_regression": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0206031"),
    "multiple_regression": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0681923"),
    "mr_steiger_test": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/MrSteigerTest"),
    "mr_egger_intercept_test": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/MrEggerInterceptTest"),
    "double-blind_clinical_trial" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5548274"),
    "randomized_controlled_trial" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1096777"),
    "randomization": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0034656"),
    "repeat_analysis": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4266672"),
    "simpson_index": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/SimpsonIndex"),
    "intervention_trial": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0814861"),
    "mesh_mining_method": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/MeshMiningMethod"),
    "ranking_algorithm": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/RankingAlgorithm"),
    "predictive_analysis_method": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/PredictiveAnalysisMethod"),
    "statistical_testing_method": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/StatisticalTestingMethod"),
    "lasso" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/Lasso"),
    "linear_models": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0023732"),
    "cluster_method": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0009085"),
    "linear_regression": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0023733"),
    "weight/weight_ratio" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C2919747"),
    "jaccard_index": URIRef("http://www.ebi.ac.uk/swo/SWO_0000243"),
    "multidimensional_scaling_analysis" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0681930"),
    "effect_size_measurement": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5962230"),
    "biostatistical_methods":   URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1511167"),
    "positive_and_negative_affect_schedule" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0582655"),
    "multilevel_models_(statistics)": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C3824847"),
    "multiple_imputation_technique": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C2825511"),
    "software_tools":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0037589"),
    "intention_to_treat_analysis":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C2718028"),
    "social_network_analysis": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1171218"),
    "analysis":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0936012"),
    "regression_analysis":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0034980"),
    "analysis_of_variance": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0002780"),
}

created = dict(manual_created)
UMLS_BASE = "https://uts.nlm.nih.gov/uts/umls/concept/"


regex_map = [

    (r"rf", "random_forest"),
    (r"chao1","chao1_index"),
    (r"multiple_imputation_by_chained_equation","multiple_imputation_technique"),
    (r"jaccard","jaccard_index"),
    (r"\bprincipal_coordinates_analysi\w*\b","multidimensional_scaling_analysis"),
    (r"\bprincipal_coordinate_analysi\w*\b","multidimensional_scaling_analysis"),
    (r"\bpcoa\b","multidimensional_scaling_analysis"),
    (r"biostatistical_method","biostatistical_methods"),
    (r"\bpana\b","positive_and_negative_affect_schedule"),
    (r"\bcluster-based_analysi\w*\b","cluster_method"),
    (r"\bgeneralized_linear_regression_analysi\w*\b","regression_analysis"),
    (r"multilevel_mediation_model","multilevel_models_(statistics)"),
    (r"positive_affect_negative_affect_schedule","positive_and_negative_affect_schedule"),
    (r"weighted_unifrac","weight/weight_ratio"),
    (r"\bglmm\b","linear_models"),
    (r"glm_model","linear_models"),
    (r"\bpermanova\b","analysis_of_variance"),
    (r"\bcorrelation_and_regression_analyse\w*\b","regression_analysis"),
    (r"\bclustering_on_human_microbiome_sequencing_data\b","cluster_method"),
    (r"clustering_method","cluster_method"),
    (r"standardized_clustering_method_for_the_complex_microbiome_sequencing_data","cluster_method"),
    (r"clustering_algorithm_with_a_specific_beta_diversity_measure","cluster_method"),
    (r"\bmd\b","mean_difference"),
    (r"\bnetwork_analysi\w*\b","social_network_analysis"),
    (r"\bdecision_tree_analysi\w*\b","analysis"),
    (r"lasso_multinomial_logistic_regression_model","lasso"),
    (r"screening_glm","linear_models"),
    (r"medical_subject_headings__mesh_-based_text_mining_method","mesh_mining_method"),
    (r"text_mining_from_high-volume_biomedical_literature","mesh_mining_method"),
    (r"systematic_feature-ranking_algorithm","ranking_algorithm"),
    (r"mesh-based_text_mining_method","mesh_mining_method"),
    (r"\bintention-to-treat_analysi\b","intention_to_treat_analysis"),
    (r"\bmixed_model_for_repeated_measures_analysi\w*\b","repeat_analysis"),
    (r"\bsmd\b","standardized_mean_difference"),
    (r"computer-generated_randomisation","randomization"),
    (r"double-blinded__randomised_controlled_trial","double-blind_clinical_trial"),
    (r"random-effects_meta-analyse", "random-effects_meta-analyses"),
    (r"shannon", "shannon_diversity_index"),
    (r"inverse_simpson", "inverse_simpson_diversity_index"),
    (r"random_forests__rf_", "random_forest"),
    (r"mr_analysi", "mr_analysis"),
    (r"lefse","linear_discriminant_analysis"),
    (r"lefse_analysi", "linear_discriminant_analysis"),
    (r"random_forest_classification", "random_forest"),
    (r"two-sample_mr", "two-stage_cluster_random_sampling"),
    (r"inverse_variance_weighted__ivw___mr-egger__and_weighted_median__wm__method","inverse_variance_weighted_mr_analysis"),
    (r"multivariable_mr", "multivariate_mr_analysis"),
    (r"\bmultivariate_analysi\w*\b","multivariate_mr_analysis"),
    (r"joanna_briggs_institute__jbi__critical_appraisal_checklist","software_tools"),
    (r"large__sample-based__and_randomized_controlled_trial","randomized_controlled_trial"),
    (r"pseudo-randomised_pre-post_designed_controlled_intervention_trial","intervention_trial"),
    (r"mvmr", "multivariate_mr_analysis"),
    (r"cochran_s_q_test","q_test"),
    (r"sensitivity_analyse", "sensitivity_analysis"),
    (r"linear_discriminant_analysi","linear_discriminant_analysis"),
    (r"lda", "linear_discriminant_analysis"),
    (r"statistical_modeling_with_logistic_regression", "logistic_regression"),
    (r"random_forest_model", "random_forest"),
    (r"pearson_or_spearman_correlation_test", "pearson_correlation_test"),
    (r"\bpearson_correlation_analysi\w*\b","pearson_correlation_test"),
    (r"multiple_regression_analysi","multiple_regression"),
    (r"receiver_operating_characteristic_curve_analysi", "receiver_operating_characteristic_curve_analysis"),
]

CREATOR = "Samuel Piron"

UMLS_BASE = "https://uts.nlm.nih.gov/uts/umls/concept/"

for uri in manual_created.values():
    uri_str = str(uri)

    if uri_str.startswith(UMLS_BASE):
        # only a UMLS‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("UMLS Match", datatype=XSD.string)))
    elif "PCO" in uri_str:
        # only a STATO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("PCO Match", datatype=XSD.string)))
    else:
        # everything else still gets a creator
        g.add((uri,
               DCTERMS.creator,
               Literal(CREATOR, datatype=XSD.string)))
        
for term_raw, uri in manual_created.items():
    uri_str = str(uri)

    # NCIT definitions
    if uri_str.startswith(NCBI_BASE) and "NCIT_" in uri_str:
        ncit_id = uri_str.rsplit("_", 1)[-1]
        desc = get_ncit_description(ncit_id, ncit_file)
        m = re.search(r'—\s*(.*?)\s*—', desc)
        if m:
            desc = m.group(1).strip()
            comment = f"{desc} [Definition Source: NCIT]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # UMLS definitions
    elif uri_str.startswith(UMLS_BASES):
        cui = uri_str.rsplit("/", 1)[-1]
        defn = get_umls_definition(cui)
        if defn:
            comment = f"{defn.strip()} [Definition Source: UMLS]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # MeSH definitions via your mesh_index
    elif uri_str.startswith(MESH_BASE):
        ui     = uri_str.rsplit("/",1)[-1]
        hits   = [d['name'] for d in mesh_descs if d['ui']==ui]
        if hits:
            comment = f"{hits[0]} [Definition Source: MeSH]"
        elif term_raw == "patients":
            comment = "Patients with various diseases. [Definition Source: GUTBRAIN]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    elif uri_str.startswith(HEREDITARY_BASE):
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"
    else:
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    g.add((uri,
           RDFS.comment,
           Literal(comment, datatype=XSD.string)))
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "statistical technique":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                        RDFS.label,
                        Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                        RDFS.label,
                        Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine1(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "iao_" in uri_str:
                        comment = "IAO Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if re.match(r"(?i)pearson['’]s correlation coefficient", lbl.strip()):
                        label_str = "Pearsons Correlation Coefficient"
                    else:
                        label_str = lbl.title()

                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(label_str, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "iao_" in uri_str:
                        comment = "IAO Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if re.match(r"(?i)pearson['’]s correlation coefficient", lbl.strip()):
                        label_str = "Pearsons Correlation Coefficient"
                    else:
                        label_str = lbl.title()

                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(label_str, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "iao_" in uri_str:
                        comment = "IAO Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

print("entering gold")

for paper_id, paper_data in data_gold.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "statistical technique":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                        RDFS.label,
                        Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                        RDFS.label,
                        Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine1(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "iao_" in uri_str:
                        comment = "IAO Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if re.match(r"(?i)pearson['’]s correlation coefficient", lbl.strip()):
                        label_str = "Pearsons Correlation Coefficient"
                    else:
                        label_str = lbl.title()

                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(label_str, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "iao_" in uri_str:
                        comment = "IAO Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if re.match(r"(?i)pearson['’]s correlation coefficient", lbl.strip()):
                        label_str = "Pearsons Correlation Coefficient"
                    else:
                        label_str = lbl.title()

                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(label_str, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "iao_" in uri_str:
                        comment = "IAO Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

print("entering dev")

for paper_id, paper_data in data_dev.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "statistical technique":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                        RDFS.label,
                        Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                        RDFS.label,
                        Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine1(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "iao_" in uri_str:
                        comment = "IAO Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if re.match(r"(?i)pearson['’]s correlation coefficient", lbl.strip()):
                        label_str = "Pearsons Correlation Coefficient"
                    else:
                        label_str = lbl.title()

                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(label_str, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "iao_" in uri_str:
                        comment = "IAO Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if re.match(r"(?i)pearson['’]s correlation coefficient", lbl.strip()):
                        label_str = "Pearsons Correlation Coefficient"
                    else:
                        label_str = lbl.title()

                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(label_str, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "iao_" in uri_str:
                        comment = "IAO Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "statistical technique":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_gold_file, "r", encoding="utf-8") as f_sent:
    tokenized_gold_data = json.load(f_sent)

for entry in tokenized_gold_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "statistical technique":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_dev, "r", encoding="utf-8") as f_sent:
    tokenized_dev_data = json.load(f_sent)

for entry in tokenized_dev_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "statistical technique":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

output_file = os.path.join(save_path, "gutbrain_entities.ttl")
ttl_output = g.serialize(format="turtle")
with open(output_file, "w", encoding="utf-8") as f_out:
    f_out.write(ttl_output)

print(f"The RDF graph has been saved in {output_file}")
# Out:
# random-effects_meta-analyses
# Query: random-effects meta-analyses
# lookup term: random-effects_meta-analyses
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/RandomEffectsMetaAnalyses
#
#
# Query: wald test
# lookup term: wald_test
#   • Wald test                                URI=http://purl.obolibrary.org/obo/STATO_0000559
# receiver_operating_characteristic_curve_analysis
# Query: receiver operating characteristic curve analysis
# lookup term: receiver_operating_characteristic_curve_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/ReceiverOperatingCharacteristicCurveAnalysis
#
#
# Query: random forest
# lookup term: random_forest
#   • random forest procedure                  URI=http://purl.obolibrary.org/obo/STATO_0000549 score=0.82
#
# random_forest
# Query: random forest
# lookup term: random_forest
#   • random forest procedure                  URI=http://purl.obolibrary.org/obo/STATO_0000549 score=0.82
#
# Query: boruta algorithm
# lookup term: boruta_algorithm
#   • algorithm                                URI=http://purl.obolibrary.org/obo/IAO_0000064 score=1.00
#
# random_forest
# Query: random forest
# lookup term: random_forest
#   → Reusing existing URI: http://purl.obolibrary.org/obo/STATO_0000549
#
#
# chao1_index
# Query: chao1 index
# lookup term: chao1_index
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/Chao1Index
#
#
# shannon_diversity_index
# Query: shannon diversity index
# lookup term: shannon_diversity_index
#   → Reusing existing URI: http://purl.obolibrary.org/obo/PCO_0000062
#
# inverse_simpson_diversity_index
# Query: inverse simpson diversity index
# lookup term: inverse_simpson_diversity_index
#   → Reusing existing URI: http://purl.obolibrary.org/obo/PCO_0000064
#
# Query: bray curtis dissimilarity
# lookup term: bray_curtis_dissimilarity
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/BrayCurtisDissimilarity
#
# Query: two sided mann whitney test
# lookup term: two_sided_mann_whitney_test
#   • Mann-Whitney U-test                      URI=http://purl.obolibrary.org/obo/STATO_0000076 score=0.85
#
# Query: cochrane risk of bia
# lookup term: cochrane_risk_of_bia
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/CochraneRiskOfBias
#
#
# random_forest
# Query: random forest
# lookup term: random_forest
#   • random forest procedure                  URI=http://purl.obolibrary.org/obo/STATO_0000549 score=0.82
#
# Query: boruta algorithm
# lookup term: boruta_algorithm
#   → Reusing existing URI: http://purl.obolibrary.org/obo/IAO_0000064
#
#
# mr_analysis
# Query: mr analysis
# lookup term: mr_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/MrAnalysis
#
#
# mr_analysis
# Query: mr analysis
# lookup term: mr_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/MrAnalysis
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# random_forest
# Query: random forest
# lookup term: random_forest
#   • random forest procedure                  URI=http://purl.obolibrary.org/obo/STATO_0000549 score=0.82
#
# Query: false discovery rate  fdr
# lookup term: false_discovery_rate__fdr_
#   • false discovery rate correction method   URI=http://purl.obolibrary.org/obo/OBI_0200163 score=0.78
#
# Query: mendelian randomization  mr  analyse
# lookup term: mendelian_randomization__mr__analyse
#   • group randomization                      URI=http://purl.obolibrary.org/obo/OBI_0302900 score=0.77
#
# two-stage_cluster_random_sampling
# Query: two-stage cluster random sampling
# lookup term: two-stage_cluster_random_sampling
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2348830
#
# inverse_variance_weighted_mr_analysis
# Query: inverse variance weighted mr analysis
# lookup term: inverse_variance_weighted_mr_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/InverseVarianceWeightedMrAnalysis
#
# multivariate_mr_analysis
# Query: multivariate mr analysis
# lookup term: multivariate_mr_analysis
#   • multivariate analysis of variance        URI=http://purl.obolibrary.org/obo/STATO_0000454 score=0.82
#
# multivariate_mr_analysis
# Query: multivariate mr analysis
# lookup term: multivariate_mr_analysis
#   • multivariate analysis of variance        URI=http://purl.obolibrary.org/obo/STATO_0000454 score=0.82
#
# q_test
# Query: q test
# lookup term: q_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0809418
#
# Query: mr egger intercept test
# lookup term: mr_egger_intercept_test
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/MrEggerInterceptTest
#
#
# Query: mr steiger test
# lookup term: mr_steiger_test
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/MrSteigerTest
#
#
# sensitivity_analysis
# Query: sensitivity analysis
# lookup term: sensitivity_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/SensitivityAnalysis
#
# mr_analysis
# Query: mr analysis
# lookup term: mr_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/MrAnalysis
#
# Query: independent sample t test
# lookup term: independent_sample_t_test
#   • One Sample t-Test                        URI=http://purl.obolibrary.org/obo/NCIT_C53240 score=1.00
#
# Query: mann-whitney u test
# lookup term: mann-whitney_u_test
#   • Mann-Whitney U-test                      URI=http://purl.obolibrary.org/obo/STATO_0000076 score=1.00
#
# pearson_correlation_test
# Query: pearson correlation test
# lookup term: pearson_correlation_test
#   • Pearson's correlation coefficient        URI=http://purl.obolibrary.org/obo/STATO_0000280 score=0.78
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# logistic_regression
# Query: logistic regression
# lookup term: logistic_regression
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0206031
#
# Query: correlation analysi
# lookup term: correlation_analysi
#   • Correlation Test                         URI=http://purl.obolibrary.org/obo/NCIT_C53236 score=0.78
#
# pearson_correlation_test
# Query: pearson correlation test
# lookup term: pearson_correlation_test
#   • Pearson's correlation coefficient        URI=http://purl.obolibrary.org/obo/STATO_0000280 score=0.78
#
# Query: pearson s correlation analysi
# lookup term: pearson_s_correlation_analysi
#   • Pearson's correlation coefficient        URI=http://purl.obolibrary.org/obo/STATO_0000280 score=0.85
#
# Query: pearson s correlation analysi
# lookup term: pearson_s_correlation_analysi
#   → Reusing existing URI: http://purl.obolibrary.org/obo/STATO_0000280
#
#
# random_forest
# Query: random forest
# lookup term: random_forest
#   • random forest procedure                  URI=http://purl.obolibrary.org/obo/STATO_0000549 score=0.82
#
# multiple_regression
# Query: multiple regression
# lookup term: multiple_regression
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0681923
#
# double-blind_clinical_trial
# Query: double-blind clinical trial
# lookup term: double-blind_clinical_trial
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5548274
#
# multivariate_mr_analysis
# Query: multivariate mr analysis
# lookup term: multivariate_mr_analysis
#   • multivariate analysis of variance        URI=http://purl.obolibrary.org/obo/STATO_0000454 score=0.82
#
# Query: repeated measures analysis of variance  anova
# lookup term: repeated_measures_analysis_of_variance__anova_
#   • Analysis of Variance                     URI=http://purl.obolibrary.org/obo/NCIT_C53241 score=1.00
#
# Query: meta-analysi
# lookup term: meta-analysi
#   • meta analysis                            URI=http://purl.obolibrary.org/obo/STATO_0000155 score=0.81
#
# Query: population  intervention  control  and outcome  pico  approach
# lookup term: population__intervention__control__and_outcome__pico__approach
#   • Population Analysis                      URI=http://purl.obolibrary.org/obo/NCIT_C18949 score=0.78
#
# software_tools
# Query: software tools
# lookup term: software_tools
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0037589
#
# Query: random model
# lookup term: random_model
#   • random effect model                      URI=http://purl.obolibrary.org/obo/STATO_0000099 score=0.80
#
# Query: meta-analysi
# lookup term: meta-analysi
#   → Reusing existing URI: http://purl.obolibrary.org/obo/STATO_0000155
#
#
# sensitivity_analysis
# Query: sensitivity analysis
# lookup term: sensitivity_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/SensitivityAnalysis
#
# randomized_controlled_trial
# Query: randomized controlled trial
# lookup term: randomized_controlled_trial
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1096777
#
# Query: meta-analysi
# lookup term: meta-analysi
#   → Reusing existing URI: http://purl.obolibrary.org/obo/STATO_0000155
#
#
# Query: meta-analysi
# lookup term: meta-analysi
#   → Reusing existing URI: http://purl.obolibrary.org/obo/STATO_0000155
#
#
# Query: standard deviation
# lookup term: standard_deviation
#   • standard deviation                       URI=http://purl.obolibrary.org/obo/STATO_0000237
# Query: standardized mean difference
# lookup term: standardized_mean_difference
#   • standardized mean difference             URI=http://purl.obolibrary.org/obo/STATO_0000100
# standardized_mean_difference
# Query: standardized mean difference
# lookup term: standardized_mean_difference
#   → Reusing existing URI: http://purl.obolibrary.org/obo/STATO_0000100
#
# Query: paired and unpaired student s t-test
# lookup term: paired_and_unpaired_student_s_t-test
#   • Student's t-test                         URI=http://purl.obolibrary.org/obo/OBI_0000739 score=0.77
#
# Query: covariance analyse
# lookup term: covariance_analyse
#   • covariance                               URI=http://purl.obolibrary.org/obo/STATO_0000301 score=1.00
#
# randomization
# Query: randomization
# lookup term: randomization
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0034656
#
# Query: permutated-block scheduling
# lookup term: permutated-block_scheduling
#   • block design                             URI=http://purl.obolibrary.org/obo/STATO_0000046 score=0.84
#
# intention_to_treat_analysis
# Query: intention to treat analysis
# lookup term: intention_to_treat_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2718028
#
# mmrm
# Query: mmrm
# lookup term: mmrm
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/Mmrm
#
# shannon_diversity_index
# Query: shannon diversity index
# lookup term: shannon_diversity_index
#   → Reusing existing URI: http://purl.obolibrary.org/obo/PCO_0000062
#
# Query: simpson index
# lookup term: simpson_index
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/SimpsonIndex
#
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# Query: genome-wide association analysi
# lookup term: genome-wide_association_analysi
#   • genome-wide association study            URI=http://purl.obolibrary.org/obo/STATO_0000091 score=0.91
#
# intervention_trial
# Query: intervention trial
# lookup term: intervention_trial
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0814861
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# mesh_mining_method
# Query: mesh mining method
# lookup term: mesh_mining_method
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/MeshMiningMethod
#
# mesh_mining_method
# Query: mesh mining method
# lookup term: mesh_mining_method
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/MeshMiningMethod
#
# ranking_algorithm
# Query: ranking algorithm
# lookup term: ranking_algorithm
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/RankingAlgorithm
#
# Query: cross-validation procedure
# lookup term: cross-validation_procedure
#   • Cross Validation                         URI=http://purl.obolibrary.org/obo/NCIT_C78545 score=0.81
#
# mesh_mining_method
# Query: mesh mining method
# lookup term: mesh_mining_method
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/MeshMiningMethod
#
# Query: spearman correlation analysi
# lookup term: spearman_correlation_analysi
#   • Spearman Correlation Test                URI=http://purl.obolibrary.org/obo/NCIT_C53249 score=0.89
#
# Query: predictive analysis method
# lookup term: predictive_analysis_method
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/PredictiveAnalysisMethod
#
# Query: statistical testing method
# lookup term: statistical_testing_method
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/StatisticalTestingMethod
#
# Query: statistical testing method
# lookup term: statistical_testing_method
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/StatisticalTestingMethod
#
# Query: lasso
# lookup term: lasso
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/Lasso
#
#
# Query: lasso
# lookup term: lasso
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/Lasso
#
#
# lasso
# Query: lasso
# lookup term: lasso
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/Lasso
#
# linear_models
# Query: linear models
# lookup term: linear_models
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0023732
#
# linear_models
# Query: linear models
# lookup term: linear_models
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0023732
#
# linear_models
# Query: linear models
# lookup term: linear_models
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0023732
#
# Query: lasso
# lookup term: lasso
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/Lasso
#
#
# Query: lasso
# lookup term: lasso
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/Lasso
#
#
# linear_models
# Query: linear models
# lookup term: linear_models
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0023732
#
# Query: dirichlet-multinomial model
# lookup term: dirichlet-multinomial_model
#   • Multinomial Distribution                 URI=http://purl.obolibrary.org/obo/NCIT_C53210 score=0.86
#
# Query: lasso
# lookup term: lasso
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/Lasso
#
#
# analysis_of_variance
# Query: analysis of variance
# lookup term: analysis_of_variance
#   • variance                                 URI=http://purl.obolibrary.org/obo/STATO_0000113 score=0.77
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# random_forest
# Query: random forest
# lookup term: random_forest
#   • random forest procedure                  URI=http://purl.obolibrary.org/obo/STATO_0000549 score=0.82
#
# Query: comparative statistic
# lookup term: comparative_statistic
#   • q-statistic                              URI=http://purl.obolibrary.org/obo/STATO_0000606 score=1.00
#
# Query: analysis of variance
# lookup term: analysis_of_variance
#   • variance                                 URI=http://purl.obolibrary.org/obo/STATO_0000113 score=0.77
#
# Query: unpaired samples t-test
# lookup term: unpaired_samples_t-test
#   • Z-test                                   URI=http://purl.obolibrary.org/obo/STATO_0000052 score=1.00
#
# regression_analysis
# Query: regression analysis
# lookup term: regression_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0034980
#
# Query: meta-analysis of the parkinson s disease gut microbiome
# lookup term: meta-analysis_of_the_parkinson_s_disease_gut_microbiome
#   • meta analysis                            URI=http://purl.obolibrary.org/obo/STATO_0000155 score=1.00
#
# random_forest
# Query: random forest
# lookup term: random_forest
#   → Reusing existing URI: http://purl.obolibrary.org/obo/STATO_0000549
#
#
# cluster_method
# Query: cluster method
# lookup term: cluster_method
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009085
#
# cluster_method
# Query: cluster method
# lookup term: cluster_method
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009085
#
# cluster_method
# Query: cluster method
# lookup term: cluster_method
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009085
#
# cluster_method
# Query: cluster method
# lookup term: cluster_method
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009085
#
# Query: cross-sectional design
# lookup term: cross-sectional_design
#   • cross over design                        URI=http://purl.obolibrary.org/obo/OBI_0500003 score=1.00
#
# Query: small sample size
# lookup term: small_sample_size
#   • One Sample t-Test                        URI=http://purl.obolibrary.org/obo/NCIT_C53240 score=0.82
#
# Query: multiple comparison
# lookup term: multiple_comparison
#   • Multiple Comparison Adjustment           URI=http://purl.obolibrary.org/obo/NCIT_C61601 score=0.82
#
# Query: pooled mean difference
# lookup term: pooled_mean_difference
#   • mean difference                          URI=http://purl.obolibrary.org/obo/STATO_0000457 score=1.00
#
# mean_difference
# Query: mean difference
# lookup term: mean_difference
#   • mean difference                          URI=http://purl.obolibrary.org/obo/STATO_0000457
# Query: odds ratio
# lookup term: odds_ratio
#   • odds ratio                               URI=http://purl.obolibrary.org/obo/STATO_0000182
# Query: 95  confidence interval
# lookup term: 95__confidence_interval
#   • 95% confidence interval                  URI=http://purl.obolibrary.org/obo/STATO_0000231 score=1.00
#
# random-effects_meta-analyses
# Query: random-effects meta-analyses
# lookup term: random-effects_meta-analyses
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/RandomEffectsMetaAnalyses
#
#
# social_network_analysis
# Query: social network analysis
# lookup term: social_network_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1171218
#
# shannon_diversity_index
# Query: shannon diversity index
# lookup term: shannon_diversity_index
#   → Reusing existing URI: http://purl.obolibrary.org/obo/PCO_0000062
#
#
# Query: meta-analysi
# lookup term: meta-analysi
#   → Reusing existing URI: http://purl.obolibrary.org/obo/STATO_0000155
#
#
# Query: meta-analysi
# lookup term: meta-analysi
#   → Reusing existing URI: http://purl.obolibrary.org/obo/STATO_0000155
#
#
# shannon_diversity_index
# Query: shannon diversity index
# lookup term: shannon_diversity_index
#   → Reusing existing URI: http://purl.obolibrary.org/obo/PCO_0000062
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# Query: clinical cohort
# lookup term: clinical_cohort
#   • cohort                                   URI=http://purl.obolibrary.org/obo/STATO_0000203 score=1.00
#
# analysis
# Query: analysis
# lookup term: analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0936012
#
# shannon_diversity_index
# Query: shannon diversity index
# lookup term: shannon_diversity_index
#   → Reusing existing URI: http://purl.obolibrary.org/obo/PCO_0000062
#
# Query: simpson index
# lookup term: simpson_index
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/SimpsonIndex
#
#
# analysis
# Query: analysis
# lookup term: analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0936012
#
# Query: logistic regression
# lookup term: logistic_regression
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0206031
#
#
# Query: linear regression
# lookup term: linear_regression
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0023733
#
#
# Query: permutational analysis of variance
# lookup term: permutational_analysis_of_variance
#   • variance                                 URI=http://purl.obolibrary.org/obo/STATO_0000113 score=0.77
#
# analysis_of_variance
# Query: analysis of variance
# lookup term: analysis_of_variance
#   → Reusing existing URI: http://purl.obolibrary.org/obo/STATO_0000113
#
#
# Query: linear regression
# lookup term: linear_regression
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0023733
#
#
# Query: regression analysi
# lookup term: regression_analysi
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0034980
#
#
# Query: permutational multivariate analysis of variance
# lookup term: permutational_multivariate_analysis_of_variance
#   • multivariate analysis of variance        URI=http://purl.obolibrary.org/obo/STATO_0000454 score=1.00
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# chao1_index
# Query: chao1 index
# lookup term: chao1_index
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/statisticaltechnique/Chao1Index
#
# shannon_diversity_index
# Query: shannon diversity index
# lookup term: shannon_diversity_index
#   → Reusing existing URI: http://purl.obolibrary.org/obo/PCO_0000062
#
# weight/weight_ratio
# Query: weight/weight ratio
# lookup term: weight/weight_ratio
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2919747
#
# jaccard_index
# Query: jaccard index
# lookup term: jaccard_index
#   → Reusing existing URI: http://www.ebi.ac.uk/swo/SWO_0000243
#
# shannon_diversity_index
# Query: shannon diversity index
# lookup term: shannon_diversity_index
#   → Reusing existing URI: http://purl.obolibrary.org/obo/PCO_0000062
#
# multidimensional_scaling_analysis
# Query: multidimensional scaling analysis
# lookup term: multidimensional_scaling_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0681930
#
# multidimensional_scaling_analysis
# Query: multidimensional scaling analysis
# lookup term: multidimensional_scaling_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0681930
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# Query: effect size measurement
# lookup term: effect_size_measurement
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5962230
#
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# Query: receiver operating characteristic  roc  curve
# lookup term: receiver_operating_characteristic__roc__curve
#   • area under the receiver operator characteristic curve URI=http://purl.obolibrary.org/obo/STATO_0000608 score=0.77
#
# Query: subgroup meta-analysi
# lookup term: subgroup_meta-analysi
#   • meta analysis                            URI=http://purl.obolibrary.org/obo/STATO_0000155 score=0.81
#
# Query: random effects model
# lookup term: random_effects_model
#   • random effect model                      URI=http://purl.obolibrary.org/obo/STATO_0000099 score=0.80
#
# Query: mean difference  md
# lookup term: mean_difference__md_
#   • mean difference                          URI=http://purl.obolibrary.org/obo/STATO_0000457 score=1.00
#
# Query: continuous model
# lookup term: continuous_model
#   • Continuous Distribution                  URI=http://purl.obolibrary.org/obo/NCIT_C53213 score=0.86
#
# Query: meta-analysi
# lookup term: meta-analysi
#   → Reusing existing URI: http://purl.obolibrary.org/obo/STATO_0000155
#
#
# Query: meta-analysi
# lookup term: meta-analysi
#   → Reusing existing URI: http://purl.obolibrary.org/obo/STATO_0000155
#
#
# biostatistical_methods
# Query: biostatistical methods
# lookup term: biostatistical_methods
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1511167
#
#
# Query: correlation analysi
# lookup term: correlation_analysi
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C53236
#
#
# positive_and_negative_affect_schedule
# Query: positive and negative affect schedule
# lookup term: positive_and_negative_affect_schedule
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0582655
#
# positive_and_negative_affect_schedule
# Query: positive and negative affect schedule
# lookup term: positive_and_negative_affect_schedule
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0582655
#
# cluster_method
# Query: cluster method
# lookup term: cluster_method
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009085
#
# regression_analysis
# Query: regression analysis
# lookup term: regression_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0034980
#
# Query: random forest classifier
# lookup term: random_forest_classifier
#   • random forest procedure                  URI=http://purl.obolibrary.org/obo/STATO_0000549 score=0.82
#
# Query: receiver operating characteristic  roc -area under curve  auc
# lookup term: receiver_operating_characteristic__roc_-area_under_curve__auc_
#   • area under the receiver operator characteristic curve URI=http://purl.obolibrary.org/obo/STATO_0000608 score=0.89
#
# Query: precision-recall curve  prc -auc
# lookup term: precision-recall_curve__prc_-auc
#   • precision-recall curve                   URI=http://purl.obolibrary.org/obo/STATO_0000695 score=1.00
#
# multilevel_models_(statistics)
# Query: multilevel models (statistics)
# lookup term: multilevel_models_(statistics)
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3824847
#
# multiple_imputation_technique
# Query: multiple imputation technique
# lookup term: multiple_imputation_technique
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2825511
#
# entering dev
# Query: principal coordinate analysi
# lookup term: principal_coordinate_analysi
# no matches
# linear_discriminant_analysis
# Query: linear discriminant analysis
# lookup term: linear_discriminant_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5940528
#
# cluster_method
# Query: cluster method
# lookup term: cluster_method
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009085
#
# The RDF graph has been saved in c:\Users\samue\OneDrive\Desktop\ThesisPiron\rdf\gutbrain_entities.ttl

# %% [markdown]
# <h1>INGEST BIOMEDICAL TECHNIQUE</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from rdflib.namespace import DCTERMS
from groqutils import get_llm_definition
from funcutils import get_ncit_description, get_chebi_description, get_omit_description, NCBI_BASE, HEREDITARY_BASE, UMLS_BASES, foodon_file, ncit_file, omit_file, chebi_file, hash_term_sha256

BIOMEDICALTECHNIQUE_BASE = "http://purl.obolibrary.org/obo/"
BIOMEDICALTECHNIQUE_CLASS = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/BiomedicalTechnique")
BIOMEDICALTECHNIQUE_CONCEPT_SCHEME = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/BiomedicalTechnique")

def load_biomedical_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = BIOMEDICALTECHNIQUE_BASE + term_id
            rows.append((label, uri))
    return rows

BIOMEDICAL_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncbitaxon_full_taxonomy.txt"
STATO_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\stato_full_taxonomy.txt"
biom_rows = load_biomedical_labels(BIOMEDICAL_LABELS_FILE)
biom1_rows = load_biomedical_labels(STATO_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in biom_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

exact_ix1 = defaultdict(list)
for lbl, uri in biom1_rows:
    exact_ix1[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in biom_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

labels1_only = [preprocess(lbl) for lbl, _ in biom1_rows]
vec1 = TfidfVectorizer(stop_words="english")
mat1 = vec1.fit_transform(labels1_only)

def top_cosine(term, k=5, thr=0.75):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = biom_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

def top_cosine1(term, k=5, thr=0.75):
    v   = vec1.transform([term])
    sc  = cosine_similarity(v, mat1).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = biom1_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

manual_created = {}
created = {}

manual_created = {
    "dqi-i" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/Dqii"),
    "16s_rdna_pcr" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRdnaPcr"),
    "childhood_behaviour_checklist" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/ChildhoodBehaviourChecklist"),
    "liquid_chromatography_mass_spectrometry" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0872318"),
    "gas_chromatography" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0008555"),
    "16s_rrna_sequencing" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing"),
    "picrust_analysis" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/PicrustAnalysis"),
    "dual_hit_toxin_model" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/DualHitToxinModel"),
    "forced_swim_test" : URIRef("http://purl.obolibrary.org/obo/MMO_0000574"),
    "open_field_apparatus_method" : URIRef("http://purl.obolibrary.org/obo/MMO_0000258"),
    "sucrose_preference_test" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SucrosePreferenceTest"),
    "multiomics_study" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MultiomicsStudy"),
    "metagenomic_dna_and_rna_sequencing" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5848503"),
    "serum_metabolomics_profiling" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SerumMetabolomicsProfiling"),
    "metagenomic_analysis": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5906995"),
    "hippocampal_proteomic_analysis" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/HippocampalProteomicAnalysis"),
    "gut_permeability_assay" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/GutPermeabilityAssay"),
    "ussing_chamber_permeability_assay" : URIRef("http://www.bioassayontology.org/bao#BAO_0010084"),
    "immunoblotting":URIRef("http://purl.obolibrary.org/obo/OMIT_0015957"),
    "immunohistochemical_analyses" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/ImmunohistochemicalAnalyses"),
    "liquid_chromatography_mass_spectrometry": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0872318"),
    "body_weight_test" : URIRef("http://purl.obolibrary.org/obo/NCIT_C119794"),
    "enzyme-linked_immunosorbent_assay" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0014441"),
    "westrern_blotting" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0005863"),
    "social_stress_scale" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4050347"),
    "shotgun_metagenomic_sequencing" : URIRef("http://edamontology.org/topic_3837"),
    "fpg_technique" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/FpgTechnique"),
    "fpi_technique" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/FpiTechnique"),
    "homeostasis_model_assessment_insulin_resistance" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/HomeostasisModelAssessmentInsulinResistance"),
    "ancom-bc2" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/AncomBc2"),
    "updrs_part_iii_motor_scores" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/UpdrsPartIIIMotorScores"),
    "comparative_genomic_analysis" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0796358"),
    "mitbamp_analyses": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MitbampAnalyses"),
    "aav-shrna" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/AavShrna"),
    "biological_laboratory_methods" :URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0814046"),
    "c14_d-xylose_breath_test" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0430719"),
    "targeted_therapy" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C2985566"),
    "strain-level_meta-analysis" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StrainLevelMetaAnalysis"),
    "nuclear_spectroscopy" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4295577"),
    "kegg_analysis" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/KeggAnalysis"),
    "gastrointestinal_and_microbiome_profiling" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/GastrointestinalAndMicrobiomeProfiling"),
    "splash": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/Splash"),
    "elevated_plus_maze_test": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5392082"),
    "metabolomic":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1328813"),
    "double-blind_method" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0013072"),
    "burst_testing" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/BurstTesting"),
    "bielschowsky_head_tilt_test": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1302989"),
    "fluorescent_in_situ_hybridization": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0162789"),
    "intravenous_glucose_tolerance_test" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0021911"),
    "immunofluorescent_stain_method": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1318793"),
    "analysis":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0936012"),
    "shotgun_sequencing": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1519305"),
    "stress_model" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel"),
    "multiplex_electrochemiluminescence_immunoassay":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5225027"),
    "sleep_latency_test" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0430629"),
    "microbiome_profiling": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MicrobiomeProfiling"),
    "bielschowsky_head_tilt_test": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1302989"),
    "glucose_tolerance_test" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0017741"),
    "liver_lipid_kit" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/LiverLipidKit"),
    "legend_plex_kit" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/LegendPlexKit"),
    "enzyme-linked_immunosorbent_assay" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0014441"),
    "functional_enrichment_analysis" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/FunctionalEnrichmentAnalysis"),
    "duodenal_aspirate_analysis" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0430151"),
    "bioinformatics_analysis" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/BioinformaticsAnalysis"),
    "stool_biobank" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StoolBiobank"),
    "double-blind_method" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0013072"),
    "high_sensitivity_c-reactive_protein_measurement" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4763419"),
    "in_situ_hybridization": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0162788"),
    "human_rna_sequencing": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1328904"),
    "biomarker_test": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/BiomarkerTest"),
    "randomized_controlled_trial": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1096777"),
    "screening_colonoscopy": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1882982"),
    "neurologic_examination": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0027853"),
    "self-reporting_questionnaire": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SelfReportingQuestionnaire"),
    "applied_behavior_analysis": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4277701"),
    "phylogenetic_analysis" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1519068"),
    "fluorescence_resonance_energy_transfer": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0597717"),
    "photobiomodulation": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/Photobiomodulation"),
    "epm_test": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/EmpTest"),
    "behavorial_testing": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/BehavorialTesting"),
    "screening_procedure": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0220908"),
    "cleverage_biota": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/CleverageBiota"),
    "neuropsychological_battery": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0451331"),
    "validated_questionnaire": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/ValidatedQuestionnaire"),
    "alba_test": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/AlbaTest"),
    "tmt_functional_test_question": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4087090"),
    "16s_rdna_analysis": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRdnsAnalysis"),
    "spatial_transcriptome_analysis": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5958871"),
    "molecular_docking": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5392994"),
    "bioinformatic_test" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/BioinformaticTest"),
    "culturomics": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/Culturomics"),
    "magnetic_resonance_imaging": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0024485"),
    "metatranscriptomic": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5908247"),
    "diagnostic_interview_schedule": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0451119"),
    "brief_symptom_inventory_18": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1707044"),
    "elevated_plus_maze_test": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5392082"),
    "open_field_test": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5392081"),
    "novel_object_recognition_test": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5392823"),
    "lipidomic_study": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/LipidomicStudy"),
    "inflammatory_marker_test" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C3805088"),
    "digit_span_backward": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/DigitSpanBackward"),
    "semantic_fluency_span": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SemanticFluencySpan"),
    "memory_domain": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MemoryDomain"),
    "trail_making_test": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0040604"),
    "vagotomy": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0394374"),
    "deamination": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0011061"),
    "unifrac": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/Unifrac"),
    "nasogastric_feeding": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0192456"),
    "proteomics": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0872252"),
    "biotics_test": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/BioticsTest"),
    "tail_suspension": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0376592"),
    "colonscopy":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0009378"),
    "deoxyribonucleic_acid_extraction_technique":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C3839098"),
    "transcriptomics":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4727081"),
    "semantic_fluency_span":URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SemanticFluencySpan"),
    "human_induced_pluripotent_stem_cells": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C3658289"),
    "microbial_concentration": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MicrobialConcentration"),
    "microbiome_analysis": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MicrobiomeAnalysis"),
    "manipulation_procedure": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0947647"),
    "vagal_stimulation": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1293903"),
    "nanosring_ncounter_analysis_system": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5787151"),
    "blastn_analysis": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/BlastnAnalysis"),
    "morris_water_maze_test": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5197854"),
    "proton_magnetic_resonance_spectroscopy": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C3850002"),
    "immunohistochemistry": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0021044"),
    "gas_chromatography_and_flame_ionization_detection": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4525803"),
    "sequence-based_typing": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4319106"),
    "ga-map_dysbiosis_test": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/GaMapDysbiosisTest"),
    "osteopathic_manipulation_(procedure)" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0949744"),
}

created = dict(manual_created)

regex_map = [
    (r"16s_rdna_survey", "16s_rdna_pcr"),
    (r"analysis_of_composition_of_microbiome","microbiome_analysis"),
    (r"\bmeasurements_of_fecal_microbial_concentration\b","microbial_concentration"),
    (r"\bancom\b","microbiome_analysis"),
    (r"\bga-map__dysbiosis_test\b","ga-map_dysbiosis_test")
    (r"sequence-based_and_ultramicroscopic_study","sequence-based_typing"),
    (r"flame_ionisation_detection","gas_chromatography_and_flame_ionization_detection"),
    (r"\b1h-nmr\b","proton_magnetic_resonance_spectroscopy"),
    (r"\bmorris_water_maze\b","morris_water_maze_test"),
    (r"\bblastn_analysi\w*\b","blastn_analysis"),
    (r"ncounter_nanostring_platform","nanosring_ncounter_analysis_system")
    (r"\bdietary_manipulation\b","manipulation_procedure"),
    (r"open-field_test","open_field_test"),
    (r"\bmeasurements_of_fecal_microbial_concentration\w*\b","microbial_concentration")
    (r"phylogenetic_investigation_of_communities_by_reconstruction_of_unobserved_states__picrust_","picrust_analysis"),
    (r"\bbiotic\w*\b","biotics_test"),
    (r"next_generation_sequencing__ngs__of_the_v3-v4_region_of_the_bacterial_rna_16_","16s_rrna_sequencing"),
    (r"\bdsb\b","digit_span_backward"),
    (r"human_induced_pluripotent_stem_cell-derived_cerebral_mp","human_induced_pluripotent_stem_cells"),
    (r"\bmd\b","memory_domain"),
    (r"color_trails_test_2","trail_making_test"),
    (r"\bctt2\b","trail_making_test"),
    (r"unweighted_unifrac_pcoa","unifrac"),
    (r"\bbdb","block_design"),
    (r"\bort\b","novel_object_recognition_test"),
    (r"\bbd\b","block_design"),
    (r"\bmicrobiome_analysis_approache\w*\b","microbiome_analysis")
    (r"\bsf\b","semantic_fluency_span"),
    (r"subdiaphragmatic_vagotomy","vagotomy"),
    (r"\bsdv\b","vagotomy"),
    (r"kegg_pathway_analysi","kegg_analysis"),
    (r"\boft\b","open_field_test"),
    (r"object_recognition_test","novel_object_recognition_test"),
    (r"\bopt\b","novel_object_recognition_test"),
    (r"object_placement_test","novel_object_recognition_test"),
    (r"recognition_trial","novel_object_recognition_test"),
    (r"\brt\b","novel_object_recognition_test"),
    (r"gut_bacterial_deamination","deamination"),
    (r"intra-gastric_gavage","nasogastric_feeding"),
    (r"\bbiochemical_analysi\w*\b","analysis"),
    (r"\blipid_analyse\w*\b","analysis"),
    (r"elevated-plus_maze_test","elevated_plus_maze_test"),
    (r"brief_symptom_inventory","brief_symptom_inventory_18"),
    (r"\bbile_acid_analysi\w*\b","analysis"),
    (r"\bproteomic_and_transcriptomic_analysi\w*\b","analysis"),
    (r"composite_international_diagnostic_interview_for_women","diagnostic_interview_schedule"),
    (r"\bculturomic\w*\b","culturomics"),
    (r"self-report_questionnaire","self-reporting_questionnaire"),
    (r"microbiota-related_biomarker","biomarker_test"),
    (r"16s_ribosomal_rna_gene_sequencing","16s_rrna_sequencing"),
    (r"16s_rrna_sequencin\w*\b","16s_rrna_sequencing"),
    (r"\bamplification_and_sequencing_of_the_v4_region_of_the_16_s_rdna_gene\b","16s_rdna_analysis"),
    (r"16sr_rna_gene_sequencing","16s_rrna_sequencing"),
    (r"\b16s_ribosomal_rna_gene_amplicon_sequencing\b","16s_rrna_sequencing"),
    (r"\bmetatranscriptomic_analysi\w*\b","metatranscriptomic"),
    (r"infant_behavior_questionnaire_-revised","validated_questionnaire"),
    (r"\bibq-r\b","validated_questionnaire"),
    (r"inflammatory_marker","inflammatory_marker_test"),
    (r"\b16_s_rdna_analysi\w*\b","16s_rdna_analysis"),
    (r"\btranscriptomics_analysi\w*\b","spatial_transcriptome_analysis"),
    (r"genome_sequencing_technology","metagenomic_dna_and_rna_sequencing"),
    (r"bioinformatic","bioinformatic_test"),
    (r"depression_and_anxiety_questionnaire","validated_questionnaire"),
    (r"\bfret\b","fluorescence_resonance_energy_transfer"),
    (r"\bpbm\b","photobiomodulation"),
    (r"\bscreen\b","screening_procedure"),
    (r"bi-center__double-blind__randomized__and_placebo-controlled_clinical_trial","randomized_controlled_trial"),
    (r"randomized-control_trial_of_mindful_awareness_practice","randomized_controlled_trial"),
    (r"tmt_b","tmt_functional_test_question"),
    (r"colonoscopy","colonscopy"),
    (r"neuropsychological_test","neurologic_examination"),
    (r"neurological_examination","neurologic_examination"),
    (r"\bmri\b","magnetic_resonance_imaging"),
    (r"\bsequencing-based_phylogenetic_analysi\w*\b","phylogenetic_analysis"),
    (r"randomised__triple-blind__placebo-controlled_trial","randomized_controlled_trial"),
    (r"lc-ms","liquid_chromatography_mass_spectrometry"),
    (r"gc","gas_chromatography"),
    (r"16s_rrna_gene_sequencing", "16s_rrna_sequencing"),
    (r"\b16s_ribosome_rna_analysi\w*\b","16s_rrna_sequencing"),
    (r"16_s_rna_sequencing", "16s_rrna_sequencing"),
    (r"picrust_analysi", "picrust_analysis"),
    (r"\bfst\b","forced_swim_test"),
    (r"forced_swimming_test", "forced_swim_test"),
    (r"open_field_test","open_field_apparatus_method"),
    (r"body_weight", "body_weight_test"),
    (r"immunofluorescence","immunofluorescent_staining_method"),
    (r"fecal_metagenome-wide-sequencing","metagenomic_dna_and_rna_sequencing"),
    (r"qpcr","real_time_pcr"),
    (r"social_defeat_stress", "social_stress_scale"),
    (r"rsd","social_stress_scale"),
    (r"metagenomics_analysis_of_the_microbiome", "metagenomic_analysis"),
    (r"ussing_chamber","ussing_chamber_permeability_assay"),
    (r"immunohistochemical_analyse","immunohistochemical_analyses") ,
    (r"lc-m","liquid_chromatography_mass_spectrometry"),
    (r"enzyme_linked_immunosorbent_assay","enzyme-linked_immunosorbent_assay"),
    (r"fecal_metagenome-wide_sequencing","metagenomic_dna_and_rna_sequencing"),
    (r"mechanistic_analysi","analysis"),
    (r"mitbamp_analyse","mitbamp_analyses"),
    (r"shotgun_metagenomic","shotgun_metagenomic_sequencing"),
    (r"shotgun_metagenomics_sequencing","shotgun_metagenomic_sequencing"),
    (r"hippocampal_proteomic_analysi","hippocampal_proteomic_analysis"),
    (r"sms","shotgun_metagenomic_sequencing"),
    (r"fpg","fpg_technique"),
    (r"hippocampal_proteomic_analysi","hippocampal_proteomic_analysis"),
    (r"splash","splash"),
    (r"spt","sucrose_preference_test"),
    (r"fpi","fpi_technique"),
    (r"homa-ir","homeostasis_model_assessment_insulin_resistance"),
    (r"chronic_unpredictable_mild_stress__cums__model","stress_model"),
    (r"16s_rrna_gene-sequenced_gut_microbiota_data","16s_rrna_sequencing"),
    (r"16s_ribosomal_rna_gene_sequencing","16s_rrna_sequencing"),
    (r"pentobarbital-induced_sleep_test","sleep_latency_test"),
    (r"comparative_genomics_analysi", "analysis"),
    (r"rna-seq_profiling","metagenomic_dna_and_rna_sequencing"),
    (r"multi-omics_analyses","multiomics_study"),
    (r"multi-omics_testing","multiomics_study"),
    (r"metabolomics_profiling","serum_metabolomics_profiling"),
    (r"metabolomic_profiling","serum_metabolomics_profiling"),
    (r"16s_rrna", "16s_rrna_sequencing"),
    (r"untargeted_metabolomic", "serum_metabolomics_profiling"),
    (r"16s_ribosomal_rna_analysi", "16s_rrna_sequencing"),
    (r"bacterial_16s_sequencing","16s_rrna_sequencin"),
    (r"untargeted_metabolomic_analysi", "serum_metabolomics_profiling"),
    (r"analysis_of_the_fecal_sample", "metagenomic_analysis"),
    (r"wet_laboratory_method","biological_laboratory_methods"),
    (r"13c-d-xylose_breath_test","c14_d-xylose_breath_test"),
    (r"13c-d-xylose_breath_testing","c14_d-xylose_breath_test"),
    (r"single-cell_rna-seq_analysi","single-cell_rna-seq_analysis"),
    (r"microbiota-targeted_therapy","targeted_therapy"),
    (r"strain-level_meta-analysi", "strain-level_meta-analysis"),
    (r"nuclear_mr_spectroscopy","nuclear_spectroscopy"),
    (r"kegg_analysi", "kegg_analysis"),
    (r"16s_kegg_function_prediction","kegg_analysis"),
    (r"\bkegg_bacterial_16s_function_prediction_analysi\w*\b","kegg_analysis"),
    (r"neurological_examination","neurologic_examination"),
    (r"\btst\b","tail_suspension"),
    (r"omics_technique", "multiomics_study"),
    (r"elevated_plus_maze","elevated_plus_maze_test"),
    (r"16s_ribosomal_rna__16s_rrna__gene_sequence-based_approach","16s_rrna_sequencing"),
    (r"untargeted_liquid_chromatography-mass_spectrometry-based_metabolic_profiling_approach","liquid_chromatography_mass_spectrometry"),
    (r"16s_rrna_gene_amplicon_sequencing","16s_rrna_sequencing"),
    (r"16s_and_18s_ribosomal_rna_amplicon_sequencing","16s_rrna_sequencing"),
    (r"16s_ribosomal_rna_gene_v3-4_amplicon_sequencing","16s_rrna_sequencing"),
    (r"metatranscriptomics_analyses","metagenomic_dna_and_rna_sequencing"),
    (r"double-blind__randomized__placebo-controlled_trial","double-blind_method"),
    (r"hutt","bielschowsky_head_tilt_test"),
    (r"quantitative_fluorescence_in_situ_hybridization","fluorescent_in_situ_hybridization"),
    (r"high-sensitivity_c-reactive_protein","high_sensitivity_c-reactive_protein_measurement"),
    (r"itt","intravenous_glucose_tolerance_test"),
    (r"transcriptomics_data","transcriptomics"),
    (r"metatranscriptomics_analyse", "metagenomic_dna_and_rna_sequencing"),
    (r"sm", "shotgun_sequencing"),
    (r"genomic_sequencing","shotgun_sequencing"),
    (r"whole_genome_shotgun_sequencing","shotgun_sequencing"),
    (r"multiplex_immunoassay", "multiplex_electrochemiluminescence_immunoassay"),
    (r"sleep_test","sleep_latency_test"),
    (r"rna_sequencing","human_rna_sequencing"),
    (r"comparative_genomics_analysis","analysis"),
    (r"multi-omics_analyses","multiomics_study"),
    (r"single-cell_rna-seq_analysis","metagenomic_dna_and_rna_sequencing"),
    (r"multiple_integrated_omic","multiomics_study"),
    (r"head-up_tilt_test","bielschowsky_head_tilt_test"),
    (r"igtt","glucose_tolerance_test"),
    (r"elisa","enzyme-linked_immunosorbent_assay"),
    (r"multi-omics_approach","multiomics_study"),
    (r"functional_enrichment_analysi","functional_enrichment_analysis"),
    (r"duodenal_aspirate", "duodenal_aspirate_analysis"),
    (r"bioinformatics_analysi", "bioinformatics_analysis"),
    (r"single_prolonged_stress__sps__model","stress_model"),
    (r"sp","stress_model"),
    (r"sps_model","stress_model"),
    (r"dna_extraction","deoxyribonucleic_acid_extraction_technique"),
    (r"taxon-function_analysi","analysis"),
    (r"randomized__double-blinded__two-arm_feasibility_study","double-blind_method"),
    (r"16s_rna_method","16s_rrna_sequencing"),
    (r"elisa_kit","enzyme-linked_immunosorbent_assay"),
    (r"community-based_metabolic_modeling","metagenomic_analysis"),
    (r"metabolic_modelling","metagenomic_analysis"),
    (r"\bbehavioral_and_biochemical_analyse\w*\b","applied_behavior_analysis"),
    (r"\bmetagenomic_approache\w*\b","metagenomic_analysis"),
    (r"metagenomic","metagenomic_analysis"),
    (r"\bmajor_metagenomic_approache\w*\b","metagenomic_analysis"),
    (r"rna_sequencing","16s_rrna_sequencing"),
    (r"\bproteomic\w*\b","proteomics"),
    (r"metagenomic_analysi","metagenomic_analysis"),
    (r"immunofluorescent_staining_method","immunofluorescent_stain_method"),
    (r"\bmulti-omics_analyse\w*\b", "multiomics_study"),
    (r"single-cell_rna-seq_analysis","metagenomic_dna_and_rna_sequencing"),
    (r"multi-omics_animal_experiment","multiomics_study"),
    (r"multi-omics_analysi", "multiomics_study"),
    (r"single-cell_rna-seq_analysis","analysis"),
    (r"\bphylogenetic\b","phylogenetic_analysis"),
    (r"\bosteopathic_manipulative_medicine__omm__sequence\b","osteopathic_manipulation_(procedure)"),
    (r"omm-sequence","osteopathic_manipulation_(procedure)"),
    (r"\bphylogenetic_investigation_of_communities_by_reconstruction_of_unobserved_states__picrust__analysi\w*\b","picrust_analysis"),
]

CREATOR = "Samuel Piron"

UMLS_BASE = "https://uts.nlm.nih.gov/uts/umls/concept/"

for uri in manual_created.values():
    uri_str = str(uri)

    if uri_str.startswith(UMLS_BASE):
        # only a UMLS‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("UMLS Match", datatype=XSD.string)))
    elif "MMO" in uri_str:
        # only a STATO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("MNO Match", datatype=XSD.string)))
    elif "BAO" in uri_str:
        # only a BAO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("BAO Match", datatype=XSD.string)))
    elif "NCIT" in uri_str:
        # only a NCIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("NCIT Match", datatype=XSD.string)))
    elif "OMIT" in uri_str:
        # only a OMIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("OMIT Match", datatype=XSD.string)))
    else:
        # everything else still gets a creator
        g.add((uri,
               DCTERMS.creator,
               Literal(CREATOR, datatype=XSD.string)))
        
for term_raw, uri in manual_created.items():
    uri_str = str(uri)

    # NCIT definitions
    if uri_str.startswith(NCBI_BASE) and "NCIT_" in uri_str:
        ncit_id = uri_str.rsplit("_", 1)[-1]
        desc = get_ncit_description(ncit_id, ncit_file)
        m = re.search(r'—\s*(.*?)\s*—', desc)
        if m:
            desc = m.group(1).strip()
            comment = f"{desc} [Definition Source: NCIT]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # UMLS definitions
    elif uri_str.startswith(UMLS_BASES):
        cui = uri_str.rsplit("/", 1)[-1]
        defn = get_umls_definition(cui)
        if defn:
            comment = f"{defn.strip()} [Definition Source: UMLS]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # MeSH definitions via your mesh_index
    elif uri_str.startswith(MESH_BASE):
        ui     = uri_str.rsplit("/",1)[-1]
        hits   = [d['name'] for d in mesh_descs if d['ui']==ui]
        if hits:
            comment = f"{hits[0]} [Definition Source: MeSH]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    elif uri_str.startswith(HEREDITARY_BASE):
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"
    else:
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    g.add((uri,
           RDFS.comment,
           Literal(comment, datatype=XSD.string)))
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "biomedical technique":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    if lookup_key == "single-cell_rna-seq_analysis":
                        lookup_key = "metagenomic_dna_and_rna_sequencing"
                    elif lookup_key == "immunofluorescent_staining_method":
                        lookup_key = "immunofluorescent_stain_method"
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine1(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass
print("entering gold")

for paper_id, paper_data in data_gold.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "biomedical technique":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    if lookup_key == "single-cell_rna-seq_analysis":
                        lookup_key = "metagenomic_dna_and_rna_sequencing"
                    elif lookup_key == "immunofluorescent_staining_method":
                        lookup_key = "immunofluorescent_stain_method"
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine1(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

print("entering dev")

for paper_id, paper_data in data_dev.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "biomedical technique":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    if lookup_key == "single-cell_rna-seq_analysis":
                        lookup_key = "metagenomic_dna_and_rna_sequencing"
                    elif lookup_key == "immunofluorescent_staining_method":
                        lookup_key = "immunofluorescent_stain_method"
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine1(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]
    
    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "biomedical technique":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_gold_file, "r", encoding="utf-8") as f_sent:
    tokenized_gold_data = json.load(f_sent)

for entry in tokenized_gold_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "biomedical technique":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_dev, "r", encoding="utf-8") as f_sent:
    tokenized_dev_data = json.load(f_sent)

for entry in tokenized_dev_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "biomedical technique":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

output_file = os.path.join(save_path, "gutbrain_entities.ttl")
ttl_output = g.serialize(format="turtle")
with open(output_file, "w", encoding="utf-8") as f_out:
    f_out.write(ttl_output)

print(f"The RDF graph has been saved in {output_file}")
# Out:
# Query: dqi-i
# lookup term: dqi-i
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/Dqii
#
#
# 16s_rdna_pcr
# Query: 16s rdna pcr
# lookup term: 16s_rdna_pcr
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRdnaPcr
#
# 16s_rdna_pcr
# Query: 16s rdna pcr
# lookup term: 16s_rdna_pcr
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRdnaPcr
#
# metagenomic_dna_and_rna_sequencing
# Query: metagenomic dna and rna sequencing
# lookup term: metagenomic_dna_and_rna_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5848503
#
# Query: metabolomic
# lookup term: metabolomic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1328813
#
# metagenomic_analysis
# Query: metagenomic analysis
# lookup term: metagenomic_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5906995
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# Query: childhood behaviour checklist
# lookup term: childhood_behaviour_checklist
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/ChildhoodBehaviourChecklist
#
#
# liquid_chromatography_mass_spectrometry
# Query: liquid chromatography mass spectrometry
# lookup term: liquid_chromatography_mass_spectrometry
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0872318
#
# gas_chromatography
# Query: gas chromatography
# lookup term: gas_chromatography
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0008555
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
#
# picrust_analysis
# Query: picrust analysis
# lookup term: picrust_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/PicrustAnalysis
#
#
# Query: dual hit toxin model
# lookup term: dual_hit_toxin_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/DualHitToxinModel
#
#
# forced_swim_test
# Query: forced swim test
# lookup term: forced_swim_test
#   → Reusing existing URI: http://purl.obolibrary.org/obo/MMO_0000574
#
# open_field_apparatus_method
# Query: open field apparatus method
# lookup term: open_field_apparatus_method
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392081
#
#
# Query: sucrose preference test
# lookup term: sucrose_preference_test
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SucrosePreferenceTest
#
#
# body_weight_test
# Query: body weight test
# lookup term: body_weight_test
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C119794
#
# enzyme-linked_immunosorbent_assay
# Query: enzyme-linked immunosorbent assay
# lookup term: enzyme-linked_immunosorbent_assay
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0014441
#
# immunofluorescent_stain_method
# Query: immunofluorescent stain method
# lookup term: immunofluorescent_stain_method
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1318793
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# Query: western blotting
# lookup term: western_blotting
#   • Western X phytoplasma                    URI=http://purl.obolibrary.org/obo/NCBITaxon_37704 score=0.80
#
# Query: multiomics study
# lookup term: multiomics_study
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MultiomicsStudy
#
#
# Query: multiomics study
# lookup term: multiomics_study
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MultiomicsStudy
#
#
# metagenomic_dna_and_rna_sequencing
# Query: metagenomic dna and rna sequencing
# lookup term: metagenomic_dna_and_rna_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5848503
#
# serum_metabolomics_profiling
# Query: serum metabolomics profiling
# lookup term: serum_metabolomics_profiling
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SerumMetabolomicsProfiling
#
#
# metagenomic_analysis
# Query: metagenomic analysis
# lookup term: metagenomic_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5906995
#
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
#
# real_time_pcr
# Query: real time pcr
# lookup term: real_time_pcr
#   • real time quantitative pcr plot          URI=http://purl.obolibrary.org/obo/STATO_0000168 score=0.80
#
# hippocampal_proteomic_analysis
# Query: hippocampal proteomic analysis
# lookup term: hippocampal_proteomic_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/HippocampalProteomicAnalysis
#
#
# social_stress_scale
# Query: social stress scale
# lookup term: social_stress_scale
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4050347
#
# social_stress_scale
# Query: social stress scale
# lookup term: social_stress_scale
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4050347
#
# social_stress_scale
# Query: social stress scale
# lookup term: social_stress_scale
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4050347
#
# metagenomic_analysis
# Query: metagenomic analysis
# lookup term: metagenomic_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5906995
#
# Query: gut permeability assay
# lookup term: gut_permeability_assay
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/GutPermeabilityAssay
#
#
# ussing_chamber_permeability_assay
# Query: ussing chamber permeability assay
# lookup term: ussing_chamber_permeability_assay
#   → Reusing existing URI: http://www.bioassayontology.org/bao#BAO_0010084
#
# Query: immunoblotting
# lookup term: immunoblotting
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0015957
#
#
# immunohistochemical_analyses
# Query: immunohistochemical analyses
# lookup term: immunohistochemical_analyses
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/ImmunohistochemicalAnalyses
#
#
# analysis
# Query: analysis
# lookup term: analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0936012
#
# shotgun_metagenomic_sequencing
# Query: shotgun metagenomic sequencing
# lookup term: shotgun_metagenomic_sequencing
#   → Reusing existing URI: http://edamontology.org/topic_3837
#
# shotgun_metagenomic_sequencing
# Query: shotgun metagenomic sequencing
# lookup term: shotgun_metagenomic_sequencing
#   → Reusing existing URI: http://edamontology.org/topic_3837
#
# shotgun_sequencing
# Query: shotgun sequencing
# lookup term: shotgun_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1519305
#
# Query: tryptophan concentration measurement
# lookup term: tryptophan_concentration_measurement
#   • concentration                            URI=http://purl.obolibrary.org/obo/STATO_0000704 score=0.78
#
# fpg_technique
# Query: fpg technique
# lookup term: fpg_technique
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/FpgTechnique
#
# fpi_technique
# Query: fpi technique
# lookup term: fpi_technique
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/FpiTechnique
#
# homeostasis_model_assessment_insulin_resistance
# Query: homeostasis model assessment insulin resistance
# lookup term: homeostasis_model_assessment_insulin_resistance
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/HomeostasisModelAssessmentInsulinResistance
#
# Query: ancom-bc2
# lookup term: ancom-bc2
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/AncomBc2
#
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel
#
# shotgun_sequencing
# Query: shotgun sequencing
# lookup term: shotgun_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1519305
#
# shotgun_sequencing
# Query: shotgun sequencing
# lookup term: shotgun_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1519305
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
#
# multiplex_electrochemiluminescence_immunoassay
# Query: multiplex electrochemiluminescence immunoassay
# lookup term: multiplex_electrochemiluminescence_immunoassay
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5225027
#
# Query: updrs part iii motor score
# lookup term: updrs_part_iii_motor_score
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/UpdrsPartIIIMotorScores
#
#
# sleep_latency_test
# Query: sleep latency test
# lookup term: sleep_latency_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0430629
#
# analysis
# Query: analysis
# lookup term: analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0936012
#
# Query: phenol-sulfate assay
# lookup term: phenol-sulfate_assay
#   • assay                                    URI=http://purl.obolibrary.org/obo/OBI_0000070 score=1.00
#
# sleep_latency_test
# Query: sleep latency test
# lookup term: sleep_latency_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0430629
#
# shotgun_sequencing
# Query: shotgun sequencing
# lookup term: shotgun_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1519305
#
# Query: transcriptome sequencing
# lookup term: transcriptome_sequencing
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# Query: rna-seq
# lookup term: rna-seq
#   • RNA-seq assay                            URI=http://purl.obolibrary.org/obo/OBI_0001271 score=0.88
#
# metagenomic_dna_and_rna_sequencing
# Query: metagenomic dna and rna sequencing
# lookup term: metagenomic_dna_and_rna_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5848503
#
# double-blind_method
# Query: double-blind method
# lookup term: double-blind_method
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0013072
#
# multiomics_study
# Query: multiomics study
# lookup term: multiomics_study
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MultiomicsStudy
#
# Query: metabolomic
# lookup term: metabolomic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1328813
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# serum_metabolomics_profiling
# Query: serum metabolomics profiling
# lookup term: serum_metabolomics_profiling
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SerumMetabolomicsProfiling
#
# shotgun_metagenomic_sequencing
# Query: shotgun metagenomic sequencing
# lookup term: shotgun_metagenomic_sequencing
#   → Reusing existing URI: http://edamontology.org/topic_3837
#
# shotgun_metagenomic_sequencing
# Query: shotgun metagenomic sequencing
# lookup term: shotgun_metagenomic_sequencing
#   → Reusing existing URI: http://edamontology.org/topic_3837
#
#
# mitbamp_analyses
# Query: mitbamp analyses
# lookup term: mitbamp_analyses
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MitbampAnalyses
#
#
# Query: aav-shrna
# lookup term: aav-shrna
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/AavShrna
#
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# serum_metabolomics_profiling
# Query: serum metabolomics profiling
# lookup term: serum_metabolomics_profiling
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SerumMetabolomicsProfiling
#
# Query: burst testing
# lookup term: burst_testing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/BurstTesting
#
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# shotgun_metagenomic_sequencing
# Query: shotgun metagenomic sequencing
# lookup term: shotgun_metagenomic_sequencing
#   → Reusing existing URI: http://edamontology.org/topic_3837
#
#
# metagenomic_analysis
# Query: metagenomic analysis
# lookup term: metagenomic_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5906995
#
# biological_laboratory_methods
# Query: biological laboratory methods
# lookup term: biological_laboratory_methods
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0814046
#
# c14_d-xylose_breath_test
# Query: c14 d-xylose breath test
# lookup term: c14_d-xylose_breath_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0430719
#
# c14_d-xylose_breath_test
# Query: c14 d-xylose breath test
# lookup term: c14_d-xylose_breath_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0430719
#
# metagenomic_dna_and_rna_sequencing
# Query: metagenomic dna and rna sequencing
# lookup term: metagenomic_dna_and_rna_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5848503
#
# targeted_therapy
# Query: targeted therapy
# lookup term: targeted_therapy
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C2985566
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# shotgun_metagenomic_sequencing
# Query: shotgun metagenomic sequencing
# lookup term: shotgun_metagenomic_sequencing
#   → Reusing existing URI: http://edamontology.org/topic_3837
#
#
# strain-level_meta-analysis
# Query: strain-level meta-analysis
# lookup term: strain-level_meta-analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StrainLevelMetaAnalysis
#
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# picrust_analysis
# Query: picrust analysis
# lookup term: picrust_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/PicrustAnalysis
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# nuclear_spectroscopy
# Query: nuclear spectroscopy
# lookup term: nuclear_spectroscopy
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4295577
#
# Query: illumina sequencing
# lookup term: illumina_sequencing
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# kegg_analysis
# Query: kegg analysis
# lookup term: kegg_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/KeggAnalysis
#
#
# kegg_analysis
# Query: kegg analysis
# lookup term: kegg_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/KeggAnalysis
#
#
# multiomics_study
# Query: multiomics study
# lookup term: multiomics_study
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MultiomicsStudy
#
# liquid_chromatography_mass_spectrometry
# Query: liquid chromatography mass spectrometry
# lookup term: liquid_chromatography_mass_spectrometry
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0872318
#
# Query: gastrointestinal and microbiome profiling
# lookup term: gastrointestinal_and_microbiome_profiling
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/GastrointestinalAndMicrobiomeProfiling
#
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# Query: microbiome profiling
# lookup term: microbiome_profiling
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MicrobiomeProfiling
#
#
# Query: voluntary wheel running
# lookup term: voluntary_wheel_running
#   • voluntary sampling                       URI=http://purl.obolibrary.org/obo/STATO_0000513 score=0.83
#
# splash
# Query: splash
# lookup term: splash
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/Splash
#
#
# elevated_plus_maze_test
# Query: elevated plus maze test
# lookup term: elevated_plus_maze_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392082
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel
#
# multiomics_study
# Query: multiomics study
# lookup term: multiomics_study
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MultiomicsStudy
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# liquid_chromatography_mass_spectrometry
# Query: liquid chromatography mass spectrometry
# lookup term: liquid_chromatography_mass_spectrometry
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0872318
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# Query: metabolomic
# lookup term: metabolomic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1328813
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# bielschowsky_head_tilt_test
# Query: bielschowsky head tilt test
# lookup term: bielschowsky_head_tilt_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1302989
#
# bielschowsky_head_tilt_test
# Query: bielschowsky head tilt test
# lookup term: bielschowsky_head_tilt_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1302989
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
#
# fluorescent_in_situ_hybridization
# Query: fluorescent in situ hybridization
# lookup term: fluorescent_in_situ_hybridization
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0162789
#
# high_sensitivity_c-reactive_protein_measurement
# Query: high sensitivity c-reactive protein measurement
# lookup term: high_sensitivity_c-reactive_protein_measurement
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4763419
#
# open_field_test
# Query: open field test
# lookup term: open_field_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392081
#
# sucrose_preference_test
# Query: sucrose preference test
# lookup term: sucrose_preference_test
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SucrosePreferenceTest
#
# tail_suspension
# Query: tail suspension
# lookup term: tail_suspension
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0376592
#
# glucose_tolerance_test
# Query: glucose tolerance test
# lookup term: glucose_tolerance_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0017741
#
# Query: liver lipid kit
# lookup term: liver_lipid_kit
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/LiverLipidKit
#
#
# Query: legend plex kit
# lookup term: legend_plex_kit
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/LegendPlexKit
#
# enzyme-linked_immunosorbent_assay
# Query: enzyme-linked immunosorbent assay
# lookup term: enzyme-linked_immunosorbent_assay
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0014441
#
# novel_object_recognition_test
# Query: novel object recognition test
# lookup term: novel_object_recognition_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392823
#
# Query: western blot
# lookup term: western_blot
#   • Western X phytoplasma                    URI=http://purl.obolibrary.org/obo/NCBITaxon_37704 score=0.80
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# multiomics_study
# Query: multiomics study
# lookup term: multiomics_study
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MultiomicsStudy
#
# multiomics_study
# Query: multiomics study
# lookup term: multiomics_study
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MultiomicsStudy
#
# functional_enrichment_analysis
# Query: functional enrichment analysis
# lookup term: functional_enrichment_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/FunctionalEnrichmentAnalysis
#
#
# shotgun_metagenomic_sequencing
# Query: shotgun metagenomic sequencing
# lookup term: shotgun_metagenomic_sequencing
#   → Reusing existing URI: http://edamontology.org/topic_3837
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
#
# shotgun_metagenomic_sequencing
# Query: shotgun metagenomic sequencing
# lookup term: shotgun_metagenomic_sequencing
#   → Reusing existing URI: http://edamontology.org/topic_3837
#
# shotgun_metagenomic_sequencing
# Query: shotgun metagenomic sequencing
# lookup term: shotgun_metagenomic_sequencing
#   → Reusing existing URI: http://edamontology.org/topic_3837
#
# duodenal_aspirate_analysis
# Query: duodenal aspirate analysis
# lookup term: duodenal_aspirate_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0430151
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
#
# bioinformatic_test
# Query: bioinformatic test
# lookup term: bioinformatic_test
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/BioinformaticsAnalysis
#
#
# Query: stool biobank
# lookup term: stool_biobank
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StoolBiobank
#
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel
#
# Query: behavioral test
# lookup term: behavioral_test
#   • test organism                            URI=http://purl.obolibrary.org/obo/NCBITaxon_457483 score=0.81
#
# Query: anxiety index
# lookup term: anxiety_index
#   • Xiphinema index                          URI=http://purl.obolibrary.org/obo/NCBITaxon_46003 score=0.80
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel
#
# multiomics_study
# Query: multiomics study
# lookup term: multiomics_study
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MultiomicsStudy
#
# analysis
# Query: analysis
# lookup term: analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0936012
#
# double-blind_method
# Query: double-blind method
# lookup term: double-blind_method
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0013072
#
# Query: quantitative sybr green real-time pcr
# lookup term: quantitative_sybr_green_real-time_pcr
#   • real time quantitative pcr plot          URI=http://purl.obolibrary.org/obo/STATO_0000168 score=0.94
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# enzyme-linked_immunosorbent_assay
# Query: enzyme-linked immunosorbent assay
# lookup term: enzyme-linked_immunosorbent_assay
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0014441
#
# metagenomic_analysis
# Query: metagenomic analysis
# lookup term: metagenomic_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5906995
#
# metagenomic_analysis
# Query: metagenomic analysis
# lookup term: metagenomic_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5906995
#
# metagenomic_analysis
# Query: metagenomic analysis
# lookup term: metagenomic_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5906995
#
# shotgun_sequencing
# Query: shotgun sequencing
# lookup term: shotgun_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1519305
#
# shotgun_sequencing
# Query: shotgun sequencing
# lookup term: shotgun_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1519305
#
# human_rna_sequencing
# Query: human rna sequencing
# lookup term: human_rna_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1328904
#
# Query: metabolomic
# lookup term: metabolomic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1328813
#
# transcriptomics
# Query: transcriptomics
# lookup term: transcriptomics
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4727081
#
# Query: biomarker test
# lookup term: biomarker_test
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/BiomarkerTest
#
# enzyme-linked_immunosorbent_assay
# Query: enzyme-linked immunosorbent assay
# lookup term: enzyme-linked_immunosorbent_assay
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0014441
#
# immunofluorescent_stain_method
# Query: immunofluorescent stain method
# lookup term: immunofluorescent_stain_method
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1318793
#
# Query: western blot
# lookup term: western_blot
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_37704
#
#
# Query: enzyme-linked immunosorbent assay
# lookup term: enzyme-linked_immunosorbent_assay
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0014441
#
#
# enzyme-linked_immunosorbent_assay
# Query: enzyme-linked immunosorbent assay
# lookup term: enzyme-linked_immunosorbent_assay
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0014441
#
# Query: western blot
# lookup term: western_blot
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_37704
#
#
# Query: sequencing 16s rdna
# lookup term: sequencing_16s_rdna
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# randomized_controlled_trial
# Query: randomized controlled trial
# lookup term: randomized_controlled_trial
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1096777
#
# shotgun_metagenomic_sequencing
# Query: shotgun metagenomic sequencing
# lookup term: shotgun_metagenomic_sequencing
#   → Reusing existing URI: http://edamontology.org/topic_3837
#
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# colonscopy
# Query: colonscopy
# lookup term: colonscopy
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1882982
#
#
# colonscopy
# Query: colonscopy
# lookup term: colonscopy
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0009378
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# kegg_analysis
# Query: kegg analysis
# lookup term: kegg_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/KeggAnalysis
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# social_stress_scale
# Query: social stress scale
# lookup term: social_stress_scale
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4050347
#
# neurologic_examination
# Query: neurologic examination
# lookup term: neurologic_examination
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027853
#
# neurologic_examination
# Query: neurologic examination
# lookup term: neurologic_examination
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027853
#
# Query: self-reporting questionnaire
# lookup term: self-reporting_questionnaire
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SelfReportingQuestionnaire
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# metagenomic_analysis
# Query: metagenomic analysis
# lookup term: metagenomic_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5906995
#
# applied_behavior_analysis
# Query: applied behavior analysis
# lookup term: applied_behavior_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4277701
#
# phylogenetic_analysis
# Query: phylogenetic analysis
# lookup term: phylogenetic_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1519068
#
# Query: fluorescence resonance energy transfer
# lookup term: fluorescence_resonance_energy_transfer
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0597717
#
#
# fluorescence_resonance_energy_transfer
# Query: fluorescence resonance energy transfer
# lookup term: fluorescence_resonance_energy_transfer
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0597717
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# shotgun_sequencing
# Query: shotgun sequencing
# lookup term: shotgun_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1519305
#
# metagenomic_analysis
# Query: metagenomic analysis
# lookup term: metagenomic_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5906995
#
# Query: brain imaging technique
# lookup term: brain_imaging_technique
#   • imaging assay                            URI=http://purl.obolibrary.org/obo/OBI_0000185 score=0.80
#
# Query: in situ hybridization
# lookup term: in_situ_hybridization
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0162788
#
#
# enzyme-linked_immunosorbent_assay
# Query: enzyme-linked immunosorbent assay
# lookup term: enzyme-linked_immunosorbent_assay
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0014441
#
# Query: miseq sequencing
# lookup term: miseq_sequencing
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# 16s_rrna_sequencin
# Query: 16s rrna sequencin
# lookup term: 16s_rrna_sequencin
#   • fungal sp. 16S-7                         URI=http://purl.obolibrary.org/obo/NCBITaxon_1080634 score=0.84
#
# kegg_analysis
# Query: kegg analysis
# lookup term: kegg_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/KeggAnalysis
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
#
# Query: photobiomodulation
# lookup term: photobiomodulation
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/Photobiomodulation
#
#
# photobiomodulation
# Query: photobiomodulation
# lookup term: photobiomodulation
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/Photobiomodulation
#
# photobiomodulation
# Query: photobiomodulation
# lookup term: photobiomodulation
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/Photobiomodulation
#
# photobiomodulation
# Query: photobiomodulation
# lookup term: photobiomodulation
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/Photobiomodulation
#
# Query: metabolomic
# lookup term: metabolomic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1328813
#
# elevated_plus_maze_test
# Query: elevated plus maze test
# lookup term: elevated_plus_maze_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392082
#
# Query: epm test
# lookup term: epm_test
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/EmpTest
#
#
# Query: behavorial testing
# lookup term: behavorial_testing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/BehavorialTesting
#
#
# Query: assay technique
# lookup term: assay_technique
#   • assay                                    URI=http://purl.obolibrary.org/obo/OBI_0000070 score=1.00
#
# screening_procedure
# Query: screening procedure
# lookup term: screening_procedure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0220908
#
# randomized_controlled_trial
# Query: randomized controlled trial
# lookup term: randomized_controlled_trial
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1096777
#
# Query: cleverage biota
# lookup term: cleverage_biota
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/CleverageBiota
#
#
# Query: neuropsychological battery
# lookup term: neuropsychological_battery
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0451331
#
#
# Query: validated questionnaire
# lookup term: validated_questionnaire
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/ValidatedQuestionnaire
#
# validated_questionnaire
# Query: validated questionnaire
# lookup term: validated_questionnaire
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/ValidatedQuestionnaire
#
# Query: alba test
# lookup term: alba_test
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/AlbaTest
#
#
# tmt_functional_test_question
# Query: tmt functional test question
# lookup term: tmt_functional_test_question
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4087090
#
# 16s_rdna_analysis
# Query: 16s rdna analysis
# lookup term: 16s_rdna_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRdnsAnalysis
#
# spatial_transcriptome_analysis
# Query: spatial transcriptome analysis
# lookup term: spatial_transcriptome_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5958871
#
# Query: molecular docking
# lookup term: molecular_docking
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392994
#
#
# metagenomic_dna_and_rna_sequencing
# Query: metagenomic dna and rna sequencing
# lookup term: metagenomic_dna_and_rna_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5848503
#
# bioinformatic_test
# Query: bioinformatic test
# lookup term: bioinformatic_test
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/BioinformaticTest
#
# culturomics
# Query: culturomics
# lookup term: culturomics
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/Culturomics
#
#
# validated_questionnaire
# Query: validated questionnaire
# lookup term: validated_questionnaire
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/ValidatedQuestionnaire
#
# validated_questionnaire
# Query: validated questionnaire
# lookup term: validated_questionnaire
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/ValidatedQuestionnaire
#
# validated_questionnaire
# Query: validated questionnaire
# lookup term: validated_questionnaire
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/ValidatedQuestionnaire
#
# validated_questionnaire
# Query: validated questionnaire
# lookup term: validated_questionnaire
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/ValidatedQuestionnaire
#
# neurologic_examination
# Query: neurologic examination
# lookup term: neurologic_examination
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027853
#
# magnetic_resonance_imaging
# Query: magnetic resonance imaging
# lookup term: magnetic_resonance_imaging
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0024485
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel
#
# self-reporting_questionnaire
# Query: self-reporting questionnaire
# lookup term: self-reporting_questionnaire
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SelfReportingQuestionnaire
#
# biomarker_test
# Query: biomarker test
# lookup term: biomarker_test
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/BiomarkerTest
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# Query: sucrose preference test
# lookup term: sucrose_preference_test
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SucrosePreferenceTest
#
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# Query: next-generation sequencing
# lookup term: next-generation_sequencing
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# metatranscriptomic
# Query: metatranscriptomic
# lookup term: metatranscriptomic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5908247
#
# analysis
# Query: analysis
# lookup term: analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0936012
#
# analysis
# Query: analysis
# lookup term: analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0936012
#
# diagnostic_interview_schedule
# Query: diagnostic interview schedule
# lookup term: diagnostic_interview_schedule
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0451119
#
# brief_symptom_inventory_18
# Query: brief symptom inventory 18
# lookup term: brief_symptom_inventory_18
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1707044
#
# serum_metabolomics_profiling
# Query: serum metabolomics profiling
# lookup term: serum_metabolomics_profiling
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SerumMetabolomicsProfiling
#
# Query: sucrose preference test
# lookup term: sucrose_preference_test
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SucrosePreferenceTest
#
#
# sucrose_preference_test
# Query: sucrose preference test
# lookup term: sucrose_preference_test
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SucrosePreferenceTest
#
# elevated_plus_maze_test
# Query: elevated plus maze test
# lookup term: elevated_plus_maze_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392082
#
# open_field_test
# Query: open field test
# lookup term: open_field_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392081
#
# open_field_test
# Query: open field test
# lookup term: open_field_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392081
#
# novel_object_recognition_test
# Query: novel object recognition test
# lookup term: novel_object_recognition_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392823
#
# Query: ort
# lookup term: ort
# no matches
# novel_object_recognition_test
# Query: novel object recognition test
# lookup term: novel_object_recognition_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392823
#
# novel_object_recognition_test
# Query: novel object recognition test
# lookup term: novel_object_recognition_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392823
#
# analysis
# Query: analysis
# lookup term: analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0936012
#
# analysis
# Query: analysis
# lookup term: analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0936012
#
# Query: lipidomic study
# lookup term: lipidomic_study
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/LipidomicStudy
#
# randomized_controlled_trial
# Query: randomized controlled trial
# lookup term: randomized_controlled_trial
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1096777
#
# shotgun_sequencing
# Query: shotgun sequencing
# lookup term: shotgun_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1519305
#
# inflammatory_marker_test
# Query: inflammatory marker test
# lookup term: inflammatory_marker_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3805088
#
# novel_object_recognition_test
# Query: novel object recognition test
# lookup term: novel_object_recognition_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392823
#
# novel_object_recognition_test
# Query: novel object recognition test
# lookup term: novel_object_recognition_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392823
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/DigitSpanBackward
#
#
# digit_span_backward
# Query: digit span backward
# lookup term: digit_span_backward
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/DigitSpanBackward
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SemanticFluencySpan
#
#
# semantic_fluency_span
# Query: semantic fluency span
# lookup term: semantic_fluency_span
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SemanticFluencySpan
#
# Query: memory domain
# lookup term: memory_domain
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MemoryDomain
#
#
# memory_domain
# Query: memory domain
# lookup term: memory_domain
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MemoryDomain
#
# digit_span_backward
# Query: digit span backward
# lookup term: digit_span_backward
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/DigitSpanBackward
#
# trail_making_test
# Query: trail making test
# lookup term: trail_making_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0040604
#
# trail_making_test
# Query: trail making test
# lookup term: trail_making_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0040604
#
# Query: block design
# lookup term: block_design
#   • block design                             URI=http://purl.obolibrary.org/obo/STATO_0000046 score=1.00
#
# Query: bd
# lookup term: bd
#   • bacterium BD                             URI=http://purl.obolibrary.org/obo/NCBITaxon_158884 score=0.87
#
# digit_span_backward
# Query: digit span backward
# lookup term: digit_span_backward
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/DigitSpanBackward
#
# semantic_fluency_span
# Query: semantic fluency span
# lookup term: semantic_fluency_span
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SemanticFluencySpan
#
# digit_span_backward
# ...
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/DigitSpanBackward
#
# trail_making_test
# Query: trail making test
# lookup term: trail_making_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0040604
#
# Query: bd
# lookup term: bd
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_158884
#
#
# semantic_fluency_span
# Query: semantic fluency span
# lookup term: semantic_fluency_span
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SemanticFluencySpan
#
# digit_span_backward
# Query: digit span backward
# lookup term: digit_span_backward
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/DigitSpanBackward
#
# memory_domain
# Query: memory domain
# lookup term: memory_domain
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MemoryDomain
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# vagotomy
# Query: vagotomy
# lookup term: vagotomy
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0394374
#
# vagotomy
# Query: vagotomy
# lookup term: vagotomy
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0394374
#
# vagotomy
# Query: vagotomy
# lookup term: vagotomy
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0394374
#
# Query: comparative genomic
# lookup term: comparative_genomic
#   • genomic coordinate system                URI=http://purl.obolibrary.org/obo/STATO_0000197 score=0.78
#
# phylogenetic_analysis
# Query: phylogenetic analysis
# lookup term: phylogenetic_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1519068
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# shotgun_metagenomic_sequencing
# Query: shotgun metagenomic sequencing
# lookup term: shotgun_metagenomic_sequencing
#   → Reusing existing URI: http://edamontology.org/topic_3837
#
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
#
# metagenomic_analysis
# Query: metagenomic analysis
# lookup term: metagenomic_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5906995
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# picrust_analysis
# Query: picrust analysis
# lookup term: picrust_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/PicrustAnalysis
#
# kegg_analysis
# Query: kegg analysis
# lookup term: kegg_analysis
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/KeggAnalysis
#
# deamination
# Query: deamination
# lookup term: deamination
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0011061
#
# unifrac
# Query: unifrac
# lookup term: unifrac
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/Unifrac
#
# nasogastric_feeding
# Query: nasogastric feeding
# lookup term: nasogastric_feeding
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0192456
#
# open_field_apparatus_method
# Query: open field apparatus method
# lookup term: open_field_apparatus_method
#   → Reusing existing URI: http://purl.obolibrary.org/obo/MMO_0000258
#
# shotgun_metagenomic_sequencing
# Query: shotgun metagenomic sequencing
# lookup term: shotgun_metagenomic_sequencing
#   → Reusing existing URI: http://edamontology.org/topic_3837
#
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel
#
# liquid_chromatography_mass_spectrometry
# Query: liquid chromatography mass spectrometry
# lookup term: liquid_chromatography_mass_spectrometry
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0872318
#
# bioinformatic_test
# Query: bioinformatic test
# lookup term: bioinformatic_test
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/BioinformaticTest
#
# liquid_chromatography_mass_spectrometry
# Query: liquid chromatography mass spectrometry
# lookup term: liquid_chromatography_mass_spectrometry
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0872318
#
# metagenomic_analysis
# Query: metagenomic analysis
# lookup term: metagenomic_analysis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5906995
#
# Query: behavioral  biochemical test
# lookup term: behavioral__biochemical_test
#   • test organism                            URI=http://purl.obolibrary.org/obo/NCBITaxon_457483 score=0.81
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# stem_cells
# Query: stem cells
# lookup term: stem_cells
# no matches
# forced_swim_test
# Query: forced swim test
# lookup term: forced_swim_test
#   → Reusing existing URI: http://purl.obolibrary.org/obo/MMO_0000574
#
# forced_swim_test
# Query: forced swim test
# lookup term: forced_swim_test
#   → Reusing existing URI: http://purl.obolibrary.org/obo/MMO_0000574
#
# forced_swim_test
# Query: forced swim test
# lookup term: forced_swim_test
#   → Reusing existing URI: http://purl.obolibrary.org/obo/MMO_0000574
#
# Query: metabolomic
# lookup term: metabolomic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1328813
#
# proteomics
# Query: proteomics
# lookup term: proteomics
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0872252
#
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel
#
# biotics_test
# Query: biotics test
# lookup term: biotics_test
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/BioticsTest
#
# Query: sequencing
# lookup term: sequencing
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# Query: measurements of fecal microbial concentration
# lookup term: measurements_of_fecal_microbial_concentration
#   • concentration                            URI=http://purl.obolibrary.org/obo/STATO_0000704 score=1.00
#
# shotgun_sequencing
# Query: shotgun sequencing
# lookup term: shotgun_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1519305
#
# deoxyribonucleic_acid_extraction_technique
# Query: deoxyribonucleic acid extraction technique
# lookup term: deoxyribonucleic_acid_extraction_technique
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3839098
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# real_time_pcr
# Query: real time pcr
# lookup term: real_time_pcr
#   → Reusing existing URI: http://purl.obolibrary.org/obo/STATO_0000168
#
#
# real_time_pcr
# Query: real time pcr
# lookup term: real_time_pcr
#   → Reusing existing URI: http://purl.obolibrary.org/obo/STATO_0000168
#
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# Query: osteopathic manipulative medicine  omm  sequence
# lookup term: osteopathic_manipulative_medicine__omm__sequence
#   • sequence data                            URI=http://purl.obolibrary.org/obo/OBI_0000973 score=0.81
#
# shotgun_sequencing
# Query: shotgun sequencing
# lookup term: shotgun_sequencing
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1519305
#
# Query: omm-sequence
# lookup term: omm-sequence
#   • unclassified DNA sequence                URI=http://purl.obolibrary.org/obo/NCBITaxon_2495523 score=0.76
#
# Query: next-generation sequencing
# lookup term: next-generation_sequencing
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OBI_0600047
#
#
# shotgun_metagenomic_sequencing
# Query: shotgun metagenomic sequencing
# lookup term: shotgun_metagenomic_sequencing
#   → Reusing existing URI: http://edamontology.org/topic_3837
#
# serum_metabolomics_profiling
# Query: serum metabolomics profiling
# lookup term: serum_metabolomics_profiling
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SerumMetabolomicsProfiling
#
# multiomics_study
# Query: multiomics study
# lookup term: multiomics_study
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MultiomicsStudy
#
# multiomics_study
# Query: multiomics study
# lookup term: multiomics_study
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/MultiomicsStudy
#
# shotgun_metagenomic_sequencing
# Query: shotgun metagenomic sequencing
# lookup term: shotgun_metagenomic_sequencing
#   → Reusing existing URI: http://edamontology.org/topic_3837
#
#
# serum_metabolomics_profiling
# Query: serum metabolomics profiling
# lookup term: serum_metabolomics_profiling
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/SerumMetabolomicsProfiling
#
# open_field_apparatus_method
# Query: open field apparatus method
# lookup term: open_field_apparatus_method
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392081
#
#
# stress_model
# Query: stress model
# lookup term: stress_model
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/StressModel
#
# Query: passive avoidance test
# lookup term: passive_avoidance_test
#   • test organism                            URI=http://purl.obolibrary.org/obo/NCBITaxon_457483 score=0.81
#
# Query: behavioral test
# lookup term: behavioral_test
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_457483
#
#
# entering dev
# Query: flow cytometry
# lookup term: flow_cytometry
#   • flow cytometry assay                     URI=http://purl.obolibrary.org/obo/OBI_0000916 score=0.87
#
# Query: amplification and sequencing of the v4 region of the 16 s rdna gene
# lookup term: amplification_and_sequencing_of_the_v4_region_of_the_16_s_rdna_gene
# no matches
# Query: microbiome analysis approache
# lookup term: microbiome_analysis_approache
# no matches
# Query: dietary manipulation
# lookup term: dietary_manipulation
# no matches
# Query: vagal stimulation
# lookup term: vagal_stimulation
# no matches
# Query: customized v-plex assay
# lookup term: customized_v-plex_assay
#   • assay                                    URI=http://purl.obolibrary.org/obo/OBI_0000070 score=1.00
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# Query: ncounter nanostring platform
# lookup term: ncounter_nanostring_platform
# no matches
# Query: blastn analysi
# lookup term: blastn_analysi
# no matches
# Query: fecal enema
# lookup term: fecal_enema
#   • Enema                                    URI=http://purl.obolibrary.org/obo/NCBITaxon_1247158 score=0.81
#
# Query: fecal enema
# lookup term: fecal_enema
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1247158
#
#
# Query: enema
# lookup term: enema
#   • Enema                                    URI=http://purl.obolibrary.org/obo/NCBITaxon_1247158
# Query: 16s rdna sequencing
# lookup term: 16s_rdna_sequencing
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# Query: metabolomic
# lookup term: metabolomic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1328813
#
# elevated_plus_maze_test
# Query: elevated plus maze test
# lookup term: elevated_plus_maze_test
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5392082
#
# Query: morris water maze
# lookup term: morris_water_maze
# no matches
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# Query: 1h-nmr
# lookup term: 1h-nmr
# no matches
# enzyme-linked_immunosorbent_assay
# Query: enzyme-linked immunosorbent assay
# lookup term: enzyme-linked_immunosorbent_assay
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0014441
#
# Query: rna-sequencing
# lookup term: rna-sequencing
# no matches
# ussing_chamber_permeability_assay
# Query: ussing chamber permeability assay
# lookup term: ussing_chamber_permeability_assay
#   → Reusing existing URI: http://www.bioassayontology.org/bao#BAO_0010084
#
# Query: immunohistochemistry
# lookup term: immunohistochemistry
# no matches
# immunofluorescent_stain_method
# Query: immunofluorescent stain method
# lookup term: immunofluorescent_stain_method
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1318793
#
# liquid_chromatography_mass_spectrometry
# Query: liquid chromatography mass spectrometry
# lookup term: liquid_chromatography_mass_spectrometry
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0872318
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# Query: ga-map  dysbiosis test
# lookup term: ga-map__dysbiosis_test
#   • Z-test                                   URI=http://purl.obolibrary.org/obo/STATO_0000052 score=1.00
#
# Query: gas chromatography
# lookup term: gas_chromatography
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0008555
#
#
# Query: flame ionisation detection
# lookup term: flame_ionisation_detection
# no matches
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
#
# Query: analysis of composition of microbiome
# lookup term: analysis_of_composition_of_microbiome
# no matches
# Query: ancom
# lookup term: ancom
# no matches
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
# Query: 16s ribosomal rna gene amplicon sequencing
# lookup term: 16s_ribosomal_rna_gene_amplicon_sequencing
# no matches
# social_stress_scale
# Query: social stress scale
# lookup term: social_stress_scale
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4050347
#
# 16s_rrna_sequencing
# Query: 16s rrna sequencing
# lookup term: 16s_rrna_sequencing
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/biomedicaltechnique/16sRrnaSequencing
#
#
# Query: sequence-based and ultramicroscopic study
# lookup term: sequence-based_and_ultramicroscopic_study
# no matches
# The RDF graph has been saved in c:\Users\samue\OneDrive\Desktop\ThesisPiron\rdf\gutbrain_entities.ttl

# %% [markdown]
# <h1>INGEST ANATOMICAL LOCATION</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint
from rdflib.namespace import DCTERMS
from groqutils import get_llm_definition
from funcutils import get_ncit_description, get_chebi_description, get_omit_description, NCBI_BASE, HEREDITARY_BASE, UMLS_BASES, foodon_file, ncit_file, omit_file, chebi_file, hash_term_sha256

ANATOMICALLOCATION_BASE = "http://purl.obolibrary.org/obo/"
ANATOMICALLOCATION_CLASS = URIRef("https://w3id.org/brainteaser/ontology/schema/AnatomicalSite")
ANATOMICALLOCATION_CONCEPT_SCHEME = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/AnatomicSite")

def load_anatomical_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = ANATOMICALLOCATION_BASE + term_id
            rows.append((label, uri))
    return rows

ANATOMICALLOCATION_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncit_full_taxonomy.txt"
anat_rows = load_anatomical_labels(ANATOMICALLOCATION_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in biom_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in anat_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

def top_cosine(term, k=5, thr=0.75):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = anat_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

manual_created = {}
created = {}

manual_created = {
    "skin_lipid_metabolism_gene" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/anatomicalsite/SkinLipidMetabolismGene"),
    "intestinal_(intended_site)" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5702674"),
    "gut" :URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0699819"),
    "pilosebaceous_unit" : URIRef("http://purl.obolibrary.org/obo/FMA_70661"),
    "intestinal_barrier_function" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5828281"),
    "medial_prefrontal_cortex_-_human": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C3853912"),
    "brain_tissue_(substance)" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0440746"),
    "human_body": URIRef("http://purl.obolibrary.org/obo/FMA_20394"),
    "postsynaptic_density": URIRef("https://amigo.geneontology.org/amigo/term/GO:0014069"),
    "systemic_blood_circulation" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0678860"),
    "colon" : URIRef("http://purl.obolibrary.org/obo/NCIT_C12382"),
    "hippocampus" : URIRef("http://purl.obolibrary.org/obo/NCIT_C12444"),
    "skin" : URIRef("http://purl.obolibrary.org/obo/NCIT_C12470"),
    "vagus_nerve_structure" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0042276"),
    "blood" : URIRef("http://purl.obolibrary.org/obo/NCIT_C12434"),
    "nasal_cavity" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0027423"),
    "liver_tissue": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/anatomicsite/LiverTissue"),
    "meninges":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0025285"),
    "gut_tissue": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/anatomicsite/GutTissue"),
    "mesencephalic_neoplasms": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0751888"),
    "hypothalamic_structure": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0020663"),
    "peripheral_gut": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/anatomicsite/PeripheralGut"),
    "organ": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0178784"),
}

created = dict(manual_created)

regex_map = [
    (r"intestinal_site", "intestinal_(intended_site)"),
    (r"\bvn\b","vagus_nerve_structure"),
    (r"\bperiphery\b","organ"),
    (r"\bhypothalamu\w*\b","hypothalamic_structure"),
    (r"intestinal_epithelial_layer","intestinal_epithelial_structure_maintenance"),
    (r"\bnervous_system\b","central_nervous_system"),
    (r"higher_order_brain_structure","brain"),
    (r"subdiaphragmatic_vagus_nerve", "vagus_nerve_structure"),
    (r"\bvagal_nerve_structure\b","vagus_nerve_structure"),
    (r"\bvagus_nerve\b", "vagus_nerve_structure"),
    (r"\bcn\b","central_nervous_system"),
    (r"\bbrain_area\b","brain"),
    (r"\bhuman_gut\b","gut"),
    (r"vagal_nerve","vagal_nerve_structure"),
    (r"primary_human_gut","gut"),
    (r"\bpfc\b","prefrontal_cortex"),
    (r"\bsn\b","substantia_nigra"),
    (r"vulnerable_brain_region","brain"),
    (r"substantia_nigra_pars_compacta","substantia_nigra"),
    (r"\bsnpc\b","substantia_nigra"),
    (r"human_brain","brain"),
    (r"\bhost_gut\b","gut"),
    (r"brain_region","brain"),
    (r"\bmeninge\w*\b","meninges"),
    (r"\bnasal_passage\w*\b","nasal_cavity"),
    (r"gi_sites", "intestinal_(intended_site)"),
    (r"gastrointestinal__gi__site", "intestinal_(intended_site)"),
    (r"digestive_tract","intestinal_(intended_site)"),
    (r"hippocampu", "hippocampus"),
    (r"nasal_passage", "nasal_passages"),
    (r"colonic_tracts", "colon"),
    (r"colonic_tract", "colon"),
    (r"intestinal_barrier", "intestinal_barrier_function"),
    (r"maternal_vagina","vagina"),
    (r"git","gut"),
    (r"\bpd_gut\b","gut"),
    (r"\bpd_appendix\b","appendix"),
    (r"aged_and_alzheimer_s_disease__ad__brain","brain"),
    (r"healthy_mature_brain","brain"),
    (r"mesencephalic_mitochondria","mesencephalic_neoplasms"),
    (r"infant_stool_and_nose","nose"),
    (r"hippocampal_synaptic_ultrastructure","hippocampal"),
    (r"urogenital_tract","genitourinary_system"),
    (r"mpfc","medial_prefrontal_cortex_-_human"),
    (r"cognitive_brain_area","medial_prefrontal_cortex_-_human"),
    (r"cuprizone-treated_mouse_brain","brain"),
    (r"gastrointestinal__gi__tract","intestinal_(intended_site)"),
    (r"rodent_gut","gut"),
    (r"gi_tract", "intestinal_(intended_site)"),
    (r"gi_site", "intestinal_(intended_site)"),
    (r"enteric_nervous_system","nervous_system"),
    (r"gut_barrier","intestinal_barrier_function"),
    (r"selected_brain_tissue","brain_tissue_(substance)"),
    (r"systemic_circulation","systemic_blood_circulation"),
    (r"brainstem","brain_stem"),
]
CREATOR = "Samuel Piron"

UMLS_BASE = "https://uts.nlm.nih.gov/uts/umls/concept/"

for uri in manual_created.values():
    uri_str = str(uri)

    if uri_str.startswith(UMLS_BASE):
        # only a UMLS‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("UMLS Match", datatype=XSD.string)))
    elif "MMO" in uri_str:
        # only a STATO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("MNO Match", datatype=XSD.string)))
    elif "BAO" in uri_str:
        # only a BAO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("BAO Match", datatype=XSD.string)))
    elif "NCIT" in uri_str:
        # only a NCIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("NCIT Match", datatype=XSD.string)))
    elif "OMIT" in uri_str:
        # only a OMIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("OMIT Match", datatype=XSD.string)))
    elif "FMA" in uri_str:
        # only a FMA‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("FMA Match", datatype=XSD.string)))
    elif "GO" in uri_str:
        # only a GO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("GO Match", datatype=XSD.string)))
    else:
        # everything else still gets a creator
        g.add((uri,
               DCTERMS.creator,
               Literal(CREATOR, datatype=XSD.string)))
        
for term_raw, uri in manual_created.items():
    uri_str = str(uri)

    # NCIT definitions
    if uri_str.startswith(NCBI_BASE) and "NCIT_" in uri_str:
        ncit_id = uri_str.rsplit("_", 1)[-1]
        desc = get_ncit_description(ncit_id, ncit_file)
        m = re.search(r'—\s*(.*?)\s*—', desc)
        if m:
            desc = m.group(1).strip()
            comment = f"{desc} [Definition Source: NCIT]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # UMLS definitions
    elif uri_str.startswith(UMLS_BASES):
        cui = uri_str.rsplit("/", 1)[-1]
        defn = get_umls_definition(cui)
        if defn:
            comment = f"{defn.strip()} [Definition Source: UMLS]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # MeSH definitions via your mesh_index
    elif uri_str.startswith(MESH_BASE):
        ui     = uri_str.rsplit("/",1)[-1]
        hits   = [d['name'] for d in mesh_descs if d['ui']==ui]
        if hits:
            comment = f"{hits[0]} [Definition Source: MeSH]"
        elif term_raw == "patients":
            comment = "Patients with various diseases. [Definition Source: GUTBRAIN]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    elif uri_str.startswith(HEREDITARY_BASE):
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"
    else:
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    g.add((uri,
           RDFS.comment,
           Literal(comment, datatype=XSD.string)))
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "anatomical location":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, ANATOMICALLOCATION_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, ANATOMICALLOCATION_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, ANATOMICALLOCATION_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, ANATOMICALLOCATION_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, ANATOMICALLOCATION_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, ANATOMICALLOCATION_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, ANATOMICALLOCATION_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, ANATOMICALLOCATION_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

print("entering gold")

for paper_id, paper_data in data_gold.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "anatomical location":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, ANATOMICALLOCATION_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, ANATOMICALLOCATION_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, ANATOMICALLOCATION_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, ANATOMICALLOCATION_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, ANATOMICALLOCATION_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, ANATOMICALLOCATION_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, ANATOMICALLOCATION_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, ANATOMICALLOCATION_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

print("entering dev")

for paper_id, paper_data in data_dev.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "anatomical location":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, ANATOMICALLOCATION_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, ANATOMICALLOCATION_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, ANATOMICALLOCATION_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, ANATOMICALLOCATION_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, ANATOMICALLOCATION_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, ANATOMICALLOCATION_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, ANATOMICALLOCATION_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, ANATOMICALLOCATION_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "anatomical location":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_gold_file, "r", encoding="utf-8") as f_sent:
    tokenized_gold_data = json.load(f_sent)

for entry in tokenized_gold_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "anatomical location":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_dev, "r", encoding="utf-8") as f_sent:
    tokenized_dev_data = json.load(f_sent)

for entry in tokenized_dev_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "anatomical location":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

output_file = os.path.join(save_path, "gutbrain_entities.ttl")
ttl_output = g.serialize(format="turtle")
with open(output_file, "w", encoding="utf-8") as f_out:
    f_out.write(ttl_output)

print(f"The RDF graph has been saved in {output_file}")
# Out:
# intestinal_(intended_site)
# Query: intestinal (intended site)
# lookup term: intestinal_(intended_site)
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5702674
#
# intestinal_(intended_site)
# Query: intestinal (intended site)
# lookup term: intestinal_(intended_site)
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5702674
#
# intestinal_(intended_site)
# Query: intestinal (intended site)
# lookup term: intestinal_(intended_site)
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5702674
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# Query: oral cavity
# lookup term: oral_cavity
#   • Oral Cavity                              URI=http://purl.obolibrary.org/obo/NCIT_C12421 score=1.00
#
# nasal_cavity
# Query: nasal cavity
# lookup term: nasal_cavity
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0027423
#
# Query: lung
# lookup term: lung
#   • Lung                                     URI=http://purl.obolibrary.org/obo/NCIT_C12468 score=1.00
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: skin
# lookup term: skin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12470
#
#
# Query: bladder
# lookup term: bladder
#   • Bladder                                  URI=http://purl.obolibrary.org/obo/NCIT_C12414 score=1.00
#
# Query: vagina
# lookup term: vagina
#   • Vagina                                   URI=http://purl.obolibrary.org/obo/NCIT_C12407 score=1.00
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   • Gastrointestinal Tract                   URI=http://purl.obolibrary.org/obo/NCIT_C34082 score=1.00
#
# Query: brain
# lookup term: brain
#   • Brain                                    URI=http://purl.obolibrary.org/obo/NCIT_C12439 score=1.00
#
# Query: pilosebaceous unit
# lookup term: pilosebaceous_unit
#   → Reusing existing URI: http://purl.obolibrary.org/obo/FMA_70661
#
#
# Query: skin
# lookup term: skin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12470
#
#
# Query: brain
# lookup term: brain
#   • Brain                                    URI=http://purl.obolibrary.org/obo/NCIT_C12439 score=1.00
#
# Query: heart
# lookup term: heart
#   • Heart Part                               URI=http://purl.obolibrary.org/obo/NCIT_C13023 score=1.00
#
# Query: artery
# lookup term: artery
#   • Artery                                   URI=http://purl.obolibrary.org/obo/NCIT_C12372 score=1.00
#
# Query: ovary
# lookup term: ovary
#   • Ovary                                    URI=http://purl.obolibrary.org/obo/NCIT_C12404 score=1.00
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# colon
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# Query: ascending colon vessel
# lookup term: ascending_colon_vessel
#   • Ascending Colon                          URI=http://purl.obolibrary.org/obo/NCIT_C12265 score=0.83
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# intestinal_barrier_function
# Query: intestinal barrier function
# lookup term: intestinal_barrier_function
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5828281
#
# Query: human body
# lookup term: human_body
#   → Reusing existing URI: http://purl.obolibrary.org/obo/FMA_20394
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# gut
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# Query: immune system
# lookup term: immune_system
#   • Immune                                   URI=http://purl.obolibrary.org/obo/NCIT_C17997 score=1.00
#
# Query: central nervous system
# lookup term: central_nervous_system
#   • Central Nervous System                   URI=http://purl.obolibrary.org/obo/NCIT_C12438 score=1.00
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# vagina
# Query: vagina
# lookup term: vagina
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12407
#
# Query: rectum
# lookup term: rectum
#   • Rectum                                   URI=http://purl.obolibrary.org/obo/NCIT_C12390 score=1.00
#
# Query: skin
# lookup term: skin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12470
#
#
# nose
# Query: nose
# lookup term: nose
#   • Nose                                     URI=http://purl.obolibrary.org/obo/NCIT_C12756 score=1.00
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# hippocampal
# Query: hippocampal
# lookup term: hippocampal
#   • Hippocampal Fissure                      URI=http://purl.obolibrary.org/obo/NCIT_C32743 score=0.78
#
# Query: synaptic cleft
# lookup term: synaptic_cleft
#   • Synaptic Cleft                           URI=http://purl.obolibrary.org/obo/NCIT_C33715 score=1.00
#
# Query: postsynaptic density
# lookup term: postsynaptic_density
#   → Reusing existing URI: https://amigo.geneontology.org/amigo/term/GO:0014069
#
# Query: mouse colon
# lookup term: mouse_colon
#   • Mouse Colon                              URI=http://purl.obolibrary.org/obo/NCIT_C22528 score=1.00
#
# systemic_blood_circulation
# Query: systemic blood circulation
# lookup term: systemic_blood_circulation
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0678860
#
# Query: synapse
# lookup term: synapse
#   • Synapse                                  URI=http://purl.obolibrary.org/obo/NCIT_C13281 score=1.00
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# Query: skin
# lookup term: skin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12470
#
#
# Query: nasopharynx
# lookup term: nasopharynx
#   • Nasopharynx                              URI=http://purl.obolibrary.org/obo/NCIT_C12423 score=1.00
#
# Query: oral cavity
# lookup term: oral_cavity
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12421
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# genitourinary_system
# Query: genitourinary system
# lookup term: genitourinary_system
#   • Genitourinary                            URI=http://purl.obolibrary.org/obo/NCIT_C25350 score=1.00
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# Query: duodenum
# lookup term: duodenum
#   • Duodenum                                 URI=http://purl.obolibrary.org/obo/NCIT_C12263 score=1.00
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: serum
# lookup term: serum
#   • Serum                                    URI=http://purl.obolibrary.org/obo/NCIT_C13325 score=1.00
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: medial prefrontal cortex
# lookup term: medial_prefrontal_cortex
#   • Prefrontal Cortex                        URI=http://purl.obolibrary.org/obo/NCIT_C154779 score=0.85
#
# medial_prefrontal_cortex_-_human
# Query: medial prefrontal cortex - human
# lookup term: medial_prefrontal_cortex_-_human
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3853912
#
# medial_prefrontal_cortex_-_human
# Query: medial prefrontal cortex - human
# lookup term: medial_prefrontal_cortex_-_human
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3853912
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# medial_prefrontal_cortex_-_human
# Query: medial prefrontal cortex - human
# lookup term: medial_prefrontal_cortex_-_human
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3853912
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# brain
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: peripheral tissue
# lookup term: peripheral_tissue
#   • Peripheral                               URI=http://purl.obolibrary.org/obo/NCIT_C25233 score=0.75
#
# intestinal_(intended_site)
# Query: intestinal (intended site)
# lookup term: intestinal_(intended_site)
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5702674
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: substantia nigra
# lookup term: substantia_nigra
#   • Substantia Nigra                         URI=http://purl.obolibrary.org/obo/NCIT_C12453 score=1.00
#
# Query: substantia nigra
# lookup term: substantia_nigra
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12453
#
#
# Query: striatum
# lookup term: striatum
#   • Striatum                                 URI=http://purl.obolibrary.org/obo/NCIT_C12450 score=1.00
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# gut
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: jejunum
# lookup term: jejunum
#   • Jejunum                                  URI=http://purl.obolibrary.org/obo/NCIT_C12388 score=1.00
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# Query: cecum
# lookup term: cecum
#   • Cecum                                    URI=http://purl.obolibrary.org/obo/NCIT_C12381 score=1.00
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# Query: liver
# lookup term: liver
#   • Liver                                    URI=http://purl.obolibrary.org/obo/NCIT_C12392 score=1.00
#
# Query: liver
# lookup term: liver
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12392
#
#
# Query: liver
# lookup term: liver
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12392
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: pulmonary
# lookup term: pulmonary
#   • Pulmonary                                URI=http://purl.obolibrary.org/obo/NCIT_C13304 score=1.00
#
# intestinal_(intended_site)
# Query: intestinal (intended site)
# lookup term: intestinal_(intended_site)
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5702674
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: small intestine
# lookup term: small_intestine
#   • Small Intestine                          URI=http://purl.obolibrary.org/obo/NCIT_C12386 score=1.00
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# nervous_system
# Query: nervous system
# lookup term: nervous_system
#   • Nervous                                  URI=http://purl.obolibrary.org/obo/NCIT_C25584 score=1.00
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# intestinal_barrier_function
# Query: intestinal barrier function
# lookup term: intestinal_barrier_function
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5828281
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# Query: stomach
# lookup term: stomach
#   • Stomach Part                             URI=http://purl.obolibrary.org/obo/NCIT_C13025 score=1.00
#
# Query: small intestine
# lookup term: small_intestine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12386
#
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# Query: cecum
# lookup term: cecum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12381
#
#
# brain_tissue_(substance)
# Query: brain tissue (substance)
# lookup term: brain_tissue_(substance)
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0440746
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: blood
# lookup term: blood
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12434
#
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# brain_stem
# Query: brain stem
# lookup term: brain_stem
#   • Brain Stem                               URI=http://purl.obolibrary.org/obo/NCIT_C12441 score=1.00
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: blood
# lookup term: blood
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12434
#
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# brain_stem
# Query: brain stem
# lookup term: brain_stem
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12441
#
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# brain_stem
# Query: brain stem
# lookup term: brain_stem
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12441
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# brain_stem
# Query: brain stem
# lookup term: brain_stem
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12441
#
#
# Query: intestine
# lookup term: intestine
#   • Intestine                                URI=http://purl.obolibrary.org/obo/NCIT_C12736 score=1.00
#
# Query: lung
# lookup term: lung
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12468
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: large bowel
# lookup term: large_bowel
#   • Large Bowel Leak, CTCAE                  URI=http://purl.obolibrary.org/obo/NCIT_C57833 score=0.78
#
# gut
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# Query: prefrontal cortex
# lookup term: prefrontal_cortex
#   • Prefrontal Cortex                        URI=http://purl.obolibrary.org/obo/NCIT_C154779 score=1.00
#
# prefrontal_cortex
# Query: prefrontal cortex
# lookup term: prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
# prefrontal_cortex
# Query: prefrontal cortex
# lookup term: prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
# central_nervous_system
# Query: central nervous system
# lookup term: central_nervous_system
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12438
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# central_nervous_system
# Query: central nervous system
# lookup term: central_nervous_system
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12438
#
# Query: substantia nigra
# lookup term: substantia_nigra
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12453
#
#
# substantia_nigra
# Query: substantia nigra
# lookup term: substantia_nigra
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12453
#
# Query: basal ganglia
# lookup term: basal_ganglia
#   • Basal Ganglia                            URI=http://purl.obolibrary.org/obo/NCIT_C12447 score=1.00
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# substantia_nigra
# Query: substantia nigra
# lookup term: substantia_nigra
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12453
#
# substantia_nigra
# Query: substantia nigra
# lookup term: substantia_nigra
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12453
#
# substantia_nigra
# Query: substantia nigra
# lookup term: substantia_nigra
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12453
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: rat brain
# lookup term: rat_brain
#   • Rat Brain                                URI=http://purl.obolibrary.org/obo/NCIT_C60544 score=1.00
#
# Query: prefrontal cortex
# lookup term: prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: puborectalis muscle
# lookup term: puborectalis_muscle
#   • Muscle                                   URI=http://purl.obolibrary.org/obo/NCIT_C13056 score=1.00
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# Query: host brain
# lookup term: host_brain
#   • Host                                     URI=http://purl.obolibrary.org/obo/NCIT_C66819 score=0.77
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# Query: host brain
# lookup term: host_brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C66819
#
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: substantia nigra
# lookup term: substantia_nigra
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12453
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# brain
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: intestine
# lookup term: intestine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12736
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: kidney
# lookup term: kidney
#   • Kidney Part                              URI=http://purl.obolibrary.org/obo/NCIT_C34028 score=1.00
#
# Query: liver
# lookup term: liver
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12392
#
#
# Query: liver
# lookup term: liver
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12392
#
#
# Query: kidney
# lookup term: kidney
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34028
#
#
# Query: kidney
# lookup term: kidney
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34028
#
#
# Query: liver
# lookup term: liver
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12392
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# gut
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# Query: prefrontal cortex
# lookup term: prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
#
# intestinal_(intended_site)
# Query: intestinal (intended site)
# lookup term: intestinal_(intended_site)
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5702674
#
# nervous_system
# Query: nervous system
# lookup term: nervous_system
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C25584
#
#
# Query: en
# lookup term: en
#   • FACT-En Questionnaire                    URI=http://purl.obolibrary.org/obo/NCIT_C118607 score=0.77
#
# intestinal_(intended_site)
# Query: intestinal (intended site)
# lookup term: intestinal_(intended_site)
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5702674
#
# intestinal_barrier_function
# Query: intestinal barrier function
# lookup term: intestinal_barrier_function
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5828281
#
# Query: en
# lookup term: en
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C118607
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# brain
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: small and large intestine
# lookup term: small_and_large_intestine
#   • Large Intestine                          URI=http://purl.obolibrary.org/obo/NCIT_C12379 score=0.86
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: prefrontal cortex
# lookup term: prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
#
# intestinal_barrier_function
# Query: intestinal barrier function
# lookup term: intestinal_barrier_function
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5828281
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: venous blood
# lookup term: venous_blood
#   • Venous Blood                             URI=http://purl.obolibrary.org/obo/NCIT_C78730 score=1.00
#
# Query: host s gastrointestinal tract
# lookup term: host_s_gastrointestinal_tract
#   • Gastrointestinal Tract                   URI=http://purl.obolibrary.org/obo/NCIT_C34082 score=0.76
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: perivascular space
# lookup term: perivascular_space
#   • Perivascular Space                       URI=http://purl.obolibrary.org/obo/NCIT_C83196 score=1.00
#
# meninges
# Query: meninges
# lookup term: meninges
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0025285
#
#
# Query: choroid plexu
# lookup term: choroid_plexu
#   • Choroid                                  URI=http://purl.obolibrary.org/obo/NCIT_C12344 score=1.00
#
# Query: head
# lookup term: head
#   • Head                                     URI=http://purl.obolibrary.org/obo/NCIT_C12419 score=1.00
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: mouth
# lookup term: mouth
#   • Nothing by Mouth                         URI=http://purl.obolibrary.org/obo/NCIT_C28250 score=1.00
#
# Query: abdomen
# lookup term: abdomen
#   • Abdomen                                  URI=http://purl.obolibrary.org/obo/NCIT_C12664 score=1.00
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: neuron
# lookup term: neuron
#   • Neuron                                   URI=http://purl.obolibrary.org/obo/NCIT_C12623 score=1.00
#
# Query: human body
# lookup term: human_body
#   → Reusing existing URI: http://purl.obolibrary.org/obo/FMA_20394
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# Query: human body
# lookup term: human_body
#   → Reusing existing URI: http://purl.obolibrary.org/obo/FMA_20394
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# gut
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: intestinal epithelium
# lookup term: intestinal_epithelium
#   • Intestinal Epithelium                    URI=http://purl.obolibrary.org/obo/NCIT_C49240 score=1.00
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: tissue
# lookup term: tissue
#   • Tissue Part                              URI=http://purl.obolibrary.org/obo/NCIT_C38625 score=1.00
#
# Query: gut tissue
# lookup term: gut_tissue
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/anatomicsite/GutTissue
#
#
# Query: gland
# lookup term: gland
#   • Gland                                    URI=http://purl.obolibrary.org/obo/NCIT_C13319 score=1.00
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# Query: prefrontal cortex
# lookup term: prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
#
# prefrontal_cortex
# Query: prefrontal cortex
# lookup term: prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# intestinal_(intended_site)
# Query: intestinal (intended site)
# lookup term: intestinal_(intended_site)
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5702674
#
# Query: intestine
# lookup term: intestine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12736
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# gut
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: vermiform appendix
# lookup term: vermiform_appendix
#   • Appendix                                 URI=http://purl.obolibrary.org/obo/NCIT_C12380 score=1.00
#
# Query: cecum
# lookup term: cecum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12381
#
#
# Query: appendix
# lookup term: appendix
#   • Appendix                                 URI=http://purl.obolibrary.org/obo/NCIT_C12380 score=1.00
#
# Query: appendix
# lookup term: appendix
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12380
#
#
# Query: ileum
# lookup term: ileum
#   • Ileum                                    URI=http://purl.obolibrary.org/obo/NCIT_C12387 score=1.00
#
# appendix
# Query: appendix
# lookup term: appendix
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12380
#
# Query: appendix
# lookup term: appendix
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12380
#
#
# Query: ileum
# lookup term: ileum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12387
#
#
# gut
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# Query: prefrontal cortex
# lookup term: prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
#
# prefrontal_cortex
# Query: prefrontal cortex
# lookup term: prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
# prefrontal_cortex
# Query: prefrontal cortex
# lookup term: prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: spinal cord
# lookup term: spinal_cord
#   • Spinal Cord Part                         URI=http://purl.obolibrary.org/obo/NCIT_C33969 score=1.00
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: intestine
# lookup term: intestine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12736
#
# brain
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# brain
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# mesencephalic_neoplasms
# Query: mesencephalic neoplasms
# lookup term: mesencephalic_neoplasms
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0751888
#
# Query: midbrain
# lookup term: midbrain
#   • Murine Midbrain                          URI=http://purl.obolibrary.org/obo/NCIT_C23444 score=0.88
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut epithelium
# lookup term: gut_epithelium
#   • Gut Epithelium                           URI=http://purl.obolibrary.org/obo/NCIT_C12963 score=1.00
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# brain
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: kidney
# lookup term: kidney
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34028
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: prefrontal cortex
# lookup term: prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# Query: medial prefrontal cortex
# lookup term: medial_prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
#
# medial_prefrontal_cortex_-_human
# Query: medial prefrontal cortex - human
# lookup term: medial_prefrontal_cortex_-_human
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3853912
#
# medial_prefrontal_cortex_-_human
# Query: medial prefrontal cortex - human
# lookup term: medial_prefrontal_cortex_-_human
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3853912
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# gut
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# gut
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# gut
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: medial prefrontal cortex
# lookup term: medial_prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
#
# medial_prefrontal_cortex_-_human
# Query: medial prefrontal cortex - human
# lookup term: medial_prefrontal_cortex_-_human
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3853912
#
# medial_prefrontal_cortex_-_human
# Query: medial prefrontal cortex - human
# lookup term: medial_prefrontal_cortex_-_human
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3853912
#
# medial_prefrontal_cortex_-_human
# Query: medial prefrontal cortex - human
# lookup term: medial_prefrontal_cortex_-_human
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3853912
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# Query: medial prefrontal cortex
# lookup term: medial_prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: prefrontal cortex
# lookup term: prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: liver
# lookup term: liver
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12392
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# gut
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# Query: liver
# lookup term: liver
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12392
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# vagal_nerve_structure
# Query: vagal nerve structure
# lookup term: vagal_nerve_structure
# no matches
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# gut
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# Query: ileum
# lookup term: ileum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12387
#
#
# Query: duodenum
# lookup term: duodenum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12263
#
#
# Query: liver
# lookup term: liver
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12392
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# Query: liver tissue
# lookup term: liver_tissue
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/anatomicsite/LiverTissue
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# Query: dietary polyphenol
# lookup term: dietary_polyphenol
#   • Dietary Polyphenol                       URI=http://purl.obolibrary.org/obo/NCIT_C70553 score=1.00
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# brain
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# brain
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# intestinal_(intended_site)
# Query: intestinal (intended site)
# lookup term: intestinal_(intended_site)
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5702674
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# entering dev
# brain
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# gut
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# Query: vn
# lookup term: vn
# no matches
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# vagus_nerve_structure
# Query: vagus nerve structure
# lookup term: vagus_nerve_structure
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042276
#
# vagal_nerve_structure
# Query: vagal nerve structure
# lookup term: vagal_nerve_structure
# no matches
# Query: striatum
# lookup term: striatum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12450
#
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# Query: striatum
# lookup term: striatum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12450
#
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# Query: striatum
# lookup term: striatum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12450
#
#
# Query: striatum
# lookup term: striatum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12450
#
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# Query: striatum
# lookup term: striatum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12450
#
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# Query: striatum
# lookup term: striatum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12450
#
#
# Query: striatum
# lookup term: striatum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12450
#
#
# intestinal_barrier_function
# Query: intestinal barrier function
# lookup term: intestinal_barrier_function
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5828281
#
# intestinal_barrier_function
# Query: intestinal barrier function
# lookup term: intestinal_barrier_function
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5828281
#
# Query: spinal cord
# lookup term: spinal_cord
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C33969
#
#
# Query: higher order brain structure
# lookup term: higher_order_brain_structure
#   • Higher Order Chromatin Structure         URI=http://purl.obolibrary.org/obo/NCIT_C13434 score=0.79
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# Query: brain area
# lookup term: brain_area
# no matches
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# Query: colon
# lookup term: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: intestinal epithelial layer
# lookup term: intestinal_epithelial_layer
# no matches
# nervous_system
# Query: nervous system
# lookup term: nervous_system
#   • Nervous                                  URI=http://purl.obolibrary.org/obo/NCIT_C25584 score=1.00
#
# Query: olfactory bulb
# lookup term: olfactory_bulb
#   • Olfactory Bulb                           URI=http://purl.obolibrary.org/obo/NCIT_C28401 score=1.00
#
# Query: forebrain
# lookup term: forebrain
#   • Forebrain                                URI=http://purl.obolibrary.org/obo/NCIT_C40185 score=1.00
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: midbrain
# lookup term: midbrain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C23444
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: prefrontal cortex
# lookup term: prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
#
# prefrontal_cortex
# Query: prefrontal cortex
# lookup term: prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
#
# gut
# Query: gut
# lookup term: gut
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0699819
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: central nervous system
# lookup term: central_nervous_system
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12438
#
#
# central_nervous_system
# Query: central nervous system
# lookup term: central_nervous_system
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12438
#
# Query: gastrointestinal tract
# lookup term: gastrointestinal_tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
#
# central_nervous_system
# Query: central nervous system
# lookup term: central_nervous_system
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12438
#
# Query: hypothalamu
# lookup term: hypothalamu
# no matches
# Query: peripheral gut
# lookup term: peripheral_gut
# no matches
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# brain
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
#
# Query: periphery
# lookup term: periphery
# no matches
# brain
# Query: brain
# lookup term: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: periphery
# lookup term: periphery
# no matches
# Query: periphery
# lookup term: periphery
# no matches
# hippocampus
# Query: hippocampus
# lookup term: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
#
# Query: medial prefrontal cortex
# lookup term: medial_prefrontal_cortex
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C154779
#
#
# Query: oral cavity
# lookup term: oral_cavity
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12421
#
#
# The RDF graph has been saved in c:\Users\samue\OneDrive\Desktop\ThesisPiron\rdf\gutbrain_entities.ttl

# %% [markdown]
# <h1>INGEST GENE</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint
from rdflib.namespace import DCTERMS
from groqutils import get_llm_definition
from funcutils import get_ncit_description, get_chebi_description, get_omit_description, NCBI_BASE, HEREDITARY_BASE, UMLS_BASES, foodon_file, ncit_file, omit_file, chebi_file, hash_term_sha256

GENE_BASE = "http://purl.obolibrary.org/obo/"
GENE_CLASS = URIRef("https://w3id.org/brainteaser/ontology/schema/Gene")
GENE_CONCEPT_SCHEME = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Gene")

def load_gene_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = GENE_BASE + term_id
            rows.append((label, uri))
    return rows

GENE_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncit_full_taxonomy.txt"
gene_rows = load_gene_labels(GENE_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in gene_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in gene_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

def top_cosine(term, k=5, thr=0.75):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = gene_rows[i]
        out.append((lbl, uri, sc[i]))
    return out
manual_created = {}
created = {}

manual_created = {
    "skin_lipid_metabolism_gene" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/gene/SkinLipidMetabolismGene"),
    "ppar-gamma" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0166417"),
    "srebp-1c" : URIRef("http://purl.obolibrary.org/obo/TFClass_human.obo#1.2.6.3.1.3"),
    "acaca_gene" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1412104"),
    "hormone-sensitive_lipase" : URIRef("http://purl.obolibrary.org/obo/PR_000009834"),
    "adipose_triglyceride_lipase" : URIRef("http://purl.obolibrary.org/obo/PR_000012942"),
    #"tumor_necrosis_factor-alpha" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1456820"),
    "glucose1pmetab-pwy" : URIRef("https://pubchem.ncbi.nlm.nih.gov/pathway/BioCyc:ECO_GLUCOSE1PMETAB-PWY"), 
    "maltose_catabolic_process":URIRef("http://purl.obolibrary.org/obo/GO_0000025"), 
    "l-fucose-proton_symporter":URIRef("http://purl.obolibrary.org/obo/PR_000022731"),
    "urease_accessory_proteins_uree" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/gene/UreaseAccessoryProteinsUree"),
    "camkiid_inhibitor_np202":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5690415"),
    "aromatic_aminotransferase":URIRef("https://www.kegg.jp/dbget-bin/www_bget?K00837"),
    "2-oxoglutarate_dehydrogenase_e2_component":URIRef("https://www.genome.jp/dbget-bin/www_bget?K00658"),                                     
    "tryptophan_synthase_beta_chain" : URIRef("https://www.genome.jp/dbget-bin/www_bget?K01696"),
    "dihydrolipoyl_dehydrogenase":URIRef("https://www.genome.jp/entry/K00382"),
    "acetyl-coa_c-acetyltransferase":URIRef("https://www.genome.jp/dbget-bin/www_bget?K00626"),
    "bacterial_16s_rrna_gene" :URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5380697"),
    "slc27a3_gene" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1420165"),
    "pnpla3": URIRef("http://purl.obolibrary.org/obo/OGG_3000080339"),
    "elovl6": URIRef("http://purl.obolibrary.org/obo/OMIT_0044699"),
    "5-ht(1dalpha)_receptor": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0534687"),
    "tight_junction_protein_1":URIRef("https://proconsortium.org/cgi-bin/entry_pro?id=PR_000016364"),
    "nycol_K01667": URIRef("http://prgdb.org/prgdb4/genes/type/putative/3183135"),
    "abhd5": URIRef("http://purl.obolibrary.org/obo/OGG_3000051099"),
    "csga_protein,_e_coli" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0210303"),
    "smadcam-1":URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/gene/Smadcam-1"),
    "major_histocompatibility_complex_gene" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1334545"),
    "lagr-1_gene":URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/gene/Lagr1Gene"),
    "asm-3_protein,_c_elegans": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C3659546"),
    "sptl-3": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/gene/Sptl3"),
    "mettl8_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1825978"),
    "proser3_gene":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1824496"),
    "aif1_gene" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1412299"),
    "alpha_syn_a53t": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/gene/AlphaSynA53t"),
    "trimethylamine": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0077172"),
    "soluble_guanylyl_cyclase": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1097411"),
    "tyramine_receptor_3,c_elegans": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C3181863"),
    "cfos_mrna": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/gene/CfosMrna"),
    "bdnf_mrna": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/gene/BdnfMrna"),
    "susceptibility/resistance_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0919542"),
    "rufy3_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1826955"),
    "chrna7_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1413406"),
    "gad1_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1414925"),
    "glutamate_synthase":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0017787"),
    "bacterial_16s_rrna_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5380697"),
    "htr3a_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1333933"),
    "htr4a_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1415813"),
    "intestinal_gene": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/gene/IntestinalGene"),
    "ba_gene": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/gene/BaGene"),
    "bai_cd": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/gene/BaiCd"),
    "human_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0314604"),
    "ephx2_gene":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1414433"),
    "daf-16_protein,_c_elegans": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1447582"),
    "siga_gene": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/gene/SigaGene"),
    "transforming_growth_factor_beta_1" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1704256"),
    "tnfaip3_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1420799"),
    "il10_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1334098"),
    "cxcl8_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1366571"),
    "ifng_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1334085"),
    "ccl2_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1337092"),
    "il6r_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1416409"),
    "il17a_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1825592"),
    "il6_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1334122"),
    "slc6a3_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1420213"),
    "th_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1420718"),
    "snca_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1420276"),
    "genes,_regulator": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0017362"),
    "inflammatory_gene": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/gene/InflammatoryGene"),
    "il1a_wt_allele": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1708430"),
    "il6_wt_allele": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1704829"),
    "tlr4_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1336636"),
    "smpd1_gene": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1420259"),

}

created = dict(manual_created)

regex_map = [
    (r"ppar-", "ppar-gamma"),
    (r"\bil-1\b","il1a_wt_allele"),
    (r"toll-like_receptor_4","tlr4_gene")
    (r"phosphorylated_-synuclein","snca_gene"),
    (r"barrier_regulating_gene","genes,_regulator"),
    (r"human_alpha-synuclein","snca_gene"),
    (r"\btyrosine_hydroxylase\b","th_gene"),
    (r"dopamine_transporter","slc6a3_gene"),
    (r"\bp--syn\b","snca_gene"),
    (r"\bdat\b","slc6a3_gene"),
    (r"\binterleukin-6\b","il6_wt_allele"),
    (r"\bil-8\b","cxcl8_gene"),
    (r"pro-inflammatory_cytokine","il1a_wt_allele"),
    (r"\bperipheral_il-6\b","il6_gene"),
    (r"\bil-6\b","il6_gene"),
    (r"\bil-17\b","il17a_gene"),
    (r"\bil-1ra\b","il6r_gene"),
    (r"\bifn-\b","ifng_gene"),
    (r"\bmcp-1\b","ccl2_gene"),
    (r"\bil-6\b","cxcl8_gene"),
    (r"\bsiga\b","siga_gene"),
    (r"\btgf-1\b","transforming_growth_factor_beta_1"),
    (r"\bdaf-16\b","daf-16_protein,_c_elegans"),
    (r"host_gene","human_gene"),
    (r"ba-inducible_gene","ba_gene"),
    (r"baicd_e_h","bai_cd"),
    (r"pd-causing_a53t_mutation","alpha_syn_a53t"),
    (r"\bgogat\b","glutamate_synthase"),
    (r"serotonin-related_intestinal_gene","intestinal_gene"),
    (r"\b5-htr3\b","htr3a_gene"),
    (r"\btnf-\b","tnfaip3_gene"),
    (r"\b5-htr4\b","htr4a_gene"),
    (r"bipolar_susceptibility_gene_trank1","trank1"),
    (r"16s_rrna_v3-v4_gene_region","bacterial_16s_rrna_gene"),
    (r"glutamate_decarboxylase__gad_-encoding_gene","gad1_gene"),
    (r"chrna7","chrna7_gene"),
    (r"pd_susceptibility_gene","susceptibility/resistance_gene"),
    (r"rs58010457","rufy3_gene"),
    (r"stress-evoked_cfos_mrna","cfos_mrna"),
    (r"basal_bdnf_mrna","bdnf_mrna"),
    (r"ionized_calcium-binding_adapter_molecule_1","aif1_gene"),
    (r"\basm-3\b","smpd1_gene"),
    (r"tyra-3","tyramine_receptor_3,c_elegans"),
    (r"-syn-a53t-cfp_yfp","alpha_syn_a53t"),
    (r"tyramine_receptor_tyra-3","trimethylamine"),
    (r"guanylyl_cyclase_daf-11","soluble_guanylyl_cyclase"),
    (r"tyra-3_daf-11","trimethylamine"),
    (r"proser3","proser3_gene"),
    (r"\bmettl8\b","mettl8_gene"),
    (r"sphingolipid_metabolism_genes_lagr-1","lagr-1_gene"),
    (r"asm-3","smpd1_gene"),
    (r"\bacc\b","acaca_gene"),
    (r"escherichia_coli_functional_amyloid_csga","csga_protein,_e_coli"),
    (r"\bcsga\b","csga_protein,_e_coli"),
    (r"csga_homolog","csga_protein,_e_coli"),
    (r"gut_bacterial_csga_homolog","csga_protein,_e_coli"),
    (r"mic","major_histocompatibility_complex_gene"),
    (r"hsl","hormone-sensitive_lipase"),
    (r"atgl","adipose_triglyceride_lipase"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))migraine_headache\b","migraine"),
    (r"skin_lipid_metabolism-related_gene" , "skin_lipid_metabolism_gene"),
    (r"TNFA","tnfaip3_gene"),
    (r"pwy-7328","glucose1pmetab-pwy"),
    (r"maltose_hydrolase", "maltose_catabolic_process"),
    (r"cog1554","maltose_catabolic_process"),
    (r"fucose_permease","l-fucose-proton_symporter"),
    (r"cog0738","l-fucose-proton_symporter"),
    (r"cog2371","urease_accessory_proteins_uree"),
    (r"camkiid","camkiid_inhibitor_np202"),
    (r"k00658","2-oxoglutarate_dehydrogenase_e2_component"),
    (r"k00837","aromatic_aminotransferase"),
    (r"k01696","tryptophan_synthase_beta_chain"),
    (r"k00382", "dihydrolipoyl_dehydrogenase"),
    (r"k00626","acetyl-coa_c-acetyltransferase"),
    (r"\bil-10\b","il10_gene"),
    (r"k01667","nycol_K01667"),
    (r"k03781","catalase"),
    (r"differential_expressed_gene","tissue-specific_gene_expression"),
    (r"deg","tissue-specific_gene_expression"),
    (r"gut_microbe-related_degs","tissue-specific_gene_expression"),
    (r"ccdc173","parafibromin"),
    (r"16s_rrna_gene","bacterial_16s_rrna_gene"),
    (r"microglia_activation-related_gene","microglia"),
    (r"fatty_acid_transport_gene","slc27a3_gene"),
    (r"5-ht_receptor_htr2a" ,"5-ht(1dalpha)_receptor"),
    (r"tight_junction_protein_claudin-5","tight_junction_protein_1"),
    (r"adipogenesi","adipogenesis"),
    (r"\bfasn\b","fasn_gene"),
    (r"\bhtr1a\b","htr1a_gene"),
    (r"\bsecretory_iga\b","secretory_immunoglobulin_a"),

]

CREATOR = "Samuel Piron"

UMLS_BASE = "https://uts.nlm.nih.gov/uts/umls/concept/"

for uri in manual_created.values():
    uri_str = str(uri)

    if uri_str.startswith(UMLS_BASE):
        # only a UMLS‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("UMLS Match", datatype=XSD.string)))
    elif "MMO" in uri_str:
        # only a STATO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("MNO Match", datatype=XSD.string)))
    elif "BAO" in uri_str:
        # only a BAO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("BAO Match", datatype=XSD.string)))
    elif "NCIT" in uri_str:
        # only a NCIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("NCIT Match", datatype=XSD.string)))
    elif "OMIT" in uri_str:
        # only a OMIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("OMIT Match", datatype=XSD.string)))
    elif "PR" in uri_str:
        # only a FMA‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("PR Match", datatype=XSD.string)))
    elif "TFClass" in uri_str:
        # only a TFClass‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("TFClass Match", datatype=XSD.string)))
    elif "GO" in uri_str:
        # only a GO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("GO Match", datatype=XSD.string)))
    elif "BioCyc" in uri_str:
        # only a BioCyc‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("BioCyc Match", datatype=XSD.string)))
    elif "kegg" in uri_str:
        # only a KEGG‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("KEGG Match", datatype=XSD.string)))
    elif "OGG" in uri_str:
        # only a OGG‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("OGG Match", datatype=XSD.string)))
    elif "genome" in uri_str:
        # only a Genome‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("KEGG Match", datatype=XSD.string)))
    else:
        # everything else still gets a creator
        g.add((uri,
               DCTERMS.creator,
               Literal(CREATOR, datatype=XSD.string)))
        
for term_raw, uri in manual_created.items():
    uri_str = str(uri)

    # NCIT definitions
    if uri_str.startswith(NCBI_BASE) and "NCIT_" in uri_str:
        ncit_id = uri_str.rsplit("_", 1)[-1]
        desc = get_ncit_description(ncit_id, ncit_file)
        m = re.search(r'—\s*(.*?)\s*—', desc)
        if m:
            desc = m.group(1).strip()
            comment = f"{desc} [Definition Source: NCIT]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # UMLS definitions
    elif uri_str.startswith(UMLS_BASES):
        cui = uri_str.rsplit("/", 1)[-1]
        defn = get_umls_definition(cui)
        if defn:
            comment = f"{defn.strip()} [Definition Source: UMLS]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # MeSH definitions via your mesh_index
    elif uri_str.startswith(MESH_BASE):
        ui     = uri_str.rsplit("/",1)[-1]
        hits   = [d['name'] for d in mesh_descs if d['ui']==ui]
        if hits:
            comment = f"{hits[0]} [Definition Source: MeSH]"
        elif term_raw == "patients":
            comment = "Patients with various diseases. [Definition Source: GUTBRAIN]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    elif uri_str.startswith(HEREDITARY_BASE):
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"
    else:
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    g.add((uri,
           RDFS.comment,
           Literal(comment, datatype=XSD.string)))
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "gene":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, GENE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, GENE_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, GENE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, GENE_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, GENE_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, GENE_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, GENE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, GENE_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

print("entering gold")

for paper_id, paper_data in data_gold.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "gene":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, GENE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, GENE_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, GENE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, GENE_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, GENE_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, GENE_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, GENE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, GENE_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

print("entering dev")

for paper_id, paper_data in data_dev.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "gene":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, GENE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, GENE_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, GENE_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, GENE_CONCEPT_SCHEME))
                g.add((entity_uri, RDFS.label, Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, GENE_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, GENE_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, GENE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, GENE_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "gene":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_gold_file, "r", encoding="utf-8") as f_sent:
    tokenized_gold_data = json.load(f_sent)

for entry in tokenized_gold_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "gene":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_dev, "r", encoding="utf-8") as f_sent:
    tokenized_dev_data = json.load(f_sent)

for entry in tokenized_dev_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "gene":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

output_file = os.path.join(save_path, "gutbrain_entities.ttl")
ttl_output = g.serialize(format="turtle")
with open(output_file, "w", encoding="utf-8") as f_out:
    f_out.write(ttl_output)

print(f"The RDF graph has been saved in {output_file}")
# Out:
# skin_lipid_metabolism_gene
# Query: skin lipid metabolism gene
# lookup term: skin_lipid_metabolism_gene
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/gene/SkinLipidMetabolismGene
#
# ppar-gamma
# Query: ppar-gamma
# lookup term: ppar-gamma
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0166417
#
# Query: srebp-1c
# lookup term: srebp-1c
#   → Reusing existing URI: http://purl.obolibrary.org/obo/TFClass_human.obo#1.2.6.3.1.3
#
#
# acaca_gene
# Query: acaca gene
# lookup term: acaca_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1412104
#
# fasn_gene
# Query: fasn gene
# lookup term: fasn_gene
#   • FASN Gene                                URI=http://purl.obolibrary.org/obo/NCIT_C26564
# ppar-gamma
# Query: ppar-gamma
# lookup term: ppar-gamma
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0166417
#
# Query: acox1
# lookup term: acox1
#   • ACOX1 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C191889 score=0.95
#
# hormone-sensitive_lipase
# Query: hormone-sensitive lipase
# lookup term: hormone-sensitive_lipase
#   → Reusing existing URI: http://purl.obolibrary.org/obo/PR_000009834
#
# adipose_triglyceride_lipase
# Query: adipose triglyceride lipase
# lookup term: adipose_triglyceride_lipase
#   → Reusing existing URI: http://purl.obolibrary.org/obo/PR_000012942
#
# skin_lipid_metabolism_gene
# Query: skin lipid metabolism gene
# lookup term: skin_lipid_metabolism_gene
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/gene/SkinLipidMetabolismGene
#
# ppar-gamma
# Query: ppar-gamma
# lookup term: ppar-gamma
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0166417
#
# Query: srebp-1c
# lookup term: srebp-1c
#   → Reusing existing URI: http://purl.obolibrary.org/obo/TFClass_human.obo#1.2.6.3.1.3
#
#
# fasn_gene
# Query: fasn gene
# lookup term: fasn_gene
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26564
#
#
# adipose_triglyceride_lipase
# Query: adipose triglyceride lipase
# lookup term: adipose_triglyceride_lipase
#   → Reusing existing URI: http://purl.obolibrary.org/obo/PR_000012942
#
# Query: trem2
# lookup term: trem2
#   • TREM2 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C125468 score=0.94
#
# Query: c3
# lookup term: c3
#   • C3 Gene                                  URI=http://purl.obolibrary.org/obo/NCIT_C21521 score=0.92
#
# Query: c3ar1
# lookup term: c3ar1
#   • C3AR1 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C182144 score=0.95
#
# tumor_necrosis_factor-alpha
# Query: tumor necrosis factor-alpha
# lookup term: tumor_necrosis_factor-alpha
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1456820
#
# Query: nf-kb
# lookup term: nf-kb
#   • NF-kB                                    URI=http://purl.obolibrary.org/obo/NCIT_C17380
# Query: tgfb1 2
# lookup term: tgfb1_2
#   • TGFB1 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C24856 score=0.94
#
# Query: sirt1 6
# lookup term: sirt1_6
#   • SIRT1 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C80113 score=0.95
#
# Query: hmgb1
# lookup term: hmgb1
#   • HMGB1 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C20578 score=0.94
#
# Query: sting
# lookup term: sting
#   • STING Agonist                            URI=http://purl.obolibrary.org/obo/NCIT_C176586 score=0.77
#
# glucose1pmetab-pwy
# Query: glucose1pmetab-pwy
# lookup term: glucose1pmetab-pwy
#   → Reusing existing URI: https://pubchem.ncbi.nlm.nih.gov/pathway/BioCyc:ECO_GLUCOSE1PMETAB-PWY
#
# Query: trehalose
# lookup term: trehalose
#   • Trehalose                                URI=http://purl.obolibrary.org/obo/NCIT_C87705
# maltose_catabolic_process
# Query: maltose catabolic process
# lookup term: maltose_catabolic_process
#   → Reusing existing URI: http://purl.obolibrary.org/obo/GO_0000025
#
# maltose_catabolic_process
# Query: maltose catabolic process
# lookup term: maltose_catabolic_process
#   → Reusing existing URI: http://purl.obolibrary.org/obo/GO_0000025
#
# l-fucose-proton_symporter
# Query: l-fucose-proton symporter
# lookup term: l-fucose-proton_symporter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/PR_000022731
#
# l-fucose-proton_symporter
# Query: l-fucose-proton symporter
# lookup term: l-fucose-proton_symporter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/PR_000022731
#
# Query: urease accessory proteins uree
# lookup term: urease_accessory_proteins_uree
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/gene/UreaseAccessoryProteinsUree
#
#
# urease_accessory_proteins_uree
# Query: urease accessory proteins uree
# lookup term: urease_accessory_proteins_uree
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/gene/UreaseAccessoryProteinsUree
#
# camkiid_inhibitor_np202
# Query: camkiid inhibitor np202
# lookup term: camkiid_inhibitor_np202
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5690415
#
# 2-oxoglutarate_dehydrogenase_e2_component
# Query: 2-oxoglutarate dehydrogenase e2 component
# lookup term: 2-oxoglutarate_dehydrogenase_e2_component
#   → Reusing existing URI: https://www.genome.jp/dbget-bin/www_bget?K00658
#
# aromatic_aminotransferase
# Query: aromatic aminotransferase
# lookup term: aromatic_aminotransferase
#   → Reusing existing URI: https://www.kegg.jp/dbget-bin/www_bget?K00837
#
# tryptophan_synthase_beta_chain
# Query: tryptophan synthase beta chain
# lookup term: tryptophan_synthase_beta_chain
#   → Reusing existing URI: https://www.genome.jp/dbget-bin/www_bget?K01696
#
# dihydrolipoyl_dehydrogenase
# Query: dihydrolipoyl dehydrogenase
# lookup term: dihydrolipoyl_dehydrogenase
#   → Reusing existing URI: https://www.genome.jp/entry/K00382
#
# acetyl-coa_c-acetyltransferase
# Query: acetyl-coa c-acetyltransferase
# lookup term: acetyl-coa_c-acetyltransferase
#   → Reusing existing URI: https://www.genome.jp/dbget-bin/www_bget?K00626
#
# nycol_K01667
# Query: nycol k01667
# lookup term: nycol_K01667
#   → Reusing existing URI: http://prgdb.org/prgdb4/genes/type/putative/3183135
#
# catalase
# Query: catalase
# lookup term: catalase
#   • Catalase                                 URI=http://purl.obolibrary.org/obo/NCIT_C61062
# Query: hba1
# lookup term: hba1
#   • HBA1 Gene                                URI=http://purl.obolibrary.org/obo/NCIT_C75429 score=0.95
#
# Query: 16s ribosomal rna gene
# lookup term: 16s_ribosomal_rna_gene
#   • 16S Mitochondrial Ribosomal RNA          URI=http://purl.obolibrary.org/obo/NCIT_C131261 score=0.88
#
# tissue-specific_gene_expression
# Query: tissue-specific gene expression
# lookup term: tissue-specific_gene_expression
#   • Tissue-Specific Gene Expression          URI=http://purl.obolibrary.org/obo/NCIT_C19563
# tissue-specific_gene_expression
# Query: tissue-specific gene expression
# lookup term: tissue-specific_gene_expression
#   • Tissue-Specific Gene Expression          URI=http://purl.obolibrary.org/obo/NCIT_C19563
# major_histocompatibility_complex_gene
# Query: major histocompatibility complex gene
# lookup term: major_histocompatibility_complex_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1334545
#
# Query: creb3l3
# lookup term: creb3l3
#   • CREB3L3 Gene                             URI=http://purl.obolibrary.org/obo/NCIT_C95485 score=0.95
#
# parafibromin
# Query: parafibromin
# lookup term: parafibromin
#   • Parafibromin                             URI=http://purl.obolibrary.org/obo/NCIT_C43572
# bacterial_16s_rrna_gene
# Query: bacterial 16s rrna gene
# lookup term: bacterial_16s_rrna_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5380697
#
#
# htr1a_gene
# Query: htr1a gene
# lookup term: htr1a_gene
#   • HTR1A Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C105868
# htr1a_gene
# Query: htr1a gene
# lookup term: htr1a_gene
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C105868
#
#
# htr1a_gene
# Query: htr1a gene
# lookup term: htr1a_gene
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C105868
#
#
# Query: apolipoprotein b
# lookup term: apolipoprotein_b
#   • Apolipoprotein A-V                       URI=http://purl.obolibrary.org/obo/NCIT_C190089 score=1.00
#
# bacterial_16s_rrna_gene
# Query: bacterial 16s rrna gene
# lookup term: bacterial_16s_rrna_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5380697
#
# major_histocompatibility_complex_gene
# Query: major histocompatibility complex gene
# lookup term: major_histocompatibility_complex_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1334545
#
# slc27a3_gene
# Query: slc27a3 gene
# lookup term: slc27a3_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1420165
#
# Query: abhd5
# lookup term: abhd5
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OGG_3000051099
#
#
# adipogenesis
# Query: adipogenesis
# lookup term: adipogenesis
#   • Adipogenesis                             URI=http://purl.obolibrary.org/obo/NCIT_C20906
# Query: me1
# lookup term: me1
#   • ME1 Gene                                 URI=http://purl.obolibrary.org/obo/NCIT_C127139 score=0.94
#
# fasn_gene
# Query: fasn gene
# lookup term: fasn_gene
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26564
#
#
# Query: pnpla3
# lookup term: pnpla3
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OGG_3000080339
#
#
# Query: elovl6
# lookup term: elovl6
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0044699
#
#
# Query: peroxisome proliferator-activated receptor gamma  pparg  gene
# lookup term: peroxisome_proliferator-activated_receptor_gamma__pparg__gene
#   • Peroxisome Proliferator-Activated Receptor Gamma URI=http://purl.obolibrary.org/obo/NCIT_C34077 score=0.85
#
# 5-ht(1dalpha)_receptor
# Query: 5-ht(1dalpha) receptor
# lookup term: 5-ht(1dalpha)_receptor
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0534687
#
# bacterial_16s_rrna_gene
# Query: bacterial 16s rrna gene
# lookup term: bacterial_16s_rrna_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5380697
#
# tight_junction_protein_1
# Query: tight junction protein 1
# lookup term: tight_junction_protein_1
#   → Reusing existing URI: https://proconsortium.org/cgi-bin/entry_pro?id=PR_000016364
#
# entering gold
# csga_protein,_e_coli
# Query: csga protein, e coli
# lookup term: csga_protein,_e_coli
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0210303
#
# csga_protein,_e_coli
# Query: csga protein, e coli
# lookup term: csga_protein,_e_coli
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0210303
#
# csga_protein,_e_coli
# Query: csga protein, e coli
# lookup term: csga_protein,_e_coli
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0210303
#
# csga_protein,_e_coli
# Query: csga protein, e coli
# lookup term: csga_protein,_e_coli
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0210303
#
# csga_protein,_e_coli
# Query: csga protein, e coli
# lookup term: csga_protein,_e_coli
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0210303
#
# csga_protein,_e_coli
# Query: csga protein, e coli
# lookup term: csga_protein,_e_coli
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0210303
#
# Query: caspase-1
# lookup term: caspase-1
#   • Caspase-1                                URI=http://purl.obolibrary.org/obo/NCIT_C18045
# Query: nlrp3
# lookup term: nlrp3
#   • NLRP3 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C77202 score=0.94
#
# Query: striatal tyrosine hydroxylase
# lookup term: striatal_tyrosine_hydroxylase
#   • Tyrosine Hydroxylase Inhibitor           URI=http://purl.obolibrary.org/obo/NCIT_C2155 score=0.90
#
# Query: th
# lookup term: th
#   • TH Gene                                  URI=http://purl.obolibrary.org/obo/NCIT_C127894 score=0.94
#
# Query: nlrp3
# lookup term: nlrp3
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C77202
#
#
# Query: nlrc4
# lookup term: nlrc4
#   • NLRC4 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C175710 score=0.94
#
# Query: smadcam-1
# lookup term: smadcam-1
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/gene/Smadcam-1
#
#
# Query: nlrc4
# lookup term: nlrc4
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C175710
#
#
# major_histocompatibility_complex_gene
# Query: major histocompatibility complex gene
# lookup term: major_histocompatibility_complex_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1334545
#
# Query: nlrp3
# lookup term: nlrp3
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C77202
#
#
# daf-16_protein,_c_elegans
# Query: daf-16 protein, c elegans
# lookup term: daf-16_protein,_c_elegans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1447582
#
# lagr-1_gene
# Query: lagr-1 gene
# lookup term: lagr-1_gene
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/gene/Lagr1Gene
#
# asm-3_protein,_c_elegans
# Query: asm-3 protein, c elegans
# lookup term: asm-3_protein,_c_elegans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3659546
#
# Query: sptl-3
# lookup term: sptl-3
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/gene/Sptl3
#
#
# Query: bacterial gene
# lookup term: bacterial_gene
#   • Bacterial Protein                        URI=http://purl.obolibrary.org/obo/NCIT_C16319 score=0.79
#
# mettl8_gene
# Query: mettl8 gene
# lookup term: mettl8_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1825978
#
# Query: itgb2
# lookup term: itgb2
#   • ITGB2 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C21263 score=0.94
#
# Query: otulin
# lookup term: otulin
#   • OTULIN Gene                              URI=http://purl.obolibrary.org/obo/NCIT_C176454 score=0.94
#
# proser3_gene
# Query: proser3 gene
# lookup term: proser3_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1824496
#
# Query: serpina5
# lookup term: serpina5
#   • SERPINA5 Gene                            URI=http://purl.obolibrary.org/obo/NCIT_C39654 score=0.95
#
# aif1_gene
# Query: aif1 gene
# lookup term: aif1_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1412299
#
# Query: toll-like receptor 2
# lookup term: toll-like_receptor_2
#   • Toll-Like Receptor 2                     URI=http://purl.obolibrary.org/obo/NCIT_C30102
# Query: toll-like receptor 4
# lookup term: toll-like_receptor_4
#   • Toll-Like Receptor 4                     URI=http://purl.obolibrary.org/obo/NCIT_C30105
# alpha_syn_a53t
# Query: alpha syn a53t
# lookup term: alpha_syn_a53t
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/gene/AlphaSynA53t
#
# tyramine_receptor_3,c_elegans
# Query: tyramine receptor 3,c elegans
# lookup term: tyramine_receptor_3,c_elegans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3181863
#
# tyramine_receptor_3,c_elegans
# Query: tyramine receptor 3,c elegans
# lookup term: tyramine_receptor_3,c_elegans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3181863
#
# soluble_guanylyl_cyclase
# Query: soluble guanylyl cyclase
# lookup term: soluble_guanylyl_cyclase
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1097411
#
# tyramine_receptor_3,c_elegans
# Query: tyramine receptor 3,c elegans
# lookup term: tyramine_receptor_3,c_elegans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3181863
#
# cfos_mrna
# Query: cfos mrna
# lookup term: cfos_mrna
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/gene/CfosMrna
#
# bdnf_mrna
# Query: bdnf mrna
# lookup term: bdnf_mrna
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/gene/BdnfMrna
#
# Query: alpha-synuclein locu
# lookup term: alpha-synuclein_locu
#   • Alpha-Synuclein                          URI=http://purl.obolibrary.org/obo/NCIT_C90119 score=1.00
#
# Query: alpha-synuclein locu
# lookup term: alpha-synuclein_locu
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C90119
#
#
# susceptibility/resistance_gene
# Query: susceptibility/resistance gene
# lookup term: susceptibility/resistance_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0919542
#
# rufy3_gene
# Query: rufy3 gene
# lookup term: rufy3_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1826955
#
# chrna7_gene
# Query: chrna7 gene
# lookup term: chrna7_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1413406
#
# gad1_gene
# Query: gad1 gene
# lookup term: gad1_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1414925
#
# Query: glutamate synthase
# lookup term: glutamate_synthase
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0017787
#
#
# glutamate_synthase
# Query: glutamate synthase
# lookup term: glutamate_synthase
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0017787
#
# Query: trem2
# lookup term: trem2
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C125468
#
#
# Query: cx3cr1
# lookup term: cx3cr1
#   • CX3CR1 Gene                              URI=http://purl.obolibrary.org/obo/NCIT_C24326 score=0.95
#
# Query: ephb6
# lookup term: ephb6
#   • EPHB6 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C150223 score=0.95
#
# Query: ephb6
# lookup term: ephb6
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C150223
#
#
# Query: ephb6
# lookup term: ephb6
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C150223
#
#
# Query: ephx2 gene
# lookup term: ephx2_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1414433
#
#
# trank1
# Query: trank1
# lookup term: trank1
#   • TRANK1 Gene                              URI=http://purl.obolibrary.org/obo/NCIT_C189683 score=0.95
#
# Query: trank1
# lookup term: trank1
#   • TRANK1 Gene                              URI=http://purl.obolibrary.org/obo/NCIT_C189683 score=0.95
#
# Query: bipolar gene trank1
# lookup term: bipolar_gene_trank1
#   • TRANK1 Gene                              URI=http://purl.obolibrary.org/obo/NCIT_C189683 score=0.80
#
# Query: trank1
# lookup term: trank1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C189683
#
#
# bacterial_16s_rrna_gene
# Query: bacterial 16s rrna gene
# lookup term: bacterial_16s_rrna_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5380697
#
# alpha_syn_a53t
# Query: alpha syn a53t
# lookup term: alpha_syn_a53t
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/gene/AlphaSynA53t
#
# Query: tph1
# lookup term: tph1
#   • TPH1 Gene                                URI=http://purl.obolibrary.org/obo/NCIT_C105871 score=0.95
#
# Query: slc6a4
# lookup term: slc6a4
#   • SLC6A4 Gene                              URI=http://purl.obolibrary.org/obo/NCIT_C105874 score=0.95
#
# htr3a_gene
# Query: htr3a gene
# lookup term: htr3a_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1333933
#
# htr4a_gene
# Query: htr4a gene
# lookup term: htr4a_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C1415813
#
# intestinal_gene
# Query: intestinal gene
# lookup term: intestinal_gene
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/gene/IntestinalGene
#
# ba_gene
# Query: ba gene
# lookup term: ba_gene
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/gene/BaGene
#
# bai_cd
# Query: bai cd
# lookup term: bai_cd
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/gene/BaiCd
#
# human_gene
# Query: human gene
# lookup term: human_gene
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0314604
#
# entering dev
# Query: secretory iga
# lookup term: secretory_iga
# no matches
# Query: siga
# lookup term: siga
# no matches
# Query: tgf-1
# lookup term: tgf-1
# no matches
# Query: tnf-
# lookup term: tnf-
#   • TNF Gene                                 URI=http://purl.obolibrary.org/obo/NCIT_C18368 score=0.92
#
# Query: il-10
# lookup term: il-10
# no matches
# Query: il-8
# lookup term: il-8
#   • Will County, IL                          URI=http://purl.obolibrary.org/obo/NCIT_C108381 score=0.83
#
# Query: il-6
# lookup term: il-6
#   • Will County, IL                          URI=http://purl.obolibrary.org/obo/NCIT_C108381 score=0.83
#
# Query: ifn-
# lookup term: ifn-
# no matches
# Query: mcp-1
# lookup term: mcp-1
# no matches
# Query: il-1ra
# lookup term: il-1ra
#   • Will County, IL                          URI=http://purl.obolibrary.org/obo/NCIT_C108381 score=0.83
#
# Query: il-1
# lookup term: il-1
#   • Will County, IL                          URI=http://purl.obolibrary.org/obo/NCIT_C108381 score=0.83
#
# Query: il-17
# lookup term: il-17
# no matches
# Query: il-6
# lookup term: il-6
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C108381
#
#
# Query: ifn-
# lookup term: ifn-
# no matches
# Query: mcp-1
# lookup term: mcp-1
# no matches
# Query: tgf-1
# lookup term: tgf-1
# no matches
# Query: tnf-
# lookup term: tnf-
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C18368
#
#
# Query: il-8
# lookup term: il-8
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C108381
#
#
# Query: il-6
# lookup term: il-6
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C108381
#
#
# Query: ifn-
# lookup term: ifn-
# no matches
# Query: mcp-1
# lookup term: mcp-1
# no matches
# Query: tgf-1
# lookup term: tgf-1
# no matches
# Query: dopamine transporter
# lookup term: dopamine_transporter
#   • Dopamine Transporter Deficiency Syndrome URI=http://purl.obolibrary.org/obo/NCIT_C129866 score=0.82
#
# Query: dat
# lookup term: dat
#   • DAT Regimen                              URI=http://purl.obolibrary.org/obo/NCIT_C67206 score=0.91
#
# Query: tyrosine hydroxylase
# lookup term: tyrosine_hydroxylase
#   • Tyrosine Hydroxylase Inhibitor           URI=http://purl.obolibrary.org/obo/NCIT_C2155 score=0.90
#
# Query: th
# lookup term: th
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C127894
#
#
# Query: phosphorylated -synuclein
# lookup term: phosphorylated_-synuclein
# no matches
# Query: p--syn
# lookup term: p--syn
#   • FULL_SYN                                 URI=http://purl.obolibrary.org/obo/NCIT_C43684 score=1.00
#
# Query: th
# lookup term: th
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C127894
#
#
# Query: p--syn
# lookup term: p--syn
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C43684
#
#
# Query: th
# lookup term: th
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C127894
#
#
# Query: barrier regulating gene
# lookup term: barrier_regulating_gene
# no matches
# Query: human alpha-synuclein
# lookup term: human_alpha-synuclein
#   • Alpha-Synuclein                          URI=http://purl.obolibrary.org/obo/NCIT_C90119 score=0.89
#
# Query: human snca gene
# lookup term: human_snca_gene
#   • SNCA Gene                                URI=http://purl.obolibrary.org/obo/NCIT_C90101 score=0.88
#
# Query: inflammatory gene
# lookup term: inflammatory_gene
#   • Inflammatory                             URI=http://purl.obolibrary.org/obo/NCIT_C25535 score=0.90
#
# Query: pro-inflammatory cytokine
# lookup term: pro-inflammatory_cytokine
# no matches
# Query: interleukin-6
# lookup term: interleukin-6
#   • Interleukin-6                            URI=http://purl.obolibrary.org/obo/NCIT_C20451
# Query: il-6
# lookup term: il-6
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C108381
#
#
# Query: peripheral il-6
# lookup term: peripheral_il-6
# no matches
# The RDF graph has been saved in c:\Users\samue\OneDrive\Desktop\ThesisPiron\rdf\gutbrain_entities.ttl

# %% [markdown]
# <h1>INGEST DDF</h1>

# %%
import re
import json
import numpy as np
import requests
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint
from rdflib.namespace import DCTERMS
from groqutils import get_llm_definition
from umlsutils import best_umls_match, search_umls, get_umls_definition
from funcutils import get_ncit_description, get_chebi_description, get_omit_description, NCBI_BASE, HEREDITARY_BASE, UMLS_BASES, foodon_file, ncit_file, omit_file, chebi_file, hash_term_sha256

DDF_BASE = "http://purl.obolibrary.org/obo/"
DDF_CLASS = URIRef("https://w3id.org/brainteaser/ontology/schema/DiseaseDisorderOrFinding")
DDF_CONCEPT_SCHEME = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/DiseaseDisorderOrFinding")

def load_ddf_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = DDF_BASE + term_id
            rows.append((label, uri))
    return rows

OMIT_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\omit_full_taxonomy.txt"
DDF_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncit_full_taxonomy.txt"
ddf_rows = load_ddf_labels(DDF_LABELS_FILE)
omit_rows = load_ddf_labels(OMIT_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in ddf_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

exact_ix1 = defaultdict(list)
for lbl, uri in omit_rows:
    exact_ix1[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in ddf_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

labels_only1 = [preprocess(lbl) for lbl, _ in omit_rows]
vec1 = TfidfVectorizer(stop_words="english")
mat1 = vec1.fit_transform(labels_only1)

manual_created = {
    "neuropsychiatric_disorders" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeuropsychiatricDisorders"),
    "oleic_acid-induced_acne" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/OleicAcidInducedAcne"),
    "neurodegenerative_diseases" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeurodegenerativeDiseases"),
    "nervous_system_disorder" : URIRef("http://purl.obolibrary.org/obo/NCIT_C26835"),
    "inflammatory_disease" : URIRef("http://purl.obolibrary.org/obo/MONDO_0021166"),
    "cancer" : URIRef("http://purl.obolibrary.org/obo/NCBITaxon_6754"),
    "neurodegeneration" : URIRef("http://purl.obolibrary.org/obo/MP_0002229"),
    "intestinal_dysbiosis" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4287543"),
    "brain_diseases": URIRef("http://purl.obolibrary.org/obo/OMIT_0003283"),
    "functional_gastric_disease": URIRef("http://purl.obolibrary.org/obo/MONDO_0001318"),
    "functional_gastrointestinal_disorders" : URIRef("https://bioportal.bioontology.org/ontologies/EDAM?p=classes&conceptid=topic_3409"),
    "synucleinopathies" : URIRef("http://purl.obolibrary.org/obo/MONDO_0000510"),
    "hippocampal_volume_loss,_mild" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C5394342"),
    "gastric_mucins" : URIRef("https://meshb.nlm.nih.gov/record/ui?ui=D005752"),
    "gastric_disease" : URIRef("http://purl.obolibrary.org/obo/MONDO_0004298"),
    "neurodegenerative_disorders" : URIRef("http://purl.obolibrary.org/obo/NCIT_C39737"),
    "headaches" : URIRef("http://purl.obolibrary.org/obo/NCIT_C34661"),
    "disorder" : URIRef("http://purl.obolibrary.org/obo/OGMS_0000045"),
    "neuronitis": URIRef("http://purl.obolibrary.org/obo/MONDO_0004466"),
    "endolysosomal_deficits" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/EndolysosomalDeficits"),
    "coeliac_disease" : URIRef("https://disease-ontology.org/?id=DOID:10608"),
    "intestinal_malabsorption" : URIRef("https://hpo.jax.org/browse/term/HP:0002024"),
    "cell_danger_response": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/CellDangerResponse"),
    "intestinal_dysbiosis" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4287543"),
    "migraine" : URIRef("http://purl.obolibrary.org/obo/NCIT_C89715"),
    "cognitive_impairment" : URIRef("http://purl.obolibrary.org/obo/NCIT_C116921"),
    "attention_deficit_hyperactivity_disorder": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1263846"),
    "amyotrophic_lateral_scleroris" : URIRef("http://purl.obolibrary.org/obo/NCIT_C34373"),
    "antipsychotic-generated_motility_effects" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/AntipsychoticGeneratedMotilityEffects"),
    "neurometabolic_alterations" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeurometabolicAlterations"),
    "gastrointestinal_and_mental_health_symptoms" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/GastrointestinalAndMentalHealthSymptoms"),
    "postinfection_disorders" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/PostinfectionDisorders"),
    "alterations_in_the_enteroendocrine_system" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/AlterationsInTheEnteroendocrineSystem"),
    "altered_gut_microbiota" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/AlteredGutMicrobiota"),
    "mental_disorders" : URIRef("http://purl.obolibrary.org/obo/OMIT_0002893"),
    "abnormal_blood_levels" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/AbnormalBloodLevels"),
    "alzheimers_disease" : URIRef("http://purl.obolibrary.org/obo/NCIT_C2866"),
    "amyotrophic_lateral_sclerosis" : URIRef("http://purl.obolibrary.org/obo/NCIT_C34373"),
    "intestinal_alteration" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/IntestinalAlteration"),
    "colorectal_cancer" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0009402"),
    "irritable_bowel_syndrome" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0022104"),
    "polycistic_ovary_syndrome" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0032460"),
    "altered_intestinal_microbiome" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/AlteredIntestinalMicrobiome"),
    "salsolinol-induced_toxicity": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/SalsolinolInducedToxicity"),
    "increasing_antibiotic_resistance": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/IncreasingAntibioticResistance"),
    "deleterious_metabolic_effect":URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/DeleteriousMetabolicEffect"),
    "immunosuppression": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C4048329"),


}

created = dict(manual_created)

regex_map = [
    (r"\bdepressive_symptoms\b", "major_depressive_disorder"),
    (r"\badolescence_inflammatory_stres\w*\b","inflammatory_disease"),
    (r"\bpubertal_neuroinflammatory_insult\w*\b","inflammatory_disease"),
    (r"\bnas-mediated_deleterious_metabolic_effect\w*\b","deleterious_metabolic_effect"),
    (r"\bpolycystic_ovarian_syndrome\b", "polycystic_ovary_syndrome"),
    (r"\bbipolar_disorders\b", "bipolar_disorder"),
    (r"\bneurocognitive_dysfunction\b","cognitive_impairment"),
    (r"crc_onset_and_progression","colorectal_cancer"),
    (r"\bcancerous_lesion\w*\b","lesion"),
    (r"\bmetabolic_disease\b","disease"),
    (r"\bocular_condition\w*\b","disease"),
    (r"\bdry_eye_discomfort\b","discomfort"),
    (r"\bpss\b","primary_sjogren_s_syndrome"),
    (r"\bpss-mediated_dry_eye\b","primary_sjogren_s_syndrome"),
    (r"\bnas-induced_dysbiosi\w*\b","dysbiosis"),
    (r"\bibds\b","inflammatory_bowel_diseases"),
    (r"\bdyssynergic_contraction\w*\b","contraction_(finding)"),
    (r"\bcomplex_chronic_inflammatory_disorder\w*\b","inflammatory_disorder"),
    (r"dex-induced_depression","depression"),
    (r"\bpd_symptom\w*\b","parkinson_disease"),
    (r"\bgut_symptomw*\b","irritable_bowel_syndrome"),
    (r"\bbowel_symptom\w*\b","irritable_bowel_syndrome"),
    (r"\bulcer_stomach_and_intestine\w*\b","ulcer"),
    (r"\bsalsolionl__sals_-induced_toxicity\b","salsolinol-induced_toxicity"),
    (r"\bdyskinetic_side_effect\w*\b","dyskinetic_syndrome"),
    (r"human_depression","depression"),
    (r"\bmood_and_anxiety_disorder\w*\b","mood_disorder"),
    (r"\bcum\w*\b","stress"),
    (r"\bdepression-like_phenotype\w*\b","depression"),
    (r"\bsevere_depression-like_behaviour\w*\b","depression"),
    (r"cums-induced_depression","depression"),
    (r"\bexcessive_immunosuppression_with_damaged_neuronal_synapse\w*\b","immunosuppression"),
    (r"\bprogressive_memory_los\w*\b","memory_loss"),
    (r"\bsars-cov2\b", "sars"),
    (r"\banxiety_depression\b", "mixed_anxiety_and_depressive_disorder"),
    (r"gastrointestinal_and_mental_health_symptoms","gastrointestinal_and_mental_health_symptoms"),
    (r"non-celiac_food_sensitivities","coeliac_disease"),
    (r"\bdementia\w*\b","dementia"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))migraine_headache\b","migraine"),
    (r"\bt1d\b","Type_1_Diabetes_Mellitus"),
    (r"gut_microbiome_changes", "altered_gut_microbiota"),
    (r"\bmental_health_issue\b","mental_health"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))gut_dysfunction","dysfunction"),
    (r"cognitive_or_motor_dysfunction", "dysfunction"),
    (r"gut_microbiota_disorder","disorder"),
    (r"age-related_neurodegeneration","neurodegeneration"),
    (r"low-grade_inflammation_and_anomalies","inflammation"),
    (r"viral_respiratory_infections","respiratory_tract_infections"),
    (r"respiratory_infections","respiratory_tract_infections"),
    (r"inflammatory_conditions","inflammation"),
    (r"chemotherapy-associated_psychological_distress","distress"),
    (r"stage_i_disease","disease"),
    (r"central_and_peripheral_inflammation","inflammation"),
    (r"neuronal_disorders","disorder"),
    (r"brain_mental-health-related_disease", "disease"),
    (r"autoimmune_central_nervous_system_disease","disease"),
    (r"ms_condition","multiple_sclerosis"),
    (r"psychiatric_clinical_symptoms","symptom"),
    (r"states_of_dysmetabolism","dysmetabolic_syndrome"),
    (r"anxiety-like_behaviors","anxiety"),
    (r"jejunal_expression_of_pro-inflammatory_markers", "elevated_inflammatory_markers"),
    (r"inflammatory-__autoimmune-__neurodegenerative-__metabolic-__mood-__behavioral-__cognitive-__autism-spectrum-__stress-_and_pain-related_disorders","disorder"),
    (r"motor_symptoms","symptom"),
    (r"olfaction_dysfunction","dysfunction"),
    (r"systemic_disorders","disorder"),
    (r"mental_health_symptoms","symptom"),
    (r"microbiota_gut_brain_dysfunction","dysfunction"),
    (r"anxiety_depression_symptom","symptom"),
    (r"clinical_symptoms","symptom"),
    (r"pro-inflammatory_state","elevated_inflammatory_markers"),
    (r"peripheral_and_central_inflammation","inflammation"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))cardiometabolic_disorder","cardiometabolic_syndrome"),
    (r"\bgastrointestinal_manifestation\w*\b","functional_gastrointestinal_disorders"),
    (r"chronic_hyperglycaemia-related_damage","hyperglycaemia"),
    (r"\bgastrointestinal_issue\w*\b","functional_gastrointestinal_disorders"),
    (r"gastrointestinal__gi__problems", "functional_gastrointestinal_disorders"),
    (r"\bearly-stage_pd\b","parkinson_disease"),
    (r"reduced_life_expectancy","therapy_assessment:_life_expectancy_reduced"),
    (r"social_dysfunction","dysfunction"),
    (r"\bocd\b","obsessive_compulsive_disorder"),
    (r"\bgad\b","generalized_anxiety_disorder"),
    (r"\btrait_anxiety\b","generalized_anxiety_disorder"),
    (r"dysbiosis_of_the_microbiota","dysbiosis"),
    (r"\bperipheral_inflammation\b","inflammation"),
    (r"\bsci\b","spinal_cord_injury"),
    (r"post-acute_coronavirus_disease__covid_-19_syndrome", "covid-19_post-intensive_care_syndrome"),
    (r"coronavirus_disease","_covid_-19"),
    (r"postinfection disorders of gut-brain interaction","postinfection_disorders"),
    (r"dgbi","postinfection_disorders"),
    (r"visceral_hypersensitivity", "hypersensitivity"),
    (r"kidney__liver__and_heart_disease","disease"),
    (r"alzheimer_and_parkinson_disease","alzheimers_disease"),
    (r"long-term_acetate_deficiency","deficiency"),
    (r"cognitive_decline","mental_deterioration"),
    (r"systemic_inflammation","inflammation"),
    (r"gastrointestinal_disorders", "functional_gastrointestinal_disorders"),
    (r"psychiatric_and_neurodegenerative_disorders", "mental_disorders"),
    (r"\bai\b","autoimmune_disease"),
    (r"ai-related_musculoskeletal_pathology","musculoskeletal_diseases"),
    (r"oleic_acid-induced_acne","oleic_acid-induced_acne"),
    (r"acne_pathogenesis", "acne"),
    (r"serum_hormone_secretion", "hormone_secretion"),
    (r"neurodegenerative__inflammatory__metabolic__and_cardiovascular_diseases", "disease"),
    (r"alzheimer_s_and_parkinson_s_diseases","alzheimers_disease"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))dysfunctions","dysfunction"),
    (r"dysregulation_of_microglia_genes","microglia_gene"),
    (r"telomere_attrition","telomere"),
    (r"neuronal_stem_cell_degradation","stem_cells"),
    (r"loss_of_chromosome_x_inactivation","x_chromosome_inactivation"),
    (r"gut_microbiome_dysbiosis","intestinal_dysbiosis"),
    (r"\bintestinal_barrier_inflammation_and_dysfunction\b","intestinal_dysbiosis"),
    (r"\banxiety-related_behavior\w*\b","anxiety"),
    (r"sporadic_pd","parkinson_disease"),
    (r"\bad\b","alzheimers_disease"),
    (r"parkinson_s_disease","parkinson_disease"),
    (r"\bpd\b", "parkinson_disease"),
    (r"\blbd\b", "lewy_body_dementia"),
    (r"gut_dysbiosis", "intestinal_dysbiosis"),
    (r"melanomas", "melanoma"),
    (r"cums-induced_depressive_disorder", "major_depressive_disorder"),
    (r"chronic_unpredictable_mild_stress__cums_-induced_depressive-like_symptoms", "depression"),
    (r"depressive_behaviors","depression"),
    (r"major_depressive_disorders", "major_depressive_disorder"),
    (r"human_stress", "stress"),
    (r"headaches","headaches"),
    (r"mental_health_problems","major_depressive_disorder"),
    (r"\bstress\w*\b", "stress"),
    (r"\baltered_gut_microbiome\w*\b", "altered_intestinal_microbiome"),
    (r"gastric_disturbances", "functional_gastric_disease"),
    (r"\bmicrobiome_alteration\w*\b" , "altered_intestinal_microbiome"),
    (r"pd-like_pathology", "parkinson_disease"),
    (r"lps_paraquat-induced_weight_loss" , "weight_loss"),
    (r"inflamed_gut" , "gut"),
    (r"brain-gut_changes" , "brain-gut_axis"),
    (r"human_neurological_disorders" , "nervous_system_disorder"),
    (r"\bcns_neurodegenerative_disease\w*\b","nervous_system_disorder"),
    (r"\bcns_neuroinflammatory_disease\w*\b","inflammatory_disease"),
    (r"\bchronic_central_nervous_system__cns__disease\w*\b","nervous_system_disorder"),
    (r"\bimbalance_in_the_gut_microflora\w*\b" , "altered_intestinal_microbiome"),
    (r"neurological_conditions" , "progressive_neurological_conditions"),
    (r"neurological_disorders" , "nervous_system_disorder"),
    (r"\bdd\b", "major_depressive_disorder"),
    (r"hpa_axis_dysfunction", "dysfunction"),
    (r"chronic_mild_stress", "stress"),
    (r"\bcms\b", "stress"),
    (r"anxiety-_and_depressive-like_behaviors", "major_depressive_disorder"),
    (r"cms-induced_anxiety-_and_depressive-like_behaviors", "major_depressive_disorder"),
    (r"gastrointestinal disorders", "functional_gastrointestinal_disorders"),
    (r"food_allergies", "food_allergy"),
    (r"ulcerative_histiocytic_colitis","ulcerative_colitis"),
    (r"depression_patients", "depression"),
    (r"\bibs-d\b", "irritable_bowel_syndrome"),
    (r"\bnds\b", "neurodegenerative_diseases"),
    (r"\bmsa\b", "multiple_system_atrophy"),
    (r"\bms\b", "multiple_sclerosis"),
    (r"\bnmo\b", "neuromyelitis_optica"),
    (r"alpha_synucleinopathies" , "synucleinopathies"),
    (r"hippocampal_microglia-mediated_synaptic_loss", "hippocampal_volume_loss,_mild"),
    (r"inflammatory_gut_milieu", "milieu_therapy"),
    (r"\bptsd\b", "acute_stress_disorder"),
    (r"posttraumatic_stress_disorder", "acute_stress_disorder"),
    (r"alzheimer_s_disease", "alzheimers_disease"),
    (r"vascular_system_dysfunction","dysfunction"),
    (r"intestinal_dysbiosis", "intestinal_dysbiosis"),
    (r"microbiota_dysbiosis", "dysbiosis"),
    (r"chronic_enteropathy", "enteropathy"),
    (r"amyotrophic_lateral_scleroris", "amyotrophic_lateral_scleroris"),
    (r"\bals\b", "amyotrophic_lateral_scleroris"),
    (r"dysregulation_of_gut_barrier_functions", "dysregulated_immune_function"),
    (r"transepithelial_electrical_resistance" , "electrical_resistance"),
    (r"mucin_homeostasis", "gastric_mucins"),
    (r"antimicrobial_responses","antibiotic"),
    (r"helicobacter_pylori-related_hyperhomocysteinemia", "helicobacter_pylori"),
    (r"gastric_pathologies", "gastric_disease"),
    (r"\bidiopathic_disorder\w*\b","conn_syndrome"),
    (r"\bmetabolic_pathologie\w*\b","pathology"),
    (r"\bcns_disease\w*\b","disease"),
    (r"\bhuman_disorder\w*\b","disorder"),
    (r"\bsevere_mental_illnes\w*\b","mental_disorder"),
    (r"\bsmi\b","mental_disorder"),
    (r"\bgut_barrier_disruption\b","altered_intestinal_microbiome"),
    (r"\baff\b","disorder"),
    (r"neurodegenerative_central_nervous_system_disorders", "neurodegenerative_disorders"),
    (r"ocular_alzheimer_s_disease", "alzheimers_disease"),
    (r"gastrointestinal_diseases","disease"),
    (r"autoimmune__ai__diseases","disease"),
    (r"age-associated_diseases","disease"),
    (r"age-associated_brain_diseases","disease"),
    (r"age-related_brain_diseases","disease"),
    (r"mental_diseases","disease"),
    (r"endocrine_and_metabolic_diseases","disease"),
    (r"diseases_of_the_gi_tract","disease"),
    (r"psychotic_and_affective_disorders","disorder"),
    (r"postinfection_disorders_of_gut-brain_interaction","disorder"),
    (r"age-related_diseases","disease"),
    (r"neurological_diseases","disease"),
    (r"migraine", "migraine"),
    (r"gut_dysbiosis","dysbiosis"),
    (r"cognitive_impairment","cognitive_impairment"),
    (r"gut_dysbiosis_and_inflammation","intestinal_dysbiosis"),
    (r"hyperhomocysteinemia-related_brain_cortical_thinning","hyperhomocysteinemia"),
    (r"\bbct\b","hyperhomocysteinemia"),
    (r"major_depressive_episode","major_depressive_disorder"),
    (r"\bbpd\b","major_depressive_disorder"),
    (r"mild_metabolic_disorders","disorder"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))metabolic_disturbances","metabolic_disturbance"),
    (r"schizoaffective_psychosis","psychosis"),
    (r"affective_disorder","mood_disorder"),
    (r"gastrointestinal__gi__disorders","disorder"),
    (r"autoimmune_disorders","disorder"),
    (r"non-celiac_food_sensitivities","coeliac_disease"),
    (r"co-morbid_gi_inflammation","inflammation"),
    (r"inefficient_gluten_digestion","digestion"),
    (r"polygenic_brain_disorders","disorder"),
    (r"autism_spectrum_disorder","disorder"),
    (r"\basd\b","disorder"),
    (r"\bmia\b","systemic_immune_activation"),
    (r"\badhd\b","attention_deficit_hyperactivity_disorder"),
    (r"\bt2dm\b","type_2_diabetes_mellitus"),
    (r"intestinal_microbiota_alterations","intestinal_alteration"),
    (r"depression-like_behavior","major_depressive_disorder"),
    (r"chronic_and_unpredictable_mild_stress","stress"),
    (r"depression-like_behaviors","depression"),
    (r"gastric_and_esophageal_cancer","cancer"),
    (r"parkinsonian_pathology","parkinson_disease"),
    (r"neuroinflammation","neuronitis"),
    (r"nigrostriatal_neurodegeneration","neurodegeneration"),
    (r"disease-related_malnutrition","malnutrition"),
    (r"neurological_and_psychiatric_disorders","disorder"),
    (r"brain_disorders","disorder"),
    (r"\bmdd\b","major_depressive_disorders"),
    (r"inflammatory_processes","inflammation"),
    (r"\binflammatory_issue\w*\b","inflammation"),
    (r"\bpd_pathogenesi\w*\b","parkinson_disease"),
    (r"\bpd_pathology\w*\b","parkinson_disease"),
    (r"anxiety_symptoms","anxiety"),
    (r"\bpcos\b","polycystic_ovary_syndrome"),
    (r"gi symptoms","hama_-_gastrointestinal_symptoms"),
    (r"\baltered_microbiota\w*\b","altered_gut_microbiota"),
    (r"colon_cancer-related_anemia","colon_carcinoma"),
    (r"\bccra\b","colon_carcinoma"),
    (r"colon_cancer","colon_carcinoma"),
    (r"ccra-induced_intestinal_flora_disorder","colon_carcinoma"),
    (r"chronic_stress-induced_anhedonia","stress"),
    (r"chronic_unpredictable_stress","stress"),
    (r"cus-induced_anhedonic_behaviors","anhedonia"),
    (r"irritable_bowel_disease","inflammatory_bowel_disease"),
    (r"\bsdv\b","vagotomy"),
    (r"\bgut_disease\w*\b","disease"),
    (r"abnormal_crypt_foci","aberrant_crypt_foci"),
    (r"\bcrc\b","colorectal_carcinoma"),
    (r"small_intestinal_malabsorption","intestinal_malabsorption"),
    (r"impaired_colonic_microbial_metabolism","metabolism"),
    (r"chronic_alcohol_overconsumption","alcohol"),
    (r"-synuclein_pathology", "pathology"),
    (r"\bcdr\b","cell_danger_response"),
    (r"\bptsd\b","post-traumatic_stress_disorder"),
    (r"\bcte\b","chronic_traumatic_encephalopathy"),
    (r"traumatic_brain_injury","injury"),
    (r"\btbi\b","injury"),
    (r"\balteration_of_faecal_microbiota_balance\b","altered_gut_microbiota"),
    (r"\baltered_microbiota\w*\b","altered_gut_microbiota"),
    (r"\bbd\b","bipolar_disorder"),
    (r"prader-willi_syndrome","prader-willi_syndrome"),
    (r"\bosa\b", "obstructive_sleep_apnea"),
    (r"osa_onset","obstructive_sleep_apnea"),
    (r"\bvvs\b","vasovagal_syncope"),
    (r"systolic_and_diastolic_pressure_reduction", "pressure"),
    (r"mean_pressure_drop", "pressure"),
    (r"diastolic_pressure_drop","pressure"),
    (r"\bcd\b","crohn_s_disease"),
    (r"gut_inflammation", "inflammation"),
    (r"\bscz\b","schizophrenia"),
    (r"anxiety-like_and_depression-like_behaviours","anxiety"),
    (r"\bdepressive\w*\b","anxiety"),
    (r"\bliver_fat\b","hepatic_steatosis"),
    (r"\bhcd\b","colesterol"),
    (r"\bdisorder\w*\b","disorder"),
    (r"first-episode_depression","depression"),
    (r"\bfcr\b","fear_of_cancer_recurrence"),
    (r"learning_and_memory_impairments","cognitive_impairment"),
    (r"migraine","migraine"),
    (r"\bparkinson_s\b","parkinson_disease"),
    (r"psychiatric_and_neurodegenerative_disorders","disorder"),
    (r"gastric_disturbances","intestinal_inflammation"),
    (r"inflamed_gut","intestinal_inflammation"),
    (r"impaired_cognition","cognitive_impairment"),
    (r"helicobacter_pylori_infection","helicobacter_pylori"),
    (r"maternal_immune_activation","systemic_immune_activation"),
    (r"cancers_of_the_esophagus_and_stomach","cancer"),
    (r"gi_symptoms","symptom"),
    (r"gastrointestinal__gi__symptoms","symptom"),
    (r"chronic_restraint_stress-induced_neurobehavioral_and_gut_barrier_deficits", "deficit"),
    (r"idiopathic_pd","parkinson_disease"),
    (r"gut_brain_axis_dysfunction","dysfunction"),
    (r"gut_microbiome_composition_alterations","intestinal_alteration"),
    (r"non-tremor_pd_subtype","parkinson_disease"),
    (r"\bgut_microbiota_alteration\w*\b","intestinal_alteration"),
    (r"dysbiosis_of_intestinal_microbiota","dysbiosis"),
    (r"influenza_infections","severe_influenza_infection"),
    (r"\bcus\b","stress"),
    (r"-synuclein_aggregation","synuclein"),
    (r"\bneurodegenerative_disease\w*\b","neurodegenerative_diseases"),
    (r"chronic__developmental__autoimmune__and_degenerative_disorders","disorder"),
    (r"brain_inflammatory_activity", "brain_inflammatory_disease"),
    (r"\bcardiovascular_disease\w*\b","cardiovascular_diseases"),
    (r"hyperlipidemia","hyperlipidemia"),
    (r"intestinal_microbial_and_metabolites_dysbiosis","dysbiosis"),
    (r"microbial_dysbiosis","dysbiosis"),
    (r"systemic_low-grade_inflammation","inflammation"),
    (r"severe_psychiatric_disorders","disorder"),
    (r"chronic_unpredictable_mild_stress","stress"),
    (r"depression-_and_anxiety-like_behavior","depression"),
    (r"depression-_and_anxiety-like_behaviors","depression"),
    (r"\bcad\b","coronary_artery_disease"),
    (r"anosmia","anosmia"),
    (r"altered_gut_motility","gut-brain_axis"),
    (r"changes_in_intestinal_permeability","intestinal"),
    (r"\bndd\b","neurodegenerative_diseases"),
    (r"\bneurological_and_mental_disorder\w*\b","mental_disorders"),
    (r"\bmicrobiome_and_specific_bacterial_change\w*\b","altered_intestinal_microbiome"),
    (r"postinfection_disorders_of_gut-brain_interaction", "disease_(or_disorder);_spleen,_postinfectional"),
    (r"\bacute_and_chronic_insomnia\b","chronic_insomnia"),
    (r"\bautoimmune_disease\w*\b","autoimmune_disease"),
    (r"\benteropathic_celiac_disease\w*\b","coeliac_disease"),
    (r"\bmental_health_disorders\b","mental_disorders"),
    (r"\bpsychiatric_and_neurodegenerative_disorder\w*\b","mental_disorders"),
    (r"\bmental_dysfunction\w*\b","mental_disorders"),
    (r"\bmental_illnesses\w*\b","mental_disorders"),
    (r"\bpsychological_dysfunction\w*\b","mental_disorders"),
    (r"\bmood_disorders\b","mood_disorder"),

]

CREATOR = "Samuel Piron"

UMLS_BASES = "https://uts.nlm.nih.gov/uts/umls/concept/"

for uri in manual_created.values():
    uri_str = str(uri)

    if uri_str.startswith(UMLS_BASES):
        # only a UMLS‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("UMLS Match", datatype=XSD.string)))
    elif "MMO" in uri_str:
        # only a STATO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("MNO Match", datatype=XSD.string)))
    elif "meshb" in uri_str:
        # only a MESH‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("MESH Match", datatype=XSD.string)))
    elif "BAO" in uri_str:
        # only a BAO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("BAO Match", datatype=XSD.string)))
    elif "NCIT" in uri_str:
        # only a NCIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("NCIT Match", datatype=XSD.string)))
    elif "OMIT" in uri_str:
        # only a OMIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("OMIT Match", datatype=XSD.string)))
    elif "PR" in uri_str:
        # only a FMA‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("PR Match", datatype=XSD.string)))
    elif "TFClass" in uri_str:
        # only a TFClass‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("TFClass Match", datatype=XSD.string)))
    elif "GO" in uri_str:
        # only a GO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("GO Match", datatype=XSD.string)))
    elif "BioCyc" in uri_str:
        # only a BioCyc‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("BioCyc Match", datatype=XSD.string)))
    elif "kegg" in uri_str:
        # only a KEGG‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("KEGG Match", datatype=XSD.string)))
    elif "OGG" in uri_str:
        # only a OGG‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("OGG Match", datatype=XSD.string)))
    elif "MONDO" in uri_str:
        # only a Genome‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("MONDO Match", datatype=XSD.string)))
    elif "NCBITaxon" in uri_str:
        # only a NCBITaxon‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("NCBITaxon Match", datatype=XSD.string)))
    elif "OGMS" in uri_str:
        # only a OGMS‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("OGMS Match", datatype=XSD.string)))
    elif "DOID" in uri_str:
        # only a DOID‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("DOID Match", datatype=XSD.string)))
    elif "HP" in uri_str:
        # only a HP‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("HP Match", datatype=XSD.string)))
    elif "MP" in uri_str:
        # only a MP‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("MP Match", datatype=XSD.string)))
    else:
        # everything else still gets a creator
        g.add((uri,
               DCTERMS.creator,
               Literal(CREATOR, datatype=XSD.string)))
        
for term_raw, uri in manual_created.items():
    uri_str = str(uri)

    # NCIT definitions
    if uri_str.startswith(NCBI_BASE) and "NCIT_" in uri_str:
        ncit_id = uri_str.rsplit("_", 1)[-1]
        desc = get_ncit_description(ncit_id, ncit_file)
        m = re.search(r'—\s*(.*?)\s*—', desc)
        if m:
            desc = m.group(1).strip()
            comment = f"{desc} [Definition Source: NCIT]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # UMLS definitions
    elif uri_str.startswith(UMLS_BASES):
        cui = uri_str.rsplit("/", 1)[-1]
        defn = get_umls_definition(cui)
        if defn:
            comment = f"{defn.strip()} [Definition Source: UMLS]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # MeSH definitions via your mesh_index
    elif uri_str.startswith(MESH_BASE):
        ui     = uri_str.rsplit("/",1)[-1]
        hits   = [d['name'] for d in mesh_descs if d['ui']==ui]
        if hits:
            comment = f"{hits[0]} [Definition Source: MeSH]"
        elif term_raw == "patients":
            comment = "Patients with various diseases. [Definition Source: GUTBRAIN]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    elif uri_str.startswith(HEREDITARY_BASE):
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"
    else:
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    g.add((uri,
           RDFS.comment,
           Literal(comment, datatype=XSD.string)))

def top_cosine(term, k=5, thr=0.85):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = ddf_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

def top_cosine_omit(term, k=5, thr=0.85):
    v  = vec1.transform([term])
    sc = cosine_similarity(v, mat1).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = omit_rows[i]
        out.append((lbl, uri, sc[i]))
    return out
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "DDF":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            #lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, DDF_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, DDF_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue
            
            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine_omit(term)
            if ex:
                lbl, uri = ex[0]
                print(f"  • {lbl:40s} URI={uri}")
                entity_uri = URIRef(f"{uri}")
                created[term_raw] = entity_uri
                g.add((entity_uri, RDF.type, DDF_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                g.add((entity_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                uri_str = str(entity_uri).lower()

                if "stato_" in uri_str:
                    comment = "STATO Match"
                elif "ncbitaxon_" in uri_str:
                    comment = "NCBITaxon Match"
                elif "ncit_" in uri_str:
                    comment = "NCIT Match"
                elif "obi_" in uri_str:
                    comment = "OBI Match"
                elif "umls" in uri_str:
                    comment = "UMLS Match"
                elif "omit" in uri_str:
                    comment = "OMIT Match"
                else:
                    comment = CREATOR 
                g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                uri_str = str(entity_uri)
                definition = choose_definition(uri_str, term_raw)
                existing_defs = [
                    c for c in g.objects(entity_uri, RDFS.comment)
                    if "[Definition Source:" in str(c)
                ]
                if not existing_defs:
                    g.add((entity_uri,
                        RDFS.comment,
                        Literal(definition, datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                continue
                print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DDF_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DDF_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
                
            else:
                api_term = lookup_key.replace("_", " ")
                umls_hits = search_umls(api_term)
                if umls_hits:
                    cui, name, score, definition = best_umls_match(api_term, umls_hits)
                    if name in created:
                        entity_uri = created[term_raw]
                    else:
                        entity_uri = URIRef(f"https://uts.nlm.nih.gov/uts/umls/concept/{cui}")
                        created[term_raw] = entity_uri

                    g.add((entity_uri, RDF.type,      DDF_CLASS))
                    g.add((entity_uri, RDF.type,      SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                                RDFS.label,
                                Literal(name.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                    if definition:
                        comment_str = f"{definition.strip()} [Definition Source: UMLS]"
                    else:
                        llm_def = get_llm_definition(term_raw)
                        comment_str = f"{llm_def} [Definition Source: llama3-8b-8192]"
                    g.add((entity_uri, RDFS.comment, Literal("UMLS Match", datatype=XSD.string)))
            
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,        MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,      Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn,    mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print(f"  • UMLS CUI={cui}  Name={name!r}  sim={score:.2f}")
                    continue
                    
                else: 
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,      MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,    Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    tokenized_mentions[term_raw] = mention_uri
                    print("no matches locally or in UMLS")

        else:
            pass 

print("entering gold")

for paper_id, paper_data in data_gold.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "DDF":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            #lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, DDF_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, DDF_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue
            
            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine_omit(term)
            if ex:
                lbl, uri = ex[0]
                print(f"  • {lbl:40s} URI={uri}")
                entity_uri = URIRef(f"{uri}")
                created[term_raw] = entity_uri
                g.add((entity_uri, RDF.type, DDF_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                g.add((entity_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                uri_str = str(entity_uri).lower()

                if "stato_" in uri_str:
                    comment = "STATO Match"
                elif "ncbitaxon_" in uri_str:
                    comment = "NCBITaxon Match"
                elif "ncit_" in uri_str:
                    comment = "NCIT Match"
                elif "obi_" in uri_str:
                    comment = "OBI Match"
                elif "umls" in uri_str:
                    comment = "UMLS Match"
                elif "omit" in uri_str:
                    comment = "OMIT Match"
                else:
                    comment = CREATOR 
                g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                uri_str = str(entity_uri)
                definition = choose_definition(uri_str, term_raw)
                existing_defs = [
                    c for c in g.objects(entity_uri, RDFS.comment)
                    if "[Definition Source:" in str(c)
                ]
                if not existing_defs:
                    g.add((entity_uri,
                        RDFS.comment,
                        Literal(definition, datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                continue
                print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DDF_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DDF_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
                
            else:
                api_term = lookup_key.replace("_", " ")
                umls_hits = search_umls(api_term)
                if umls_hits:
                    cui, name, score, definition = best_umls_match(api_term, umls_hits)
                    if name in created:
                        entity_uri = created[term_raw]
                    else:
                        entity_uri = URIRef(f"https://uts.nlm.nih.gov/uts/umls/concept/{cui}")
                        created[term_raw] = entity_uri

                    g.add((entity_uri, RDF.type,      DDF_CLASS))
                    g.add((entity_uri, RDF.type,      SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                                RDFS.label,
                                Literal(name.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                    if definition:
                        comment_str = f"{definition.strip()} [Definition Source: UMLS]"
                    else:
                        llm_def = get_llm_definition(term_raw)
                        comment_str = f"{llm_def} [Definition Source: llama3-8b-8192]"
                    g.add((entity_uri, RDFS.comment, Literal("UMLS Match", datatype=XSD.string)))
            
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,        MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,      Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn,    mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print(f"  • UMLS CUI={cui}  Name={name!r}  sim={score:.2f}")
                    continue
                    
                else: 
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,      MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,    Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    tokenized_mentions[term_raw] = mention_uri
                    print("no matches locally or in UMLS")

        else:
            pass
    
print("entering dev")

for paper_id, paper_data in data_dev.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "DDF":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            #lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, DDF_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, DDF_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue
            
            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine_omit(term)
            if ex:
                lbl, uri = ex[0]
                print(f"  • {lbl:40s} URI={uri}")
                entity_uri = URIRef(f"{uri}")
                created[term_raw] = entity_uri
                g.add((entity_uri, RDF.type, DDF_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                g.add((entity_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                uri_str = str(entity_uri).lower()

                if "stato_" in uri_str:
                    comment = "STATO Match"
                elif "ncbitaxon_" in uri_str:
                    comment = "NCBITaxon Match"
                elif "ncit_" in uri_str:
                    comment = "NCIT Match"
                elif "obi_" in uri_str:
                    comment = "OBI Match"
                elif "umls" in uri_str:
                    comment = "UMLS Match"
                elif "omit" in uri_str:
                    comment = "OMIT Match"
                else:
                    comment = CREATOR 
                g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                uri_str = str(entity_uri)
                definition = choose_definition(uri_str, term_raw)
                existing_defs = [
                    c for c in g.objects(entity_uri, RDFS.comment)
                    if "[Definition Source:" in str(c)
                ]
                if not existing_defs:
                    g.add((entity_uri,
                        RDFS.comment,
                        Literal(definition, datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                continue
                print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DDF_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DDF_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
                
            else:
                api_term = lookup_key.replace("_", " ")
                umls_hits = search_umls(api_term)
                if umls_hits:
                    cui, name, score, definition = best_umls_match(api_term, umls_hits)
                    if name in created:
                        entity_uri = created[term_raw]
                    else:
                        entity_uri = URIRef(f"https://uts.nlm.nih.gov/uts/umls/concept/{cui}")
                        created[term_raw] = entity_uri

                    g.add((entity_uri, RDF.type,      DDF_CLASS))
                    g.add((entity_uri, RDF.type,      SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                                RDFS.label,
                                Literal(name.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                    if definition:
                        comment_str = f"{definition.strip()} [Definition Source: UMLS]"
                    else:
                        llm_def = get_llm_definition(term_raw)
                        comment_str = f"{llm_def} [Definition Source: llama3-8b-8192]"
                    g.add((entity_uri, RDFS.comment, Literal("UMLS Match", datatype=XSD.string)))
            
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,        MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,      Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn,    mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print(f"  • UMLS CUI={cui}  Name={name!r}  sim={score:.2f}")
                    continue
                    
                else: 
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type,      MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,    Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs,      Literal(raw_label, datatype=XSD.string)))
                    tokenized_mentions[term_raw] = mention_uri
                    print("no matches locally or in UMLS")

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip()
        else:
            continue

        if label != "DDF":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_gold_file, "r", encoding="utf-8") as f_sent:
    tokenized_gold_data = json.load(f_sent)

for entry in tokenized_gold_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "DDF":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_dev, "r", encoding="utf-8") as f_sent:
    tokenized_dev_data = json.load(f_sent)

for entry in tokenized_dev_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "DDF":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

output_file = os.path.join(save_path, "gutbrain_entities.ttl")
ttl_output = g.serialize(format="turtle")
with open(output_file, "w", encoding="utf-8") as f_out:
    f_out.write(ttl_output)

print(f"The RDF graph has been saved in {output_file}")
# Out:
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   • Depressive Disorder, Major               URI=http://purl.obolibrary.org/obo/OMIT_0005141 score=1.00
# Query: mental deterioration
# lookup term: mental_deterioration
#   • UMLS CUI=C0234985  Name='Mental deterioration'  sim=1.00
# mood_disorder
# Query: mood disorder
# lookup term: mood_disorder
#   • Mood Disorder                            URI=http://purl.obolibrary.org/obo/NCIT_C92200
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005141
#
#
# Query: antimicrobial resistance
# lookup term: antimicrobial_resistance
#   • Antimicrobial Resistance Result          URI=http://purl.obolibrary.org/obo/NCIT_C85562 score=0.91
# Query: inflammation
# lookup term: inflammation
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137
# Query: psychosis
# lookup term: psychosis
#   • Psychosis                                URI=http://purl.obolibrary.org/obo/NCIT_C78576
# Query: schizophrenia
# lookup term: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
# Query: psychosis
# lookup term: psychosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C78576
#
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# Query: psychosis
# lookup term: psychosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C78576
#
#
# Query: psychosis
# lookup term: psychosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C78576
#
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# Query: psychosis
# lookup term: psychosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C78576
#
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# Query: psychosis
# lookup term: psychosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C78576
#
#
# Query: psychosis
# lookup term: psychosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C78576
#
#
# migraine
# Query: migraine
# lookup term: migraine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C89715
#
# migraine
# Query: migraine
# lookup term: migraine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C89715
#
# disease
# Query: disease
# lookup term: disease
#   • Disease                                  URI=http://purl.obolibrary.org/obo/OMIT_0005457 score=1.00
# headaches
# Query: headache
# lookup term: headaches
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34661
#
#
# functional_gastrointestinal_disorders
# Query: functional gastrointestinal disorder
# lookup term: functional_gastrointestinal_disorders
#   → Reusing existing URI: https://bioportal.bioontology.org/ontologies/EDAM?p=classes&conceptid=topic_3409
#
# migraine
# Query: migraine
# lookup term: migraine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C89715
#
#
# functional_gastrointestinal_disorders
# Query: functional gastrointestinal disorder
# lookup term: functional_gastrointestinal_disorders
#   → Reusing existing URI: https://bioportal.bioontology.org/ontologies/EDAM?p=classes&conceptid=topic_3409
#
# migraine
# Query: migraine
# lookup term: migraine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C89715
#
#
# disease
# Query: disease
# lookup term: disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005457
#
#
# Query: inflammation
# lookup term: inflammation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3137
#
#
# migraine
# Query: migraine
# lookup term: migraine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C89715
#
# migraine
# Query: migraine
# lookup term: migraine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C89715
#
# migraine
# Query: migraine
# lookup term: migraine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C89715
#
# migraine
# Query: migraine
# lookup term: migraine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C89715
#
# migraine
# Query: migraine
# lookup term: migraine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C89715
#
# migraine
# Query: migraine
# lookup term: migraine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C89715
#
# migraine
# Query: migraine
# lookup term: migraine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C89715
#
# Query: depression
# lookup term: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
# Query: anxiety
# lookup term: anxiety
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696
# Query: inflammation
# lookup term: inflammation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3137
#
#
# migraine
# Query: migraine
# lookup term: migraine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C89715
#
# migraine
# Query: migraine
# lookup term: migraine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C89715
#
# cognitive_impairment
# Query: cognitive impairment
# lookup term: cognitive_impairment
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C116921
#
#
# Query: type 1 diabetes mellitus
# lookup term: type_1_diabetes_mellitus
#   • Type 1 Diabetes Mellitus                 URI=http://purl.obolibrary.org/obo/NCIT_C2986
# Type_1_Diabetes_Mellitus
# Query: Type 1 Diabetes Mellitus
# lookup term: Type_1_Diabetes_Mellitus
#   • Type 1 Diabetes Mellitus                 URI=http://purl.obolibrary.org/obo/NCIT_C2986 score=1.00
# Type_1_Diabetes_Mellitus
# Query: Type 1 Diabetes Mellitus
# lookup term: Type_1_Diabetes_Mellitus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2986
#
#
# cognitive_impairment
# Query: cognitive impairment
# lookup term: cognitive_impairment
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C116921
#
#
# deficiency
# Query: deficiency
# lookup term: deficiency
#   • Deficiency                               URI=http://purl.obolibrary.org/obo/NCIT_C94372
# cognitive_impairment
# Query: cognitive impairment
# lookup term: cognitive_impairment
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C116921
#
# deficiency
# Query: deficiency
# lookup term: deficiency
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C94372
#
#
# mental_deterioration
# Query: mental deterioration
# lookup term: mental_deterioration
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0234985
#
# Query: neuropsychiatric disorder
# lookup term: neuropsychiatric_disorders
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeuropsychiatricDisorders
#
#
# Query: neuropsychiatric disorder
# lookup term: neuropsychiatric_disorders
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeuropsychiatricDisorders
#
#
# mental_disorders
# Query: mental disorder
# lookup term: mental_disorders
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0002893
#
# Query: neuropsychiatric disorder
# lookup term: neuropsychiatric_disorders
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeuropsychiatricDisorders
#
#
# Query: periodontitis
# lookup term: periodontitis
#   • Periodontitis                            URI=http://purl.obolibrary.org/obo/NCIT_C34918
# Query: neuropsychiatric disorder
# lookup term: neuropsychiatric_disorders
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeuropsychiatricDisorders
#
#
# alzheimers_disease
# Query: alzheimers disease
# lookup term: alzheimers_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2866
#
# Query: neuropsychiatric disorder
# lookup term: neuropsychiatric_disorders
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeuropsychiatricDisorders
#
#
# autoimmune_disease
# Query: autoimmune disease
# lookup term: autoimmune_disease
#   • Autoimmune Disease                       URI=http://purl.obolibrary.org/obo/NCIT_C2889
# disease
# Query: disease
# lookup term: disease
#   • Disease                                  URI=http://purl.obolibrary.org/obo/OMIT_0005457 score=1.00
# intestinal_dysbiosis
# Query: intestinal dysbiosis
# lookup term: intestinal_dysbiosis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4287543
#
# intestinal_dysbiosis
# Query: intestinal dysbiosis
# lookup term: intestinal_dysbiosis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4287543
#
# autoimmune_disease
# Query: autoimmune disease
# lookup term: autoimmune_disease
#   • Autoimmune Disease                       URI=http://purl.obolibrary.org/obo/NCIT_C2889
# inflammation
# Query: inflammation
# lookup term: inflammation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3137
#
# Query: arthropathy
# lookup term: arthropathy
#   • Arthropathy                              URI=http://purl.obolibrary.org/obo/NCIT_C35760
# intestinal_dysbiosis
# Query: intestinal dysbiosis
# lookup term: intestinal_dysbiosis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4287543
#
# Query: chronic inflammation
# lookup term: chronic_inflammation
#   • Chronic Inflammation                     URI=http://purl.obolibrary.org/obo/NCIT_C174450
# autoimmune_disease
# Query: autoimmune disease
# lookup term: autoimmune_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2889
#
#
# Query: psoriatic arthritis
# lookup term: psoriatic_arthritis
#   • Psoriatic Arthritis                      URI=http://purl.obolibrary.org/obo/NCIT_C61277
# Query: systemic lupus erythematosus
# lookup term: systemic_lupus_erythematosus
#   • Systemic Lupus Erythematosus             URI=http://purl.obolibrary.org/obo/NCIT_C3201
# inflammatory_bowel_disease
# Query: inflammatory bowel disease
# lookup term: inflammatory_bowel_disease
#   • Inflammatory Bowel Disease               URI=http://purl.obolibrary.org/obo/NCIT_C3138
# Query: rheumatoid arthritis
# lookup term: rheumatoid_arthritis
#   • Rheumatoid Arthritis                     URI=http://purl.obolibrary.org/obo/NCIT_C2884
# autoimmune_disease
# Query: autoimmune disease
# lookup term: autoimmune_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2889
#
#
# inflammation
# Query: inflammation
# lookup term: inflammation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3137
#
# Query: inflammation
# lookup term: inflammation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3137
#
#
# autoimmune_disease
# Query: autoimmune disease
# lookup term: autoimmune_disease
#   • Autoimmune Disease                       URI=http://purl.obolibrary.org/obo/NCIT_C2889
# oleic_acid-induced_acne
# Query: oleic acid-induced acne
# lookup term: oleic_acid-induced_acne
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/OleicAcidInducedAcne
#
#
# acne
# Query: acne
# lookup term: acne
#   • Acne                                     URI=http://purl.obolibrary.org/obo/NCIT_C27195
# Query: acne vulgaris
# lookup term: acne_vulgaris
#   • Acne Vulgaris                            URI=http://purl.obolibrary.org/obo/OMIT_0001590 score=1.00
# Query: inflammatory disease
# lookup term: inflammatory_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/MONDO_0021166
#
#
# oleic_acid-induced_acne
# Query: oleic acid-induced acne
# lookup term: oleic_acid-induced_acne
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/OleicAcidInducedAcne
#
#
# Query: skin inflammation
# lookup term: skin_inflammation
#   • Skin Inflammation                        URI=http://purl.obolibrary.org/obo/NCIT_C50742
# Query: skin inflammation
# lookup term: skin_inflammation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C50742
#
#
# hormone_secretion
# Query: hormone secretion
# lookup term: hormone_secretion
#   • UMLS CUI=C0312431  Name='Hormone secretion'  sim=1.00
# Query: acne
# lookup term: acne
#   • Acne                                     URI=http://purl.obolibrary.org/obo/NCIT_C27195
# Query: skin inflammation
# lookup term: skin_inflammation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C50742
#
#
# neurodegenerative_diseases
# Query: neurodegenerative disease
# lookup term: neurodegenerative_diseases
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeurodegenerativeDiseases
#
#
# disease
# Query: disease
# lookup term: disease
#   • Disease                                  URI=http://purl.obolibrary.org/obo/OMIT_0005457 score=1.00
# disease
# Query: disease
# lookup term: disease
#   • Disease                                  URI=http://purl.obolibrary.org/obo/OMIT_0005457 score=1.00
# Query: cancer
# lookup term: cancer
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_6754
#
#
# Query: senescence
# lookup term: senescence
#   • Senescence                               URI=http://purl.obolibrary.org/obo/NCIT_C17467
# Query: neurodegeneration
# lookup term: neurodegeneration
#   → Reusing existing URI: http://purl.obolibrary.org/obo/MP_0002229
#
#
# disease
# Query: disease
# lookup term: disease
#   • Disease                                  URI=http://purl.obolibrary.org/obo/OMIT_0005457 score=1.00
# alzheimers_disease
# Query: alzheimers disease
# lookup term: alzheimers_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2866
#
# dysfunction
# Query: dysfunction
# lookup term: dysfunction
#   • Dysfunction                              URI=http://purl.obolibrary.org/obo/NCIT_C53526
# microglia_gene
# Query: microglia gene
# lookup term: microglia_gene
#   • Microglia                                URI=http://purl.obolibrary.org/obo/NCIT_C12616 score=0.95
# neuronitis
# Query: neuronitis
# lookup term: neuronitis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/MONDO_0004466
#
# telomere
# Query: telomere
# lookup term: telomere
#   • Telomere                                 URI=http://purl.obolibrary.org/obo/NCIT_C13295
# stem_cells
# Query: stem cell
# lookup term: stem_cells
#   • Stem Cell                                URI=http://purl.obolibrary.org/obo/NCIT_C12662
# dysfunction
# Query: dysfunction
# lookup term: dysfunction
#   • Dysfunction                              URI=http://purl.obolibrary.org/obo/NCIT_C53526
# x_chromosome_inactivation
# Query: x chromosome inactivation
# lookup term: x_chromosome_inactivation
#   • X-Chromosome Inactivation                URI=http://purl.obolibrary.org/obo/NCIT_C20674 score=1.00
# intestinal_dysbiosis
# Query: intestinal dysbiosis
# lookup term: intestinal_dysbiosis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4287543
#
# Query: neurodegeneration
# lookup term: neurodegeneration
#   → Reusing existing URI: http://purl.obolibrary.org/obo/MP_0002229
#
#
# disease
# Query: disease
# lookup term: disease
#   • Disease                                  URI=http://purl.obolibrary.org/obo/OMIT_0005457 score=1.00
# neurodegenerative_diseases
# Query: neurodegenerative disease
# lookup term: neurodegenerative_diseases
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeurodegenerativeDiseases
#
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   • Parkinson Disease                        URI=http://purl.obolibrary.org/obo/NCIT_C26845
# Query: alzheimer s
# lookup term: alzheimer_s
#   • Alzheimer's Disease                      URI=http://purl.obolibrary.org/obo/NCIT_C2866 score=0.86
# Query: lewy body dementia
# lookup term: lewy_body_dementia
#   • Lewy Body Dementia                       URI=http://purl.obolibrary.org/obo/NCIT_C84826
# alzheimers_disease
# Query: alzheimers disease
# lookup term: alzheimers_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2866
#
# alzheimers_disease
# Query: alzheimers disease
# lookup term: alzheimers_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2866
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   • Parkinson Disease                        URI=http://purl.obolibrary.org/obo/NCIT_C26845
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   • Parkinson Disease                        URI=http://purl.obolibrary.org/obo/NCIT_C26845
# Query: lewy body dementia
# lookup term: lewy_body_dementia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C84826
#
#
# lewy_body_dementia
# Query: lewy body dementia
# lookup term: lewy_body_dementia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C84826
#
# Query: vitiligo
# lookup term: vitiligo
#   • Vitiligo                                 URI=http://purl.obolibrary.org/obo/NCIT_C26915
# alzheimers_disease
# Query: alzheimers disease
# lookup term: alzheimers_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2866
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# lewy_body_dementia
# Query: lewy body dementia
# lookup term: lewy_body_dementia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C84826
#
# Query: vitiligo
# lookup term: vitiligo
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26915
#
#
# Query: apoptosis
# lookup term: apoptosis
#   • Apoptosis                                URI=http://purl.obolibrary.org/obo/NCIT_C17557
# intestinal_dysbiosis
# Query: intestinal dysbiosis
# lookup term: intestinal_dysbiosis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4287543
#
# Query: inflammation
# lookup term: inflammation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3137
#
#
# intestinal_dysbiosis
# Query: intestinal dysbiosis
# lookup term: intestinal_dysbiosis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4287543
#
# Query: inflammation
# lookup term: inflammation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3137
#
#
# alzheimers_disease
# Query: alzheimers disease
# lookup term: alzheimers_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2866
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# lewy_body_dementia
# Query: lewy body dementia
# lookup term: lewy_body_dementia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C84826
#
# neurodegenerative_diseases
# Query: neurodegenerative disease
# lookup term: neurodegenerative_diseases
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeurodegenerativeDiseases
#
#
# Query: inflammation
# lookup term: inflammation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3137
#
#
# melanoma
# Query: melanoma
# lookup term: melanoma
#   • Melanoma                                 URI=http://purl.obolibrary.org/obo/NCIT_C3224
# Query: vitiligo
# lookup term: vitiligo
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26915
#
#
# stress
# Query: stress
# lookup term: stress
#   • Stress                                   URI=http://purl.obolibrary.org/obo/NCIT_C35041
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   • Depressive Disorder, Major               URI=http://purl.obolibrary.org/obo/OMIT_0005141 score=1.00
# depression
# Query: depression
# lookup term: depression
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C124639
#
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   • Depressive Disorder, Major               URI=http://purl.obolibrary.org/obo/OMIT_0005141 score=1.00
# depression
# Query: depression
# lookup term: depression
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C124639
#
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005141
#
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# stress
# Query: stress
# lookup term: stress
#   • Stress                                   URI=http://purl.obolibrary.org/obo/NCIT_C35041
# anxiety
# Query: anxiety
# lookup term: anxiety
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26696
#
# stress
# Query: stress
# lookup term: stress
#   • Stress                                   URI=http://purl.obolibrary.org/obo/NCIT_C35041
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005141
#
# Query: anxiety
# lookup term: anxiety
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26696
#
#
# Query: depression
# lookup term: depression
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C124639
#
#
# stress
# Query: stress
# lookup term: stress
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C35041
#
#
# Query: anxiety
# lookup term: anxiety
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26696
#
#
# stress
# Query: stress
# lookup term: stress
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C35041
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# altered_intestinal_microbiome
# Query: altered intestinal microbiome
# lookup term: altered_intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/AlteredIntestinalMicrobiome
#
# Query: intestinal inflammation
# lookup term: intestinal_inflammation
#   • UMLS CUI=C3889047  Name='Intestinal inflammation'  sim=1.00
# functional_gastric_disease
# Query: functional gastric disease
# lookup term: functional_gastric_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/MONDO_0001318
#
# altered_intestinal_microbiome
# Query: altered intestinal microbiome
# lookup term: altered_intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/AlteredIntestinalMicrobiome
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   • Parkinson Disease                        URI=http://purl.obolibrary.org/obo/NCIT_C26845
# Query: colitis
# lookup term: colitis
#   • Colitis                                  URI=http://purl.obolibrary.org/obo/NCIT_C26723
# inflammation
# Query: inflammation
# lookup term: inflammation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3137
#
# weight_loss
# Query: weight loss
# lookup term: weight_loss
#   • Weight Loss                              URI=http://purl.obolibrary.org/obo/NCIT_C3445
# gut
# Query: gut
# lookup term: gut
#   • UMLS CUI=C0699819  Name='Gut'  sim=1.00
# brain-gut_axis
# Query: brain-gut axis
# lookup term: brain-gut_axis
#   • UMLS CUI=C5544358  Name='Brain-Gut Axis'  sim=1.00
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# nervous_system_disorder
# Query: nervous system disorder
# lookup term: nervous_system_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26835
#
# altered_intestinal_microbiome
# Query: altered intestinal microbiome
# lookup term: altered_intestinal_microbiome
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/AlteredIntestinalMicrobiome
#
# Query: dysbiosis
# lookup term: dysbiosis
#   • Dysbiosis                                URI=http://purl.obolibrary.org/obo/OMIT_0028544 score=1.00
# nervous_system_disorder
# Query: nervous system disorder
# lookup term: nervous_system_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26835
#
# progressive_neurological_conditions
# Query: progressive neurological condition
# lookup term: progressive_neurological_conditions
#   • UMLS CUI=C4699656  Name='Progressive neurological conditions'  sim=1.00
# disorder
# Query: disorder
# lookup term: disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OGMS_0000045
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# Query: multiple sclerosis
# lookup term: multiple_sclerosis
#   • Multiple Sclerosis                       URI=http://purl.obolibrary.org/obo/NCIT_C3243
# alzheimers_disease
# Query: alzheimers disease
# lookup term: alzheimers_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2866
#
# Query: epilepsy
# lookup term: epilepsy
#   • Epilepsy                                 URI=http://purl.obolibrary.org/obo/OMIT_0006064 score=1.00
# Query: stroke
# lookup term: stroke
#   • Stroke                                   URI=http://purl.obolibrary.org/obo/NCIT_C3390
# nervous_system_disorder
# Query: nervous system disorder
# lookup term: nervous_system_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26835
#
# nervous_system_disorder
# Query: nervous system disorder
# lookup term: nervous_system_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26835
#
# anxiety
# Query: anxiety
# lookup term: anxiety
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26696
#
# anxiety
# Query: anxiety
# lookup term: anxiety
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26696
#
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005141
#
# dysfunction
# Query: dysfunction
# lookup term: dysfunction
#   • Dysfunction                              URI=http://purl.obolibrary.org/obo/NCIT_C53526
# stress
# Query: stress
# lookup term: stress
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C35041
#
# Query: depression
# lookup term: depression
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C124639
#
#
# stress
# Query: stress
# lookup term: stress
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C35041
#
# Query: depression
# lookup term: depression
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C124639
#
#
# stress
# Query: stress
# lookup term: stress
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C35041
#
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005141
#
# stress
# Query: stress
# lookup term: stress
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C35041
#
# Query: dysbiosis
# lookup term: dysbiosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0028544
#
#
# Query: inflammatory bowel disease
# lookup term: inflammatory_bowel_disease
#   • Inflammatory Bowel Disease               URI=http://purl.obolibrary.org/obo/NCIT_C3138
# Query: obesity
# lookup term: obesity
#   • Obesity                                  URI=http://purl.obolibrary.org/obo/NCIT_C3283
# progressive_neurological_conditions
# Query: progressive neurological condition
# lookup term: progressive_neurological_conditions
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4699656
#
#
# functional_gastrointestinal_disorders
# Query: functional gastrointestinal disorder
# lookup term: functional_gastrointestinal_disorders
#   → Reusing existing URI: https://bioportal.bioontology.org/ontologies/EDAM?p=classes&conceptid=topic_3409
#
# enteropathy
# Query: enteropathy
# lookup term: enteropathy
#   • UMLS CUI=C0021831  Name='Intestinal Diseases'  sim=0.00
# Query: inflammatory bowel disease
# lookup term: inflammatory_bowel_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3138
#
#
# food_allergy
# Query: food allergy
# lookup term: food_allergy
#   • Food Allergy                             URI=http://purl.obolibrary.org/obo/NCIT_C172304
# ulcerative_colitis
# Query: ulcerative colitis
# lookup term: ulcerative_colitis
#   • Ulcerative Colitis                       URI=http://purl.obolibrary.org/obo/NCIT_C2952
# Query: irritable bowel syndrome
# lookup term: irritable_bowel_syndrome
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0022104
#
#
# depression
# Query: depression
# lookup term: depression
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C124639
#
# Query: irritable bowel syndrome
# lookup term: irritable_bowel_syndrome
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0022104
#
#
# Query: ibs
# lookup term: ibs
#   • UMLS CUI=C0022104  Name='Irritable Bowel Syndrome'  sim=0.00
# Query: depression
# lookup term: depression
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C124639
#
#
# Query: diarrhea-predominant ibs
# lookup term: diarrhea-predominant_ibs
#   • Diarrhea                                 URI=http://purl.obolibrary.org/obo/OMIT_0005240 score=1.00
# irritable_bowel_syndrome
# Query: irritable bowel syndrome
# lookup term: irritable_bowel_syndrome
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0022104
#
# Query: depression
# lookup term: depression
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C124639
#
#
# irritable_bowel_syndrome
# Query: irritable bowel syndrome
# lookup term: irritable_bowel_syndrome
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0022104
#
# irritable_bowel_syndrome
# Query: irritable bowel syndrome
# lookup term: irritable_bowel_syndrome
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0022104
#
# Query: depression
# lookup term: depression
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C124639
#
#
# irritable_bowel_syndrome
# Query: irritable bowel syndrome
# lookup term: irritable_bowel_syndrome
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0022104
#
# Query: depression
# lookup term: depression
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C124639
#
#
# irritable_bowel_syndrome
# Query: irritable bowel syndrome
# lookup term: irritable_bowel_syndrome
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0022104
#
# Query: depression
# lookup term: depression
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C124639
#
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# neurodegenerative_diseases
# Query: neurodegenerative disease
# lookup term: neurodegenerative_diseases
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeurodegenerativeDiseases
#
#
# neurodegenerative_diseases
# Query: neurodegenerative disease
# lookup term: neurodegenerative_diseases
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeurodegenerativeDiseases
#
#
# neurodegenerative_diseases
# Query: neurodegenerative disease
# lookup term: neurodegenerative_diseases
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeurodegenerativeDiseases
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# neurodegenerative_diseases
# Query: neurodegenerative disease
# lookup term: neurodegenerative_diseases
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeurodegenerativeDiseases
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# neurodegenerative_diseases
# Query: neurodegenerative disease
# lookup term: neurodegenerative_diseases
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeurodegenerativeDiseases
#
# alzheimers_disease
# Query: alzheimers disease
# lookup term: alzheimers_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2866
#
# alzheimers_disease
# Query: alzheimers disease
# lookup term: alzheimers_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2866
#
# Query: multiple system atrophy
# lookup term: multiple_system_atrophy
#   • Multiple System Atrophy                  URI=http://purl.obolibrary.org/obo/NCIT_C84909
# multiple_system_atrophy
# Query: multiple system atrophy
# lookup term: multiple_system_atrophy
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C84909
#
# Query: multiple sclerosis
# lookup term: multiple_sclerosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3243
#
#
# multiple_sclerosis
# Query: multiple sclerosis
# lookup term: multiple_sclerosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3243
#
# Query: neuromyelitis optica
# lookup term: neuromyelitis_optica
#   • Neuromyelitis Optica                     URI=http://purl.obolibrary.org/obo/NCIT_C84934
# neuromyelitis_optica
# Query: neuromyelitis optica
# lookup term: neuromyelitis_optica
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C84934
#
# Query: amyotrophic lateral sclerosis
# lookup term: amyotrophic_lateral_sclerosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34373
#
#
# amyotrophic_lateral_scleroris
# Query: amyotrophic lateral scleroris
# lookup term: amyotrophic_lateral_scleroris
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34373
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# multiple_system_atrophy
# Query: multiple system atrophy
# lookup term: multiple_system_atrophy
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C84909
#
# synucleinopathies
# Query: synucleinopathies
# lookup term: synucleinopathies
#   → Reusing existing URI: http://purl.obolibrary.org/obo/MONDO_0000510
#
# cognitive_impairment
# Query: cognitive impairment
# lookup term: cognitive_impairment
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C116921
#
#
# hippocampal_volume_loss,_mild
# Query: hippocampal volume loss, mild
# lookup term: hippocampal_volume_loss,_mild
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5394342
#
# cognitive_impairment
# Query: cognitive impairment
# lookup term: cognitive_impairment
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C116921
#
#
# neurodegenerative_diseases
# Query: neurodegenerative disease
# lookup term: neurodegenerative_diseases
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeurodegenerativeDiseases
#
#
# cognitive_impairment
# Query: cognitive impairment
# lookup term: cognitive_impairment
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C116921
#
#
# cognitive_impairment
# Query: cognitive impairment
# lookup term: cognitive_impairment
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C116921
#
# dysbiosis
# Query: dysbiosis
# lookup term: dysbiosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0028544
#
# cognitive_impairment
# Query: cognitive impairment
# lookup term: cognitive_impairment
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C116921
#
#
# cognitive_impairment
# Query: cognitive impairment
# lookup term: cognitive_impairment
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C116921
#
#
# cognitive_impairment
# Query: cognitive impairment
# lookup term: cognitive_impairment
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C116921
#
#
# neurodegenerative_diseases
# Query: neurodegenerative disease
# lookup term: neurodegenerative_diseases
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeurodegenerativeDiseases
#
#
# milieu_therapy
# Query: milieu therapy
# lookup term: milieu_therapy
#   • Milieu Therapy                           URI=http://purl.obolibrary.org/obo/OMIT_0009938 score=1.00
# acute_stress_disorder
# Query: acute stress disorder
# lookup term: acute_stress_disorder
#   • Acute Stress Disorder                    URI=http://purl.obolibrary.org/obo/NCIT_C92621
# acute_stress_disorder
# Query: acute stress disorder
# lookup term: acute_stress_disorder
#   • Acute Stress Disorder                    URI=http://purl.obolibrary.org/obo/NCIT_C92621
# acute_stress_disorder
# Query: acute stress disorder
# lookup term: acute_stress_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C92621
#
#
# acute_stress_disorder
# Query: acute stress disorder
# lookup term: acute_stress_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C92621
#
#
# acute_stress_disorder
# Query: acute stress disorder
# lookup term: acute_stress_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C92621
#
#
# intestinal_dysbiosis
# Query: intestinal dysbiosis
# lookup term: intestinal_dysbiosis
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C4287543
#
# acute_stress_disorder
# Query: acute stress disorder
# lookup term: acute_stress_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C92621
#
#
# dysbiosis
# Query: dysbiosis
# lookup term: dysbiosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0028544
#
# dysregulated_immune_function
# Query: dysregulated immune function
# lookup term: dysregulated_immune_function
#   • UMLS CUI=C5394401  Name='Dysregulated immune function'  sim=1.00
# electrical_resistance
# Query: electrical resistance
# lookup term: electrical_resistance
#   • UMLS CUI=C0162535  Name='electrical resistance'  sim=1.00
# gastric_mucins
# Query: gastric mucin
# lookup term: gastric_mucins
#   → Reusing existing URI: https://meshb.nlm.nih.gov/record/ui?ui=D005752
#
# antibiotic
# Query: antibiotic
# lookup term: antibiotic
#   • Antibiotic                               URI=http://purl.obolibrary.org/obo/NCIT_C258
# Query: traumatic stress
# lookup term: traumatic_stress
#   • Stress Disorders, Traumatic              URI=http://purl.obolibrary.org/obo/OMIT_0023016 score=0.88
# dysregulated_immune_function
# Query: dysregulated immune function
# lookup term: dysregulated_immune_function
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C5394401
#
#
# milieu_therapy
# Query: milieu therapy
# lookup term: milieu_therapy
#   • Milieu Therapy                           URI=http://purl.obolibrary.org/obo/OMIT_0009938 score=1.00
# acute_stress_disorder
# Query: acute stress disorder
# lookup term: acute_stress_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C92621
#
#
# helicobacter_pylori
# Query: helicobacter pylorus
# lookup term: helicobacter_pylori
#   • Helicobacter pylori                      URI=http://purl.obolibrary.org/obo/NCIT_C14289 score=1.00
# Query: neurodegeneration
# lookup term: neurodegeneration
#   → Reusing existing URI: http://purl.obolibrary.org/obo/MP_0002229
#
#
# helicobacter_pylori
# Query: helicobacter pylorus
# lookup term: helicobacter_pylori
#   • Helicobacter pylori                      URI=http://purl.obolibrary.org/obo/NCIT_C14289 score=1.00
# gastric_disease
# Query: gastric disease
# lookup term: gastric_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/MONDO_0004298
#
# Query: peptic ulcer
# lookup term: peptic_ulcers
#   • Peptic Ulcer                             URI=http://purl.obolibrary.org/obo/NCIT_C3318
# Query: gastric cancer
# lookup term: gastric_cancer
#   • UMLS CUI=C0024623  Name='Malignant neoplasm of stomach'  sim=0.00
# Query: neurodegenerative disorder
# lookup term: neurodegenerative_disorders
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C39737
#
#
# hyperhomocysteinemia
# Query: hyperhomocysteinemia
# lookup term: hyperhomocysteinemia
#   • Hyperhomocysteinemia                     URI=http://purl.obolibrary.org/obo/NCIT_C84770
# hyperhomocysteinemia
# Query: hyperhomocysteinemia
# lookup term: hyperhomocysteinemia
#   • Hyperhomocysteinemia                     URI=http://purl.obolibrary.org/obo/NCIT_C84770
# hyperhomocysteinemia
# Query: hyperhomocysteinemia
# lookup term: hyperhomocysteinemia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C84770
#
#
# neurodegenerative_disorders
# Query: neurodegenerative disorder
# lookup term: neurodegenerative_disorders
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C39737
#
# alzheimers_disease
# Query: alzheimers disease
# lookup term: alzheimers_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2866
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# Query: multiple sclerosis
# lookup term: multiple_sclerosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3243
#
#
# Query: glaucoma
# lookup term: glaucoma
#   • Glaucoma                                 URI=http://purl.obolibrary.org/obo/NCIT_C26782
# alzheimers_disease
# Query: alzheimers disease
# lookup term: alzheimers_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2866
#
# Query: neurodegeneration
# lookup term: neurodegeneration
#   → Reusing existing URI: http://purl.obolibrary.org/obo/MP_0002229
#
#
# neurodegenerative_diseases
# Query: neurodegenerative disease
# lookup term: neurodegenerative_diseases
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeurodegenerativeDiseases
#
#
# alzheimers_disease
# Query: alzheimers disease
# lookup term: alzheimers_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2866
#
# helicobacter_pylori
# Query: helicobacter pylorus
# lookup term: helicobacter_pylori
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14289
#
#
# Query: neurodegenerative disorder
# lookup term: neurodegenerative_disorders
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C39737
#
#
# Query: bipolar disorder
# lookup term: bipolar_disorder
#   • Bipolar Disorder                         URI=http://purl.obolibrary.org/obo/NCIT_C34423
# Query: bipolar disorder
# lookup term: bipolar_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34423
#
#
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005141
#
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005141
#
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005141
#
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005141
#
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005141
#
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005141
#
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005141
#
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005141
#
# bipolar_disorder
# Query: bipolar disorder
# lookup term: bipolar_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34423
#
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005141
#
# major_depressive_disorder
# Query: major depressive disorder
# lookup term: major_depressive_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0005141
#
# disorder
# Query: disorder
# lookup term: disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OGMS_0000045
#
# metabolic_disturbance
# Query: metabolic disturbance
# lookup term: metabolic_disturbance
#   • UMLS CUI=C0746556  Name='metabolic disturbance'  sim=1.00
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# Query: bipolar disorder
# lookup term: bipolar_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34423
#
#
# disorder
# Query: disorder
# lookup term: disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OGMS_0000045
#
# Query: metabolic syndrome
# lookup term: metabolic_syndrome
#   • Metabolic Syndrome                       URI=http://purl.obolibrary.org/obo/NCIT_C84442
# disorder
# Query: disorder
# lookup term: disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OGMS_0000045
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# Query: bipolar disorder
# lookup term: bipolar_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34423
#
#
# psychosis
# Query: psychosis
# lookup term: psychosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C78576
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# Query: bipolar disorder
# lookup term: bipolar_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34423
#
#
# metabolic_disturbance
# Query: metabolic disturbance
# lookup term: metabolic_disturbance
#   • UMLS CUI=C0746556  Name='metabolic disturbance'  sim=1.00
# autoimmune_disease
# Query: autoimmune disease
# lookup term: autoimmune_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2889
#
#
# functional_gastrointestinal_disorders
# Query: functional gastrointestinal disorder
# lookup term: functional_gastrointestinal_disorders
#   → Reusing existing URI: https://bioportal.bioontology.org/ontologies/EDAM?p=classes&conceptid=topic_3409
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# Query: autoimmunity
# lookup term: autoimmunity
#   • Autoimmunity                             URI=http://purl.obolibrary.org/obo/OMIT_0016272 score=1.00
# disorder
# Query: disorder
# lookup term: disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OGMS_0000045
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# disorder
# Query: disorder
# lookup term: disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OGMS_0000045
#
# coeliac_disease
# Query: coeliac disease
# lookup term: coeliac_disease
#   → Reusing existing URI: https://disease-ontology.org/?id=DOID:10608
#
# coeliac_disease
# Query: coeliac disease
# lookup term: coeliac_disease
#   → Reusing existing URI: https://disease-ontology.org/?id=DOID:10608
#
# inflammation
# Query: inflammation
# lookup term: inflammation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3137
#
# Query: humoral immunity
# lookup term: humoral_immunity
#   • Humoral Immunity                         URI=http://purl.obolibrary.org/obo/NCIT_C16712
# Query: schizophrenia
# lookup term: schizophrenia
# ...
# cardiovascular_diseases
# Query: cardiovascular disease
# lookup term: cardiovascular_diseases
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0007222
#
#
# Query: ischemic and non-ischemic heart disease
# lookup term: ischemic_and_non-ischemic_heart_disease
#   • Ischemic Heart Disease                   URI=http://purl.obolibrary.org/obo/NCIT_C50625 score=0.91
# inflammation
# Query: inflammation
# lookup term: inflammation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3137
#
# Query: liver disease
# lookup term: liver_diseases
#   • UMLS CUI=C0023895  Name='Liver diseases'  sim=1.00
# Query: inflammatory bowel disease
# lookup term: inflammatory_bowel_diseases
#   • Inflammatory Bowel Disease               URI=http://purl.obolibrary.org/obo/NCIT_C3138
# Query: rheumatoid arthritis
# lookup term: rheumatoid_arthritis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2884
#
#
# Query: neurologic disorder
# lookup term: neurologic_disorders
#   • Neurologic                               URI=http://purl.obolibrary.org/obo/NCIT_C25262 score=0.86
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# alzheimers_disease
# Query: alzheimers disease
# lookup term: alzheimers_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C2866
#
# Query: multiple sclerosis
# lookup term: multiple_sclerosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3243
#
#
# Query: amyotrophic lateral sclerosis
# lookup term: amyotrophic_lateral_sclerosis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34373
#
#
# nervous_system_disorder
# Query: nervous system disorder
# lookup term: nervous_system_disorder
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26835
#
# Query: motor dysfunction
# lookup term: motor_dysfunction
#   • UMLS CUI=C5979810  Name='Motor dysfunction'  sim=1.00
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# Query: gastrointestinal dysfunction
# lookup term: gastrointestinal_dysfunction
#   • Gastrointestinal Dysfunction             URI=http://purl.obolibrary.org/obo/NCIT_C162870
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   • Parkinson Disease                        URI=http://purl.obolibrary.org/obo/NCIT_C26845
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   • Parkinson Disease                        URI=http://purl.obolibrary.org/obo/NCIT_C26845
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# Query: salsolinol-induced toxicity
# lookup term: salsolinol-induced_toxicity
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/SalsolinolInducedToxicity
#
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# Query: progressive neurodegenerative disorder
# lookup term: progressive_neurodegenerative_disorder
#   • UMLS CUI=C0027746  Name='Nerve Degeneration'  sim=0.00
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# neurodegenerative_diseases
# Query: neurodegenerative disease
# lookup term: neurodegenerative_diseases
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/NeurodegenerativeDiseases
#
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# salsolinol-induced_toxicity
# Query: salsolinol-induced toxicity
# lookup term: salsolinol-induced_toxicity
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/diseasedisorderorfinding/SalsolinolInducedToxicity
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# Query: anxiety
# lookup term: anxiety
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26696
#
#
# Query: depression
# lookup term: depression
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C124639
#
#
# Query: inflammation
# lookup term: inflammation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3137
#
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# dyskinetic_syndrome
# Query: dyskinetic syndrome
# lookup term: dyskinetic_syndrome
#   • Syndrome                                 URI=http://purl.obolibrary.org/obo/NCIT_C28193 score=1.00
# Query: parkinsonian symptom
# lookup term: parkinsonian_symptoms
#   • Symptom                                  URI=http://purl.obolibrary.org/obo/NCIT_C4876 score=1.00
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# Query: mptp lesion
# lookup term: mptp_lesion
#   • Lesion                                   URI=http://purl.obolibrary.org/obo/NCIT_C71163 score=1.00
# parkinson_disease
# Query: parkinson disease
# lookup term: parkinson_disease
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26845
#
#
# Query: schizophrenia
# lookup term: schizophrenia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C3362
#
#
# disease
# Query: disease
# lookup term: disease
#   • Disease                                  URI=http://purl.obolibrary.org/obo/OMIT_0005457 score=1.00
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File c:\Python312\Lib\socket.py:964, in getaddrinfo(host, port, family, type, proto, flags)
#     963 addrlist = []
# --> 964 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     965     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:490, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     489         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 490     raise new_e
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connection.py:693, in HTTPSConnection.connect(self)
#     692 sock: socket.socket | ssl.SSLSocket
# --> 693 self.sock = sock = self._new_conn()
#     694 server_hostname: str = self.host
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connection.py:206, in HTTPConnection._new_conn(self)
#     205 except socket.gaierror as e:
# --> 206     raise NameResolutionError(self.host, self, e) from e
#     207 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x000001A5028D1940>: Failed to resolve 'api.groq.com' ([Errno 11001] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.groq.com', port=443): Max retries exceeded with url: /openai/v1/chat/completions (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001A5028D1940>: Failed to resolve 'api.groq.com' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[8], line 1086
#    1084 g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
#    1085 uri_str = str(name_uri)
# -> 1086 definition = choose_definition(uri_str, term_raw)
#    1087 existing_defs = [
#    1088     c for c in g.objects(name_uri, RDFS.comment)
#    1089     if "[Definition Source:" in str(c)
#    1090 ]
#    1091 if not existing_defs:
#
# Cell In[7], line 167, in choose_definition(uri_str, term_raw)
#     165     return f"{raw_mesh.strip()} [Definition Source: MeSH]"
#     166 else:
# --> 167     llm_def = get_llm_definition(term_raw)
#     168     return f"{llm_def} [Definition Source: llama3-8b-8192]"
#
# File c:\Users\samue\OneDrive\Desktop\ThesisPiron\groqutils.py:42, in get_llm_definition(term, model, max_tokens, backoff)
#      28 headers = {
#      29     "Authorization": f"Bearer {GROQ_API_KEY}",
#      30     "Content-Type": "application/json",
#      31 }
#      32 payload = {
#      33     "model": model,
#      34     "messages": [
#    (...)
#      39     "temperature": 0.0,
#      40 }
# ---> 42 resp = requests.post(GROQ_CHAT_URL, json=payload, headers=headers)
#      43 resp.raise_for_status()
#      44 data = resp.json()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='api.groq.com', port=443): Max retries exceeded with url: /openai/v1/chat/completions (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001A5028D1940>: Failed to resolve 'api.groq.com' ([Errno 11001] getaddrinfo failed)"))

# %% [markdown]
# <h1>INGEST ANIMAL</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint
from rdflib.namespace import DCTERMS
from groqutils import get_llm_definition
from funcutils import get_ncit_description, get_chebi_description, get_omit_description, NCBI_BASE, HEREDITARY_BASE, UMLS_BASES, foodon_file, ncit_file, omit_file, chebi_file, hash_term_sha256

ANIMAL_BASE = "http://purl.obolibrary.org/obo/"
ANIMAL_CLASS = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/Animal")
ANIMAL_CONCEPT_SCHEME = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/Animal")

def load_animal_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = ANIMAL_BASE + term_id
            rows.append((label, uri))
    return rows

ANIMAL_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncbitaxon_full_taxonomy.txt"
NCIT_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncit_full_taxonomy.txt"
animal_rows = load_animal_labels(ANIMAL_LABELS_FILE)
ncit_rows = load_animal_labels(NCIT_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in animal_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

exact_ix1 = defaultdict(list)
for lbl, uri in ncit_rows:
    exact_ix1[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in animal_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

labels_only1 = [preprocess(lbl) for lbl, _ in ncit_rows]
vec1 = TfidfVectorizer(stop_words="english")
mat1 = vec1.fit_transform(labels_only1)

def top_cosine(term, k=5, thr=0.78):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = animal_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

def top_cosine_ncit(term, k=5, thr=0.80):
    v  = vec1.transform([term])
    sc = cosine_similarity(v, mat1).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = ncit_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

manual_created = {
                "animal" : URIRef("http://purl.obolibrary.org/obo/NCIT_C14182"),
                "mouse_intestinal_tract" : URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/animal/MouseIntestinalTract"),
                "offspring" : URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0680063"),
                "mouse_mother":URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/animal/MouseMother"),
                "caenorhabditis_elegans":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0162610"),
                "mutant":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0596988"),
                "helminths": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0018893"),
                "zebrafish":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0043457"),
                "fruit_fly":URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/animal/FruitFly"),
                "treated_group": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/animal/TreatedGroup"),

}
created = dict(manual_created)

regex_map = [
                (r"mouse",           "mus_musculus"),
                (r"mild_stress__cums__group","mus_musculus"),
                (r"worm","helminths"),
                (r"taconic_c57bl_6j","taconic_c57bl_6n"),
                (r"ko___sdv_group","mus_musculus"),
                (r"three_groups__wild-type__wt____sham_group__ko___sham_group__ko___sdv_group_","mus_musculus"),
                (r"three_group","animal"),
                (r"pm_group","animal"),
                (r"parasitic_worm","helminths"),
                (r"dexamethasone__dex__group","animal"),
                (r"dex_group","animal"),
                (r"cums_group","mus_musculus"),
                (r"cums_and_dex_group","mus_musculus"),
                (r"germ-free_animal","animal"),
                (r"antibiotic-treated_group","mus_musculus"),
                (r"spf_animal","animal"),
                (r"nematode_caenorhabditis_elegan","caenorhabditis_elegans"),
                (r"bacterial_mutant","mutant"),
                (r"skin_lipid",     "skin"),
                (r"mice",            "mus_musculus"),
                (r"rat"     ,        "mus_musculus"),
                (r"dogs"   ,         "canis_lupus_familiaris"),
                (r"children"  ,      "offspring"),
                (r"young_and_aging_animal","animal"),
                (r"lactating_offspring","offspring"),
                (r"newborn_wild-type__wt__pup","offspring"),
                (r"ko_dam","mouse_mother"),
                (r"child",           "offspring"),
                (r"ampillicin_ns9_treated_group","treated_group"),
                (r"wt_offspring","offspring"),
                (r"\bwt\b","offspring"),
                (r"\bko\b","mus_musculus"),
                (r"\bmptp-treated_group\b","control_group"),
                (r"\bc__elegan\w*\b","caenorhabditis_elegans"),
                (r"pig"     ,        "sus"),
                (r"bird"   ,        "aves"),
                (r"rodent"  ,       "rodentia"),
                (r"6-ohda"  ,       "mus_musculus"),
                (r"sps-susceptible_male", "mus_musculus"),
                (r"sps-susceptible_female", "mus_musculus"),
                (r"SPS-resilient_females" ,"mus_musculus"),
                (r"SPS-resilient_males", "mus_musculus"),
                (r"sps resilient_females" ,"mus_musculus"),
                (r"sps-s_males", "mus_musculus"),
                (r"female", "animal"),
                (r"plx5622-treated_group","treated_group"),
                (r"gastrointestinal__gi__tract", "mouse_intestinal_tract"),
                (r"male", "animal"),
                (r"females", "animal"),
                (r"males", "animal"),
]
CREATOR = "Samuel Piron"

UMLS_BASES = "https://uts.nlm.nih.gov/uts/umls/concept/"

for uri in manual_created.values():
    uri_str = str(uri)

    if uri_str.startswith(UMLS_BASES):
        # only a UMLS‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("UMLS Match", datatype=XSD.string)))
    elif "NCIT" in uri_str:
        # only a NCIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("NCIT Match", datatype=XSD.string)))
    elif "OMIT" in uri_str:
        # only a OMIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("OMIT Match", datatype=XSD.string)))
    elif "NCBITaxon" in uri_str:
        # only a NCBITaxon‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("NCBITaxon Match", datatype=XSD.string)))
    else:
        # everything else still gets a creator
        g.add((uri,
               DCTERMS.creator,
               Literal(CREATOR, datatype=XSD.string)))
        
for term_raw, uri in manual_created.items():
    uri_str = str(uri)

    # NCIT definitions
    if uri_str.startswith(NCBI_BASE) and "NCIT_" in uri_str:
        ncit_id = uri_str.rsplit("_", 1)[-1]
        desc = get_ncit_description(ncit_id, ncit_file)
        m = re.search(r'—\s*(.*?)\s*—', desc)
        if m:
            desc = m.group(1).strip()
            comment = f"{desc} [Definition Source: NCIT]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # UMLS definitions
    elif uri_str.startswith(UMLS_BASES):
        cui = uri_str.rsplit("/", 1)[-1]
        defn = get_umls_definition(cui)
        if defn:
            comment = f"{defn.strip()} [Definition Source: UMLS]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # MeSH definitions via your mesh_index
    elif uri_str.startswith(MESH_BASE):
        ui     = uri_str.rsplit("/",1)[-1]
        hits   = [d['name'] for d in mesh_descs if d['ui']==ui]
        if hits:
            comment = f"{hits[0]} [Definition Source: MeSH]"
        elif term_raw == "patients":
            comment = "Patients with various diseases. [Definition Source: GUTBRAIN]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    elif uri_str.startswith(HEREDITARY_BASE):
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"
    else:
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    g.add((uri,
           RDFS.comment,
           Literal(comment, datatype=XSD.string)))
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "animal":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, ANIMAL_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, ANIMAL_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine_ncit(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, ANIMAL_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                    g.add((entity_uri, RDFS.comment, Literal("NCBITaxon Match", datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, ANIMAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                    g.add((name_uri, RDFS.comment, Literal("NCBITaxon Match", datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, ANIMAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                    g.add((name_uri, RDFS.comment, Literal("NCIT Match", datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

print("entering gold")

for paper_id, paper_data in data_gold.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "animal":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, ANIMAL_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, ANIMAL_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine_ncit(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, ANIMAL_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                    g.add((entity_uri, RDFS.comment, Literal("NCBITaxon Match", datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, ANIMAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                    g.add((name_uri, RDFS.comment, Literal("NCBITaxon Match", datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, ANIMAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                    g.add((name_uri, RDFS.comment, Literal("NCIT Match", datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

print("entering dev")

for paper_id, paper_data in data_dev.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "animal":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, ANIMAL_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, ANIMAL_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine_ncit(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, ANIMAL_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                    g.add((entity_uri, RDFS.comment, Literal("NCBITaxon Match", datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, ANIMAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                    g.add((name_uri, RDFS.comment, Literal("NCBITaxon Match", datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, ANIMAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                    g.add((name_uri, RDFS.comment, Literal("NCIT Match", datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip()
        else:
            continue

        if label != "animal":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_gold_file, "r", encoding="utf-8") as f_sent:
    tokenized_gold_data = json.load(f_sent)

for entry in tokenized_gold_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "animal":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_dev, "r", encoding="utf-8") as f_sent:
    tokenized_dev_data = json.load(f_sent)

for entry in tokenized_dev_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "animal":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))
# Out:
# aves
# Query: aves
# lookup term: aves
#   • Aves                                     URI=http://purl.obolibrary.org/obo/NCBITaxon_8782
# aves
# Query: aves
# lookup term: aves
#   • Aves                                     URI=http://purl.obolibrary.org/obo/NCBITaxon_8782
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# Query: offspring
# lookup term: offspring
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0680063
#
#
# Query: mother
# lookup term: mother
#   • Mother                                   URI=http://purl.obolibrary.org/obo/NCIT_C25189 score=1.00
#
# offspring
# Query: offspring
# lookup term: offspring
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0680063
#
# Query: mother
# lookup term: mother
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C25189
#
#
# offspring
# Query: offspring
# lookup term: offspring
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0680063
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# Query: dog
# lookup term: dog
#   • Dog                                      URI=http://purl.obolibrary.org/obo/NCIT_C14201 score=1.00
#
# Query: dog
# lookup term: dog
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14201
#
#
# Query: dog
# lookup term: dog
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14201
#
#
# Query: dog
# lookup term: dog
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14201
#
#
# Query: dog
# lookup term: dog
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14201
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mouse_intestinal_tract
# Query: mouse intestinal tract
# lookup term: mouse_intestinal_tract
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/animal/MouseIntestinalTract
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# rodentia
# Query: rodentia
# lookup term: rodentia
#   • Rodentia                                 URI=http://purl.obolibrary.org/obo/NCBITaxon_9989
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# sus
# Query: sus
# lookup term: sus
#   • Sus                                      URI=http://purl.obolibrary.org/obo/NCBITaxon_9822
# entering gold
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# offspring
# Query: offspring
# lookup term: offspring
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0680063
#
# offspring
# Query: offspring
# lookup term: offspring
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0680063
#
# offspring
# Query: offspring
# lookup term: offspring
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0680063
#
# mouse_mother
# Query: mouse mother
# lookup term: mouse_mother
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/animal/MouseMother
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# offspring
# Query: offspring
# lookup term: offspring
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0680063
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# offspring
# Query: offspring
# lookup term: offspring
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0680063
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# offspring
# Query: offspring
# lookup term: offspring
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0680063
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# Query: c  elegan
# lookup term: c__elegan
# no matches
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# helminths
# Query: helminths
# lookup term: helminths
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0018893
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# Query: control  con  group
# lookup term: control__con__group
#   • Control Group                            URI=http://purl.obolibrary.org/obo/NCIT_C28143 score=1.00
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# Query: control group
# lookup term: control_group
#   • Control Group                            URI=http://purl.obolibrary.org/obo/NCIT_C28143 score=1.00
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# rodentia
# Query: rodentia
# lookup term: rodentia
#   • Rodentia                                 URI=http://purl.obolibrary.org/obo/NCBITaxon_9989
# rodentia
# Query: rodentia
# lookup term: rodentia
#   • Rodentia                                 URI=http://purl.obolibrary.org/obo/NCBITaxon_9989
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# Query: donor
# lookup term: donor
#   • Donor                                    URI=http://purl.obolibrary.org/obo/NCIT_C48284 score=1.00
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# Query: caenorhabditis elegan
# lookup term: caenorhabditis_elegan
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0162610
#
#
# caenorhabditis_elegans
# Query: caenorhabditis elegans
# lookup term: caenorhabditis_elegans
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0162610
#
# mutant
# Query: mutant
# lookup term: mutant
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0596988
#
# Query: c  elegan
# lookup term: c__elegan
# no matches
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# rodentia
# Query: rodentia
# lookup term: rodentia
#   • Rodentia                                 URI=http://purl.obolibrary.org/obo/NCBITaxon_9989
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# helminths
# Query: helminths
# lookup term: helminths
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0018893
#
# Query: helminth
# lookup term: helminth
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0018893
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# Query: balb c
# lookup term: balb_c
#   • BALB/c Mouse                             URI=http://purl.obolibrary.org/obo/NCIT_C37357 score=0.88
#
# Query: orient c57bl 6n
# lookup term: orient_c57bl_6n
#   • C57BL/6N Mouse                           URI=http://purl.obolibrary.org/obo/NCIT_C37385 score=0.94
#
# Query: taconic c57bl 6n
# lookup term: taconic_c57bl_6n
#   • C57BL/6N Mouse                           URI=http://purl.obolibrary.org/obo/NCIT_C37385 score=0.94
#
# taconic_c57bl_6n
# Query: taconic c57bl 6n
# lookup term: taconic_c57bl_6n
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C37385
#
# Query: caenorhabditis elegan
# lookup term: caenorhabditis_elegan
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0162610
#
#
# Query: caenorhabditis elegan
# lookup term: caenorhabditis_elegan
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0162610
#
#
# Query: c  elegan
# lookup term: c__elegan
# no matches
# Query: c  elegan
# lookup term: c__elegan
# no matches
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# Query: offspring
# lookup term: offspring
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0680063
#
#
# rodentia
# Query: rodentia
# lookup term: rodentia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_9989
#
#
# Query: adult offspring
# lookup term: adult_offspring
#   • Offspring                                URI=http://purl.obolibrary.org/obo/NCIT_C42708 score=0.88
#
# Query: offspring
# lookup term: offspring
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0680063
#
#
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# Query: zebrafish
# lookup term: zebrafish
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0043457
#
#
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# Query: dog
# lookup term: dog
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14201
#
#
# Query: dog
# lookup term: dog
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14201
#
#
# Query: dog
# lookup term: dog
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14201
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# rodentia
# Query: rodentia
# lookup term: rodentia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_9989
#
#
# rodentia
# Query: rodentia
# lookup term: rodentia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_9989
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# rodentia
# Query: rodentia
# lookup term: rodentia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_9989
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# Query: mammal
# lookup term: mammal
#   • mammal metagenome                        URI=http://purl.obolibrary.org/obo/NCBITaxon_3127350 score=0.82
#
# Query: fruit fly
# lookup term: fruit_fly
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/animal/FruitFly
#
#
# Query: drosophila melanogaster
# lookup term: drosophila_melanogaster
#   • Drosophila melanogaster                  URI=http://purl.obolibrary.org/obo/NCBITaxon_7227
# Query: drosophila
# lookup term: drosophila
#   • Drosophila sp. T                         URI=http://purl.obolibrary.org/obo/NCBITaxon_381473 score=0.98
#
# Query: drosophila
# lookup term: drosophila
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_381473
#
#
# entering dev
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# Query: mptp-treated group
# lookup term: mptp-treated_group
# no matches
# Query: control group
# lookup term: control_group
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C28143
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# Query: ampillicin ns9 treated group
# lookup term: ampillicin_ns9_treated_group
# no matches
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# Query: older tg animal
# lookup term: older_tg_animal
#   • Klebsiella sp. TG-1                      URI=http://purl.obolibrary.org/obo/NCBITaxon_876701 score=0.82
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# Query: plx5622-treated group
# lookup term: plx5622-treated_group
# no matches
# Query: plx5622-treated group
# lookup term: plx5622-treated_group
# no matches
# Query: control group
# lookup term: control_group
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C28143
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# animal
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# Query: animal
# lookup term: animal
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# rodentia
# Query: rodentia
# lookup term: rodentia
#   • Rodentia                                 URI=http://purl.obolibrary.org/obo/NCBITaxon_9989
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#
# mus_musculus
# Query: mus musculus
# lookup term: mus_musculus
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090

# %% [markdown]
# <h1>INGEST DIETARY SUPPLEMENT</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint
from nltk.stem import WordNetLemmatizer
from rdflib import Graph, Namespace, URIRef
from rdflib.namespace import RDFS
from rdflib.namespace import DCTERMS
from groqutils import get_llm_definition
from funcutils import get_ncit_description, get_chebi_description, get_omit_description, NCBI_BASE, HEREDITARY_BASE, UMLS_BASES, foodon_file, ncit_file, omit_file, chebi_file, hash_term_sha256, get_foodon_description

DIETARYSUPPLEMENT_BASE = "http://purl.obolibrary.org/obo/"
DIETARYSUPPLEMENT_CLASS = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/DietarySupplement")
DIETARYSUPPLEMENT_CONCEPT_SCHEME = URIRef("https://w3id.org/hereditary/ontology/gutbrain/schema/conceptScheme/DietarySupplement")

lemmatizer = WordNetLemmatizer()

#created = {}

# 1.1) keep only your hand-picked seeds here
manual_created = {
    "dietary_supplementation":  URIRef("https://www.ncbi.nlm.nih.gov/mesh/68019587"),
    "egcg":                     URIRef("http://purl.obolibrary.org/obo/XCO_0001093"),
    "hippophae_rhamnoide":      URIRef("http://purl.obolibrary.org/obo/NCBITaxon_193516"),
    "prebiotic":                URIRef("http://purl.obolibrary.org/obo/OMIT_0026689"),
    "acacetin":                 URIRef("http://purl.obolibrary.org/obo/CHEBI_15335"),
    "probiotic":                URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0525033"),  
    "gluten":                   URIRef("http://purl.obolibrary.org/obo/FOODON_03420177"),
    "triphala":                 URIRef("https://www.ncbi.nlm.nih.gov/mesh/67520904"),
    "lacticaseibacillus_rhamnosus": URIRef("http://purl.obolibrary.org/obo/NCBITaxon_47715"),
    "metabolite" :URIRef("http://purl.obolibrary.org/obo/CHEBI_25212"),
    "nvp-1704" : URIRef("http://purl.obolibrary.org/obo/CHEBI_230487"),
    "micronutrient" : URIRef("http://purl.obolibrary.org/obo/CHEBI_27027"),
    "lactobacillus" : URIRef("http://purl.obolibrary.org/obo/NCBITaxon_1578"),
    "food" : URIRef("http://purl.obolibrary.org/obo/NCIT_C62695"),
    "polyphenol" : URIRef("http://purl.obolibrary.org/obo/CHEBI_26195"),
    "short-chain_fatty_acid" : URIRef("http://purl.obolibrary.org/obo/CHEBI_26666"),
    "microbiota_modulator": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/MicrobiotaModulator"),
    "date_seed_powder":URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/DateSeedPowder"),
    "psychobiotic": URIRef("https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/Psychobiotic"),
    "synbiotic_supplement": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C3274627"),
    "lactobacillus_helveticus": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0317592"),
    "vitamins":URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0042890"),
    "milk,_human": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C0026140"),
    "nutraceuticals": URIRef("https://uts.nlm.nih.gov/uts/umls/concept/C1518478"),

}

created = dict(manual_created)

regex_map = [
    (r"\bprobiot(?:ic|ics|ic_supplementation)\b", "probiotic"),
    (r"\bsynbiotic_supplementation\b","synbiotic_supplement"),
    (r"\bsynbiotics_supplementation\w*\b","synbiotic_supplement"),
    (r"\bns9\b","lactobacillus_fermentum"),
    (r"supplemental_lactobacillus_helveticus_ns8","lactobacillus_helveticus"),
    (r"\bl__helveticus_ns8\b","lactobacillus_helveticus"),
    (r"\blipid-based_nutraceutical\b","lipid"),
    (r"\bslab51\b","probiotic"),
    (r"\bsingle_nutrient_supplementation\b","nutrient"),
    (r"\bcarbohydrate-type_prebiotic\b","prebiotic"),
    (r"\bmultinutrient\b","nutrient"),
    (r"broad-spectrum_multinutrient","nutrient"),
    (r"supplemental_vitamin_use","vitamins"),
    (r"feed_additive",       "feed"),
    (r"\bnovel_prebiotic\b","prebiotic"),
    (r"\bbioactive_milk_fraction\b","milk,_human"),
    (r"\bgo\b","galactooligosaccharide"),
    (r"\bpdx\b","polydextrose"),
    (r"\bnon-caloric_artificial_sweetener\b","artificial_sweetener"),
    (r"next-generation_feed_additive", "feed"),
    (r"\bmicronutrient_supplementation\b", "micronutrient"),
    (r"\bmicronutrient_treatment\b", "micronutrient"),
    (r"seabuckthorn","hippophae_rhamnoide"),
    (r"vsl__3","prebiotic"),
    (r"vsl_3","prebiotic"),
    (r"sbf","hippophae_rhamnoide"),
    (r"\bwheat_germ\w*\b","fermented_wheat_germ"),
    (r"\bfwg\w*\b","fermented_wheat_germ"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))probiotic\w*\b", "probiotic"),
    (r"postbiotic","metabolite"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))scfa\w*\b","short-chain_fatty_acid"),
    (r"\btriphala_polyphenol\w*\b","polyphenol"),
    (r"\bpolyphenol\w*\b", "polyphenol"),
    (r"prebiotic_supplementation","synbiotic_supplement"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))starch\w*\b","Starch"),
    (r"nvp-1704_treatment", "probiotic"),
    (r"danggui_buxue_decoction","medication"),
    (r"\bdbd\w*\b","medication"),
    (r"f4_consumption","lactobacillus"),
    (r"f4_supplementation","lactobacillus"),
    (r"medicinal_herb", "medication"),
    (r"\bprebiotic\w*\b","prebiotic"),
    (r"b__licheniformi","bacillus"),
    (r"plant_polysaccharide","plant"),
    (r"zhe_busong_decoction","triphala"),
    (r"\blacticaseibacillus_rhamnosus\w*\b", "lacticaseibacillus_rhamnosus"),
    (r"high-cholesterol_diet", "diet"),
    (r"\bbacillus_licheniformi\w*\b", "bacillus"),
    (r"\bb__licheniformi\w*\b", "bacillus"),
    (r"sialylated_human_milk_oligosaccharide","milk,_human"),
    (r"human_milk_oligosaccharide","milk,_human"),
    (r"\bneutraceutical_supplementation\w*\b","nutraceuticals")
    (r"\bhmo\b","human_milk"),
    (r"\bsialylated_hmo\b","human_milk"),
    (r"\bmicrobiota_modulator\b","microbiota_modulator"),
    (r"\bna\b","artificial_sweetener"),
    (r"date_seed_powder","date_seed_powder"),
    (r"\bdsp\b","date_seed_powder"),
    (r"\bdsp_supplementation\b","date_seed_powder"),
]

for term_raw, uri in manual_created.items():
    uri_str = str(uri)

    # NCIT definitions
    if uri_str.startswith(NCBI_BASE) and "NCIT_" in uri_str:
        ncit_id = uri_str.rsplit("_", 1)[-1]
        desc = get_ncit_description(ncit_id, ncit_file)
        m = re.search(r'—\s*(.*?)\s*—', desc)
        if m:
            desc = m.group(1).strip()
            comment = f"{desc} [Definition Source: NCIT]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # UMLS definitions
    elif uri_str.startswith(UMLS_BASES):
        cui = uri_str.rsplit("/", 1)[-1]
        defn = get_umls_definition(cui)
        if defn:
            comment = f"{defn.strip()} [Definition Source: UMLS]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    # MeSH definitions via your mesh_index
    elif uri_str.startswith(MESH_BASE):
        ui     = uri_str.rsplit("/",1)[-1]
        hits   = [d['name'] for d in mesh_descs if d['ui']==ui]
        if hits:
            comment = f"{hits[0]} [Definition Source: MeSH]"
        elif term_raw == "patients":
            comment = "Patients with various diseases. [Definition Source: GUTBRAIN]"
        else:
            llm_def = get_llm_definition(term_raw)
            comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    elif uri_str.startswith(HEREDITARY_BASE):
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"
    else:
        llm_def = get_llm_definition(term_raw)
        comment = f"{llm_def} [Definition Source: llama3-8b-8192]"

    g.add((uri,
           RDFS.comment,
           Literal(comment, datatype=XSD.string)))

def load_dietary_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = DIETARYSUPPLEMENT_BASE + term_id
            rows.append((label, uri))
    return rows

def load_chebi_labels(path):
    rows = []
    with open(path, encoding="utf-8") as fh:
        next(fh) 
        for ln in fh:
            uri, label = ln.rstrip("\n").split("\t", 1)
            rows.append((label, uri))
    return rows

CHEBI_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\chebi_labels.txt"
PARSED_NCIT_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\ncit_full_taxonomy.txt"
DIETARYSUPPLEMENT_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncit_full_taxonomy.txt"
dietary_rows = load_dietary_labels(DIETARYSUPPLEMENT_LABELS_FILE)
chebi_rows = load_chebi_labels(CHEBI_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in dietary_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

exact_ix1 = defaultdict(list)
for lbl, uri in chebi_rows:
    exact_ix1[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in dietary_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

labels_only1 = [preprocess(lbl) for lbl, _ in chebi_rows]
vec1 = TfidfVectorizer(stop_words="english")
mat1 = vec1.fit_transform(labels_only1)

def top_cosine(term, k=5, thr=0.80):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = dietary_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

def top_cosine_chebi(term, k=5, thr=0.80):
    v  = vec1.transform([term])
    sc = cosine_similarity(v, mat1).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = chebi_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

CREATOR = "Samuel Piron"

UMLS_BASES = "https://uts.nlm.nih.gov/uts/umls/concept/"
#MESH_BASE = "https://meshb.nlm.nih.gov/record/ui?ui="

for uri in manual_created.values():
    uri_str = str(uri)

    if uri_str.startswith(UMLS_BASES):
        # only a UMLS‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("UMLS Match", datatype=XSD.string)))
    elif "NCIT" in uri_str:
        # only a NCIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("NCIT Match", datatype=XSD.string)))
    elif "OMIT" in uri_str:
        # only a OMIT‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("OMIT Match", datatype=XSD.string)))
    elif "NCBITaxon" in uri_str:
        # only a NCBITaxon‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("NCBITaxon Match", datatype=XSD.string)))
    elif "CHEBI" in uri_str:
        # only a CHEBI‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("CHEBI Match", datatype=XSD.string)))
    elif "FOODON" in uri_str:
        # only a FOODON‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("FOODON Match", datatype=XSD.string)))
    elif "mesh" in uri_str:
        # only a MESH‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("MESH Match", datatype=XSD.string)))
    elif "XCO" in uri_str:
        # only a XCO‐Match comment
        g.add((uri,
               RDFS.comment,
               Literal("XCO Match", datatype=XSD.string)))
    else:
        # everything else still gets a creator
        g.add((uri,
               DCTERMS.creator,
               Literal(CREATOR, datatype=XSD.string)))
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        if raw_label == "dietary supplement":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine_chebi(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

print("entering gold")

for paper_id, paper_data in data_gold.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        if raw_label == "dietary supplement":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine_chebi(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

print("entering dev")

for paper_id, paper_data in data_dev.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        if raw_label == "dietary supplement":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    print(lookup_key)
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            print(f"lookup term: {lookup_key}")
            
            
            if term_raw in created:

                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                g.add((entity_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            if lookup_key in created:
                print(f"  → Reusing existing URI: {created[lookup_key]}")
                entity_uri = created[lookup_key]
                g.add((entity_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                g.add((entity_uri, RDF.type, SKOS.Concept))
                g.add((entity_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                if (entity_uri, RDFS.label, None) not in g:
                    g.add((entity_uri,
                            RDFS.label,
                            Literal(term.title(), datatype=XSD.string)))
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                print()
                continue

            ex = exact_ix.get(term, [])
            cos = top_cosine(term)
            cos1 = top_cosine_chebi(term)
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    if (entity_uri, RDFS.label, None) not in g:
                        g.add((entity_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                    uri_str = str(entity_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    else:
                        comment = CREATOR 
                    g.add((entity_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(entity_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(entity_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((entity_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            elif cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    if (name_uri, RDFS.label, None) not in g:
                        g.add((name_uri,
                            RDFS.label,
                            Literal(lbl.title(), datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                    uri_str = str(name_uri).lower()

                    if "stato_" in uri_str:
                        comment = "STATO Match"
                    elif "ncbitaxon_" in uri_str:
                        comment = "NCBITaxon Match"
                    elif "ncit_" in uri_str:
                        comment = "NCIT Match"
                    elif "obi_" in uri_str:
                        comment = "OBI Match"
                    elif "umls" in uri_str:
                        comment = "UMLS Match"
                    elif "omit" in uri_str:
                        comment = "OMIT Match"
                    elif "chebi" in uri_str:
                        comment = "CHEBI Match"
                    else:
                        comment = CREATOR 
                    g.add((name_uri, RDFS.comment, Literal(comment, datatype=XSD.string)))
                    uri_str = str(name_uri)
                    definition = choose_definition(uri_str, term_raw)
                    existing_defs = [
                        c for c in g.objects(name_uri, RDFS.comment)
                        if "[Definition Source:" in str(c)
                    ]
                    if not existing_defs:
                        g.add((name_uri,
                            RDFS.comment,
                            Literal(definition, datatype=XSD.string)))
                    mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(term_raw, max_length=16)])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip()
        else:
            continue

        if label != "dietary supplement":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_gold_file, "r", encoding="utf-8") as f_sent:
    tokenized_gold_data = json.load(f_sent)

for entry in tokenized_gold_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "dietary supplement":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

with open(tokenized_dev, "r", encoding="utf-8") as f_sent:
    tokenized_dev_data = json.load(f_sent)

for entry in tokenized_dev_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAINSENTENCE[f"{pmid}_{sent_id}"])
    g.add((sent_uri, RDFS.label, Literal(f"sentence_{pmid}_{sent_id}", datatype=XSD.string)))
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAINTITLE[f"{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAINABSTRACT[f"{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "dietary supplement":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAINMENTION[hash_term_sha256(cleaned_text_span, max_length=16)])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

output_file = os.path.join(save_path, "gutbrain_entities.ttl")
ttl_output = g.serialize(format="turtle")
with open(output_file, "w", encoding="utf-8") as f_out:
    f_out.write(ttl_output)

print(f"The RDF graph has been saved in {output_file}")
# Out:
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
#
# Query: dietary supplementation
# lookup term: dietary_supplementation
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/68019587
#
#
# feed
# Query: feed
# lookup term: feed
#   • Feed                                     URI=http://purl.obolibrary.org/obo/NCIT_C69427
# feed
# Query: feed
# lookup term: feed
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C69427
#
#
# feed
# Query: feed
# lookup term: feed
#   • Feed                                     URI=http://purl.obolibrary.org/obo/NCIT_C69427
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: phytochemical
# lookup term: phytochemical
#   • Phytochemical                            URI=http://purl.obolibrary.org/obo/NCIT_C28269
# Query: nutrient
# lookup term: nutrient
#   • Nutrient                                 URI=http://purl.obolibrary.org/obo/NCIT_C1814
# Query: phytochemical
# lookup term: phytochemical
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C28269
#
#
# Query: phytochemical
# lookup term: phytochemical
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C28269
#
#
# Query: curcumin
# lookup term: curcumin
#   • Curcumin                                 URI=http://purl.obolibrary.org/obo/NCIT_C401
# Query: egcg
# lookup term: egcg
#   → Reusing existing URI: http://purl.obolibrary.org/obo/XCO_0001093
#
#
# Query: fucoidan
# lookup term: fucoidan
#   • fucoidan                                 URI=http://purl.obolibrary.org/obo/CHEBI_5181 score=1.00
# Query: galangin
# lookup term: galangin
#   • galangin                                 URI=http://purl.obolibrary.org/obo/CHEBI_5262 score=1.00
# Query: astin c
# lookup term: astin_c
#   • Astin I                                  URI=http://purl.obolibrary.org/obo/CHEBI_192105 score=1.00
# Query: apigenin
# lookup term: apigenin
#   • Apigenin                                 URI=http://purl.obolibrary.org/obo/NCIT_C68466
# Query: resveratrol
# lookup term: resveratrol
#   • Resveratrol                              URI=http://purl.obolibrary.org/obo/NCIT_C1215
# Query: phytic acid
# lookup term: phytic_acid
#   • Phytic Acid                              URI=http://purl.obolibrary.org/obo/NCIT_C87652
# Query: acacetin
# lookup term: acacetin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_15335
#
#
# Query: daucosterol
# lookup term: daucosterol
#   • daucosterol                              URI=http://purl.obolibrary.org/obo/CHEBI_67554 score=1.00
# Query: silibinin
# lookup term: silibinin
#   • Silibinin                                URI=http://purl.obolibrary.org/obo/NCIT_C152359
# Query: sulforaphane
# lookup term: sulforaphane
#   • Sulforaphane                             URI=http://purl.obolibrary.org/obo/NCIT_C1424
# Query: withaferin a
# lookup term: withaferin_a
#   • withaferin A                             URI=http://purl.obolibrary.org/obo/CHEBI_69120 score=1.00
# Query: betulinic acid
# lookup term: betulinic_acid
#   • Betulinic Acid                           URI=http://purl.obolibrary.org/obo/NCIT_C38126
# Query: phytochemical
# lookup term: phytochemical
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C28269
#
#
# hippophae_rhamnoide
# Query: hippophae rhamnoide
# lookup term: hippophae_rhamnoide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_193516
#
# Query: hippophae rhamnoide
# lookup term: hippophae_rhamnoide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_193516
#
# hippophae_rhamnoide
# Query: hippophae rhamnoide
# lookup term: hippophae_rhamnoide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_193516
#
# Query: hippophae rhamnoide
# lookup term: hippophae_rhamnoide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_193516
#
# hippophae_rhamnoide
# Query: hippophae rhamnoide
# lookup term: hippophae_rhamnoide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_193516
#
# hippophae_rhamnoide
# Query: hippophae rhamnoide
# lookup term: hippophae_rhamnoide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_193516
#
# hippophae_rhamnoide
# Query: hippophae rhamnoide
# lookup term: hippophae_rhamnoide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_193516
#
# hippophae_rhamnoide
# Query: hippophae rhamnoide
# lookup term: hippophae_rhamnoide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_193516
#
# hippophae_rhamnoide
# Query: hippophae rhamnoide
# lookup term: hippophae_rhamnoide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_193516
#
# Query: fermented food
# lookup term: fermented_food
#   • food                                     URI=http://purl.obolibrary.org/obo/CHEBI_33290 score=1.00
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# metabolite
# Query: metabolite
# lookup term: metabolite
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25212
#
# Query: synbiotic
# lookup term: synbiotic
#   • Synbiotic Supplement                     URI=http://purl.obolibrary.org/obo/NCIT_C99230 score=0.83
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# short-chain_fatty_acid
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: berberine
# lookup term: berberine
#   • Berberine                                URI=http://purl.obolibrary.org/obo/NCIT_C83551
# Query: berberine
# lookup term: berberine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C83551
#
#
# Query: berberine
# lookup term: berberine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C83551
#
#
# Query: berberine
# lookup term: berberine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C83551
#
#
# Query: berberine
# lookup term: berberine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C83551
#
#
# Query: berberine
# lookup term: berberine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C83551
#
#
# Query: berberine
# lookup term: berberine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C83551
#
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# synbiotic_supplement
# Query: synbiotic supplement
# lookup term: synbiotic_supplement
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3274627
#
# synbiotic_supplement
# Query: synbiotic supplement
# lookup term: synbiotic_supplement
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3274627
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# micronutrient
# Query: micronutrient
# lookup term: micronutrient
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_27027
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: fermented wheat germ
# lookup term: fermented_wheat_germ
#   • Fermented Wheat Germ Extract             URI=http://purl.obolibrary.org/obo/NCIT_C64763 score=0.90
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: fermented wheat germ
# lookup term: fermented_wheat_germ
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C64763
#
# fermented_wheat_germ
# Query: fermented wheat germ
# lookup term: fermented_wheat_germ
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C64763
#
# fermented_wheat_germ
# Query: fermented wheat germ
# lookup term: fermented_wheat_germ
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C64763
#
# fermented_wheat_germ
# Query: fermented wheat germ
# lookup term: fermented_wheat_germ
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C64763
#
# fermented_wheat_germ
# Query: fermented wheat germ
# lookup term: fermented_wheat_germ
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C64763
#
# fermented_wheat_germ
# Query: fermented wheat germ
# lookup term: fermented_wheat_germ
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C64763
#
# fermented_wheat_germ
# Query: fermented wheat germ
# lookup term: fermented_wheat_germ
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C64763
#
# fermented_wheat_germ
# Query: fermented wheat germ
# lookup term: fermented_wheat_germ
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C64763
#
# fermented_wheat_germ
# Query: fermented wheat germ
# lookup term: fermented_wheat_germ
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C64763
#
# Starch
# Query: starch
# lookup term: Starch
#   • Starch                                   URI=http://purl.obolibrary.org/obo/NCIT_C68488
# short-chain_fatty_acid
# Query: short-chain fatty acid
# lookup term: short-chain_fatty_acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
# Starch
# Query: starch
# lookup term: Starch
#   • Starch                                   URI=http://purl.obolibrary.org/obo/NCIT_C68488
# Starch
# Query: starch
# lookup term: Starch
#   • Starch                                   URI=http://purl.obolibrary.org/obo/NCIT_C68488
# Query: standard diet
# lookup term: standard_diet
#   • Standard Diet                            URI=http://purl.obolibrary.org/obo/NCIT_C165169
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# Query: gluten
# lookup term: gluten
#   → Reusing existing URI: http://purl.obolibrary.org/obo/FOODON_03420177
#
#
# Query: casein
# lookup term: casein
#   • Casein                                   URI=http://purl.obolibrary.org/obo/NCIT_C73337
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: nvp-1704
# lookup term: nvp-1704
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_230487
#
#
# Query: nvp-1704
# lookup term: nvp-1704
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_230487
#
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: nvp-1704
# lookup term: nvp-1704
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_230487
#
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# medication
# Query: medication
# lookup term: medication
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459
# medication
# Query: medication
# lookup term: medication
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C459
#
#
# medication
# Query: medication
# lookup term: medication
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459
# medication
# Query: medication
# lookup term: medication
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459
# medication
# Query: medication
# lookup term: medication
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C459
#
#
# medication
# Query: medication
# lookup term: medication
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C459
#
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# lactobacillus
# Query: lactobacillus
# lookup term: lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# medication
# Query: medication
# lookup term: medication
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# micronutrient
# Query: micronutrient
# lookup term: micronutrient
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_27027
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# bacillus
# Query: bacillus
# lookup term: bacillus
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202
# bacillus
# Query: bacillus
# lookup term: bacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C76202
#
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
#
# bacillus
# Query: bacillus
# lookup term: bacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C76202
#
#
# bacillus
# Query: bacillus
# lookup term: bacillus
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202
# bacillus
# Query: bacillus
# lookup term: bacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C76202
#
#
# bacillus
# Query: bacillus
# lookup term: bacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C76202
#
#
# bacillus
# Query: bacillus
# lookup term: bacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C76202
#
#
# bacillus
# Query: bacillus
# lookup term: bacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C76202
#
#
# bacillus
# Query: bacillus
# lookup term: bacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C76202
#
#
# diet
# Query: diet
# lookup term: diet
#   • Diet                                     URI=http://purl.obolibrary.org/obo/NCIT_C15222
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
#
# plant
# Query: plant
# lookup term: plant
#   • Plant                                    URI=http://purl.obolibrary.org/obo/NCIT_C14258
# plant
# Query: plant
# lookup term: plant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14258
#
#
# plant
# Query: plant
# lookup term: plant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14258
#
#
# plant
# Query: plant
# lookup term: plant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14258
#
#
# plant
# Query: plant
# lookup term: plant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14258
#
#
# plant
# Query: plant
# lookup term: plant
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14258
#
#
# polyphenol
# Query: polyphenol
# lookup term: polyphenol
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26195
#
# polyphenol
# Query: polyphenol
# lookup term: polyphenol
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26195
#
# Query: triphala
# lookup term: triphala
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/67520904
#
#
# triphala
# Query: triphala
# lookup term: triphala
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/67520904
#
# polyphenol
# Query: polyphenol
# lookup term: polyphenol
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26195
#
# polyphenol
# Query: polyphenol
# lookup term: polyphenol
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26195
#
# polyphenol
# Query: polyphenol
# lookup term: polyphenol
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26195
#
# polyphenol
# Query: polyphenol
# lookup term: polyphenol
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26195
#
# polyphenol
# Query: polyphenol
# lookup term: polyphenol
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26195
#
# polyphenol
# Query: polyphenol
# lookup term: polyphenol
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26195
#
# polyphenol
# Query: polyphenol
# lookup term: polyphenol
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26195
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# metabolite
# Query: metabolite
# lookup term: metabolite
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25212
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# metabolite
# Query: metabolite
# lookup term: metabolite
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25212
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# lacticaseibacillus_rhamnosus
# Query: lacticaseibacillus rhamnosus
# lookup term: lacticaseibacillus_rhamnosus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_47715
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# entering gold
# Query: fibre-fix
# lookup term: fibre-fix
#   • Fix                                      URI=http://purl.obolibrary.org/obo/NCIT_C52253 score=1.00
# Query: fibre-fix
# lookup term: fibre-fix
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C52253
#
#
# Query: fibre-fix
# lookup term: fibre-fix
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C52253
#
#
# Query: fibre-fix
# lookup term: fibre-fix
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C52253
#
#
# Query: psyllium
# lookup term: psyllium
#   • Psyllium                                 URI=http://purl.obolibrary.org/obo/NCIT_C29393
# Query: peppermint oil
# lookup term: peppermint_oil
#   • Peppermint Oil                           URI=http://purl.obolibrary.org/obo/NCIT_C84045
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# human_milk
# Query: human milk
# lookup term: human_milk
#   • Whole Milk                               URI=http://purl.obolibrary.org/obo/NCIT_C188111 score=0.81
# human_milk
# Query: human milk
# lookup term: human_milk
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C188111
#
#
# human_milk
# Query: human milk
# lookup term: human_milk
#   • Whole Milk                               URI=http://purl.obolibrary.org/obo/NCIT_C188111 score=0.81
# human_milk
# Query: human milk
# lookup term: human_milk
#   • Whole Milk                               URI=http://purl.obolibrary.org/obo/NCIT_C188111 score=0.81
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: metabolite supplementation
# lookup term: metabolite_supplementation
#   • metabolite                               URI=http://purl.obolibrary.org/obo/CHEBI_25212 score=1.00
# microbiota_modulator
# Query: microbiota modulator
# lookup term: microbiota_modulator
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/MicrobiotaModulator
#
# Query: psychobiotic agent
# lookup term: psychobiotic_agent
#   • Agent                                    URI=http://purl.obolibrary.org/obo/NCIT_C1708 score=1.00
# Query: artificial sweetener
# lookup term: artificial_sweetener
#   • Artificial Sweetener                     URI=http://purl.obolibrary.org/obo/NCIT_C283
# artificial_sweetener
# Query: artificial sweetener
# lookup term: artificial_sweetener
#   • Artificial Sweetener                     URI=http://purl.obolibrary.org/obo/NCIT_C283
# artificial_sweetener
# Query: artificial sweetener
# lookup term: artificial_sweetener
#   • Artificial Sweetener                     URI=http://purl.obolibrary.org/obo/NCIT_C283
# artificial_sweetener
# Query: artificial sweetener
# lookup term: artificial_sweetener
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C283
#
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# date_seed_powder
# Query: date seed powder
# lookup term: date_seed_powder
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/DateSeedPowder
#
#
# date_seed_powder
# Query: date seed powder
# lookup term: date_seed_powder
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/DateSeedPowder
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
#
# date_seed_powder
# Query: date seed powder
# lookup term: date_seed_powder
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/DateSeedPowder
#
# date_seed_powder
# Query: date seed powder
# lookup term: date_seed_powder
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/DateSeedPowder
#
# date_seed_powder
# Query: date seed powder
# lookup term: date_seed_powder
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/DateSeedPowder
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
#
# Query: synbiotic
# lookup term: synbiotic
#   • Synbiotic Supplement                     URI=http://purl.obolibrary.org/obo/NCIT_C99230 score=0.83
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# milk
# Query: milk
# lookup term: milk
#   • How Often Have Milk                      URI=http://purl.obolibrary.org/obo/NCIT_C188086 score=1.00
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# Query: galactooligosaccharide
# lookup term: galactooligosaccharide
#   • galactooligosaccharide                   URI=http://purl.obolibrary.org/obo/CHEBI_24151 score=1.00
# galactooligosaccharide
# Query: galactooligosaccharide
# lookup term: galactooligosaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_24151
#
# Query: polydextrose
# lookup term: polydextrose
#   • Polydextrose                             URI=http://purl.obolibrary.org/obo/NCIT_C81624
# polydextrose
# Query: polydextrose
# lookup term: polydextrose
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C81624
#
# galactooligosaccharide
# Query: galactooligosaccharide
# lookup term: galactooligosaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_24151
#
# polydextrose
# Query: polydextrose
# lookup term: polydextrose
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C81624
#
# galactooligosaccharide
# Query: galactooligosaccharide
# lookup term: galactooligosaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_24151
#
# polydextrose
# Query: polydextrose
# lookup term: polydextrose
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C81624
#
# galactooligosaccharide
# Query: galactooligosaccharide
# lookup term: galactooligosaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_24151
#
# polydextrose
# Query: polydextrose
# lookup term: polydextrose
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C81624
#
# galactooligosaccharide
# Query: galactooligosaccharide
# lookup term: galactooligosaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_24151
#
# polydextrose
# Query: polydextrose
# lookup term: polydextrose
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C81624
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: psychobiotic
# lookup term: psychobiotic
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/Psychobiotic
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
#
# Query: sodium oligomannate
# lookup term: sodium_oligomannate
#   • Sodium                                   URI=http://purl.obolibrary.org/obo/NCIT_C830 score=1.00
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: betaine supplementation
# lookup term: betaine_supplementation
#   • amino-acid betaine                       URI=http://purl.obolibrary.org/obo/CHEBI_22860 score=0.86
# Query: betaine
# lookup term: betaine
#   • Betaine                                  URI=http://purl.obolibrary.org/obo/NCIT_C81038
# Query: betaine supplementation
# lookup term: betaine_supplementation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_22860
#
#
# Query: betaine supplementation
# lookup term: betaine_supplementation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_22860
#
#
# Query: betaine supplementation
# lookup term: betaine_supplementation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_22860
#
#
# Query: betaine supplementation
# lookup term: betaine_supplementation
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_22860
#
#
# Query: betaine
# lookup term: betaine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C81038
#
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: fiber
# lookup term: fiber
#   • Fiber                                    URI=http://purl.obolibrary.org/obo/NCIT_C1502
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
#
# synbiotic_supplement
# Query: synbiotic supplement
# lookup term: synbiotic_supplement
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3274627
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: synbiotics supplementation
# lookup term: synbiotics_supplementation
# no matches
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
#
# Query: synbiotic supplement
# lookup term: synbiotic_supplement
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C3274627
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# lactobacillus_helveticus
# Query: lactobacillus helveticus
# lookup term: lactobacillus_helveticus
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0317592
#
# lactobacillus_helveticus
# Query: lactobacillus helveticus
# lookup term: lactobacillus_helveticus
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0317592
#
# lactobacillus_helveticus
# Query: lactobacillus helveticus
# lookup term: lactobacillus_helveticus
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0317592
#
# lactobacillus_helveticus
# Query: lactobacillus helveticus
# lookup term: lactobacillus_helveticus
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0317592
#
# lactobacillus_helveticus
# Query: lactobacillus helveticus
# lookup term: lactobacillus_helveticus
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0317592
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: nutraceutical
# lookup term: nutraceutical
#   • Nutraceutical                            URI=http://purl.obolibrary.org/obo/NCIT_C1954
# lipid
# Query: lipid
# lookup term: lipid
#   • Lipid                                    URI=http://purl.obolibrary.org/obo/NCIT_C616
# Query: lipid
# lookup term: lipid
#   • Lipid                                    URI=http://purl.obolibrary.org/obo/NCIT_C616
# nutrient
# Query: nutrient
# lookup term: nutrient
#   • Nutrient                                 URI=http://purl.obolibrary.org/obo/NCIT_C1814
# lipid
# Query: lipid
# lookup term: lipid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C616
#
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# Query: inulin-type fructan
# lookup term: inulin-type_fructan
#   • Inulin                                   URI=http://purl.obolibrary.org/obo/NCIT_C61506 score=0.90
# Query: galactooligosaccharide
# lookup term: galactooligosaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_24151
#
# galactooligosaccharide
# Query: galactooligosaccharide
# lookup term: galactooligosaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_24151
#
# Query: human milk oligosaccharide
# lookup term: human_milk_oligosaccharide
# no matches
# Starch
# Query: starch
# lookup term: Starch
#   • Starch                                   URI=http://purl.obolibrary.org/obo/NCIT_C68488
# galactooligosaccharide
# Query: galactooligosaccharide
# lookup term: galactooligosaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_24151
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# Query: supplemental nutrient
# lookup term: supplemental_nutrient
#   • Nutrient                                 URI=http://purl.obolibrary.org/obo/NCIT_C1814 score=0.81
# nutrient
# Query: nutrient
# lookup term: nutrient
#   • Nutrient                                 URI=http://purl.obolibrary.org/obo/NCIT_C1814
# nutrient
# Query: nutrient
# lookup term: nutrient
#   • Nutrient                                 URI=http://purl.obolibrary.org/obo/NCIT_C1814
# nutrient
# Query: nutrient
# lookup term: nutrient
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C1814
#
#
# nutrient
# Query: nutrient
# lookup term: nutrient
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C1814
#
#
# nutrient
# Query: nutrient
# lookup term: nutrient
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C1814
#
#
# nutrient
# Query: nutrient
# lookup term: nutrient
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C1814
#
#
# vitamins
# Query: vitamins
# lookup term: vitamins
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0042890
#
# Query: dietary fiber
# lookup term: dietary_fiber
#   • Dietary Fiber                            URI=http://purl.obolibrary.org/obo/NCIT_C68492
# Query: dietary fiber
# lookup term: dietary_fiber
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C68492
#
#
# Query: dietary fiber
# lookup term: dietary_fiber
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C68492
#
#
# Query: dietary fiber
# lookup term: dietary_fiber
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C68492
#
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: psychobiotic
# lookup term: psychobiotic
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/Psychobiotic
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: psychobiotic
# lookup term: psychobiotic
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/Psychobiotic
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# entering dev
# Query: dietary fiber
# lookup term: dietary_fiber
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C68492
#
#
# Query: dietary fiber
# lookup term: dietary_fiber
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C68492
#
#
# Query: dietary fiber
# lookup term: dietary_fiber
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C68492
#
#
# Query: dietary fiber
# lookup term: dietary_fiber
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C68492
#
#
# Query: dietary fiber
# lookup term: dietary_fiber
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C68492
#
#
# Query: neutraceutical supplementation
# lookup term: neutraceutical_supplementation
# no matches
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# prebiotic
# Query: prebiotic
# lookup term: prebiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OMIT_0026689
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: lactobacillus fermentum ns9
# lookup term: lactobacillus_fermentum_ns9
#   • Lactobacillus fermentum                  URI=http://purl.obolibrary.org/obo/NCIT_C86478 score=1.00
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: lactobacillus fermentum strain ns9
# lookup term: lactobacillus_fermentum_strain_ns9
#   • Lactobacillus fermentum                  URI=http://purl.obolibrary.org/obo/NCIT_C86478 score=0.88
# Query: ns9
# lookup term: ns9
# no matches
# Query: ns9
# lookup term: ns9
# no matches
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: psychobiotic
# lookup term: psychobiotic
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/Psychobiotic
#
# Query: psychobiotic
# lookup term: psychobiotic
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/Psychobiotic
#
# Query: psychobiotic
# lookup term: psychobiotic
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/Psychobiotic
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: psychobiotics intervention
# lookup term: psychobiotics_intervention
#   • Intervention Name                        URI=http://purl.obolibrary.org/obo/NCIT_C177930 score=1.00
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# Query: psychobiotic
# lookup term: psychobiotic
#   → Reusing existing URI: https://w3id.org/hereditary/ontology/gutbrain/resource/dietarysupplement/Psychobiotic
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# probiotic
# Query: probiotic
# lookup term: probiotic
#   → Reusing existing URI: https://uts.nlm.nih.gov/uts/umls/concept/C0525033
#
# The RDF graph has been saved in c:\Users\samue\OneDrive\Desktop\ThesisPiron\rdf\gutbrain_entities.ttl

# %%
for paper_id, paper_data in data.items():
    relations = paper_data.get("relations", [])
    for rel in relations:
        # a) find the mention URI for subject
        subj_key     = normalize_to_ascii(create_uri_fragment(rel["subject_text_span"])).lower()
        mention_subj = tokenized_mentions.get(subj_key)
        if not mention_subj:
            print(f"⚠️ No mention for subject “{rel['subject_text_span']}”")
            continue

        # b) follow mention → concept
        subj_concepts = list(g.subjects(GUTPROP.containedIn, mention_subj))
        if not subj_concepts:
            print(f"⚠️ No concept contains {mention_subj}")
            continue
        subj_uri = subj_concepts[0]

        # c) same for object
        obj_key     = normalize_to_ascii(create_uri_fragment(rel["object_text_span"])).lower()
        mention_obj = tokenized_mentions.get(obj_key)
        if not mention_obj:
            print(f"⚠️ No mention for object “{rel['object_text_span']}”")
            continue

        obj_concepts = list(g.subjects(GUTPROP.containedIn, mention_obj))
        if not obj_concepts:
            print(f"⚠️ No concept contains {mention_obj}")
            continue
        obj_uri = obj_concepts[0]

        # d) build or lookup the predicate
        prop_local = to_camel_case(rel["predicate"])
        prop_uri   = URIRef(f"{GUTPROP}{prop_local}")
        if (prop_uri, RDF.type, OWL.ObjectProperty) not in g:
            g.add((prop_uri, RDF.type,    OWL.ObjectProperty))
            g.add((prop_uri, RDFS.label, Literal(rel["predicate"], datatype=XSD.string)))

        # e) finally link the two *concept* URIs
        g.add((subj_uri, prop_uri, obj_uri))

# %%
output_file = os.path.join(save_path, "gutbrain_entities.ttl")
ttl_output = g.serialize(format="turtle")
with open(output_file, "w", encoding="utf-8") as f_out:
    f_out.write(ttl_output)

print(f"The RDF graph has been saved in {output_file}")
# Out:
# The RDF graph has been saved in c:\Users\samue\OneDrive\Desktop\ThesisPiron\rdf\gutbrain_entities.ttl

# %%
#!/usr/bin/env python3
import os, json
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDFS, XSD
from groqutils import get_llm_definition

# --- Configuration ---
INPUT_FILE   = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\gutbrain_entities_cleaned.ttl"
OUTPUT_FILE  = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\gutbrain_with_definitions1.ttl"

# Your list of URIs (duplicates collapsed, unwanted filtered below)
uris = [
    "https://uts.nlm.nih.gov/uts/umls/concept/C0001956",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0006826",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0008679",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0011303",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0011847",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0013473",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0016807",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0021053",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0021400",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0021831",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0024623",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0025517",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0027895",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0030920",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0037317",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0038443",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0038586",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0040822",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0041696",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0068563",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0068608",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0149654",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0162535",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0201950",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0214743",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0233401",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0234985",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0250400",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0267373",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0312431",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0338908",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0383327",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0409974",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0426576",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0599588",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0683323",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0684155",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0685938",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0746556",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0815020",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0851578",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0853879",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0870281",
    "https://uts.nlm.nih.gov/uts/umls/concept/C0871189",
    "https://uts.nlm.nih.gov/uts/umls/concept/C1144501",
    "https://uts.nlm.nih.gov/uts/umls/concept/C1448177",
    "https://uts.nlm.nih.gov/uts/umls/concept/C1518478",
    "https://uts.nlm.nih.gov/uts/umls/concept/C1535950",
    "https://uts.nlm.nih.gov/uts/umls/concept/C1623218",
    "https://uts.nlm.nih.gov/uts/umls/concept/C1667359",
    "https://uts.nlm.nih.gov/uts/umls/concept/C1705947",
    "https://uts.nlm.nih.gov/uts/umls/concept/C1821067",
    "https://uts.nlm.nih.gov/uts/umls/concept/C1843921",
    "https://uts.nlm.nih.gov/uts/umls/concept/C3179158",
    "https://uts.nlm.nih.gov/uts/umls/concept/C3276087",
    "https://uts.nlm.nih.gov/uts/umls/concept/C3668481",
    "https://uts.nlm.nih.gov/uts/umls/concept/C3889047",
    "https://uts.nlm.nih.gov/uts/umls/concept/C4021734",
    "https://uts.nlm.nih.gov/uts/umls/concept/C4046029",
    "https://uts.nlm.nih.gov/uts/umls/concept/C4049273",
    "https://uts.nlm.nih.gov/uts/umls/concept/C4082764",
    "https://uts.nlm.nih.gov/uts/umls/concept/C4280021",
    "https://uts.nlm.nih.gov/uts/umls/concept/C4505389",
    "https://uts.nlm.nih.gov/uts/umls/concept/C4699656",
    "https://uts.nlm.nih.gov/uts/umls/concept/C5196781",
    "https://uts.nlm.nih.gov/uts/umls/concept/C5203670",
    "https://uts.nlm.nih.gov/uts/umls/concept/C5394401",
    "https://uts.nlm.nih.gov/uts/umls/concept/C5433282",
    "https://uts.nlm.nih.gov/uts/umls/concept/C5447456",
    "https://uts.nlm.nih.gov/uts/umls/concept/C5544358",
    "https://uts.nlm.nih.gov/uts/umls/concept/C5544449",
    "https://uts.nlm.nih.gov/uts/umls/concept/C5544451",
    "https://uts.nlm.nih.gov/uts/umls/concept/C5567842",
    "https://uts.nlm.nih.gov/uts/umls/concept/C5676829",
    "https://uts.nlm.nih.gov/uts/umls/concept/C5681775",
    "https://uts.nlm.nih.gov/uts/umls/concept/C5780362",
    "https://uts.nlm.nih.gov/uts/umls/concept/C5873086",
    "https://uts.nlm.nih.gov/uts/umls/concept/C5979810"
]

# Deduplicate and exclude unwanted
excluded = {
}
unique_uris = {u for u in set(uris) if u not in excluded}

# Load existing graph
g = Graph()
g.parse(INPUT_FILE, format="turtle")

# Ensure SKOS prefix is bound if needed
SKOS = Namespace("http://www.w3.org/2004/02/skos/core#")
g.bind("skos", SKOS)

# Add definitions
for uri_str in unique_uris:
    uri = URIRef(uri_str)
    # 1) Get label from graph or fallback to URI fragment
    label_node = g.value(uri, RDFS.label)
    if label_node:
        term = str(label_node)
    else:
        term = uri_str.rsplit("/", 1)[-1]
    # 2) Call LLM with the term, not the URI
    definition = get_llm_definition(term)
    # 3) Construct natural comment
    comment_text = f"{definition} [Definition Source: llama3-8b-8192]"
    comment = Literal(comment_text, datatype=XSD.string)
    # 4) Replace existing comment (if any)
    g.set((uri, RDFS.comment, comment))
    g.add((uri, RDFS.comment, Literal("UMLS Match", datatype=XSD.string)))

# Write out updated graph
g.serialize(destination=OUTPUT_FILE, format="turtle")
print(f"Written updated graph with definitions to {OUTPUT_FILE}")
# Out:
# Written updated graph with definitions to C:\Users\samue\OneDrive\Desktop\ThesisPiron\gutbrain_with_definitions1.ttl
