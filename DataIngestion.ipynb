# %%
import xml.etree.ElementTree as ET
from difflib import SequenceMatcher, get_close_matches

def parse_mesh_descriptors(xml_path):
    """Parse the MeSH XML and return a list of descriptors."""
    tree = ET.parse(xml_path)
    root = tree.getroot()
    descriptors = []
    for dr in root.findall('DescriptorRecord'):
        ui_el   = dr.find('DescriptorUI')
        name_el = dr.find('DescriptorName/String')
        if ui_el is None or name_el is None:
            continue
        ui   = ui_el.text
        name = name_el.text
        tree_nums = [tn.text for tn in dr.findall('TreeNumberList/TreeNumber') if tn.text]
        descriptors.append({'ui':ui, 'name':name, 'tree_numbers':tree_nums})
    return descriptors

MESH_XML = 'desc2025.xml' #from the folder
descriptors = parse_mesh_descriptors(MESH_XML)
print(f"Parsed {len(descriptors)} descriptors")
#print(descriptors)
# Out:
# Parsed 30956 descriptors

# %%
def get_bacteria_taxonomy(descriptors):
    """
    Find the descriptor with name 'Bacteria', 
    then collect every descriptor under that tree-number prefix.
    """
    prefix = None #bacteria is B03
    for d in descriptors:
        if d['name'].lower() == 'bacteria' and d['tree_numbers']:
            prefix = d['tree_numbers'][0]
            break
    if not prefix:
        raise RuntimeError("Could not find 'Bacteria' in descriptors")
    tax = {}
    for d in descriptors:
        for tn in d['tree_numbers']:
            if tn == prefix or tn.startswith(prefix + '.'):
                tax[tn] = {'ui':d['ui'], 'name':d['name']}
                break
    return tax

bacteria_tax = get_bacteria_taxonomy(descriptors)
#print(f"{len(bacteria_tax)} bacterial MeSH nodes")

# %%
def build_name_index(taxonomy):
    """
    Build a dict: lower-case name -> list of (tree#, ui, canonical name)
    """
    idx = {}
    for tree_num, info in taxonomy.items():
        key = info['name'].lower()
        idx.setdefault(key, []).append((tree_num, info['ui'], info['name']))
    return idx

name_index = build_name_index(bacteria_tax)
print(f"Indexed {len(name_index)} bacterial names")
# Out:
# Indexed 859 bacterial names

# %%
from difflib import SequenceMatcher

def find_mesh_match(input_name, name_index, n=5, cutoff=0.6):
    """
    Return matches for input_name among the MeSH bacterial names.
    Exact matches come first with score=1.0.
    Then fuzzy matches (score computed via SequenceMatcher.ratio).
    """
    key = input_name.lower()
    results = []
    if key in name_index:
        for tree_num, ui, name in name_index[key]:
            results.append((name, ui, tree_num, 1.0))
        return results

    all_names = list(name_index.keys())
    #print(all_names)
    
    close = get_close_matches(key, all_names, n=n, cutoff=cutoff)
    for cname in close:
        score = SequenceMatcher(None, key, cname).ratio()
        for tree_num, ui, name in name_index[cname]:
            results.append((name, ui, tree_num, score))
    results.sort(key=lambda x: x[3], reverse=True)
    return results

# %%
import re
import json

def strip_html_tags(text):
    return re.sub(r'<[^>]+>', '', text)
path = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\data\train_platinum\train_platinum.json"
with open(path, "r", encoding="utf-8") as f:
    data = json.load(f)

bacteria_terms = set()
for record in data.values():
    for ent in record.get("entities", []):
        if ent.get("label", "").lower() == "bacteria":
            raw = ent["text_span"]
            clean = strip_html_tags(raw).strip()
            if clean:
                bacteria_terms.add(clean)

bacteria_terms.add(clean)

for term in sorted(bacteria_terms):
    print(f"Query: {term}")
    matches = find_mesh_match(term, name_index)
    if not matches:
        print("no matches")
    else:
        for name, ui, tree, score in matches[:5]:
            print(f"  • {name:30s} UI={ui:8s} Tree={tree:12s}  score={score:.2f}")
    print()
# Out:
# Query: A. muciniphila
#   • Acidiphilium                   UI=D041801  Tree=B03.440.400.425.100.110  score=0.62
#
# Query: Acidaminococcus intestini
#   • Acidaminococcus                UI=D045850  Tree=B03.353.250   score=0.75
#   • Micrococcus luteus             UI=D016982  Tree=B03.510.024.850.500.500  score=0.60
#
# Query: Actinobacteria
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=1.00
#
# Query: Actinobacteriota
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.93
#   • Acidobacteria                  UI=D061271  Tree=B03.026       score=0.83
#   • Cyanobacteria                  UI=D000458  Tree=B03.280       score=0.76
#   • Acinetobacter                  UI=D000150  Tree=B03.440.400.425.537.050  score=0.76
#   • Acetobacter                    UI=D000091  Tree=B03.440.400.425.100.100  score=0.74
#
# Query: Acute/chronic insomnia-related signature bacteria
# no matches
#
# Query: Agathobaculum
#   • Thiobacillus                   UI=D013855  Tree=B03.440.400.450.800  score=0.64
#   • Halothiobacillus               UI=D044222  Tree=B03.440.400.425.395  score=0.62
#   • Tenacibaculum                  UI=D060493  Tree=B03.440.080.190.800  score=0.62
#   • Lactobacillus                  UI=D007778  Tree=B03.353.750.450.475  score=0.62
#   • Agrobacterium                  UI=D060054  Tree=B03.440.400.425.700.024  score=0.62
#
# Query: Akkermansia
#   • Akkermansia                    UI=D000086102 Tree=B03.440.930.500  score=1.00
#
# Query: Akkermansia muciniphila
#   • Akkermansia                    UI=D000086102 Tree=B03.440.930.500  score=0.65
#
# Query: Akkermansia_muciniphila
#   • Akkermansia                    UI=D000086102 Tree=B03.440.930.500  score=0.65
#
# Query: Akkermansias
#   • Akkermansia                    UI=D000086102 Tree=B03.440.930.500  score=0.96
#   • Aeromonas                      UI=D000333  Tree=B03.440.450.019.025  score=0.67
#   • Alteromonas                    UI=D020591  Tree=B03.440.400.425.126  score=0.61
#
# Query: Alloprevotella
#   • Prevotella                     UI=D018720  Tree=B03.440.080.094.640  score=0.83
#   • Taylorella                     UI=D042502  Tree=B03.440.400.425.115.800  score=0.67
#   • Bordetella                     UI=D001884  Tree=B03.440.400.425.115.425  score=0.67
#   • Moritella                      UI=D034221  Tree=B03.440.450.510  score=0.61
#
# Query: Anaerostipes
#   • Bacteroides                    UI=D001439  Tree=B03.440.080.094.152  score=0.61
#
# Query: Bacteroidaceae and Porphyromonadaceae families
# no matches
#
# Query: Bacteroides
#   • Bacteroides                    UI=D001439  Tree=B03.440.080.094.152  score=1.00
#
# Query: Bacteroides eggerthii
#   • Bacteroides fragilis           UI=D001441  Tree=B03.440.080.094.152.400  score=0.73
#   • Bacteroides                    UI=D001439  Tree=B03.440.080.094.152  score=0.69
#   • Bacteroides thetaiotaomicron   UI=D000070077 Tree=B03.440.080.094.152.700  score=0.65
#   • Bacteroidetes                  UI=D041963  Tree=B03.440.080   score=0.65
#   • Bacteroidaceae                 UI=D001438  Tree=B03.440.080.094  score=0.63
#
# Query: Bacteroides genus
#   • Bacteroides                    UI=D001439  Tree=B03.440.080.094.152  score=0.79
#   • Bacteroides fragilis           UI=D001441  Tree=B03.440.080.094.152.400  score=0.76
#   • Bacteroidetes                  UI=D041963  Tree=B03.440.080   score=0.73
#   • Bacteroidaceae                 UI=D001438  Tree=B03.440.080.094  score=0.71
#   • Bacteroides thetaiotaomicron   UI=D000070077 Tree=B03.440.080.094.152.700  score=0.62
#
# Query: Bacteroides uniformis
#   • Bacteroides fragilis           UI=D001441  Tree=B03.440.080.094.152.400  score=0.73
#   • Bacteroides                    UI=D001439  Tree=B03.440.080.094.152  score=0.69
#   • Bacteroides thetaiotaomicron   UI=D000070077 Tree=B03.440.080.094.152.700  score=0.65
#   • Bacillus licheniformis         UI=D000069976 Tree=B03.300.390.400.158.218.376  score=0.65
#   • Bacteroidetes                  UI=D041963  Tree=B03.440.080   score=0.65
#
# Query: Bacteroidetes
#   • Bacteroidetes                  UI=D041963  Tree=B03.440.080   score=1.00
#
# Query: Barnesiella
#   • Bartonella                     UI=D001473  Tree=B03.440.090.100  score=0.76
#   • Gardnerella                    UI=D016975  Tree=B03.510.024.400  score=0.73
#   • Edwardsiella                   UI=D020594  Tree=B03.440.450.425.260  score=0.70
#   • Tannerella                     UI=D000084422 Tree=B03.440.080.850  score=0.67
#   • Klebsiella                     UI=D007709  Tree=B03.440.450.425.425  score=0.67
#
# Query: Barnesiella viscericola
# no matches
#
# Query: Barnesiellaceae
#   • Bartonellaceae                 UI=D001475  Tree=B03.440.090   score=0.83
#   • Bacillaceae                    UI=D001406  Tree=B03.300.390.400.158  score=0.77
#   • Brucellaceae                   UI=D042021  Tree=B03.440.400.425.215  score=0.74
#   • Legionellaceae                 UI=D016951  Tree=B03.440.400.425.450  score=0.62
#   • Veillonellaceae                UI=D045854  Tree=B03.353.984   score=0.60
#
# Query: Biffdobacterium
#   • Bifidobacterium                UI=D001644  Tree=B03.510.024.100  score=0.93
#   • Fusobacterium                  UI=D005673  Tree=B03.370.250   score=0.79
#   • Bifidobacterium breve          UI=D000069984 Tree=B03.510.024.100.375  score=0.78
#   • Microbacterium                 UI=D000083822 Tree=B03.510.024.775  score=0.76
#   • Flavobacterium                 UI=D005417  Tree=B03.440.080.190.250  score=0.76
#
# Query: Bifidobacteria
#   • Bifidobacterium                UI=D001644  Tree=B03.510.024.100  score=0.90
#   • Acidobacteria                  UI=D061271  Tree=B03.026       score=0.81
#   • Fusobacteria                   UI=D045182  Tree=B03.370       score=0.77
#   • Bifidobacterium breve          UI=D000069984 Tree=B03.510.024.100.375  score=0.74
#   • Bifidobacterium animalis       UI=D000069982 Tree=B03.510.024.100.250  score=0.74
#
# Query: Bifidobacteriaceae
#   • Flavobacteriaceae              UI=D041965  Tree=B03.440.080.190  score=0.80
#   • Bifidobacterium                UI=D001644  Tree=B03.510.024.100  score=0.79
#   • Cardiobacteriaceae             UI=D044065  Tree=B03.440.450.342  score=0.78
#   • Bifidobacterium breve          UI=D000069984 Tree=B03.510.024.100.375  score=0.77
#   • Rhodobacteraceae               UI=D041902  Tree=B03.660.050.750  score=0.76
#
# Query: Bifidobacterium
#   • Bifidobacterium                UI=D001644  Tree=B03.510.024.100  score=1.00
#
# Query: Bifidobacterium adolescentis
#   • Bifidobacterium adolescentis   UI=D000070005 Tree=B03.510.024.100.125  score=1.00
#
# Query: Bifidobacterium adolescentis NK98
#   • Bifidobacterium adolescentis   UI=D000070005 Tree=B03.510.024.100.125  score=0.92
#   • Bifidobacterium animalis       UI=D000069982 Tree=B03.510.024.100.250  score=0.70
#   • Bifidobacterium pseudocatenulatum UI=D000070257 Tree=B03.510.024.100.750  score=0.67
#   • Bifidobacterium breve          UI=D000069984 Tree=B03.510.024.100.375  score=0.67
#   • Bifidobacterium longum         UI=D000069978 Tree=B03.510.024.100.500  score=0.65
#
# Query: Bifidobacterium longum
#   • Bifidobacterium longum         UI=D000069978 Tree=B03.510.024.100.500  score=1.00
#
# Query: Bifidobacterium longum R0175
#   • Bifidobacterium longum         UI=D000069978 Tree=B03.510.024.100.500  score=0.88
#   • Bifidobacterium bifidum        UI=D000069985 Tree=B03.510.024.100.313  score=0.71
#   • Bifidobacterium                UI=D001644  Tree=B03.510.024.100  score=0.70
#   • Bifidobacterium breve          UI=D000069984 Tree=B03.510.024.100.375  score=0.69
#   • Bifidobacterium animalis       UI=D000069982 Tree=B03.510.024.100.250  score=0.65
#
# Query: Bilophila
#   • Bilophila                      UI=D045282  Tree=B03.440.425.410.200  score=1.00
#
# Query: Bilophila wadsworthia
#   • Bilophila                      UI=D045282  Tree=B03.440.425.410.200  score=0.60
#
# Query: Blautia
#   • Bacteria                       UI=D001419  Tree=B03           score=0.67
#
# Query: Christensenellaceae
#   • Bartonellaceae                 UI=D001475  Tree=B03.440.090   score=0.67
#   • Pasteurellaceae                UI=D015661  Tree=B03.440.450.600  score=0.65
#   • Coxiellaceae                   UI=D044125  Tree=B03.440.400.425.297  score=0.65
#   • Legionellaceae                 UI=D016951  Tree=B03.440.400.425.450  score=0.61
#   • Bacillaceae                    UI=D001406  Tree=B03.300.390.400.158  score=0.60
#
# Query: Christensenellaceae R-7 group
# no matches
#
# Query: Citrobacter
#   • Citrobacter                    UI=D002954  Tree=B03.440.450.425.200  score=1.00
#
# Query: Clostridium
#   • Clostridium                    UI=D003013  Tree=B03.300.390.400.200  score=1.00
#
# Query: Clostridium sp. BR31
#   • Clostridium                    UI=D003013  Tree=B03.300.390.400.200  score=0.71
#   • Clostridium septicum           UI=D052557  Tree=B03.300.390.400.200.690  score=0.70
#   • Clostridium symbiosum          UI=D048009  Tree=B03.300.390.400.200.713  score=0.68
#   • Clostridium sordellii          UI=D047989  Tree=B03.300.390.400.200.700  score=0.68
#   • Clostridium butyricum          UI=D046972  Tree=B03.300.390.400.200.180  score=0.68
#
# Query: Clostridiuminnocuumgroup
#   • Clostridium septicum           UI=D052557  Tree=B03.300.390.400.200.690  score=0.68
#   • Clostridium symbiosum          UI=D048009  Tree=B03.300.390.400.200.713  score=0.67
#   • Clostridium histolyticum       UI=D047009  Tree=B03.300.390.400.200.412  score=0.67
#   • Clostridium butyricum          UI=D046972  Tree=B03.300.390.400.200.180  score=0.67
#   • Clostridium botulinum          UI=D003014  Tree=B03.300.390.400.200.160  score=0.67
#
# Query: Collinsella
#   • Wolinella                      UI=D016968  Tree=B03.440.425.410.875  score=0.80
#   • Coxiella                       UI=D003381  Tree=B03.440.400.425.297.150  score=0.74
#   • Listonella                     UI=D053526  Tree=B03.440.450.900.500  score=0.67
#   • Veillonella                    UI=D014678  Tree=B03.440.425.410.800.938  score=0.64
#   • Legionella                     UI=D007875  Tree=B03.440.400.425.450.450  score=0.57
#
# Query: Coprococcus
#   • Micrococcus                    UI=D008837  Tree=B03.510.024.850.500  score=0.82
#   • Paracoccus                     UI=D010230  Tree=B03.440.400.425.600  score=0.76
#   • Oenococcus                     UI=D056585  Tree=B03.353.750.475.600  score=0.76
#   • Aerococcus                     UI=D056570  Tree=B03.353.750.030.030  score=0.76
#   • Rhodococcus                    UI=D012240  Tree=B03.510.024.981.775  score=0.73
#
# Query: Coprococcus 1
#   • Micrococcus                    UI=D008837  Tree=B03.510.024.850.500  score=0.75
#   • Paracoccus                     UI=D010230  Tree=B03.440.400.425.600  score=0.70
#   • Oenococcus                     UI=D056585  Tree=B03.353.750.475.600  score=0.70
#   • Aerococcus                     UI=D056570  Tree=B03.353.750.030.030  score=0.70
#   • Rhodococcus                    UI=D012240  Tree=B03.510.024.981.775  score=0.67
#
# Query: Coprococcus comes
#   • Micrococcus luteus             UI=D016982  Tree=B03.510.024.850.500.500  score=0.69
#   • Micrococcus                    UI=D008837  Tree=B03.510.024.850.500  score=0.64
#   • Lactococcus lactis             UI=D013294  Tree=B03.353.750.737.500.400  score=0.63
#   • Streptococcus pyogenes         UI=D013297  Tree=B03.353.750.737.872.575  score=0.62
#   • Staphylococcus hominis         UI=D041181  Tree=B03.300.390.400.800.750.425  score=0.62
#
# Query: Coriobacteriaceae
#   • Cardiobacteriaceae             UI=D044065  Tree=B03.440.450.342  score=0.91
#   • Carnobacteriaceae              UI=D056568  Tree=B03.353.750.130  score=0.88
#   • Mycobacteriaceae               UI=D009159  Tree=B03.510.024.962  score=0.85
#   • Propionibacteriaceae           UI=D011423  Tree=B03.510.024.990  score=0.81
#   • Enterobacteriaceae             UI=D004755  Tree=B03.440.450.425  score=0.80
#
# Query: Corynebacterium
#   • Corynebacterium                UI=D003352  Tree=B03.510.024.250  score=1.00
#
# Query: Desulfovibrio
#   • Desulfovibrio                  UI=D003901  Tree=B03.440.425.410.350  score=1.00
#
# Query: Desulfovibrionaceae
#   • Desulfovibrionaceae            UI=D000073564 Tree=B03.440.425.200  score=1.00
#
# Query: Dialister
#   • Listeria                       UI=D008087  Tree=B03.353.500.500  score=0.71
#
# Query: Dorea
#   • Orientia                       UI=D000084162 Tree=B03.660.050.783.875.650.450  score=0.62
#   • Moorella                       UI=D058845  Tree=B03.300.390.400.525  score=0.62
#   • Borrelia                       UI=D001898  Tree=B03.440.425.410.711.193  score=0.62
#
# Query: EC Ruminococcus torques
#   • Ruminococcus                   UI=D045857  Tree=B03.353.625.806  score=0.69
#   • Micrococcus luteus             UI=D016982  Tree=B03.510.024.850.500.500  score=0.63
#
# Query: Eggerthellaceae
#   • Legionellaceae                 UI=D016951  Tree=B03.440.400.425.450  score=0.69
#   • Bartonellaceae                 UI=D001475  Tree=B03.440.090   score=0.69
#   • Brucellaceae                   UI=D042021  Tree=B03.440.400.425.215  score=0.67
#   • Methylophilaceae               UI=D042762  Tree=B03.440.400.425.525  score=0.65
#   • Moraxellaceae                  UI=D044007  Tree=B03.440.400.425.537  score=0.64
#
# Query: Enterobacter cloacae
#   • Enterobacter cloacae           UI=D016972  Tree=B03.440.450.425.275.200  score=1.00
#
# Query: Enterobacteriaceae
#   • Enterobacteriaceae             UI=D004755  Tree=B03.440.450.425  score=1.00
#
# Query: Enterococcaceae
#   • Enterococcaceae                UI=D056569  Tree=B03.353.750.250  score=1.00
#
# Query: Enterococcus
#   • Enterococcus                   UI=D016983  Tree=B03.353.750.250.250  score=1.00
#
# Query: Escherichia
#   • Escherichia                    UI=D004925  Tree=B03.440.450.425.325  score=1.00
#
# Query: Escherichia coli
#   • Escherichia coli               UI=D004926  Tree=B03.440.450.425.325.300  score=1.00
#
# Query: Escherichia-Shigella
#   • Escherichia                    UI=D004925  Tree=B03.440.450.425.325  score=0.71
#   • Escherichia coli               UI=D004926  Tree=B03.440.450.425.325.300  score=0.67
#   • Escherichia coli K12           UI=D048168  Tree=B03.440.450.425.325.300.360  score=0.60
#
# Query: Eubacterium rectale
#   • Eubacterium                    UI=D005051  Tree=B03.353.625.750  score=0.73
#   • Fusobacterium nucleatum        UI=D016967  Tree=B03.370.250.500  score=0.67
#   • Bifidobacterium breve          UI=D000069984 Tree=B03.510.024.100.375  score=0.65
#   • Exiguobacterium                UI=D000086183 Tree=B03.353.500.100.309  score=0.65
#   • Mycobacterium phlei            UI=D009168  Tree=B03.510.024.962.500.640  score=0.63
#
# Query: F4
# no matches
#
# Query: Faecalibacterium
#   • Faecalibacterium               UI=D000070036 Tree=B03.353.625.766  score=1.00
#
# Query: Faecalibacterium prausnitzii
#   • Faecalibacterium prausnitzii   UI=D000070037 Tree=B03.353.625.766.500  score=1.00
#
# Query: Faecalibaculum
#   • Faecalibacterium               UI=D000070036 Tree=B03.353.625.766  score=0.80
#   • Tenacibaculum                  UI=D060493  Tree=B03.440.080.190.800  score=0.74
#
# Query: Family_Ruminococcaceae
#   • Micrococcaceae                 UI=D008835  Tree=B03.510.024.850  score=0.72
#   • Aerococcaceae                  UI=D056567  Tree=B03.353.750.030  score=0.69
#   • Planococcaceae                 UI=D058641  Tree=B03.353.500.700  score=0.67
#   • Methylococcaceae               UI=D008772  Tree=B03.440.400.425.500  score=0.63
#   • Staphylococcaceae              UI=D040141  Tree=B03.300.390.400.800  score=0.62
#
# Query: Fecalibacterium prausnitzii
#   • Faecalibacterium prausnitzii   UI=D000070037 Tree=B03.353.625.766.500  score=0.98
#   • Faecalibacterium               UI=D000070036 Tree=B03.353.625.766  score=0.70
#   • Mycobacterium kansasii         UI=D019909  Tree=B03.510.024.962.500.720.400  score=0.61
#   • Mycobacterium lepraemurium     UI=D009167  Tree=B03.510.024.962.500.602  score=0.60
#   • Mycobacterium fortuitum        UI=D019907  Tree=B03.510.024.962.500.720.325  score=0.60
#
# Query: Firmicutes
#   • Firmicutes                     UI=D000068536 Tree=B03.353       score=1.00
#
# Query: Flavonifractor
#   • Flavobacterium                 UI=D005417  Tree=B03.440.080.190.250  score=0.64
#   • Clavibacter                    UI=D000086162 Tree=B03.510.024.232  score=0.64
#
# Query: Fusicatenibacter saccharivorans
# no matches
#
# Query: Fusobacterium
#   • Fusobacterium                  UI=D005673  Tree=B03.370.250   score=1.00
#
# Query: Fusobacterium nucleatum
#   • Fusobacterium nucleatum        UI=D016967  Tree=B03.370.250.500  score=1.00
#
# Query: GABA-producing bacteria
#   • Sulfur-Reducing Bacteria       UI=D016999  Tree=B03.900       score=0.72
#   • Gram-Positive Bacteria         UI=D006094  Tree=B03.510       score=0.67
#   • Gammaproteobacteria            UI=D020563  Tree=B03.660.250   score=0.67
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.65
#   • Betaproteobacteria             UI=D020562  Tree=B03.660.075   score=0.59
#
# Query: GR1009
# no matches
#
# Query: Gut Bacteria
#   • Bacteria                       UI=D001419  Tree=B03           score=0.80
#   • Fusobacteria                   UI=D045182  Tree=B03.370       score=0.75
#   • Eubacterium                    UI=D005051  Tree=B03.353.625.750  score=0.70
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.69
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.69
#
# Query: Gut bacteria
#   • Bacteria                       UI=D001419  Tree=B03           score=0.80
#   • Fusobacteria                   UI=D045182  Tree=B03.370       score=0.75
#   • Eubacterium                    UI=D005051  Tree=B03.353.625.750  score=0.70
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.69
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.69
#
# Query: Haemophilu
#   • Haemophilus                    UI=D006190  Tree=B03.440.450.600.450  score=0.95
#   • Haemophilus somnus             UI=D044138  Tree=B03.440.450.600.450.750  score=0.71
#   • Chlamydophila                  UI=D023501  Tree=B03.440.190.190.230  score=0.70
#   • Haemophilus ducreyi            UI=D006191  Tree=B03.440.450.600.450.125  score=0.69
#   • Dermatophilus                  UI=D000086182 Tree=B03.510.024.288  score=0.61
#
# Query: Haemophilus
#   • Haemophilus                    UI=D006190  Tree=B03.440.450.600.450  score=1.00
#
# Query: Helicobacter
#   • Helicobacter                   UI=D016998  Tree=B03.440.500   score=1.00
#
# Query: Helicobacter pylori
#   • Helicobacter pylori            UI=D016480  Tree=B03.440.500.550  score=1.00
#
# Query: Hungatella
#   • Stigmatella                    UI=D020597  Tree=B03.660.125.500.710  score=0.67
#   • Shigella                       UI=D012760  Tree=B03.440.450.425.850  score=0.67
#   • Kingella                       UI=D017881  Tree=B03.440.400.425.550.400  score=0.67
#   • Shewanella                     UI=D020592  Tree=B03.440.450.690  score=0.60
#   • Morganella                     UI=D020596  Tree=B03.440.450.425.500  score=0.60
#
# Query: Intestinal bacteria
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.67
#   • Gram-Negative Bacteria         UI=D006090  Tree=B03.440       score=0.63
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.61
#   • Acinetobacter                  UI=D000150  Tree=B03.440.400.425.537.050  score=0.56
#   • Atypical Bacterial Forms       UI=D001295  Tree=B03.110       score=0.56
#
# Query: Intestinibacter
#   • Liberibacter                   UI=D000086202 Tree=B03.660.050.662.347  score=0.67
#   • Enterobacter                   UI=D004754  Tree=B03.440.450.425.275  score=0.67
#   • Acinetobacter                  UI=D000150  Tree=B03.440.400.425.537.050  score=0.64
#   • Renibacterium                  UI=D000084402 Tree=B03.510.024.850.750  score=0.64
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.62
#
# Query: Kineothrix
#   • Thiothrix                      UI=D053525  Tree=B03.440.400.645.800  score=0.74
#   • Leptothrix                     UI=D042743  Tree=B03.440.400.425.481  score=0.70
#   • Planktothrix                   UI=D000086302 Tree=B03.280.641   score=0.64
#
# Query: Klebsiella
#   • Klebsiella                     UI=D007709  Tree=B03.440.450.425.425  score=1.00
#
# Query: L
# no matches
#
# Query: L. brevis P30021
# no matches
#
# Query: L. fermentum strain
# no matches
#
# Query: L. plantarum CCFM8661
# no matches
#
# Query: L. plantarum P30025
# no matches
#
# Query: Lachnoclostridium
#   • Clostridium                    UI=D003013  Tree=B03.300.390.400.200  score=0.79
#   • Clostridium tetani             UI=D003017  Tree=B03.300.390.400.200.725  score=0.63
#   • Clostridium tertium            UI=D048010  Tree=B03.300.390.400.200.722  score=0.61
#   • Clostridiales                  UI=D000068016 Tree=B03.353.625   score=0.60
#   • Arcanobacterium                UI=D055667  Tree=B03.510.024.049.050.287  score=0.44
#
# Query: Lachnospira
#   • Brachyspira                    UI=D017400  Tree=B03.440.097   score=0.73
#   • Leptospira                     UI=D007919  Tree=B03.440.400.425.475.475  score=0.67
#   • Wolbachia                      UI=D020577  Tree=B03.660.050.783.500.762  score=0.60
#
# Query: Lachnospiraceae
#   • Leptospiraceae                 UI=D016953  Tree=B03.440.400.425.475  score=0.76
#   • Oceanospirillaceae             UI=D044130  Tree=B03.440.595   score=0.73
#   • Holosporaceae                  UI=D042281  Tree=B03.660.050.340  score=0.71
#   • Alcanivoraceae                 UI=D053521  Tree=B03.660.250.019  score=0.69
#   • Rhodospirillaceae              UI=D012244  Tree=B03.440.400.425.708  score=0.69
#
# Query: Lachnospiraceae FCS020 group
# no matches
#
# Query: Lachnospiraceae NK4A136 group
# no matches
#
# Query: Lachnospiraceae family
#   • Leptospiraceae                 UI=D016953  Tree=B03.440.400.425.475  score=0.61
#   • Oceanospirillaceae             UI=D044130  Tree=B03.440.595   score=0.60
#
# Query: Lachnospiraceae.g
#   • Leptospiraceae                 UI=D016953  Tree=B03.440.400.425.475  score=0.71
#   • Oceanospirillaceae             UI=D044130  Tree=B03.440.595   score=0.69
#   • Holosporaceae                  UI=D042281  Tree=B03.660.050.340  score=0.67
#   • Rhodospirillaceae              UI=D012244  Tree=B03.440.400.425.708  score=0.65
#   • Alcanivoraceae                 UI=D053521  Tree=B03.660.250.019  score=0.65
#
# Query: Lachnospiraceae_Incertae_Sedis
# no matches
#
# Query: Lachnostridium
#   • Clostridium                    UI=D003013  Tree=B03.300.390.400.200  score=0.80
#   • Phormidium                     UI=D000084242 Tree=B03.280.631   score=0.67
#   • Clostridium tetani             UI=D003017  Tree=B03.300.390.400.200.725  score=0.62
#   • Clostridium tertium            UI=D048010  Tree=B03.300.390.400.200.722  score=0.61
#   • Arcanobacterium                UI=D055667  Tree=B03.510.024.049.050.287  score=0.48
#
# Query: Lacticaseibacillus paracasei
#   • Lacticaseibacillus paracasei   UI=D000069980 Tree=B03.353.750.450.606.750  score=1.00
#
# Query: Lactiplantibacillus plantarum
#   • Lactobacillus plantarum        UI=D048191  Tree=B03.353.750.450.475.612  score=0.85
#   • Lactobacillus pentosus         UI=D000070018 Tree=B03.353.750.450.475.586  score=0.67
#   • Lacticaseibacillus paracasei   UI=D000069980 Tree=B03.353.750.450.606.750  score=0.67
#   • Lacticaseibacillus casei       UI=D007780  Tree=B03.353.750.450.606.500  score=0.64
#   • Paenibacillus larvae           UI=D000070059 Tree=B03.300.390.400.645.500  score=0.61
#
# Query: Lactobacillacea
#   • Lactobacillaceae               UI=D007777  Tree=B03.353.750.450  score=0.97
#   • Lactobacillales                UI=D056546  Tree=B03.353.750   score=0.87
#   • Lactobacillus                  UI=D007778  Tree=B03.353.750.450.475  score=0.79
#   • Bacillaceae                    UI=D001406  Tree=B03.300.390.400.158  score=0.77
#   • Lactobacillus gasseri          UI=D000069998 Tree=B03.353.750.450.475.363  score=0.72
#
# Query: Lactobacillaceae
#   • Lactobacillaceae               UI=D007777  Tree=B03.353.750.450  score=1.00
#
# Query: Lactobacilli
#   • Lactobacillus                  UI=D007778  Tree=B03.353.750.450.475  score=0.88
#   • Lactobacillales                UI=D056546  Tree=B03.353.750   score=0.81
#   • Lactobacillaceae               UI=D007777  Tree=B03.353.750.450  score=0.79
#   • Actinobacillus                 UI=D000188  Tree=B03.440.450.009  score=0.77
#   • Lactobacillus gasseri          UI=D000069998 Tree=B03.353.750.450.475.363  score=0.73
#
# Query: Lactobacillus
#   • Lactobacillus                  UI=D007778  Tree=B03.353.750.450.475  score=1.00
#
# Query: Lactobacillus fermentum PS150
#   • Limosilactobacillus fermentum  UI=D052197  Tree=B03.353.750.450.672  score=0.79
#   • Lactobacillus pentosus         UI=D000070018 Tree=B03.353.750.450.475.586  score=0.75
#   • Lactobacillus helveticus       UI=D052198  Tree=B03.353.750.450.475.400  score=0.72
#   • Lactobacillus plantarum        UI=D048191  Tree=B03.353.750.450.475.612  score=0.69
#   • Lactobacillus crispatus        UI=D000070003 Tree=B03.353.750.450.475.238  score=0.69
#
# Query: Lactobacillus helveticus R0052
#   • Lactobacillus helveticus       UI=D052198  Tree=B03.353.750.450.475.400  score=0.89
#   • Lactobacillus pentosus         UI=D000070018 Tree=B03.353.750.450.475.586  score=0.69
#   • Lactobacillus plantarum        UI=D048191  Tree=B03.353.750.450.475.612  score=0.64
#   • Lactobacillus crispatus        UI=D000070003 Tree=B03.353.750.450.475.238  score=0.64
#   • Lactobacillus leichmannii      UI=D052199  Tree=B03.353.750.450.475.506  score=0.62
#
# Query: Lactobacillus plantarum
#   • Lactobacillus plantarum        UI=D048191  Tree=B03.353.750.450.475.612  score=1.00
#
# Query: Lactobacillus plantarum CCFM8661
#   • Lactobacillus plantarum        UI=D048191  Tree=B03.353.750.450.475.612  score=0.84
#   • Lactobacillus pentosus         UI=D000070018 Tree=B03.353.750.450.475.586  score=0.67
#   • Lactobacillus delbrueckii      UI=D048668  Tree=B03.353.750.450.475.250  score=0.63
#   • Lactobacillus helveticus       UI=D052198  Tree=B03.353.750.450.475.400  score=0.61
#   • Lactobacillus gasseri          UI=D000069998 Tree=B03.353.750.450.475.363  score=0.60
#
# Query: Lactobacillus plantarum R1012
#   • Lactobacillus plantarum        UI=D048191  Tree=B03.353.750.450.475.612  score=0.88
#   • Lactobacillus pentosus         UI=D000070018 Tree=B03.353.750.450.475.586  score=0.71
#   • Lactobacillus helveticus       UI=D052198  Tree=B03.353.750.450.475.400  score=0.64
#   • Lactobacillus gasseri          UI=D000069998 Tree=B03.353.750.450.475.363  score=0.64
#   • Ligilactobacillus salivarius   UI=D000069996 Tree=B03.353.750.450.656  score=0.63
#
# Query: Lactobacillus reuteri ATG-F4
#   • Limosilactobacillus reuteri    UI=D052200  Tree=B03.353.750.450.705  score=0.76
#   • Lactobacillus crispatus        UI=D000070003 Tree=B03.353.750.450.475.238  score=0.71
#   • Lactobacillus gasseri          UI=D000069998 Tree=B03.353.750.450.475.363  score=0.69
#   • Levilactobacillus brevis       UI=D052196  Tree=B03.353.750.450.639  score=0.65
#   • Lactobacillus helveticus       UI=D052198  Tree=B03.353.750.450.475.400  score=0.62
#
# Query: Lactobacillus reuteri NK33
#   • Limosilactobacillus reuteri    UI=D052200  Tree=B03.353.750.450.705  score=0.79
#   • Lactobacillus gasseri          UI=D000069998 Tree=B03.353.750.450.475.363  score=0.72
#   • Actinobacillus equuli          UI=D044131  Tree=B03.440.450.009.200  score=0.68
#   • Levilactobacillus brevis       UI=D052196  Tree=B03.353.750.450.639  score=0.68
#   • Lactobacillus helveticus       UI=D052198  Tree=B03.353.750.450.475.400  score=0.64
#
# Query: Lactobacillus species
#   • Actinobacillus suis            UI=D044132  Tree=B03.440.450.009.700  score=0.80
#   • Lactobacillus pentosus         UI=D000070018 Tree=B03.353.750.450.475.586  score=0.79
#   • Actinobacillus seminis         UI=D044133  Tree=B03.440.450.009.675  score=0.79
#   • Latilactobacillus sakei        UI=D000070256 Tree=B03.353.750.450.623  score=0.77
#   • Lactobacillus crispatus        UI=D000070003 Tree=B03.353.750.450.475.238  score=0.77
#
# Query: Lactococcus
#   • Lactococcus                    UI=D017045  Tree=B03.353.750.737.500  score=1.00
#
# Query: Levilactobacillus brevis
#   • Levilactobacillus brevis       UI=D052196  Tree=B03.353.750.450.639  score=1.00
#
# Query: Ligilactobacillus salivarius
#   • Ligilactobacillus salivarius   UI=D000069996 Tree=B03.353.750.450.656  score=1.00
#
# Query: Listeria monocytogenes
#   • Listeria monocytogenes         UI=D008089  Tree=B03.353.500.500.500  score=1.00
#
# Query: Megamonas
#   • Comamonas                      UI=D020585  Tree=B03.440.400.425.293.150  score=0.78
#   • Marinomonas                    UI=D053544  Tree=B03.660.250.540.500  score=0.70
#   • Zymomonas                      UI=D017355  Tree=B03.440.450.980  score=0.67
#   • Methylomonas                   UI=D020620  Tree=B03.440.400.425.500.505  score=0.67
#   • Halomonas                      UI=D020632  Tree=B03.440.400.425.377.500  score=0.67
#
# Query: Megasphaera
#   • Megasphaera                    UI=D045851  Tree=B03.440.425.400.500  score=1.00
#
# Query: Megasphaera elsdenii
#   • Megasphaera elsdenii           UI=D000070101 Tree=B03.440.425.400.500.500  score=1.00
#
# Query: Methanobrevibacter
#   • Brevibacterium                 UI=D001951  Tree=B03.510.024.175  score=0.69
#   • Marinobacter                   UI=D053520  Tree=B03.660.250.021.480  score=0.67
#   • Methylobacterium               UI=D020580  Tree=B03.440.400.425.487.500  score=0.65
#   • Clavibacter                    UI=D000086162 Tree=B03.510.024.232  score=0.62
#   • Acetobacter                    UI=D000091  Tree=B03.440.400.425.100.100  score=0.62
#
# Query: Mucispirillum
#   • Spirillum                      UI=D013139  Tree=B03.440.840.750  score=0.82
#   • Azospirillum                   UI=D016949  Tree=B03.440.400.425.708.100  score=0.72
#   • Magnetospirillum               UI=D042201  Tree=B03.440.400.425.708.500  score=0.69
#   • Rhodospirillum                 UI=D012246  Tree=B03.440.400.425.708.733  score=0.67
#   • Herbaspirillum                 UI=D042803  Tree=B03.440.400.425.587.400  score=0.67
#
# Query: Muribaculaceae
#   • Bacillaceae                    UI=D001406  Tree=B03.300.390.400.158  score=0.72
#   • Moraxellaceae                  UI=D044007  Tree=B03.440.400.425.537  score=0.67
#   • Cardiobacteriaceae             UI=D044065  Tree=B03.440.450.342  score=0.62
#   • Spirillaceae                   UI=D043167  Tree=B03.440.840   score=0.62
#   • Rhizobiaceae                   UI=D012230  Tree=B03.440.400.425.700  score=0.62
#
# Query: Negativicutes
#   • Tenericutes                    UI=D008973  Tree=B03.440.860   score=0.67
#   • Firmicutes                     UI=D000068536 Tree=B03.353       score=0.61
#
# Query: Odoribacter
#   • Rhodobacter                    UI=D016992  Tree=B03.440.623   score=0.82
#   • Pedobacter                     UI=D060485  Tree=B03.440.080.600  score=0.76
#   • Azotobacter                    UI=D001395  Tree=B03.440.400.425.625.050  score=0.73
#   • Geobacter                      UI=D045302  Tree=B03.440.425.410.430  score=0.70
#   • Marinobacter                   UI=D053520  Tree=B03.660.250.021.480  score=0.70
#
# Query: Oscillibacter
#   • Clavibacter                    UI=D000086162 Tree=B03.510.024.232  score=0.75
#   • Roseobacter                    UI=D041904  Tree=B03.440.680   score=0.67
#   • Flexibacter                    UI=D045248  Tree=B03.440.080.130.200  score=0.67
#   • Citrobacter                    UI=D002954  Tree=B03.440.450.425.200  score=0.67
#   • Oscillatoria                   UI=D054300  Tree=B03.280.612   score=0.64
#
# Query: Oscillospira
#   • Leptospira                     UI=D007919  Tree=B03.440.400.425.475.475  score=0.64
#
# Query: PS150
# no matches
#
# Query: ParaBacteroides
#   • Bacteroides                    UI=D001439  Tree=B03.440.080.094.152  score=0.85
#   • Bacteroidetes                  UI=D041963  Tree=B03.440.080   score=0.79
#   • Nocardia asteroides            UI=D009616  Tree=B03.510.024.981.550.550  score=0.71
#   • Bacteroidaceae                 UI=D001438  Tree=B03.440.080.094  score=0.69
#   • Arcanobacterium                UI=D055667  Tree=B03.510.024.049.050.287  score=0.67
#
# Query: Parabacteroides
#   • Bacteroides                    UI=D001439  Tree=B03.440.080.094.152  score=0.85
#   • Bacteroidetes                  UI=D041963  Tree=B03.440.080   score=0.79
#   • Nocardia asteroides            UI=D009616  Tree=B03.510.024.981.550.550  score=0.71
#   • Bacteroidaceae                 UI=D001438  Tree=B03.440.080.094  score=0.69
#   • Arcanobacterium                UI=D055667  Tree=B03.510.024.049.050.287  score=0.67
#
# Query: Parasutterella
#   • Pasteurella                    UI=D010325  Tree=B03.440.450.600.600  score=0.80
#   • Pasteurellaceae                UI=D015661  Tree=B03.440.450.600  score=0.69
#   • Gardnerella                    UI=D016975  Tree=B03.510.024.400  score=0.64
#   • Pasteuria                      UI=D058676  Tree=B03.300.390.650  score=0.61
#
# Query: Porphyromonas
#   • Porphyromonas                  UI=D017861  Tree=B03.440.080.094.625  score=1.00
#
# Query: Prevotella
#   • Prevotella                     UI=D018720  Tree=B03.440.080.094.640  score=1.00
#
# Query: Prevotella species
#   • Prevotella nigrescens          UI=D045242  Tree=B03.440.080.094.640.550  score=0.72
#   • Prevotella                     UI=D018720  Tree=B03.440.080.094.640  score=0.71
#   • Prevotella intermedia          UI=D018713  Tree=B03.440.080.094.640.375  score=0.67
#   • Prevotella ruminicola          UI=D045243  Tree=B03.440.080.094.640.700  score=0.62
#   • Prevotella melaninogenica      UI=D001443  Tree=B03.440.080.094.640.500  score=0.60
#
# Query: Prevotella7
#   • Prevotella                     UI=D018720  Tree=B03.440.080.094.640  score=0.95
#   • Prevotella ruminicola          UI=D045243  Tree=B03.440.080.094.640.700  score=0.62
#   • Prevotella nigrescens          UI=D045242  Tree=B03.440.080.094.640.550  score=0.62
#   • Prevotella intermedia          UI=D018713  Tree=B03.440.080.094.640.375  score=0.62
#   • Moritella                      UI=D034221  Tree=B03.440.450.510  score=0.60
#
# Query: Prevotellaceae
#   • Prevotella                     UI=D018720  Tree=B03.440.080.094.640  score=0.83
#   • Legionellaceae                 UI=D016951  Tree=B03.440.400.425.450  score=0.71
#   • Bartonellaceae                 UI=D001475  Tree=B03.440.090   score=0.71
#   • Spirillaceae                   UI=D043167  Tree=B03.440.840   score=0.69
#   • Coxiellaceae                   UI=D044125  Tree=B03.440.400.425.297  score=0.69
#
# Query: Prevotellaceae NK3B31
#   • Prevotella                     UI=D018720  Tree=B03.440.080.094.640  score=0.65
#
# Query: Proteobacteria
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=1.00
#
# Query: Psychobiotics
#   • Synechocystis                  UI=D046939  Tree=B03.280.750   score=0.62
#   • Psychrobacter                  UI=D044096  Tree=B03.440.400.425.537.650  score=0.62
#
# Query: Rikencellaceae
#   • Brucellaceae                   UI=D042021  Tree=B03.440.400.425.215  score=0.77
#   • Legionellaceae                 UI=D016951  Tree=B03.440.400.425.450  score=0.71
#   • Bartonellaceae                 UI=D001475  Tree=B03.440.090   score=0.71
#   • Eikenella                      UI=D016970  Tree=B03.440.450.400  score=0.70
#   • Spirillaceae                   UI=D043167  Tree=B03.440.840   score=0.69
#
# Query: Romboutsia
# no matches
#
# Query: Roseburia
#   • Pasteuria                      UI=D058676  Tree=B03.300.390.650  score=0.67
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.61
#   • Roseobacter                    UI=D041904  Tree=B03.440.680   score=0.60
#
# Query: Roseburia faecis
# no matches
#
# Query: Roseburia inulinivorans
# no matches
#
# Query: Ruminococcaceae
#   • Micrococcaceae                 UI=D008835  Tree=B03.510.024.850  score=0.83
#   • Aerococcaceae                  UI=D056567  Tree=B03.353.750.030  score=0.79
#   • Planococcaceae                 UI=D058641  Tree=B03.353.500.700  score=0.76
#   • Ruminococcus                   UI=D045857  Tree=B03.353.625.806  score=0.74
#   • Enterococcaceae                UI=D056569  Tree=B03.353.750.250  score=0.73
#
# Query: Ruminococcaceae Incertae Sedis
# no matches
#
# Query: Ruminococcaceae_UCG-014
#   • Micrococcaceae                 UI=D008835  Tree=B03.510.024.850  score=0.65
#   • Ruminococcus                   UI=D045857  Tree=B03.353.625.806  score=0.63
#   • Aerococcaceae                  UI=D056567  Tree=B03.353.750.030  score=0.61
#
# Query: Ruminococcus
#   • Ruminococcus                   UI=D045857  Tree=B03.353.625.806  score=1.00
#
# Query: Ruminococcus-2
#   • Ruminococcus                   UI=D045857  Tree=B03.353.625.806  score=0.92
#   • Micrococcus                    UI=D008837  Tree=B03.510.024.850.500  score=0.72
#   • Deinococcus                    UI=D034301  Tree=B03.510.400.200  score=0.72
#   • Acidaminococcus                UI=D045850  Tree=B03.353.250   score=0.69
#   • Oenococcus                     UI=D056585  Tree=B03.353.750.475.600  score=0.67
#
# Query: S24-7
# no matches
#
# Query: Salmonella
#   • Salmonella                     UI=D012475  Tree=B03.440.450.425.800  score=1.00
#
# Query: Selenomonadalesare
#   • Selenomonas                    UI=D020357  Tree=B03.440.425.410.800.877  score=0.76
#   • Aeromonadales                  UI=D000074762 Tree=B03.660.250.018  score=0.71
#   • Pseudomonadaceae               UI=D011548  Tree=B03.440.400.425.625  score=0.71
#   • Halomonadaceae                 UI=D044129  Tree=B03.440.400.425.377  score=0.69
#   • Alteromonadaceae               UI=D034241  Tree=B03.660.250.021  score=0.65
#
# Query: Shigella
#   • Shigella                       UI=D012760  Tree=B03.440.450.425.850  score=1.00
#
# Query: Staphylococcus
#   • Staphylococcus                 UI=D013210  Tree=B03.300.390.400.800.750  score=1.00
#
# Query: Streptococcus
#   • Streptococcus                  UI=D013291  Tree=B03.353.750.737.872  score=1.00
#
# Query: Streptococcus thermophilus
#   • Streptococcus thermophilus     UI=D048249  Tree=B03.353.750.737.872.800  score=1.00
#
# Query: Subdoligranulum
# no matches
#
# Query: Succinivibrio
#   • Succinivibrionaceae            UI=D044063  Tree=B03.440.425.410.722  score=0.81
#   • Aliivibrio                     UI=D059706  Tree=B03.440.450.900.050  score=0.70
#   • Butyrivibrio                   UI=D045856  Tree=B03.353.625.250  score=0.64
#   • Vibrio                         UI=D014733  Tree=B03.440.450.900.859  score=0.63
#   • Desulfovibrio                  UI=D003901  Tree=B03.440.425.410.350  score=0.62
#
# Query: Synergistetes
# no matches
#
# Query: Thermodesulfobacteriota
#   • Thermoanaerobacter             UI=D046968  Tree=B03.353.937   score=0.68
#   • Desulfitobacterium             UI=D045858  Tree=B03.353.625.782.149  score=0.68
#   • Thermoanaerobacterium          UI=D046950  Tree=B03.353.968   score=0.68
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.59
#   • Betaproteobacteria             UI=D020562  Tree=B03.660.075   score=0.54
#
# Query: Toxoplasma gondii
#   • Mycoplasma genitalium          UI=D045704  Tree=B03.440.860.580.553.553.355  score=0.63
#   • Mycoplasma hominis             UI=D019535  Tree=B03.440.860.580.553.553.400  score=0.63
#   • Mycoplasma pulmonis            UI=D045803  Tree=B03.440.860.580.553.553.670  score=0.61
#   • Mycoplasma bovis               UI=D045682  Tree=B03.440.860.580.553.553.200  score=0.61
#
# Query: Turicibacter
#   • Arcobacter                     UI=D020640  Tree=B03.440.050   score=0.73
#   • Clavibacter                    UI=D000086162 Tree=B03.510.024.232  score=0.70
#   • Citrobacter                    UI=D002954  Tree=B03.440.450.425.200  score=0.70
#   • Marinobacter                   UI=D053520  Tree=B03.660.250.021.480  score=0.67
#   • Liberibacter                   UI=D000086202 Tree=B03.660.050.662.347  score=0.67
#
# Query: UCG-005
# no matches
#
# Query: UCG009
# no matches
#
# Query: Veillonella
#   • Veillonella                    UI=D014678  Tree=B03.440.425.410.800.938  score=1.00
#
# Query: Veillonellaceae
#   • Veillonellaceae                UI=D045854  Tree=B03.353.984   score=1.00
#
# Query: Verrucomicrobia
#   • Verrucomicrobia                UI=D061327  Tree=B03.440.930   score=1.00
#
# Query: Verrucomicrobiaceae
#   • Verrucomicrobia                UI=D061327  Tree=B03.440.930   score=0.88
#   • Hyphomicrobiaceae              UI=D041921  Tree=B03.660.050.350  score=0.72
#   • Rhizobiaceae                   UI=D012230  Tree=B03.440.400.425.700  score=0.65
#   • Aerococcaceae                  UI=D056567  Tree=B03.353.750.030  score=0.62
#   • Bradyrhizobiaceae              UI=D041841  Tree=B03.440.400.425.200  score=0.61
#
# Query: Verrucomicrobiota
#   • Verrucomicrobia                UI=D061327  Tree=B03.440.930   score=0.94
#
# Query: acetate-producing bacteria
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.65
#   • Sulfur-Reducing Bacteria       UI=D016999  Tree=B03.900       score=0.64
#   • Betaproteobacteria             UI=D020562  Tree=B03.660.075   score=0.64
#   • Deltaproteobacteria            UI=D020564  Tree=B03.660.125   score=0.62
#   • Endospore-Forming Bacteria     UI=D004725  Tree=B03.300       score=0.62
#
# Query: bacteria
#   • Bacteria                       UI=D001419  Tree=B03           score=1.00
#
# Query: bacteroides
#   • Bacteroides                    UI=D001439  Tree=B03.440.080.094.152  score=1.00
#
# Query: bifidobacteria
#   • Bifidobacterium                UI=D001644  Tree=B03.510.024.100  score=0.90
#   • Acidobacteria                  UI=D061271  Tree=B03.026       score=0.81
#   • Fusobacteria                   UI=D045182  Tree=B03.370       score=0.77
#   • Bifidobacterium breve          UI=D000069984 Tree=B03.510.024.100.375  score=0.74
#   • Bifidobacterium animalis       UI=D000069982 Tree=B03.510.024.100.250  score=0.74
#
# Query: bifidobacterial populations
#   • Bifidobacterium pseudocatenulatum UI=D000070257 Tree=B03.510.024.100.750  score=0.67
#   • Bifidobacterium animalis       UI=D000069982 Tree=B03.510.024.100.250  score=0.67
#   • Bifidobacterium                UI=D001644  Tree=B03.510.024.100  score=0.67
#   • Bifidobacterium adolescentis   UI=D000070005 Tree=B03.510.024.100.125  score=0.65
#   • Bifidobacterium longum         UI=D000069978 Tree=B03.510.024.100.500  score=0.65
#
# Query: butyrate-producing bacteria
#   • Sulfur-Reducing Bacteria       UI=D016999  Tree=B03.900       score=0.71
#   • Gram-Positive Bacteria         UI=D006094  Tree=B03.510       score=0.61
#   • Endospore-Forming Bacteria     UI=D004725  Tree=B03.300       score=0.60
#
# Query: cancer-related bacteria
#   • Gram-Negative Bacteria         UI=D006090  Tree=B03.440       score=0.67
#   • Deltaproteobacteria            UI=D020564  Tree=B03.660.125   score=0.62
#   • Cyanobacteria                  UI=D000458  Tree=B03.280       score=0.61
#   • Alphaproteobacteria            UI=D020561  Tree=B03.660.050   score=0.57
#   • Acidobacteria                  UI=D061271  Tree=B03.026       score=0.56
#
# Query: coliform
#   • L Forms                        UI=D007740  Tree=B03.110.422   score=0.67
#
# Query: coliform genera
# no matches
#
# Query: dysregulated bacteria
#   • Gram-Negative Bacteria         UI=D006090  Tree=B03.440       score=0.70
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.63
#   • Desulfitobacterium             UI=D045858  Tree=B03.353.625.782.149  score=0.62
#   • Deltaproteobacteria            UI=D020564  Tree=B03.660.125   score=0.60
#   • Sulfur-Reducing Bacteria       UI=D016999  Tree=B03.900       score=0.58
#
# Query: firmicutes
#   • Firmicutes                     UI=D000068536 Tree=B03.353       score=1.00
#
# Query: genus_Coprococcus2
#   • Enterococcus                   UI=D016983  Tree=B03.353.750.250.250  score=0.67
#   • Oenococcus                     UI=D056585  Tree=B03.353.750.475.600  score=0.64
#   • Aerococcus                     UI=D056570  Tree=B03.353.750.030.030  score=0.64
#   • Micrococcus                    UI=D008837  Tree=B03.510.024.850.500  score=0.62
#   • Deinococcus                    UI=D034301  Tree=B03.510.400.200  score=0.62
#
# Query: genus_Eggerthella
# no matches
#
# Query: genus_Eubacterium
#   • Eubacterium                    UI=D005051  Tree=B03.353.625.750  score=0.79
#   • Renibacterium                  UI=D000084402 Tree=B03.510.024.850.750  score=0.73
#   • Fusobacterium                  UI=D005673  Tree=B03.370.250   score=0.73
#   • Exiguobacterium                UI=D000086183 Tree=B03.353.500.100.309  score=0.69
#   • Corynebacterium                UI=D003352  Tree=B03.510.024.250  score=0.62
#
# Query: genus_Ruminococcaceae
#   • Enterococcaceae                UI=D056569  Tree=B03.353.750.250  score=0.72
#   • Aerococcaceae                  UI=D056567  Tree=B03.353.750.030  score=0.71
#   • Micrococcaceae                 UI=D008835  Tree=B03.510.024.850  score=0.69
#   • Planococcaceae                 UI=D058641  Tree=B03.353.500.700  score=0.63
#   • Streptococcaceae               UI=D013289  Tree=B03.353.750.737  score=0.59
#
# Query: genus_Subdoligranulum
# no matches
#
# Query: gut Bifidobacterium
#   • Bifidobacterium                UI=D001644  Tree=B03.510.024.100  score=0.88
#   • Bifidobacterium breve          UI=D000069984 Tree=B03.510.024.100.375  score=0.75
#   • Bifidobacterium longum         UI=D000069978 Tree=B03.510.024.100.500  score=0.73
#   • Bifidobacterium bifidum        UI=D000069985 Tree=B03.510.024.100.313  score=0.71
#   • Exiguobacterium                UI=D000086183 Tree=B03.353.500.100.309  score=0.71
#
# Query: gut Christensenellaceae family
# no matches
#
# Query: gut Flavonifractor genus
# no matches
#
# Query: gut bacteria
#   • Bacteria                       UI=D001419  Tree=B03           score=0.80
#   • Fusobacteria                   UI=D045182  Tree=B03.370       score=0.75
#   • Eubacterium                    UI=D005051  Tree=B03.353.625.750  score=0.70
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.69
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.69
#
# Query: gut-resident bacteria
#   • Sulfur-Reducing Bacteria       UI=D016999  Tree=B03.900       score=0.67
#   • Gram-Positive Bacteria         UI=D006094  Tree=B03.510       score=0.65
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.63
#   • Epsilonproteobacteria          UI=D020565  Tree=B03.660.150   score=0.57
#   • Gordonia Bacterium             UI=D033601  Tree=B03.510.024.700  score=0.56
#
# Query: heat-killed PS150
# no matches
#
# Query: hypnotic psychobiotic strain
# no matches
#
# Query: imbalance-inducing bacteria
#   • Sulfur-Reducing Bacteria       UI=D016999  Tree=B03.900       score=0.67
#
# Query: inactivated L. plantarum CCFM8661
# no matches
#
# Query: intestinal bacteria
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.67
#   • Gram-Negative Bacteria         UI=D006090  Tree=B03.440       score=0.63
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.61
#   • Acinetobacter                  UI=D000150  Tree=B03.440.400.425.537.050  score=0.56
#   • Atypical Bacterial Forms       UI=D001295  Tree=B03.110       score=0.56
#
# Query: live L. plantarum CCFM8661
# no matches
#
# Query: live and inactivated L. plantarum CCFM8661
# no matches
#
# Query: live and inactivated Lactobacillus plantarum CCFM8661
#   • Lactobacillus plantarum        UI=D048191  Tree=B03.353.750.450.475.612  score=0.61
#
# Query: maternal vaginal microbes
#   • Gardnerella vaginalis          UI=D006194  Tree=B03.510.024.400.800  score=0.61
#
# Query: microbes
#   • Microbacterium                 UI=D000083822 Tree=B03.510.024.775  score=0.64
#   • Microcystis                    UI=D046931  Tree=B03.280.500   score=0.63
#   • Micrococcus                    UI=D008837  Tree=B03.510.024.850.500  score=0.63
#
# Query: microorganisms
# no matches
#
# Query: mucus-associated species
# no matches
#
# Query: olidextribacter
#   • Liberibacter                   UI=D000086202 Tree=B03.660.050.662.347  score=0.81
#   • Flexibacter                    UI=D045248  Tree=B03.440.080.130.200  score=0.77
#   • Nitrobacter                    UI=D009576  Tree=B03.440.400.425.200.520  score=0.69
#   • Citrobacter                    UI=D002954  Tree=B03.440.450.425.200  score=0.69
#   • Enterobacter                   UI=D004754  Tree=B03.440.450.425.275  score=0.52
#
# Query: oral bacteria
#   • Bacteria                       UI=D001419  Tree=B03           score=0.76
#   • Fusobacteria                   UI=D045182  Tree=B03.370       score=0.72
#   • Gordonia Bacterium             UI=D033601  Tree=B03.510.024.700  score=0.71
#   • Cyanobacteria                  UI=D000458  Tree=B03.280       score=0.69
#   • Acidobacteria                  UI=D061271  Tree=B03.026       score=0.69
#
# Query: phylum Proteobacteria
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.80
#   • Alphaproteobacteria            UI=D020561  Tree=B03.660.050   score=0.80
#   • Epsilonproteobacteria          UI=D020565  Tree=B03.660.150   score=0.76
#   • Gammaproteobacteria            UI=D020563  Tree=B03.660.250   score=0.75
#   • Deltaproteobacteria            UI=D020564  Tree=B03.660.125   score=0.75
#
# Query: plantarum P-8
# no matches
#
# Query: predominant bacteria
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.71
#   • Endospore-Forming Bacteria     UI=D004725  Tree=B03.300       score=0.70
#   • Gordonia Bacterium             UI=D033601  Tree=B03.510.024.700  score=0.68
#   • Pedobacter                     UI=D060485  Tree=B03.440.080.600  score=0.67
#   • Propionibacteriaceae           UI=D011423  Tree=B03.510.024.990  score=0.65
#
# Query: probiotics
# no matches
#
# Query: psychobiotic strain
# no matches
#
# Query: psychobiotics
#   • Synechocystis                  UI=D046939  Tree=B03.280.750   score=0.62
#   • Psychrobacter                  UI=D044096  Tree=B03.440.400.425.537.650  score=0.62
#
# Query: short-chain fatty acid (SCFA)-producing bacteria
# no matches
#
# Query: short-chain fatty acid producing bacteria
# no matches
#
# Query: xylanophilum_group
#   • Xylophilus                     UI=D000086326 Tree=B03.660.075.090.941  score=0.64

# %%
import xml.etree.ElementTree as ET

def parse_mesh_descriptors(xml_path):
    """
    Parse the MeSH XML and return a list of dicts:
      { 'ui': DescriptorUI,
        'name': DescriptorName,
        'tree_numbers': [treeNum1, treeNum2, ...]
      }
    """
    tree = ET.parse(xml_path)
    root = tree.getroot()
    descriptors = []
    for dr in root.findall('DescriptorRecord'):
        ui_el = dr.find('DescriptorUI')
        name_el = dr.find('DescriptorName/String')
        if ui_el is None or name_el is None:
            continue
        ui = ui_el.text
        name = name_el.text
        tree_numbers = [tn.text for tn in dr.findall('TreeNumberList/TreeNumber') if tn.text]
        descriptors.append({
            'ui': ui,
            'name': name,
            'tree_numbers': tree_numbers
        })
    return descriptors

def get_bacteria_taxonomy(xml_path):
    """
    From the full MeSH descriptors file, extract all descriptors
    under the 'Bacteria' branch (tree number B03).
    Returns a dict: { tree_number: { 'ui': ..., 'name': ... }, ... }
    """
    descriptors = parse_mesh_descriptors(xml_path)

    bacteria_prefix = None
    for d in descriptors:
        if d['name'] == 'Bacteria':
            bacteria_prefix = d['tree_numbers'][0]
            break

    if not bacteria_prefix:
        raise RuntimeError("Couldn't find a descriptor named 'Bacteria' in the file.")

    taxonomy = {}
    for d in descriptors:
        for tn in d['tree_numbers']:
            if tn == bacteria_prefix or tn.startswith(bacteria_prefix + '.'):
                taxonomy[tn] = {
                    'ui': d['ui'],
                    'name': d['name']
                }
                break

    return taxonomy

if __name__ == '__main__':
    xml_file = 'desc2025.xml'
    bacteria_tax = get_bacteria_taxonomy(xml_file)

    for tree_num in sorted(bacteria_tax):
        info = bacteria_tax[tree_num]
        print(f"{tree_num:10s}  {info['name']:30s}  ({info['ui']})")
# Out:
# B03         Bacteria                        (D001419)
# B03.026     Acidobacteria                   (D061271)
# B03.054     Agricultural Inoculants         (D059827)
# B03.110     Atypical Bacterial Forms        (D001295)
# B03.110.422  L Forms                         (D007740)
# B03.110.761  Spheroplasts                    (D013104)
# B03.120     Bacteria, Aerobic               (D001420)
# B03.130     Bacteria, Anaerobic             (D001421)
# B03.135     Bacteria, Thermoduric           (D000072280)
# B03.250     Chlorobi                        (D019414)
# B03.250.140  Chlorobium                      (D041883)
# B03.275     Chloroflexi                     (D041862)
# B03.275.150  Chloroflexus                    (D041861)
# B03.275.575  Dehalococcoides                 (D000082942)
# B03.280     Cyanobacteria                   (D000458)
# B03.280.100  Anabaena                        (D017033)
# B03.280.100.150  Anabaena cylindrica             (D046868)
# B03.280.100.900  Anabaena variabilis             (D046870)
# B03.280.110  Aphanizomenon                   (D046890)
# B03.280.200  Cyanothece                      (D046889)
# B03.280.210  Cylindrospermopsis              (D046891)
# B03.280.283  Dolichospermum flos-aquae       (D046869)
# B03.280.355  Lyngbya                         (D000083582)
# B03.280.500  Microcystis                     (D046931)
# B03.280.550  Nodularia                       (D046932)
# B03.280.575  Nostoc                          (D046937)
# B03.280.575.150  Nostoc commune                  (D050501)
# B03.280.575.500  Nostoc muscorum                 (D050502)
# B03.280.612  Oscillatoria                    (D054300)
# B03.280.622  Pannus                          (D000086282)
# B03.280.631  Phormidium                      (D000084242)
# B03.280.641  Planktothrix                    (D000086302)
# B03.280.650  Plectonema                      (D046938)
# B03.280.697  Spirulina                       (D053545)
# B03.280.745  Synechococcus                   (D046940)
# B03.280.750  Synechocystis                   (D046939)
# B03.280.813  Thermosynechococcus             (D000086325)
# B03.280.875  Trichodesmium                   (D000072359)
# B03.300     Endospore-Forming Bacteria      (D004725)
# B03.300.390  Gram-Positive Endospore-Forming Bacteria  (D016936)
# B03.300.390.400  Gram-Positive Endospore-Forming Rods  (D016937)
# B03.300.390.400.158  Bacillaceae                     (D001406)
# B03.300.390.400.158.108  Anoxybacillus                   (D058677)
# B03.300.390.400.158.218  Bacillus                        (D001407)
# B03.300.390.400.158.218.076  Bacillus amyloliquefaciens      (D000069977)
# B03.300.390.400.158.218.151  Bacillus anthracis              (D001408)
# B03.300.390.400.158.218.252  Bacillus cereus                 (D001409)
# B03.300.390.400.158.218.283  Bacillus clausii                (D000070019)
# B03.300.390.400.158.218.314  Bacillus coagulans              (D000070000)
# B03.300.390.400.158.218.345  Bacillus firmus                 (D000070098)
# B03.300.390.400.158.218.376  Bacillus licheniformis          (D000069976)
# B03.300.390.400.158.218.500  Bacillus megaterium             (D001410)
# B03.300.390.400.158.218.613  Bacillus pumilus                (D000069979)
# B03.300.390.400.158.218.725  Bacillus subtilis               (D001412)
# B03.300.390.400.158.218.800  Bacillus thuringiensis          (D001413)
# B03.300.390.400.158.400  Geobacillus                     (D056506)
# B03.300.390.400.158.400.400  Geobacillus stearothermophilus  (D001411)
# B03.300.390.400.158.600  Halobacillus                    (D058678)
# B03.300.390.400.158.900  Virgibacillus                   (D058679)
# B03.300.390.400.160  Brevibacillus                   (D058675)
# B03.300.390.400.200  Clostridium                     (D003013)
# B03.300.390.400.200.025  Clostridium acetobutylicum      (D046969)
# B03.300.390.400.200.100  Clostridium beijerinckii        (D046970)
# B03.300.390.400.200.130  Clostridium bifermentans        (D046971)
# B03.300.390.400.200.160  Clostridium botulinum           (D003014)
# B03.300.390.400.200.160.050  Clostridium botulinum type A    (D047013)
# B03.300.390.400.200.160.100  Clostridium botulinum type B    (D047014)
# B03.300.390.400.200.160.150  Clostridium botulinum type C    (D047968)
# B03.300.390.400.200.160.200  Clostridium botulinum type D    (D047969)
# B03.300.390.400.200.160.250  Clostridium botulinum type E    (D047970)
# B03.300.390.400.200.160.300  Clostridium botulinum type F    (D047971)
# B03.300.390.400.200.160.350  Clostridium botulinum type G    (D048568)
# B03.300.390.400.200.180  Clostridium butyricum           (D046972)
# B03.300.390.400.200.200  Clostridium cellulolyticum      (D046973)
# B03.300.390.400.200.205  Clostridium cellulovorans       (D046974)
# B03.300.390.400.200.215  Clostridium chauvoei            (D046975)
# B03.300.390.400.200.412  Clostridium histolyticum        (D047009)
# B03.300.390.400.200.493  Clostridium kluyveri            (D047010)
# B03.300.390.400.200.575  Clostridium perfringens         (D003016)
# B03.300.390.400.200.690  Clostridium septicum            (D052557)
# B03.300.390.400.200.700  Clostridium sordellii           (D047989)
# B03.300.390.400.200.710  Clostridium sticklandii         (D047991)
# B03.300.390.400.200.713  Clostridium symbiosum           (D048009)
# B03.300.390.400.200.722  Clostridium tertium             (D048010)
# B03.300.390.400.200.725  Clostridium tetani              (D003017)
# B03.300.390.400.200.740  Clostridium tetanomorphum       (D048012)
# B03.300.390.400.200.770  Clostridium thermocellum        (D048013)
# B03.300.390.400.200.800  Clostridium tyrobutyricum       (D048014)
# B03.300.390.400.500  Micromonosporaceae              (D008848)
# B03.300.390.400.500.250  Actinoplanes                    (D000079584)
# B03.300.390.400.500.500  Micromonospora                  (D008847)
# B03.300.390.400.525  Moorella                        (D058845)
# B03.300.390.400.645  Paenibacillus                   (D056507)
# B03.300.390.400.645.500  Paenibacillus larvae            (D000070059)
# B03.300.390.400.645.750  Paenibacillus polymyxa          (D000070057)
# B03.300.390.400.790  Saccharopolyspora               (D016930)
# B03.300.390.400.800  Staphylococcaceae               (D040141)
# B03.300.390.400.800.750  Staphylococcus                  (D013210)
# B03.300.390.400.800.750.100  Staphylococcus aureus           (D013211)
# B03.300.390.400.800.750.100.500  Methicillin-Resistant Staphylococcus aureus  (D055624)
# B03.300.390.400.800.750.100.750  Vancomycin-Resistant Staphylococcus aureus  (D000083123)
# B03.300.390.400.800.750.222  Staphylococcus capitis          (D000074039)
# B03.300.390.400.800.750.343  Staphylococcus epidermidis      (D013212)
# B03.300.390.400.800.750.400  Staphylococcus haemolyticus     (D041162)
# B03.300.390.400.800.750.425  Staphylococcus hominis          (D041181)
# B03.300.390.400.800.750.435  Staphylococcus hyicus           (D057788)
# B03.300.390.400.800.750.445  Staphylococcus intermedius      (D057789)
# B03.300.390.400.800.750.500  Staphylococcus lugdunensis      (D057787)
# B03.300.390.400.800.750.750  Staphylococcus saprophyticus    (D057790)
# B03.300.390.400.810  Streptomycetaceae               (D013306)
# B03.300.390.400.810.768  Streptomyces                    (D013302)
# B03.300.390.400.810.768.100  Streptomyces antibioticus       (D013303)
# B03.300.390.400.810.768.125  Streptomyces aureofaciens       (D013304)
# B03.300.390.400.810.768.200  Streptomyces coelicolor         (D048372)
# B03.300.390.400.810.768.375  Streptomyces griseus            (D013305)
# B03.300.390.400.810.768.500  Streptomyces lividans           (D048170)
# B03.300.390.400.810.768.750  Streptomyces rimosus            (D064411)
# B03.300.390.650  Pasteuria                       (D058676)
# B03.300.390.825  Sporosarcina                    (D058644)
# B03.353     Firmicutes                      (D000068536)
# B03.353.250  Acidaminococcus                 (D045850)
# B03.353.500  Bacillales                      (D056449)
# B03.353.500.050  Alicyclobacillus                (D056450)
# B03.353.500.100.309  Exiguobacterium                 (D000086183)
# B03.353.500.120  Brochothrix                     (D058640)
# B03.353.500.310  Gemella                         (D058834)
# B03.353.500.500  Listeria                        (D008087)
# B03.353.500.500.500  Listeria monocytogenes          (D008089)
# B03.353.500.700  Planococcaceae                  (D058641)
# B03.353.500.875  Thermoactinomyces               (D056509)
# B03.353.563  Caldicellulosiruptor            (D000082623)
# B03.353.625  Clostridiales                   (D000068016)
# B03.353.625.250  Butyrivibrio                    (D045856)
# B03.353.625.250.500  Butyrivibrio fibrisolvens       (D000070097)
# B03.353.625.375  Clostridiaceae                  (D000073561)
# B03.353.625.375.750  Sarcina                         (D012505)
# B03.353.625.657  Clostridioides                  (D000082682)
# B03.353.625.657.500  Clostridioides difficile        (D016360)
# B03.353.625.750  Eubacterium                     (D005051)
# B03.353.625.766  Faecalibacterium                (D000070036)
# B03.353.625.766.500  Faecalibacterium prausnitzii    (D000070037)
# B03.353.625.774  Neglecta                        (D000086242)
# B03.353.625.782  Peptococcaceae                  (D010459)
# B03.353.625.782.149  Desulfitobacterium              (D045858)
# B03.353.625.782.297  Desulfotomaculum                (D045859)
# B03.353.625.782.593  Peptococcus                     (D010460)
# B03.353.625.798  Peptostreptococcus              (D010462)
# B03.353.625.806  Ruminococcus                    (D045857)
# B03.353.688  Erysipelothrix                  (D004888)
# B03.353.750  Lactobacillales                 (D056546)
# B03.353.750.030  Aerococcaceae                   (D056567)
# B03.353.750.030.014  Abiotrophia                     (D058835)
# B03.353.750.030.030  Aerococcus                      (D056570)
# B03.353.750.130  Carnobacteriaceae               (D056568)
# B03.353.750.130.150  Carnobacterium                  (D056573)
# B03.353.750.250  Enterococcaceae                 (D056569)
# B03.353.750.250.250  Enterococcus                    (D016983)
# B03.353.750.250.250.280  Enterococcus faecalis           (D013293)
# B03.353.750.250.250.300  Enterococcus faecium            (D016984)
# B03.353.750.250.250.475  Enterococcus hirae              (D000070076)
# B03.353.750.250.250.650  Vancomycin-Resistant Enterococci  (D065507)
# B03.353.750.450  Lactobacillaceae                (D007777)
# B03.353.750.450.475  Lactobacillus                   (D007778)
# B03.353.750.450.475.100  Lactobacillus acidophilus       (D007779)
# B03.353.750.450.475.238  Lactobacillus crispatus         (D000070003)
# B03.353.750.450.475.250  Lactobacillus delbrueckii       (D048668)
# B03.353.750.450.475.363  Lactobacillus gasseri           (D000069998)
# B03.353.750.450.475.400  Lactobacillus helveticus        (D052198)
# B03.353.750.450.475.453  Lactobacillus johnsonii         (D000069999)
# B03.353.750.450.475.506  Lactobacillus leichmannii       (D052199)
# B03.353.750.450.475.586  Lactobacillus pentosus          (D000070018)
# B03.353.750.450.475.612  Lactobacillus plantarum         (D048191)
# B03.353.750.450.606  Lacticaseibacillus              (D000093622)
# B03.353.750.450.606.500  Lacticaseibacillus casei        (D007780)
# B03.353.750.450.606.750  Lacticaseibacillus paracasei    (D000069980)
# B03.353.750.450.606.875  Lacticaseibacillus rhamnosus    (D052201)
# B03.353.750.450.623  Latilactobacillus sakei         (D000070256)
# B03.353.750.450.639  Levilactobacillus brevis        (D052196)
# B03.353.750.450.656  Ligilactobacillus salivarius    (D000069996)
# B03.353.750.450.672  Limosilactobacillus fermentum   (D052197)
# B03.353.750.450.705  Limosilactobacillus reuteri     (D052200)
# B03.353.750.450.737  Pediococcus                     (D010376)
# B03.353.750.450.737.500  Pediococcus acidilactici        (D000070016)
# B03.353.750.450.737.750  Pediococcus pentosaceus         (D000070006)
# B03.353.750.475  Leuconostocaceae                (D056584)
# B03.353.750.475.450  Leuconostoc                     (D007934)
# B03.353.750.475.450.500  Leuconostoc mesenteroides       (D000070007)
# B03.353.750.475.600  Oenococcus                      (D056585)
# B03.353.750.475.900  Weissella                       (D058836)
# B03.353.750.737  Streptococcaceae                (D013289)
# B03.353.750.737.500  Lactococcus                     (D017045)
# B03.353.750.737.500.400  Lactococcus lactis              (D013294)
# B03.353.750.737.872  Streptococcus                   (D013291)
# B03.353.750.737.872.100  Streptococcus agalactiae        (D013292)
# B03.353.750.737.872.150  Streptococcus bovis             (D016985)
# B03.353.750.737.872.225  Streptococcus equi              (D018502)
# B03.353.750.737.872.243  Streptococcus gallolyticus      (D000070099)
# B03.353.750.737.872.243.500  Streptococcus gallolyticus subspecies gallolyticus  (D000070197)
# B03.353.750.737.872.260  Streptococcus gordonii          (D054773)
# B03.353.750.737.872.405  Streptococcus iniae             (D000070058)
# B03.353.750.737.872.550  Streptococcus pneumoniae        (D013296)
# B03.353.750.737.872.575  Streptococcus pyogenes          (D013297)
# B03.353.750.737.872.663  Streptococcus salivarius        (D000070001)
# B03.353.750.737.872.750  Streptococcus suis              (D017011)
# B03.353.750.737.872.800  Streptococcus thermophilus      (D048249)
# B03.353.750.737.872.875  Viridans Streptococci           (D034363)
# B03.353.750.737.872.875.475  Streptococcus milleri Group     (D034364)
# B03.353.750.737.872.875.475.080  Streptococcus anginosus         (D034366)
# B03.353.750.737.872.875.475.150  Streptococcus constellatus      (D034365)
# B03.353.750.737.872.875.475.400  Streptococcus intermedius       (D034367)
# B03.353.750.737.872.875.500  Streptococcus mitis             (D034361)
# B03.353.750.737.872.875.520  Streptococcus mutans            (D013295)
# B03.353.750.737.872.875.600  Streptococcus oralis            (D019533)
# B03.353.750.737.872.875.700  Streptococcus sanguis           (D013298)
# B03.353.750.737.872.875.750  Streptococcus sobrinus          (D016986)
# B03.353.937  Thermoanaerobacter              (D046968)
# B03.353.968  Thermoanaerobacterium           (D046950)
# B03.353.984  Veillonellaceae                 (D045854)
# B03.370     Fusobacteria                    (D045182)
# B03.370.250  Fusobacterium                   (D005673)
# B03.370.250.400  Fusobacterium necrophorum       (D005675)
# B03.370.250.500  Fusobacterium nucleatum         (D016967)
# B03.370.437  Leptotrichia                    (D045183)
# B03.370.600  Propionigenium                  (D045184)
# B03.370.700  Streptobacillus                 (D013288)
# B03.440     Gram-Negative Bacteria          (D006090)
# B03.440.025  Aquifex                         (D000086142)
# B03.440.050  Arcobacter                      (D020640)
# B03.440.080  Bacteroidetes                   (D041963)
# B03.440.080.094  Bacteroidaceae                  (D001438)
# B03.440.080.094.152  Bacteroides                     (D001439)
# B03.440.080.094.152.400  Bacteroides fragilis            (D001441)
# B03.440.080.094.152.700  Bacteroides thetaiotaomicron    (D000070077)
# B03.440.080.094.389  Mediterranea                    (D000086222)
# B03.440.080.094.625  Porphyromonas                   (D017861)
# B03.440.080.094.625.350  Porphyromonas endodontalis      (D045202)
# B03.440.080.094.625.515  Porphyromonas gingivalis        (D016966)
# B03.440.080.094.640  Prevotella                      (D018720)
# B03.440.080.094.640.375  Prevotella intermedia           (D018713)
# B03.440.080.094.640.500  Prevotella melaninogenica       (D001443)
# B03.440.080.094.640.550  Prevotella nigrescens           (D045242)
# B03.440.080.094.640.700  Prevotella ruminicola           (D045243)
# B03.440.080.130  Cytophagaceae                   (D041964)
# B03.440.080.130.150  Cytophaga                       (D003589)
# B03.440.080.130.200  Flexibacter                     (D045248)
# B03.440.080.190  Flavobacteriaceae               (D041965)
# B03.440.080.190.100  Capnocytophaga                  (D002206)
# B03.440.080.190.120  Chryseobacterium                (D045247)
# B03.440.080.190.250  Flavobacterium                  (D005417)
# B03.440.080.190.600  Ornithobacterium                (D045246)
# B03.440.080.190.700  Riemerella                      (D060494)
# B03.440.080.190.800  Tenacibaculum                   (D060493)
# B03.440.080.600  Pedobacter                      (D060485)
# B03.440.080.750  Rhodothermus                    (D045245)
# B03.440.080.800  Sphingobacterium                (D045249)
# B03.440.080.850  Tannerella                      (D000084422)
# B03.440.080.850.500  Tannerella forsythia            (D000070436)
# B03.440.090  Bartonellaceae                  (D001475)
# B03.440.090.100  Bartonella                      (D001473)
# B03.440.090.100.080  Bartonella bacilliformis        (D045503)
# B03.440.090.100.350  Bartonella henselae             (D018416)
# B03.440.090.100.650  Bartonella quintana             (D018413)
# B03.440.097  Brachyspira                     (D017400)
# B03.440.097.100  Brachyspira hyodysenteriae      (D017401)
# B03.440.100  Buchnera                        (D020635)
# B03.440.180  Campylobacter                   (D002167)
# B03.440.180.200  Campylobacter coli              (D017000)
# B03.440.180.325  Campylobacter fetus             (D002168)
# B03.440.180.375  Campylobacter hyointestinalis   (D044862)
# B03.440.180.425  Campylobacter jejuni            (D016123)
# B03.440.180.500  Campylobacter lari              (D044863)
# B03.440.180.650  Campylobacter rectus            (D044883)
# B03.440.180.700  Campylobacter sputorum          (D044884)
# B03.440.180.800  Campylobacter upsaliensis       (D044885)
# B03.440.190  Chlamydiales                    (D002695)
# B03.440.190.190  Chlamydiaceae                   (D002693)
# B03.440.190.190.190  Chlamydia                       (D002689)
# B03.440.190.190.190.500  Chlamydia muridarum             (D023502)
# B03.440.190.190.190.750  Chlamydia trachomatis           (D002692)
# B03.440.190.190.230  Chlamydophila                   (D023501)
# B03.440.190.190.230.249  Chlamydophila pneumoniae        (D016993)
# B03.440.190.190.230.500  Chlamydophila psittaci          (D002691)
# B03.440.305  Fibrobacteres                   (D061306)
# B03.440.305.500  Fibrobacter                     (D045848)
# B03.440.400  Gram-Negative Aerobic Bacteria  (D006088)
# B03.440.400.280  Caulobacter                     (D016934)
# B03.440.400.280.280  Caulobacter crescentus          (D016935)
# B03.440.400.400  Gallionellaceae                 (D043372)
# B03.440.400.425  Gram-Negative Aerobic Rods and Cocci  (D016946)
# B03.440.400.425.100  Acetobacteraceae                (D016947)
# B03.440.400.425.100.100  Acetobacter                     (D000091)
# B03.440.400.425.100.110  Acidiphilium                    (D041801)
# B03.440.400.425.100.550  Gluconobacter                   (D020576)
# B03.440.400.425.100.550.550  Gluconobacter oxydans           (D020600)
# B03.440.400.425.103  Acidithiobacillus               (D042763)
# B03.440.400.425.103.800  Acidithiobacillus thiooxidans   (D013856)
# B03.440.400.425.115  Alcaligenaceae                  (D042401)
# B03.440.400.425.115.030  Achromobacter                   (D042402)
# B03.440.400.425.115.030.100  Achromobacter cycloclastes      (D042422)
# B03.440.400.425.115.030.120  Achromobacter denitrificans     (D042441)
# B03.440.400.425.115.050  Alcaligenes                     (D000421)
# B03.440.400.425.115.050.200  Alcaligenes faecalis            (D042481)
# B03.440.400.425.115.425  Bordetella                      (D001884)
# B03.440.400.425.115.425.024  Bordetella avium                (D042482)
# B03.440.400.425.115.425.050  Bordetella bronchiseptica       (D016950)
# B03.440.400.425.115.425.590  Bordetella parapertussis        (D042483)
# B03.440.400.425.115.425.600  Bordetella pertussis            (D001886)
# B03.440.400.425.115.800  Taylorella                      (D042502)
# B03.440.400.425.115.800.200  Taylorella equigenitalis        (D020625)
# B03.440.400.425.126  Alteromonas                     (D020591)
# B03.440.400.425.127  Azorhizobium                    (D020583)
# B03.440.400.425.127.100  Azorhizobium caulinodans        (D020599)
# B03.440.400.425.180  Bdellovibrio                    (D001501)
# B03.440.400.425.180.500  Bdellovibrio bacteriovorus      (D000070060)
# B03.440.400.425.200  Bradyrhizobiaceae               (D041841)
# B03.440.400.425.200.040  Afipia                          (D020622)
# B03.440.400.425.200.090  Bradyrhizobium                  (D020369)
# B03.440.400.425.200.520  Nitrobacter                     (D009576)
# B03.440.400.425.200.700  Rhodopseudomonas                (D012241)
# B03.440.400.425.215  Brucellaceae                    (D042021)
# B03.440.400.425.215.500  Brucella                        (D002002)
# B03.440.400.425.215.500.100  Brucella abortus                (D002003)
# B03.440.400.425.215.500.150  Brucella canis                  (D041002)
# B03.440.400.425.215.500.500  Brucella melitensis             (D017347)
# B03.440.400.425.215.500.625  Brucella ovis                   (D042061)
# B03.440.400.425.215.500.750  Brucella suis                   (D041021)
# B03.440.400.425.251  Burkholderiaceae                (D042521)
# B03.440.400.425.251.200  Cupriavidus                     (D049921)
# B03.440.400.425.251.200.200  Cupriavidus necator             (D020118)
# B03.440.400.425.288  Caulobacteraceae                (D042063)
# B03.440.400.425.293  Comamonadaceae                  (D042621)
# B03.440.400.425.293.150  Comamonas                       (D020585)
# B03.440.400.425.293.150.750  Comamonas testosteroni          (D020604)
# B03.440.400.425.293.170  Delftia                         (D042742)
# B03.440.400.425.293.170.030  Delftia acidovorans             (D020605)
# B03.440.400.425.293.750  Sphaerotilus                    (D042744)
# B03.440.400.425.297  Coxiellaceae                    (D044125)
# B03.440.400.425.297.150  Coxiella                        (D003381)
# B03.440.400.425.297.150.100  Coxiella burnetii               (D016997)
# B03.440.400.425.340  Francisella                     (D005603)
# B03.440.400.425.340.590  Francisella tularensis          (D005604)
# B03.440.400.425.365  Gluconacetobacter               (D041821)
# B03.440.400.425.365.500  Gluconacetobacter xylinus       (D041822)
# B03.440.400.425.377  Halomonadaceae                  (D044129)
# B03.440.400.425.377.249  Chromohalobacter                (D055353)
# B03.440.400.425.377.500  Halomonas                       (D020632)
# B03.440.400.425.395  Halothiobacillus                (D044222)
# B03.440.400.425.450  Legionellaceae                  (D016951)
# B03.440.400.425.450.450  Legionella                      (D007875)
# B03.440.400.425.450.450.400  Legionella longbeachae          (D044128)
# B03.440.400.425.450.450.500  Legionella pneumophila          (D016952)
# B03.440.400.425.475  Leptospiraceae                  (D016953)
# B03.440.400.425.475.475  Leptospira                      (D007919)
# B03.440.400.425.475.475.400  Leptospira interrogans          (D007921)
# B03.440.400.425.475.475.400.050  Leptospira interrogans serovar australis  (D041281)
# B03.440.400.425.475.475.400.055  Leptospira interrogans serovar autumnalis  (D041301)
# B03.440.400.425.475.475.400.150  Leptospira interrogans serovar canicola  (D041341)
# B03.440.400.425.475.475.400.400  Leptospira interrogans serovar hebdomadis  (D041343)
# B03.440.400.425.475.475.400.420  Leptospira interrogans serovar icterohaemorrhagiae  (D041383)
# B03.440.400.425.475.475.400.650  Leptospira interrogans serovar pomona  (D041401)
# B03.440.400.425.481  Leptothrix                      (D042743)
# B03.440.400.425.487  Methylobacteriaceae             (D042082)
# B03.440.400.425.487.500  Methylobacterium                (D020580)
# B03.440.400.425.487.500.150  Methylobacterium extorquens     (D020601)
# B03.440.400.425.500  Methylococcaceae                (D008772)
# B03.440.400.425.500.500  Methylococcus                   (D020618)
# B03.440.400.425.500.500.100  Methylococcus capsulatus        (D020619)
# B03.440.400.425.500.505  Methylomonas                    (D020620)
# B03.440.400.425.525  Methylophilaceae                (D042762)
# B03.440.400.425.525.500  Methylobacillus                 (D020631)
# B03.440.400.425.525.520  Methylophilus                   (D020629)
# B03.440.400.425.525.520.500  Methylophilus methylotrophus    (D020630)
# B03.440.400.425.537  Moraxellaceae                   (D044007)
# B03.440.400.425.537.050  Acinetobacter                   (D000150)
# B03.440.400.425.537.050.099  Acinetobacter baumannii         (D040981)
# B03.440.400.425.537.050.200  Acinetobacter calcoaceticus     (D016954)
# B03.440.400.425.537.525  Moraxella                       (D009016)
# B03.440.400.425.537.525.200  Moraxella catarrhalis           (D001936)
# B03.440.400.425.537.525.500  Moraxella bovis                 (D016955)
# B03.440.400.425.537.650  Psychrobacter                   (D044096)
# B03.440.400.425.550  Neisseriaceae                   (D009346)
# B03.440.400.425.550.400  Kingella                        (D017881)
# B03.440.400.425.550.400.375  Kingella kingae                 (D017882)
# B03.440.400.425.550.550  Neisseria                       (D009343)
# B03.440.400.425.550.550.125  Neisseria cinerea               (D042804)
# B03.440.400.425.550.550.299  Neisseria elongata              (D042805)
# B03.440.400.425.550.550.474  Neisseria gonorrhoeae           (D009344)
# B03.440.400.425.550.550.600  Neisseria lactamica             (D042806)
# B03.440.400.425.550.550.641  Neisseria meningitidis          (D009345)
# B03.440.400.425.550.550.641.700  Neisseria meningitidis, Serogroup A  (D038381)
# B03.440.400.425.550.550.641.710  Neisseria meningitidis, Serogroup B  (D038541)
# B03.440.400.425.550.550.641.720  Neisseria meningitidis, Serogroup C  (D038542)
# B03.440.400.425.550.550.641.800  Neisseria meningitidis, Serogroup W-135  (D038582)
# B03.440.400.425.550.550.641.820  Neisseria meningitidis, Serogroup Y  (D038581)
# B03.440.400.425.550.550.660  Neisseria mucosa                (D042807)
# B03.440.400.425.550.550.800  Neisseria sicca                 (D042808)
# B03.440.400.425.562  Nitrosomonadaceae               (D043369)
# B03.440.400.425.562.500  Nitrosomonas                    (D009606)
# B03.440.400.425.562.500.200  Nitrosomonas europaea           (D043370)
# B03.440.400.425.575  Ochrobactrum                    (D042041)
# B03.440.400.425.575.650  Ochrobactrum anthropi           (D020621)
# B03.440.400.425.587  Oxalobacteraceae                (D042802)
# B03.440.400.425.587.400  Herbaspirillum                  (D042803)
# B03.440.400.425.600  Paracoccus                      (D010230)
# B03.440.400.425.600.380  Paracoccus denitrificans        (D010231)
# B03.440.400.425.600.690  Paracoccus pantotrophus         (D042084)
# B03.440.400.425.622  Pseudoalteromonas               (D031161)
# B03.440.400.425.625  Pseudomonadaceae                (D011548)
# B03.440.400.425.625.050  Azotobacter                     (D001395)
# B03.440.400.425.625.050.850  Azotobacter vinelandii          (D016948)
# B03.440.400.425.625.150  Cellvibrio                      (D020633)
# B03.440.400.425.625.625  Pseudomonas                     (D011549)
# B03.440.400.425.625.625.100  Pseudomonas aeruginosa          (D011550)
# B03.440.400.425.625.625.120  Pseudomonas alcaligenes         (D044202)
# B03.440.400.425.625.625.223  Pseudomonas chlororaphis        (D000070096)
# B03.440.400.425.625.625.325  Pseudomonas fluorescens         (D011551)
# B03.440.400.425.625.625.350  Pseudomonas fragi               (D044206)
# B03.440.400.425.625.625.500  Pseudomonas mendocina           (D044203)
# B03.440.400.425.625.625.650  Pseudomonas oleovorans          (D044204)
# B03.440.400.425.625.625.662  Pseudomonas pseudoalcaligenes   (D044205)
# B03.440.400.425.625.625.675  Pseudomonas putida              (D016958)
# B03.440.400.425.625.625.750  Pseudomonas stutzeri            (D044223)
# B03.440.400.425.625.625.770  Pseudomonas syringae            (D044224)
# B03.440.400.425.700  Rhizobiaceae                    (D012230)
# B03.440.400.425.700.024  Agrobacterium                   (D060054)
# B03.440.400.425.700.024.050  Agrobacterium tumefaciens       (D016960)
# B03.440.400.425.700.800  Rhizobium                       (D012231)
# B03.440.400.425.700.800.337  Rhizobium etli                  (D042163)
# B03.440.400.425.700.800.450  Rhizobium leguminosarum         (D016961)
# B03.440.400.425.700.800.600  Rhizobium phaseoli              (D042161)
# B03.440.400.425.700.800.800  Rhizobium tropici               (D042162)
# B03.440.400.425.700.887  Sinorhizobium                   (D020579)
# B03.440.400.425.700.887.249  Sinorhizobium fredii            (D042181)
# B03.440.400.425.700.887.500  Sinorhizobium meliloti          (D016962)
# B03.440.400.425.708  Rhodospirillaceae               (D012244)
# B03.440.400.425.708.100  Azospirillum                    (D016949)
# B03.440.400.425.708.100.020  Azospirillum brasilense         (D015806)
# B03.440.400.425.708.100.510  Azospirillum lipoferum          (D042081)
# B03.440.400.425.708.500  Magnetospirillum                (D042201)
# B03.440.400.425.708.733  Rhodospirillum                  (D012246)
# B03.440.400.425.708.733.150  Rhodospirillum centenum         (D042182)
# B03.440.400.425.708.733.650  Rhodospirillum rubrum           (D012247)
# B03.440.400.425.750  Sphingomonas                    (D020578)
# B03.440.400.425.875  Thermus                         (D013824)
# B03.440.400.425.875.875  Thermus thermophilus            (D016963)
# B03.440.400.425.935  Xanthobacter                    (D020584)
# B03.440.400.425.967  Xanthomonadaceae                (D044166)
# B03.440.400.425.967.500  Lysobacter                      (D053528)
# B03.440.400.425.967.750  Stenotrophomonas                (D020588)
# B03.440.400.425.967.750.500  Stenotrophomonas maltophilia    (D020615)
# B03.440.400.425.967.930  Xanthomonas                     (D014974)
# B03.440.400.425.967.930.100  Xanthomonas campestris          (D016959)
# B03.440.400.425.967.930.850  Xanthomonas vesicatoria         (D044184)
# B03.440.400.425.967.950  Xylella                         (D044167)
# B03.440.400.425.983  Zoogloea                        (D015045)
# B03.440.400.450  Gram-Negative Chemolithotrophic Bacteria  (D006091)
# B03.440.400.450.800  Thiobacillus                    (D013855)
# B03.440.400.645  Thiotrichaceae                  (D041962)
# B03.440.400.645.100  Beggiatoa                       (D053524)
# B03.440.400.645.800  Thiothrix                       (D053525)
# B03.440.400.840  Vitreoscilla                    (D020589)
# B03.440.425  Gram-Negative Anaerobic Bacteria  (D006089)
# B03.440.425.200  Desulfovibrionaceae             (D000073564)
# B03.440.425.400  Gram-Negative Anaerobic Cocci   (D016964)
# B03.440.425.400.500  Megasphaera                     (D045851)
# B03.440.425.400.500.500  Megasphaera elsdenii            (D000070101)
# B03.440.425.400.750  Thiocapsa                       (D020586)
# B03.440.425.400.750.660  Thiocapsa roseopersicina        (D020616)
# B03.440.425.410  Gram-Negative Anaerobic Straight, Curved, and Helical Rods  (D016965)
# B03.440.425.410.145  Anaerobiospirillum              (D044064)
# B03.440.425.410.200  Bilophila                       (D045282)
# B03.440.425.410.290  Chromatium                      (D002844)
# B03.440.425.410.350  Desulfovibrio                   (D003901)
# B03.440.425.410.350.040  Desulfovibrio africanus         (D045284)
# B03.440.425.410.350.150  Desulfovibrio desulfuricans     (D045285)
# B03.440.425.410.350.350  Desulfovibrio gigas             (D045286)
# B03.440.425.410.350.875  Desulfovibrio vulgaris          (D016969)
# B03.440.425.410.360  Desulfuromonas                  (D045287)
# B03.440.425.410.400  Dichelobacter nodosus           (D020376)
# B03.440.425.410.405  Ectothiorhodospiraceae          (D042001)
# B03.440.425.410.405.500  Ectothiorhodospira              (D020587)
# B03.440.425.410.405.500.720  Ectothiorhodospira shaposhnikovii  (D020608)
# B03.440.425.410.405.750  Halorhodospira halophila        (D020607)
# B03.440.425.410.430  Geobacter                       (D045302)
# B03.440.425.410.580  Oxalobacter formigenes          (D020624)
# B03.440.425.410.711  Spirochaetaceae                 (D013143)
# B03.440.425.410.711.193  Borrelia                        (D001898)
# B03.440.425.410.711.193.150  Borrelia burgdorferi Group      (D015748)
# B03.440.425.410.711.193.150.125  Borrelia burgdorferi            (D025065)
# B03.440.425.410.711.679  Spirochaeta                     (D013142)
# B03.440.425.410.711.795  Treponema                       (D014208)
# B03.440.425.410.711.795.700  Treponema denticola             (D048373)
# B03.440.425.410.711.795.840  Treponema pallidum              (D014210)
# B03.440.425.410.722  Succinivibrionaceae             (D044063)
# B03.440.425.410.745  Thauera                         (D020628)
# B03.440.425.410.748  Thermotoga                      (D000084444)
# B03.440.425.410.748.500  Thermotoga maritima             (D020124)
# B03.440.425.410.748.750  Thermotoga neapolitana          (D046949)
# B03.440.425.410.800.755  Pectinatus                      (D045852)
# B03.440.425.410.800.877  Selenomonas                     (D020357)
# B03.440.425.410.800.938  Veillonella                     (D014678)
# B03.440.425.410.875  Wolinella                       (D016968)
# B03.440.450  Gram-Negative Facultatively Anaerobic Rods  (D006092)
# B03.440.450.009  Actinobacillus                  (D000188)
# B03.440.450.009.200  Actinobacillus equuli           (D044131)
# B03.440.450.009.580  Actinobacillus pleuropneumoniae  (D016977)
# B03.440.450.009.675  Actinobacillus seminis          (D044133)
# B03.440.450.009.700  Actinobacillus suis             (D044132)
# B03.440.450.019  Aeromonadaceae                  (D044044)
# B03.440.450.019.025  Aeromonas                       (D000333)
# B03.440.450.019.025.150  Aeromonas caviae                (D057585)
# B03.440.450.019.025.380  Aeromonas hydrophila            (D016980)
# B03.440.450.019.025.690  Aeromonas salmonicida           (D048409)
# B03.440.450.019.025.845  Aeromonas veronii               (D000070079)
# B03.440.450.040  Azoarcus                        (D020627)
# B03.440.450.342  Cardiobacteriaceae              (D044065)
# B03.440.450.342.100  Cardiobacterium                 (D044066)
# B03.440.450.360  Chromobacterium                 (D002861)
# B03.440.450.400  Eikenella                       (D016970)
# B03.440.450.400.275  Eikenella corrodens             (D016124)
# B03.440.450.425  Enterobacteriaceae              (D004755)
# B03.440.450.425.180  Calymmatobacterium              (D002157)
# B03.440.450.425.189  Carbapenem-Resistant Enterobacteriaceae  (D000073182)
# B03.440.450.425.200  Citrobacter                     (D002954)
# B03.440.450.425.200.275  Citrobacter freundii            (D016971)
# B03.440.450.425.200.475  Citrobacter koseri              (D041041)
# B03.440.450.425.200.737  Citrobacter rodentium           (D044082)
# B03.440.450.425.215  Cronobacter                     (D059126)
# B03.440.450.425.215.150  Cronobacter sakazakii           (D044083)
# B03.440.450.425.260  Edwardsiella                    (D020594)
# B03.440.450.425.260.340  Edwardsiella ictaluri           (D020610)
# B03.440.450.425.260.750  Edwardsiella tarda              (D020609)
# B03.440.450.425.275  Enterobacter                    (D004754)
# B03.440.450.425.275.099  Enterobacter aerogenes          (D021902)
# B03.440.450.425.275.200  Enterobacter cloacae            (D016972)
# B03.440.450.425.300  Erwinia                         (D004885)
# B03.440.450.425.300.050  Erwinia amylovora               (D044084)
# B03.440.450.425.325  Escherichia                     (D004925)
# B03.440.450.425.325.300  Escherichia coli                (D004926)
# B03.440.450.425.325.300.330  Enteropathogenic Escherichia coli  (D054308)
# B03.440.450.425.325.300.340  Enterotoxigenic Escherichia coli  (D054307)
# B03.440.450.425.325.300.360  Escherichia coli K12            (D048168)
# B03.440.450.425.325.300.580  Extraintestinal Pathogenic Escherichia coli  (D000072282)
# B03.440.450.425.325.300.580.500  Uropathogenic Escherichia coli  (D056689)
# B03.440.450.425.325.300.800  Shiga-Toxigenic Escherichia coli  (D054323)
# B03.440.450.425.325.300.800.250  Enterohemorrhagic Escherichia coli  (D054324)
# B03.440.450.425.325.300.800.250.250  Escherichia coli O104           (D000069981)
# B03.440.450.425.325.300.800.250.500  Escherichia coli O157           (D019453)
# B03.440.450.425.375  Hafnia                          (D020595)
# B03.440.450.425.375.050  Hafnia alvei                    (D020611)
# B03.440.450.425.425  Klebsiella                      (D007709)
# B03.440.450.425.425.580  Klebsiella oxytoca              (D041121)
# B03.440.450.425.425.600  Klebsiella pneumoniae           (D007711)
# B03.440.450.425.435  Kluyvera                        (D044086)
# B03.440.450.425.500  Morganella                      (D020596)
# B03.440.450.425.500.500  Morganella morganii             (D020613)
# B03.440.450.425.580  Pantoea                         (D020636)
# B03.440.450.425.585  Pectobacterium                  (D044043)
# B03.440.450.425.585.120  Pectobacterium carotovorum      (D016973)
# B03.440.450.425.590  Photorhabdus                    (D020637)
# B03.440.450.425.595  Plesiomonas                     (D016981)
# B03.440.450.425.600  Proteus                         (D011511)
# B03.440.450.425.600.501  Proteus mirabilis               (D011513)
# B03.440.450.425.600.650  Proteus penneri                 (D044095)
# B03.440.450.425.600.800  Proteus vulgaris                (D011514)
# B03.440.450.425.670  Providencia                     (D011532)
# B03.440.450.425.800  Salmonella                      (D012475)
# B03.440.450.425.800.100  Salmonella arizonae             (D012476)
# B03.440.450.425.800.200  Salmonella enterica             (D019779)
# B03.440.450.425.800.200.300  Salmonella enteritidis          (D012477)
# B03.440.450.425.800.200.600  Salmonella paratyphi A          (D012482)
# B03.440.450.425.800.200.700  Salmonella paratyphi B          (D012484)
# B03.440.450.425.800.200.750  Salmonella paratyphi C          (D012479)
# B03.440.450.425.800.200.800  Salmonella typhi                (D012485)
# B03.440.450.425.800.200.825  Salmonella typhimurium          (D012486)
# B03.440.450.425.814  Serratia                        (D012705)
# B03.440.450.425.814.620  Serratia liquefaciens           (D044090)
# B03.440.450.425.814.664  Serratia marcescens             (D012706)
# B03.440.450.425.850  Shigella                        (D012760)
# B03.440.450.425.850.175  Shigella boydii                 (D012761)
# B03.440.450.425.850.350  Shigella dysenteriae            (D012762)
# B03.440.450.425.850.450  Shigella flexneri               (D012763)
# B03.440.450.425.850.800  Shigella sonnei                 (D012764)
# B03.440.450.425.887  Wigglesworthia                  (D044106)
# B03.440.450.425.890  Xenorhabdus                     (D020593)
# B03.440.450.425.900  Yersinia                        (D015007)
# B03.440.450.425.900.300  Yersinia enterocolitica         (D015008)
# B03.440.450.425.900.600  Yersinia pestis                 (D015010)
# B03.440.450.425.900.615  Yersinia pseudotuberculosis     (D015011)
# B03.440.450.425.900.650  Yersinia ruckeri                (D044124)
# B03.440.450.510  Moritella                       (D034221)
# B03.440.450.600  Pasteurellaceae                 (D015661)
# B03.440.450.600.224  Aggregatibacter                 (D064206)
# B03.440.450.600.224.500  Aggregatibacter actinomycetemcomitans  (D016976)
# B03.440.450.600.224.750  Aggregatibacter aphrophilus     (D064207)
# B03.440.450.600.224.875  Aggregatibacter segnis          (D064208)
# B03.440.450.600.450  Haemophilus                     (D006190)
# B03.440.450.600.450.125  Haemophilus ducreyi             (D006191)
# B03.440.450.600.450.330  Haemophilus influenzae          (D006193)
# B03.440.450.600.450.330.150  Haemophilus influenzae type b   (D019741)
# B03.440.450.600.450.665  Haemophilus paragallinarum      (D044134)
# B03.440.450.600.450.675  Haemophilus parainfluenzae      (D044135)
# B03.440.450.600.450.690  Haemophilus paraphrophilus      (D044136)
# B03.440.450.600.450.700  Haemophilus parasuis            (D044137)
# B03.440.450.600.450.750  Haemophilus somnus              (D044138)
# B03.440.450.600.500  Mannheimia                      (D031121)
# B03.440.450.600.500.500  Mannheimia haemolytica          (D016978)
# B03.440.450.600.600  Pasteurella                     (D010325)
# B03.440.450.600.600.500  Pasteurella multocida           (D016979)
# B03.440.450.600.600.650  Pasteurella pneumotropica       (D044142)
# B03.440.450.650  Rahnella                        (D020638)
# B03.440.450.690  Shewanella                      (D020592)
# B03.440.450.690.590  Shewanella putrefaciens         (D020614)
# B03.440.450.900  Vibrionaceae                    (D014737)
# B03.440.450.900.050  Aliivibrio                      (D059706)
# B03.440.450.900.050.860  Aliivibrio fischeri             (D048908)
# B03.440.450.900.050.930  Aliivibrio salmonicida          (D044165)
# B03.440.450.900.500  Listonella                      (D053526)
# B03.440.450.900.604  Photobacterium                  (D010776)
# B03.440.450.900.859  Vibrio                          (D014733)
# B03.440.450.900.859.030  Vibrio alginolyticus            (D044149)
# B03.440.450.900.859.225  Vibrio cholerae                 (D014734)
# B03.440.450.900.859.225.075  Vibrio cholerae non-O1          (D044163)
# B03.440.450.900.859.225.151  Vibrio cholerae O1              (D041241)
# B03.440.450.900.859.225.200  Vibrio cholerae O139            (D041242)
# B03.440.450.900.859.500  Vibrio mimicus                  (D044164)
# B03.440.450.900.859.550  Vibrio parahaemolyticus         (D014736)
# B03.440.450.900.859.900  Vibrio vulnificus               (D041261)
# B03.440.450.980  Zymomonas                       (D017355)
# B03.440.475  Gram-Negative Oxygenic Photosynthetic Bacteria  (D019688)
# B03.440.475.100.655  Prochlorophytes                 (D048928)
# B03.440.475.100.655.600  Prochlorococcus                 (D048929)
# B03.440.475.100.655.620  Prochloron                      (D019691)
# B03.440.475.100.655.640  Prochlorothrix                  (D019692)
# B03.440.500  Helicobacter                    (D016998)
# B03.440.500.250  Helicobacter felis              (D044922)
# B03.440.500.350  Helicobacter heilmannii         (D018247)
# B03.440.500.362  Helicobacter hepaticus          (D044923)
# B03.440.500.450  Helicobacter mustelae           (D045502)
# B03.440.500.550  Helicobacter pylori             (D016480)
# B03.440.520  Lawsonia Bacteria               (D020639)
# B03.440.540  Methylosinus                    (D020581)
# B03.440.540.500  Methylosinus trichosporium      (D020602)
# B03.440.595  Oceanospirillaceae              (D044130)
# B03.440.612  Piscirickettsiaceae             (D044147)
# B03.440.619  Planctomycetes                  (D000090643)
# B03.440.619.500  Planctomycetales                (D061328)
# B03.440.623  Rhodobacter                     (D016992)
# B03.440.623.225  Rhodobacter capsulatus          (D016354)
# B03.440.623.700  Rhodobacter sphaeroides         (D012242)
# B03.440.645  Rhodomicrobium                  (D020623)
# B03.440.646  Rhodovulum                      (D041903)
# B03.440.664  Rickettsiales                   (D000076944)
# B03.440.664.750  Anaplasmataceae                 (D000710)
# B03.440.664.750.050  Anaplasma                       (D000709)
# B03.440.664.750.050.100  Anaplasma centrale              (D042321)
# B03.440.664.750.050.500  Anaplasma marginale             (D042322)
# B03.440.664.750.050.575  Anaplasma ovis                  (D042323)
# B03.440.664.750.050.600  Anaplasma phagocytophilum       (D041081)
# B03.440.664.750.287  Ehrlichia                       (D004536)
# B03.440.664.750.287.090  Ehrlichia canis                 (D041061)
# B03.440.664.750.287.150  Ehrlichia chaffeensis           (D018469)
# B03.440.664.750.287.700  Ehrlichia ruminantium           (D016995)
# B03.440.664.750.525  Neorickettsia                   (D041102)
# B03.440.664.750.525.700  Neorickettsia risticii          (D041103)
# B03.440.664.750.525.720  Neorickettsia sennetsu          (D041101)
# B03.440.680  Roseobacter                     (D041904)
# B03.440.840  Spirillaceae                    (D043167)
# B03.440.840.750  Spirillum                       (D013139)
# B03.440.860  Tenericutes                     (D008973)
# B03.440.860.074  Acholeplasmataceae              (D000129)
# B03.440.860.074.150  Acholeplasma                    (D000127)
# B03.440.860.074.150.500  Acholeplasma laidlawii          (D000128)
# B03.440.860.074.575  Phytoplasma                     (D045582)
# B03.440.860.300  Entomoplasmatales               (D060366)
# B03.440.860.300.250  Entomoplasmataceae              (D045622)
# B03.440.860.300.750  Spiroplasmataceae               (D016991)
# B03.440.860.300.750.625  Spiroplasma                     (D013149)
# B03.440.860.300.750.625.500  Spiroplasma citri               (D045642)
# B03.440.860.580  Mycoplasmatales                 (D009179)
# B03.440.860.580.553  Mycoplasmataceae                (D009178)
# B03.440.860.580.553.553  Mycoplasma                      (D009174)
# B03.440.860.580.553.553.050  Mycoplasma agalactiae           (D045644)
# B03.440.860.580.553.553.075  Mycoplasma arthritidis          (D045645)
# B03.440.860.580.553.553.195  Mycoplasma bovigenitalium       (D045646)
# B03.440.860.580.553.553.200  Mycoplasma bovis                (D045682)
# B03.440.860.580.553.553.210  Mycoplasma capricolum           (D045623)
# B03.440.860.580.553.553.220  Mycoplasma conjunctivae         (D045684)
# B03.440.860.580.553.553.267  Mycoplasma dispar               (D045685)
# B03.440.860.580.553.553.315  Mycoplasma fermentans           (D016858)
# B03.440.860.580.553.553.345  Mycoplasma gallisepticum        (D045686)
# B03.440.860.580.553.553.355  Mycoplasma genitalium           (D045704)
# B03.440.860.580.553.553.400  Mycoplasma hominis              (D019535)
# B03.440.860.580.553.553.420  Mycoplasma hyopneumoniae        (D045705)
# B03.440.860.580.553.553.425  Mycoplasma hyorhinis            (D045790)
# B03.440.860.580.553.553.430  Mycoplasma hyosynoviae          (D045791)
# B03.440.860.580.553.553.450  Mycoplasma iowae                (D045793)
# B03.440.860.580.553.553.570  Mycoplasma meleagridis          (D045794)
# B03.440.860.580.553.553.585  Mycoplasma mycoides             (D009176)
# B03.440.860.580.553.553.630  Mycoplasma orale                (D045795)
# B03.440.860.580.553.553.635  Mycoplasma ovipneumoniae        (D045802)
# B03.440.860.580.553.553.645  Mycoplasma penetrans            (D018661)
# B03.440.860.580.553.553.650  Mycoplasma pneumoniae           (D009177)
# B03.440.860.580.553.553.670  Mycoplasma pulmonis             (D045803)
# B03.440.860.580.553.553.720  Mycoplasma salivarium           (D045804)
# B03.440.860.580.553.553.770  Mycoplasma synoviae             (D045805)
# B03.440.860.580.553.900  Ureaplasma                      (D014509)
# B03.440.860.580.553.900.800  Ureaplasma urealyticum          (D016990)
# B03.440.930  Verrucomicrobia                 (D061327)
# B03.440.930.500  Akkermansia                     (D000086102)
# B03.510     Gram-Positive Bacteria          (D006094)
# B03.510.024  Actinobacteria                  (D039903)
# B03.510.024.049  Actinomycetales                 (D000192)
# B03.510.024.049.025  Actinomadura                    (D000082403)
# B03.510.024.049.050  Actinomycetaceae                (D000191)
# B03.510.024.049.050.050  Actinomyces                     (D000190)
# B03.510.024.049.050.050.050  Actinomyces viscosus            (D016924)
# B03.510.024.049.050.287  Arcanobacterium                 (D055667)
# B03.510.024.049.050.525  Mobiluncus                      (D017904)
# B03.510.024.049.075  Amycolatopsis                   (D000082502)
# B03.510.024.100  Bifidobacterium                 (D001644)
# B03.510.024.100.125  Bifidobacterium adolescentis    (D000070005)
# B03.510.024.100.250  Bifidobacterium animalis        (D000069982)
# B03.510.024.100.313  Bifidobacterium bifidum         (D000069985)
# B03.510.024.100.375  Bifidobacterium breve           (D000069984)
# B03.510.024.100.500  Bifidobacterium longum          (D000069978)
# B03.510.024.100.500.500  Bifidobacterium longum subspecies infantis  (D000070236)
# B03.510.024.100.750  Bifidobacterium pseudocatenulatum  (D000070257)
# B03.510.024.175  Brevibacterium                  (D001951)
# B03.510.024.213  Cellulomonas                    (D040143)
# B03.510.024.232  Clavibacter                     (D000086162)
# B03.510.024.250  Corynebacterium                 (D003352)
# B03.510.024.250.100  Brevibacterium flavum           (D040142)
# B03.510.024.250.150  Corynebacterium diphtheriae     (D003353)
# B03.510.024.250.300  Corynebacterium glutamicum      (D048230)
# B03.510.024.250.600  Corynebacterium pseudotuberculosis  (D016925)
# B03.510.024.250.625  Corynebacterium pyogenes        (D003355)
# B03.510.024.288  Dermatophilus                   (D000086182)
# B03.510.024.325  Frankia                         (D040161)
# B03.510.024.400  Gardnerella                     (D016975)
# B03.510.024.400.800  Gardnerella vaginalis           (D006194)
# B03.510.024.700  Gordonia Bacterium              (D033601)
# B03.510.024.775  Microbacterium                  (D000083822)
# B03.510.024.850  Micrococcaceae                  (D008835)
# B03.510.024.850.050  Arthrobacter                    (D001173)
# B03.510.024.850.500  Micrococcus                     (D008837)
# B03.510.024.850.500.500  Micrococcus luteus              (D016982)
# B03.510.024.850.750  Renibacterium                   (D000084402)
# B03.510.024.962  Mycobacteriaceae                (D009159)
# B03.510.024.962.500  Mycobacterium                   (D009161)
# B03.510.024.962.500.300  Mycobacterium avium             (D009162)
# B03.510.024.962.500.300.600  Mycobacterium avium subsp. paratuberculosis  (D016927)
# B03.510.024.962.500.402  Mycobacterium bovis             (D009163)
# B03.510.024.962.500.480  Mycobacterium haemophilum       (D018393)
# B03.510.024.962.500.502  Mycobacterium leprae            (D009166)
# B03.510.024.962.500.602  Mycobacterium lepraemurium      (D009167)
# B03.510.024.962.500.640  Mycobacterium phlei             (D009168)
# B03.510.024.962.500.702  Mycobacterium tuberculosis      (D009169)
# B03.510.024.962.500.720  Nontuberculous Mycobacteria     (D009170)
# B03.510.024.962.500.720.050  Mycobacterium abscessus         (D000073358)
# B03.510.024.962.500.720.100  Mycobacterium avium Complex     (D015269)
# B03.510.024.962.500.720.225  Mycobacterium chelonae          (D016926)
# B03.510.024.962.500.720.325  Mycobacterium fortuitum         (D019907)
# B03.510.024.962.500.720.400  Mycobacterium kansasii          (D019909)
# B03.510.024.962.500.720.500  Mycobacterium marinum           (D019910)
# B03.510.024.962.500.720.625  Mycobacterium scrofulaceum      (D015359)
# B03.510.024.962.500.720.662  Mycobacterium smegmatis         (D020102)
# B03.510.024.962.500.720.700  Mycobacterium ulcerans          (D019911)
# B03.510.024.962.500.720.950  Mycobacterium xenopi            (D019912)
# B03.510.024.981  Nocardiaceae                    (D009618)
# B03.510.024.981.550  Nocardia                        (D009615)
# B03.510.024.981.550.550  Nocardia asteroides             (D009616)
# B03.510.024.981.775  Rhodococcus                     (D012240)
# B03.510.024.981.775.700  Rhodococcus equi                (D016929)
# B03.510.024.986  Nocardioides                    (D000083962)
# B03.510.024.988  Nocardiopsis                    (D000086262)
# B03.510.024.990  Propionibacteriaceae            (D011423)
# B03.510.024.990.600  Propionibacterium               (D011424)
# B03.510.024.990.600.600  Propionibacterium acnes         (D011425)
# B03.510.024.990.600.800  Propionibacterium freudenreichii  (D000070002)
# B03.510.024.993  Pseudonocardia                  (D000084382)
# B03.510.024.998  Tropheryma                      (D054851)
# B03.510.400  Gram-Positive Cocci             (D006095)
# B03.510.400.200  Deinococcus                     (D034301)
# B03.510.400.630.600  Planococcus Bacteria            (D058642)
# B03.510.460  Gram-Positive Rods              (D016987)
# B03.510.460.400  Gram-Positive Asporogenous Rods  (D006093)
# B03.510.460.400.400  Gram-Positive Asporogenous Rods, Irregular  (D016988)
# B03.510.460.400.400.024  Acetobacterium                  (D045855)
# B03.510.460.400.400.049.957  Thermobifida                    (D000086324)
# B03.510.460.400.400.049.971  Thermomonospora                 (D000084442)
# B03.510.460.400.410  Gram-Positive Asporogenous Rods, Regular  (D016989)
# B03.585     Nitrogen-Fixing Bacteria        (D000072738)
# B03.585.200  Beijerinckiaceae                (D042062)
# B03.660     Proteobacteria                  (D020560)
# B03.660.050  Alphaproteobacteria             (D020561)
# B03.660.050.340  Holosporaceae                   (D042281)
# B03.660.050.350  Hyphomicrobiaceae               (D041921)
# B03.660.050.350.400  Hyphomicrobium                  (D020582)
# B03.660.050.512  Methylocystaceae                (D042083)
# B03.660.050.600  Phyllobacteriaceae              (D059127)
# B03.660.050.600.500  Mesorhizobium                   (D059128)
# B03.660.050.662.347  Liberibacter                    (D000086202)
# B03.660.050.750  Rhodobacteraceae                (D041902)
# B03.660.050.755  Rhodospirillales                (D012245)
# B03.660.050.783.500.762  Wolbachia                       (D020577)
# B03.660.050.783.875  Rickettsiaceae                  (D012287)
# B03.660.050.783.875.650  Rickettsieae                    (D016996)
# B03.660.050.783.875.650.450  Orientia                        (D000084162)
# B03.660.050.783.875.650.450.500  Orientia tsutsugamushi          (D012285)
# B03.660.050.783.875.650.650  Rickettsia                      (D012281)
# B03.660.050.783.875.650.650.040  Rickettsia akari                (D041141)
# B03.660.050.783.875.650.650.180  Rickettsia conorii              (D020114)
# B03.660.050.783.875.650.650.320  Rickettsia felis                (D041161)
# B03.660.050.783.875.650.650.600  Rickettsia prowazekii           (D012283)
# B03.660.050.783.875.650.650.650  Rickettsia rickettsii           (D012284)
# B03.660.050.783.875.650.650.810  Rickettsia typhi                (D012286)
# B03.660.050.800  Sphingomonadaceae               (D042301)
# B03.660.075  Betaproteobacteria              (D020562)
# B03.660.075.090  Burkholderiales                 (D000073556)
# B03.660.075.090.688.100  Burkholderia                    (D019117)
# B03.660.075.090.688.100.110  Burkholderia cepacia complex    (D042602)
# B03.660.075.090.688.100.110.490  Burkholderia cenocepacia        (D057508)
# B03.660.075.090.688.100.110.500  Burkholderia cepacia            (D016956)
# B03.660.075.090.688.100.355  Burkholderia gladioli           (D042725)
# B03.660.075.090.688.100.477  Burkholderia mallei             (D042726)
# B03.660.075.090.688.100.600  Burkholderia pseudomallei       (D016957)
# B03.660.075.090.688.600  Ralstonia                       (D043367)
# B03.660.075.090.688.600.600  Ralstonia pickettii             (D049920)
# B03.660.075.090.688.600.750  Ralstonia solanacearum          (D043368)
# B03.660.075.090.941  Xylophilus                      (D000086326)
# B03.660.075.400  Hydrogenophilaceae              (D043363)
# B03.660.075.655  Rhodocyclaceae                  (D043362)
# B03.660.125  Deltaproteobacteria             (D020564)
# B03.660.125.144  Desulfovibrionales              (D000076642)
# B03.660.125.500  Myxococcales                    (D009231)
# B03.660.125.500.605  Myxococcus                      (D016940)
# B03.660.125.500.605.900  Myxococcus xanthus              (D016941)
# B03.660.125.500.658  Sorangium                       (D000086323)
# B03.660.125.500.710  Stigmatella                     (D020597)
# B03.660.125.500.710.050  Stigmatella aurantiaca          (D020606)
# B03.660.150  Epsilonproteobacteria           (D020565)
# B03.660.150.235  Campylobacterales               (D000074707)
# B03.660.150.235.250  Campylobacteraceae              (D000073557)
# B03.660.150.235.500  Helicobacteraceae               (D000073569)
# B03.660.250  Gammaproteobacteria             (D020563)
# B03.660.250.018  Aeromonadales                   (D000074762)
# B03.660.250.019  Alcanivoraceae                  (D053521)
# B03.660.250.021  Alteromonadaceae                (D034241)
# B03.660.250.021.480  Marinobacter                    (D053520)
# B03.660.250.080.775  Rappaport                       (D000086322)
# B03.660.250.110  Chromatiaceae                   (D002841)
# B03.660.250.139  Dickeya                         (D000083042)
# B03.660.250.139.500  Dickeya chrysanthemi            (D016974)
# B03.660.250.540.500  Marinomonas                     (D053544)
# B03.660.250.565.600  Piscirickettsia                 (D053522)
# B03.660.250.915.930.049  Xanthomonas axonopodis          (D053532)
# B03.851     Spirochaetales                  (D013144)
# B03.900     Sulfur-Reducing Bacteria        (D016999)

# %%
import xml.etree.ElementTree as ET
from difflib import SequenceMatcher, get_close_matches

def parse_mesh_descriptors(xml_path):
    """Parse the MeSH XML and return a list of descriptors."""
    tree = ET.parse(xml_path)
    root = tree.getroot()
    descriptors = []
    for dr in root.findall('DescriptorRecord'):
        ui_el   = dr.find('DescriptorUI')
        name_el = dr.find('DescriptorName/String')
        if ui_el is None or name_el is None:
            continue
        ui   = ui_el.text
        name = name_el.text
        tree_nums = [tn.text for tn in dr.findall('TreeNumberList/TreeNumber') if tn.text]
        descriptors.append({'ui':ui, 'name':name, 'tree_numbers':tree_nums})
    return descriptors

MESH_XML = 'desc2025.xml' #from the folder
descriptors = parse_mesh_descriptors(MESH_XML)
print(f"Parsed {len(descriptors)} descriptors")
#print(descriptors)
# Out:
# Parsed 30956 descriptors

# %%
def get_bacteria_taxonomy(descriptors):
    """
    Find the descriptor with name 'Bacteria', 
    then collect every descriptor under that tree-number prefix.
    """
    prefix = None #bacteria is B03
    for d in descriptors:
        if d['name'].lower() == 'bacteria' and d['tree_numbers']:
            prefix = d['tree_numbers'][0]
            break
    if not prefix:
        raise RuntimeError("Could not find 'Bacteria' in descriptors")
    tax = {}
    for d in descriptors:
        for tn in d['tree_numbers']:
            if tn == prefix or tn.startswith(prefix + '.'):
                tax[tn] = {'ui':d['ui'], 'name':d['name']}
                break
    return tax

bacteria_tax = get_bacteria_taxonomy(descriptors)
#print(f"{len(bacteria_tax)} bacterial MeSH nodes")

# %%
def build_name_index(taxonomy):
    """
    Build a dict: lower-case name -> list of (tree#, ui, canonical name)
    """
    idx = {}
    for tree_num, info in taxonomy.items():
        key = info['name'].lower()
        idx.setdefault(key, []).append((tree_num, info['ui'], info['name']))
    return idx

name_index = build_name_index(bacteria_tax)
print(f"Indexed {len(name_index)} bacterial names")
# Out:
# Indexed 859 bacterial names

# %%
from difflib import SequenceMatcher

def find_mesh_match(input_name, name_index, n=5, cutoff=0.6):
    """
    Return matches for input_name among the MeSH bacterial names.
    Exact matches come first with score=1.0.
    Then fuzzy matches (score computed via SequenceMatcher.ratio).
    """
    key = input_name.lower()
    results = []
    if key in name_index:
        for tree_num, ui, name in name_index[key]:
            results.append((name, ui, tree_num, 1.0))
        return results

    all_names = list(name_index.keys())
    #print(all_names)
    
    close = get_close_matches(key, all_names, n=n, cutoff=cutoff)
    for cname in close:
        score = SequenceMatcher(None, key, cname).ratio()
        for tree_num, ui, name in name_index[cname]:
            results.append((name, ui, tree_num, score))
    results.sort(key=lambda x: x[3], reverse=True)
    return results

# %%
import re, json, numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def load_taxonomy_tree(path):
    row_re = re.compile(r"^\s*(.*?)\s+\[([^\]]+)\]\s*$")
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = row_re.match(ln)
            if m:
                label, tid = m.groups()
                depth      = len(ln) - len(ln.lstrip())
                rows.append((label, tid, depth))
    return rows

TAX_FILE = "bacteria_tree1.txt"
rows     = load_taxonomy_tree(TAX_FILE)

exact_ix  = defaultdict(list)
for lbl, tid, depth in rows:
    exact_ix[lbl.lower()].append((lbl, tid, depth))

labels_only  = [r[0] for r in rows]
vec          = TfidfVectorizer(stop_words="english")
mat          = vec.fit_transform(labels_only)

def top_cosine(term, k=5, thr=0.75):
    v   = vec.transform([term])
    sc  = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr: break
        lbl, tid, d = rows[i]
        out.append((lbl, tid, d, sc[i]))
    return out

abbr_re = re.compile(r"^([A-Z])\.\s+([A-Za-z_-]+)$")
def preprocess(term):
    """toglie _ e spazio finale/iniziale"""
    return term.replace('_', ' ').strip()

def genus_abbrev_lookup(term):
    """
    Se il termine è tipo 'L. plantarum' cerca qualunque label che:
      • finisca con ' plantarum'
      • abbia un genere che comincia con 'L'
    """
    m = abbr_re.match(term)
    if not m:
        return []
    initial, species = m.groups()
    species = species.lower()
    hits = []
    for lbl, tid, d in rows:
        if lbl.lower().endswith(' ' + species) and lbl[0].upper() == initial:
            hits.append((lbl, tid, d, 1.00))
    return hits

# ---------------------------------------------------------------------------
# 2)  CARICA LE QUERY DAL JSON ----------------------------------------------
def strip_html(text):   # copia dalla tua versione originale
    return re.sub(r"<[^>]+>", "", text)

with open(r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\data\train_platinum\train_platinum.json", encoding="utf-8") as fh:
    js = json.load(fh)

queries = { strip_html(e["text_span"]).strip()
            for rec in js.values()
            for e in rec.get("entities", [])
            if e.get("label","").lower() == "bacteria" }

# ---------------------------------------------------------------------------
# 3)  MATCHING ---------------------------------------------------------------
for term_raw in sorted(queries):
    term = preprocess(term_raw)
    print(f"Query: {term_raw}")

    # 3-a   scorciatoia “L.” / “_”  -----------------------------------------
    hits = genus_abbrev_lookup(term)
    if hits:
        for l,t,d,s in hits: print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f} (abbr)")
        print(); continue

    # 3-b   exact (case-insensitive)  ---------------------------------------
    ex = exact_ix.get(term.lower(), [])
    if ex:
        for l,t,d in ex: print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score=1.00 (exact)")
        print(); continue

    # 3-c   cosine fallback  -------------------------------------------------
    cos = top_cosine(term)
    if not cos:
        matches = find_mesh_match(term, name_index)
        for name, ui, tree, score in matches[:5]:
            print(f"  • {name:30s} UI={ui:8s} Tree={tree:12s}  score={score:.2f}")
            #print("  no matches\n")
    else:
        for l,t,d,s in cos:
            print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f}")
        print()
# Out:
# Query: A. muciniphila
#   • Akkermansia muciniphila                  ID=NCBITaxon_239935 depth=16 score=1.00 (abbr)
#
# Query: Acidaminococcus intestini
#   • Acidaminococcus intestini                ID=NCBITaxon_187327 depth=14 score=1.00 (exact)
#
# Query: Actinobacteria
#   • Actinobacteria bacterium HGW-Actinobacteria-9 ID=NCBITaxon_2013654 depth=8  score=0.87
#   • Actinobacteria bacterium HGW-Actinobacteria-8 ID=NCBITaxon_2013653 depth=8  score=0.87
#   • Actinobacteria bacterium HGW-Actinobacteria-7 ID=NCBITaxon_2013652 depth=8  score=0.87
#   • Actinobacteria bacterium HGW-Actinobacteria-6 ID=NCBITaxon_2013651 depth=8  score=0.87
#   • Actinobacteria bacterium HGW-Actinobacteria-5 ID=NCBITaxon_2013650 depth=8  score=0.87
#
# Query: Actinobacteriota
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.93
#   • Acidobacteria                  UI=D061271  Tree=B03.026       score=0.83
#   • Cyanobacteria                  UI=D000458  Tree=B03.280       score=0.76
#   • Acinetobacter                  UI=D000150  Tree=B03.440.400.425.537.050  score=0.76
#   • Acetobacter                    UI=D000091  Tree=B03.440.400.425.100.100  score=0.74
# Query: Acute/chronic insomnia-related signature bacteria
# Query: Agathobaculum
#   • Agathobaculum                            ID=NCBITaxon_2048137 depth=12 score=1.00 (exact)
#
# Query: Akkermansia
#   • Akkermansia                              ID=NCBITaxon_239934 depth=14 score=1.00 (exact)
#
# Query: Akkermansia muciniphila
#   • Akkermansia muciniphila                  ID=NCBITaxon_239935 depth=16 score=1.00 (exact)
#
# Query: Akkermansia_muciniphila
#   • Akkermansia muciniphila                  ID=NCBITaxon_239935 depth=16 score=1.00 (exact)
#
# Query: Akkermansias
#   • Akkermansia                    UI=D000086102 Tree=B03.440.930.500  score=0.96
#   • Aeromonas                      UI=D000333  Tree=B03.440.450.019.025  score=0.67
#   • Alteromonas                    UI=D020591  Tree=B03.440.400.425.126  score=0.61
# Query: Alloprevotella
#   • Alloprevotella                           ID=NCBITaxon_1283313 depth=16 score=1.00 (exact)
#
# Query: Anaerostipes
#   • Anaerostipes                             ID=NCBITaxon_207244 depth=12 score=1.00 (exact)
#
# Query: Bacteroidaceae and Porphyromonadaceae families
#   • Bacteroidaceae                           ID=NCBITaxon_815   depth=14 score=0.76
#
# Query: Bacteroides
#   • Bacteroides                              ID=NCBITaxon_816   depth=16 score=1.00 (exact)
#
# Query: Bacteroides eggerthii
#   • Bacteroides eggerthii                    ID=NCBITaxon_28111 depth=18 score=1.00 (exact)
#
# Query: Bacteroides genus
#   • Bacteroides                              ID=NCBITaxon_816   depth=16 score=0.77
#   • Bacteroides sp. F-4                      ID=NCBITaxon_575334 depth=20 score=0.75
#   • Bacteroides sp. 6-8                      ID=NCBITaxon_936068 depth=20 score=0.75
#   • Bacteroides sp. D-2                      ID=NCBITaxon_714195 depth=20 score=0.75
#   • Bacteroides sp.                          ID=NCBITaxon_29523 depth=20 score=0.75
#
# Query: Bacteroides uniformis
#   • Bacteroides uniformis                    ID=NCBITaxon_820   depth=18 score=1.00 (exact)
#
# Query: Bacteroidetes
#   • Bacteroidetes bacterium 5-4              ID=NCBITaxon_226197 depth=12 score=0.93
#   • Bacteroidetes bacterium 5-5              ID=NCBITaxon_226198 depth=12 score=0.93
#   • Bacteroidetes bacterium U-3              ID=NCBITaxon_244235 depth=12 score=0.93
#   • Bacteroidetes bacterium U-5              ID=NCBITaxon_244236 depth=12 score=0.93
#   • Bacteroidetes bacterium U-9              ID=NCBITaxon_244237 depth=12 score=0.93
#
# Query: Barnesiella
#   • Barnesiella                              ID=NCBITaxon_397864 depth=16 score=1.00 (exact)
#
# Query: Barnesiella viscericola
#   • Barnesiella viscericola                  ID=NCBITaxon_397865 depth=18 score=1.00 (exact)
#
# Query: Barnesiellaceae
#   • Barnesiellaceae                          ID=NCBITaxon_2005519 depth=14 score=1.00 (exact)
#
# Query: Biffdobacterium
#   • Bifidobacterium                UI=D001644  Tree=B03.510.024.100  score=0.93
#   • Fusobacterium                  UI=D005673  Tree=B03.370.250   score=0.79
#   • Bifidobacterium breve          UI=D000069984 Tree=B03.510.024.100.375  score=0.78
#   • Microbacterium                 UI=D000083822 Tree=B03.510.024.775  score=0.76
#   • Flavobacterium                 UI=D005417  Tree=B03.440.080.190.250  score=0.76
# Query: Bifidobacteria
#   • Bifidobacterium                UI=D001644  Tree=B03.510.024.100  score=0.90
#   • Acidobacteria                  UI=D061271  Tree=B03.026       score=0.81
#   • Fusobacteria                   UI=D045182  Tree=B03.370       score=0.77
#   • Bifidobacterium breve          UI=D000069984 Tree=B03.510.024.100.375  score=0.74
#   • Bifidobacterium animalis       UI=D000069982 Tree=B03.510.024.100.250  score=0.74
# Query: Bifidobacteriaceae
#   • Bifidobacteriaceae                       ID=NCBITaxon_31953 depth=10 score=1.00 (exact)
#
# Query: Bifidobacterium
#   • Bifidobacterium                          ID=NCBITaxon_1678  depth=12 score=1.00 (exact)
#
# Query: Bifidobacterium adolescentis
#   • Bifidobacterium adolescentis             ID=NCBITaxon_1680  depth=14 score=1.00 (exact)
#
# Query: Bifidobacterium adolescentis NK98
#   • Bifidobacterium adolescentis             ID=NCBITaxon_1680  depth=14 score=1.00
#   • Bifidobacterium adolescentis L2-32       ID=NCBITaxon_411481 depth=16 score=0.75
#
# Query: Bifidobacterium longum
#   • Bifidobacterium longum                   ID=NCBITaxon_216816 depth=14 score=1.00 (exact)
#
# Query: Bifidobacterium longum R0175
#   • Bifidobacterium longum                   ID=NCBITaxon_216816 depth=14 score=1.00
#   • Bifidobacterium longum subsp. longum     ID=NCBITaxon_1679  depth=16 score=0.93
#   • Bifidobacterium longum subsp. longum 7-1B ID=NCBITaxon_1350472 depth=18 score=0.87
#   • Bifidobacterium longum subsp. longum 2-2B ID=NCBITaxon_1161745 depth=18 score=0.87
#   • Bifidobacterium longum subsp. longum F8  ID=NCBITaxon_722911 depth=18 score=0.86
#
# Query: Bilophila
#   • Bilophila                                ID=NCBITaxon_35832 depth=12 score=1.00 (exact)
#
# Query: Bilophila wadsworthia
#   • Bilophila wadsworthia                    ID=NCBITaxon_35833 depth=14 score=1.00 (exact)
#
# Query: Blautia
#   • Blautia                                  ID=NCBITaxon_572511 depth=12 score=1.00 (exact)
#
# Query: Christensenellaceae
#   • Christensenellaceae                      ID=NCBITaxon_990719 depth=10 score=1.00 (exact)
#
# Query: Christensenellaceae R-7 group
#   • Christensenellaceae                      ID=NCBITaxon_990719 depth=10 score=0.87
#   • Christensenellaceae bacterium            ID=NCBITaxon_2054177 depth=14 score=0.84
#   • uncultured Christensenellaceae bacterium ID=NCBITaxon_1229255 depth=14 score=0.79
#   • unclassified Christensenellaceae         ID=NCBITaxon_1917874 depth=12 score=0.78
#
# Query: Citrobacter
#   • Citrobacter                              ID=NCBITaxon_544   depth=12 score=1.00 (exact)
#
# Query: Clostridium
#   • Clostridium                              ID=NCBITaxon_1485  depth=12 score=1.00 (exact)
#
# Query: Clostridium sp. BR31
#   • Clostridium                    UI=D003013  Tree=B03.300.390.400.200  score=0.71
#   • Clostridium septicum           UI=D052557  Tree=B03.300.390.400.200.690  score=0.70
#   • Clostridium symbiosum          UI=D048009  Tree=B03.300.390.400.200.713  score=0.68
#   • Clostridium sordellii          UI=D047989  Tree=B03.300.390.400.200.700  score=0.68
#   • Clostridium butyricum          UI=D046972  Tree=B03.300.390.400.200.180  score=0.68
# Query: Clostridiuminnocuumgroup
#   • Clostridium septicum           UI=D052557  Tree=B03.300.390.400.200.690  score=0.68
#   • Clostridium symbiosum          UI=D048009  Tree=B03.300.390.400.200.713  score=0.67
#   • Clostridium histolyticum       UI=D047009  Tree=B03.300.390.400.200.412  score=0.67
#   • Clostridium butyricum          UI=D046972  Tree=B03.300.390.400.200.180  score=0.67
#   • Clostridium botulinum          UI=D003014  Tree=B03.300.390.400.200.160  score=0.67
# Query: Collinsella
#   • Collinsella                              ID=NCBITaxon_102106 depth=12 score=1.00 (exact)
#
# Query: Coprococcus
#   • Coprococcus                              ID=NCBITaxon_33042 depth=12 score=1.00 (exact)
#
# Query: Coprococcus 1
#   • Coprococcus                              ID=NCBITaxon_33042 depth=12 score=1.00
#   • Coprococcus sp.                          ID=NCBITaxon_2049024 depth=16 score=0.99
#   • uncultured Coprococcus sp.               ID=NCBITaxon_458253 depth=16 score=0.91
#   • unclassified Coprococcus                 ID=NCBITaxon_2684943 depth=14 score=0.87
#
# Query: Coprococcus comes
#   • Coprococcus comes                        ID=NCBITaxon_410072 depth=14 score=1.00 (exact)
#
# Query: Coriobacteriaceae
#   • Coriobacteriaceae                        ID=NCBITaxon_84107 depth=10 score=1.00 (exact)
#
# Query: Corynebacterium
#   • Corynebacterium                          ID=NCBITaxon_1716  depth=12 score=1.00 (exact)
#
# Query: Desulfovibrio
#   • Desulfovibrio                            ID=NCBITaxon_872   depth=12 score=1.00 (exact)
#
# Query: Desulfovibrionaceae
#   • Desulfovibrionaceae                      ID=NCBITaxon_194924 depth=10 score=1.00 (exact)
#
# Query: Dialister
#   • Dialister                                ID=NCBITaxon_39948 depth=12 score=1.00 (exact)
#
# Query: Dorea
#   • Dorea                                    ID=NCBITaxon_189330 depth=12 score=1.00 (exact)
#
# Query: EC Ruminococcus torques
#   • [Ruminococcus] torques                   ID=NCBITaxon_33039 depth=14 score=0.83
#
# Query: Eggerthellaceae
#   • Eggerthellaceae                          ID=NCBITaxon_1643826 depth=10 score=1.00 (exact)
#
# Query: Enterobacter cloacae
#   • Enterobacter cloacae                     ID=NCBITaxon_550   depth=16 score=1.00 (exact)
#
# Query: Enterobacteriaceae
#   • Enterobacteriaceae                       ID=NCBITaxon_543   depth=10 score=1.00 (exact)
#
# Query: Enterococcaceae
#   • Enterococcaceae                          ID=NCBITaxon_81852 depth=10 score=1.00 (exact)
#
# Query: Enterococcus
#   • Enterococcus                             ID=NCBITaxon_1350  depth=12 score=1.00 (exact)
#
# Query: Escherichia
#   • Escherichia                              ID=NCBITaxon_561   depth=12 score=1.00 (exact)
#
# Query: Escherichia coli
#   • Escherichia coli                         ID=NCBITaxon_562   depth=14 score=1.00 (exact)
#
# Query: Escherichia-Shigella
#   • Escherichia/Shigella sp.                 ID=NCBITaxon_1940338 depth=14 score=0.99
#   • uncultured Escherichia/Shigella sp.      ID=NCBITaxon_1985117 depth=14 score=0.90
#   • Shigella                                 ID=NCBITaxon_620   depth=12 score=0.80
#   • Shigella sp.                             ID=NCBITaxon_625   depth=16 score=0.79
#   • Shigella sp. 5                           ID=NCBITaxon_588531 depth=16 score=0.79
#
# Query: Eubacterium rectale
#   • Treponema rectale                        ID=NCBITaxon_744512 depth=14 score=0.78
#
# Query: F4
#   • Bacillus sp. F4-1                        ID=NCBITaxon_489169 depth=16 score=0.92
#   • Bacillus sp. F4                          ID=NCBITaxon_694271 depth=16 score=0.92
#   • Pseudomonas sp. F4                       ID=NCBITaxon_50279 depth=16 score=0.92
#   • Pseudomonas sp. I-F4                     ID=NCBITaxon_299700 depth=16 score=0.92
#   • Pseudomonas sp. F4-3                     ID=NCBITaxon_488138 depth=16 score=0.92
#
# Query: Faecalibacterium
#   • Faecalibacterium                         ID=NCBITaxon_216851 depth=12 score=1.00 (exact)
#
# Query: Faecalibacterium prausnitzii
#   • Faecalibacterium prausnitzii             ID=NCBITaxon_853   depth=14 score=1.00 (exact)
#
# Query: Faecalibaculum
#   • Faecalibaculum                           ID=NCBITaxon_1729679 depth=12 score=1.00 (exact)
#
# Query: Family_Ruminococcaceae
#   • Micrococcaceae                 UI=D008835  Tree=B03.510.024.850  score=0.72
#   • Aerococcaceae                  UI=D056567  Tree=B03.353.750.030  score=0.69
#   • Planococcaceae                 UI=D058641  Tree=B03.353.500.700  score=0.67
#   • Methylococcaceae               UI=D008772  Tree=B03.440.400.425.500  score=0.63
#   • Staphylococcaceae              UI=D040141  Tree=B03.300.390.400.800  score=0.62
# Query: Fecalibacterium prausnitzii
#   • Faecalibacterium prausnitzii             ID=NCBITaxon_853   depth=14 score=0.79
#
# Query: Firmicutes
#   • Bacillus <firmicutes>                    ID=NCBITaxon_1386  depth=12 score=0.87
#   • Bacillus sp. (in: firmicutes)            ID=NCBITaxon_1409  depth=16 score=0.86
#   • Firmicutes bacterium HGW-Firmicutes-5    ID=NCBITaxon_2013786 depth=8  score=0.82
#   • Firmicutes bacterium HGW-Firmicutes-8    ID=NCBITaxon_2013789 depth=8  score=0.82
#   • Firmicutes bacterium HGW-Firmicutes-3    ID=NCBITaxon_2013784 depth=8  score=0.82
#
# Query: Flavonifractor
#   • Flavonifractor                           ID=NCBITaxon_946234 depth=12 score=1.00 (exact)
#
# Query: Fusicatenibacter saccharivorans
#   • Fusicatenibacter saccharivorans          ID=NCBITaxon_1150298 depth=14 score=1.00 (exact)
#
# Query: Fusobacterium
#   • Fusobacterium                            ID=NCBITaxon_848   depth=12 score=1.00 (exact)
#
# Query: Fusobacterium nucleatum
#   • Fusobacterium nucleatum                  ID=NCBITaxon_851   depth=14 score=1.00 (exact)
#
# Query: GABA-producing bacteria
#   • Sulfur-Reducing Bacteria       UI=D016999  Tree=B03.900       score=0.72
#   • Gram-Positive Bacteria         UI=D006094  Tree=B03.510       score=0.67
#   • Gammaproteobacteria            UI=D020563  Tree=B03.660.250   score=0.67
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.65
#   • Betaproteobacteria             UI=D020562  Tree=B03.660.075   score=0.59
# Query: GR1009
# Query: Gut Bacteria
#   • Bacteria                       UI=D001419  Tree=B03           score=0.80
#   • Fusobacteria                   UI=D045182  Tree=B03.370       score=0.75
#   • Eubacterium                    UI=D005051  Tree=B03.353.625.750  score=0.70
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.69
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.69
# Query: Gut bacteria
#   • Bacteria                       UI=D001419  Tree=B03           score=0.80
#   • Fusobacteria                   UI=D045182  Tree=B03.370       score=0.75
#   • Eubacterium                    UI=D005051  Tree=B03.353.625.750  score=0.70
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.69
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.69
# Query: Haemophilu
#   • Haemophilus                    UI=D006190  Tree=B03.440.450.600.450  score=0.95
#   • Haemophilus somnus             UI=D044138  Tree=B03.440.450.600.450.750  score=0.71
#   • Chlamydophila                  UI=D023501  Tree=B03.440.190.190.230  score=0.70
#   • Haemophilus ducreyi            UI=D006191  Tree=B03.440.450.600.450.125  score=0.69
#   • Dermatophilus                  UI=D000086182 Tree=B03.510.024.288  score=0.61
# Query: Haemophilus
#   • Haemophilus                              ID=NCBITaxon_724   depth=12 score=1.00 (exact)
#
# Query: Helicobacter
#   • Helicobacter                             ID=NCBITaxon_209   depth=12 score=1.00 (exact)
#
# Query: Helicobacter pylori
#   • Helicobacter pylori                      ID=NCBITaxon_210   depth=14 score=1.00 (exact)
#
# Query: Hungatella
#   • Hungatella                               ID=NCBITaxon_1649459 depth=12 score=1.00 (exact)
#
# Query: Intestinal bacteria
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.67
#   • Gram-Negative Bacteria         UI=D006090  Tree=B03.440       score=0.63
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.61
#   • Acinetobacter                  UI=D000150  Tree=B03.440.400.425.537.050  score=0.56
#   • Atypical Bacterial Forms       UI=D001295  Tree=B03.110       score=0.56
# Query: Intestinibacter
#   • Intestinibacter                          ID=NCBITaxon_1505657 depth=12 score=1.00 (exact)
#
# Query: Kineothrix
#   • Kineothrix                               ID=NCBITaxon_2163168 depth=12 score=1.00 (exact)
#
# Query: Klebsiella
#   • Klebsiella                               ID=NCBITaxon_570   depth=14 score=1.00 (exact)
#
# Query: L
# Query: L. brevis P30021
#   • Paenibacillus brevis                     ID=NCBITaxon_2841508 depth=14 score=0.88
#   • Sphingomonas brevis                      ID=NCBITaxon_2908206 depth=14 score=0.87
#   • Brevibacillus brevis                     ID=NCBITaxon_1393  depth=14 score=0.81
#   • Sulfitobacter brevis                     ID=NCBITaxon_74348 depth=14 score=0.80
#   • Oscillatoria brevis                      ID=NCBITaxon_177969 depth=18 score=0.78
#
# Query: L. fermentum strain
# Query: L. plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#   • Microbacterium plantarum                 ID=NCBITaxon_1816425 depth=14 score=0.88
#   • Paenibacillus plantarum                  ID=NCBITaxon_2654975 depth=14 score=0.88
#   • Lactiplantibacillus plantarum subsp. plantarum ID=NCBITaxon_337330 depth=16 score=0.88
#   • Lactiplantibacillus plantarum subsp. plantarum P-8 ID=NCBITaxon_767468 depth=18 score=0.88
#
# Query: L. plantarum P30025
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#   • Microbacterium plantarum                 ID=NCBITaxon_1816425 depth=14 score=0.88
#   • Paenibacillus plantarum                  ID=NCBITaxon_2654975 depth=14 score=0.88
#   • Lactiplantibacillus plantarum subsp. plantarum ID=NCBITaxon_337330 depth=16 score=0.88
#   • Lactiplantibacillus plantarum subsp. plantarum P-8 ID=NCBITaxon_767468 depth=18 score=0.88
#
# Query: Lachnoclostridium
#   • Lachnoclostridium                        ID=NCBITaxon_1506553 depth=12 score=1.00 (exact)
#
# Query: Lachnospira
#   • Lachnospira                              ID=NCBITaxon_28050 depth=12 score=1.00 (exact)
#
# Query: Lachnospiraceae
#   • Lachnospiraceae                          ID=NCBITaxon_186803 depth=10 score=1.00 (exact)
#
# Query: Lachnospiraceae FCS020 group
#   • bacterium FCS020                         ID=NCBITaxon_1451755 depth=4  score=0.78
#
# Query: Lachnospiraceae NK4A136 group
#   • Lachnospiraceae bacterium NK4A136        ID=NCBITaxon_877420 depth=14 score=0.90
#
# Query: Lachnospiraceae family
#   • Leptospiraceae                 UI=D016953  Tree=B03.440.400.425.475  score=0.61
#   • Oceanospirillaceae             UI=D044130  Tree=B03.440.595   score=0.60
# Query: Lachnospiraceae.g
#   • Lachnospiraceae                          ID=NCBITaxon_186803 depth=10 score=1.00
#   • Lachnospiraceae bacterium 6-1            ID=NCBITaxon_397289 depth=14 score=0.94
#   • Lachnospiraceae bacterium                ID=NCBITaxon_1898203 depth=14 score=0.94
#   • Lachnospiraceae bacterium 3-1            ID=NCBITaxon_397288 depth=14 score=0.94
#   • uncultured Lachnospiraceae bacterium     ID=NCBITaxon_297314 depth=14 score=0.83
#
# Query: Lachnospiraceae_Incertae_Sedis
#   • Lachnospiraceae incertae sedis           ID=NCBITaxon_2840493 depth=12 score=1.00 (exact)
#
# Query: Lachnostridium
#   • Clostridium                    UI=D003013  Tree=B03.300.390.400.200  score=0.80
#   • Phormidium                     UI=D000084242 Tree=B03.280.631   score=0.67
#   • Clostridium tetani             UI=D003017  Tree=B03.300.390.400.200.725  score=0.62
#   • Clostridium tertium            UI=D048010  Tree=B03.300.390.400.200.722  score=0.61
#   • Arcanobacterium                UI=D055667  Tree=B03.510.024.049.050.287  score=0.48
# Query: Lacticaseibacillus paracasei
#   • Lacticaseibacillus paracasei             ID=NCBITaxon_1597  depth=14 score=1.00 (exact)
#
# Query: Lactiplantibacillus plantarum
#   • Lactiplantibacillus plantarum            ID=NCBITaxon_1590  depth=14 score=1.00 (exact)
#
# Query: Lactobacillacea
#   • Lactobacillaceae               UI=D007777  Tree=B03.353.750.450  score=0.97
#   • Lactobacillales                UI=D056546  Tree=B03.353.750   score=0.87
#   • Lactobacillus                  UI=D007778  Tree=B03.353.750.450.475  score=0.79
#   • Bacillaceae                    UI=D001406  Tree=B03.300.390.400.158  score=0.77
#   • Lactobacillus gasseri          UI=D000069998 Tree=B03.353.750.450.475.363  score=0.72
# Query: Lactobacillaceae
#   • Lactobacillaceae                         ID=NCBITaxon_33958 depth=10 score=1.00 (exact)
#
# Query: Lactobacilli
#   • Lactobacillus                  UI=D007778  Tree=B03.353.750.450.475  score=0.88
#   • Lactobacillales                UI=D056546  Tree=B03.353.750   score=0.81
#   • Lactobacillaceae               UI=D007777  Tree=B03.353.750.450  score=0.79
#   • Actinobacillus                 UI=D000188  Tree=B03.440.450.009  score=0.77
#   • Lactobacillus gasseri          UI=D000069998 Tree=B03.353.750.450.475.363  score=0.73
# Query: Lactobacillus
#   • Lactobacillus                            ID=NCBITaxon_1578  depth=12 score=1.00 (exact)
#
# Query: Lactobacillus fermentum PS150
#   • Limosilactobacillus fermentum  UI=D052197  Tree=B03.353.750.450.672  score=0.79
#   • Lactobacillus pentosus         UI=D000070018 Tree=B03.353.750.450.475.586  score=0.75
#   • Lactobacillus helveticus       UI=D052198  Tree=B03.353.750.450.475.400  score=0.72
#   • Lactobacillus plantarum        UI=D048191  Tree=B03.353.750.450.475.612  score=0.69
#   • Lactobacillus crispatus        UI=D000070003 Tree=B03.353.750.450.475.238  score=0.69
# Query: Lactobacillus helveticus R0052
#   • Lactobacillus helveticus R0052           ID=NCBITaxon_880633 depth=16 score=1.00 (exact)
#
# Query: Lactobacillus plantarum
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.76
#   • Microbacterium plantarum                 ID=NCBITaxon_1816425 depth=14 score=0.75
#   • Paenibacillus plantarum                  ID=NCBITaxon_2654975 depth=14 score=0.75
#
# Query: Lactobacillus plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.76
#   • Microbacterium plantarum                 ID=NCBITaxon_1816425 depth=14 score=0.75
#   • Paenibacillus plantarum                  ID=NCBITaxon_2654975 depth=14 score=0.75
#
# Query: Lactobacillus plantarum R1012
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.76
#   • Microbacterium plantarum                 ID=NCBITaxon_1816425 depth=14 score=0.75
#   • Paenibacillus plantarum                  ID=NCBITaxon_2654975 depth=14 score=0.75
#
# Query: Lactobacillus reuteri ATG-F4
#   • Limosilactobacillus reuteri    UI=D052200  Tree=B03.353.750.450.705  score=0.76
#   • Lactobacillus crispatus        UI=D000070003 Tree=B03.353.750.450.475.238  score=0.71
#   • Lactobacillus gasseri          UI=D000069998 Tree=B03.353.750.450.475.363  score=0.69
#   • Levilactobacillus brevis       UI=D052196  Tree=B03.353.750.450.639  score=0.65
#   • Lactobacillus helveticus       UI=D052198  Tree=B03.353.750.450.475.400  score=0.62
# Query: Lactobacillus reuteri NK33
#   • Limosilactobacillus reuteri    UI=D052200  Tree=B03.353.750.450.705  score=0.79
#   • Lactobacillus gasseri          UI=D000069998 Tree=B03.353.750.450.475.363  score=0.72
#   • Actinobacillus equuli          UI=D044131  Tree=B03.440.450.009.200  score=0.68
#   • Levilactobacillus brevis       UI=D052196  Tree=B03.353.750.450.639  score=0.68
#   • Lactobacillus helveticus       UI=D052198  Tree=B03.353.750.450.475.400  score=0.64
# Query: Lactobacillus species
#   • Actinobacillus suis            UI=D044132  Tree=B03.440.450.009.700  score=0.80
#   • Lactobacillus pentosus         UI=D000070018 Tree=B03.353.750.450.475.586  score=0.79
#   • Actinobacillus seminis         UI=D044133  Tree=B03.440.450.009.675  score=0.79
#   • Latilactobacillus sakei        UI=D000070256 Tree=B03.353.750.450.623  score=0.77
#   • Lactobacillus crispatus        UI=D000070003 Tree=B03.353.750.450.475.238  score=0.77
# Query: Lactococcus
#   • Lactococcus                              ID=NCBITaxon_1357  depth=12 score=1.00 (exact)
#
# Query: Levilactobacillus brevis
#   • Levilactobacillus brevis                 ID=NCBITaxon_1580  depth=14 score=1.00 (exact)
#
# Query: Ligilactobacillus salivarius
#   • Ligilactobacillus salivarius             ID=NCBITaxon_1624  depth=14 score=1.00 (exact)
#
# Query: Listeria monocytogenes
#   • Listeria monocytogenes                   ID=NCBITaxon_1639  depth=14 score=1.00 (exact)
#
# Query: Megamonas
#   • Megamonas                                ID=NCBITaxon_158846 depth=12 score=1.00 (exact)
#
# Query: Megasphaera
#   • Megasphaera                              ID=NCBITaxon_906   depth=12 score=1.00 (exact)
#
# Query: Megasphaera elsdenii
#   • Megasphaera elsdenii                     ID=NCBITaxon_907   depth=14 score=1.00 (exact)
#
# Query: Methanobrevibacter
#   • Brevibacterium                 UI=D001951  Tree=B03.510.024.175  score=0.69
#   • Marinobacter                   UI=D053520  Tree=B03.660.250.021.480  score=0.67
#   • Methylobacterium               UI=D020580  Tree=B03.440.400.425.487.500  score=0.65
#   • Clavibacter                    UI=D000086162 Tree=B03.510.024.232  score=0.62
#   • Acetobacter                    UI=D000091  Tree=B03.440.400.425.100.100  score=0.62
# Query: Mucispirillum
#   • Mucispirillum                            ID=NCBITaxon_248038 depth=12 score=1.00 (exact)
#
# Query: Muribaculaceae
#   • Muribaculaceae                           ID=NCBITaxon_2005473 depth=14 score=1.00 (exact)
#
# Query: Negativicutes
#   • Negativicutes                            ID=NCBITaxon_909932 depth=6  score=1.00 (exact)
#
# Query: Odoribacter
#   • Odoribacter                              ID=NCBITaxon_283168 depth=16 score=1.00 (exact)
#
# Query: Oscillibacter
#   • Oscillibacter                            ID=NCBITaxon_459786 depth=12 score=1.00 (exact)
#
# Query: Oscillospira
#   • Oscillospira                             ID=NCBITaxon_119852 depth=12 score=1.00 (exact)
#
# Query: PS150
# Query: ParaBacteroides
#   • Parabacteroides                          ID=NCBITaxon_375288 depth=16 score=1.00 (exact)
#
# Query: Parabacteroides
#   • Parabacteroides                          ID=NCBITaxon_375288 depth=16 score=1.00 (exact)
#
# Query: Parasutterella
#   • Parasutterella                           ID=NCBITaxon_577310 depth=12 score=1.00 (exact)
#
# Query: Porphyromonas
#   • Porphyromonas                            ID=NCBITaxon_836   depth=16 score=1.00 (exact)
#
# Query: Prevotella
#   • Prevotella                               ID=NCBITaxon_838   depth=16 score=1.00 (exact)
#
# Query: Prevotella species
#   • Prevotella nigrescens          UI=D045242  Tree=B03.440.080.094.640.550  score=0.72
#   • Prevotella                     UI=D018720  Tree=B03.440.080.094.640  score=0.71
#   • Prevotella intermedia          UI=D018713  Tree=B03.440.080.094.640.375  score=0.67
#   • Prevotella ruminicola          UI=D045243  Tree=B03.440.080.094.640.700  score=0.62
#   • Prevotella melaninogenica      UI=D001443  Tree=B03.440.080.094.640.500  score=0.60
# Query: Prevotella7
#   • Prevotella                     UI=D018720  Tree=B03.440.080.094.640  score=0.95
#   • Prevotella ruminicola          UI=D045243  Tree=B03.440.080.094.640.700  score=0.62
#   • Prevotella nigrescens          UI=D045242  Tree=B03.440.080.094.640.550  score=0.62
#   • Prevotella intermedia          UI=D018713  Tree=B03.440.080.094.640.375  score=0.62
#   • Moritella                      UI=D034221  Tree=B03.440.450.510  score=0.60
# Query: Prevotellaceae
#   • Prevotellaceae                           ID=NCBITaxon_171552 depth=14 score=1.00 (exact)
#
# Query: Prevotellaceae NK3B31
#   • Prevotella                     UI=D018720  Tree=B03.440.080.094.640  score=0.65
# Query: Proteobacteria
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=1.00
# Query: Psychobiotics
#   • Synechocystis                  UI=D046939  Tree=B03.280.750   score=0.62
#   • Psychrobacter                  UI=D044096  Tree=B03.440.400.425.537.650  score=0.62
# Query: Rikencellaceae
#   • Brucellaceae                   UI=D042021  Tree=B03.440.400.425.215  score=0.77
#   • Legionellaceae                 UI=D016951  Tree=B03.440.400.425.450  score=0.71
#   • Bartonellaceae                 UI=D001475  Tree=B03.440.090   score=0.71
#   • Eikenella                      UI=D016970  Tree=B03.440.450.400  score=0.70
#   • Spirillaceae                   UI=D043167  Tree=B03.440.840   score=0.69
# Query: Romboutsia
#   • Romboutsia                               ID=NCBITaxon_1501226 depth=12 score=1.00 (exact)
#
# Query: Roseburia
#   • Roseburia                                ID=NCBITaxon_841   depth=12 score=1.00 (exact)
#
# Query: Roseburia faecis
#   • Roseburia faecis                         ID=NCBITaxon_301302 depth=14 score=1.00 (exact)
#
# Query: Roseburia inulinivorans
#   • Roseburia inulinivorans                  ID=NCBITaxon_360807 depth=14 score=1.00 (exact)
#
# Query: Ruminococcaceae
#   • Ruminococcaceae bacterium enrichment culture ID=NCBITaxon_1776336 depth=14 score=0.80
#
# Query: Ruminococcaceae Incertae Sedis
#   • uncultured incertae sedis 5 bacterium    ID=NCBITaxon_412050 depth=4  score=0.77
#
# Query: Ruminococcaceae_UCG-014
#   • Micrococcaceae                 UI=D008835  Tree=B03.510.024.850  score=0.65
#   • Ruminococcus                   UI=D045857  Tree=B03.353.625.806  score=0.63
#   • Aerococcaceae                  UI=D056567  Tree=B03.353.750.030  score=0.61
# Query: Ruminococcus
#   • Ruminococcus                             ID=NCBITaxon_1263  depth=12 score=1.00 (exact)
#
# Query: Ruminococcus-2
#   • Ruminococcus                             ID=NCBITaxon_1263  depth=12 score=1.00
#   • Ruminococcus sp. K-1                     ID=NCBITaxon_337462 depth=16 score=0.98
#   • Ruminococcus sp.                         ID=NCBITaxon_41978 depth=16 score=0.98
#   • Ruminococcus sp. M-1                     ID=NCBITaxon_253240 depth=16 score=0.98
#   • Ruminococcus sp. 5                       ID=NCBITaxon_169436 depth=16 score=0.98
#
# Query: S24-7
#   • bacterium S24                            ID=NCBITaxon_1315627 depth=4  score=0.97
#   • bacterium Co.S24                         ID=NCBITaxon_1197020 depth=4  score=0.97
#   • Bacillus sp. S24                         ID=NCBITaxon_1779385 depth=16 score=0.93
#   • Pseudomonas sp. S24                      ID=NCBITaxon_1573717 depth=16 score=0.93
#   • Streptomyces sp. S24                     ID=NCBITaxon_591199 depth=16 score=0.93
#
# Query: Salmonella
#   • Salmonella                               ID=NCBITaxon_590   depth=12 score=1.00 (exact)
#
# Query: Selenomonadalesare
#   • Selenomonas                    UI=D020357  Tree=B03.440.425.410.800.877  score=0.76
#   • Aeromonadales                  UI=D000074762 Tree=B03.660.250.018  score=0.71
#   • Pseudomonadaceae               UI=D011548  Tree=B03.440.400.425.625  score=0.71
#   • Halomonadaceae                 UI=D044129  Tree=B03.440.400.425.377  score=0.69
#   • Alteromonadaceae               UI=D034241  Tree=B03.660.250.021  score=0.65
# Query: Shigella
#   • Shigella                                 ID=NCBITaxon_620   depth=12 score=1.00 (exact)
#
# Query: Staphylococcus
#   • Staphylococcus                           ID=NCBITaxon_1279  depth=12 score=1.00 (exact)
#
# Query: Streptococcus
#   • Streptococcus                            ID=NCBITaxon_1301  depth=12 score=1.00 (exact)
#
# Query: Streptococcus thermophilus
#   • Streptococcus thermophilus               ID=NCBITaxon_1308  depth=14 score=1.00 (exact)
#
# Query: Subdoligranulum
#   • Subdoligranulum                          ID=NCBITaxon_292632 depth=12 score=1.00 (exact)
#
# Query: Succinivibrio
#   • Succinivibrio                            ID=NCBITaxon_83770 depth=12 score=1.00 (exact)
#
# Query: Synergistetes
#   • Synergistetes bacterium HGW-Synergistetes-1 ID=NCBITaxon_2013842 depth=8  score=0.91
#   • Synergistetes bacterium HGW-Synergistetes-2 ID=NCBITaxon_2013843 depth=8  score=0.91
#   • Synergistetes bacterium enrichment culture ID=NCBITaxon_1647750 depth=8  score=0.84
#
# Query: Thermodesulfobacteriota
#   • Thermodesulfobacteriota                  ID=NCBITaxon_200940 depth=4  score=1.00 (exact)
#
# Query: Toxoplasma gondii
#   • Mycoplasma genitalium          UI=D045704  Tree=B03.440.860.580.553.553.355  score=0.63
#   • Mycoplasma hominis             UI=D019535  Tree=B03.440.860.580.553.553.400  score=0.63
#   • Mycoplasma pulmonis            UI=D045803  Tree=B03.440.860.580.553.553.670  score=0.61
#   • Mycoplasma bovis               UI=D045682  Tree=B03.440.860.580.553.553.200  score=0.61
# Query: Turicibacter
#   • Turicibacter                             ID=NCBITaxon_191303 depth=12 score=1.00 (exact)
#
# Query: UCG-005
#   • Ruminococcaceae bacterium UCG-005        ID=NCBITaxon_3068309 depth=14 score=0.87
#
# Query: UCG009
# Query: Veillonella
#   • Veillonella                              ID=NCBITaxon_29465 depth=12 score=1.00 (exact)
#
# Query: Veillonellaceae
#   • Veillonellaceae                          ID=NCBITaxon_31977 depth=10 score=1.00 (exact)
#
# Query: Verrucomicrobia
#   • Verrucomicrobia bacterium B-1-8          ID=NCBITaxon_747582 depth=10 score=0.94
#
# Query: Verrucomicrobiaceae
#   • Verrucomicrobiaceae                      ID=NCBITaxon_203557 depth=12 score=1.00 (exact)
#
# Query: Verrucomicrobiota
#   • Verrucomicrobiota                        ID=NCBITaxon_74201 depth=6  score=1.00 (exact)
#
# Query: acetate-producing bacteria
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.65
#   • Sulfur-Reducing Bacteria       UI=D016999  Tree=B03.900       score=0.64
#   • Betaproteobacteria             UI=D020562  Tree=B03.660.075   score=0.64
#   • Deltaproteobacteria            UI=D020564  Tree=B03.660.125   score=0.62
#   • Endospore-Forming Bacteria     UI=D004725  Tree=B03.300       score=0.62
# Query: bacteria
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  score=1.00 (exact)
#
# Query: bacteroides
#   • Bacteroides                              ID=NCBITaxon_816   depth=16 score=1.00 (exact)
#
# Query: bifidobacteria
#   • Bifidobacterium                UI=D001644  Tree=B03.510.024.100  score=0.90
#   • Acidobacteria                  UI=D061271  Tree=B03.026       score=0.81
#   • Fusobacteria                   UI=D045182  Tree=B03.370       score=0.77
#   • Bifidobacterium breve          UI=D000069984 Tree=B03.510.024.100.375  score=0.74
#   • Bifidobacterium animalis       UI=D000069982 Tree=B03.510.024.100.250  score=0.74
# Query: bifidobacterial populations
#   • Bifidobacterium pseudocatenulatum UI=D000070257 Tree=B03.510.024.100.750  score=0.67
#   • Bifidobacterium animalis       UI=D000069982 Tree=B03.510.024.100.250  score=0.67
#   • Bifidobacterium                UI=D001644  Tree=B03.510.024.100  score=0.67
#   • Bifidobacterium adolescentis   UI=D000070005 Tree=B03.510.024.100.125  score=0.65
#   • Bifidobacterium longum         UI=D000069978 Tree=B03.510.024.100.500  score=0.65
# Query: butyrate-producing bacteria
#   • butyrate-producing bacterium             ID=NCBITaxon_2811711 depth=4  score=0.89
#   • butyrate-producing bacterium R4          ID=NCBITaxon_340485 depth=4  score=0.76
#
# Query: cancer-related bacteria
#   • Gram-Negative Bacteria         UI=D006090  Tree=B03.440       score=0.67
#   • Deltaproteobacteria            UI=D020564  Tree=B03.660.125   score=0.62
#   • Cyanobacteria                  UI=D000458  Tree=B03.280       score=0.61
#   • Alphaproteobacteria            UI=D020561  Tree=B03.660.050   score=0.57
#   • Acidobacteria                  UI=D061271  Tree=B03.026       score=0.56
# Query: coliform
#   • coliform bacterium S1/7                  ID=NCBITaxon_464824 depth=4  score=0.78
#   • coliform bacterium S1/2                  ID=NCBITaxon_464823 depth=4  score=0.78
#   • coliform bacterium S4/2                  ID=NCBITaxon_464829 depth=4  score=0.76
#   • coliform bacterium 3-80                  ID=NCBITaxon_464821 depth=4  score=0.75
#
# Query: coliform genera
# Query: dysregulated bacteria
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  score=1.00
#   • unclassified Bacteria                    ID=NCBITaxon_49928 depth=2  score=0.77
#
# Query: firmicutes
#   • Bacillus <firmicutes>                    ID=NCBITaxon_1386  depth=12 score=0.87
#   • Bacillus sp. (in: firmicutes)            ID=NCBITaxon_1409  depth=16 score=0.86
#   • Firmicutes bacterium HGW-Firmicutes-5    ID=NCBITaxon_2013786 depth=8  score=0.82
#   • Firmicutes bacterium HGW-Firmicutes-8    ID=NCBITaxon_2013789 depth=8  score=0.82
#   • Firmicutes bacterium HGW-Firmicutes-3    ID=NCBITaxon_2013784 depth=8  score=0.82
#
# Query: genus_Coprococcus2
#   • Enterococcus                   UI=D016983  Tree=B03.353.750.250.250  score=0.67
#   • Oenococcus                     UI=D056585  Tree=B03.353.750.475.600  score=0.64
#   • Aerococcus                     UI=D056570  Tree=B03.353.750.030.030  score=0.64
#   • Micrococcus                    UI=D008837  Tree=B03.510.024.850.500  score=0.62
#   • Deinococcus                    UI=D034301  Tree=B03.510.400.200  score=0.62
# Query: genus_Eggerthella
#   • Eggerthella                              ID=NCBITaxon_84111 depth=12 score=0.85
#   • Eggerthella sp.                          ID=NCBITaxon_1929886 depth=16 score=0.84
#   • uncultured Eggerthella sp.               ID=NCBITaxon_293422 depth=16 score=0.77
#
# Query: genus_Eubacterium
#   • Eubacterium                    UI=D005051  Tree=B03.353.625.750  score=0.79
#   • Renibacterium                  UI=D000084402 Tree=B03.510.024.850.750  score=0.73
#   • Fusobacterium                  UI=D005673  Tree=B03.370.250   score=0.73
#   • Exiguobacterium                UI=D000086183 Tree=B03.353.500.100.309  score=0.69
#   • Corynebacterium                UI=D003352  Tree=B03.510.024.250  score=0.62
# Query: genus_Ruminococcaceae
#   • Enterococcaceae                UI=D056569  Tree=B03.353.750.250  score=0.72
#   • Aerococcaceae                  UI=D056567  Tree=B03.353.750.030  score=0.71
#   • Micrococcaceae                 UI=D008835  Tree=B03.510.024.850  score=0.69
#   • Planococcaceae                 UI=D058641  Tree=B03.353.500.700  score=0.63
#   • Streptococcaceae               UI=D013289  Tree=B03.353.750.737  score=0.59
# Query: genus_Subdoligranulum
#   • Subdoligranulum                          ID=NCBITaxon_292632 depth=12 score=0.86
#   • Subdoligranulum sp.                      ID=NCBITaxon_2053618 depth=16 score=0.85
#   • uncultured Subdoligranulum sp.           ID=NCBITaxon_512298 depth=16 score=0.78
#   • unclassified Subdoligranulum             ID=NCBITaxon_2685293 depth=14 score=0.75
#
# Query: gut Bifidobacterium
#   • Bifidobacterium                UI=D001644  Tree=B03.510.024.100  score=0.88
#   • Bifidobacterium breve          UI=D000069984 Tree=B03.510.024.100.375  score=0.75
#   • Bifidobacterium longum         UI=D000069978 Tree=B03.510.024.100.500  score=0.73
#   • Bifidobacterium bifidum        UI=D000069985 Tree=B03.510.024.100.313  score=0.71
#   • Exiguobacterium                UI=D000086183 Tree=B03.353.500.100.309  score=0.71
# Query: gut Christensenellaceae family
# Query: gut Flavonifractor genus
# Query: gut bacteria
#   • Bacteria                       UI=D001419  Tree=B03           score=0.80
#   • Fusobacteria                   UI=D045182  Tree=B03.370       score=0.75
#   • Eubacterium                    UI=D005051  Tree=B03.353.625.750  score=0.70
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.69
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.69
# Query: gut-resident bacteria
#   • Sulfur-Reducing Bacteria       UI=D016999  Tree=B03.900       score=0.67
#   • Gram-Positive Bacteria         UI=D006094  Tree=B03.510       score=0.65
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.63
#   • Epsilonproteobacteria          UI=D020565  Tree=B03.660.150   score=0.57
#   • Gordonia Bacterium             UI=D033601  Tree=B03.510.024.700  score=0.56
# Query: heat-killed PS150
# Query: hypnotic psychobiotic strain
# Query: imbalance-inducing bacteria
#   • Sulfur-Reducing Bacteria       UI=D016999  Tree=B03.900       score=0.67
# Query: inactivated L. plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#   • Microbacterium plantarum                 ID=NCBITaxon_1816425 depth=14 score=0.88
#   • Paenibacillus plantarum                  ID=NCBITaxon_2654975 depth=14 score=0.88
#   • Lactiplantibacillus plantarum subsp. plantarum ID=NCBITaxon_337330 depth=16 score=0.88
#   • Lactiplantibacillus plantarum subsp. plantarum P-8 ID=NCBITaxon_767468 depth=18 score=0.88
#
# Query: intestinal bacteria
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   score=0.67
#   • Gram-Negative Bacteria         UI=D006090  Tree=B03.440       score=0.63
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.61
#   • Acinetobacter                  UI=D000150  Tree=B03.440.400.425.537.050  score=0.56
#   • Atypical Bacterial Forms       UI=D001295  Tree=B03.110       score=0.56
# Query: live L. plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#   • Microbacterium plantarum                 ID=NCBITaxon_1816425 depth=14 score=0.88
#   • Paenibacillus plantarum                  ID=NCBITaxon_2654975 depth=14 score=0.88
#   • Lactiplantibacillus plantarum subsp. plantarum ID=NCBITaxon_337330 depth=16 score=0.88
#   • Lactiplantibacillus plantarum subsp. plantarum P-8 ID=NCBITaxon_767468 depth=18 score=0.88
#
# Query: live and inactivated L. plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#   • Microbacterium plantarum                 ID=NCBITaxon_1816425 depth=14 score=0.88
#   • Paenibacillus plantarum                  ID=NCBITaxon_2654975 depth=14 score=0.88
#   • Lactiplantibacillus plantarum subsp. plantarum ID=NCBITaxon_337330 depth=16 score=0.88
#   • Lactiplantibacillus plantarum subsp. plantarum P-8 ID=NCBITaxon_767468 depth=18 score=0.88
#
# Query: live and inactivated Lactobacillus plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.76
#   • Microbacterium plantarum                 ID=NCBITaxon_1816425 depth=14 score=0.75
#   • Paenibacillus plantarum                  ID=NCBITaxon_2654975 depth=14 score=0.75
#
# Query: maternal vaginal microbes
#   • Gardnerella vaginalis          UI=D006194  Tree=B03.510.024.400.800  score=0.61
# Query: microbes
#   • Microbacterium                 UI=D000083822 Tree=B03.510.024.775  score=0.64
#   • Microcystis                    UI=D046931  Tree=B03.280.500   score=0.63
#   • Micrococcus                    UI=D008837  Tree=B03.510.024.850.500  score=0.63
# Query: microorganisms
# Query: mucus-associated species
# Query: olidextribacter
#   • Liberibacter                   UI=D000086202 Tree=B03.660.050.662.347  score=0.81
#   • Flexibacter                    UI=D045248  Tree=B03.440.080.130.200  score=0.77
#   • Nitrobacter                    UI=D009576  Tree=B03.440.400.425.200.520  score=0.69
#   • Citrobacter                    UI=D002954  Tree=B03.440.450.425.200  score=0.69
#   • Enterobacter                   UI=D004754  Tree=B03.440.450.425.275  score=0.52
# Query: oral bacteria
#   • Bacteria                       UI=D001419  Tree=B03           score=0.76
#   • Fusobacteria                   UI=D045182  Tree=B03.370       score=0.72
#   • Gordonia Bacterium             UI=D033601  Tree=B03.510.024.700  score=0.71
#   • Cyanobacteria                  UI=D000458  Tree=B03.280       score=0.69
#   • Acidobacteria                  UI=D061271  Tree=B03.026       score=0.69
# Query: phylum Proteobacteria
#   • Proteobacteria                 UI=D020560  Tree=B03.660       score=0.80
#   • Alphaproteobacteria            UI=D020561  Tree=B03.660.050   score=0.80
#   • Epsilonproteobacteria          UI=D020565  Tree=B03.660.150   score=0.76
#   • Gammaproteobacteria            UI=D020563  Tree=B03.660.250   score=0.75
#   • Deltaproteobacteria            UI=D020564  Tree=B03.660.125   score=0.75
# Query: plantarum P-8
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#   • Microbacterium plantarum                 ID=NCBITaxon_1816425 depth=14 score=0.88
#   • Paenibacillus plantarum                  ID=NCBITaxon_2654975 depth=14 score=0.88
#   • Lactiplantibacillus plantarum subsp. plantarum ID=NCBITaxon_337330 depth=16 score=0.88
#   • Lactiplantibacillus plantarum subsp. plantarum P-8 ID=NCBITaxon_767468 depth=18 score=0.88
#
# Query: predominant bacteria
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  score=1.00
#   • unclassified Bacteria                    ID=NCBITaxon_49928 depth=2  score=0.77
#
# Query: probiotics
# Query: psychobiotic strain
# Query: psychobiotics
#   • Synechocystis                  UI=D046939  Tree=B03.280.750   score=0.62
#   • Psychrobacter                  UI=D044096  Tree=B03.440.400.425.537.650  score=0.62
# Query: short-chain fatty acid (SCFA)-producing bacteria
# Query: short-chain fatty acid producing bacteria
# Query: xylanophilum_group
#   • Eubacterium xylanophilum                 ID=NCBITaxon_39497 depth=14 score=0.79

# %%
#!/usr/bin/env python3
import os
import re
import unicodedata
import json
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint

# -----------------------------------------------------------------------------
# 1. Setup paths and namespaces
# -----------------------------------------------------------------------------
path = str(Path(os.path.abspath(os.getcwd())).absolute())
json_file = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\data\train_platinum\train_platinum.json"
#json_file = os.path.join(path, "train_gold.json")
#vertex_file = os.path.join(path, "train_vertexsets.json")
tokenized_file = os.path.join(path, "tokenized_sentences_with_entitiesv2.json")
save_path = os.path.join(path, "rdf")
os.makedirs(save_path, exist_ok=True)

GUTBRAIN = Namespace("https://hereditary.dei.unipd.it/ontology/gutbrain/resource/")
GUTPROP = Namespace("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/")

PAPER_CLASS       = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Paper")
MENTION_CLASS     = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Mention")
PAPER_ABSTRACT    = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/PaperAbstract")
PAPER_TITLE       = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/PaperTitle")
PAPER_COLLECTION  = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/PaperCollection")
PROJECT           = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Project")
SAMPLE            = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Sample")
SENTENCE          = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Sentence")

# -----------------------------------------------------------------------------
# 2. Load the JSON paper data
# -----------------------------------------------------------------------------
with open(json_file, "r", encoding="utf-8") as f:
    data = json.load(f)
# -----------------------------------------------------------------------------
# 3. Mapping dictionaries (keys must be in Title case)
# -----------------------------------------------------------------------------
label_mapping = {
    "Anatomical Location":   URIRef("https://w3id.org/brainteaser/ontology/schema/AnatomicalSite"),
    "Animal":                URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Animal"),
    "Biomedical Technique":  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/BiomedicalTechnique"),
    "Bacteria":              URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Species"),
    "Chemical":              URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Chemical"),
    "Dietary Supplement":    URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/DietarySupplement"),
    "DDF":                   URIRef("https://w3id.org/brainteaser/ontology/schema/DiseaseDisorderOrFinding"),
    "Drug":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Drug"),
    "Food":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Food"),
    "Gene":                  URIRef("https://w3id.org/brainteaser/ontology/schema/Gene"),
    "Human":                 URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Human"),
    "Microbiome":            URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Microbiome"),
    "Statistical Technique": URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/StatisticalTechnique")
}
concept_scheme_mapping = {
    "Anatomical Location":   URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/AnatomicSite"),
    "Animal":                URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Animal"),
    "Human":                 URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Human"),
    "Drug":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Drug"),
    "Gene":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Gene"),
    "Dietary Supplement":    URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/dietarySupplement"),
    "DDF":                   URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/diseaseDisorderOrFindingTaxonomy"),
    "Metabolite":            URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Metabolite"),
    "Bacteria":               URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Bacteria"),
    "Food":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Food"),
    "Chemical":              URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Chemical"),
    "Biomedical Technique":  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/BiomedicalTechnique"),
    "Microbiome":            URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Microbiome"),
    "Statistical Technique": URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/StatisticalTechnique")
}

# -----------------------------------------------------------------------------
# 4. Initialize the RDF graph and bind namespaces
# -----------------------------------------------------------------------------
BACTERIA_CLASS = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Species")
FAMILY_CLASS = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Family")
OBO_BASE = "http://purl.obolibrary.org/obo/"
MESH_BASE = "https://www.ncbi.nlm.nih.gov/mesh/"
BACTERIA_CONCEPT_SCHEME = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Bacteria")

g = Graph()
g.bind("gutbrain", GUTBRAIN)
g.bind("rdfs", RDFS)
g.bind("xsd", XSD)
g.bind("skos", SKOS)
g.bind("owl", OWL)
g.bind("gutprop", GUTPROP)

g.add((SKOS.inScheme, RDF.type, OWL.ObjectProperty))
g.add((SKOS.broaderTransitive, RDF.type, OWL.ObjectProperty))

g.add((GUTPROP.partOf, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.partOf, RDFS.label, Literal("partOf", datatype=XSD.string)))
g.add((GUTPROP.hasTitle, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.hasTitle, RDFS.label, Literal("hasTitle", datatype=XSD.string)))
g.add((GUTPROP.hasAbstract, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.hasAbstract, RDFS.label, Literal("hasAbstract", datatype=XSD.string)))

g.add((GUTPROP.containedIn, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.containedIn, RDFS.label, Literal("containedIn", datatype=XSD.string)))
g.add((GUTBRAIN.contains, RDF.type, OWL.ObjectProperty))
g.add((GUTBRAIN.contains, RDFS.label, Literal("contains", datatype=XSD.string)))
g.add((GUTPROP.composedOf, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.composedOf, RDFS.label, Literal("composedOf", datatype=XSD.string)))

g.add((GUTPROP.locatedIn, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.locatedIn, RDFS.label, Literal("locatedIn", datatype=XSD.string)))

g.add((GUTPROP.paperId, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.paperId, RDFS.label, Literal("paperId", datatype=XSD.string)))
g.add((GUTPROP.paperAnnotator, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.paperAnnotator, RDFS.label, Literal("paperAnnotator", datatype=XSD.string)))
g.add((GUTPROP.paperYear, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.paperYear, RDFS.label, Literal("paperYear", datatype=XSD.string)))
g.add((GUTPROP.paperJournal, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.paperJournal, RDFS.label, Literal("paperJournal", datatype=XSD.string)))
g.add((GUTPROP.paperAuthor, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.paperAuthor, RDFS.label, Literal("paperAuthor", datatype=XSD.string)))
g.add((GUTPROP.numberOfRunsFound, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.numberOfRunsFound, RDFS.label, Literal("numberOfRunsFound", datatype=XSD.string)))
g.add((GUTPROP.NCBITaxonID, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.NCBITaxonID, RDFS.label, Literal("NCBITaxonID", datatype=XSD.string)))
g.add((GUTPROP.sdRelativeAbundance, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.sdRelativeAbundance, RDFS.label, Literal("sdRelativeAbundance", datatype=XSD.string)))
g.add((GUTPROP.medianRelativeAbundance, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.medianRelativeAbundance, RDFS.label, Literal("medianRelativeAbundance", datatype=XSD.string)))
g.add((GUTPROP.meanRelativeAbundance, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.meanRelativeAbundance, RDFS.label, Literal("meanRelativeAbundance", datatype=XSD.string)))
g.add((GUTPROP.scientificName, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.scientificName, RDFS.label, Literal("scientificName", datatype=XSD.string)))
g.add((GUTPROP.hasMentionText, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.hasMentionText, RDFS.label, Literal("hasMentionText", datatype=XSD.string)))
g.add((GUTPROP.hasSentenceText, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.hasSentenceText, RDFS.label, Literal("hasSentenceText", datatype=XSD.string)))
g.add((GUTPROP.hasTitleText, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.hasTitleText, RDFS.label, Literal("hasTitleText", datatype=XSD.string)))
g.add((GUTPROP.hasAbstractText, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.hasAbstractText, RDFS.label, Literal("hasAbstractText", datatype=XSD.string)))

for scheme_uri in set(concept_scheme_mapping.values()):
    keys = [k for k, v in concept_scheme_mapping.items() if v == scheme_uri]
    label_text = ", ".join(k.title() for k in keys) + " Concept Scheme"
    g.add((scheme_uri, RDF.type, SKOS.ConceptScheme))
    g.add((scheme_uri, RDFS.label, Literal(label_text, datatype=XSD.string)))

is_train_platinum = "train_platinum" in os.path.basename(json_file)
#is_train_gold = "train_gold" in os.path.basename(json_file)

#if is_train_gold:
 #   gold_collection_uri = URIRef(GUTBRAIN["goldCollection"])
 #   label_text = "goldCollection"
  #  g.add((gold_collection_uri, RDF.type, PAPER_COLLECTION))
   # g.add((gold_collection_uri, RDFS.label, Literal(label_text, datatype=XSD.string)))
    
if is_train_platinum:
    platinum_collection_uri = URIRef(GUTBRAIN["platinumCollection"])
    label_text = "platinumCollection"
    g.add((platinum_collection_uri, RDF.type, PAPER_COLLECTION))
    g.add((platinum_collection_uri, RDFS.label, Literal(label_text, datatype=XSD.string)))

# -----------------------------------------------------------------------------
# Utility functions
# -----------------------------------------------------------------------------
def create_uri_fragment(text):
    cleaned = re.sub(r'<[^>]*>', '', text)
    cleaned = normalize_text(cleaned)
    # Allow word characters, digits, underscores, hyphens, and Greek characters (U+0370 to U+03FF)
    cleaned = re.sub(r'[^\w\u0370-\u03FF-]', '_', cleaned)
    return cleaned

def to_camel_case(s):
    s = re.sub(r'[^\w\s]', '', s)
    parts = re.split(r'\s+', s.strip())
    if not parts:
        return ""
    return parts[0].lower() + ''.join(word.title() for word in parts[1:])

def normalize_text(text):
    return unicodedata.normalize('NFC', text)

def preprocess(term):
    return term.replace('_', ' ').strip()

def normalize_to_ascii(s: str) -> str:
    # 1) Decomponi i caratteri accentati in base + segni diacritici
    nfkd = unicodedata.normalize('NFKD', s)
    # 2) Filtra solo i caratteri ASCII
    ascii_bytes = nfkd.encode('ascii', 'ignore')
    # 3) Ritorna la stringa decodificata
    return ascii_bytes.decode('ascii')

mention_counter   = 1
tokenized_mentions = {}
missing_mentions = []
created = {}
label2uri = {}
created["Bacteria"] = URIRef(f"{OBO_BASE}NCBITaxon_2")
g.add((created["Bacteria"], RDF.type, FAMILY_CLASS))
g.add((created["Bacteria"], RDF.type, SKOS.Concept))
g.add((created["Bacteria"], RDFS.label, Literal("Bacteria", datatype=XSD.string)))
g.add((created["Bacteria"], SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
#created["Bifidobacterium"] = URIRef(f"{MESH_BASE}D001644")
#g.add((created["Bifidobacterium"], RDF.type, BACTERIA_CLASS))
#g.add((created["Bifidobacterium"], RDF.type, SKOS.Concept))
#g.add((created["Bifidobacterium"], RDFS.label, Literal("Bifidobacterium", datatype=XSD.string)))
#g.add((created["Bifidobacterium"], SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))

# -----------------------------------------------------------------------------
# 5. Process each paper (each key in the JSON represents a paper)
# -----------------------------------------------------------------------------
for paper_id, paper_data in data.items():
    paper_uri = URIRef(GUTBRAIN[f"paper_{paper_id}"])
    g.add((paper_uri, RDF.type, PAPER_CLASS))
    
    if is_train_platinum:
        g.add((paper_uri, GUTPROP.partOf, platinum_collection_uri))
        g.add((platinum_collection_uri, GUTBRAIN.contains, paper_uri))

    #if is_train_gold:
    #    g.add((paper_uri, GUTPROP.partOf, gold_collection_uri))
    #    g.add((gold_collection_uri, GUTBRAIN.contains, paper_uri))
    
    # Each paper gets its own mention node
    #paper_mention = URIRef(GUTBRAIN[f"mention_{paper_id}"])
    #g.add((paper_mention, RDF.type, MENTION_CLASS))
    #g.add((paper_uri, GUTPROP.hasMention, paper_mention))
    
    metadata = paper_data.get("metadata", {})
    full_title = metadata.get("title", None)
    full_abstract = metadata.get("abstract", None)
    try:
        paper_id_val = int(paper_id)
    except ValueError:
        paper_id_val = paper_id
    paper_annotator = metadata.get("annotator", None)
    paper_year = metadata.get("year", None)
    paper_journal = metadata.get("journal", None)
    paper_author = metadata.get("author", None)
    
    g.add((paper_uri, GUTPROP.paperId, Literal(paper_id_val, datatype=XSD.integer)))
    if paper_annotator is not None:
        g.add((paper_uri, GUTPROP.paperAnnotator, Literal(paper_annotator, datatype=XSD.string)))
    if paper_year is not None:
        g.add((paper_uri, GUTPROP.paperYear, Literal(paper_year, datatype=XSD.gYear)))
    if paper_journal is not None:
        g.add((paper_uri, GUTPROP.paperJournal, Literal(paper_journal, datatype=XSD.string)))
    if paper_author is not None:
        g.add((paper_uri, GUTPROP.paperAuthor, Literal(paper_author, datatype=XSD.string)))
    
    title_texts = []
    abstract_texts = []
    mention_created = False
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        label_title = raw_label.title() if raw_label.lower() != "ddf" else "DDF"
        
        text_span = entity.get("text_span", "").strip()
        cleaned_text = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(cleaned_text)
        
        if label_title == "Bacteria":
            if cleaned_text_span.lower().endswith(" bacteria"):
                term_raw = "Bacteria"
            elif cleaned_text_span.lower().endswith(" Bifidobacterium"):
                term_raw = "Bifidobacterium"
            else:
                term_raw = cleaned_text_span
                
            term = preprocess(term_raw)
            
            print(f"Query: {term}")
            
            if term_raw in created:
                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {uri}\n")
                continue
                
            hits = genus_abbrev_lookup(term)
            if hits:
                for l,t,d,s in hits: 
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f} (abbr)")
                    entity_uri = URIRef(f"{OBO_BASE}{t}")
                    created[term_raw] = entity_uri
                    label2uri[label_name.lower()] = entity_uri
                    g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(label_name, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                    g.add((entity_uri, SKOS.broaderTransitive, created["Bacteria"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_{mention_counter}", datatype=XSD.string)))
                    #mention_counter += 1
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    continue

            ex = exact_ix.get(term.lower(), [])
            if ex:
                for label_name, taxon_id, depth in ex:
                    print(f"  • {label_name:40s} ID={taxon_id:15s} depth={depth:<2d} (exact)")
                    entity_uri = URIRef(f"{OBO_BASE}{taxon_id}")
                    created[term_raw] = entity_uri
                    label2uri[label_name.lower()] = entity_uri
                    g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(label_name, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                    g.add((entity_uri, SKOS.broaderTransitive, created["Bacteria"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_{mention_counter}", datatype=XSD.string)))
                    #mention_counter += 1
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            cos = top_cosine(term)
            if not cos:
                matches = find_mesh_match(term, name_index)
                if matches: 
                    for name, ui, tree, score in matches[:1]:
                        name_key = name.lower()
                        reused = False
                        if name_key in label2uri:
                            entity_uri = label2uri[name_key]
                            print(f"  → Reusing existing URI by label: {entity_uri}\n")
                            reused = True
                            continue
                        if reused:
                            break
                            
                        print(f"  • {name:30s} UI={ui:8s} Tree={tree:12s}  scoreMESH={score:.2f}")
                        name_uri = URIRef(f"{MESH_BASE}{ui}")
                        created[term_raw] = name_uri
                        label2uri[name_key] = name_uri
                        g.add((name_uri, RDF.type, BACTERIA_CLASS))
                        g.add((name_uri, RDF.type, SKOS.Concept))
                        g.add((name_uri, RDFS.label, Literal(name, datatype=XSD.string)))
                        g.add((name_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                        g.add((name_uri, SKOS.broaderTransitive, created["Bacteria"]))
                        mention_uri = URIRef(GUTBRAIN[term_raw])
                        g.add((mention_uri, RDF.type, MENTION_CLASS))
                        g.add((mention_uri, RDFS.label, Literal(f"mention_{mention_counter}", datatype=XSD.string)))
                        #mention_counter += 1
                        g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                        g.add((name_uri, GUTPROP.containedIn, mention_uri))
                        tokenized_mentions[term_raw] = mention_uri
                        continue
                else:
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_{mention_counter}", datatype=XSD.string)))
                    #mention_counter += 1
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((created["Bacteria"], GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    
            else:
                for l,t,d,s in cos[:1]:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f}")
                    name_uri = URIRef(f"{OBO_BASE}{t}")
                    created[term_raw] = name_uri
                    label2uri[label_name.lower()] = name_uri
                    g.add((name_uri, RDF.type, BACTERIA_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(l, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                    g.add((name_uri, SKOS.broaderTransitive, created["Bacteria"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_{mention_counter}", datatype=XSD.string)))
                    mention_counter += 1
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                print()
                
        #mention_uri = URIRef(GUTBRAIN[f"mention_{mention_counter}"])
        #mention_counter += 1
        #g.add((mention_uri, RDF.type, MENTION_CLASS))
        #g.add((mention_uri, GUTPROP.hasMentionText, Literal(cleaned_text_span, datatype=XSD.string)))
        #canonical = create_uri_fragment(cleaned_text_span)
        #tokenized_mentions[canonical] = mention_uri
        #continue
        
        location_lower = entity.get("location", "").strip().lower()
        if location_lower == "title":
            title_texts.append(cleaned_text_span)
        elif location_lower == "abstract":
            abstract_texts.append(cleaned_text_span)
        
        #if label_title in label_mapping:
            #entity_node = URIRef(GUTBRAIN[instance_fragment])
            #class_uri = label_mapping[label_title]
            #g.add((entity_node, RDF.type, class_uri))
            #g.add((entity_node, RDF.type, SKOS.Concept))
            #g.add((entity_node, RDFS.label, Literal(cleaned_text_span, datatype=XSD.string)))

            #if label_title in concept_scheme_mapping:
                #scheme_uri = concept_scheme_mapping[label_title]
                #g.add((entity_node, SKOS.inScheme, scheme_uri))

        else:
            entity_node = URIRef(GUTBRAIN[f"entity_{paper_id}_{i}"])
            g.add((entity_node, RDF.type, MENTION_CLASS))
            g.add((entity_node, RDF.type, SKOS.Concept))
            g.add((entity_node, RDFS.label, Literal(label_title, datatype=XSD.string)))
            g.add((entity_node, GUTPROP.annotator, Literal(metadata.get("annotator", "unknown"), datatype=XSD.string)))
            g.add((entity_node, GUTPROP.location, Literal(entity.get("location", ""), datatype=XSD.string)))
            g.add((entity_node, GUTPROP.text_span, Literal(cleaned_text_span, datatype=XSD.string)))
        
        #g.add((entity_node, GUTPROP.containedIn, paper_mention))
    
    
    if full_title is None and title_texts:
        full_title = " ".join(title_texts)
    if full_abstract is None and abstract_texts:
        full_abstract = " ".join(abstract_texts)
    
    if full_title:
        title_uri = URIRef(GUTBRAIN[f"title_{paper_id}"])
        g.add((title_uri, RDF.type, PAPER_TITLE))
        g.add((title_uri, GUTPROP.hasTitleText, Literal(full_title, datatype=XSD.string)))
        g.add((paper_uri, GUTPROP.hasTitle, title_uri))
    
    if full_abstract:
        abstract_uri = URIRef(GUTBRAIN[f"abstract_{paper_id}"])
        g.add((abstract_uri, RDF.type, PAPER_ABSTRACT))
        g.add((abstract_uri, GUTPROP.hasAbstractText, Literal(full_abstract, datatype=XSD.string)))
        g.add((paper_uri, GUTPROP.hasAbstract, abstract_uri))
    
    # Process relations
    #relations = paper_data.get("relations", [])
    #for relation in relations:
        #subj_text = relation.get("subject_text_span", "").strip()
        #cleaned_subj_text = re.sub(r'<[^>]*>', '', subj_text).strip()
        #subj_fragment = create_uri_fragment(cleaned_subj_text)
        #subj_uri = URIRef(GUTBRAIN[subj_fragment])
        #if not list(g.triples((subj_uri, None, None))):
           # print(f"Warning: Subject not recognized: {subj_uri}. Info: '{cleaned_subj_text}'")
        
        #obj_text = relation.get("object_text_span", "").strip()
        #cleaned_obj_text = re.sub(r'<[^>]*>', '', obj_text).strip()
        #obj_fragment = create_uri_fragment(cleaned_obj_text)
        #obj_uri = URIRef(GUTBRAIN[obj_fragment])
        #if not list(g.triples((obj_uri, None, None))):
            #print(f"Warning: Object not recognized: {obj_uri}. Info: '{cleaned_obj_text}'")
        
        #pred_text = relation.get("predicate", "").strip()
        #pred_text_clean = to_camel_case(pred_text)
        #pred_uri = URIRef(GUTPROP[pred_text_clean])
        #print(f"Predicate: '{pred_text}' -> '{pred_text_clean}'")
        #g.add((pred_uri, RDF.type, OWL.ObjectProperty))
        #g.add((pred_uri, RDFS.label, Literal(pred_text_clean, datatype=XSD.string)))
       # g.add((subj_uri, pred_uri, obj_uri))

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAIN[f"title_{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAIN[f"abstract_{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue # o None, se ti serve

        if label != "bacteria":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical)
        #print(cleaned_text_span)
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAIN[cleaned_text_span])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

        #entity_uri = URIRef(GUTBRAIN[canonical])
        #g.add((entity_uri, GUTPROP.containedIn, mention_node))
        #lit = Literal(ent_text, datatype=XSD.string)
        #if (mention_node, GUTPROP.hasMentionText, lit) not in g:
            #g.add((mention_node, GUTPROP.hasMentionText, lit))
print("\nDettaglio di tokenized_mentions:")
for canonical, mention_uri in tokenized_mentions.items():
    print(f"{canonical!r} → {mention_uri}")
# -----------------------------------------------------------------------------
# 7. Serialize and print the graph in Turtle format
# -----------------------------------------------------------------------------
output_file = os.path.join(save_path, "gutbrain_entities.ttl")
ttl_output = g.serialize(format="turtle")
with open(output_file, "w", encoding="utf-8") as f_out:
    f_out.write(ttl_output)

print(f"The RDF graph has been saved in {output_file}")
# Out:
# Query: Veillonella
#   • Veillonella                              ID=NCBITaxon_29465 depth=12 (exact)
#   • Veillonella                              ID=NCBITaxon_29465 depth=12 score=1.00
#
# Query: Roseburia
#   • Roseburia                                ID=NCBITaxon_841   depth=12 (exact)
#   • Roseburia                                ID=NCBITaxon_841   depth=12 score=1.00
#
# Query: Christensenellaceae R-7 group
#   • Christensenellaceae                      ID=NCBITaxon_990719 depth=10 score=0.87
#
# Query: Subdoligranulum
#   • Subdoligranulum                          ID=NCBITaxon_292632 depth=12 (exact)
#   • Subdoligranulum                          ID=NCBITaxon_292632 depth=12 score=1.00
#
# Query: Oscillibacter
#   • Oscillibacter                            ID=NCBITaxon_459786 depth=12 (exact)
#   • Oscillibacter                            ID=NCBITaxon_459786 depth=12 score=1.00
#
# Query: UCG-005
#   • Ruminococcaceae bacterium UCG-005        ID=NCBITaxon_3068309 depth=14 score=0.87
#
# Query: acetate-producing bacteria
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   scoreMESH=0.65
# Query: acetate-producing bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: bacteria
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  (exact)
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  score=1.00
#
# Query: oral bacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# Query: Lactobacillus plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.76
#
# Query: live and inactivated Lactobacillus plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.76
#
# Query: live L  plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#
# Query: live L  plantarum CCFM8661
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: inactivated L  plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#
# Query: live and inactivated L  plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#
# Query: Staphylococcus
#   • Staphylococcus                           ID=NCBITaxon_1279  depth=12 (exact)
#   • Staphylococcus                           ID=NCBITaxon_1279  depth=12 score=1.00
#
# Query: L  plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#
# Query: Lactobacillaceae
#   • Lactobacillaceae                         ID=NCBITaxon_33958 depth=10 (exact)
#   • Lactobacillaceae                         ID=NCBITaxon_33958 depth=10 score=1.00
#
# Query: Lachnospiraceae
#   • Lachnospiraceae                          ID=NCBITaxon_186803 depth=10 (exact)
#   • Lachnospiraceae                          ID=NCBITaxon_186803 depth=10 score=1.00
#
# Query: Lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Ruminococcaceae
#   • Ruminococcaceae bacterium enrichment culture ID=NCBITaxon_1776336 depth=14 score=0.80
#
# Query: Levilactobacillus brevis
#   • Levilactobacillus brevis                 ID=NCBITaxon_1580  depth=14 (exact)
#   • Levilactobacillus brevis                 ID=NCBITaxon_1580  depth=14 score=1.00
#
# Query: Lactiplantibacillus plantarum
#   • Lactiplantibacillus plantarum            ID=NCBITaxon_1590  depth=14 (exact)
#   • Lactiplantibacillus plantarum            ID=NCBITaxon_1590  depth=14 score=1.00
#
# Query: Lacticaseibacillus paracasei
#   • Lacticaseibacillus paracasei             ID=NCBITaxon_1597  depth=14 (exact)
#   • Lacticaseibacillus paracasei             ID=NCBITaxon_1597  depth=14 score=1.00
#
# Query: Ligilactobacillus salivarius
#   • Ligilactobacillus salivarius             ID=NCBITaxon_1624  depth=14 (exact)
#   • Ligilactobacillus salivarius             ID=NCBITaxon_1624  depth=14 score=1.00
#
# Query: Streptococcus thermophilus
#   • Streptococcus thermophilus               ID=NCBITaxon_1308  depth=14 (exact)
#   • Streptococcus thermophilus               ID=NCBITaxon_1308  depth=14 score=1.00
#
# Query: L  brevis P30021
#   • Paenibacillus brevis                     ID=NCBITaxon_2841508 depth=14 score=0.88
#
# Query: L  plantarum P30025
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#
# Query: Veillonellaceae
#   • Veillonellaceae                          ID=NCBITaxon_31977 depth=10 (exact)
#   • Veillonellaceae                          ID=NCBITaxon_31977 depth=10 score=1.00
#
# Query: Bacteroides
#   • Bacteroides                              ID=NCBITaxon_816   depth=16 (exact)
#   • Bacteroides                              ID=NCBITaxon_816   depth=16 score=1.00
#
# Query: Proteobacteria
#   • Proteobacteria                 UI=D020560  Tree=B03.660       scoreMESH=1.00
# Query: Succinivibrio
#   • Succinivibrio                            ID=NCBITaxon_83770 depth=12 (exact)
#   • Succinivibrio                            ID=NCBITaxon_83770 depth=12 score=1.00
#
# Query: Megasphaera
#   • Megasphaera                              ID=NCBITaxon_906   depth=12 (exact)
#   • Megasphaera                              ID=NCBITaxon_906   depth=12 score=1.00
#
# Query: Collinsella
#   • Collinsella                              ID=NCBITaxon_102106 depth=12 (exact)
#   • Collinsella                              ID=NCBITaxon_102106 depth=12 score=1.00
#
# Query: Clostridium
#   • Clostridium                              ID=NCBITaxon_1485  depth=12 (exact)
#   • Clostridium                              ID=NCBITaxon_1485  depth=12 score=1.00
#
# Query: Klebsiella
#   • Klebsiella                               ID=NCBITaxon_570   depth=14 (exact)
#   • Klebsiella                               ID=NCBITaxon_570   depth=14 score=1.00
#
# Query: Methanobrevibacter
#   • Brevibacterium                 UI=D001951  Tree=B03.510.024.175  scoreMESH=0.69
# Query: Blautia
#   • Blautia                                  ID=NCBITaxon_572511 depth=12 (exact)
#   • Blautia                                  ID=NCBITaxon_572511 depth=12 score=1.00
#
# Query: Coprococcus
#   • Coprococcus                              ID=NCBITaxon_33042 depth=12 (exact)
#   • Coprococcus                              ID=NCBITaxon_33042 depth=12 score=1.00
#
# Query: Roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lactobacillus
#   • Lactobacillus                            ID=NCBITaxon_1578  depth=12 (exact)
#   • Lactobacillus                            ID=NCBITaxon_1578  depth=12 score=1.00
#
# Query: L
# Query: plantarum P-8
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#
# Query: Bifidobacterium adolescentis
#   • Bifidobacterium adolescentis             ID=NCBITaxon_1680  depth=14 (exact)
#   • Bifidobacterium adolescentis             ID=NCBITaxon_1680  depth=14 score=1.00
#
# Query: Bifidobacterium longum
#   • Bifidobacterium longum                   ID=NCBITaxon_216816 depth=14 (exact)
#   • Bifidobacterium longum                   ID=NCBITaxon_216816 depth=14 score=1.00
#
# Query: Fecalibacterium prausnitzii
#   • Faecalibacterium prausnitzii             ID=NCBITaxon_853   depth=14 score=0.79
#
# Query: Roseburia faecis
#   • Roseburia faecis                         ID=NCBITaxon_301302 depth=14 (exact)
#   • Roseburia faecis                         ID=NCBITaxon_301302 depth=14 score=1.00
#
# Query: Fusicatenibacter saccharivorans
#   • Fusicatenibacter saccharivorans          ID=NCBITaxon_1150298 depth=14 (exact)
#   • Fusicatenibacter saccharivorans          ID=NCBITaxon_1150298 depth=14 score=1.00
#
# Query: Bacteroidaceae and Porphyromonadaceae families
#   • Bacteroidaceae                           ID=NCBITaxon_815   depth=14 score=0.76
#
# Query: Rikencellaceae
#   • Brucellaceae                   UI=D042021  Tree=B03.440.400.425.215  scoreMESH=0.77
# Query: S24-7
#   • bacterium S24                            ID=NCBITaxon_1315627 depth=4  score=0.97
#
# Query: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lactococcus
#   • Lactococcus                              ID=NCBITaxon_1357  depth=12 (exact)
#   • Lactococcus                              ID=NCBITaxon_1357  depth=12 score=1.00
#
# Query: Biffdobacterium
#   • Bifidobacterium                UI=D001644  Tree=B03.510.024.100  scoreMESH=0.93
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Biffdobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lactobacillus helveticus R0052
#   • Lactobacillus helveticus R0052           ID=NCBITaxon_880633 depth=16 (exact)
#   • Lactobacillus helveticus R0052           ID=NCBITaxon_880633 depth=16 score=1.00
#
# Query: Lactobacillus plantarum R1012
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.76
#
# Query: Bifidobacterium longum R0175
#   • Bifidobacterium longum                   ID=NCBITaxon_216816 depth=14 score=1.00
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lactobacillus species
#   • Actinobacillus suis            UI=D044132  Tree=B03.440.450.009.700  scoreMESH=0.80
# Query: Gut Bacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: Escherichia coli
#   • Escherichia coli                         ID=NCBITaxon_562   depth=14 (exact)
#   • Escherichia coli W                       ID=NCBITaxon_566546 depth=16 score=1.00
#
# Query: Enterobacter cloacae
#   • Enterobacter cloacae                     ID=NCBITaxon_550   depth=16 (exact)
#   • Enterobacter cloacae                     ID=NCBITaxon_550   depth=16 score=1.00
#
# Query: maternal vaginal microbes
#   • Gardnerella vaginalis          UI=D006194  Tree=B03.510.024.400.800  scoreMESH=0.61
# Query: Bifidobacteria
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D001644
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bifidobacterium
#   • Bifidobacterium                          ID=NCBITaxon_1678  depth=12 (exact)
#   • Bifidobacterium                          ID=NCBITaxon_1678  depth=12 score=1.00
#
# Query: Verrucomicrobiaceae
#   • Verrucomicrobiaceae                      ID=NCBITaxon_203557 depth=12 (exact)
#   • Verrucomicrobiaceae                      ID=NCBITaxon_203557 depth=12 score=1.00
#
# Query: Akkermansia
#   • Akkermansia                              ID=NCBITaxon_239934 depth=14 (exact)
#   • Akkermansia                              ID=NCBITaxon_239934 depth=14 score=1.00
#
# Query: Faecalibacterium
#   • Faecalibacterium                         ID=NCBITaxon_216851 depth=12 (exact)
#   • Faecalibacterium                         ID=NCBITaxon_216851 depth=12 score=1.00
#
# Query: Coprococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Prevotella
#   • Prevotella                               ID=NCBITaxon_838   depth=16 (exact)
#   • Prevotella                               ID=NCBITaxon_838   depth=16 score=1.00
#
# Query: Prevotellaceae
#   • Prevotellaceae                           ID=NCBITaxon_171552 depth=14 (exact)
#   • Prevotellaceae                           ID=NCBITaxon_171552 depth=14 score=1.00
#
# Query: Bacteroidetes
#   • Bacteroidetes bacterium 5-4              ID=NCBITaxon_226197 depth=12 score=0.93
#
# Query: Proteobacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Helicobacter pylori
#   • Helicobacter pylori                      ID=NCBITaxon_210   depth=14 (exact)
#   • Helicobacter pylori                      ID=NCBITaxon_210   depth=14 score=1.00
#
# Query: Bacteroidetes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Actinobacteria
#   • Actinobacteria bacterium HGW-Actinobacteria-9 ID=NCBITaxon_2013654 depth=8  score=0.87
#
# Query: Firmicutes
#   • Bacillus <firmicutes>                    ID=NCBITaxon_1386  depth=12 score=0.87
#
# Query: microbes
#   • Microbacterium                 UI=D000083822 Tree=B03.510.024.775  scoreMESH=0.64
# Query: firmicutes
#   • Bacillus <firmicutes>                    ID=NCBITaxon_1386  depth=12 score=0.87
#
# Query: coliform
#   • coliform bacterium S1/7                  ID=NCBITaxon_464824 depth=4  score=0.78
#
# Query: bacteroides
#   • Bacteroides                              ID=NCBITaxon_816   depth=16 (exact)
#   • Bacteroides                              ID=NCBITaxon_816   depth=16 score=1.00
#
# Query: firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: gut bacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: Toxoplasma gondii
#   • Mycoplasma genitalium          UI=D045704  Tree=B03.440.860.580.553.553.355  scoreMESH=0.63
# Query: Lachnospiraceae family
#   • Leptospiraceae                 UI=D016953  Tree=B03.440.400.425.475  scoreMESH=0.61
# Query: bifidobacterial populations
#   • Bifidobacterium pseudocatenulatum UI=D000070257 Tree=B03.510.024.100.750  scoreMESH=0.67
# Query: gut Bifidobacterium
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Akkermansias
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_239934
#
# Query: Desulfovibrio
#   • Desulfovibrio                            ID=NCBITaxon_872   depth=12 (exact)
#   • Desulfovibrio                            ID=NCBITaxon_872   depth=12 score=1.00
#
# Query: Klebsiella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lactobacillus plantarum
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.76
#
# Query: GABA-producing bacteria
#   • Sulfur-Reducing Bacteria       UI=D016999  Tree=B03.900       scoreMESH=0.72
# Query: Lactobacillus plantarum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Odoribacter
#   • Odoribacter                              ID=NCBITaxon_283168 depth=16 (exact)
#   • Odoribacter                              ID=NCBITaxon_283168 depth=16 score=1.00
#
# Query: Oscillibacter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bifidobacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Clostridium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lachnospiraceae NK4A136 group
#   • Lachnospiraceae bacterium NK4A136        ID=NCBITaxon_877420 depth=14 score=0.90
#
# Query: Subdoligranulum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Faecalibacterium prausnitzii
#   • Faecalibacterium prausnitzii             ID=NCBITaxon_853   depth=14 (exact)
#   • Faecalibacterium prausnitzii             ID=NCBITaxon_853   depth=14 score=1.00
#
# Query: Corynebacterium
#   • Corynebacterium                          ID=NCBITaxon_1716  depth=12 (exact)
#   • Corynebacterium                          ID=NCBITaxon_1716  depth=12 score=1.00
#
# Query: Ruminococcaceae Incertae Sedis
#   • uncultured incertae sedis 5 bacterium    ID=NCBITaxon_412050 depth=4  score=0.77
#
# Query: Fusobacterium
#   • Fusobacterium                            ID=NCBITaxon_848   depth=12 (exact)
#   • Fusobacterium                            ID=NCBITaxon_848   depth=12 score=1.00
#
# Query: Corynebacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Ruminococcaceae Incertae Sedis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: microorganisms
# Query: intestinal bacteria
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D039903
#
# Query: Verrucomicrobia
#   • Verrucomicrobia bacterium B-1-8          ID=NCBITaxon_747582 depth=10 score=0.94
#
# Query: Mucispirillum
#   • Mucispirillum                            ID=NCBITaxon_248038 depth=12 (exact)
#   • Mucispirillum                            ID=NCBITaxon_248038 depth=12 score=1.00
#
# Query: Porphyromonas
#   • Porphyromonas                            ID=NCBITaxon_836   depth=16 (exact)
#   • Porphyromonas                            ID=NCBITaxon_836   depth=16 score=1.00
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Parabacteroides
#   • Parabacteroides                          ID=NCBITaxon_375288 depth=16 (exact)
#   • Parabacteroides                          ID=NCBITaxon_375288 depth=16 score=1.00
#
# Query: Prevotella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Verrucomicrobia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lactobacillus fermentum PS150
#   • Limosilactobacillus fermentum  UI=D052197  Tree=B03.353.750.450.672  scoreMESH=0.79
# Query: hypnotic psychobiotic strain
# Query: Psychobiotics
#   • Synechocystis                  UI=D046939  Tree=B03.280.750   scoreMESH=0.62
# Query: probiotics
# Query: psychobiotic strain
# Query: Lactobacillus fermentum PS150
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: PS150
# Query: L  fermentum strain
# Query: GR1009
# Query: PS150
# Query: GR1009
# Query: PS150
# Query: PS150
# Query: GR1009
# Query: heat-killed PS150
# Query: GR1009
# Query: PS150
# Query: PS150
# Query: GR1009
# Query: PS150
# Query: GR1009
# Query: GR1009
# Query: PS150
# Query: PS150
# Query: PS150
# Query: GR1009
# Query: EC Ruminococcus torques
#   • [Ruminococcus] torques                   ID=NCBITaxon_33039 depth=14 score=0.83
#
# Query: Coprococcus comes
#   • Coprococcus comes                        ID=NCBITaxon_410072 depth=14 (exact)
#   • Coprococcus comes                        ID=NCBITaxon_410072 depth=14 score=1.00
#
# Query: Megasphaera elsdenii
#   • Megasphaera elsdenii                     ID=NCBITaxon_907   depth=14 (exact)
#   • Megasphaera elsdenii                     ID=NCBITaxon_907   depth=14 score=1.00
#
# Query: Acidaminococcus intestini
#   • Acidaminococcus intestini                ID=NCBITaxon_187327 depth=14 (exact)
#   • Acidaminococcus intestini                ID=NCBITaxon_187327 depth=14 score=1.00
#
# Query: Barnesiella viscericola
#   • Barnesiella viscericola                  ID=NCBITaxon_397865 depth=18 (exact)
#   • Barnesiella viscericola                  ID=NCBITaxon_397865 depth=18 score=1.00
#
# Query: Bacteroides eggerthii
#   • Bacteroides eggerthii                    ID=NCBITaxon_28111 depth=18 (exact)
#   • Bacteroides eggerthii                    ID=NCBITaxon_28111 depth=18 score=1.00
#
# Query: Gut Bacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: Gut bacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: mucus-associated species
# Query: Desulfovibrionaceae
#   • Desulfovibrionaceae                      ID=NCBITaxon_194924 depth=10 (exact)
#   • Desulfovibrionaceae                      ID=NCBITaxon_194924 depth=10 score=1.00
#
# Query: Enterobacteriaceae
#   • Enterobacteriaceae                       ID=NCBITaxon_543   depth=10 (exact)
#   • Enterobacteriaceae                       ID=NCBITaxon_543   depth=10 score=1.00
#
# Query: Turicibacter
#   • Turicibacter                             ID=NCBITaxon_191303 depth=12 (exact)
#   • Turicibacter                             ID=NCBITaxon_191303 depth=12 score=1.00
#
# Query: Coprococcus 1
#   • Coprococcus                              ID=NCBITaxon_33042 depth=12 score=1.00
#
# Query: Lachnospiraceae FCS020 group
#   • bacterium FCS020                         ID=NCBITaxon_1451755 depth=4  score=0.78
#
# Query: Eggerthellaceae
#   • Eggerthellaceae                          ID=NCBITaxon_1643826 depth=10 (exact)
#   • Eggerthellaceae                          ID=NCBITaxon_1643826 depth=10 score=1.00
#
# Query: Turicibacter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Coprococcus 1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Eggerthellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Clostridium sp  BR31
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1485
#
# Query: Turicibacter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Coprococcus 1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Eggerthellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Clostridium sp  BR31
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1485
#
# Query: Bacteroidetes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Actinobacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lactobacillus reuteri NK33
#   • Limosilactobacillus reuteri    UI=D052200  Tree=B03.353.750.450.705  scoreMESH=0.79
# Query: Bifidobacterium adolescentis NK98
#   • Bifidobacterium adolescentis             ID=NCBITaxon_1680  depth=14 score=1.00
#
# Query: Bifidobacteriaceae
#   • Bifidobacteriaceae                       ID=NCBITaxon_31953 depth=10 (exact)
#   • Bifidobacteriaceae                       ID=NCBITaxon_31953 depth=10 score=1.00
#
# Query: Lactobacillacea
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_33958
#
# Query: Enterobacteriaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Odoribacter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: cancer-related bacteria
#   • Gram-Negative Bacteria         UI=D006090  Tree=B03.440       scoreMESH=0.67
# Query: Helicobacter
#   • Helicobacter                             ID=NCBITaxon_209   depth=12 (exact)
#   • Helicobacter                             ID=NCBITaxon_209   depth=12 score=1.00
#
# Query: Lactococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Alloprevotella
#   • Alloprevotella                           ID=NCBITaxon_1283313 depth=16 (exact)
#   • Alloprevotella                           ID=NCBITaxon_1283313 depth=16 score=1.00
#
# Query: imbalance-inducing bacteria
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D016999
#
# Query: Escherichia-Shigella
#   • Escherichia/Shigella sp.                 ID=NCBITaxon_1940338 depth=14 score=0.99
#
# Query: Parabacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: butyrate-producing bacteria
#   • butyrate-producing bacterium             ID=NCBITaxon_2811711 depth=4  score=0.89
#
# Query: Ruminococcaceae UCG-014
#   • Micrococcaceae                 UI=D008835  Tree=B03.510.024.850  scoreMESH=0.65
# Query: Lactobacillus reuteri ATG-F4
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D052200
#
# Query: Lactobacillus reuteri ATG-F4
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D052200
#
# Query: F4
#   • Bacillus sp. F4-1                        ID=NCBITaxon_489169 depth=16 score=0.92
#
# Query: F4
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: F4
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: F4
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: short-chain fatty acid producing bacteria
# Query: gut-resident bacteria
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D016999
#
# Query: dysregulated bacteria
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  score=1.00
#
# Query: Fusobacterium nucleatum
#   • Fusobacterium nucleatum                  ID=NCBITaxon_851   depth=14 (exact)
#   • Fusobacterium nucleatum                  ID=NCBITaxon_851   depth=14 score=1.00
#
# Query: bifidobacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Actinobacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Intestinal bacteria
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D039903
#
# Query: short-chain fatty acid  SCFA -producing bacteria
# Query: Lachnospira
#   • Lachnospira                              ID=NCBITaxon_28050 depth=12 (exact)
#   • Lachnospira                              ID=NCBITaxon_28050 depth=12 score=1.00
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Acute chronic insomnia-related signature bacteria
# Query: Negativicutes
#   • Negativicutes                            ID=NCBITaxon_909932 depth=6  (exact)
#   • Negativicutes                            ID=NCBITaxon_909932 depth=6  score=1.00
#
# Query: Clostridiuminnocuumgroup
#   • Clostridium septicum           UI=D052557  Tree=B03.300.390.400.200.690  scoreMESH=0.68
# Query: Dorea
#   • Dorea                                    ID=NCBITaxon_189330 depth=12 (exact)
#   • Dorea                                    ID=NCBITaxon_189330 depth=12 score=1.00
#
# Query: Lachnoclostridium
#   • Lachnoclostridium                        ID=NCBITaxon_1506553 depth=12 (exact)
#   • Lachnoclostridium                        ID=NCBITaxon_1506553 depth=12 score=1.00
#
# Query: Prevotella7
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_838
#
# Query: Selenomonadalesare
#   • Selenomonas                    UI=D020357  Tree=B03.440.425.410.800.877  scoreMESH=0.76
# Query: gut bacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: Bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Prevotella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Megamonas
#   • Megamonas                                ID=NCBITaxon_158846 depth=12 (exact)
#   • Megamonas                                ID=NCBITaxon_158846 depth=12 score=1.00
#
# Query: Faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Synergistetes
#   • Synergistetes bacterium HGW-Synergistetes-1 ID=NCBITaxon_2013842 depth=8  score=0.91
#
# Query: Proteobacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: olidextribacter
#   • Liberibacter                   UI=D000086202 Tree=B03.660.050.662.347  scoreMESH=0.81
# Query: Intestinibacter
#   • Intestinibacter                          ID=NCBITaxon_1505657 depth=12 (exact)
#   • Intestinibacter                          ID=NCBITaxon_1505657 depth=12 score=1.00
#
# Query: Kineothrix
#   • Kineothrix                               ID=NCBITaxon_2163168 depth=12 (exact)
#   • Kineothrix                               ID=NCBITaxon_2163168 depth=12 score=1.00
#
# Query: Agathobaculum
#   • Agathobaculum                            ID=NCBITaxon_2048137 depth=12 (exact)
#   • Agathobaculum                            ID=NCBITaxon_2048137 depth=12 score=1.00
#
# Query: Roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Prevotella species
#   • Prevotella nigrescens          UI=D045242  Tree=B03.440.080.094.640.550  scoreMESH=0.72
# Query: Actinobacteriota
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D039903
#
# Query: Bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Verrucomicrobiota
#   • Verrucomicrobiota                        ID=NCBITaxon_74201 depth=6  (exact)
#   • Verrucomicrobiota                        ID=NCBITaxon_74201 depth=6  score=1.00
#
# Query: Akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Enterococcus
#   • Enterococcus                             ID=NCBITaxon_1350  depth=12 (exact)
#   • Enterococcus                             ID=NCBITaxon_1350  depth=12 score=1.00
#
# Query: Hungatella
#   • Hungatella                               ID=NCBITaxon_1649459 depth=12 (exact)
#   • Hungatella                               ID=NCBITaxon_1649459 depth=12 score=1.00
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Oscillospira
#   • Oscillospira                             ID=NCBITaxon_119852 depth=12 (exact)
#   • Oscillospira                             ID=NCBITaxon_119852 depth=12 score=1.00
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Ruminococcaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bacteroidetes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Proteobacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Coprococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Verrucomicrobiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Akkermansia muciniphila
#   • Akkermansia muciniphila                  ID=NCBITaxon_239935 depth=16 (exact)
#   • Akkermansia muciniphila                  ID=NCBITaxon_239935 depth=16 score=1.00
#
# Query: Verrucomicrobiaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Verrucomicrobiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lactobacillaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Barnesiellaceae
#   • Barnesiellaceae                          ID=NCBITaxon_2005519 depth=14 (exact)
#   • Barnesiellaceae                          ID=NCBITaxon_2005519 depth=14 score=1.00
#
# Query: Bacteroidetes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Actinobacteriota
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D039903
#
# Query: Bilophila wadsworthia
#   • Bilophila wadsworthia                    ID=NCBITaxon_35833 depth=14 (exact)
#   • Bilophila wadsworthia                    ID=NCBITaxon_35833 depth=14 score=1.00
#
# Query: Thermodesulfobacteriota
#   • Thermodesulfobacteriota                  ID=NCBITaxon_200940 depth=4  (exact)
#   • Thermodesulfobacteriota                  ID=NCBITaxon_200940 depth=4  score=1.00
#
# Query: Prevotella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bacteroidetes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Verrucomicrobiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bifidobacteriaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Coriobacteriaceae
#   • Coriobacteriaceae                        ID=NCBITaxon_84107 depth=10 (exact)
#   • Coriobacteriaceae                        ID=NCBITaxon_84107 depth=10 score=1.00
#
# Query: Actinobacteriota
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D039903
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Christensenellaceae
#   • Christensenellaceae                      ID=NCBITaxon_990719 depth=10 (exact)
#   • Christensenellaceae                      ID=NCBITaxon_990719 depth=10 score=1.00
#
# Query: Lactobacillaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Enterococcaceae
#   • Enterococcaceae                          ID=NCBITaxon_81852 depth=10 (exact)
#   • Enterococcaceae                          ID=NCBITaxon_81852 depth=10 score=1.00
#
# Query: Enterococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lactococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Oscillospira
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Proteobacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Enterobacteriaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Citrobacter
#   • Citrobacter                              ID=NCBITaxon_544   depth=12 (exact)
#   • Citrobacter                              ID=NCBITaxon_544   depth=12 score=1.00
#
# Query: Klebsiella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Salmonella
#   • Salmonella                               ID=NCBITaxon_590   depth=12 (exact)
#   • Salmonella                               ID=NCBITaxon_590   depth=12 score=1.00
#
# Query: Shigella
#   • Shigella                                 ID=NCBITaxon_620   depth=12 (exact)
#   • Shigella                                 ID=NCBITaxon_620   depth=12 score=1.00
#
# Query: ParaBacteroides
#   • Parabacteroides                          ID=NCBITaxon_375288 depth=16 (exact)
#   • Parabacteroides                          ID=NCBITaxon_375288 depth=16 score=1.00
#
# Query: Bacteroidetes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Ruminococcus
#   • Ruminococcus                             ID=NCBITaxon_1263  depth=12 (exact)
#   • Ruminococcus                             ID=NCBITaxon_1263  depth=12 score=1.00
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Muribaculaceae
#   • Muribaculaceae                           ID=NCBITaxon_2005473 depth=14 (exact)
#   • Muribaculaceae                           ID=NCBITaxon_2005473 depth=14 score=1.00
#
# Query: Faecalibaculum
#   • Faecalibaculum                           ID=NCBITaxon_1729679 depth=12 (exact)
#   • Faecalibaculum                           ID=NCBITaxon_1729679 depth=12 score=1.00
#
# Query: Flavonifractor
#   • Flavonifractor                           ID=NCBITaxon_946234 depth=12 (exact)
#   • Flavonifractor                           ID=NCBITaxon_946234 depth=12 score=1.00
#
# Query: Christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: gut Flavonifractor genus
# Query: gut Christensenellaceae family
# Query: Flavonifractor
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Flavonifractor
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Flavonifractor
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Flavonifractor
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Flavonifractor
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: genus Ruminococcaceae
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_81852
#
# Query: UCG009
# Query: genus Subdoligranulum
#   • Subdoligranulum                          ID=NCBITaxon_292632 depth=12 score=0.86
#
# Query: Family Ruminococcaceae
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D008835
#
# Query: genus Coprococcus2
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1350
#
# Query: genus Eggerthella
#   • Eggerthella                              ID=NCBITaxon_84111 depth=12 score=0.85
#
# Query: genus Eubacterium
#   • Eubacterium                    UI=D005051  Tree=B03.353.625.750  scoreMESH=0.79
# Query: xylanophilum group
#   • Eubacterium xylanophilum                 ID=NCBITaxon_39497 depth=14 score=0.79
#
# Query: predominant bacteria
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  score=1.00
#
# Query: Ruminococcaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Ruminococcaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Ruminococcaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Ruminococcaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Ruminococcaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: gut bacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: Lachnoclostridium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lachnostridium
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1485
#
# Query: Lachnoclostridium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Parabacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Anaerostipes
#   • Anaerostipes                             ID=NCBITaxon_207244 depth=12 (exact)
#   • Anaerostipes                             ID=NCBITaxon_207244 depth=12 score=1.00
#
# Query: Ruminococcus-2
#   • Ruminococcus                             ID=NCBITaxon_1263  depth=12 score=1.00
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Akkermansia muciniphila
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Akkermansia muciniphila
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Listeria monocytogenes
#   • Listeria monocytogenes                   ID=NCBITaxon_1639  depth=14 (exact)
#   • Listeria monocytogenes                   ID=NCBITaxon_1639  depth=14 score=1.00
#
# Query: Haemophilus
#   • Haemophilus                              ID=NCBITaxon_724   depth=12 (exact)
#   • Haemophilus                              ID=NCBITaxon_724   depth=12 score=1.00
#
# Query: Haemophilu
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_724
#
# Query: Coprococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Haemophilus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lachnospira
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Prevotella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Streptococcus
#   • Streptococcus                            ID=NCBITaxon_1301  depth=12 (exact)
#   • Streptococcus                            ID=NCBITaxon_1301  depth=12 score=1.00
#
# Query: Bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Desulfovibrio
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: psychobiotics
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D046939
#
# Query: psychobiotics
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D046939
#
# Query: Bacteroides uniformis
#   • Bacteroides uniformis                    ID=NCBITaxon_820   depth=18 (exact)
#   • Bacteroides uniformis                    ID=NCBITaxon_820   depth=18 score=1.00
#
# Query: Roseburia inulinivorans
#   • Roseburia inulinivorans                  ID=NCBITaxon_360807 depth=14 (exact)
#   • Roseburia inulinivorans                  ID=NCBITaxon_360807 depth=14 score=1.00
#
# Query: Eubacterium rectale
#   • Treponema rectale                        ID=NCBITaxon_744512 depth=14 score=0.78
#
# Query: Faecalibacterium prausnitzii
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: psychobiotics
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D046939
#
# Query: phylum Proteobacteria
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D020560
#
# Query: Enterobacteriaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: coliform genera
# Query: Escherichia
#   • Escherichia                              ID=NCBITaxon_561   depth=12 (exact)
#   • Escherichia                              ID=NCBITaxon_561   depth=12 score=1.00
#
# Query: Klebsiella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Klebsiella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Clostridium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bilophila
#   • Bilophila                                ID=NCBITaxon_35832 depth=12 (exact)
#   • Bilophila                                ID=NCBITaxon_35832 depth=12 score=1.00
#
# Query: Escherichia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Enterococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lachnospiraceae Incertae Sedis
#   • Lachnospiraceae incertae sedis           ID=NCBITaxon_2840493 depth=12 (exact)
#   • Lachnospiraceae incertae sedis           ID=NCBITaxon_2840493 depth=12 score=1.00
#
# Query: Barnesiella
#   • Barnesiella                              ID=NCBITaxon_397864 depth=16 (exact)
#   • Barnesiella                              ID=NCBITaxon_397864 depth=16 score=1.00
#
# Query: Romboutsia
#   • Romboutsia                               ID=NCBITaxon_1501226 depth=12 (exact)
#   • Romboutsia                               ID=NCBITaxon_1501226 depth=12 score=1.00
#
# Query: A  muciniphila
#   • Akkermansia muciniphila                  ID=NCBITaxon_239935 depth=16 score=0.80
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bifidobacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Prevotella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bifidobacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Lactobacilli
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: Bacteroides genus
#   • Bacteroides                              ID=NCBITaxon_816   depth=16 score=0.77
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bacteroidetes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lachnospiraceae g
#   • Lachnospiraceae                          ID=NCBITaxon_186803 depth=10 score=1.00
#
# Query: Ruminococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Megamonas
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Prevotellaceae NK3B31
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_838
#
# Query: butyrate-producing bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Lachnospira
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Subdoligranulum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Dialister
#   • Dialister                                ID=NCBITaxon_39948 depth=12 (exact)
#   • Dialister                                ID=NCBITaxon_39948 depth=12 score=1.00
#
# Query: acetate-producing bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: Streptococcus
# ...
# 'Lactobacillus_helveticus_R0052' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lactobacillus_helveticus_R0052
# 'Lactobacillus_plantarum_R1012' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lactobacillus_plantarum_R1012
# 'Bifidobacterium_longum_R0175' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Bifidobacterium_longum_R0175
# 'Lactobacillus_species' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lactobacillus_species
# 'Escherichia_coli' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Escherichia_coli
# 'Enterobacter_cloacae' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Enterobacter_cloacae
# 'maternal_vaginal_microbes' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/maternal_vaginal_microbes
# 'Bifidobacterium' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Bifidobacterium
# 'Verrucomicrobiaceae' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Verrucomicrobiaceae
# 'Akkermansia' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Akkermansia
# 'Faecalibacterium' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Faecalibacterium
# 'Prevotella' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Prevotella
# 'Prevotellaceae' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Prevotellaceae
# 'Bacteroidetes' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Bacteroidetes
# 'Helicobacter_pylori' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Helicobacter_pylori
# 'Actinobacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Actinobacteria
# 'Firmicutes' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Firmicutes
# 'microbes' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/microbes
# 'firmicutes' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/firmicutes
# 'coliform' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/coliform
# 'bacteroides' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/bacteroides
# 'Toxoplasma_gondii' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Toxoplasma_gondii
# 'Lachnospiraceae_family' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lachnospiraceae_family
# 'bifidobacterial_populations' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/bifidobacterial_populations
# 'Desulfovibrio' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Desulfovibrio
# 'Lactobacillus_plantarum' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lactobacillus_plantarum
# 'GABA-producing_bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/GABA-producing_bacteria
# 'Odoribacter' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Odoribacter
# 'Lachnospiraceae_NK4A136_group' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lachnospiraceae_NK4A136_group
# 'Faecalibacterium_prausnitzii' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Faecalibacterium_prausnitzii
# 'Corynebacterium' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Corynebacterium
# 'Ruminococcaceae_Incertae_Sedis' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Ruminococcaceae_Incertae_Sedis
# 'Fusobacterium' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Fusobacterium
# 'microorganisms' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/microorganisms
# 'Verrucomicrobia' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Verrucomicrobia
# 'Mucispirillum' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Mucispirillum
# 'Porphyromonas' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Porphyromonas
# 'Parabacteroides' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Parabacteroides
# 'Lactobacillus_fermentum_PS150' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lactobacillus_fermentum_PS150
# 'hypnotic_psychobiotic_strain' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/hypnotic_psychobiotic_strain
# 'Psychobiotics' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Psychobiotics
# 'probiotics' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/probiotics
# 'psychobiotic_strain' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/psychobiotic_strain
# 'PS150' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/PS150
# 'L__fermentum_strain' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/L__fermentum_strain
# 'GR1009' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/GR1009
# 'heat-killed_PS150' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/heat-killed_PS150
# 'EC_Ruminococcus_torques' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/EC_Ruminococcus_torques
# 'Coprococcus_comes' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Coprococcus_comes
# 'Megasphaera_elsdenii' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Megasphaera_elsdenii
# 'Acidaminococcus_intestini' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Acidaminococcus_intestini
# 'Barnesiella_viscericola' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Barnesiella_viscericola
# 'Bacteroides_eggerthii' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Bacteroides_eggerthii
# 'mucus-associated_species' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/mucus-associated_species
# 'Desulfovibrionaceae' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Desulfovibrionaceae
# 'Enterobacteriaceae' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Enterobacteriaceae
# 'Turicibacter' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Turicibacter
# 'Coprococcus_1' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Coprococcus_1
# 'Lachnospiraceae_FCS020_group' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lachnospiraceae_FCS020_group
# 'Eggerthellaceae' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Eggerthellaceae
# 'Lactobacillus_reuteri_NK33' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lactobacillus_reuteri_NK33
# 'Bifidobacterium_adolescentis_NK98' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Bifidobacterium_adolescentis_NK98
# 'Bifidobacteriaceae' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Bifidobacteriaceae
# 'cancer-related_bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/cancer-related_bacteria
# 'Helicobacter' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Helicobacter
# 'Alloprevotella' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Alloprevotella
# 'Escherichia-Shigella' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Escherichia-Shigella
# 'butyrate-producing_bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/butyrate-producing_bacteria
# 'Ruminococcaceae_UCG-014' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Ruminococcaceae_UCG-014
# 'F4' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/F4
# 'short-chain_fatty_acid_producing_bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/short-chain_fatty_acid_producing_bacteria
# 'dysregulated_bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/dysregulated_bacteria
# 'Fusobacterium_nucleatum' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Fusobacterium_nucleatum
# 'short-chain_fatty_acid__SCFA_-producing_bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/short-chain_fatty_acid__SCFA_-producing_bacteria
# 'Lachnospira' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lachnospira
# 'Acute_chronic_insomnia-related_signature_bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Acute_chronic_insomnia-related_signature_bacteria
# 'Negativicutes' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Negativicutes
# 'Clostridiuminnocuumgroup' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Clostridiuminnocuumgroup
# 'Dorea' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Dorea
# 'Lachnoclostridium' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lachnoclostridium
# 'Selenomonadalesare' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Selenomonadalesare
# 'Megamonas' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Megamonas
# 'Synergistetes' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Synergistetes
# 'olidextribacter' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/olidextribacter
# 'Intestinibacter' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Intestinibacter
# 'Kineothrix' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Kineothrix
# 'Agathobaculum' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Agathobaculum
# 'Prevotella_species' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Prevotella_species
# 'Verrucomicrobiota' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Verrucomicrobiota
# 'Enterococcus' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Enterococcus
# 'Hungatella' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Hungatella
# 'Oscillospira' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Oscillospira
# 'Akkermansia_muciniphila' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Akkermansia_muciniphila
# 'Barnesiellaceae' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Barnesiellaceae
# 'Bilophila_wadsworthia' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Bilophila_wadsworthia
# 'Thermodesulfobacteriota' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Thermodesulfobacteriota
# 'Coriobacteriaceae' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Coriobacteriaceae
# 'Christensenellaceae' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Christensenellaceae
# 'Enterococcaceae' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Enterococcaceae
# 'Citrobacter' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Citrobacter
# 'Salmonella' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Salmonella
# 'Shigella' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Shigella
# 'ParaBacteroides' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/ParaBacteroides
# 'Ruminococcus' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Ruminococcus
# 'Muribaculaceae' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Muribaculaceae
# 'Faecalibaculum' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Faecalibaculum
# 'Flavonifractor' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Flavonifractor
# 'gut_Flavonifractor_genus' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/gut_Flavonifractor_genus
# 'gut_Christensenellaceae_family' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/gut_Christensenellaceae_family
# 'UCG009' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/UCG009
# 'genus_Subdoligranulum' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/genus_Subdoligranulum
# 'genus_Eggerthella' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/genus_Eggerthella
# 'genus_Eubacterium' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/genus_Eubacterium
# 'xylanophilum_group' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/xylanophilum_group
# 'predominant_bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/predominant_bacteria
# 'Anaerostipes' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Anaerostipes
# 'Ruminococcus-2' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Ruminococcus-2
# 'Listeria_monocytogenes' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Listeria_monocytogenes
# 'Haemophilus' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Haemophilus
# 'Streptococcus' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Streptococcus
# 'Bacteroides_uniformis' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Bacteroides_uniformis
# 'Roseburia_inulinivorans' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Roseburia_inulinivorans
# 'Eubacterium_rectale' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Eubacterium_rectale
# 'coliform_genera' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/coliform_genera
# 'Escherichia' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Escherichia
# 'Bilophila' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Bilophila
# 'Lachnospiraceae_Incertae_Sedis' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lachnospiraceae_Incertae_Sedis
# 'Barnesiella' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Barnesiella
# 'Romboutsia' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Romboutsia
# 'A__muciniphila' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/A__muciniphila
# 'Bacteroides_genus' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Bacteroides_genus
# 'Lachnospiraceae_g' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lachnospiraceae_g
# 'Dialister' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Dialister
# 'Parasutterella' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Parasutterella
# 'oral_bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/oral_bacteria
# 'Gut_Bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Gut_Bacteria
# 'Bifidobacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Bifidobacteria
# 'gut_bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/gut_bacteria
# 'gut_Bifidobacterium' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/gut_Bifidobacterium
# 'Akkermansias' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Akkermansias
# 'intestinal_bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/intestinal_bacteria
# 'Gut_bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Gut_bacteria
# 'Lactobacillacea' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lactobacillacea
# 'imbalance-inducing_bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/imbalance-inducing_bacteria
# 'Lactobacillus_reuteri_ATG-F4' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lactobacillus_reuteri_ATG-F4
# 'gut-resident_bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/gut-resident_bacteria
# 'bifidobacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/bifidobacteria
# 'Intestinal_bacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Intestinal_bacteria
# 'Prevotella7' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Prevotella7
# 'Actinobacteriota' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Actinobacteriota
# 'genus_Ruminococcaceae' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/genus_Ruminococcaceae
# 'Family_Ruminococcaceae' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Family_Ruminococcaceae
# 'genus_Coprococcus2' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/genus_Coprococcus2
# 'Lachnostridium' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lachnostridium
# 'Haemophilu' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Haemophilu
# 'psychobiotics' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/psychobiotics
# 'phylum_Proteobacteria' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/phylum_Proteobacteria
# 'Lactobacilli' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Lactobacilli
# 'Prevotellaceae_NK3B31' → https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Prevotellaceae_NK3B31
# The RDF graph has been saved in C:\Users\samue\OneDrive\Desktop\ThesisPiron\rdf\gutbrain_entities.ttl

# %%
from rdflib.namespace import RDFS

def labels_equal(uri1, uri2, graph):
    # Estrae tutti i label di uri1 e uri2
    labels1 = [str(lbl) for lbl in graph.objects(uri1, RDFS.label)]
    labels2 = [str(lbl) for lbl in graph.objects(uri2, RDFS.label)]
    # Confronta ogni coppia
    return any(l1 == l2 for l1 in labels1 for l2 in labels2)

# Esempio di utilizzo:
ncbi_uri = URIRef(f"{OBO_BASE}NCBITaxon_239934")       # l'individual da NCBITaxon
mesh_uri = URIRef(f"{MESH_BASE}D000086102")          # sostituisci con il tuo UI MeSH per Clostridium

if labels_equal(ncbi_uri, mesh_uri, g):
    print("I label coincidono!")
else:
    print("I label sono diversi.")
# Out:
# I label coincidono!

# %%
# Funzione per contare le righe che iniziano con "Query:" in un file di testo
def count_queries(file_path):
    """
    Conta il numero di righe che iniziano con 'Query:' in un file.
    
    Args:
        file_path (str): Percorso del file di testo da analizzare.
    
    Returns:
        int: Numero di query trovate.
    """
    count = 0
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            if line.lstrip().startswith("Query:"):
                count += 1
    return count

# Sostituisci con i percorsi dei tuoi file
file1 = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\file1.txt"
file2 = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\file2.txt"

n1 = count_queries(file1)
n2 = count_queries(file2)

print(f"{file1}: {n1} query")
print(f"{file2}: {n2} query")

if n1 == n2:
    print("⚖️ I due file hanno lo stesso numero di query.")
else:
    print("❌ I due file hanno un numero diverso di query.")
# Out:
# C:\Users\samue\OneDrive\Desktop\ThesisPiron\file1.txt: 210 query
# C:\Users\samue\OneDrive\Desktop\ThesisPiron\file2.txt: 416 query
# ❌ I due file hanno un numero diverso di query.
