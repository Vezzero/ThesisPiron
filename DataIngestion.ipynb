# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\samue\appdata\roaming\python\python312\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\samue\appdata\roaming\python\python312\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\samue\appdata\roaming\python\python312\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\samue\appdata\roaming\python\python312\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\python312\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\samue\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)
# WARNING: Ignoring invalid distribution ~ (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (C:\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import xml.etree.ElementTree as ET
from difflib import SequenceMatcher, get_close_matches

def parse_mesh_descriptors(xml_path):
    """Parse the MeSH XML and return a list of descriptors."""
    tree = ET.parse(xml_path)
    root = tree.getroot()
    descriptors = []
    for dr in root.findall('DescriptorRecord'):
        ui_el   = dr.find('DescriptorUI')
        name_el = dr.find('DescriptorName/String')
        if ui_el is None or name_el is None:
            continue
        ui   = ui_el.text
        name = name_el.text
        tree_nums = [tn.text for tn in dr.findall('TreeNumberList/TreeNumber') if tn.text]
        descriptors.append({'ui':ui, 'name':name, 'tree_numbers':tree_nums})
    return descriptors

MESH_XML = 'desc2025.xml'
descriptors = parse_mesh_descriptors(MESH_XML)
print(f"Parsed {len(descriptors)} descriptors")
# Out:
# Parsed 30956 descriptors

# %%
def get_bacteria_taxonomy(descriptors):
    """
    Find the descriptor with name 'Bacteria', 
    then collect every descriptor under that tree-number prefix.
    """
    prefix = None #bacteria is B03
    for d in descriptors:
        if d['name'].lower() == 'bacteria' and d['tree_numbers']:
            prefix = d['tree_numbers'][0]
            break
    if not prefix:
        raise RuntimeError("Could not find 'Bacteria' in descriptors")
    tax = {}
    for d in descriptors:
        for tn in d['tree_numbers']:
            if tn == prefix or tn.startswith(prefix + '.'):
                tax[tn] = {'ui':d['ui'], 'name':d['name']}
                break
    return tax

bacteria_tax = get_bacteria_taxonomy(descriptors)
#print(f"{len(bacteria_tax)} bacterial MeSH nodes")

# %%
def build_name_index(taxonomy):
    """
    Build a dict: lower-case name -> list of (tree#, ui, canonical name)
    """
    idx = {}
    for tree_num, info in taxonomy.items():
        key = info['name'].lower()
        idx.setdefault(key, []).append((tree_num, info['ui'], info['name']))
    return idx

name_index = build_name_index(bacteria_tax)
print(f"Indexed {len(name_index)} bacterial names")
# Out:
# Indexed 859 bacterial names

# %%
import xml.etree.ElementTree as ET

def parse_mesh_descriptors(xml_path):
    """
    Parse the MeSH XML and return a list of dicts:
      { 'ui': DescriptorUI,
        'name': DescriptorName,
        'tree_numbers': [treeNum1, treeNum2, ...]
      }
    """
    tree = ET.parse(xml_path)
    root = tree.getroot()
    descriptors = []
    for dr in root.findall('DescriptorRecord'):
        ui_el = dr.find('DescriptorUI')
        name_el = dr.find('DescriptorName/String')
        if ui_el is None or name_el is None:
            continue
        ui = ui_el.text
        name = name_el.text
        tree_numbers = [tn.text for tn in dr.findall('TreeNumberList/TreeNumber') if tn.text]
        descriptors.append({
            'ui': ui,
            'name': name,
            'tree_numbers': tree_numbers
        })
    return descriptors

def get_bacteria_taxonomy(xml_path):
    """
    From the full MeSH descriptors file, extract all descriptors
    under the 'Bacteria' branch (tree number B03).
    Returns a dict: { tree_number: { 'ui': ..., 'name': ... }, ... }
    """
    descriptors = parse_mesh_descriptors(xml_path)

    bacteria_prefix = None
    for d in descriptors:
        if d['name'] == 'Bacteria':
            bacteria_prefix = d['tree_numbers'][0]
            break

    if not bacteria_prefix:
        raise RuntimeError("Couldn't find a descriptor named 'Bacteria' in the file.")

    taxonomy = {}
    for d in descriptors:
        for tn in d['tree_numbers']:
            if tn == bacteria_prefix or tn.startswith(bacteria_prefix + '.'):
                taxonomy[tn] = {
                    'ui': d['ui'],
                    'name': d['name']
                }
                break

    return taxonomy

if __name__ == '__main__':
    xml_file = 'desc2025.xml'
    bacteria_tax = get_bacteria_taxonomy(xml_file)

    for tree_num in sorted(bacteria_tax):
        info = bacteria_tax[tree_num]
        print(f"{tree_num:10s}  {info['name']:30s}  ({info['ui']})")
# Out:
# B03         Bacteria                        (D001419)
# B03.026     Acidobacteria                   (D061271)
# B03.054     Agricultural Inoculants         (D059827)
# B03.110     Atypical Bacterial Forms        (D001295)
# B03.110.422  L Forms                         (D007740)
# B03.110.761  Spheroplasts                    (D013104)
# B03.120     Bacteria, Aerobic               (D001420)
# B03.130     Bacteria, Anaerobic             (D001421)
# B03.135     Bacteria, Thermoduric           (D000072280)
# B03.250     Chlorobi                        (D019414)
# B03.250.140  Chlorobium                      (D041883)
# B03.275     Chloroflexi                     (D041862)
# B03.275.150  Chloroflexus                    (D041861)
# B03.275.575  Dehalococcoides                 (D000082942)
# B03.280     Cyanobacteria                   (D000458)
# B03.280.100  Anabaena                        (D017033)
# B03.280.100.150  Anabaena cylindrica             (D046868)
# B03.280.100.900  Anabaena variabilis             (D046870)
# B03.280.110  Aphanizomenon                   (D046890)
# B03.280.200  Cyanothece                      (D046889)
# B03.280.210  Cylindrospermopsis              (D046891)
# B03.280.283  Dolichospermum flos-aquae       (D046869)
# B03.280.355  Lyngbya                         (D000083582)
# B03.280.500  Microcystis                     (D046931)
# B03.280.550  Nodularia                       (D046932)
# B03.280.575  Nostoc                          (D046937)
# B03.280.575.150  Nostoc commune                  (D050501)
# B03.280.575.500  Nostoc muscorum                 (D050502)
# B03.280.612  Oscillatoria                    (D054300)
# B03.280.622  Pannus                          (D000086282)
# B03.280.631  Phormidium                      (D000084242)
# B03.280.641  Planktothrix                    (D000086302)
# B03.280.650  Plectonema                      (D046938)
# B03.280.697  Spirulina                       (D053545)
# B03.280.745  Synechococcus                   (D046940)
# B03.280.750  Synechocystis                   (D046939)
# B03.280.813  Thermosynechococcus             (D000086325)
# B03.280.875  Trichodesmium                   (D000072359)
# B03.300     Endospore-Forming Bacteria      (D004725)
# B03.300.390  Gram-Positive Endospore-Forming Bacteria  (D016936)
# B03.300.390.400  Gram-Positive Endospore-Forming Rods  (D016937)
# B03.300.390.400.158  Bacillaceae                     (D001406)
# B03.300.390.400.158.108  Anoxybacillus                   (D058677)
# B03.300.390.400.158.218  Bacillus                        (D001407)
# B03.300.390.400.158.218.076  Bacillus amyloliquefaciens      (D000069977)
# B03.300.390.400.158.218.151  Bacillus anthracis              (D001408)
# B03.300.390.400.158.218.252  Bacillus cereus                 (D001409)
# B03.300.390.400.158.218.283  Bacillus clausii                (D000070019)
# B03.300.390.400.158.218.314  Bacillus coagulans              (D000070000)
# B03.300.390.400.158.218.345  Bacillus firmus                 (D000070098)
# B03.300.390.400.158.218.376  Bacillus licheniformis          (D000069976)
# B03.300.390.400.158.218.500  Bacillus megaterium             (D001410)
# B03.300.390.400.158.218.613  Bacillus pumilus                (D000069979)
# B03.300.390.400.158.218.725  Bacillus subtilis               (D001412)
# B03.300.390.400.158.218.800  Bacillus thuringiensis          (D001413)
# B03.300.390.400.158.400  Geobacillus                     (D056506)
# B03.300.390.400.158.400.400  Geobacillus stearothermophilus  (D001411)
# B03.300.390.400.158.600  Halobacillus                    (D058678)
# B03.300.390.400.158.900  Virgibacillus                   (D058679)
# B03.300.390.400.160  Brevibacillus                   (D058675)
# B03.300.390.400.200  Clostridium                     (D003013)
# B03.300.390.400.200.025  Clostridium acetobutylicum      (D046969)
# B03.300.390.400.200.100  Clostridium beijerinckii        (D046970)
# B03.300.390.400.200.130  Clostridium bifermentans        (D046971)
# B03.300.390.400.200.160  Clostridium botulinum           (D003014)
# B03.300.390.400.200.160.050  Clostridium botulinum type A    (D047013)
# B03.300.390.400.200.160.100  Clostridium botulinum type B    (D047014)
# B03.300.390.400.200.160.150  Clostridium botulinum type C    (D047968)
# B03.300.390.400.200.160.200  Clostridium botulinum type D    (D047969)
# B03.300.390.400.200.160.250  Clostridium botulinum type E    (D047970)
# B03.300.390.400.200.160.300  Clostridium botulinum type F    (D047971)
# B03.300.390.400.200.160.350  Clostridium botulinum type G    (D048568)
# B03.300.390.400.200.180  Clostridium butyricum           (D046972)
# B03.300.390.400.200.200  Clostridium cellulolyticum      (D046973)
# B03.300.390.400.200.205  Clostridium cellulovorans       (D046974)
# B03.300.390.400.200.215  Clostridium chauvoei            (D046975)
# B03.300.390.400.200.412  Clostridium histolyticum        (D047009)
# B03.300.390.400.200.493  Clostridium kluyveri            (D047010)
# B03.300.390.400.200.575  Clostridium perfringens         (D003016)
# B03.300.390.400.200.690  Clostridium septicum            (D052557)
# B03.300.390.400.200.700  Clostridium sordellii           (D047989)
# B03.300.390.400.200.710  Clostridium sticklandii         (D047991)
# B03.300.390.400.200.713  Clostridium symbiosum           (D048009)
# B03.300.390.400.200.722  Clostridium tertium             (D048010)
# B03.300.390.400.200.725  Clostridium tetani              (D003017)
# B03.300.390.400.200.740  Clostridium tetanomorphum       (D048012)
# B03.300.390.400.200.770  Clostridium thermocellum        (D048013)
# B03.300.390.400.200.800  Clostridium tyrobutyricum       (D048014)
# B03.300.390.400.500  Micromonosporaceae              (D008848)
# B03.300.390.400.500.250  Actinoplanes                    (D000079584)
# B03.300.390.400.500.500  Micromonospora                  (D008847)
# B03.300.390.400.525  Moorella                        (D058845)
# B03.300.390.400.645  Paenibacillus                   (D056507)
# B03.300.390.400.645.500  Paenibacillus larvae            (D000070059)
# B03.300.390.400.645.750  Paenibacillus polymyxa          (D000070057)
# B03.300.390.400.790  Saccharopolyspora               (D016930)
# B03.300.390.400.800  Staphylococcaceae               (D040141)
# B03.300.390.400.800.750  Staphylococcus                  (D013210)
# B03.300.390.400.800.750.100  Staphylococcus aureus           (D013211)
# B03.300.390.400.800.750.100.500  Methicillin-Resistant Staphylococcus aureus  (D055624)
# B03.300.390.400.800.750.100.750  Vancomycin-Resistant Staphylococcus aureus  (D000083123)
# B03.300.390.400.800.750.222  Staphylococcus capitis          (D000074039)
# B03.300.390.400.800.750.343  Staphylococcus epidermidis      (D013212)
# B03.300.390.400.800.750.400  Staphylococcus haemolyticus     (D041162)
# B03.300.390.400.800.750.425  Staphylococcus hominis          (D041181)
# B03.300.390.400.800.750.435  Staphylococcus hyicus           (D057788)
# B03.300.390.400.800.750.445  Staphylococcus intermedius      (D057789)
# B03.300.390.400.800.750.500  Staphylococcus lugdunensis      (D057787)
# B03.300.390.400.800.750.750  Staphylococcus saprophyticus    (D057790)
# B03.300.390.400.810  Streptomycetaceae               (D013306)
# B03.300.390.400.810.768  Streptomyces                    (D013302)
# B03.300.390.400.810.768.100  Streptomyces antibioticus       (D013303)
# B03.300.390.400.810.768.125  Streptomyces aureofaciens       (D013304)
# B03.300.390.400.810.768.200  Streptomyces coelicolor         (D048372)
# B03.300.390.400.810.768.375  Streptomyces griseus            (D013305)
# B03.300.390.400.810.768.500  Streptomyces lividans           (D048170)
# B03.300.390.400.810.768.750  Streptomyces rimosus            (D064411)
# B03.300.390.650  Pasteuria                       (D058676)
# B03.300.390.825  Sporosarcina                    (D058644)
# B03.353     Firmicutes                      (D000068536)
# B03.353.250  Acidaminococcus                 (D045850)
# B03.353.500  Bacillales                      (D056449)
# B03.353.500.050  Alicyclobacillus                (D056450)
# B03.353.500.100.309  Exiguobacterium                 (D000086183)
# B03.353.500.120  Brochothrix                     (D058640)
# B03.353.500.310  Gemella                         (D058834)
# B03.353.500.500  Listeria                        (D008087)
# B03.353.500.500.500  Listeria monocytogenes          (D008089)
# B03.353.500.700  Planococcaceae                  (D058641)
# B03.353.500.875  Thermoactinomyces               (D056509)
# B03.353.563  Caldicellulosiruptor            (D000082623)
# B03.353.625  Clostridiales                   (D000068016)
# B03.353.625.250  Butyrivibrio                    (D045856)
# B03.353.625.250.500  Butyrivibrio fibrisolvens       (D000070097)
# B03.353.625.375  Clostridiaceae                  (D000073561)
# B03.353.625.375.750  Sarcina                         (D012505)
# B03.353.625.657  Clostridioides                  (D000082682)
# B03.353.625.657.500  Clostridioides difficile        (D016360)
# B03.353.625.750  Eubacterium                     (D005051)
# B03.353.625.766  Faecalibacterium                (D000070036)
# B03.353.625.766.500  Faecalibacterium prausnitzii    (D000070037)
# B03.353.625.774  Neglecta                        (D000086242)
# B03.353.625.782  Peptococcaceae                  (D010459)
# B03.353.625.782.149  Desulfitobacterium              (D045858)
# B03.353.625.782.297  Desulfotomaculum                (D045859)
# B03.353.625.782.593  Peptococcus                     (D010460)
# B03.353.625.798  Peptostreptococcus              (D010462)
# B03.353.625.806  Ruminococcus                    (D045857)
# B03.353.688  Erysipelothrix                  (D004888)
# B03.353.750  Lactobacillales                 (D056546)
# B03.353.750.030  Aerococcaceae                   (D056567)
# B03.353.750.030.014  Abiotrophia                     (D058835)
# B03.353.750.030.030  Aerococcus                      (D056570)
# B03.353.750.130  Carnobacteriaceae               (D056568)
# B03.353.750.130.150  Carnobacterium                  (D056573)
# B03.353.750.250  Enterococcaceae                 (D056569)
# B03.353.750.250.250  Enterococcus                    (D016983)
# B03.353.750.250.250.280  Enterococcus faecalis           (D013293)
# B03.353.750.250.250.300  Enterococcus faecium            (D016984)
# B03.353.750.250.250.475  Enterococcus hirae              (D000070076)
# B03.353.750.250.250.650  Vancomycin-Resistant Enterococci  (D065507)
# B03.353.750.450  Lactobacillaceae                (D007777)
# B03.353.750.450.475  Lactobacillus                   (D007778)
# B03.353.750.450.475.100  Lactobacillus acidophilus       (D007779)
# B03.353.750.450.475.238  Lactobacillus crispatus         (D000070003)
# B03.353.750.450.475.250  Lactobacillus delbrueckii       (D048668)
# B03.353.750.450.475.363  Lactobacillus gasseri           (D000069998)
# B03.353.750.450.475.400  Lactobacillus helveticus        (D052198)
# B03.353.750.450.475.453  Lactobacillus johnsonii         (D000069999)
# B03.353.750.450.475.506  Lactobacillus leichmannii       (D052199)
# B03.353.750.450.475.586  Lactobacillus pentosus          (D000070018)
# B03.353.750.450.475.612  Lactobacillus plantarum         (D048191)
# B03.353.750.450.606  Lacticaseibacillus              (D000093622)
# B03.353.750.450.606.500  Lacticaseibacillus casei        (D007780)
# B03.353.750.450.606.750  Lacticaseibacillus paracasei    (D000069980)
# B03.353.750.450.606.875  Lacticaseibacillus rhamnosus    (D052201)
# B03.353.750.450.623  Latilactobacillus sakei         (D000070256)
# B03.353.750.450.639  Levilactobacillus brevis        (D052196)
# B03.353.750.450.656  Ligilactobacillus salivarius    (D000069996)
# B03.353.750.450.672  Limosilactobacillus fermentum   (D052197)
# B03.353.750.450.705  Limosilactobacillus reuteri     (D052200)
# B03.353.750.450.737  Pediococcus                     (D010376)
# B03.353.750.450.737.500  Pediococcus acidilactici        (D000070016)
# B03.353.750.450.737.750  Pediococcus pentosaceus         (D000070006)
# B03.353.750.475  Leuconostocaceae                (D056584)
# B03.353.750.475.450  Leuconostoc                     (D007934)
# B03.353.750.475.450.500  Leuconostoc mesenteroides       (D000070007)
# B03.353.750.475.600  Oenococcus                      (D056585)
# B03.353.750.475.900  Weissella                       (D058836)
# B03.353.750.737  Streptococcaceae                (D013289)
# B03.353.750.737.500  Lactococcus                     (D017045)
# B03.353.750.737.500.400  Lactococcus lactis              (D013294)
# B03.353.750.737.872  Streptococcus                   (D013291)
# B03.353.750.737.872.100  Streptococcus agalactiae        (D013292)
# B03.353.750.737.872.150  Streptococcus bovis             (D016985)
# B03.353.750.737.872.225  Streptococcus equi              (D018502)
# B03.353.750.737.872.243  Streptococcus gallolyticus      (D000070099)
# B03.353.750.737.872.243.500  Streptococcus gallolyticus subspecies gallolyticus  (D000070197)
# B03.353.750.737.872.260  Streptococcus gordonii          (D054773)
# B03.353.750.737.872.405  Streptococcus iniae             (D000070058)
# B03.353.750.737.872.550  Streptococcus pneumoniae        (D013296)
# B03.353.750.737.872.575  Streptococcus pyogenes          (D013297)
# B03.353.750.737.872.663  Streptococcus salivarius        (D000070001)
# B03.353.750.737.872.750  Streptococcus suis              (D017011)
# B03.353.750.737.872.800  Streptococcus thermophilus      (D048249)
# B03.353.750.737.872.875  Viridans Streptococci           (D034363)
# B03.353.750.737.872.875.475  Streptococcus milleri Group     (D034364)
# B03.353.750.737.872.875.475.080  Streptococcus anginosus         (D034366)
# B03.353.750.737.872.875.475.150  Streptococcus constellatus      (D034365)
# B03.353.750.737.872.875.475.400  Streptococcus intermedius       (D034367)
# B03.353.750.737.872.875.500  Streptococcus mitis             (D034361)
# B03.353.750.737.872.875.520  Streptococcus mutans            (D013295)
# B03.353.750.737.872.875.600  Streptococcus oralis            (D019533)
# B03.353.750.737.872.875.700  Streptococcus sanguis           (D013298)
# B03.353.750.737.872.875.750  Streptococcus sobrinus          (D016986)
# B03.353.937  Thermoanaerobacter              (D046968)
# B03.353.968  Thermoanaerobacterium           (D046950)
# B03.353.984  Veillonellaceae                 (D045854)
# B03.370     Fusobacteria                    (D045182)
# B03.370.250  Fusobacterium                   (D005673)
# B03.370.250.400  Fusobacterium necrophorum       (D005675)
# B03.370.250.500  Fusobacterium nucleatum         (D016967)
# B03.370.437  Leptotrichia                    (D045183)
# B03.370.600  Propionigenium                  (D045184)
# B03.370.700  Streptobacillus                 (D013288)
# B03.440     Gram-Negative Bacteria          (D006090)
# B03.440.025  Aquifex                         (D000086142)
# B03.440.050  Arcobacter                      (D020640)
# B03.440.080  Bacteroidetes                   (D041963)
# B03.440.080.094  Bacteroidaceae                  (D001438)
# B03.440.080.094.152  Bacteroides                     (D001439)
# B03.440.080.094.152.400  Bacteroides fragilis            (D001441)
# B03.440.080.094.152.700  Bacteroides thetaiotaomicron    (D000070077)
# B03.440.080.094.389  Mediterranea                    (D000086222)
# B03.440.080.094.625  Porphyromonas                   (D017861)
# B03.440.080.094.625.350  Porphyromonas endodontalis      (D045202)
# B03.440.080.094.625.515  Porphyromonas gingivalis        (D016966)
# B03.440.080.094.640  Prevotella                      (D018720)
# B03.440.080.094.640.375  Prevotella intermedia           (D018713)
# B03.440.080.094.640.500  Prevotella melaninogenica       (D001443)
# B03.440.080.094.640.550  Prevotella nigrescens           (D045242)
# B03.440.080.094.640.700  Prevotella ruminicola           (D045243)
# B03.440.080.130  Cytophagaceae                   (D041964)
# B03.440.080.130.150  Cytophaga                       (D003589)
# B03.440.080.130.200  Flexibacter                     (D045248)
# B03.440.080.190  Flavobacteriaceae               (D041965)
# B03.440.080.190.100  Capnocytophaga                  (D002206)
# B03.440.080.190.120  Chryseobacterium                (D045247)
# B03.440.080.190.250  Flavobacterium                  (D005417)
# B03.440.080.190.600  Ornithobacterium                (D045246)
# B03.440.080.190.700  Riemerella                      (D060494)
# B03.440.080.190.800  Tenacibaculum                   (D060493)
# B03.440.080.600  Pedobacter                      (D060485)
# B03.440.080.750  Rhodothermus                    (D045245)
# B03.440.080.800  Sphingobacterium                (D045249)
# B03.440.080.850  Tannerella                      (D000084422)
# B03.440.080.850.500  Tannerella forsythia            (D000070436)
# B03.440.090  Bartonellaceae                  (D001475)
# B03.440.090.100  Bartonella                      (D001473)
# B03.440.090.100.080  Bartonella bacilliformis        (D045503)
# B03.440.090.100.350  Bartonella henselae             (D018416)
# B03.440.090.100.650  Bartonella quintana             (D018413)
# B03.440.097  Brachyspira                     (D017400)
# B03.440.097.100  Brachyspira hyodysenteriae      (D017401)
# B03.440.100  Buchnera                        (D020635)
# B03.440.180  Campylobacter                   (D002167)
# B03.440.180.200  Campylobacter coli              (D017000)
# B03.440.180.325  Campylobacter fetus             (D002168)
# B03.440.180.375  Campylobacter hyointestinalis   (D044862)
# B03.440.180.425  Campylobacter jejuni            (D016123)
# B03.440.180.500  Campylobacter lari              (D044863)
# B03.440.180.650  Campylobacter rectus            (D044883)
# B03.440.180.700  Campylobacter sputorum          (D044884)
# B03.440.180.800  Campylobacter upsaliensis       (D044885)
# B03.440.190  Chlamydiales                    (D002695)
# B03.440.190.190  Chlamydiaceae                   (D002693)
# B03.440.190.190.190  Chlamydia                       (D002689)
# B03.440.190.190.190.500  Chlamydia muridarum             (D023502)
# B03.440.190.190.190.750  Chlamydia trachomatis           (D002692)
# B03.440.190.190.230  Chlamydophila                   (D023501)
# B03.440.190.190.230.249  Chlamydophila pneumoniae        (D016993)
# B03.440.190.190.230.500  Chlamydophila psittaci          (D002691)
# B03.440.305  Fibrobacteres                   (D061306)
# B03.440.305.500  Fibrobacter                     (D045848)
# B03.440.400  Gram-Negative Aerobic Bacteria  (D006088)
# B03.440.400.280  Caulobacter                     (D016934)
# B03.440.400.280.280  Caulobacter crescentus          (D016935)
# B03.440.400.400  Gallionellaceae                 (D043372)
# B03.440.400.425  Gram-Negative Aerobic Rods and Cocci  (D016946)
# B03.440.400.425.100  Acetobacteraceae                (D016947)
# B03.440.400.425.100.100  Acetobacter                     (D000091)
# B03.440.400.425.100.110  Acidiphilium                    (D041801)
# B03.440.400.425.100.550  Gluconobacter                   (D020576)
# B03.440.400.425.100.550.550  Gluconobacter oxydans           (D020600)
# B03.440.400.425.103  Acidithiobacillus               (D042763)
# B03.440.400.425.103.800  Acidithiobacillus thiooxidans   (D013856)
# B03.440.400.425.115  Alcaligenaceae                  (D042401)
# B03.440.400.425.115.030  Achromobacter                   (D042402)
# B03.440.400.425.115.030.100  Achromobacter cycloclastes      (D042422)
# B03.440.400.425.115.030.120  Achromobacter denitrificans     (D042441)
# B03.440.400.425.115.050  Alcaligenes                     (D000421)
# B03.440.400.425.115.050.200  Alcaligenes faecalis            (D042481)
# B03.440.400.425.115.425  Bordetella                      (D001884)
# B03.440.400.425.115.425.024  Bordetella avium                (D042482)
# B03.440.400.425.115.425.050  Bordetella bronchiseptica       (D016950)
# B03.440.400.425.115.425.590  Bordetella parapertussis        (D042483)
# B03.440.400.425.115.425.600  Bordetella pertussis            (D001886)
# B03.440.400.425.115.800  Taylorella                      (D042502)
# B03.440.400.425.115.800.200  Taylorella equigenitalis        (D020625)
# B03.440.400.425.126  Alteromonas                     (D020591)
# B03.440.400.425.127  Azorhizobium                    (D020583)
# B03.440.400.425.127.100  Azorhizobium caulinodans        (D020599)
# B03.440.400.425.180  Bdellovibrio                    (D001501)
# B03.440.400.425.180.500  Bdellovibrio bacteriovorus      (D000070060)
# B03.440.400.425.200  Bradyrhizobiaceae               (D041841)
# B03.440.400.425.200.040  Afipia                          (D020622)
# B03.440.400.425.200.090  Bradyrhizobium                  (D020369)
# B03.440.400.425.200.520  Nitrobacter                     (D009576)
# B03.440.400.425.200.700  Rhodopseudomonas                (D012241)
# B03.440.400.425.215  Brucellaceae                    (D042021)
# B03.440.400.425.215.500  Brucella                        (D002002)
# B03.440.400.425.215.500.100  Brucella abortus                (D002003)
# B03.440.400.425.215.500.150  Brucella canis                  (D041002)
# B03.440.400.425.215.500.500  Brucella melitensis             (D017347)
# B03.440.400.425.215.500.625  Brucella ovis                   (D042061)
# B03.440.400.425.215.500.750  Brucella suis                   (D041021)
# B03.440.400.425.251  Burkholderiaceae                (D042521)
# B03.440.400.425.251.200  Cupriavidus                     (D049921)
# B03.440.400.425.251.200.200  Cupriavidus necator             (D020118)
# B03.440.400.425.288  Caulobacteraceae                (D042063)
# B03.440.400.425.293  Comamonadaceae                  (D042621)
# B03.440.400.425.293.150  Comamonas                       (D020585)
# B03.440.400.425.293.150.750  Comamonas testosteroni          (D020604)
# B03.440.400.425.293.170  Delftia                         (D042742)
# B03.440.400.425.293.170.030  Delftia acidovorans             (D020605)
# B03.440.400.425.293.750  Sphaerotilus                    (D042744)
# B03.440.400.425.297  Coxiellaceae                    (D044125)
# B03.440.400.425.297.150  Coxiella                        (D003381)
# B03.440.400.425.297.150.100  Coxiella burnetii               (D016997)
# B03.440.400.425.340  Francisella                     (D005603)
# B03.440.400.425.340.590  Francisella tularensis          (D005604)
# B03.440.400.425.365  Gluconacetobacter               (D041821)
# B03.440.400.425.365.500  Gluconacetobacter xylinus       (D041822)
# B03.440.400.425.377  Halomonadaceae                  (D044129)
# B03.440.400.425.377.249  Chromohalobacter                (D055353)
# B03.440.400.425.377.500  Halomonas                       (D020632)
# B03.440.400.425.395  Halothiobacillus                (D044222)
# B03.440.400.425.450  Legionellaceae                  (D016951)
# B03.440.400.425.450.450  Legionella                      (D007875)
# B03.440.400.425.450.450.400  Legionella longbeachae          (D044128)
# B03.440.400.425.450.450.500  Legionella pneumophila          (D016952)
# B03.440.400.425.475  Leptospiraceae                  (D016953)
# B03.440.400.425.475.475  Leptospira                      (D007919)
# B03.440.400.425.475.475.400  Leptospira interrogans          (D007921)
# B03.440.400.425.475.475.400.050  Leptospira interrogans serovar australis  (D041281)
# B03.440.400.425.475.475.400.055  Leptospira interrogans serovar autumnalis  (D041301)
# B03.440.400.425.475.475.400.150  Leptospira interrogans serovar canicola  (D041341)
# B03.440.400.425.475.475.400.400  Leptospira interrogans serovar hebdomadis  (D041343)
# B03.440.400.425.475.475.400.420  Leptospira interrogans serovar icterohaemorrhagiae  (D041383)
# B03.440.400.425.475.475.400.650  Leptospira interrogans serovar pomona  (D041401)
# B03.440.400.425.481  Leptothrix                      (D042743)
# B03.440.400.425.487  Methylobacteriaceae             (D042082)
# B03.440.400.425.487.500  Methylobacterium                (D020580)
# B03.440.400.425.487.500.150  Methylobacterium extorquens     (D020601)
# B03.440.400.425.500  Methylococcaceae                (D008772)
# B03.440.400.425.500.500  Methylococcus                   (D020618)
# B03.440.400.425.500.500.100  Methylococcus capsulatus        (D020619)
# B03.440.400.425.500.505  Methylomonas                    (D020620)
# B03.440.400.425.525  Methylophilaceae                (D042762)
# B03.440.400.425.525.500  Methylobacillus                 (D020631)
# B03.440.400.425.525.520  Methylophilus                   (D020629)
# B03.440.400.425.525.520.500  Methylophilus methylotrophus    (D020630)
# B03.440.400.425.537  Moraxellaceae                   (D044007)
# B03.440.400.425.537.050  Acinetobacter                   (D000150)
# B03.440.400.425.537.050.099  Acinetobacter baumannii         (D040981)
# B03.440.400.425.537.050.200  Acinetobacter calcoaceticus     (D016954)
# B03.440.400.425.537.525  Moraxella                       (D009016)
# B03.440.400.425.537.525.200  Moraxella catarrhalis           (D001936)
# B03.440.400.425.537.525.500  Moraxella bovis                 (D016955)
# B03.440.400.425.537.650  Psychrobacter                   (D044096)
# B03.440.400.425.550  Neisseriaceae                   (D009346)
# B03.440.400.425.550.400  Kingella                        (D017881)
# B03.440.400.425.550.400.375  Kingella kingae                 (D017882)
# B03.440.400.425.550.550  Neisseria                       (D009343)
# B03.440.400.425.550.550.125  Neisseria cinerea               (D042804)
# B03.440.400.425.550.550.299  Neisseria elongata              (D042805)
# B03.440.400.425.550.550.474  Neisseria gonorrhoeae           (D009344)
# B03.440.400.425.550.550.600  Neisseria lactamica             (D042806)
# B03.440.400.425.550.550.641  Neisseria meningitidis          (D009345)
# B03.440.400.425.550.550.641.700  Neisseria meningitidis, Serogroup A  (D038381)
# B03.440.400.425.550.550.641.710  Neisseria meningitidis, Serogroup B  (D038541)
# B03.440.400.425.550.550.641.720  Neisseria meningitidis, Serogroup C  (D038542)
# B03.440.400.425.550.550.641.800  Neisseria meningitidis, Serogroup W-135  (D038582)
# B03.440.400.425.550.550.641.820  Neisseria meningitidis, Serogroup Y  (D038581)
# B03.440.400.425.550.550.660  Neisseria mucosa                (D042807)
# B03.440.400.425.550.550.800  Neisseria sicca                 (D042808)
# B03.440.400.425.562  Nitrosomonadaceae               (D043369)
# B03.440.400.425.562.500  Nitrosomonas                    (D009606)
# B03.440.400.425.562.500.200  Nitrosomonas europaea           (D043370)
# B03.440.400.425.575  Ochrobactrum                    (D042041)
# B03.440.400.425.575.650  Ochrobactrum anthropi           (D020621)
# B03.440.400.425.587  Oxalobacteraceae                (D042802)
# B03.440.400.425.587.400  Herbaspirillum                  (D042803)
# B03.440.400.425.600  Paracoccus                      (D010230)
# B03.440.400.425.600.380  Paracoccus denitrificans        (D010231)
# B03.440.400.425.600.690  Paracoccus pantotrophus         (D042084)
# B03.440.400.425.622  Pseudoalteromonas               (D031161)
# B03.440.400.425.625  Pseudomonadaceae                (D011548)
# B03.440.400.425.625.050  Azotobacter                     (D001395)
# B03.440.400.425.625.050.850  Azotobacter vinelandii          (D016948)
# B03.440.400.425.625.150  Cellvibrio                      (D020633)
# B03.440.400.425.625.625  Pseudomonas                     (D011549)
# B03.440.400.425.625.625.100  Pseudomonas aeruginosa          (D011550)
# B03.440.400.425.625.625.120  Pseudomonas alcaligenes         (D044202)
# B03.440.400.425.625.625.223  Pseudomonas chlororaphis        (D000070096)
# B03.440.400.425.625.625.325  Pseudomonas fluorescens         (D011551)
# B03.440.400.425.625.625.350  Pseudomonas fragi               (D044206)
# B03.440.400.425.625.625.500  Pseudomonas mendocina           (D044203)
# B03.440.400.425.625.625.650  Pseudomonas oleovorans          (D044204)
# B03.440.400.425.625.625.662  Pseudomonas pseudoalcaligenes   (D044205)
# B03.440.400.425.625.625.675  Pseudomonas putida              (D016958)
# B03.440.400.425.625.625.750  Pseudomonas stutzeri            (D044223)
# B03.440.400.425.625.625.770  Pseudomonas syringae            (D044224)
# B03.440.400.425.700  Rhizobiaceae                    (D012230)
# B03.440.400.425.700.024  Agrobacterium                   (D060054)
# B03.440.400.425.700.024.050  Agrobacterium tumefaciens       (D016960)
# B03.440.400.425.700.800  Rhizobium                       (D012231)
# B03.440.400.425.700.800.337  Rhizobium etli                  (D042163)
# B03.440.400.425.700.800.450  Rhizobium leguminosarum         (D016961)
# B03.440.400.425.700.800.600  Rhizobium phaseoli              (D042161)
# B03.440.400.425.700.800.800  Rhizobium tropici               (D042162)
# B03.440.400.425.700.887  Sinorhizobium                   (D020579)
# B03.440.400.425.700.887.249  Sinorhizobium fredii            (D042181)
# B03.440.400.425.700.887.500  Sinorhizobium meliloti          (D016962)
# B03.440.400.425.708  Rhodospirillaceae               (D012244)
# B03.440.400.425.708.100  Azospirillum                    (D016949)
# B03.440.400.425.708.100.020  Azospirillum brasilense         (D015806)
# B03.440.400.425.708.100.510  Azospirillum lipoferum          (D042081)
# B03.440.400.425.708.500  Magnetospirillum                (D042201)
# B03.440.400.425.708.733  Rhodospirillum                  (D012246)
# B03.440.400.425.708.733.150  Rhodospirillum centenum         (D042182)
# B03.440.400.425.708.733.650  Rhodospirillum rubrum           (D012247)
# B03.440.400.425.750  Sphingomonas                    (D020578)
# B03.440.400.425.875  Thermus                         (D013824)
# B03.440.400.425.875.875  Thermus thermophilus            (D016963)
# B03.440.400.425.935  Xanthobacter                    (D020584)
# B03.440.400.425.967  Xanthomonadaceae                (D044166)
# B03.440.400.425.967.500  Lysobacter                      (D053528)
# B03.440.400.425.967.750  Stenotrophomonas                (D020588)
# B03.440.400.425.967.750.500  Stenotrophomonas maltophilia    (D020615)
# B03.440.400.425.967.930  Xanthomonas                     (D014974)
# B03.440.400.425.967.930.100  Xanthomonas campestris          (D016959)
# B03.440.400.425.967.930.850  Xanthomonas vesicatoria         (D044184)
# B03.440.400.425.967.950  Xylella                         (D044167)
# B03.440.400.425.983  Zoogloea                        (D015045)
# B03.440.400.450  Gram-Negative Chemolithotrophic Bacteria  (D006091)
# B03.440.400.450.800  Thiobacillus                    (D013855)
# B03.440.400.645  Thiotrichaceae                  (D041962)
# B03.440.400.645.100  Beggiatoa                       (D053524)
# B03.440.400.645.800  Thiothrix                       (D053525)
# B03.440.400.840  Vitreoscilla                    (D020589)
# B03.440.425  Gram-Negative Anaerobic Bacteria  (D006089)
# B03.440.425.200  Desulfovibrionaceae             (D000073564)
# B03.440.425.400  Gram-Negative Anaerobic Cocci   (D016964)
# B03.440.425.400.500  Megasphaera                     (D045851)
# B03.440.425.400.500.500  Megasphaera elsdenii            (D000070101)
# B03.440.425.400.750  Thiocapsa                       (D020586)
# B03.440.425.400.750.660  Thiocapsa roseopersicina        (D020616)
# B03.440.425.410  Gram-Negative Anaerobic Straight, Curved, and Helical Rods  (D016965)
# B03.440.425.410.145  Anaerobiospirillum              (D044064)
# B03.440.425.410.200  Bilophila                       (D045282)
# B03.440.425.410.290  Chromatium                      (D002844)
# B03.440.425.410.350  Desulfovibrio                   (D003901)
# B03.440.425.410.350.040  Desulfovibrio africanus         (D045284)
# B03.440.425.410.350.150  Desulfovibrio desulfuricans     (D045285)
# B03.440.425.410.350.350  Desulfovibrio gigas             (D045286)
# B03.440.425.410.350.875  Desulfovibrio vulgaris          (D016969)
# B03.440.425.410.360  Desulfuromonas                  (D045287)
# B03.440.425.410.400  Dichelobacter nodosus           (D020376)
# B03.440.425.410.405  Ectothiorhodospiraceae          (D042001)
# B03.440.425.410.405.500  Ectothiorhodospira              (D020587)
# B03.440.425.410.405.500.720  Ectothiorhodospira shaposhnikovii  (D020608)
# B03.440.425.410.405.750  Halorhodospira halophila        (D020607)
# B03.440.425.410.430  Geobacter                       (D045302)
# B03.440.425.410.580  Oxalobacter formigenes          (D020624)
# B03.440.425.410.711  Spirochaetaceae                 (D013143)
# B03.440.425.410.711.193  Borrelia                        (D001898)
# B03.440.425.410.711.193.150  Borrelia burgdorferi Group      (D015748)
# B03.440.425.410.711.193.150.125  Borrelia burgdorferi            (D025065)
# B03.440.425.410.711.679  Spirochaeta                     (D013142)
# B03.440.425.410.711.795  Treponema                       (D014208)
# B03.440.425.410.711.795.700  Treponema denticola             (D048373)
# B03.440.425.410.711.795.840  Treponema pallidum              (D014210)
# B03.440.425.410.722  Succinivibrionaceae             (D044063)
# B03.440.425.410.745  Thauera                         (D020628)
# B03.440.425.410.748  Thermotoga                      (D000084444)
# B03.440.425.410.748.500  Thermotoga maritima             (D020124)
# B03.440.425.410.748.750  Thermotoga neapolitana          (D046949)
# B03.440.425.410.800.755  Pectinatus                      (D045852)
# B03.440.425.410.800.877  Selenomonas                     (D020357)
# B03.440.425.410.800.938  Veillonella                     (D014678)
# B03.440.425.410.875  Wolinella                       (D016968)
# B03.440.450  Gram-Negative Facultatively Anaerobic Rods  (D006092)
# B03.440.450.009  Actinobacillus                  (D000188)
# B03.440.450.009.200  Actinobacillus equuli           (D044131)
# B03.440.450.009.580  Actinobacillus pleuropneumoniae  (D016977)
# B03.440.450.009.675  Actinobacillus seminis          (D044133)
# B03.440.450.009.700  Actinobacillus suis             (D044132)
# B03.440.450.019  Aeromonadaceae                  (D044044)
# B03.440.450.019.025  Aeromonas                       (D000333)
# B03.440.450.019.025.150  Aeromonas caviae                (D057585)
# B03.440.450.019.025.380  Aeromonas hydrophila            (D016980)
# B03.440.450.019.025.690  Aeromonas salmonicida           (D048409)
# B03.440.450.019.025.845  Aeromonas veronii               (D000070079)
# B03.440.450.040  Azoarcus                        (D020627)
# B03.440.450.342  Cardiobacteriaceae              (D044065)
# B03.440.450.342.100  Cardiobacterium                 (D044066)
# B03.440.450.360  Chromobacterium                 (D002861)
# B03.440.450.400  Eikenella                       (D016970)
# B03.440.450.400.275  Eikenella corrodens             (D016124)
# B03.440.450.425  Enterobacteriaceae              (D004755)
# B03.440.450.425.180  Calymmatobacterium              (D002157)
# B03.440.450.425.189  Carbapenem-Resistant Enterobacteriaceae  (D000073182)
# B03.440.450.425.200  Citrobacter                     (D002954)
# B03.440.450.425.200.275  Citrobacter freundii            (D016971)
# B03.440.450.425.200.475  Citrobacter koseri              (D041041)
# B03.440.450.425.200.737  Citrobacter rodentium           (D044082)
# B03.440.450.425.215  Cronobacter                     (D059126)
# B03.440.450.425.215.150  Cronobacter sakazakii           (D044083)
# B03.440.450.425.260  Edwardsiella                    (D020594)
# B03.440.450.425.260.340  Edwardsiella ictaluri           (D020610)
# B03.440.450.425.260.750  Edwardsiella tarda              (D020609)
# B03.440.450.425.275  Enterobacter                    (D004754)
# B03.440.450.425.275.099  Enterobacter aerogenes          (D021902)
# B03.440.450.425.275.200  Enterobacter cloacae            (D016972)
# B03.440.450.425.300  Erwinia                         (D004885)
# B03.440.450.425.300.050  Erwinia amylovora               (D044084)
# B03.440.450.425.325  Escherichia                     (D004925)
# B03.440.450.425.325.300  Escherichia coli                (D004926)
# B03.440.450.425.325.300.330  Enteropathogenic Escherichia coli  (D054308)
# B03.440.450.425.325.300.340  Enterotoxigenic Escherichia coli  (D054307)
# B03.440.450.425.325.300.360  Escherichia coli K12            (D048168)
# B03.440.450.425.325.300.580  Extraintestinal Pathogenic Escherichia coli  (D000072282)
# B03.440.450.425.325.300.580.500  Uropathogenic Escherichia coli  (D056689)
# B03.440.450.425.325.300.800  Shiga-Toxigenic Escherichia coli  (D054323)
# B03.440.450.425.325.300.800.250  Enterohemorrhagic Escherichia coli  (D054324)
# B03.440.450.425.325.300.800.250.250  Escherichia coli O104           (D000069981)
# B03.440.450.425.325.300.800.250.500  Escherichia coli O157           (D019453)
# B03.440.450.425.375  Hafnia                          (D020595)
# B03.440.450.425.375.050  Hafnia alvei                    (D020611)
# B03.440.450.425.425  Klebsiella                      (D007709)
# B03.440.450.425.425.580  Klebsiella oxytoca              (D041121)
# B03.440.450.425.425.600  Klebsiella pneumoniae           (D007711)
# B03.440.450.425.435  Kluyvera                        (D044086)
# B03.440.450.425.500  Morganella                      (D020596)
# B03.440.450.425.500.500  Morganella morganii             (D020613)
# B03.440.450.425.580  Pantoea                         (D020636)
# B03.440.450.425.585  Pectobacterium                  (D044043)
# B03.440.450.425.585.120  Pectobacterium carotovorum      (D016973)
# B03.440.450.425.590  Photorhabdus                    (D020637)
# B03.440.450.425.595  Plesiomonas                     (D016981)
# B03.440.450.425.600  Proteus                         (D011511)
# B03.440.450.425.600.501  Proteus mirabilis               (D011513)
# B03.440.450.425.600.650  Proteus penneri                 (D044095)
# B03.440.450.425.600.800  Proteus vulgaris                (D011514)
# B03.440.450.425.670  Providencia                     (D011532)
# B03.440.450.425.800  Salmonella                      (D012475)
# B03.440.450.425.800.100  Salmonella arizonae             (D012476)
# B03.440.450.425.800.200  Salmonella enterica             (D019779)
# B03.440.450.425.800.200.300  Salmonella enteritidis          (D012477)
# B03.440.450.425.800.200.600  Salmonella paratyphi A          (D012482)
# B03.440.450.425.800.200.700  Salmonella paratyphi B          (D012484)
# B03.440.450.425.800.200.750  Salmonella paratyphi C          (D012479)
# B03.440.450.425.800.200.800  Salmonella typhi                (D012485)
# B03.440.450.425.800.200.825  Salmonella typhimurium          (D012486)
# B03.440.450.425.814  Serratia                        (D012705)
# B03.440.450.425.814.620  Serratia liquefaciens           (D044090)
# B03.440.450.425.814.664  Serratia marcescens             (D012706)
# B03.440.450.425.850  Shigella                        (D012760)
# B03.440.450.425.850.175  Shigella boydii                 (D012761)
# B03.440.450.425.850.350  Shigella dysenteriae            (D012762)
# B03.440.450.425.850.450  Shigella flexneri               (D012763)
# B03.440.450.425.850.800  Shigella sonnei                 (D012764)
# B03.440.450.425.887  Wigglesworthia                  (D044106)
# B03.440.450.425.890  Xenorhabdus                     (D020593)
# B03.440.450.425.900  Yersinia                        (D015007)
# B03.440.450.425.900.300  Yersinia enterocolitica         (D015008)
# B03.440.450.425.900.600  Yersinia pestis                 (D015010)
# B03.440.450.425.900.615  Yersinia pseudotuberculosis     (D015011)
# B03.440.450.425.900.650  Yersinia ruckeri                (D044124)
# B03.440.450.510  Moritella                       (D034221)
# B03.440.450.600  Pasteurellaceae                 (D015661)
# B03.440.450.600.224  Aggregatibacter                 (D064206)
# B03.440.450.600.224.500  Aggregatibacter actinomycetemcomitans  (D016976)
# B03.440.450.600.224.750  Aggregatibacter aphrophilus     (D064207)
# B03.440.450.600.224.875  Aggregatibacter segnis          (D064208)
# B03.440.450.600.450  Haemophilus                     (D006190)
# B03.440.450.600.450.125  Haemophilus ducreyi             (D006191)
# B03.440.450.600.450.330  Haemophilus influenzae          (D006193)
# B03.440.450.600.450.330.150  Haemophilus influenzae type b   (D019741)
# B03.440.450.600.450.665  Haemophilus paragallinarum      (D044134)
# B03.440.450.600.450.675  Haemophilus parainfluenzae      (D044135)
# B03.440.450.600.450.690  Haemophilus paraphrophilus      (D044136)
# B03.440.450.600.450.700  Haemophilus parasuis            (D044137)
# B03.440.450.600.450.750  Haemophilus somnus              (D044138)
# B03.440.450.600.500  Mannheimia                      (D031121)
# B03.440.450.600.500.500  Mannheimia haemolytica          (D016978)
# B03.440.450.600.600  Pasteurella                     (D010325)
# B03.440.450.600.600.500  Pasteurella multocida           (D016979)
# B03.440.450.600.600.650  Pasteurella pneumotropica       (D044142)
# B03.440.450.650  Rahnella                        (D020638)
# B03.440.450.690  Shewanella                      (D020592)
# B03.440.450.690.590  Shewanella putrefaciens         (D020614)
# B03.440.450.900  Vibrionaceae                    (D014737)
# B03.440.450.900.050  Aliivibrio                      (D059706)
# B03.440.450.900.050.860  Aliivibrio fischeri             (D048908)
# B03.440.450.900.050.930  Aliivibrio salmonicida          (D044165)
# B03.440.450.900.500  Listonella                      (D053526)
# B03.440.450.900.604  Photobacterium                  (D010776)
# B03.440.450.900.859  Vibrio                          (D014733)
# B03.440.450.900.859.030  Vibrio alginolyticus            (D044149)
# B03.440.450.900.859.225  Vibrio cholerae                 (D014734)
# B03.440.450.900.859.225.075  Vibrio cholerae non-O1          (D044163)
# B03.440.450.900.859.225.151  Vibrio cholerae O1              (D041241)
# B03.440.450.900.859.225.200  Vibrio cholerae O139            (D041242)
# B03.440.450.900.859.500  Vibrio mimicus                  (D044164)
# B03.440.450.900.859.550  Vibrio parahaemolyticus         (D014736)
# B03.440.450.900.859.900  Vibrio vulnificus               (D041261)
# B03.440.450.980  Zymomonas                       (D017355)
# B03.440.475  Gram-Negative Oxygenic Photosynthetic Bacteria  (D019688)
# B03.440.475.100.655  Prochlorophytes                 (D048928)
# B03.440.475.100.655.600  Prochlorococcus                 (D048929)
# B03.440.475.100.655.620  Prochloron                      (D019691)
# B03.440.475.100.655.640  Prochlorothrix                  (D019692)
# B03.440.500  Helicobacter                    (D016998)
# B03.440.500.250  Helicobacter felis              (D044922)
# B03.440.500.350  Helicobacter heilmannii         (D018247)
# B03.440.500.362  Helicobacter hepaticus          (D044923)
# B03.440.500.450  Helicobacter mustelae           (D045502)
# B03.440.500.550  Helicobacter pylori             (D016480)
# B03.440.520  Lawsonia Bacteria               (D020639)
# B03.440.540  Methylosinus                    (D020581)
# B03.440.540.500  Methylosinus trichosporium      (D020602)
# B03.440.595  Oceanospirillaceae              (D044130)
# B03.440.612  Piscirickettsiaceae             (D044147)
# B03.440.619  Planctomycetes                  (D000090643)
# B03.440.619.500  Planctomycetales                (D061328)
# B03.440.623  Rhodobacter                     (D016992)
# B03.440.623.225  Rhodobacter capsulatus          (D016354)
# B03.440.623.700  Rhodobacter sphaeroides         (D012242)
# B03.440.645  Rhodomicrobium                  (D020623)
# B03.440.646  Rhodovulum                      (D041903)
# B03.440.664  Rickettsiales                   (D000076944)
# B03.440.664.750  Anaplasmataceae                 (D000710)
# B03.440.664.750.050  Anaplasma                       (D000709)
# B03.440.664.750.050.100  Anaplasma centrale              (D042321)
# B03.440.664.750.050.500  Anaplasma marginale             (D042322)
# B03.440.664.750.050.575  Anaplasma ovis                  (D042323)
# B03.440.664.750.050.600  Anaplasma phagocytophilum       (D041081)
# B03.440.664.750.287  Ehrlichia                       (D004536)
# B03.440.664.750.287.090  Ehrlichia canis                 (D041061)
# B03.440.664.750.287.150  Ehrlichia chaffeensis           (D018469)
# B03.440.664.750.287.700  Ehrlichia ruminantium           (D016995)
# B03.440.664.750.525  Neorickettsia                   (D041102)
# B03.440.664.750.525.700  Neorickettsia risticii          (D041103)
# B03.440.664.750.525.720  Neorickettsia sennetsu          (D041101)
# B03.440.680  Roseobacter                     (D041904)
# B03.440.840  Spirillaceae                    (D043167)
# B03.440.840.750  Spirillum                       (D013139)
# B03.440.860  Tenericutes                     (D008973)
# B03.440.860.074  Acholeplasmataceae              (D000129)
# B03.440.860.074.150  Acholeplasma                    (D000127)
# B03.440.860.074.150.500  Acholeplasma laidlawii          (D000128)
# B03.440.860.074.575  Phytoplasma                     (D045582)
# B03.440.860.300  Entomoplasmatales               (D060366)
# B03.440.860.300.250  Entomoplasmataceae              (D045622)
# B03.440.860.300.750  Spiroplasmataceae               (D016991)
# B03.440.860.300.750.625  Spiroplasma                     (D013149)
# B03.440.860.300.750.625.500  Spiroplasma citri               (D045642)
# B03.440.860.580  Mycoplasmatales                 (D009179)
# B03.440.860.580.553  Mycoplasmataceae                (D009178)
# B03.440.860.580.553.553  Mycoplasma                      (D009174)
# B03.440.860.580.553.553.050  Mycoplasma agalactiae           (D045644)
# B03.440.860.580.553.553.075  Mycoplasma arthritidis          (D045645)
# B03.440.860.580.553.553.195  Mycoplasma bovigenitalium       (D045646)
# B03.440.860.580.553.553.200  Mycoplasma bovis                (D045682)
# B03.440.860.580.553.553.210  Mycoplasma capricolum           (D045623)
# B03.440.860.580.553.553.220  Mycoplasma conjunctivae         (D045684)
# B03.440.860.580.553.553.267  Mycoplasma dispar               (D045685)
# B03.440.860.580.553.553.315  Mycoplasma fermentans           (D016858)
# B03.440.860.580.553.553.345  Mycoplasma gallisepticum        (D045686)
# B03.440.860.580.553.553.355  Mycoplasma genitalium           (D045704)
# B03.440.860.580.553.553.400  Mycoplasma hominis              (D019535)
# B03.440.860.580.553.553.420  Mycoplasma hyopneumoniae        (D045705)
# B03.440.860.580.553.553.425  Mycoplasma hyorhinis            (D045790)
# B03.440.860.580.553.553.430  Mycoplasma hyosynoviae          (D045791)
# B03.440.860.580.553.553.450  Mycoplasma iowae                (D045793)
# B03.440.860.580.553.553.570  Mycoplasma meleagridis          (D045794)
# B03.440.860.580.553.553.585  Mycoplasma mycoides             (D009176)
# B03.440.860.580.553.553.630  Mycoplasma orale                (D045795)
# B03.440.860.580.553.553.635  Mycoplasma ovipneumoniae        (D045802)
# B03.440.860.580.553.553.645  Mycoplasma penetrans            (D018661)
# B03.440.860.580.553.553.650  Mycoplasma pneumoniae           (D009177)
# B03.440.860.580.553.553.670  Mycoplasma pulmonis             (D045803)
# B03.440.860.580.553.553.720  Mycoplasma salivarium           (D045804)
# B03.440.860.580.553.553.770  Mycoplasma synoviae             (D045805)
# B03.440.860.580.553.900  Ureaplasma                      (D014509)
# B03.440.860.580.553.900.800  Ureaplasma urealyticum          (D016990)
# B03.440.930  Verrucomicrobia                 (D061327)
# B03.440.930.500  Akkermansia                     (D000086102)
# B03.510     Gram-Positive Bacteria          (D006094)
# B03.510.024  Actinobacteria                  (D039903)
# B03.510.024.049  Actinomycetales                 (D000192)
# B03.510.024.049.025  Actinomadura                    (D000082403)
# B03.510.024.049.050  Actinomycetaceae                (D000191)
# B03.510.024.049.050.050  Actinomyces                     (D000190)
# B03.510.024.049.050.050.050  Actinomyces viscosus            (D016924)
# B03.510.024.049.050.287  Arcanobacterium                 (D055667)
# B03.510.024.049.050.525  Mobiluncus                      (D017904)
# B03.510.024.049.075  Amycolatopsis                   (D000082502)
# B03.510.024.100  Bifidobacterium                 (D001644)
# B03.510.024.100.125  Bifidobacterium adolescentis    (D000070005)
# B03.510.024.100.250  Bifidobacterium animalis        (D000069982)
# B03.510.024.100.313  Bifidobacterium bifidum         (D000069985)
# B03.510.024.100.375  Bifidobacterium breve           (D000069984)
# B03.510.024.100.500  Bifidobacterium longum          (D000069978)
# B03.510.024.100.500.500  Bifidobacterium longum subspecies infantis  (D000070236)
# B03.510.024.100.750  Bifidobacterium pseudocatenulatum  (D000070257)
# B03.510.024.175  Brevibacterium                  (D001951)
# B03.510.024.213  Cellulomonas                    (D040143)
# B03.510.024.232  Clavibacter                     (D000086162)
# B03.510.024.250  Corynebacterium                 (D003352)
# B03.510.024.250.100  Brevibacterium flavum           (D040142)
# B03.510.024.250.150  Corynebacterium diphtheriae     (D003353)
# B03.510.024.250.300  Corynebacterium glutamicum      (D048230)
# B03.510.024.250.600  Corynebacterium pseudotuberculosis  (D016925)
# B03.510.024.250.625  Corynebacterium pyogenes        (D003355)
# B03.510.024.288  Dermatophilus                   (D000086182)
# B03.510.024.325  Frankia                         (D040161)
# B03.510.024.400  Gardnerella                     (D016975)
# B03.510.024.400.800  Gardnerella vaginalis           (D006194)
# B03.510.024.700  Gordonia Bacterium              (D033601)
# B03.510.024.775  Microbacterium                  (D000083822)
# B03.510.024.850  Micrococcaceae                  (D008835)
# B03.510.024.850.050  Arthrobacter                    (D001173)
# B03.510.024.850.500  Micrococcus                     (D008837)
# B03.510.024.850.500.500  Micrococcus luteus              (D016982)
# B03.510.024.850.750  Renibacterium                   (D000084402)
# B03.510.024.962  Mycobacteriaceae                (D009159)
# B03.510.024.962.500  Mycobacterium                   (D009161)
# B03.510.024.962.500.300  Mycobacterium avium             (D009162)
# B03.510.024.962.500.300.600  Mycobacterium avium subsp. paratuberculosis  (D016927)
# B03.510.024.962.500.402  Mycobacterium bovis             (D009163)
# B03.510.024.962.500.480  Mycobacterium haemophilum       (D018393)
# B03.510.024.962.500.502  Mycobacterium leprae            (D009166)
# B03.510.024.962.500.602  Mycobacterium lepraemurium      (D009167)
# B03.510.024.962.500.640  Mycobacterium phlei             (D009168)
# B03.510.024.962.500.702  Mycobacterium tuberculosis      (D009169)
# B03.510.024.962.500.720  Nontuberculous Mycobacteria     (D009170)
# B03.510.024.962.500.720.050  Mycobacterium abscessus         (D000073358)
# B03.510.024.962.500.720.100  Mycobacterium avium Complex     (D015269)
# B03.510.024.962.500.720.225  Mycobacterium chelonae          (D016926)
# B03.510.024.962.500.720.325  Mycobacterium fortuitum         (D019907)
# B03.510.024.962.500.720.400  Mycobacterium kansasii          (D019909)
# B03.510.024.962.500.720.500  Mycobacterium marinum           (D019910)
# B03.510.024.962.500.720.625  Mycobacterium scrofulaceum      (D015359)
# B03.510.024.962.500.720.662  Mycobacterium smegmatis         (D020102)
# B03.510.024.962.500.720.700  Mycobacterium ulcerans          (D019911)
# B03.510.024.962.500.720.950  Mycobacterium xenopi            (D019912)
# B03.510.024.981  Nocardiaceae                    (D009618)
# B03.510.024.981.550  Nocardia                        (D009615)
# B03.510.024.981.550.550  Nocardia asteroides             (D009616)
# B03.510.024.981.775  Rhodococcus                     (D012240)
# B03.510.024.981.775.700  Rhodococcus equi                (D016929)
# B03.510.024.986  Nocardioides                    (D000083962)
# B03.510.024.988  Nocardiopsis                    (D000086262)
# B03.510.024.990  Propionibacteriaceae            (D011423)
# B03.510.024.990.600  Propionibacterium               (D011424)
# B03.510.024.990.600.600  Propionibacterium acnes         (D011425)
# B03.510.024.990.600.800  Propionibacterium freudenreichii  (D000070002)
# B03.510.024.993  Pseudonocardia                  (D000084382)
# B03.510.024.998  Tropheryma                      (D054851)
# B03.510.400  Gram-Positive Cocci             (D006095)
# B03.510.400.200  Deinococcus                     (D034301)
# B03.510.400.630.600  Planococcus Bacteria            (D058642)
# B03.510.460  Gram-Positive Rods              (D016987)
# B03.510.460.400  Gram-Positive Asporogenous Rods  (D006093)
# B03.510.460.400.400  Gram-Positive Asporogenous Rods, Irregular  (D016988)
# B03.510.460.400.400.024  Acetobacterium                  (D045855)
# B03.510.460.400.400.049.957  Thermobifida                    (D000086324)
# B03.510.460.400.400.049.971  Thermomonospora                 (D000084442)
# B03.510.460.400.410  Gram-Positive Asporogenous Rods, Regular  (D016989)
# B03.585     Nitrogen-Fixing Bacteria        (D000072738)
# B03.585.200  Beijerinckiaceae                (D042062)
# B03.660     Proteobacteria                  (D020560)
# B03.660.050  Alphaproteobacteria             (D020561)
# B03.660.050.340  Holosporaceae                   (D042281)
# B03.660.050.350  Hyphomicrobiaceae               (D041921)
# B03.660.050.350.400  Hyphomicrobium                  (D020582)
# B03.660.050.512  Methylocystaceae                (D042083)
# B03.660.050.600  Phyllobacteriaceae              (D059127)
# B03.660.050.600.500  Mesorhizobium                   (D059128)
# B03.660.050.662.347  Liberibacter                    (D000086202)
# B03.660.050.750  Rhodobacteraceae                (D041902)
# B03.660.050.755  Rhodospirillales                (D012245)
# B03.660.050.783.500.762  Wolbachia                       (D020577)
# B03.660.050.783.875  Rickettsiaceae                  (D012287)
# B03.660.050.783.875.650  Rickettsieae                    (D016996)
# B03.660.050.783.875.650.450  Orientia                        (D000084162)
# B03.660.050.783.875.650.450.500  Orientia tsutsugamushi          (D012285)
# B03.660.050.783.875.650.650  Rickettsia                      (D012281)
# B03.660.050.783.875.650.650.040  Rickettsia akari                (D041141)
# B03.660.050.783.875.650.650.180  Rickettsia conorii              (D020114)
# B03.660.050.783.875.650.650.320  Rickettsia felis                (D041161)
# B03.660.050.783.875.650.650.600  Rickettsia prowazekii           (D012283)
# B03.660.050.783.875.650.650.650  Rickettsia rickettsii           (D012284)
# B03.660.050.783.875.650.650.810  Rickettsia typhi                (D012286)
# B03.660.050.800  Sphingomonadaceae               (D042301)
# B03.660.075  Betaproteobacteria              (D020562)
# B03.660.075.090  Burkholderiales                 (D000073556)
# B03.660.075.090.688.100  Burkholderia                    (D019117)
# B03.660.075.090.688.100.110  Burkholderia cepacia complex    (D042602)
# B03.660.075.090.688.100.110.490  Burkholderia cenocepacia        (D057508)
# B03.660.075.090.688.100.110.500  Burkholderia cepacia            (D016956)
# B03.660.075.090.688.100.355  Burkholderia gladioli           (D042725)
# B03.660.075.090.688.100.477  Burkholderia mallei             (D042726)
# B03.660.075.090.688.100.600  Burkholderia pseudomallei       (D016957)
# B03.660.075.090.688.600  Ralstonia                       (D043367)
# B03.660.075.090.688.600.600  Ralstonia pickettii             (D049920)
# B03.660.075.090.688.600.750  Ralstonia solanacearum          (D043368)
# B03.660.075.090.941  Xylophilus                      (D000086326)
# B03.660.075.400  Hydrogenophilaceae              (D043363)
# B03.660.075.655  Rhodocyclaceae                  (D043362)
# B03.660.125  Deltaproteobacteria             (D020564)
# B03.660.125.144  Desulfovibrionales              (D000076642)
# B03.660.125.500  Myxococcales                    (D009231)
# B03.660.125.500.605  Myxococcus                      (D016940)
# B03.660.125.500.605.900  Myxococcus xanthus              (D016941)
# B03.660.125.500.658  Sorangium                       (D000086323)
# B03.660.125.500.710  Stigmatella                     (D020597)
# B03.660.125.500.710.050  Stigmatella aurantiaca          (D020606)
# B03.660.150  Epsilonproteobacteria           (D020565)
# B03.660.150.235  Campylobacterales               (D000074707)
# B03.660.150.235.250  Campylobacteraceae              (D000073557)
# B03.660.150.235.500  Helicobacteraceae               (D000073569)
# B03.660.250  Gammaproteobacteria             (D020563)
# B03.660.250.018  Aeromonadales                   (D000074762)
# B03.660.250.019  Alcanivoraceae                  (D053521)
# B03.660.250.021  Alteromonadaceae                (D034241)
# B03.660.250.021.480  Marinobacter                    (D053520)
# B03.660.250.080.775  Rappaport                       (D000086322)
# B03.660.250.110  Chromatiaceae                   (D002841)
# B03.660.250.139  Dickeya                         (D000083042)
# B03.660.250.139.500  Dickeya chrysanthemi            (D016974)
# B03.660.250.540.500  Marinomonas                     (D053544)
# B03.660.250.565.600  Piscirickettsia                 (D053522)
# B03.660.250.915.930.049  Xanthomonas axonopodis          (D053532)
# B03.851     Spirochaetales                  (D013144)
# B03.900     Sulfur-Reducing Bacteria        (D016999)

# %%
import xml.etree.ElementTree as ET
from difflib import SequenceMatcher, get_close_matches

def parse_mesh_descriptors(xml_path):
    """Parse the MeSH XML and return a list of descriptors."""
    tree = ET.parse(xml_path)
    root = tree.getroot()
    descriptors = []
    for dr in root.findall('DescriptorRecord'):
        ui_el   = dr.find('DescriptorUI')
        name_el = dr.find('DescriptorName/String')
        if ui_el is None or name_el is None:
            continue
        ui   = ui_el.text
        name = name_el.text
        tree_nums = [tn.text for tn in dr.findall('TreeNumberList/TreeNumber') if tn.text]
        descriptors.append({'ui':ui, 'name':name, 'tree_numbers':tree_nums})
    return descriptors

MESH_XML = 'desc2025.xml' #from the folder
descriptors = parse_mesh_descriptors(MESH_XML)
print(f"Parsed {len(descriptors)} descriptors")
#print(descriptors)
# Out:
# Parsed 30956 descriptors

# %%
from difflib import SequenceMatcher

def find_mesh_match(input_name, name_index, n=5, cutoff=0.6):
    """
    Return matches for input_name among the MeSH bacterial names.
    Exact matches come first with score=1.0.
    Then fuzzy matches (score computed via SequenceMatcher.ratio).
    """
    key = input_name.lower()
    results = []
    if key in name_index:
        for tree_num, ui, name in name_index[key]:
            results.append((name, ui, tree_num, 1.0))
        return results

    all_names = list(name_index.keys())
    #print(all_names)
    
    close = get_close_matches(key, all_names, n=n, cutoff=cutoff)
    for cname in close:
        score = SequenceMatcher(None, key, cname).ratio()
        for tree_num, ui, name in name_index[cname]:
            results.append((name, ui, tree_num, score))
    results.sort(key=lambda x: x[3], reverse=True)
    return results

# %%
def get_bacteria_taxonomy(descriptors):
    """
    Find the descriptor with name 'Bacteria', 
    then collect every descriptor under that tree-number prefix.
    """
    prefix = None #bacteria is B03
    for d in descriptors:
        if d['name'].lower() == 'bacteria' and d['tree_numbers']:
            prefix = d['tree_numbers'][0]
            break
    if not prefix:
        raise RuntimeError("Could not find 'Bacteria' in descriptors")
    tax = {}
    for d in descriptors:
        for tn in d['tree_numbers']:
            if tn == prefix or tn.startswith(prefix + '.'):
                tax[tn] = {'ui':d['ui'], 'name':d['name']}
                break
    return tax

bacteria_tax = get_bacteria_taxonomy(descriptors)
#print(f"{len(bacteria_tax)} bacterial MeSH nodes")

# %%
def build_name_index(taxonomy):
    """
    Build a dict: lower-case name -> list of (tree#, ui, canonical name)
    """
    idx = {}
    for tree_num, info in taxonomy.items():
        key = info['name'].lower()
        idx.setdefault(key, []).append((tree_num, info['ui'], info['name']))
    return idx

name_index = build_name_index(bacteria_tax)
print(f"Indexed {len(name_index)} bacterial names")
# Out:
# Indexed 859 bacterial names

# %%
import re, json, numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

def load_taxonomy_tree(path):
    row_re = re.compile(r"^\s*(.*?)\s+\[([^\]]+)\]\s*$")
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = row_re.match(ln)
            if m:
                label, tid = m.groups()
                depth      = len(ln) - len(ln.lstrip())
                rows.append((label, tid, depth))
    return rows

TAX_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\bacteria_tree1.txt"
rows     = load_taxonomy_tree(TAX_FILE)

exact_ix  = defaultdict(list)
for lbl, tid, depth in rows:
    exact_ix[lbl.lower()].append((lbl, tid, depth))

labels_only  = [r[0] for r in rows]
vec          = TfidfVectorizer(stop_words="english")
mat          = vec.fit_transform(labels_only)

def top_cosine(term, k=5, thr=0.75):
    v   = vec.transform([term])
    sc  = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr: break
        lbl, tid, d = rows[i]
        out.append((lbl, tid, d, sc[i]))
    return out

abbr_re = re.compile(r"^([A-Z])\.\s+([A-Za-z_-]+)$")

def preprocess(term):
    term = term.replace('_', ' ')
    term = term.strip()
    return " ".join(lemmatizer.lemmatize(w) for w in term.split())

def genus_abbrev_lookup(term):
    m = abbr_re.match(term)
    if not m:
        return []
    initial, species = m.groups()
    species = species.lower()
    hits = []
    for lbl, tid, d in rows:
        if lbl.lower().endswith(' ' + species) and lbl[0].upper() == initial:
            hits.append((lbl, tid, d, 1.00))
    return hits

# %% [markdown]
# <h1>INGEST bacteria</h1>

# %%
import os
import re
import unicodedata
import json
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint

# -----------------------------------------------------------------------------
# 1. Setup paths and namespaces
# -----------------------------------------------------------------------------
path = str(Path(os.path.abspath(os.getcwd())).absolute())
json_file = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\data\train_platinum\train_platinum.json"
#json_file = os.path.join(path, "train_gold.json")

tokenized_file = os.path.join(path, "tokenized_sentences_with_entitiesv2.json")
save_path = os.path.join(path, "rdf")
os.makedirs(save_path, exist_ok=True)

GUTBRAIN = Namespace("https://hereditary.dei.unipd.it/ontology/gutbrain/resource/")
GUTPROP = Namespace("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/")

PAPER_CLASS       = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Paper")
MENTION_CLASS     = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Mention")
PAPER_ABSTRACT    = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/PaperAbstract")
PAPER_TITLE       = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/PaperTitle")
PAPER_COLLECTION  = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/PaperCollection")
PROJECT           = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Project")
SAMPLE            = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Sample")
SENTENCE          = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Sentence")

# -----------------------------------------------------------------------------
# 2. Load the JSON paper data
# -----------------------------------------------------------------------------
with open(json_file, "r", encoding="utf-8") as f:
    data = json.load(f)
# -----------------------------------------------------------------------------
# 3. Mapping dictionaries (keys must be in Title case)
# -----------------------------------------------------------------------------
label_mapping = {
    "Anatomical Location":   URIRef("https://w3id.org/brainteaser/ontology/schema/AnatomicalSite"),
    "Animal":                URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Animal"),
    "Biomedical Technique":  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/BiomedicalTechnique"),
    "Bacteria":              URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Species"),
    "Chemical":              URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Chemical"),
    "Dietary Supplement":    URIRef("https://w3id.org/brainteaser/ontology/schema/DietarySupplement"),
    "DDF":                   URIRef("https://w3id.org/brainteaser/ontology/schema/DiseaseDisorderOrFinding"),
    "Drug":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Drug"),
    "Food":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Food"),
    "Gene":                  URIRef("https://w3id.org/brainteaser/ontology/schema/Gene"),
    "Human":                 URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Human"),
    "Microbiome":            URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Microbiome"),
    "Statistical Technique": URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/StatisticalTechnique")
}
concept_scheme_mapping = {
    "Anatomical Location":   URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/AnatomicSite"),
    "Animal":                URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Animal"),
    "Human":                 URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Human"),
    "Drug":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Drug"),
    "Gene":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Gene"),
    "Dietary Supplement":    URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/DietarySupplement"),
    "DDF":                   URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/DiseaseDisorderOrFindingTaxonomy"),
    "Metabolite":            URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Metabolite"),
    "Bacteria":               URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Bacteria"),
    "Food":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Food"),
    "Chemical":              URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Chemical"),
    "Biomedical Technique":  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/BiomedicalTechnique"),
    "Microbiome":            URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Microbiome"),
    "Statistical Technique": URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/StatisticalTechnique")
}

# -----------------------------------------------------------------------------
# 4. Initialize the RDF graph and bind namespaces
# -----------------------------------------------------------------------------
BACTERIA_CLASS = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Species")
FAMILY_CLASS = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Family")
OBO_BASE = "http://purl.obolibrary.org/obo/"
MESH_BASE = "https://www.ncbi.nlm.nih.gov/mesh/"
BACTERIA_CONCEPT_SCHEME = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Bacteria")

g = Graph()
g.bind("gutbrain", GUTBRAIN)
g.bind("rdfs", RDFS)
g.bind("xsd", XSD)
g.bind("skos", SKOS)
g.bind("owl", OWL)
g.bind("gutprop", GUTPROP)

g.add((SKOS.inScheme, RDF.type, OWL.ObjectProperty))
g.add((SKOS.broaderTransitive, RDF.type, OWL.ObjectProperty))

g.add((GUTPROP.partOf, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.partOf, RDFS.label, Literal("partOf", datatype=XSD.string)))
g.add((GUTPROP.hasTitle, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.hasTitle, RDFS.label, Literal("hasTitle", datatype=XSD.string)))
g.add((GUTPROP.hasAbstract, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.hasAbstract, RDFS.label, Literal("hasAbstract", datatype=XSD.string)))

g.add((GUTPROP.containedIn, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.containedIn, RDFS.label, Literal("containedIn", datatype=XSD.string)))
g.add((GUTBRAIN.contains, RDF.type, OWL.ObjectProperty))
g.add((GUTBRAIN.contains, RDFS.label, Literal("contains", datatype=XSD.string)))
g.add((GUTPROP.composedOf, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.composedOf, RDFS.label, Literal("composedOf", datatype=XSD.string)))

g.add((GUTPROP.locatedIn, RDF.type, OWL.ObjectProperty))
g.add((GUTPROP.locatedIn, RDFS.label, Literal("locatedIn", datatype=XSD.string)))

g.add((GUTPROP.paperId, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.paperId, RDFS.label, Literal("paperId", datatype=XSD.string)))
g.add((GUTPROP.paperAnnotator, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.paperAnnotator, RDFS.label, Literal("paperAnnotator", datatype=XSD.string)))
g.add((GUTPROP.paperYear, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.paperYear, RDFS.label, Literal("paperYear", datatype=XSD.string)))
g.add((GUTPROP.paperJournal, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.paperJournal, RDFS.label, Literal("paperJournal", datatype=XSD.string)))
g.add((GUTPROP.paperAuthor, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.paperAuthor, RDFS.label, Literal("paperAuthor", datatype=XSD.string)))
g.add((GUTPROP.numberOfRunsFound, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.numberOfRunsFound, RDFS.label, Literal("numberOfRunsFound", datatype=XSD.string)))
g.add((GUTPROP.NCBITaxonID, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.NCBITaxonID, RDFS.label, Literal("NCBITaxonID", datatype=XSD.string)))
g.add((GUTPROP.sdRelativeAbundance, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.sdRelativeAbundance, RDFS.label, Literal("sdRelativeAbundance", datatype=XSD.string)))
g.add((GUTPROP.medianRelativeAbundance, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.medianRelativeAbundance, RDFS.label, Literal("medianRelativeAbundance", datatype=XSD.string)))
g.add((GUTPROP.meanRelativeAbundance, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.meanRelativeAbundance, RDFS.label, Literal("meanRelativeAbundance", datatype=XSD.string)))
g.add((GUTPROP.scientificName, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.scientificName, RDFS.label, Literal("scientificName", datatype=XSD.string)))
g.add((GUTPROP.hasMentionText, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.hasMentionText, RDFS.label, Literal("hasMentionText", datatype=XSD.string)))
g.add((GUTPROP.hasSentenceText, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.hasSentenceText, RDFS.label, Literal("hasSentenceText", datatype=XSD.string)))
g.add((GUTPROP.hasTitleText, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.hasTitleText, RDFS.label, Literal("hasTitleText", datatype=XSD.string)))
g.add((GUTPROP.hasAbstractText, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.hasAbstractText, RDFS.label, Literal("taggedAs", datatype=XSD.string)))
g.add((GUTPROP.taggedAs, RDF.type, OWL.DatatypeProperty))
g.add((GUTPROP.taggedAs, RDFS.label, Literal("taggedAs", datatype=XSD.string)))

for scheme_uri in set(concept_scheme_mapping.values()):
    keys = [k for k, v in concept_scheme_mapping.items() if v == scheme_uri]
    label_text = ", ".join(k.title() for k in keys) + " Concept Scheme"
    g.add((scheme_uri, RDF.type, SKOS.ConceptScheme))
    g.add((scheme_uri, RDFS.label, Literal(label_text, datatype=XSD.string)))

is_train_platinum = "train_platinum" in os.path.basename(json_file)
#is_train_gold = "train_gold" in os.path.basename(json_file)

#if is_train_gold:
 #   gold_collection_uri = URIRef(GUTBRAIN["goldCollection"])
 #   label_text = "goldCollection"
  #  g.add((gold_collection_uri, RDF.type, PAPER_COLLECTION))
   # g.add((gold_collection_uri, RDFS.label, Literal(label_text, datatype=XSD.string)))
    
if is_train_platinum:
    platinum_collection_uri = URIRef(GUTBRAIN["platinumCollection"])
    label_text = "platinumCollection"
    g.add((platinum_collection_uri, RDF.type, PAPER_COLLECTION))
    g.add((platinum_collection_uri, RDFS.label, Literal(label_text, datatype=XSD.string)))

def create_uri_fragment(text):
    cleaned = re.sub(r'<[^>]*>', '', text)
    cleaned = normalize_text(cleaned)
    cleaned = re.sub(r'[^\w\u0370-\u03FF-]', '_', cleaned)
    return cleaned

def to_camel_case(s):
    s = re.sub(r'[^\w\s]', '', s)
    parts = re.split(r'\s+', s.strip())
    if not parts:
        return ""
    return parts[0].lower() + ''.join(word.title() for word in parts[1:])

def normalize_text(text):
    return unicodedata.normalize('NFC', text)

def normalize_to_ascii(s: str) -> str:
    nfkd = unicodedata.normalize('NFKD', s)
    ascii_bytes = nfkd.encode('ascii', 'ignore')
    return ascii_bytes.decode('ascii')

def singularize(term):
    if term.endswith("ies"):
        return term[:-3] + "y"
    elif term.endswith("s") and not term.endswith("ss"):
        return term[:-1]
    return term

tokenized_mentions = {}
created = {}
label2uri = {}

created["Bacteria"] = URIRef(f"{OBO_BASE}NCBITaxon_2")
g.add((created["Bacteria"], RDF.type, FAMILY_CLASS))
g.add((created["Bacteria"], RDF.type, SKOS.Concept))
g.add((created["Bacteria"], RDFS.label, Literal("Bacteria", datatype=XSD.string)))
g.add((created["Bacteria"], SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))

# -----------------------------------------------------------------------------
# 5. Process each paper (each key in the JSON represents a paper)
# -----------------------------------------------------------------------------
for paper_id, paper_data in data.items():
    paper_uri = URIRef(GUTBRAIN[f"paper_{paper_id}"])
    g.add((paper_uri, RDF.type, PAPER_CLASS))
    
    if is_train_platinum:
        g.add((paper_uri, GUTPROP.partOf, platinum_collection_uri))
        g.add((platinum_collection_uri, GUTBRAIN.contains, paper_uri))

    #if is_train_gold:
    #    g.add((paper_uri, GUTPROP.partOf, gold_collection_uri))
    #    g.add((gold_collection_uri, GUTBRAIN.contains, paper_uri))
    
    # Each paper gets its own mention node
    #paper_mention = URIRef(GUTBRAIN[f"mention_{paper_id}"])
    #g.add((paper_mention, RDF.type, MENTION_CLASS))
    #g.add((paper_uri, GUTPROP.hasMention, paper_mention))
    
    metadata = paper_data.get("metadata", {})
    full_title = metadata.get("title", None)
    full_abstract = metadata.get("abstract", None)
    try:
        paper_id_val = int(paper_id)
    except ValueError:
        paper_id_val = paper_id
    paper_annotator = metadata.get("annotator", None)
    paper_year = metadata.get("year", None)
    paper_journal = metadata.get("journal", None)
    paper_author = metadata.get("author", None)
    
    g.add((paper_uri, GUTPROP.paperId, Literal(paper_id_val, datatype=XSD.integer)))
    if paper_annotator is not None:
        g.add((paper_uri, GUTPROP.paperAnnotator, Literal(paper_annotator, datatype=XSD.string)))
    if paper_year is not None:
        g.add((paper_uri, GUTPROP.paperYear, Literal(paper_year, datatype=XSD.gYear)))
    if paper_journal is not None:
        g.add((paper_uri, GUTPROP.paperJournal, Literal(paper_journal, datatype=XSD.string)))
    if paper_author is not None:
        g.add((paper_uri, GUTPROP.paperAuthor, Literal(paper_author, datatype=XSD.string)))
    
    title_texts = []
    abstract_texts = []
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        label_title = raw_label.title() if raw_label.lower() != "ddf" else "DDF"
        
        text_span = entity.get("text_span", "").strip()
        cleaned_text = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(cleaned_text)
        
        if label_title == "Bacteria":
            if cleaned_text_span.lower().endswith(" bacteria"):
                term_raw = "Bacteria"
            elif cleaned_text_span.lower().endswith(" Bifidobacterium"):
                term_raw = "Bifidobacterium"
            else:
                term_raw = cleaned_text_span
                
            term = preprocess(term_raw)
            
            print(f"Query: {term}")
            
            if term_raw in created:
                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                continue
                
            hits = genus_abbrev_lookup(term)
            if hits:
                for l,t,d,s in hits: 
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f} (abbr)")
                    entity_uri = URIRef(f"{OBO_BASE}{t}")
                    created[term_raw] = entity_uri
                    label2uri[label_name.lower()] = entity_uri
                    g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(label_name, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                    g.add((entity_uri, SKOS.broaderTransitive, created["Bacteria"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title.lower(), datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    continue

            ex = exact_ix.get(term.lower(), [])
            if ex:
                for label_name, taxon_id, depth in ex:
                    print(f"  • {label_name:40s} ID={taxon_id:15s} depth={depth:<2d} (exact)")
                    entity_uri = URIRef(f"{OBO_BASE}{taxon_id}")
                    created[term_raw] = entity_uri
                    label2uri[label_name.lower()] = entity_uri
                    g.add((entity_uri, RDF.type, BACTERIA_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(label_name, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                    g.add((entity_uri, SKOS.broaderTransitive, created["Bacteria"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title.lower(), datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            cos = top_cosine(term)
            if not cos:
                matches = find_mesh_match(term, name_index)
                if matches: 
                    for name, ui, tree, score in matches[:1]:
                        name_key = name.lower()
                        reused = False
                        if name_key in label2uri:
                            entity_uri = label2uri[name_key]
                            print(f"  → Reusing existing URI by label: {entity_uri}\n")
                            reused = True
                            continue
                        if reused:
                            break
                            
                        print(f"  • {name:30s} UI={ui:8s} Tree={tree:12s}  scoreMESH={score:.2f}")
                        name_uri = URIRef(f"{MESH_BASE}{ui}")
                        created[term_raw] = name_uri
                        label2uri[name_key] = name_uri
                        g.add((name_uri, RDF.type, BACTERIA_CLASS))
                        g.add((name_uri, RDF.type, SKOS.Concept))
                        g.add((name_uri, RDFS.label, Literal(name, datatype=XSD.string)))
                        g.add((name_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                        g.add((name_uri, SKOS.broaderTransitive, created["Bacteria"]))
                        mention_uri = URIRef(GUTBRAIN[term_raw])
                        g.add((mention_uri, RDF.type, MENTION_CLASS))
                        g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                        g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                        g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title.lower(), datatype=XSD.string)))
                        g.add((name_uri, GUTPROP.containedIn, mention_uri))
                        tokenized_mentions[term_raw] = mention_uri
                        continue
                else:
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title.lower(), datatype=XSD.string)))
                    g.add((created["Bacteria"], GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    
            else:
                for l,t,d,s in cos[:1]:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f}")
                    name_uri = URIRef(f"{OBO_BASE}{t}")
                    created[term_raw] = name_uri
                    label2uri[label_name.lower()] = name_uri
                    g.add((name_uri, RDF.type, BACTERIA_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(l, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, BACTERIA_CONCEPT_SCHEME))
                    g.add((name_uri, SKOS.broaderTransitive, created["Bacteria"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(label_title.lower(), datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                print()
        
        location_lower = entity.get("location", "").strip().lower()
        if location_lower == "title":
            title_texts.append(cleaned_text_span)
        elif location_lower == "abstract":
            abstract_texts.append(cleaned_text_span)

        else:
            pass
    
    if full_title is None and title_texts:
        full_title = " ".join(title_texts)
    if full_abstract is None and abstract_texts:
        full_abstract = " ".join(abstract_texts)
    
    if full_title:
        title_uri = URIRef(GUTBRAIN[f"title_{paper_id}"])
        g.add((title_uri, RDF.type, PAPER_TITLE))
        g.add((title_uri, GUTPROP.hasTitleText, Literal(full_title, datatype=XSD.string)))
        g.add((paper_uri, GUTPROP.hasTitle, title_uri))
    
    if full_abstract:
        abstract_uri = URIRef(GUTBRAIN[f"abstract_{paper_id}"])
        g.add((abstract_uri, RDF.type, PAPER_ABSTRACT))
        g.add((abstract_uri, GUTPROP.hasAbstractText, Literal(full_abstract, datatype=XSD.string)))
        g.add((paper_uri, GUTPROP.hasAbstract, abstract_uri))
    
    # Process relations
    #relations = paper_data.get("relations", [])
    #for relation in relations:
        #subj_text = relation.get("subject_text_span", "").strip()
        #cleaned_subj_text = re.sub(r'<[^>]*>', '', subj_text).strip()
        #subj_fragment = create_uri_fragment(cleaned_subj_text)
        #subj_uri = URIRef(GUTBRAIN[subj_fragment])
        #if not list(g.triples((subj_uri, None, None))):
           # print(f"Warning: Subject not recognized: {subj_uri}. Info: '{cleaned_subj_text}'")
        
        #obj_text = relation.get("object_text_span", "").strip()
        #cleaned_obj_text = re.sub(r'<[^>]*>', '', obj_text).strip()
        #obj_fragment = create_uri_fragment(cleaned_obj_text)
        #obj_uri = URIRef(GUTBRAIN[obj_fragment])
        #if not list(g.triples((obj_uri, None, None))):
            #print(f"Warning: Object not recognized: {obj_uri}. Info: '{cleaned_obj_text}'")
        
        #pred_text = relation.get("predicate", "").strip()
        #pred_text_clean = to_camel_case(pred_text)
        #pred_uri = URIRef(GUTPROP[pred_text_clean])
        #print(f"Predicate: '{pred_text}' -> '{pred_text_clean}'")
        #g.add((pred_uri, RDF.type, OWL.ObjectProperty))
        #g.add((pred_uri, RDFS.label, Literal(pred_text_clean, datatype=XSD.string)))
       # g.add((subj_uri, pred_uri, obj_uri))

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAIN[f"title_{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAIN[f"abstract_{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue 

        if label != "bacteria":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical)
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAIN[cleaned_text_span])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_bacteria_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))
# Out:
# Query: Veillonella
#   • Veillonella                              ID=NCBITaxon_29465 depth=12 (exact)
#   • Veillonella                              ID=NCBITaxon_29465 depth=12 score=1.00
#
# Query: Roseburia
#   • Roseburia                                ID=NCBITaxon_841   depth=12 (exact)
#   • Roseburia                                ID=NCBITaxon_841   depth=12 score=1.00
#
# Query: Christensenellaceae R-7 group
#   • Christensenellaceae                      ID=NCBITaxon_990719 depth=10 score=0.87
#
# Query: Subdoligranulum
#   • Subdoligranulum                          ID=NCBITaxon_292632 depth=12 (exact)
#   • Subdoligranulum                          ID=NCBITaxon_292632 depth=12 score=1.00
#
# Query: Oscillibacter
#   • Oscillibacter                            ID=NCBITaxon_459786 depth=12 (exact)
#   • Oscillibacter                            ID=NCBITaxon_459786 depth=12 score=1.00
#
# Query: UCG-005
#   • Ruminococcaceae bacterium UCG-005        ID=NCBITaxon_3068309 depth=14 score=0.87
#
# Query: acetate-producing bacteria
#   • Actinobacteria                 UI=D039903  Tree=B03.510.024   scoreMESH=0.65
# Query: acetate-producing bacteria
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D039903
#
# Query: bacteria
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  (exact)
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  score=1.00
#
# Query: oral bacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# Query: Lactobacillus plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.76
#
# Query: live and inactivated Lactobacillus plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.76
#
# Query: live L plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#
# Query: live L plantarum CCFM8661
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: inactivated L plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#
# Query: live and inactivated L plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#
# Query: Staphylococcus
#   • Staphylococcus                           ID=NCBITaxon_1279  depth=12 (exact)
#   • Staphylococcus                           ID=NCBITaxon_1279  depth=12 score=1.00
#
# Query: L plantarum CCFM8661
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#
# Query: Lactobacillaceae
#   • Lactobacillaceae                         ID=NCBITaxon_33958 depth=10 (exact)
#   • Lactobacillaceae                         ID=NCBITaxon_33958 depth=10 score=1.00
#
# Query: Lachnospiraceae
#   • Lachnospiraceae                          ID=NCBITaxon_186803 depth=10 (exact)
#   • Lachnospiraceae                          ID=NCBITaxon_186803 depth=10 score=1.00
#
# Query: Lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_186803
#
# Query: Ruminococcaceae
#   • Ruminococcaceae bacterium enrichment culture ID=NCBITaxon_1776336 depth=14 score=0.80
#
# Query: Levilactobacillus brevis
#   • Levilactobacillus brevis                 ID=NCBITaxon_1580  depth=14 (exact)
#   • Levilactobacillus brevis                 ID=NCBITaxon_1580  depth=14 score=1.00
#
# Query: Lactiplantibacillus plantarum
#   • Lactiplantibacillus plantarum            ID=NCBITaxon_1590  depth=14 (exact)
#   • Lactiplantibacillus plantarum            ID=NCBITaxon_1590  depth=14 score=1.00
#
# Query: Lacticaseibacillus paracasei
#   • Lacticaseibacillus paracasei             ID=NCBITaxon_1597  depth=14 (exact)
#   • Lacticaseibacillus paracasei             ID=NCBITaxon_1597  depth=14 score=1.00
#
# Query: Ligilactobacillus salivarius
#   • Ligilactobacillus salivarius             ID=NCBITaxon_1624  depth=14 (exact)
#   • Ligilactobacillus salivarius             ID=NCBITaxon_1624  depth=14 score=1.00
#
# Query: Streptococcus thermophilus
#   • Streptococcus thermophilus               ID=NCBITaxon_1308  depth=14 (exact)
#   • Streptococcus thermophilus               ID=NCBITaxon_1308  depth=14 score=1.00
#
# Query: L brevis P30021
#   • Paenibacillus brevis                     ID=NCBITaxon_2841508 depth=14 score=0.88
#
# Query: L plantarum P30025
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#
# Query: Veillonellaceae
#   • Veillonellaceae                          ID=NCBITaxon_31977 depth=10 (exact)
#   • Veillonellaceae                          ID=NCBITaxon_31977 depth=10 score=1.00
#
# Query: Bacteroides
#   • Bacteroides                              ID=NCBITaxon_816   depth=16 (exact)
#   • Bacteroides                              ID=NCBITaxon_816   depth=16 score=1.00
#
# Query: Proteobacteria
#   • Proteobacteria                 UI=D020560  Tree=B03.660       scoreMESH=1.00
# Query: Succinivibrio
#   • Succinivibrio                            ID=NCBITaxon_83770 depth=12 (exact)
#   • Succinivibrio                            ID=NCBITaxon_83770 depth=12 score=1.00
#
# Query: Megasphaera
#   • Megasphaera                              ID=NCBITaxon_906   depth=12 (exact)
#   • Megasphaera                              ID=NCBITaxon_906   depth=12 score=1.00
#
# Query: Collinsella
#   • Collinsella                              ID=NCBITaxon_102106 depth=12 (exact)
#   • Collinsella                              ID=NCBITaxon_102106 depth=12 score=1.00
#
# Query: Clostridium
#   • Clostridium                              ID=NCBITaxon_1485  depth=12 (exact)
#   • Clostridium                              ID=NCBITaxon_1485  depth=12 score=1.00
#
# Query: Klebsiella
#   • Klebsiella                               ID=NCBITaxon_570   depth=14 (exact)
#   • Klebsiella                               ID=NCBITaxon_570   depth=14 score=1.00
#
# Query: Methanobrevibacter
#   • Brevibacterium                 UI=D001951  Tree=B03.510.024.175  scoreMESH=0.69
# Query: Blautia
#   • Blautia                                  ID=NCBITaxon_572511 depth=12 (exact)
#   • Blautia                                  ID=NCBITaxon_572511 depth=12 score=1.00
#
# Query: Coprococcus
#   • Coprococcus                              ID=NCBITaxon_33042 depth=12 (exact)
#   • Coprococcus                              ID=NCBITaxon_33042 depth=12 score=1.00
#
# Query: Roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_841
#
# Query: Lactobacillus
#   • Lactobacillus                            ID=NCBITaxon_1578  depth=12 (exact)
#   • Lactobacillus                            ID=NCBITaxon_1578  depth=12 score=1.00
#
# Query: L
# Query: plantarum P-8
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.89
#
# Query: Bifidobacterium adolescentis
#   • Bifidobacterium adolescentis             ID=NCBITaxon_1680  depth=14 (exact)
#   • Bifidobacterium adolescentis             ID=NCBITaxon_1680  depth=14 score=1.00
#
# Query: Bifidobacterium longum
#   • Bifidobacterium longum                   ID=NCBITaxon_216816 depth=14 (exact)
#   • Bifidobacterium longum                   ID=NCBITaxon_216816 depth=14 score=1.00
#
# Query: Fecalibacterium prausnitzii
#   • Faecalibacterium prausnitzii             ID=NCBITaxon_853   depth=14 score=0.79
#
# Query: Roseburia faecis
#   • Roseburia faecis                         ID=NCBITaxon_301302 depth=14 (exact)
#   • Roseburia faecis                         ID=NCBITaxon_301302 depth=14 score=1.00
#
# Query: Fusicatenibacter saccharivorans
#   • Fusicatenibacter saccharivorans          ID=NCBITaxon_1150298 depth=14 (exact)
#   • Fusicatenibacter saccharivorans          ID=NCBITaxon_1150298 depth=14 score=1.00
#
# Query: Bacteroidaceae and Porphyromonadaceae family
# Query: Rikencellaceae
#   • Brucellaceae                   UI=D042021  Tree=B03.440.400.425.215  scoreMESH=0.77
# Query: S24-7
#   • bacterium S24                            ID=NCBITaxon_1315627 depth=4  score=0.97
#
# Query: bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2
#
# Query: Lactococcus
#   • Lactococcus                              ID=NCBITaxon_1357  depth=12 (exact)
#   • Lactococcus                              ID=NCBITaxon_1357  depth=12 score=1.00
#
# Query: Biffdobacterium
#   • Bifidobacterium                UI=D001644  Tree=B03.510.024.100  scoreMESH=0.93
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# Query: Biffdobacterium
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D001644
#
# Query: Lactobacillus helveticus R0052
#   • Lactobacillus helveticus R0052           ID=NCBITaxon_880633 depth=16 (exact)
#   • Lactobacillus helveticus R0052           ID=NCBITaxon_880633 depth=16 score=1.00
#
# Query: Lactobacillus plantarum R1012
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.76
#
# Query: Bifidobacterium longum R0175
#   • Bifidobacterium longum                   ID=NCBITaxon_216816 depth=14 score=1.00
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# Query: Lactobacillus specie
#   • Lactobacillus                            ID=NCBITaxon_1578  depth=12 score=1.00
#
# Query: Gut Bacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: Escherichia coli
#   • Escherichia coli                         ID=NCBITaxon_562   depth=14 (exact)
#   • Escherichia coli W                       ID=NCBITaxon_566546 depth=16 score=1.00
#
# Query: Enterobacter cloaca
#   • Enterobacter                             ID=NCBITaxon_547   depth=12 score=1.00
#
# Query: maternal vaginal microbe
# Query: Bifidobacteria
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D001644
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# Query: Bifidobacterium
#   • Bifidobacterium                          ID=NCBITaxon_1678  depth=12 (exact)
#   • Bifidobacterium                          ID=NCBITaxon_1678  depth=12 score=1.00
#
# Query: Verrucomicrobiaceae
#   • Verrucomicrobiaceae                      ID=NCBITaxon_203557 depth=12 (exact)
#   • Verrucomicrobiaceae                      ID=NCBITaxon_203557 depth=12 score=1.00
#
# Query: Akkermansia
#   • Akkermansia                              ID=NCBITaxon_239934 depth=14 (exact)
#   • Akkermansia                              ID=NCBITaxon_239934 depth=14 score=1.00
#
# Query: Faecalibacterium
#   • Faecalibacterium                         ID=NCBITaxon_216851 depth=12 (exact)
#   • Faecalibacterium                         ID=NCBITaxon_216851 depth=12 score=1.00
#
# Query: Coprococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_33042
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
# Query: Prevotella
#   • Prevotella                               ID=NCBITaxon_838   depth=16 (exact)
#   • Prevotella                               ID=NCBITaxon_838   depth=16 score=1.00
#
# Query: Prevotellaceae
#   • Prevotellaceae                           ID=NCBITaxon_171552 depth=14 (exact)
#   • Prevotellaceae                           ID=NCBITaxon_171552 depth=14 score=1.00
#
# Query: Bacteroidetes
#   • Bacteroidetes bacterium 5-4              ID=NCBITaxon_226197 depth=12 score=0.93
#
# Query: Proteobacteria
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D020560
#
# Query: Helicobacter pylorus
#   • Helicobacter                             ID=NCBITaxon_209   depth=12 score=1.00
#
# Query: Bacteroidetes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_226197
#
# Query: Actinobacteria
#   • Actinobacteria bacterium HGW-Actinobacteria-9 ID=NCBITaxon_2013654 depth=8  score=0.87
#
# Query: Firmicutes
#   • Bacillus <firmicutes>                    ID=NCBITaxon_1386  depth=12 score=0.87
#
# Query: microbe
#   • Microbacterium                 UI=D000083822 Tree=B03.510.024.775  scoreMESH=0.67
# Query: firmicutes
#   • Bacillus <firmicutes>                    ID=NCBITaxon_1386  depth=12 score=0.87
#
# Query: coliform
#   • coliform bacterium S1/7                  ID=NCBITaxon_464824 depth=4  score=0.78
#
# Query: bacteroides
#   • Bacteroides                              ID=NCBITaxon_816   depth=16 (exact)
#   • Bacteroides                              ID=NCBITaxon_816   depth=16 score=1.00
#
# Query: firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_816
#
# Query: firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: gut bacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: Toxoplasma gondii
#   • Mycoplasma genitalium          UI=D045704  Tree=B03.440.860.580.553.553.355  scoreMESH=0.63
# Query: Lachnospiraceae family
#   • Leptospiraceae                 UI=D016953  Tree=B03.440.400.425.475  scoreMESH=0.61
# Query: bifidobacterial population
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: gut Bifidobacterium
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# Query: Bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Akkermansias
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_239934
#
# Query: Desulfovibrio
#   • Desulfovibrio                            ID=NCBITaxon_872   depth=12 (exact)
#   • Desulfovibrio                            ID=NCBITaxon_872   depth=12 score=1.00
#
# Query: Klebsiella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_570
#
# Query: Akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_239934
#
# Query: Lactobacillus plantarum
#   • Acinetobacter plantarum                  ID=NCBITaxon_1591090 depth=14 score=0.76
#
# Query: GABA-producing bacteria
#   • Sulfur-Reducing Bacteria       UI=D016999  Tree=B03.900       scoreMESH=0.72
# Query: Lactobacillus plantarum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: Odoribacter
#   • Odoribacter                              ID=NCBITaxon_283168 depth=16 (exact)
#   • Odoribacter                              ID=NCBITaxon_283168 depth=16 score=1.00
#
# Query: Oscillibacter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_459786
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
# Query: Bifidobacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Clostridium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1485
#
# Query: Lachnospiraceae NK4A136 group
#   • Lachnospiraceae bacterium NK4A136        ID=NCBITaxon_877420 depth=14 score=0.90
#
# Query: Subdoligranulum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_292632
#
# Query: Faecalibacterium prausnitzii
#   • Faecalibacterium prausnitzii             ID=NCBITaxon_853   depth=14 (exact)
#   • Faecalibacterium prausnitzii             ID=NCBITaxon_853   depth=14 score=1.00
#
# Query: Corynebacterium
#   • Corynebacterium                          ID=NCBITaxon_1716  depth=12 (exact)
#   • Corynebacterium                          ID=NCBITaxon_1716  depth=12 score=1.00
#
# Query: Ruminococcaceae Incertae Sedis
#   • uncultured incertae sedis 5 bacterium    ID=NCBITaxon_412050 depth=4  score=0.77
#
# Query: Fusobacterium
#   • Fusobacterium                            ID=NCBITaxon_848   depth=12 (exact)
#   • Fusobacterium                            ID=NCBITaxon_848   depth=12 score=1.00
#
# Query: Corynebacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1716
#
# Query: Ruminococcaceae Incertae Sedis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_412050
#
# Query: microorganism
# Query: intestinal bacteria
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D039903
#
# Query: Verrucomicrobia
#   • Verrucomicrobia bacterium B-1-8          ID=NCBITaxon_747582 depth=10 score=0.94
#
# Query: Mucispirillum
#   • Mucispirillum                            ID=NCBITaxon_248038 depth=12 (exact)
#   • Mucispirillum                            ID=NCBITaxon_248038 depth=12 score=1.00
#
# Query: Porphyromonas
#   • Porphyromonas                            ID=NCBITaxon_836   depth=16 (exact)
#   • Porphyromonas                            ID=NCBITaxon_836   depth=16 score=1.00
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# Query: Parabacteroides
#   • Parabacteroides                          ID=NCBITaxon_375288 depth=16 (exact)
#   • Parabacteroides                          ID=NCBITaxon_375288 depth=16 score=1.00
#
# Query: Prevotella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_838
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_816
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_816
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_816
#
# Query: Verrucomicrobia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_747582
#
# Query: Lactobacillus fermentum PS150
#   • Limosilactobacillus fermentum  UI=D052197  Tree=B03.353.750.450.672  scoreMESH=0.79
# Query: hypnotic psychobiotic strain
# Query: Psychobiotics
#   • Synechocystis                  UI=D046939  Tree=B03.280.750   scoreMESH=0.62
# Query: probiotic
# Query: psychobiotic strain
# Query: Lactobacillus fermentum PS150
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D052197
#
# Query: PS150
# Query: L fermentum strain
# Query: GR1009
# Query: PS150
# Query: GR1009
# Query: PS150
# Query: PS150
# Query: GR1009
# Query: heat-killed PS150
# Query: GR1009
# Query: PS150
# Query: PS150
# Query: GR1009
# Query: PS150
# Query: GR1009
# Query: GR1009
# Query: PS150
# Query: PS150
# Query: PS150
# Query: GR1009
# Query: EC Ruminococcus torque
#   • Ruminococcus                   UI=D045857  Tree=B03.353.625.806  scoreMESH=0.71
# Query: Coprococcus come
#   • Coprococcus                              ID=NCBITaxon_33042 depth=12 score=1.00
#
# Query: Megasphaera elsdenii
#   • Megasphaera elsdenii                     ID=NCBITaxon_907   depth=14 (exact)
#   • Megasphaera elsdenii                     ID=NCBITaxon_907   depth=14 score=1.00
#
# Query: Acidaminococcus intestini
#   • Acidaminococcus intestini                ID=NCBITaxon_187327 depth=14 (exact)
#   • Acidaminococcus intestini                ID=NCBITaxon_187327 depth=14 score=1.00
#
# Query: Barnesiella viscericola
#   • Barnesiella viscericola                  ID=NCBITaxon_397865 depth=18 (exact)
#   • Barnesiella viscericola                  ID=NCBITaxon_397865 depth=18 score=1.00
#
# Query: Bacteroides eggerthii
#   • Bacteroides eggerthii                    ID=NCBITaxon_28111 depth=18 (exact)
#   • Bacteroides eggerthii                    ID=NCBITaxon_28111 depth=18 score=1.00
#
# Query: Gut Bacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: Gut bacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: mucus-associated specie
# Query: Desulfovibrionaceae
#   • Desulfovibrionaceae                      ID=NCBITaxon_194924 depth=10 (exact)
#   • Desulfovibrionaceae                      ID=NCBITaxon_194924 depth=10 score=1.00
#
# Query: Enterobacteriaceae
#   • Enterobacteriaceae                       ID=NCBITaxon_543   depth=10 (exact)
#   • Enterobacteriaceae                       ID=NCBITaxon_543   depth=10 score=1.00
#
# Query: Turicibacter
#   • Turicibacter                             ID=NCBITaxon_191303 depth=12 (exact)
#   • Turicibacter                             ID=NCBITaxon_191303 depth=12 score=1.00
#
# Query: Coprococcus 1
#   • Coprococcus                              ID=NCBITaxon_33042 depth=12 score=1.00
#
# Query: Lachnospiraceae FCS020 group
#   • bacterium FCS020                         ID=NCBITaxon_1451755 depth=4  score=0.78
#
# Query: Eggerthellaceae
#   • Eggerthellaceae                          ID=NCBITaxon_1643826 depth=10 (exact)
#   • Eggerthellaceae                          ID=NCBITaxon_1643826 depth=10 score=1.00
#
# Query: Turicibacter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_191303
#
# Query: Coprococcus 1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_33042
#
# Query: Eggerthellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1643826
#
# Query: Clostridium sp BR31
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1485
#
# Query: Turicibacter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_191303
#
# Query: Coprococcus 1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_33042
#
# Query: Eggerthellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1643826
#
# Query: Clostridium sp BR31
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1485
#
# Query: Bacteroidetes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_226197
#
# Query: Actinobacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2013654
#
# Query: Bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Lactobacillus reuteri NK33
#   • Limosilactobacillus reuteri    UI=D052200  Tree=B03.353.750.450.705  scoreMESH=0.79
# Query: Bifidobacterium adolescentis NK98
#   • Bifidobacterium adolescentis             ID=NCBITaxon_1680  depth=14 score=1.00
#
# Query: Bifidobacteriaceae
#   • Bifidobacteriaceae                       ID=NCBITaxon_31953 depth=10 (exact)
#   • Bifidobacteriaceae                       ID=NCBITaxon_31953 depth=10 score=1.00
#
# Query: Lactobacillacea
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_33958
#
# Query: Enterobacteriaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_543
#
# Query: Lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_186803
#
# Query: Odoribacter
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_283168
#
# Query: cancer-related bacteria
#   • Gram-Negative Bacteria         UI=D006090  Tree=B03.440       scoreMESH=0.67
# Query: Helicobacter
#   • Helicobacter                             ID=NCBITaxon_209   depth=12 (exact)
#   • Helicobacter                             ID=NCBITaxon_209   depth=12 score=1.00
#
# Query: Lactococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1357
#
# Query: Alloprevotella
#   • Alloprevotella                           ID=NCBITaxon_1283313 depth=16 (exact)
#   • Alloprevotella                           ID=NCBITaxon_1283313 depth=16 score=1.00
#
# Query: imbalance-inducing bacteria
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D016999
#
# Query: Escherichia-Shigella
#   • Escherichia/Shigella sp.                 ID=NCBITaxon_1940338 depth=14 score=0.99
#
# Query: Parabacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_375288
#
# Query: butyrate-producing bacteria
#   • butyrate-producing bacterium             ID=NCBITaxon_2811711 depth=4  score=0.89
#
# Query: Ruminococcaceae UCG-014
#   • Micrococcaceae                 UI=D008835  Tree=B03.510.024.850  scoreMESH=0.65
# Query: Lactobacillus reuteri ATG-F4
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D052200
#
# Query: Lactobacillus reuteri ATG-F4
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D052200
#
# Query: F4
#   • Bacillus sp. F4-1                        ID=NCBITaxon_489169 depth=16 score=0.92
#
# Query: F4
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_489169
#
# Query: F4
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_489169
#
# Query: F4
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_489169
#
# Query: short-chain fatty acid producing bacteria
# Query: gut-resident bacteria
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D016999
#
# Query: dysregulated bacteria
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  score=1.00
#
# Query: Fusobacterium nucleatum
#   • Fusobacterium nucleatum                  ID=NCBITaxon_851   depth=14 (exact)
#   • Fusobacterium nucleatum                  ID=NCBITaxon_851   depth=14 score=1.00
#
# Query: bifidobacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Actinobacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2013654
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_186803
#
# Query: Faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_216851
#
# Query: Intestinal bacteria
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D039903
#
# Query: short-chain fatty acid SCFA -producing bacteria
# Query: Lachnospira
#   • Lachnospira                              ID=NCBITaxon_28050 depth=12 (exact)
#   • Lachnospira                              ID=NCBITaxon_28050 depth=12 score=1.00
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_816
#
# Query: Faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_216851
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
# Query: Acute chronic insomnia-related signature bacteria
# Query: Negativicutes
#   • Negativicutes                            ID=NCBITaxon_909932 depth=6  (exact)
#   • Negativicutes                            ID=NCBITaxon_909932 depth=6  score=1.00
#
# Query: Clostridiuminnocuumgroup
#   • Clostridium septicum           UI=D052557  Tree=B03.300.390.400.200.690  scoreMESH=0.68
# Query: Dorea
#   • Dorea                                    ID=NCBITaxon_189330 depth=12 (exact)
#   • Dorea                                    ID=NCBITaxon_189330 depth=12 score=1.00
#
# Query: Lachnoclostridium
#   • Lachnoclostridium                        ID=NCBITaxon_1506553 depth=12 (exact)
#   • Lachnoclostridium                        ID=NCBITaxon_1506553 depth=12 score=1.00
#
# Query: Prevotella7
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_838
#
# Query: Selenomonadalesare
#   • Selenomonas                    UI=D020357  Tree=B03.440.425.410.800.877  scoreMESH=0.76
# Query: gut bacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: Bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
# Query: Prevotella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_838
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_816
#
# Query: Megamonas
#   • Megamonas                                ID=NCBITaxon_158846 depth=12 (exact)
#   • Megamonas                                ID=NCBITaxon_158846 depth=12 score=1.00
#
# Query: Faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_216851
#
# Query: Synergistetes
#   • Synergistetes bacterium HGW-Synergistetes-1 ID=NCBITaxon_2013842 depth=8  score=0.91
#
# Query: Proteobacteria
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D020560
#
# Query: olidextribacter
#   • Liberibacter                   UI=D000086202 Tree=B03.660.050.662.347  scoreMESH=0.81
# Query: Intestinibacter
#   • Intestinibacter                          ID=NCBITaxon_1505657 depth=12 (exact)
#   • Intestinibacter                          ID=NCBITaxon_1505657 depth=12 score=1.00
#
# Query: Kineothrix
#   • Kineothrix                               ID=NCBITaxon_2163168 depth=12 (exact)
#   • Kineothrix                               ID=NCBITaxon_2163168 depth=12 score=1.00
#
# Query: Agathobaculum
#   • Agathobaculum                            ID=NCBITaxon_2048137 depth=12 (exact)
#   • Agathobaculum                            ID=NCBITaxon_2048137 depth=12 score=1.00
#
# Query: Roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_841
#
# Query: Prevotella specie
#   • Prevotella                               ID=NCBITaxon_838   depth=16 score=1.00
#
# Query: Actinobacteriota
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D039903
#
# Query: Bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Verrucomicrobiota
#   • Verrucomicrobiota                        ID=NCBITaxon_74201 depth=6  (exact)
#   • Verrucomicrobiota                        ID=NCBITaxon_74201 depth=6  score=1.00
#
# Query: Akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_239934
#
# Query: Enterococcus
#   • Enterococcus                             ID=NCBITaxon_1350  depth=12 (exact)
#   • Enterococcus                             ID=NCBITaxon_1350  depth=12 score=1.00
#
# Query: Hungatella
#   • Hungatella                               ID=NCBITaxon_1649459 depth=12 (exact)
#   • Hungatella                               ID=NCBITaxon_1649459 depth=12 score=1.00
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# Query: Oscillospira
#   • Oscillospira                             ID=NCBITaxon_119852 depth=12 (exact)
#   • Oscillospira                             ID=NCBITaxon_119852 depth=12 score=1.00
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Ruminococcaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1776336
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Bacteroidetes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_226197
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_816
#
# Query: Proteobacteria
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D020560
#
# Query: Lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_186803
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
# Query: Coprococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_33042
#
# Query: Roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_841
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Verrucomicrobiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_74201
#
# Query: Akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_239934
#
# Query: Akkermansia muciniphila
#   • Akkermansia muciniphila                  ID=NCBITaxon_239935 depth=16 (exact)
#   • Akkermansia muciniphila                  ID=NCBITaxon_239935 depth=16 score=1.00
#
# Query: Verrucomicrobiaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_203557
#
# Query: Verrucomicrobiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_74201
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# Query: Roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_841
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Lactobacillaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_33958
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Barnesiellaceae
#   • Barnesiellaceae                          ID=NCBITaxon_2005519 depth=14 (exact)
#   • Barnesiellaceae                          ID=NCBITaxon_2005519 depth=14 score=1.00
#
# Query: Bacteroidetes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_226197
#
# Query: Bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Actinobacteriota
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D039903
#
# Query: Bilophila wadsworthia
#   • Bilophila wadsworthia                    ID=NCBITaxon_35833 depth=14 (exact)
#   • Bilophila wadsworthia                    ID=NCBITaxon_35833 depth=14 score=1.00
#
# Query: Thermodesulfobacteriota
#   • Thermodesulfobacteriota                  ID=NCBITaxon_200940 depth=4  (exact)
#   • Thermodesulfobacteriota                  ID=NCBITaxon_200940 depth=4  score=1.00
#
# Query: Prevotella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_838
#
# Query: Bacteroidetes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_226197
#
# Query: Verrucomicrobiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_74201
#
# Query: Akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_239934
#
# Query: Bifidobacteriaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_31953
#
# Query: Coriobacteriaceae
#   • Coriobacteriaceae                        ID=NCBITaxon_84107 depth=10 (exact)
#   • Coriobacteriaceae                        ID=NCBITaxon_84107 depth=10 score=1.00
#
# Query: Actinobacteriota
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D039903
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Christensenellaceae
#   • Christensenellaceae                      ID=NCBITaxon_990719 depth=10 (exact)
#   • Christensenellaceae                      ID=NCBITaxon_990719 depth=10 score=1.00
#
# Query: Lactobacillaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_33958
#
# Query: Enterococcaceae
#   • Enterococcaceae                          ID=NCBITaxon_81852 depth=10 (exact)
#   • Enterococcaceae                          ID=NCBITaxon_81852 depth=10 score=1.00
#
# Query: Enterococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1350
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Lactococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1357
#
# Query: Oscillospira
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_119852
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Proteobacteria
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D020560
#
# Query: Enterobacteriaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_543
#
# Query: Citrobacter
#   • Citrobacter                              ID=NCBITaxon_544   depth=12 (exact)
#   • Citrobacter                              ID=NCBITaxon_544   depth=12 score=1.00
#
# Query: Klebsiella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_570
#
# Query: Salmonella
#   • Salmonella                               ID=NCBITaxon_590   depth=12 (exact)
#   • Salmonella                               ID=NCBITaxon_590   depth=12 score=1.00
#
# Query: Shigella
#   • Shigella                                 ID=NCBITaxon_620   depth=12 (exact)
#   • Shigella                                 ID=NCBITaxon_620   depth=12 score=1.00
#
# Query: ParaBacteroides
#   • Parabacteroides                          ID=NCBITaxon_375288 depth=16 (exact)
#   • Parabacteroides                          ID=NCBITaxon_375288 depth=16 score=1.00
#
# Query: Bacteroidetes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_226197
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Lachnospiraceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_186803
#
# Query: Roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_841
#
# Query: Ruminococcus
#   • Ruminococcus                             ID=NCBITaxon_1263  depth=12 (exact)
#   • Ruminococcus                             ID=NCBITaxon_1263  depth=12 score=1.00
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Muribaculaceae
#   • Muribaculaceae                           ID=NCBITaxon_2005473 depth=14 (exact)
#   • Muribaculaceae                           ID=NCBITaxon_2005473 depth=14 score=1.00
#
# Query: Faecalibaculum
#   • Faecalibaculum                           ID=NCBITaxon_1729679 depth=12 (exact)
#   • Faecalibaculum                           ID=NCBITaxon_1729679 depth=12 score=1.00
#
# Query: Flavonifractor
#   • Flavonifractor                           ID=NCBITaxon_946234 depth=12 (exact)
#   • Flavonifractor                           ID=NCBITaxon_946234 depth=12 score=1.00
#
# Query: Christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_990719
#
# Query: gut Flavonifractor genus
# Query: gut Christensenellaceae family
# Query: Flavonifractor
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_946234
#
# Query: Christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_990719
#
# Query: Flavonifractor
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_946234
#
# Query: Christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_990719
#
# Query: Christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_990719
#
# Query: Flavonifractor
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_946234
#
# Query: Christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_990719
#
# Query: Flavonifractor
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_946234
#
# Query: Christensenellaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_990719
#
# Query: Flavonifractor
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_946234
#
# Query: genus Ruminococcaceae
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_81852
#
# Query: UCG009
# Query: genus Subdoligranulum
#   • Subdoligranulum                          ID=NCBITaxon_292632 depth=12 score=0.86
#
# Query: Family Ruminococcaceae
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D008835
#
# Query: genus Coprococcus2
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1350
#
# Query: genus Eggerthella
#   • Eggerthella                              ID=NCBITaxon_84111 depth=12 score=0.85
#
# Query: genus Eubacterium
#   • Eubacterium                    UI=D005051  Tree=B03.353.625.750  scoreMESH=0.79
# Query: xylanophilum group
#   • Eubacterium xylanophilum                 ID=NCBITaxon_39497 depth=14 score=0.79
#
# Query: predominant bacteria
#   • Bacteria                                 ID=NCBITaxon_2     depth=0  score=1.00
#
# Query: Ruminococcaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1776336
#
# Query: Ruminococcaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1776336
#
# Query: Ruminococcaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1776336
#
# Query: Ruminococcaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1776336
#
# Query: Ruminococcaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1776336
#
# Query: gut bacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: Lachnoclostridium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1506553
#
# Query: Lachnostridium
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1485
#
# Query: Lachnoclostridium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1506553
#
# Query: Parabacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_375288
#
# Query: Anaerostipes
#   • Anaerostipes                             ID=NCBITaxon_207244 depth=12 (exact)
#   • Anaerostipes                             ID=NCBITaxon_207244 depth=12 score=1.00
#
# Query: Ruminococcus-2
#   • Ruminococcus                             ID=NCBITaxon_1263  depth=12 score=1.00
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
# Query: Akkermansia muciniphila
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_239935
#
# Query: Akkermansia muciniphila
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_239935
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# Query: Listeria monocytogenes
#   • Listeria monocytogenes                   ID=NCBITaxon_1639  depth=14 (exact)
#   • Listeria monocytogenes                   ID=NCBITaxon_1639  depth=14 score=1.00
#
# Query: Haemophilus
#   • Haemophilus                              ID=NCBITaxon_724   depth=12 (exact)
#   • Haemophilus                              ID=NCBITaxon_724   depth=12 score=1.00
#
# Query: Haemophilu
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_724
#
# Query: Coprococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_33042
#
# Query: Haemophilus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_724
#
# Query: Roseburia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_841
#
# Query: Faecalibacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_216851
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
# Query: Lachnospira
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_28050
#
# Query: Prevotella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_838
#
# Query: Streptococcus
#   • Streptococcus                            ID=NCBITaxon_1301  depth=12 (exact)
#   • Streptococcus                            ID=NCBITaxon_1301  depth=12 score=1.00
#
# Query: Bifidobacterium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# Query: Akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_239934
#
# Query: Desulfovibrio
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_872
#
# Query: psychobiotics
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D046939
#
# Query: psychobiotics
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D046939
#
# Query: Bacteroides uniformis
#   • Bacteroides uniformis                    ID=NCBITaxon_820   depth=18 (exact)
#   • Bacteroides uniformis                    ID=NCBITaxon_820   depth=18 score=1.00
#
# Query: Roseburia inulinivorans
#   • Roseburia inulinivorans                  ID=NCBITaxon_360807 depth=14 (exact)
#   • Roseburia inulinivorans                  ID=NCBITaxon_360807 depth=14 score=1.00
#
# Query: Eubacterium rectale
#   • Treponema rectale                        ID=NCBITaxon_744512 depth=14 score=0.78
#
# Query: Faecalibacterium prausnitzii
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_853
#
# Query: psychobiotics
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D046939
#
# Query: phylum Proteobacteria
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D020560
#
# Query: Enterobacteriaceae
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_543
#
# Query: coliform genus
# Query: Escherichia
#   • Escherichia                              ID=NCBITaxon_561   depth=12 (exact)
#   • Escherichia                              ID=NCBITaxon_561   depth=12 score=1.00
#
# Query: Klebsiella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_570
#
# Query: Klebsiella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_570
#
# Query: Clostridium
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1485
#
# Query: Bilophila
#   • Bilophila                                ID=NCBITaxon_35832 depth=12 (exact)
#   • Bilophila                                ID=NCBITaxon_35832 depth=12 score=1.00
#
# Query: Escherichia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_561
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# Query: Enterococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1350
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Lactobacillus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1578
#
# Query: Lachnospiraceae Incertae Sedis
#   • Lachnospiraceae incertae sedis           ID=NCBITaxon_2840493 depth=12 (exact)
#   • Lachnospiraceae incertae sedis           ID=NCBITaxon_2840493 depth=12 score=1.00
#
# Query: Barnesiella
#   • Barnesiella                              ID=NCBITaxon_397864 depth=16 (exact)
#   • Barnesiella                              ID=NCBITaxon_397864 depth=16 score=1.00
#
# Query: Romboutsia
#   • Romboutsia                               ID=NCBITaxon_1501226 depth=12 (exact)
#   • Romboutsia                               ID=NCBITaxon_1501226 depth=12 score=1.00
#
# Query: A muciniphila
#   • Akkermansia muciniphila                  ID=NCBITaxon_239935 depth=16 score=0.80
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_816
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Bifidobacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Prevotella
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_838
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_816
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Bifidobacteria
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1678
#
# Query: Lactobacilli
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_1591090
#
# Query: Bacteroides genus
#   • Bacteroides                              ID=NCBITaxon_816   depth=16 score=0.77
#
# Query: Firmicutes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1386
#
# Query: Bacteroidetes
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_226197
#
# Query: Bacteroides
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_816
#
# Query: Lachnospiraceae g
#   • Lachnospiraceae                          ID=NCBITaxon_186803 depth=10 score=1.00
#
# Query: Ruminococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1263
#
# Query: Akkermansia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_239934
#
# Query: Megamonas
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_158846
#
# Query: Prevotellaceae NK3B31
#   → Reusing existing URI by label: http://purl.obolibrary.org/obo/NCBITaxon_838
#
# Query: butyrate-producing bacteria
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2811711
#
# Query: Lachnospira
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_28050
#
# Query: Subdoligranulum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_292632
#
# Query: Blautia
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_572511
#
# Query: Dialister
#   • Dialister                                ID=NCBITaxon_39948 depth=12 (exact)
#   • Dialister                                ID=NCBITaxon_39948 depth=12 score=1.00
#
# Query: acetate-producing bacteria
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D039903
#
# Query: Streptococcus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1301
#
# Query: Parasutterella
#   • Parasutterella                           ID=NCBITaxon_577310 depth=12 (exact)
#   • Parasutterella                           ID=NCBITaxon_577310 depth=12 score=1.00
#
# Query: Dialister
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_39948
#
# Query: intestinal bacteria
#   → Reusing existing URI by label: https://www.ncbi.nlm.nih.gov/mesh/D039903

# %% [markdown]
# <h1>INGEST CHEMICAL</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL

CHEBI_BASE = "http://purl.obolibrary.org/obo/"
CHEMICAL_CLASS = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Chemical")
CHEMICAL_CONCEPT_SCHEME = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Chemical")
UBERON_URI = URIRef("http://purl.obolibrary.org/obo/UBERON_0002097")

created["Chemical Entity"] = URIRef(f"{CHEBI_BASE}CHEBI_24431")
g.add((created["Chemical Entity"], RDF.type, CHEMICAL_CLASS))
g.add((created["Chemical Entity"], RDF.type, SKOS.Concept))
g.add((created["Chemical Entity"], RDFS.label, Literal("Chemical Entity", datatype=XSD.string)))
g.add((created["Chemical Entity"], SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))

def load_ncbitaxon_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = CHEBI_BASE + term_id
            rows.append((label, uri))
    return rows
    
def load_chebi_labels(path):
    rows = []
    with open(path, encoding="utf-8") as fh:
        next(fh) 
        for ln in fh:
            uri, label = ln.rstrip("\n").split("\t", 1)
            rows.append((label, uri))
    return rows

CHEBI_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\chebi_labels.txt"
NCBITAXON_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncit_full_taxonomy.txt"
chebi_rows = load_chebi_labels(CHEBI_LABELS_FILE)
ncbi_rows = load_ncbitaxon_labels(NCBITAXON_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in chebi_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

exact_ix1 = defaultdict(list)
for lbl, uri in ncbi_rows:
    exact_ix1[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in chebi_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

labels_only1 = [preprocess(lbl) for lbl, _ in ncbi_rows]
vec1 = TfidfVectorizer(stop_words="english")
mat1 = vec1.fit_transform(labels_only1)

def top_cosine(term, k=5, thr=0.75):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = chebi_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

def top_cosine_ncbitaxon(term, k=5, thr=0.75):
    v  = vec1.transform([term])
    sc = cosine_similarity(v, mat1).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = ncbi_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

greek_map = {
    'α': 'alpha',  'Α': 'alpha',
    'β': 'beta',   'Β': 'beta',
    'γ': 'gamma',  'Γ': 'gamma',
    'δ': 'delta',  'Δ': 'delta',
    'ε': 'epsilon','Ε': 'epsilon',
    'ζ': 'zeta',   'Ζ': 'zeta',
    'η': 'eta',    'Η': 'eta',
    'θ': 'theta',  'Θ': 'theta',
    'ι': 'iota',   'Ι': 'iota',
    'κ': 'kappa',  'Κ': 'kappa',
    'λ': 'lambda', 'Λ': 'lambda',
    'μ': 'mu',     'Μ': 'mu',
    'ν': 'nu',     'Ν': 'nu',
    'ξ': 'xi',     'Ξ': 'xi',
    'ο': 'omicron','Ο': 'omicron',
    'π': 'pi',     'Π': 'pi',
    'ρ': 'rho',    'Ρ': 'rho',
    'σ': 'sigma',  'Σ': 'sigma',
    'τ': 'tau',    'Τ': 'tau',
    'υ': 'upsilon','Υ': 'upsilon',
    'φ': 'phi',    'Φ': 'phi',
    'χ': 'chi',    'Χ': 'chi',
    'ψ': 'psi',    'Ψ': 'psi',
    'ω': 'omega',  'Ω': 'omega',
}

def preprocess(term):
    for greek_char, name in greek_map.items():
        if greek_char in term:
            term = term.replace(greek_char, name)
    term = term.replace('_', ' ')
    term = term.strip()
    return " ".join(lemmatizer.lemmatize(w) for w in term.split())
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "chemical":
            text_span = entity.get("text_span", "").strip()
            cleaned_text = create_uri_fragment(text_span)
            cleaned_text_span = normalize_to_ascii(cleaned_text)
            term_raw = cleaned_text_span.lower()
            term = preprocess(term_raw)
            print(f"Query: {term}")
            
            if term_raw in created:
                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                continue

            ex = exact_ix.get(term, [])
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, CHEMICAL_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                    g.add((entity_uri, SKOS.broaderTransitive, created["Chemical Entity"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            cos = top_cosine(term)
            cos1 = top_cosine_ncbitaxon(term)
            if cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, CHEMICAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                    g.add((name_uri, SKOS.broaderTransitive, created["Chemical Entity"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, CHEMICAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, CHEMICAL_CONCEPT_SCHEME))
                    g.add((name_uri, SKOS.broaderTransitive, created["Chemical Entity"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAIN[term_raw])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((created["Chemical Entity"], GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                continue
        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAIN[f"title_{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAIN[f"abstract_{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "chemical":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAIN[cleaned_text_span])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_chemical_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))
# Out:
# Query: simple sugar
# Query: sfa
# Query: monounsaturated fatty acid
#   • monounsaturated fatty acid               URI=http://purl.obolibrary.org/obo/CHEBI_25413
#   • monounsaturated fatty acid               URI=http://purl.obolibrary.org/obo/CHEBI_25413 score=1.00
#
# Query: metabolite acetate
#   • metabolite                               URI=http://purl.obolibrary.org/obo/CHEBI_25212 score=0.81
#
# Query: fat and sugar content
# Query: tnf-a
#   • TNF Gene                                 URI=http://purl.obolibrary.org/obo/NCIT_C18368 score=0.92
#
# Query: il-6
#   • Will County, IL                          URI=http://purl.obolibrary.org/obo/NCIT_C108381 score=0.83
#
# Query: il-17
# Query: serum hormone
# Query: insulin
#   • insulin                                  URI=http://purl.obolibrary.org/obo/CHEBI_145810
#   • insulin                                  URI=http://purl.obolibrary.org/obo/CHEBI_145810 score=1.00
#
# Query: testosterone
#   • testosterone                             URI=http://purl.obolibrary.org/obo/CHEBI_17347
#   • testosterone                             URI=http://purl.obolibrary.org/obo/CHEBI_17347 score=1.00
#
# Query: skin lipid
#   • Lipid                                    URI=http://purl.obolibrary.org/obo/NCIT_C616 score=0.82
#
# Query: triglyceride
#   • triglyceride                             URI=http://purl.obolibrary.org/obo/CHEBI_17855
#   • triglyceride                             URI=http://purl.obolibrary.org/obo/CHEBI_17855 score=1.00
#
# Query: non-esterified free fatty acid
#   • Free Non-esterified Fatty Acids Measurement URI=http://purl.obolibrary.org/obo/NCIT_C80181 score=0.79
#
# Query: skin triglyceride
#   • Triglyceride                             URI=http://purl.obolibrary.org/obo/NCIT_C68436 score=0.86
#
# Query: hormone
#   • hormone                                  URI=http://purl.obolibrary.org/obo/CHEBI_24621
#   • hormone                                  URI=http://purl.obolibrary.org/obo/CHEBI_24621 score=1.00
#
# Query: skin lipid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C616
#
# Query: melanin
#   • Melanin                                  URI=http://purl.obolibrary.org/obo/CHEBI_89634
#   • melanins                                 URI=http://purl.obolibrary.org/obo/CHEBI_25179 score=1.00
#
# Query: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25179
#
# Query: reactive oxygen specie
#   • reactive oxygen species                  URI=http://purl.obolibrary.org/obo/CHEBI_26523 score=1.00
#
# Query: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25179
#
# Query: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25179
#
# Query: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25179
#
# Query: neuromelanin
# Query: herpesvirus
#   • Herpesvirus                              URI=http://purl.obolibrary.org/obo/NCIT_C14217 score=1.00
#
# Query: melanosomes
#   • Melanosomes Present                      URI=http://purl.obolibrary.org/obo/NCIT_C41415 score=0.88
#
# Query: herpesvirus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14217
#
# Query: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25179
#
# Query: atp
#   • ATP                                      URI=http://purl.obolibrary.org/obo/CHEBI_15422
#   • ATP(3-)                                  URI=http://purl.obolibrary.org/obo/CHEBI_57299 score=1.00
#
# Query: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25179
#
# Query: atp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_57299
#
# Query: atp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_57299
#
# Query: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25179
#
# Query: melanin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25179
#
# Query: flavonoid
#   • flavonoid                                URI=http://purl.obolibrary.org/obo/CHEBI_47916
#   • flavonoid                                URI=http://purl.obolibrary.org/obo/CHEBI_47916 score=1.00
#
# Query: isorhamnetin
#   • isorhamnetin                             URI=http://purl.obolibrary.org/obo/CHEBI_6052
#   • isorhamnetin                             URI=http://purl.obolibrary.org/obo/CHEBI_6052 score=1.00
#
# Query: quercetin
#   • quercetin                                URI=http://purl.obolibrary.org/obo/CHEBI_16243
#   • quercetin                                URI=http://purl.obolibrary.org/obo/CHEBI_16243 score=1.00
#
# Query: kaempferol
#   • kaempferol                               URI=http://purl.obolibrary.org/obo/CHEBI_28499
#   • kaempferol                               URI=http://purl.obolibrary.org/obo/CHEBI_28499 score=1.00
#
# Query: neurotrophins
#   • Recombinant Neurotrophins                URI=http://purl.obolibrary.org/obo/NCIT_C1396 score=0.85
#
# Query: neurotransmitter
#   • neurotransmitter                         URI=http://purl.obolibrary.org/obo/CHEBI_25512
#   • neurotransmitter                         URI=http://purl.obolibrary.org/obo/CHEBI_25512 score=1.00
#
# Query: stress-related hormone
# Query: inflammation-related cytokine
# Query: neuroactive compound
#   • Compound 5                               URI=http://purl.obolibrary.org/obo/CHEBI_220497 score=1.00
#
# Query: neuroactive compound
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_220497
#
# Query: neuroactive compound
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_220497
#
# Query: gamma-aminobutyric acid
#   • gamma-aminobutyric acid                  URI=http://purl.obolibrary.org/obo/CHEBI_16865
#   • gamma-aminobutyric acid                  URI=http://purl.obolibrary.org/obo/CHEBI_16865 score=1.00
#
# Query: gaba
#   • N-Oleoyl GABA                            URI=http://purl.obolibrary.org/obo/CHEBI_165543 score=0.82
#
# Query: serotonin
#   • serotonin                                URI=http://purl.obolibrary.org/obo/CHEBI_28790
#   • serotonin(1+)                            URI=http://purl.obolibrary.org/obo/CHEBI_350546 score=1.00
#
# Query: melatonin
#   • melatonin                                URI=http://purl.obolibrary.org/obo/CHEBI_16796
#   • melatonin                                URI=http://purl.obolibrary.org/obo/CHEBI_16796 score=1.00
#
# Query: kynurenine
#   • kynurenine                               URI=http://purl.obolibrary.org/obo/CHEBI_28683
#   • D-kynurenine                             URI=http://purl.obolibrary.org/obo/CHEBI_86262 score=1.00
#
# Query: kynurenic acid
#   • kynurenic acid                           URI=http://purl.obolibrary.org/obo/CHEBI_18344
#   • kynurenic acid                           URI=http://purl.obolibrary.org/obo/CHEBI_18344 score=1.00
#
# Query: dopamine
#   • dopamine                                 URI=http://purl.obolibrary.org/obo/CHEBI_18243
#   • dopamine                                 URI=http://purl.obolibrary.org/obo/CHEBI_18243 score=1.00
#
# Query: norepinephrine
#   • Norepinephrine sulfate                   URI=http://purl.obolibrary.org/obo/CHEBI_90022 score=0.89
#
# Query: histamine
#   • histamine                                URI=http://purl.obolibrary.org/obo/CHEBI_18295
#   • histamine                                URI=http://purl.obolibrary.org/obo/CHEBI_18295 score=1.00
#
# Query: tryptamine
#   • tryptamine                               URI=http://purl.obolibrary.org/obo/CHEBI_16765
#   • tryptamine                               URI=http://purl.obolibrary.org/obo/CHEBI_16765 score=1.00
#
# Query: tyramine
#   • tyramine                                 URI=http://purl.obolibrary.org/obo/CHEBI_15760
#   • m-tyramine                               URI=http://purl.obolibrary.org/obo/CHEBI_89626 score=1.00
#
# Query: -phenylethylamine
#   • phenylethylamine                         URI=http://purl.obolibrary.org/obo/CHEBI_50048 score=1.00
#
# Query: neuroactive compound
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_220497
#
# Query: plant-origin and microbially-formed neuroactive compound
# Query: neuroactive compound
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_220497
#
# Query: neuroactive compound
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_220497
#
# Query: microbial metabolite
# Query: neuroactive compound
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_220497
#
# Query: gaba
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_165543
#
# Query: neuroactive compound
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_220497
#
# Query: -aminobutyric acid
#   • L-3-Aminobutyric acid                    URI=http://purl.obolibrary.org/obo/CHEBI_229980 score=1.00
#
# Query: gaba
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_165543
#
# Query: acetylcholine
#   • acetylcholine                            URI=http://purl.obolibrary.org/obo/CHEBI_15355
#   • acetylcholine                            URI=http://purl.obolibrary.org/obo/CHEBI_15355 score=1.00
#
# Query: gaba
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_165543
#
# Query: acetylcholine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_15355
#
# Query: gaba
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_165543
#
# Query: short chain fatty acid
#   • short-chain fatty acid                   URI=http://purl.obolibrary.org/obo/CHEBI_26666 score=1.00
#
# Query: scfa
# Query: gaba
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_165543
#
# Query: acetylcholine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_15355
#
# Query: glutamate
#   • L-glutamate(1-)                          URI=http://purl.obolibrary.org/obo/CHEBI_29985 score=1.00
#
# Query: gaba
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_165543
#
# Query: short-chain fatty acid
#   • short-chain fatty acid                   URI=http://purl.obolibrary.org/obo/CHEBI_26666
#   • short-chain fatty acid                   URI=http://purl.obolibrary.org/obo/CHEBI_26666 score=1.00
#
# Query: gaba
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_165543
#
# Query: gaba
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_165543
#
# Query: vitamin b6
#   • vitamin B6                               URI=http://purl.obolibrary.org/obo/CHEBI_27306
#   • vitamin B6                               URI=http://purl.obolibrary.org/obo/CHEBI_27306 score=1.00
#
# Query: fatty acid
#   • fatty acid                               URI=http://purl.obolibrary.org/obo/CHEBI_35366
#   • fatty acid 8:2                           URI=http://purl.obolibrary.org/obo/CHEBI_132545 score=1.00
#
# Query: microbial neuroactive metabolite
# Query: short-chain fatty acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
# Query: gamma-aminobutyric acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: arachidonic acid
#   • arachidonic acid                         URI=http://purl.obolibrary.org/obo/CHEBI_15843
#   • arachidonic acid                         URI=http://purl.obolibrary.org/obo/CHEBI_15843 score=1.00
#
# Query: sphingomyelin
#   • sphingomyelin                            URI=http://purl.obolibrary.org/obo/CHEBI_64583
#   • sphingomyelin                            URI=http://purl.obolibrary.org/obo/CHEBI_64583 score=1.00
#
# Query: dextran sodium sulphate
# Query: dextran sodium sulphate
# Query: ds
#   • DS-1-38                                  URI=http://purl.obolibrary.org/obo/CHEBI_231606 score=0.84
#
# Query: lipopolysaccharide
#   • lipopolysaccharide                       URI=http://purl.obolibrary.org/obo/CHEBI_16412
#   • lipopolysaccharide                       URI=http://purl.obolibrary.org/obo/CHEBI_16412 score=1.00
#
# Query: lp
#   • LP Mouse                                 URI=http://purl.obolibrary.org/obo/NCIT_C14566 score=0.90
#
# Query: ds
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_231606
#
# Query: ds
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_231606
#
# Query: ds
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_231606
#
# Query: lp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14566
#
# Query: paraquat
#   • paraquat                                 URI=http://purl.obolibrary.org/obo/CHEBI_34905
#   • paraquat                                 URI=http://purl.obolibrary.org/obo/CHEBI_34905 score=1.00
#
# Query: circulating lipocalin-2
# Query: il-6
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C108381
#
# Query: ds
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_231606
#
# Query: xingpijieyu formula
#   • Chemical_Formula                         URI=http://purl.obolibrary.org/obo/NCIT_C68604 score=0.76
#
# Query: xingpijieyu formula
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C68604
#
# Query: xpjyf
# Query: xpjyf
# Query: serum cytokine
#   • Cytokine                                 URI=http://purl.obolibrary.org/obo/NCIT_C20464 score=0.76
#
# Query: glial fibrillary acidic protein
#   • Glial Fibrillary Acidic Protein          URI=http://purl.obolibrary.org/obo/NCIT_C68804 score=1.00
#
# Query: gfap
#   • GFAP Gene                                URI=http://purl.obolibrary.org/obo/NCIT_C68802 score=0.94
#
# Query: xpjyf
# Query: lipopolysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16412
#
# Query: lp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14566
#
# Query: cytokine
#   • Cytokine                                 URI=http://purl.obolibrary.org/obo/NCIT_C20464 score=1.00
#
# Query: 2-deoxy-d-glucose
#   • 2-deoxy-D-glucose                        URI=http://purl.obolibrary.org/obo/CHEBI_15866
#   • 6-deoxy-L-glucose                        URI=http://purl.obolibrary.org/obo/CHEBI_194166 score=1.00
#
# Query: 2-dg
#   • dG+                                      URI=http://purl.obolibrary.org/obo/CHEBI_190142 score=1.00
#
# Query: adenosine triphosphate
#   • adenosine 3'-diphosphate,5'-triphosphate(6-) URI=http://purl.obolibrary.org/obo/CHEBI_145540 score=0.86
#
# Query: atp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_57299
#
# Query: glucose-1-phosphate
#   • glucose phosphate                        URI=http://purl.obolibrary.org/obo/CHEBI_21008 score=1.00
#
# Query: g1p
# Query: xpjyf
# Query: glucose1pmetab-pwy
# Query: xpjyf
# Query: xpjyf
# Query: atp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_57299
#
# Query: glucose-1-phosphate
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_21008
#
# Query: xpjyf
# Query: interferon-
#   • interferon                               URI=http://purl.obolibrary.org/obo/CHEBI_52999 score=1.00
#
# Query: tumor necrosis factor-
#   • Recombinant Tumor Necrosis Factor-alpha (human) URI=http://purl.obolibrary.org/obo/CHEBI_197440 score=0.77
#
# Query: indoleamine 2 3-dioxygenase-1
#   • Indoleamine 2,3-Dioxygenase 1            URI=http://purl.obolibrary.org/obo/NCIT_C79782 score=1.00
#
# Query: maltotriose
#   • maltotriose                              URI=http://purl.obolibrary.org/obo/CHEBI_61993
#   • maltotriose                              URI=http://purl.obolibrary.org/obo/CHEBI_61993 score=1.00
#
# Query: isomaltose
#   • isomaltose                               URI=http://purl.obolibrary.org/obo/CHEBI_28189
#   • isomaltose                               URI=http://purl.obolibrary.org/obo/CHEBI_28189 score=1.00
#
# Query: anandamide
#   • anandamide                               URI=http://purl.obolibrary.org/obo/CHEBI_2700
#   • anandamide                               URI=http://purl.obolibrary.org/obo/CHEBI_2700 score=1.00
#
# Query: associated synaptic protein
# Query: gap43
# Query: sv2c
# Query: short-chain fatty acid
#   • short-chain fatty acid                   URI=http://purl.obolibrary.org/obo/CHEBI_26666
#   • short-chain fatty acid                   URI=http://purl.obolibrary.org/obo/CHEBI_26666 score=1.00
#
# Query: scfa
# Query: scfa
# Query: claudin-2
#   • Claudin-6                                URI=http://purl.obolibrary.org/obo/NCIT_C117145 score=1.00
#
# Query: epinephrine
#   • Epinephrine sulfate                      URI=http://purl.obolibrary.org/obo/CHEBI_89878 score=0.88
#
# Query: norepinephrine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_90022
#
# Query: helicobacter pylori-related inflammatory mediator
# Query: defensins
#   • Defensins                                URI=http://purl.obolibrary.org/obo/NCIT_C1063 score=1.00
#
# Query: vitamin d
#   • vitamin D                                URI=http://purl.obolibrary.org/obo/CHEBI_27300
#   • B vitamin                                URI=http://purl.obolibrary.org/obo/CHEBI_75769 score=1.00
#
# Query: microbial tryptophan
#   • Tryptophan                               URI=http://purl.obolibrary.org/obo/NCIT_C29603 score=0.75
#
# Query: wheat gluten
#   • Wheat Gluten                             URI=http://purl.obolibrary.org/obo/NCIT_C84242 score=1.00
#
# Query: bovine milk casein
# Query: food antigen
#   • Food                                     URI=http://purl.obolibrary.org/obo/NCIT_C62695 score=0.79
#
# Query: complement c1q
#   • Complement C1q Measurement               URI=http://purl.obolibrary.org/obo/NCIT_C186029 score=0.94
#
# Query: serum metabolome
#   • Serum                                    URI=http://purl.obolibrary.org/obo/NCIT_C13325 score=1.00
#
# Query: gamma-aminobutyric acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: gaba
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_165543
#
# Query: short-chain fatty acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
# Query: scfas
# Query: scfa
# Query: scfas
# Query: tight junction protein
#   • Tight Junction                           URI=http://purl.obolibrary.org/obo/NCIT_C13333 score=0.94
#
# Query: zo-1
# Query: claudin
#   • Claudin-6                                URI=http://purl.obolibrary.org/obo/NCIT_C117145 score=1.00
#
# Query: occludin
# Query: inflammatory cytokine
# Query: il-1
#   • Will County, IL                          URI=http://purl.obolibrary.org/obo/NCIT_C108381 score=0.83
#
# Query: il-6
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C108381
#
# Query: butyrate
#   • butyrate                                 URI=http://purl.obolibrary.org/obo/CHEBI_17968
#   • butyrate                                 URI=http://purl.obolibrary.org/obo/CHEBI_17968 score=1.00
#
# Query: trichloroethylene
#   • Trichloroethylene                        URI=http://purl.obolibrary.org/obo/NCIT_C44459 score=1.00
#
# Query: pesticide
#   • pesticide                                URI=http://purl.obolibrary.org/obo/CHEBI_25944
#   • pesticide                                URI=http://purl.obolibrary.org/obo/CHEBI_25944 score=1.00
#
# Query: metal
#   • metal sulfate                            URI=http://purl.obolibrary.org/obo/CHEBI_51336 score=0.84
#
# Query: organic solvent
#   • solvent                                  URI=http://purl.obolibrary.org/obo/CHEBI_46787 score=0.79
#
# Query: trichloroethylene
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C44459
#
# Query: tce
# Query: tce
# Query: tce
# Query: tce
# Query: short-chain fatty acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
# Query: lactic-acid
#   • (S)-lactic acid                          URI=http://purl.obolibrary.org/obo/CHEBI_422 score=1.00
#
# Query: il-1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C108381
#
# Query: il-2
#   • Will County, IL                          URI=http://purl.obolibrary.org/obo/NCIT_C108381 score=0.83
#
# Query: il-4
#   • Will County, IL                          URI=http://purl.obolibrary.org/obo/NCIT_C108381 score=0.83
#
# Query: il-6
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C108381
#
# Query: il-13
# Query: il-18
# Query: gm-csf
#   • GM-CSF Receptor                          URI=http://purl.obolibrary.org/obo/NCIT_C38991 score=0.91
#
# Query: ifn
# Query: tnf
#   • TNF Gene                                 URI=http://purl.obolibrary.org/obo/NCIT_C18368 score=0.92
#
# Query: ifn
# Query: tnf
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C18368
#
# Query: tnf
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C18368
#
# Query: ifn
# Query: tnf
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C18368
#
# Query: ifn
# Query: exopolysaccharide
#   • exopolysaccharide                        URI=http://purl.obolibrary.org/obo/CHEBI_72813
#   • exopolysaccharide                        URI=http://purl.obolibrary.org/obo/CHEBI_72813 score=1.00
#
# Query: exopolysaccharide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_72813
#
# Query: eps
#   • EPS Library                              URI=http://purl.obolibrary.org/obo/NCIT_C15804 score=0.88
#
# Query: eps
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C15804
#
# Query: eps
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C15804
#
# Query: c-eps
#   • EPS Library                              URI=http://purl.obolibrary.org/obo/NCIT_C15804 score=0.88
#
# Query: c-eps
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C15804
#
# Query: eps
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C15804
#
# Query: hydrogen sulfide
#   • hydrogen sulfide                         URI=http://purl.obolibrary.org/obo/CHEBI_16136
#   • hydrogen sulfide                         URI=http://purl.obolibrary.org/obo/CHEBI_16136 score=1.00
#
# Query: hydrogen sulfide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16136
#
# Query: h2s
# Query: h2s
# Query: h2s
# Query: h2s
# Query: cytochrome c protein
#   • cytochrome f                             URI=http://purl.obolibrary.org/obo/CHEBI_38556 score=0.77
#
# Query: reactive oxygen specie
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26523
#
# Query: alpha-synuclein oligomers
#   • N(alpha),N(alpha),N(alpha)-trimethyl-L-histidine URI=http://purl.obolibrary.org/obo/CHEBI_15781 score=0.80
#
# Query: alpha-synuclein protein
#   • protein                                  URI=http://purl.obolibrary.org/obo/CHEBI_36080 score=0.88
#
# Query: h2s
# Query: blood erythrocyte and lymphocyte
# Query: gut microbiota-derived metabolite
# Query: trp
#   • Trp-P-1                                  URI=http://purl.obolibrary.org/obo/CHEBI_82376 score=1.00
#
# Query: k01817
# Query: k11358
# Query: k01626
# Query: k01667
# Query: k01626
# Query: fe
# Query: rhepo
# Query: fe
# Query: rhepo
# Query: fe
# Query: rhepo
# Query: rhepo
# Query: fe
# Query: serotonin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_350546
#
# Query: 5-ht
#   • HT-2 toxin                               URI=http://purl.obolibrary.org/obo/CHEBI_138861 score=0.80
#
# Query: 5-ht receptor
# Query: long-chain fatty acid
#   • long-chain fatty acid                    URI=http://purl.obolibrary.org/obo/CHEBI_15904
#   • very long-chain fatty acid               URI=http://purl.obolibrary.org/obo/CHEBI_27283 score=1.00
#
# Query: bile acid
#   • bile acid                                URI=http://purl.obolibrary.org/obo/CHEBI_3098
#   • bile acid                                URI=http://purl.obolibrary.org/obo/CHEBI_3098 score=1.00
#
# Query: resistant starch
#   • starch                                   URI=http://purl.obolibrary.org/obo/CHEBI_28017 score=1.00
#
# Query: -glucuronidase
#   • Glucuronidase Inhibitor                  URI=http://purl.obolibrary.org/obo/NCIT_C1017 score=0.88
#
# Query: short-chain fatty acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
# Query: bile acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_3098
#
# Query: dna methylation
#   • DNA 5'-phosphate                         URI=http://purl.obolibrary.org/obo/CHEBI_4294 score=0.85
#
# Query: enteric glial cell network
# Query: intestinal gut enteric neuropeptides
# Query: vagal and spinal afferent neuron
# Query: gut hormone
# Query: cytokine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C20464
#
# Query: microbially-derived neurotransmitter
#   • Neurotransmitter                         URI=http://purl.obolibrary.org/obo/NCIT_C687 score=0.83
#
# Query: short-chain fatty acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
# Query: dietary microbial metabolite
# Query: short-chain fatty acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
# Query: indoles
#   • indoles                                  URI=http://purl.obolibrary.org/obo/CHEBI_24828
#   • indoles                                  URI=http://purl.obolibrary.org/obo/CHEBI_24828 score=1.00
#
# Query: bile acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_3098
#
# Query: choline metabolite
#   • 2,4-D choline                            URI=http://purl.obolibrary.org/obo/CHEBI_145558 score=0.76
#
# Query: lactate
#   • lactate                                  URI=http://purl.obolibrary.org/obo/CHEBI_24996
#   • lactate                                  URI=http://purl.obolibrary.org/obo/CHEBI_24996 score=1.00
#
# Query: vitamin
#   • B vitamin                                URI=http://purl.obolibrary.org/obo/CHEBI_75769 score=1.00
#
# Query: atp
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_57299
#
# Query: adp
#   • ADP                                      URI=http://purl.obolibrary.org/obo/CHEBI_16761
#   • ADP(3-)                                  URI=http://purl.obolibrary.org/obo/CHEBI_456216 score=1.00
#
# Query: krebs cycle intermediate
#   • intermediate I                           URI=http://purl.obolibrary.org/obo/CHEBI_142668 score=1.00
#
# Query: oxygen
#   • oxygen-16(6+)                            URI=http://purl.obolibrary.org/obo/CHEBI_149692 score=0.90
#
# Query: reactive oxygen specie
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26523
#
# Query: ro
#   • Anti-Ro Antibody                         URI=http://purl.obolibrary.org/obo/NCIT_C121322 score=0.81
#
# Query: n-acylphosphatidyl ethanolamines
#   • ethanolamines                            URI=http://purl.obolibrary.org/obo/CHEBI_23981 score=1.00
#
# Query: nape
# Query: circulating lipid
#   • lipid A(4-)                              URI=http://purl.obolibrary.org/obo/CHEBI_58712 score=1.00
#
# Query: n-acyl-phosphatidylethanolamines
#   • N-acyl-L-amino acid                      URI=http://purl.obolibrary.org/obo/CHEBI_21644 score=0.79
#
# Query: nape
# Query: nape
# Query: nape
# Query: nape
# Query: nape
# Query: lipid
#   • lipid                                    URI=http://purl.obolibrary.org/obo/CHEBI_18059
#   • lipid A(4-)                              URI=http://purl.obolibrary.org/obo/CHEBI_58712 score=1.00
#
# Query: pro-inflammatory cytokine
# Query: tight junction protein
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C13333
#
# Query: porphyra haitanensis polysaccharide
#   • Polysaccharide                           URI=http://purl.obolibrary.org/obo/NCIT_C28179 score=1.00
#
# Query: blood lipid
#   • Lipid                                    URI=http://purl.obolibrary.org/obo/NCIT_C616 score=0.81
#
# Query: porphyra haitanensis polysaccharide
#   • Polysaccharide                           URI=http://purl.obolibrary.org/obo/NCIT_C28179 score=1.00
#
# Query: php
# Query: blood lipid
#   • Lipid                                    URI=http://purl.obolibrary.org/obo/NCIT_C616 score=0.81
#
# Query: php
# Query: serum total cholesterol
#   • Serum Total Cholesterol Measurement      URI=http://purl.obolibrary.org/obo/NCIT_C61032 score=0.94
#
# Query: triglyceride
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_17855
#
# Query: low-density lipoprotein cholesterol
#   • low-density lipoprotein cholesterol      URI=http://purl.obolibrary.org/obo/CHEBI_47774
#   • low-density lipoprotein cholesterol      URI=http://purl.obolibrary.org/obo/CHEBI_47774 score=1.00
#
# Query: php
# Query: butyric acid
#   • butyric acid                             URI=http://purl.obolibrary.org/obo/CHEBI_30772
#   • butyric acid                             URI=http://purl.obolibrary.org/obo/CHEBI_30772 score=1.00
#
# Query: high-dose php
#   • High Dose Chemotherapy                   URI=http://purl.obolibrary.org/obo/NCIT_C15807 score=0.76
#
# Query: hphp
# Query: low-dose php
#   • Low-Dose Treatment                       URI=http://purl.obolibrary.org/obo/NCIT_C49341 score=0.84
#
# Query: lphp
# Query: phosphatidylcholine metabolite
#   • metabolite                               URI=http://purl.obolibrary.org/obo/CHEBI_25212 score=0.77
#
# Query: hphp
# Query: triglyceride metabolite
#   • triglyceride                             URI=http://purl.obolibrary.org/obo/CHEBI_17855 score=0.80
#
# Query: cd36
#   • CD36 Gene                                URI=http://purl.obolibrary.org/obo/NCIT_C38191 score=0.94
#
# Query: acacb
# Query: php
# Query: intestinal metabolite
#   • Metabolite                               URI=http://purl.obolibrary.org/obo/NCIT_C61154 score=0.81
#
# Query: microbial metabolite
# Query: microflora metabolite
#   • metabolite                               URI=http://purl.obolibrary.org/obo/CHEBI_25212 score=1.00
#
# Query: microbial metabolite
# Query: 3-dehydrocarnitine
#   • 3-dehydrocarnitine                       URI=http://purl.obolibrary.org/obo/CHEBI_57885
#   • 3-dehydrocarnitine                       URI=http://purl.obolibrary.org/obo/CHEBI_57885 score=1.00
#
# Query: epiandrosterone sulfate
#   • epiandrosterone sulfate                  URI=http://purl.obolibrary.org/obo/CHEBI_83040
#   • epiandrosterone sulfate                  URI=http://purl.obolibrary.org/obo/CHEBI_83040 score=1.00
#
# Query: leucine
#   • leucine                                  URI=http://purl.obolibrary.org/obo/CHEBI_25017
#   • L-leucine                                URI=http://purl.obolibrary.org/obo/CHEBI_15603 score=1.00
#
# Query: short chain fatty acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
# Query: scfas
# Query: kynurenine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_86262
#
# Query: norepinephrine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_90022
#
# Query: glutamate
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_29985
#
# Query: tryptophan
#   • tryptophan                               URI=http://purl.obolibrary.org/obo/CHEBI_27897
#   • tryptophan                               URI=http://purl.obolibrary.org/obo/CHEBI_27897 score=1.00
#
# Query: dopamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_18243
#
# Query: epinephrine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_89878
#
# Query: -aminobutyric acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_229980
#
# Query: gaba
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_165543
#
# Query: scfas
# Query: scfa
# Query: gaba
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_165543
#
# Query: gaba
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_165543
#
# Query: cholesterol
#   • cholesterol                              URI=http://purl.obolibrary.org/obo/CHEBI_16113
#   • cholesterol                              URI=http://purl.obolibrary.org/obo/CHEBI_16113 score=1.00
#
# Query: 5-ht
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_138861
#
# Query: 5-hydroxytryptamine
#   • 4-hydroxytryptamine                      URI=http://purl.obolibrary.org/obo/CHEBI_139217 score=1.00
#
# Query: 5-ht
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_138861
#
# Query: ldl-c
#   • LDL Pathway                              URI=http://purl.obolibrary.org/obo/NCIT_C39137 score=0.85
#
# Query: tc
#   • 5'-d[TC]-3'                              URI=http://purl.obolibrary.org/obo/CHEBI_75157 score=1.00
#
# Query: tg
#   • TG(8:0/8:0/10:0)                         URI=http://purl.obolibrary.org/obo/CHEBI_180791 score=0.84
#
# Query: il-1
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C108381
#
# Query: mcp-1
# Query: il-17a
# Query: mcp-1
# Query: 5-ht
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_138861
#
# Query: mcp-1
# Query: il-17a
# Query: 5-ht
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_138861
#
# Query: nutraceuticals
# Query: short-chain fatty acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
# Query: trimethylamine n-oxide
#   • trimethylamine N-oxide                   URI=http://purl.obolibrary.org/obo/CHEBI_15724
#   • trimethylamine N-oxide                   URI=http://purl.obolibrary.org/obo/CHEBI_15724 score=1.00
#
# Query: gut microbiota-associated epitope
# Query: potentially immunogenic epitope
#   • epitope                                  URI=http://purl.obolibrary.org/obo/CHEBI_53000 score=1.00
#
# Query: gut microbiota-associated epitope me
# Query: potentially immunogenic epitope
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_53000
#
# Query: candidate me
#   • Candidate                                URI=http://purl.obolibrary.org/obo/NCIT_C138079 score=1.00
#
# Query: me
# Query: me
# Query: me
# Query: gut iga level
# Query: me
# Query: me
# Query: me
# Query: peptide
#   • peptide                                  URI=http://purl.obolibrary.org/obo/CHEBI_16670
#   • peptide                                  URI=http://purl.obolibrary.org/obo/CHEBI_16670 score=1.00
#
# Query: me
# Query: gap junction alpha-1
#   • Gap Junction Alpha-1 Protein             URI=http://purl.obolibrary.org/obo/NCIT_C115172 score=0.95
#
# Query: gja1
#   • GJA1 Gene                                URI=http://purl.obolibrary.org/obo/NCIT_C115170 score=0.95
#
# Query: paired box protein pax-3
#   • Paired Box Protein Pax-6                 URI=http://purl.obolibrary.org/obo/NCIT_C75890 score=1.00
#
# Query: pax3
#   • PAX3'                                    URI=http://purl.obolibrary.org/obo/CHEBI_209474 score=1.00
#
# Query: eye absent homolog 1 isoform 4
# Query: eya1
#   • EYA1 Gene                                URI=http://purl.obolibrary.org/obo/NCIT_C75390 score=0.95
#
# Query: me
# Query: listeriolysin o peptide
#   • peptide                                  URI=http://purl.obolibrary.org/obo/CHEBI_16670 score=1.00
#
# Query: me
# Query: gut iga level
# Query: me
# Query: me
# Query: me
# Query: central monoamine neurotransmitter
# Query: amino acid transmitter
#   • amino acid                               URI=http://purl.obolibrary.org/obo/CHEBI_33709 score=1.00
#
# Query: monosaccharide glucose
#   • monosaccharide                           URI=http://purl.obolibrary.org/obo/CHEBI_35381 score=0.80
#
# Query: structure -4--glcp- 1
#   • Structure II                             URI=http://purl.obolibrary.org/obo/CHEBI_224481 score=0.76
#
# Query: short-chain fatty acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
# Query: lipopolysaccharides
# Query: hydrogen sulfide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16136
#
# Query: glutamate
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_29985
#
# Query: short-chain fatty acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
# Query: butyric
#   • butyric acid                             URI=http://purl.obolibrary.org/obo/CHEBI_30772 score=0.95
#
# Query: propionic acid
#   • propionic acid                           URI=http://purl.obolibrary.org/obo/CHEBI_30768
#   • propionic acid                           URI=http://purl.obolibrary.org/obo/CHEBI_30768 score=1.00
#
# Query: aspartic acid
#   • aspartic acid                            URI=http://purl.obolibrary.org/obo/CHEBI_22660
#   • L-aspartic acid                          URI=http://purl.obolibrary.org/obo/CHEBI_17053 score=1.00
#
# Query: glutamic acid
#   • glutamic acid                            URI=http://purl.obolibrary.org/obo/CHEBI_18237
#   • L-glutamic acid                          URI=http://purl.obolibrary.org/obo/CHEBI_16015 score=1.00
#
# Query: tryptophan
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_27897
#
# Query: glutamic acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16015
#
# Query: gamma-aminobutyric acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16865
#
# Query: tryptophan
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_27897
#
# Query: serotonin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_350546
#
# Query: kynurenic acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_18344
#
# Query: tryptamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16765
#
# Query: 5-hydroxytryptamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_139217
#
# Query: 5-ht
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_138861
#
# Query: brain-derived neurotrophic factor
#   • Brain-Derived Neurotrophic Factor        URI=http://purl.obolibrary.org/obo/NCIT_C20445 score=1.00
#
# Query: bdnf
#   • BDNF Gene                                URI=http://purl.obolibrary.org/obo/NCIT_C28534 score=0.94
#
# Query: toll-like receptor
#   • Toll-like receptor 2 agonist             URI=http://purl.obolibrary.org/obo/CHEBI_77161 score=0.91
#
# Query: toll-like receptor
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_77161
#
# Query: toll-like receptor 2
#   • Toll-like receptor 2 agonist             URI=http://purl.obolibrary.org/obo/CHEBI_77161 score=0.91
#
# Query: tlr2
#   • TLR2 Gene                                URI=http://purl.obolibrary.org/obo/NCIT_C24863 score=0.95
#
# Query: toll-like receptor 4
#   • Toll-like receptor 2 agonist             URI=http://purl.obolibrary.org/obo/CHEBI_77161 score=0.91
#
# Query: tlr4
#   • TLR4 Gene                                URI=http://purl.obolibrary.org/obo/NCIT_C24865 score=0.94
#
# Query: toll-like receptor 2
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_77161
#
# Query: toll-like receptor 4
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_77161
#
# Query: toll-like receptor 2
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_77161
#
# Query: toll-like receptor 4
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_77161
#
# Query: toll-like receptor 2
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_77161
#
# Query: toll-like receptor 4
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_77161
#
# Query: short-chain fatty acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
# Query: macro- and micro-nutrients
#   • Macro                                    URI=http://purl.obolibrary.org/obo/NCIT_C91066 score=0.76
#
# Query: micronutrient
#   • micronutrient                            URI=http://purl.obolibrary.org/obo/CHEBI_27027
#   • micronutrient                            URI=http://purl.obolibrary.org/obo/CHEBI_27027 score=1.00
#
# Query: omega-3 fatty acid
#   • omega-3 fatty acid                       URI=http://purl.obolibrary.org/obo/CHEBI_25681
#   • omega-3 fatty acid                       URI=http://purl.obolibrary.org/obo/CHEBI_25681 score=1.00
#
# Query: bioactive polyphenols
# Query: carbohydrate
#   • carbohydrate                             URI=http://purl.obolibrary.org/obo/CHEBI_16646
#   • carbohydrate                             URI=http://purl.obolibrary.org/obo/CHEBI_16646 score=1.00
#
# Query: carbohydrate
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16646
#
# Query: short-chain fatty acid butyrate
#   • short-chain fatty acid                   URI=http://purl.obolibrary.org/obo/CHEBI_26666 score=0.87
#
# Query: microbial short-chain fatty acid
#   • short-chain fatty acid                   URI=http://purl.obolibrary.org/obo/CHEBI_26666 score=0.77
#
# Query: scfas
# Query: scfas
# Query: branched-chain scfas
#   • branched-chain amino acid                URI=http://purl.obolibrary.org/obo/CHEBI_22918 score=0.92
#
# Query: cecal acetate
#   • acetate                                  URI=http://purl.obolibrary.org/obo/CHEBI_30089 score=1.00
#
# Query: scfas
# Query: microbial metabolite
# Query: serotonin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_350546
#
# Query: kynurenine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_86262
#
# Query: tryptamine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_16765
#
# Query: indole
#   • indole                                   URI=http://purl.obolibrary.org/obo/CHEBI_35581
#   • indole                                   URI=http://purl.obolibrary.org/obo/CHEBI_35581 score=1.00
#
# Query: hba1c
# Query: hba1c
# Query: hba1c
# Query: lipid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_58712
#
# Query: hunger hormone
#   • hormone                                  URI=http://purl.obolibrary.org/obo/CHEBI_24621 score=1.00
#
# Query: gut hormone
# Query: hba1c
# Query: fertilizer
#   • fertilizer                               URI=http://purl.obolibrary.org/obo/CHEBI_33287
#   • fertilizer                               URI=http://purl.obolibrary.org/obo/CHEBI_33287 score=1.00
#
# Query: pesticide
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_25944
#
# Query: short-chain fatty acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
# Query: short-chain fatty acid
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_26666
#
# Query: scfas
# Query: metabolite scfas
#   • metabolite                               URI=http://purl.obolibrary.org/obo/CHEBI_25212 score=1.00
#
# Query: scfas

# %% [markdown]
# <h1>INGEST FOOD</h1>

# %%
import os
import re
import unicodedata
import json
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint

FOODON_BASE = "http://purl.obolibrary.org/obo/"
NCIT_BASE = "http://purl.obolibrary.org/obo/"
FOOD_CLASS = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Food")
FOOD_CONCEPT_SCHEME = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Food")

TAX1_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\food_tree.txt"
TAX2_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\foodon_terms.txt"

def load_taxonomy_tree(path):
    row_re = re.compile(r"^\s*(.*?)\s+\[([^\]]+)\]\s*$")
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = row_re.match(ln)
            if m:
                label, tid = m.groups()
                depth = len(ln) - len(ln.lstrip())
                rows.append((label, tid, depth))
    return rows

rows1 = load_taxonomy_tree(TAX1_FILE)
rows2 = load_taxonomy_tree(TAX2_FILE)

exact1 = defaultdict(list)
for lbl, tid, depth in rows1:
    exact1[lbl.lower()].append((lbl, tid, depth))

exact2 = defaultdict(list)
for lbl, tid, depth in rows2:
    exact2[lbl.lower()].append((lbl, tid, depth))

labels1 = [lbl for lbl,_,_ in rows1]
vec1    = TfidfVectorizer(stop_words="english")
mat1    = vec1.fit_transform(labels1)

labels2 = [lbl for lbl,_,_ in rows2]
vec2    = TfidfVectorizer(stop_words="english")
mat2    = vec2.fit_transform(labels2)

def top_cosine(rows, vec, mat, labels, term, k=5, thr=0.75):
    v   = vec.transform([term])
    sc  = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, tid, depth = rows[i]
        out.append((lbl, tid, depth, sc[i]))
    return out

created["Food"] = URIRef(f"{NCIT_BASE}NCIT_C62695")
g.add((created["Food"], RDF.type, FOOD_CLASS))
g.add((created["Food"], RDF.type, SKOS.Concept))
g.add((created["Food"], RDFS.label, Literal("Food", datatype=XSD.string)))
g.add((created["Food"], SKOS.inScheme, FOOD_CONCEPT_SCHEME))

for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "food":
            text_span = entity.get("text_span", "").strip()
            cleaned_text = create_uri_fragment(text_span)
            cleaned_text_span = normalize_to_ascii(cleaned_text)
            term_raw = cleaned_text_span.lower()
            term = preprocess(term_raw)
            
            print(f"Query: {term}")
            
            if term_raw in created:
                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                continue

            ex1 = exact1.get(term.lower(), [])
            if ex1:
                for l,t,d in ex1:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score=1.00 (TAX1 exact)")
                    entity_uri = URIRef(f"{NCIT_BASE}{t}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, FOOD_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(l, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                    g.add((entity_uri, SKOS.broaderTransitive, created["Food"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            cos1 = top_cosine(rows1, vec1, mat1, labels1, term, k=5, thr=0.75)
            if cos1:
                for l,t,d,s in cos1[:1]:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f} (TAX1 cosine)")
                    name_uri = URIRef(f"{NCIT_BASE}{t}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, FOOD_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(l, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                    g.add((name_uri, SKOS.broaderTransitive, created["Food"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                continue

            cos2 = top_cosine(rows2, vec2, mat2, labels2, term, k=5, thr=0.75)
            if cos2:
                for l,t,d,s in cos2[:1]:
                    print(f"  • {l:40s} ID={t:15s} depth={d:<2d} score={s:.2f} (TAX2 cosine)")
                    name_uri = URIRef(f"{FOODON_BASE}{t}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, FOOD_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(l, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, FOOD_CONCEPT_SCHEME))
                    g.add((name_uri, SKOS.broaderTransitive, created["Food"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
            else:
                mention_uri = URIRef(GUTBRAIN[term_raw])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_food_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((created["Food"], GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAIN[f"title_{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAIN[f"abstract_{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "food":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAIN[cleaned_text_span])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_food_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))
# Out:
# Query: vegetable
#   • Vegetable                                ID=NCIT_C178192    depth=4  score=1.00 (TAX1 exact)
#   • Vegetable                                ID=NCIT_C178192    depth=4  score=1.00 (TAX1 cosine)
#
# Query: whole grain cereal
#   • Whole Grain                              ID=NCIT_C178197    depth=2  score=1.00 (TAX1 cosine)
#
# Query: high-fiber diet
#   • high fiber food                          ID=FOODON_03510048 depth=0  score=0.76 (TAX2 cosine)
# Query: high-fiber diet
#   → Reusing existing URI: http://purl.obolibrary.org/obo/FOODON_03510048
#
# Query: high-fiber diet
#   → Reusing existing URI: http://purl.obolibrary.org/obo/FOODON_03510048
#
# Query: high-fiber diet
#   → Reusing existing URI: http://purl.obolibrary.org/obo/FOODON_03510048
#
# Query: high-fiber diet
#   → Reusing existing URI: http://purl.obolibrary.org/obo/FOODON_03510048
#
# Query: wheat germ
#   • wheat germ                               ID=FOODON_03301595 depth=0  score=1.00 (TAX2 cosine)
# Query: wheat germ
#   • wheat germ                               ID=FOODON_03301595 depth=0  score=1.00 (TAX2 cosine)
# Query: dietary fiber
# Query: thyme
#   • thyme plant                              ID=FOODON_03411199 depth=0  score=0.90 (TAX2 cosine)
# Query: thymus vulgaris
# Query: oregano
#   • obsolete: oregano plant                  ID=FOODON_03411542 depth=0  score=0.85 (TAX2 cosine)
# Query: origanum vulgare
# Query: low-caloric diet
# Query: animal to vegetal food
#   • Food                                     ID=NCIT_C62695     depth=0  score=1.00 (TAX1 cosine)
#
# Query: poultry meat
#   • poultry meat product                     ID=FOODON_03315174 depth=0  score=0.89 (TAX2 cosine)
# Query: meat
#   • Meat                                     ID=NCIT_C126482    depth=2  score=1.00 (TAX1 exact)
#   • Meat                                     ID=NCIT_C126482    depth=2  score=1.00 (TAX1 cosine)
#
# Query: egg
#   • obsolete: whole egg                      ID=FOODON_03420274 depth=0  score=0.84 (TAX2 cosine)
# Query: pork
#   • Pork                                     ID=NCIT_C71958     depth=4  score=1.00 (TAX1 exact)
#   • Pork                                     ID=NCIT_C71958     depth=4  score=1.00 (TAX1 cosine)

# %% [markdown]
# <h1>INGEST HUMAN</h1>

# %%
import os
import re
import unicodedata
import json
from pathlib import Path
from collections import defaultdict
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint

# -----------------------------------------------------------------------------
# Constants / Namespaces
# -----------------------------------------------------------------------------
NCBI_BASE             = "http://purl.obolibrary.org/obo/"
MESH_BASE             = "https://www.ncbi.nlm.nih.gov/mesh/"
HUMAN_CLASS           = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Human")
HUMAN_CONCEPT_SCHEME  = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Human")

# add a “Humans” concept
#created["Humans"] = URIRef(f"{NCBI_BASE}NCBITaxon_9606")
#g.add((created["Humans"], RDF.type, HUMAN_CLASS))
#g.add((created["Humans"], RDF.type, SKOS.Concept))
#g.add((created["Humans"], RDFS.label, Literal("Humans", datatype=XSD.string)))
#g.add((created["Humans"], SKOS.inScheme, HUMAN_CONCEPT_SCHEME))

def parse_mesh_descriptors(xml_path):
    descs = []
    tree  = ET.parse(xml_path)
    root  = tree.getroot()
    for dr in root.findall('DescriptorRecord'):
        ui   = dr.findtext('DescriptorUI')
        name = dr.findtext('DescriptorName/String')
        tns  = [tn.text for tn in dr.findall('TreeNumberList/TreeNumber') if tn.text]
        if ui and name:
            descs.append({'ui':ui,'name':name,'tree_numbers':tns})
    return descs

def build_name_index(descriptors):
    idx = defaultdict(list)
    for d in descriptors:
        if not d['tree_numbers']: continue
        tn = d['tree_numbers'][0]
        idx[d['name'].lower()].append((tn, d['ui'], d['name']))
    return idx

MESH_XML     = 'desc2025.xml'
mesh_descs   = parse_mesh_descriptors(MESH_XML)
mesh_index   = build_name_index(mesh_descs)

mesh_items   = [(tn,ui,name) for vs in mesh_index.values() for tn,ui,name in vs]
mesh_labels  = [name for (_,_,name) in mesh_items]
mesh_uids    = [ui   for (_,ui,_)   in mesh_items]

mesh_vec     = TfidfVectorizer(stop_words="english").fit(mesh_labels)
mesh_mat     = mesh_vec.transform(mesh_labels)

def load_taxonomy_tree(path):
    row_re = re.compile(r"^\s*(.*?)\s+\[([^\]]+)\]\s*$")
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = row_re.match(ln)
            if m:
                label, tid = m.groups()
                depth      = len(ln) - len(ln.lstrip())
                rows.append((label, tid, depth))
    return rows

TAX_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\patients_output.txt"
rows     = load_taxonomy_tree(TAX_FILE)

exact_ix  = defaultdict(list)
for lbl, tid, depth in rows:
    exact_ix[lbl.lower()].append((lbl, tid, depth))

labels_only  = [r[0] for r in rows]
vec          = TfidfVectorizer(stop_words="english")
mat          = vec.fit_transform(labels_only)

def top_cosine(term, k=5, thr=0.75):
    v   = vec.transform([term])
    sc  = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr: break
        lbl, tid, d = rows[i]
        out.append((lbl, tid, d, sc[i]))
    return out
    
for paper_id, paper_data in data.items():
    entities = paper_data.get("entities", [])
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "human":
            text_span = entity.get("text_span", "").strip()
            cleaned_text = create_uri_fragment(text_span)
            cleaned_text_span = normalize_to_ascii(cleaned_text)
            term_raw = cleaned_text_span.lower()
            term = preprocess(term_raw)
            
            print(f"Query: {term}")
            
            if term_raw in created:
                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                continue

            mesh_ex = mesh_index.get(term, [])
            if mesh_ex:
                for t,u,n in mesh_ex:
                    print(f"  • {t:40s} ID={u:15s} depth={n:40s} score=1.00 (TAX1 exact)")
                    entity_uri = URIRef(f"{MESH_BASE}{u}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, HUMAN_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(n, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                    #g.add((entity_uri, SKOS.broaderTransitive, created["Humans"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            cos = top_cosine(term)
            if cos:
                for name, ui, depth, score in cos[:1]:
                    print(f"  • {name:40s} ID={ui:15s} depth={depth:<2d} score={score:.2f} (Patients cosine)")
                    name_uri = URIRef(f"{MESH_BASE}{ui}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, HUMAN_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(name, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, HUMAN_CONCEPT_SCHEME))
                    #g.add((name_uri, SKOS.broaderTransitive, created["Humans"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                continue
            else:
                mention_uri = URIRef(GUTBRAIN[term_raw])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_human_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                #g.add((created["Humans"], GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                continue

        else:
            print("Not creating human")

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAIN[f"title_{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAIN[f"abstract_{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "human":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAIN[cleaned_text_span])
            tokenized_mentions[cleaned_text_span] = mention_uri
            print(cleaned_text_span)
            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_human_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))
# Out:
# Not creating human
# Query: patient
# Query: patient
# Not creating human
# Not creating human
# Query: people
# Not creating human
# Not creating human
# Query: bariatric patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: control
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Query: healthy control
# Query: human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: female
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: schizophrenia patient
# Query: healthy control
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: schizophrenia patient
# Query: healthy control
# Not creating human
# Query: schizophrenia patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: health control
# Not creating human
# Query: schizophrenia cohort
# Query: control cohort
# Not creating human
# Query: healthy control
# Query: schizophrenia patient
# Not creating human
# Not creating human
# Not creating human
# Query: schizophrenia patient
# Query: healthy control
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: stressed adult
# Not creating human
# Not creating human
# Not creating human
# Query: placebo group
# Query: probiotic group
# Query: placebo group
# Query: probiotic group
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: probiotic group
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: stressed adult
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: parkinson s disease pd patient
# Not creating human
# Not creating human
# Not creating human
# Query: pd patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: human
# Not creating human
# Not creating human
# Query: individual
# Not creating human
# Query: human
# Not creating human
# Query: human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: human
# Not creating human
# Query: human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: individual
# Not creating human
# Not creating human
# Query: comorbid patient
# Query: healthy control
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: ibs-d patient
# Not creating human
# Not creating human
# Query: depression patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: mother-infant pair
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: mother
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: vaginally delivered infant
# Not creating human
# Query: vaginally delivered fully breastfed infant
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: world s population
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: major depressive episode patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Query: healthy control
# Query: hcs
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: hcs
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: hcs
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: individual
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: offspring
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: child
#   • M01.060.406                              ID=D002648         depth=Child                                    score=1.00 (TAX1 exact)
# Query: woman
# Not creating human
# Not creating human
# Not creating human
# Query: woman
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Not creating human
# Query: woman
# Not creating human
# Query: child
#   • M01.060.406                              ID=D002648         depth=Child                                    score=1.00 (TAX1 exact)
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: woman
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Query: adolescent
#   • M01.060.057                              ID=D000293         depth=Adolescent                               score=1.00 (TAX1 exact)
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Query: adolescent
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D000293
#
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: pediatric population
# Not creating human
# Query: child and adolescent population 0-18 year old
# Not creating human
# Not creating human
# Not creating human
# Query: youth
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: asd and healthy control
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Query: adolescent
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D000293
#
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: child and adolescent population
# Not creating human
# Not creating human
# Not creating human
# Query: type 2 diabetes patient
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Query: participant
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Query: military veteran
# Query: homeless individual
# Not creating human
# Not creating human
# Query: veteran
# Query: individual
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: veteran
# Query: veteran
# Not creating human
# Query: veteran
# Query: veteran
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: individual patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: individual
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: person
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: individual
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: hospitalized older adult
# Not creating human
# Not creating human
# Query: geriatric population
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: hospitalized acutely ill older adult
# Query: geriatric patient
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Query: older adult
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Query: inpatient
# Query: female
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: taiwanese patient
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Query: gender-matched control
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Query: pd patient
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: population
#   • N01.600                                  ID=D011153         depth=Population                               score=1.00 (TAX1 exact)
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: pcos patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: pcos patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: depressed woman
# Not creating human
# Query: pcos-dp
# Query: mentally healthy woman
# Not creating human
# Not creating human
# Query: healthy control
# Query: patient
# Not creating human
# Not creating human
# Query: pcos-dp
# Query: hc mdd and pcos group
# Query: pcos-dp
# Query: pcos patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: pcos-dp
# Not creating human
# Query: pcos-dp
# Not creating human
# Not creating human
# Query: pcos-dp
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: pcos patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: typically developing td child
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Query: td child
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: asd child
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: asd child
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Not creating human
# Not creating human
# Query: major depressive disorder patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: mdd patient
# Not creating human
# Query: mdd patient
# Query: healthy control
# Query: hcs
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: mdd patient
# Query: hcs
# Query: mdd patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: mdd group
# Not creating human
# Query: mdd group
# Not creating human
# Not creating human
# Not creating human
# Query: mdd patient
# Query: hcs
# Not creating human
# Query: healthy adult
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: healthy adult
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: nvp-1704 group
# Not creating human
# Not creating human
# Query: placebo group
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: edf group
# Not creating human
# Query: p group
# Not creating human
# Not creating human
# Query: ed and edf group
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: individual
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: individual
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: woman
# Query: reproductive-aged woman
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Query: pcos patient
# Not creating human
# Query: pcos patient
# Not creating human
# Not creating human
# Not creating human
# Query: pcos patient
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Query: healthy control
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Query: healthy control
# Query: patient
# Query: healthy control
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Query: healthy control
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: healthy control
# Query: alcohol overconsumption group
# Query: patient
# Not creating human
# Query: patient
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: pd and healthy control
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Query: healthy control
# Query: insomnia patient
# Query: healthy control
# Not creating human
# Not creating human
# Not creating human
# Query: acute insomnia patient
# Query: healthy control
# Not creating human
# Not creating human
# Query: chronic insomnia patient
# Query: healthy control
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Query: healthy control
# Query: hcs
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Query: hcs
# Not creating human
# Not creating human
# Query: hcs
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: tibetan buddhist monk
# Query: neighbouring resident
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: monk
# Query: control subject
# Query: monk
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: female
# Not creating human
# Not creating human
# Query: control
# Not creating human
# Query: female
# Query: control
# Query: participant
# Not creating human
# Not creating human
# Query: participant
# Not creating human
# Not creating human
# Query: participant
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: participant aged 18-40 year
# Query: participant
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: people with pd
# Query: pwp
# Query: pwp
# Query: healthy control
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: pwp
# Query: control group
# Query: pwp
# Not creating human
# Not creating human
# Query: pwp
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: pwp
# Query: pd cohort
# Not creating human
# Not creating human
# Query: pwp
# Not creating human
# Query: southern hemisphere pd population
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: parkinson s disease patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: human subject
# Not creating human
# Not creating human
# Query: individual
# Query: healthy control
# Not creating human
# Not creating human
# Not creating human
# Query: control
# Not creating human
# Not creating human
# Query: female pd patient
# Query: healthy control
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: pd patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# ...
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: asd child
# Query: typically developing td child
# Not creating human
# Not creating human
# Query: asd child
# Query: typically developing td child
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Query: asd child
# Query: td child
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Query: asd child
# Query: td child
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: asd child
# Query: td child
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Not creating human
# Not creating human
# Query: child
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D002648
#
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: asd child
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: participant
# Query: criteria-acute group patient with acute schizophrenia
# Query: remission group patient with schizophrenia in remission
# Query: control group healthy control
# Not creating human
# Not creating human
# Not creating human
# Query: acute group
# Query: remission and control group
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Query: healthy control
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: people
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: crew member
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: older subject
# Not creating human
# Query: older subject
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: at-risk group
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: parkinson s disease patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Query: mdd patient
# Query: healthy control
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: healthy person
# Not creating human
# Not creating human
# Query: healthy person
# Not creating human
# Query: woman
# Query: men
#   → Reusing existing URI: https://www.ncbi.nlm.nih.gov/mesh/D008571
#
# Not creating human
# Not creating human
# Query: people
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: people
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: individual
# Not creating human
# Query: participant
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: participant
# Query: participant
# Not creating human
# Not creating human
# Not creating human
# Query: probiotic group
# Query: placebo group
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: generation over 75
# Query: younger generation
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: younger generation
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: egyptian patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Query: healthy subject
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: pd patient
# Not creating human
# Query: pd patient
# Query: healthy control
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: parkinson s disease patient
# Query: healthy control
# Not creating human
# Not creating human
# Not creating human
# Query: breast cancer survivor
# Not creating human
# Not creating human
# Query: cancer survivor
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: cancer survivor
# Query: woman
# Not creating human
# Not creating human
# Query: participant
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: participant
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Query: healthy population
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: patient
# Not creating human
# Query: healthy volunteer
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Not creating human
# Query: mdd group
# Query: control c group
# Not creating human
# Query: mdd group
# Query: c group
# Not creating human
# Query: mdd group
# Query: c group
# Query: mdd group
# Query: c group
# Not creating human
# Not creating human
# Not creating human
# Not creating human

# %% [markdown]
# <h1>INGEST DRUG</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint

DRUG_BASE = "http://purl.obolibrary.org/obo/"
DRUG_CLASS = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Drug")
DRUG_CONCEPT_SCHEME = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Drug")

created["Drug"] = URIRef(f"{CHEBI_BASE}CHEBI_23888")
g.add((created["Drug"], RDF.type, DRUG_CLASS))
g.add((created["Drug"], RDF.type, SKOS.Concept))
g.add((created["Drug"], RDFS.label, Literal("Drug", datatype=XSD.string)))
g.add((created["Drug"], SKOS.inScheme, DRUG_CONCEPT_SCHEME))


def load_chebi_labels(path):
    rows = []
    with open(path, encoding="utf-8") as fh:
        next(fh) 
        for ln in fh:
            uri, label = ln.rstrip("\n").split("\t", 1)
            rows.append((label, uri))
    return rows

CHEBI_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\chebi_labels.txt"
chebi_rows = load_chebi_labels(CHEBI_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in chebi_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

labels_only = [lbl for lbl, _ in chebi_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

def top_cosine(term, k=5, thr=0.75):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = chebi_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

greek_map = {
    'α': 'alpha',  'Α': 'alpha',
    'β': 'beta',   'Β': 'beta',
    'γ': 'gamma',  'Γ': 'gamma',
    'δ': 'delta',  'Δ': 'delta',
    'ε': 'epsilon','Ε': 'epsilon',
    'ζ': 'zeta',   'Ζ': 'zeta',
    'η': 'eta',    'Η': 'eta',
    'θ': 'theta',  'Θ': 'theta',
    'ι': 'iota',   'Ι': 'iota',
    'κ': 'kappa',  'Κ': 'kappa',
    'λ': 'lambda', 'Λ': 'lambda',
    'μ': 'mu',     'Μ': 'mu',
    'ν': 'nu',     'Ν': 'nu',
    'ξ': 'xi',     'Ξ': 'xi',
    'ο': 'omicron','Ο': 'omicron',
    'π': 'pi',     'Π': 'pi',
    'ρ': 'rho',    'Ρ': 'rho',
    'σ': 'sigma',  'Σ': 'sigma',
    'τ': 'tau',    'Τ': 'tau',
    'υ': 'upsilon','Υ': 'upsilon',
    'φ': 'phi',    'Φ': 'phi',
    'χ': 'chi',    'Χ': 'chi',
    'ψ': 'psi',    'Ψ': 'psi',
    'ω': 'omega',  'Ω': 'omega',
}

def preprocess(term):
    for greek_char, name in greek_map.items():
        if greek_char in term:
            term = term.replace(greek_char, name)
    term = term.replace('_', ' ')
    term = term.strip()
    return term.lower()
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "drug":
            text_span = entity.get("text_span", "").strip()
            cleaned_text = create_uri_fragment(text_span)
            cleaned_text_span = normalize_to_ascii(cleaned_text)
            term_raw = cleaned_text_span.lower()
            term = preprocess(term_raw)
            
            print(f"Query: {term}")
            
            if term_raw in created:
                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                continue

            ex = exact_ix.get(term, [])
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, DRUG_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, DRUG_CONCEPT_SCHEME))
                    g.add((entity_uri, SKOS.broaderTransitive, created["Drug"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            cos = top_cosine(term)
            if cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DRUG_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DRUG_CONCEPT_SCHEME))
                    g.add((name_uri, SKOS.broaderTransitive, created["Drug"]))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAIN[term_raw])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                g.add((created["Drug"], GUTPROP.containedIn, mention_uri))
                tokenized_mentions[term_raw] = mention_uri
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAIN[f"title_{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAIN[f"abstract_{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "drug":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAIN[cleaned_text_span])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_drug_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))
# Out:
# Query: antibiotics
#   • amino acid derivative antibiotics        URI=http://purl.obolibrary.org/obo/CHEBI_22476 score=0.78
#
# Query: antibiotic growth promotants
# Query: agps
# Query: agps
# Query: agps
# Query: agps
# Query: agp treatments
# Query: agps
# Query: agps
# Query: agps
# Query: non-absorbable antibiotic vancomycin
# Query: olanzapine
#   • olanzapine                               URI=http://purl.obolibrary.org/obo/CHEBI_7735
#   • olanzapine                               URI=http://purl.obolibrary.org/obo/CHEBI_7735 score=1.00
#
# Query: olanzapine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_7735
#
# Query: olanzapine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_7735
#
# Query: olanzapine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_7735
#
# Query: placebo tablets
# Query: placebo
# Query: placebo
# Query: placebo
# Query: olanzapine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_7735
#
# Query: antibiotic
#   • piperidine antibiotic                    URI=http://purl.obolibrary.org/obo/CHEBI_49318 score=0.79
#
# Query: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_49318
#
# Query: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_49318
#
# Query: antibiotic
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_49318
#
# Query: antidepressants
# Query: escitalopram
#   • escitalopram                             URI=http://purl.obolibrary.org/obo/CHEBI_36791
#   • escitalopram(1+)                         URI=http://purl.obolibrary.org/obo/CHEBI_77406 score=1.00
#
# Query: escitalopram
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_77406
#
# Query: ct-26
#   • 26,26,26-trifluoro-25-hydroxyvitamin D3 / 26,26,26-trifluoro-25-hydroxycholecalciferol URI=http://purl.obolibrary.org/obo/CHEBI_168482 score=0.83
#
# Query: oxaliplatin
#   • oxaliplatin                              URI=http://purl.obolibrary.org/obo/CHEBI_31941
#   • oxaliplatin                              URI=http://purl.obolibrary.org/obo/CHEBI_31941 score=1.00
#
# Query: rhepo
# Query: cuprizone
# Query: cpz
# Query: cpz
# Query: antibiotics
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_22476
#
# Query: csf1r inhibitor
#   • inhibitor                                URI=http://purl.obolibrary.org/obo/CHEBI_35222 score=1.00
#
# Query: antidepressants
# Query: antidepressant medications
#   • antidepressant                           URI=http://purl.obolibrary.org/obo/CHEBI_35469 score=1.00
#
# Query: antidepressants
# Query: antidepressants
# Query: antidepressants
# Query: antidepressants
# Query: antidepressant pmx
# Query: antidepressants
# Query: antidepressants
# Query: psychotropic medication
#   • psychotropic drug                        URI=http://purl.obolibrary.org/obo/CHEBI_35471 score=0.82
#
# Query: drugs
# Query: antibiotics
#   → Reusing existing URI: http://purl.obolibrary.org/obo/CHEBI_22476
#
# Query: antidepressant
#   • antidepressant                           URI=http://purl.obolibrary.org/obo/CHEBI_35469
#   • antidepressant                           URI=http://purl.obolibrary.org/obo/CHEBI_35469 score=1.00
#
# Query: anti-anxiety drugs
# Query: placebo

# %% [markdown]
# <h1>INGEST MICROBIOME</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint

MICROBIOME_BASE = "http://purl.obolibrary.org/obo/"
MICROBIOME_CLASS = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Microbiome")
MICROBIOME_CONCEPT_SCHEME = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Microbiome")

def load_ohmi_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*\[([A-Za-z0-9_]+)\]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = MICROBIOME_BASE + term_id
            rows.append((label, uri))
    return rows

OHMI_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\OHMI_full_taxonomy.txt"
ohmi_rows = load_ohmi_labels(OHMI_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in ohmi_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in ohmi_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

def top_cosine(term, k=5, thr=0.75):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = ohmi_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

def preprocess(term):
    term = term.replace('_', ' ')
    term = term.strip()
    return term.lower()
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "microbiome":
            text_span = entity.get("text_span", "").strip()
            cleaned_text = create_uri_fragment(text_span)
            cleaned_text_span = normalize_to_ascii(cleaned_text)
            term_raw = cleaned_text_span.lower()
            term = preprocess(term_raw)
            
            if re.search(r'\bbacter(?:ia|ium)\b', text_span.lower()):
                mention_uri = URIRef(GUTBRAIN[term_raw])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                continue
            
            print(f"Query: {term}")
            
            if term_raw in created:
                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                continue

            ex = exact_ix.get(term, [])
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, MICROBIOME_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, MICROBIOME_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            cos = top_cosine(term)
            if cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, MICROBIOME_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, MICROBIOME_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAIN[term_raw])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAIN[f"title_{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAIN[f"abstract_{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "microbiome":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAIN[cleaned_text_span])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_microbiome_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))
# Out:
# Query: gut microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: chicken gut microbiome
#   • human gut microbiome                     URI=http://purl.obolibrary.org/obo/OHMI_0000020 score=0.91
#
# Query: gut microbiome
#   • human gut microbiome                     URI=http://purl.obolibrary.org/obo/OHMI_0000020 score=0.91
#
# Query: poultry gut microbiome
#   • human gut microbiome                     URI=http://purl.obolibrary.org/obo/OHMI_0000020 score=0.91
#
# Query: chicken gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: oral and gut microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.82
#
# Query: gut and oral microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.82
#
# Query: intestinal microbiome
#   • intestinal cancer                        URI=http://purl.obolibrary.org/obo/DOID_10155 score=0.81
#
# Query: oral and gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: oral and gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: host microbiome
#   • host-microbiome interaction              URI=http://purl.obolibrary.org/obo/OHMI_0000001 score=0.85
#
# Query: microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: host microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.77
#
# Query: host microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: individual s gut microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: individual s specific gut microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbial ecosystem
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: maternal prenatal gut microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: maternal gut microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: prenatal faecal microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: faecal microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: maternal faecal microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: maternal faecal microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: maternal prenatal gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: prenatal gut microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: human microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.96
#
# Query: probiotic-exposed microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: gut microbe
#   • microbe                                  URI=http://purl.obolibrary.org/obo/OHMI_0000460 score=0.96
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: fecal microbiota
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: human intestinal microbiota
# Query: gut metagenomes
# Query: fecal metagenomes
# Query: gut microbiomes
# Query: fecal metagenomes
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: human microbiome
#   • human microbiome                         URI=http://purl.obolibrary.org/obo/OHMI_0000002
#   • human microbiome                         URI=http://purl.obolibrary.org/obo/OHMI_0000002 score=1.00
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: human gut microbiome
#   • human gut microbiome                     URI=http://purl.obolibrary.org/obo/OHMI_0000020
#   • human gut microbiome                     URI=http://purl.obolibrary.org/obo/OHMI_0000020 score=1.00
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: fecal microbiota
# Query: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: intestinal microbiota
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: intestinal microbiota
# Query: intestinal microbiota
# Query: gut microbial community
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: canine intestinal microbiota
# Query: intestinal microbiota
# Query: intestinal microbiota
# Query: depression gut microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: maternal vaginal microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: microbiota of neonatal gut and nose
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: infant microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: maternal microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: microbiota of infant gut and nose
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: maternal vaginal microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: infant faecal microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: maternal rectal microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: infant microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: infant s nasal and gut microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: infant stool microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: maternal rectal microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: infant stool microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: microbiota of infants
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: infant gut microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: infant microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: infant microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: maternal microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: infant gut and nasal microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: colonic microbiome
#   • microbiome                               URI=http://purl.obolibrary.org/obo/OHMI_0000003 score=1.00
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: altered gut microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: dysbiotic gut microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: non-commensal gut microbiome
#   • human gut microbiome                     URI=http://purl.obolibrary.org/obo/OHMI_0000020 score=0.91
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gastrointestinal microbiome
#   • microbiome in human gastrointestinal system URI=http://purl.obolibrary.org/obo/OHMI_0000016 score=0.97
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: intestinal flora
#   • intestinal cancer                        URI=http://purl.obolibrary.org/obo/DOID_10155 score=0.93
#
# Query: intestinal flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/DOID_10155
#
# Query: intestinal flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/DOID_10155
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: maternal gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbes
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gastrointestinal tract microbiome
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: human microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: human microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: fecal microbiota
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: fecal microbiota
# Query: fecal microbiota
# Query: fecal microbiota
# Query: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: intestinal microbiota
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: intestinal microbiota
# Query: intestinal microbiota
# Query: intestinal microbiota
# Query: intestinal flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/DOID_10155
#
# Query: irif
# Query: irif
# Query: intestinal microbiota
# Query: intestinal microbiota
# Query: intestinal microbiota
# Query: intestinal microbiota
# Query: human gut microbiomes
# Query: fecal microbiota
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: duodenal microbiome
#   • microbiome                               URI=http://purl.obolibrary.org/obo/OHMI_0000003 score=1.00
#
# Query: microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: human gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microorganisms
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut-microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.95
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: microbiome populations
#   • microbiome                               URI=http://purl.obolibrary.org/obo/OHMI_0000003 score=1.00
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut flora
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: intestinal flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/DOID_10155
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gms
# Query: intestinal flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/DOID_10155
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: faecal microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: intestinal flora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/DOID_10155
#
# Query: faecal microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: oral and gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut and oral microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbial
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: pharmacomicrobiomics
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: host microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: cecal microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: intestinal microbe
# Query: intestinal microflora
#   • intestinal cancer                        URI=http://purl.obolibrary.org/obo/DOID_10155 score=0.93
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: human gut microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=0.91
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbe
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000460
#
# Query: colonic microbiota
#   • microbiota                               URI=http://purl.obolibrary.org/obo/OHMI_0000463 score=1.00
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: inflammatory microbes and genes
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: positive mood-related gut microbiota
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: small bowel microbiome
# Query: small intestinal microbiome
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: intestinal barrier
#   • intestinal cancer                        URI=http://purl.obolibrary.org/obo/DOID_10155 score=0.93
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: colon microbiota
# Query: colon microbiota
# Query: colon microbiota
# Query: colon microbiota
# Query: fecal microbiota
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: fecal microbiota
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiome
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000020
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: intestinal microflora
#   → Reusing existing URI: http://purl.obolibrary.org/obo/DOID_10155
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463
#
# Query: gut microbiota
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OHMI_0000463

# %% [markdown]
# <h1>INGEST STATISTICAL TECHNIQUE</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint

STATISTICALTECHNIQUE_BASE = "http://purl.obolibrary.org/obo/"
STATISTICALTECHNIQUE_CLASS = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/StatisticalTechnique")
STATISTICALTECHNIQUE_CONCEPT_SCHEME = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/StatisticalTechnique")

def load_statistical_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = STATISTICALTECHNIQUE_BASE + term_id
            rows.append((label, uri))
    return rows

STATISTICAL_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\stato_full_taxonomy.txt"
STATO_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\subtree_C19044.txt"
stat_rows = load_statistical_labels(STATISTICAL_LABELS_FILE)
stat1_rows = load_statistical_labels(STATO_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in stat_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

exact_ix1 = defaultdict(list)
for lbl, uri in stat1_rows:
    exact_ix1[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in stat_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

labels1_only = [preprocess(lbl) for lbl, _ in stat1_rows]
vec1 = TfidfVectorizer(stop_words="english")
mat1 = vec1.fit_transform(labels1_only)

def top_cosine(term, k=5, thr=0.75):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = stat_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

def top_cosine1(term, k=5, thr=0.75):
    v   = vec1.transform([term])
    sc  = cosine_similarity(v, mat1).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = stat1_rows[i]
        out.append((lbl, uri, sc[i]))
    return out
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "statistical technique":
            text_span = entity.get("text_span", "").strip()
            cleaned_text = create_uri_fragment(text_span)
            cleaned_text_span = normalize_to_ascii(cleaned_text)
            term_raw = cleaned_text_span.lower()
            term = preprocess(term_raw)
            
            print(f"Query: {term}")
            
            if term_raw in created:
                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                continue

            ex = exact_ix.get(term, [])
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            cos = top_cosine(term)
            cos1 = top_cosine1(term)
            if cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, STATISTICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, STATISTICALTECHNIQUE_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAIN[term_raw])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAIN[f"title_{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAIN[f"abstract_{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "statistical technique":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAIN[cleaned_text_span])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_stattechnique_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))
# Out:
# Query: random-effects meta-analyses
#   • Meta-Analysis                            URI=http://purl.obolibrary.org/obo/NCIT_C17886 score=0.84
#
# Query: wald test
#   • Wald test                                URI=http://purl.obolibrary.org/obo/STATO_0000559
#   • Wald test                                URI=http://purl.obolibrary.org/obo/STATO_0000559 score=1.00
#
# Query: receiver operating characteristic curve analysis
# no matches
# Query: random forests
#   • random variable                          URI=http://purl.obolibrary.org/obo/STATO_0000221 score=0.78
#
# Query: rf
# no matches
# Query: boruta algorithm
#   • algorithm                                URI=http://purl.obolibrary.org/obo/IAO_0000064 score=1.00
#
# Query: rf
# no matches
# Query: chao1 index
# no matches
# Query: shannon
# no matches
# Query: inverse simpson
# no matches
# Query: bray curtis dissimilarities
# no matches
# Query: two sided mann whitney test
#   • Mann-Whitney U-test                      URI=http://purl.obolibrary.org/obo/STATO_0000076 score=0.85
#
# Query: cochrane risk of bias
#   • risk                                     URI=http://purl.obolibrary.org/obo/STATO_0000620 score=1.00
#
# Query: random forests  rf
#   • random variable                          URI=http://purl.obolibrary.org/obo/STATO_0000221 score=0.78
#
# Query: boruta algorithm
#   → Reusing existing URI: http://purl.obolibrary.org/obo/IAO_0000064
#
# Query: mr analysis
# no matches
# Query: reverse mr analysis
# no matches
# Query: linear discriminant analysis effect size
# no matches
# Query: lefse
# no matches
# Query: lefse analysis
# no matches
# Query: random forest classification
# no matches
# Query: false discovery rate  fdr
#   • false discovery rate correction method   URI=http://purl.obolibrary.org/obo/OBI_0200163 score=0.78
#
# Query: mendelian randomization  mr  analyses
#   • group randomization                      URI=http://purl.obolibrary.org/obo/OBI_0302900 score=0.77
#
# Query: two-sample mr
#   • one sample t-test                        URI=http://purl.obolibrary.org/obo/STATO_0000302 score=0.82
#
# Query: inverse variance weighted  ivw   mr-egger  and weighted median  wm  methods
# no matches
# Query: multivariable mr
# no matches
# Query: mvmr
# no matches
# Query: cochran s q test
#   • F-Test                                   URI=http://purl.obolibrary.org/obo/NCIT_C53234 score=1.00
#
# Query: mr egger intercept test
#   • intercept                                URI=http://purl.obolibrary.org/obo/STATO_0000657 score=0.86
#
# Query: mr steiger test
#   • Z-test                                   URI=http://purl.obolibrary.org/obo/STATO_0000052 score=1.00
#
# Query: sensitivity analyses
# no matches
# Query: reverse mr analysis
# no matches
# Query: independent sample t test
#   • One Sample t-Test                        URI=http://purl.obolibrary.org/obo/NCIT_C53240 score=1.00
#
# Query: mann-whitney u test
#   • Mann-Whitney U-test                      URI=http://purl.obolibrary.org/obo/STATO_0000076 score=1.00
#
# Query: pearson or spearman correlation test
#   • Pearson Correlation Test                 URI=http://purl.obolibrary.org/obo/NCIT_C53244 score=0.83
#
# Query: lefse analysis
# no matches
# Query: linear discriminant analysis
# no matches
# Query: lda
# no matches
# Query: statistical modeling with logistic regression
# no matches
# Query: correlation analysis
# no matches
# Query: pearson correlation analysis
#   • Pearson Correlation Test                 URI=http://purl.obolibrary.org/obo/NCIT_C53244 score=0.79
#
# Query: pearson s correlation analysis
#   • Pearson Correlation Test                 URI=http://purl.obolibrary.org/obo/NCIT_C53244 score=0.79
#
# Query: pearson s correlation analysis
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C53244
#
# Query: random forest models
#   • random forest procedure                  URI=http://purl.obolibrary.org/obo/STATO_0000549 score=0.82
#
# Query: multiple regression analysis
# no matches

# %% [markdown]
# <h1>INGEST BIOMEDICAL TECHNIQUE</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint

BIOMEDICALTECHNIQUE_BASE = "http://purl.obolibrary.org/obo/"
BIOMEDICALTECHNIQUE_CLASS = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/BiomedicalTechnique")
BIOMEDICALTECHNIQUE_CONCEPT_SCHEME = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/BiomedicalTechnique")

def load_biomedical_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = BIOMEDICALTECHNIQUE_BASE + term_id
            rows.append((label, uri))
    return rows

BIOMEDICAL_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncbitaxon_full_taxonomy.txt"
STATO_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\stato_full_taxonomy.txt"
biom_rows = load_biomedical_labels(BIOMEDICAL_LABELS_FILE)
biom1_rows = load_biomedical_labels(STATO_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in biom_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

exact_ix1 = defaultdict(list)
for lbl, uri in biom1_rows:
    exact_ix1[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in biom_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

labels1_only = [preprocess(lbl) for lbl, _ in biom1_rows]
vec1 = TfidfVectorizer(stop_words="english")
mat1 = vec1.fit_transform(labels1_only)

def top_cosine(term, k=5, thr=0.75):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = biom_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

def top_cosine1(term, k=5, thr=0.75):
    v   = vec1.transform([term])
    sc  = cosine_similarity(v, mat1).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = biom1_rows[i]
        out.append((lbl, uri, sc[i]))
    return out
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "biomedical technique":
            text_span = entity.get("text_span", "").strip()
            cleaned_text = create_uri_fragment(text_span)
            cleaned_text_span = normalize_to_ascii(cleaned_text)
            term_raw = cleaned_text_span.lower()
            term = preprocess(term_raw)
            
            print(f"Query: {term}")
            
            if term_raw in created:
                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                continue

            ex = exact_ix.get(term, [])
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            cos = top_cosine(term)
            cos1 = top_cosine1(term)
            if cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, BIOMEDICALTECHNIQUE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, BIOMEDICALTECHNIQUE_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            else:
                mention_uri = URIRef(GUTBRAIN[term_raw])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]
    
    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAIN[f"title_{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAIN[f"abstract_{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "biomedical technique":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAIN[cleaned_text_span])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_biomtechnique_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))
# Out:
# Query: dqi-i
# no matches
# Query: 16s rdna surveys
#   • fungal sp. 16S-7                         URI=http://purl.obolibrary.org/obo/NCBITaxon_1080634 score=0.84
#
# Query: 16s rdna surveys
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_1080634
#
# Query: metatranscriptomics analyses
# no matches
# Query: metabolomics
# no matches
# Query: community-based metabolic modeling
# no matches
# Query: 16s rrna amplicon sequencing
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# Query: childhood behaviour checklist
# no matches
# Query: lc-ms
# no matches
# Query: gc
#   • Bacillus sp. GC-4                        URI=http://purl.obolibrary.org/obo/NCBITaxon_996987 score=0.88
#
# Query: 16s rrna gene sequencing
# no matches
# Query: 16s rrna sequencing
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# Query: picrust analysis
# no matches
# Query: dual hit toxin model
# no matches
# Query: forced swimming test
#   • test organism                            URI=http://purl.obolibrary.org/obo/NCBITaxon_457483 score=0.81
#
# Query: open field test
#   • Z-test                                   URI=http://purl.obolibrary.org/obo/STATO_0000052 score=1.00
#
# Query: sucrose preference test
#   • test organism                            URI=http://purl.obolibrary.org/obo/NCBITaxon_457483 score=0.81
#
# Query: body weight
#   • contrast weight                          URI=http://purl.obolibrary.org/obo/STATO_0000322 score=0.75
#
# Query: enzyme linked immunosorbent assay
#   • enzyme                                   URI=http://purl.obolibrary.org/obo/OBI_0000427 score=0.80
#
# Query: immunofluorescence
# no matches
# Query: 16 s rna sequencing
# no matches
# Query: western blotting
#   • Western X phytoplasma                    URI=http://purl.obolibrary.org/obo/NCBITaxon_37704 score=0.80
#
# Query: multiomics study
#   • study design                             URI=http://purl.obolibrary.org/obo/OBI_0500000 score=0.78
#
# Query: multiomics study
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OBI_0500000
#
# Query: fecal metagenome-wide sequencing
# no matches
# Query: serum metabolomics profiling
# no matches
# Query: metagenomic analysis
# no matches
# Query: 16s rrna sequencing
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OBI_0600047
#
# Query: qpcr
# no matches
# Query: hippocampal proteomic analysis
# no matches
# Query: repeated social defeat stress
# no matches
# Query: repeated social defeat stress
# no matches
# Query: rsds
# no matches
# Query: metagenomics analysis of the microbiome
# no matches
# Query: gut permeability assay
#   • assay                                    URI=http://purl.obolibrary.org/obo/OBI_0000070 score=1.00
#
# Query: ussing chamber
# no matches
# Query: immunoblotting
# no matches
# Query: immunohistochemical analyses
# no matches
# Query: mechanistic analysis
# no matches
# Query: shotgun metagenomics
#   • Microbacterium phage Shotgun             URI=http://purl.obolibrary.org/obo/NCBITaxon_2863847 score=0.86
#
# Query: shotgun metagenomics sequencing
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# Query: sms
#   • Streptomyces sp. SMS_7                   URI=http://purl.obolibrary.org/obo/NCBITaxon_1821634 score=0.91
#
# Query: tryptophan concentration measurements
#   • concentration                            URI=http://purl.obolibrary.org/obo/STATO_0000704 score=1.00
#
# Query: fpg
# no matches
# Query: fpi
# no matches
# Query: homa-ir
#   • Homa                                     URI=http://purl.obolibrary.org/obo/NCBITaxon_2509998 score=0.79
#
# Query: ancom-bc2
#   • Bacillus sp. BC2                         URI=http://purl.obolibrary.org/obo/2014      score=0.90
#
# Query: chronic unpredictable mild stress  cums  model
# no matches
# Query: genomic sequencing
# no matches
# Query: whole genome shotgun sequencing
# no matches
# Query: 16s rrna gene-sequenced gut microbiota data
# no matches
# Query: 16s rrna sequencing
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OBI_0600047
#
# Query: multiplex immunoassay
#   • Bambusa multiplex var. multiplex         URI=http://purl.obolibrary.org/obo/NCBITaxon_1819610 score=0.88
#
# Query: updrs part iii motor scores
# no matches
# Query: pentobarbital-induced sleep test
#   • Z-test                                   URI=http://purl.obolibrary.org/obo/STATO_0000052 score=1.00
#
# Query: comparative genomics analysis
# no matches
# Query: phenol-sulfate assay
#   • assay                                    URI=http://purl.obolibrary.org/obo/OBI_0000070 score=1.00
#
# Query: pentobarbital-induced sleep test
#   → Reusing existing URI: http://purl.obolibrary.org/obo/STATO_0000052
#
# Query: metagenomic sequencing
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# Query: transcriptome sequencing
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# Query: rna-seq
#   • RNA-seq assay                            URI=http://purl.obolibrary.org/obo/OBI_0001271 score=0.88
#
# Query: rna-seq profiling
# no matches
# Query: double-blind  randomized  placebo-controlled trials
# no matches
# Query: multi-omics analyses
# no matches
# Query: metabolomics
# no matches
# Query: 16s rrna
#   • fungal sp. 16S-7                         URI=http://purl.obolibrary.org/obo/NCBITaxon_1080634 score=0.84
#
# Query: untargeted metabolomics
# no matches
# Query: shotgun metagenomics
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2863847
#
# Query: shotgun metagenomic sequencing
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# Query: mitbamp analyses
# no matches
# Query: aav-shrna
# no matches
# Query: 16s ribosomal rna analysis
# no matches
# Query: untargeted metabolomic analysis
# no matches
# Query: burst testing
# no matches
# Query: 16s rrna sequencing technique
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# Query: shotgun metagenomic sequencing
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OBI_0600047
#
# Query: analysis of the fecal samples
# no matches
# Query: wet laboratory methods
# no matches
# Query: 13c-d-xylose breath tests
#   • Bacillus sp. 13C                         URI=http://purl.obolibrary.org/obo/NCBITaxon_1226296 score=0.91
#
# Query: 13c-d-xylose breath testing
#   • Bacillus sp. 13C                         URI=http://purl.obolibrary.org/obo/NCBITaxon_1226296 score=0.91
#
# Query: single-cell rna-seq analysis
# no matches
# Query: microbiota-targeted therapies
# no matches
# Query: 16s rrna gene sequencing
# no matches
# Query: shotgun metagenomic sequencing
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OBI_0600047
#
# Query: strain-level meta-analysis
#   • meta analysis                            URI=http://purl.obolibrary.org/obo/STATO_0000155 score=0.78
#
# Query: 16s rrna gene sequencing
# no matches
# Query: phylogenetic investigation of communities by reconstruction of unobserved states  picrust  analysis
#   • investigation                            URI=http://purl.obolibrary.org/obo/OBI_0000066 score=0.83
#
# Query: 16s rrna gene sequencing
# no matches
# Query: nuclear mr spectroscopy
# no matches
# Query: illumina sequencing
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# Query: kegg analysis
# no matches
# Query: kegg analysis
# no matches
# Query: omics techniques
# no matches
# Query: lc-ms ms
#   • bacterium MS-B-1                         URI=http://purl.obolibrary.org/obo/NCBITaxon_579390 score=0.77
#
# Query: gastrointestinal and microbiome profiling
# no matches
# Query: v4 16s rrna gene sequencing
# no matches
# Query: microbiome profiling
# no matches
# Query: voluntary wheel running
#   • voluntary sampling                       URI=http://purl.obolibrary.org/obo/STATO_0000513 score=0.83
#
# Query: splash
# no matches
# Query: elevated plus maze
# no matches
# Query: tail suspension tests
#   • Red tail virus                           URI=http://purl.obolibrary.org/obo/NCBITaxon_884614 score=0.80
#
# Query: multiple integrated omics
# no matches
# Query: 16s ribosomal rna  16s rrna  gene sequence-based approach
# no matches
# Query: untargeted liquid chromatography-mass spectrometry-based metabolic profiling approach
# no matches
# Query: 16s rrna gene amplicon sequencing
# no matches
# Query: metabolomics
# no matches
# Query: 16s rrna gene sequencing
# no matches
# Query: head-up tilt test
#   • Z-test                                   URI=http://purl.obolibrary.org/obo/STATO_0000052 score=1.00
#
# Query: hutt
# no matches
# Query: 16s rrna sequencing
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OBI_0600047
#
# Query: quantitative fluorescence in situ hybridization
# no matches
# Query: high-sensitivity c-reactive protein
# no matches
# Query: oft
# no matches
# Query: spt
#   • Trigonopterus sp. spt                    URI=http://purl.obolibrary.org/obo/NCBITaxon_657572 score=0.83
#
# Query: tst
# no matches
# Query: igtt
# no matches
# Query: liver lipid kit
# no matches
# Query: legend plex kits
#   • Staphylococcus sp. KITS-2                URI=http://purl.obolibrary.org/obo/NCBITaxon_908005 score=0.90
#
# Query: elisa
#   • Eumorpha elisa                           URI=http://purl.obolibrary.org/obo/NCBITaxon_1086307 score=0.76
#
# Query: rt-pcr
#   • RT-PCR standard curve                    URI=http://purl.obolibrary.org/obo/STATO_0000219 score=0.78
#
# Query: western blot
#   • Western X phytoplasma                    URI=http://purl.obolibrary.org/obo/NCBITaxon_37704 score=0.80
#
# Query: 16s rrna gene sequencing
# no matches
# Query: multi-omics approach
# no matches
# Query: multi-omics approach
# no matches
# Query: functional enrichment analysis
# no matches
# Query: blast shotgun metagenomic sequencing
#   • sequencing assay                         URI=http://purl.obolibrary.org/obo/OBI_0600047 score=0.79
#
# Query: 16s rrna sequencing
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OBI_0600047
#
# Query: shotgun metagenomics
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_2863847
#
# Query: 16s rrna gene and shotgun metagenomic analysis
# no matches
# Query: duodenal aspirates
# no matches
# Query: 16s rrna sequencing
#   → Reusing existing URI: http://purl.obolibrary.org/obo/OBI_0600047
#
# Query: bioinformatics analysis
# no matches
# Query: stool biobank
# no matches
# Query: single prolonged stress  sps  model
# no matches
# Query: sps
#   • Pseudomonas sp. SPS-1                    URI=http://purl.obolibrary.org/obo/NCBITaxon_435493 score=0.90
#
# Query: behavioral tests
# no matches
# Query: anxiety index
#   • Xiphinema index                          URI=http://purl.obolibrary.org/obo/NCBITaxon_46003 score=0.80
#
# Query: sps
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_435493
#
# Query: sps
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_435493
#
# Query: sps
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_435493
#
# Query: sps
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_435493
#
# Query: sps
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_435493
#
# Query: sps
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCBITaxon_435493
#
# Query: sps model
#   • Pseudomonas sp. SPS-1                    URI=http://purl.obolibrary.org/obo/NCBITaxon_435493 score=0.90
#
# Query: multi-omics analysis
# no matches
# Query: taxon-function analysis
#   • function                                 URI=http://purl.obolibrary.org/obo/BFO_0000034 score=0.75
#
# Query: randomized  double-blinded  two-arm feasibility study
# no matches
# Query: quantitative sybr green real-time pcr
#   • real time quantitative pcr plot          URI=http://purl.obolibrary.org/obo/STATO_0000168 score=0.94
#
# Query: 16s rna method
# no matches
# Query: elisa kit
# no matches

# %% [markdown]
# <h1>INGEST ANATOMICAL LOCATION</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint

ANATOMICALLOCATION_BASE = "http://purl.obolibrary.org/obo/"
ANATOMICALLOCATION_CLASS = URIRef("https://w3id.org/brainteaser/ontology/schema/AnatomicalSite")
ANATOMICALLOCATION_CONCEPT_SCHEME = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/AnatomicSite")

def load_anatomical_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = ANATOMICALLOCATION_BASE + term_id
            rows.append((label, uri))
    return rows

ANATOMICALLOCATION_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncit_full_taxonomy.txt"
anat_rows = load_anatomical_labels(ANATOMICALLOCATION_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in biom_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in anat_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

def top_cosine(term, k=5, thr=0.75):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = anat_rows[i]
        out.append((lbl, uri, sc[i]))
    return out
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "anatomical location":
            text_span = entity.get("text_span", "").strip()
            cleaned_text = create_uri_fragment(text_span)
            cleaned_text_span = normalize_to_ascii(cleaned_text)
            term_raw = cleaned_text_span.lower()
            term = preprocess(term_raw)
            
            print(f"Query: {term}")
            
            if term_raw in created:
                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                continue

            ex = exact_ix.get(term, [])
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, ANATOMICALLOCATION_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, ANATOMICALLOCATION_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            cos = top_cosine(term)
            if cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, ANATOMICALLOCATION_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, ANATOMICALLOCATION_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAIN[term_raw])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAIN[f"title_{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAIN[f"abstract_{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "anatomical location":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAIN[cleaned_text_span])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_anatomicsite_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))
# Out:
# Query: gastrointestinal  gi  site
# no matches
# Query: gi sites
# no matches
# Query: intestinal site
# no matches
# Query: hippocampus
#   • Hippocampus                              URI=http://purl.obolibrary.org/obo/NCBITaxon_72046
#   • Hippocampus                              URI=http://purl.obolibrary.org/obo/NCIT_C12444 score=1.00
#
# Query: oral cavity
#   • Oral Cavity                              URI=http://purl.obolibrary.org/obo/NCIT_C12421 score=1.00
#
# Query: nasal passages
#   • Nose, Nasal Passages                     URI=http://purl.obolibrary.org/obo/NCIT_C13320 score=0.85
#
# Query: lungs
# no matches
# Query: gut
# no matches
# Query: skin
#   • Skin                                     URI=http://purl.obolibrary.org/obo/NCIT_C12470 score=1.00
#
# Query: bladder
#   • Bladder                                  URI=http://purl.obolibrary.org/obo/NCIT_C12414 score=1.00
#
# Query: vagina
#   • Vagina                                   URI=http://purl.obolibrary.org/obo/NCIT_C12407 score=1.00
#
# Query: gastrointestinal tract
#   • Gastrointestinal Tract                   URI=http://purl.obolibrary.org/obo/NCIT_C34082 score=1.00
#
# Query: brains
# no matches
# Query: pilosebaceous unit
# no matches
# Query: skin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12470
#
# Query: brain
#   • Brain                                    URI=http://purl.obolibrary.org/obo/NCIT_C12439 score=1.00
#
# Query: heart
#   • Heart                                    URI=http://purl.obolibrary.org/obo/NCIT_C12727 score=1.00
#
# Query: arteries
#   • Atherosclerosis of Other Arteries        URI=http://purl.obolibrary.org/obo/NCIT_C196712 score=0.75
#
# Query: ovaries
#   • Uterus/Ovaries                           URI=http://purl.obolibrary.org/obo/NCIT_C77672 score=0.82
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: gut
# no matches
# Query: gut
# no matches
# Query: colon
#   • Colon                                    URI=http://purl.obolibrary.org/obo/NCBITaxon_1542223
#   • Colon                                    URI=http://purl.obolibrary.org/obo/Platycolon
#   • Colon                                    URI=http://purl.obolibrary.org/obo/NCIT_C12382 score=1.00
#
# Query: colonic tracts
# no matches
# Query: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
# Query: ascending colon vessels
#   • Ascending Colon                          URI=http://purl.obolibrary.org/obo/NCIT_C12265 score=0.77
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: intestinal barrier
#   → Reusing existing URI: http://purl.obolibrary.org/obo/DOID_10155
#
# Query: human body
# no matches
# Query: gastrointestinal tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
# Query: git
# no matches
# Query: immune system
#   • Immune                                   URI=http://purl.obolibrary.org/obo/NCIT_C17997 score=1.00
#
# Query: central nervous system
#   • Central Nervous System Part              URI=http://purl.obolibrary.org/obo/NCIT_C33966 score=1.00
#
# Query: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
# Query: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
# Query: maternal vagina
# no matches
# Query: rectum
#   • Rectum                                   URI=http://purl.obolibrary.org/obo/NCIT_C12390 score=1.00
#
# Query: skin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12470
#
# Query: infant stool and nose
# no matches
# Query: gut
# no matches
# Query: hippocampal synaptic ultrastructure
# no matches
# Query: synaptic clefts
# no matches
# Query: postsynaptic densities
# no matches
# Query: mouse colon
#   • Mouse Colon                              URI=http://purl.obolibrary.org/obo/NCIT_C22528 score=1.00
#
# Query: systemic circulation
# no matches
# Query: synapses
# no matches
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
# Query: skin
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12470
#
# Query: nasopharynx
#   • Nasopharynx                              URI=http://purl.obolibrary.org/obo/NCIT_C12423 score=1.00
#
# Query: oral cavity
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12421
#
# Query: gastrointestinal tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
# Query: urogenital tract
# no matches
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: gut
# no matches
# Query: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
# Query: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
# Query: duodenum
#   • Duodenum                                 URI=http://purl.obolibrary.org/obo/NCIT_C12263 score=1.00
#
# Query: gut
# no matches
# Query: gut
# no matches
# Query: serum
#   • Serum                                    URI=http://purl.obolibrary.org/obo/NCIT_C13325 score=1.00
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: medial prefrontal cortex
#   • Prefrontal Cortex                        URI=http://purl.obolibrary.org/obo/NCIT_C154779 score=0.85
#
# Query: mpfc
# no matches
# Query: mpfc
# no matches
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: gut
# no matches
# Query: cognitive brain areas
# no matches
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: subdiaphragmatic vagus nerve
#   • Vagus Nerve                              URI=http://purl.obolibrary.org/obo/NCIT_C12812 score=0.76
#
# Query: cuprizone-treated mouse brain
# no matches
# Query: vagus nerve
#   • Vagus Nerve                              URI=http://purl.obolibrary.org/obo/NCIT_C12812 score=1.00
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: subdiaphragmatic vagus nerve
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12812
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: peripheral tissues
# no matches
# Query: gastrointestinal  gi  tract
# no matches
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: substantia nigra
#   • Substantia Nigra                         URI=http://purl.obolibrary.org/obo/NCIT_C12453 score=1.00
#
# Query: substantia nigra
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12453
#
# Query: striatum
#   • Striatum                                 URI=http://purl.obolibrary.org/obo/NCIT_C12450 score=1.00
#
# Query: gut
# no matches
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: gastrointestinal tract
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C34082
#
# Query: gut
# no matches
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
# Query: rodent gut
# no matches
# Query: gut
# no matches
# Query: jejunum
#   • Jejunum                                  URI=http://purl.obolibrary.org/obo/NCIT_C12388 score=1.00
#
# Query: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
# Query: cecum
#   • Cecum                                    URI=http://purl.obolibrary.org/obo/NCIT_C12381 score=1.00
#
# Query: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
# Query: liver
#   • Liver                                    URI=http://purl.obolibrary.org/obo/NCIT_C12392 score=1.00
#
# Query: liver
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12392
#
# Query: liver
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12392
#
# Query: gut
# no matches
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: gut
# no matches
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439
#
# Query: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
# Query: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
# Query: gut
# no matches
# Query: pulmonary
#   • Pulmonary                                URI=http://purl.obolibrary.org/obo/NCIT_C13304 score=1.00
#
# Query: gi tract
# no matches
# Query: gut
# no matches
# Query: small intestine
#   • Small Intestine                          URI=http://purl.obolibrary.org/obo/NCIT_C12386 score=1.00
#
# Query: gut
# no matches
# Query: enteric nervous system
# no matches
# Query: gut
# no matches
# Query: gut barrier
# no matches
# Query: gut
# no matches
# Query: vagus nerve
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12812
#
# Query: stomach
#   • Stomach Part                             URI=http://purl.obolibrary.org/obo/NCIT_C13025 score=1.00
#
# Query: small intestine
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12386
#
# Query: colon
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12382
#
# Query: cecum
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12381
#
# Query: selected brain tissues
# no matches
# Query: gut
# no matches
# Query: blood
#   • Blood                                    URI=http://purl.obolibrary.org/obo/NCIT_C12434 score=1.00
#
# Query: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
# Query: brainstem
#   • Limited to brainstem                     URI=http://purl.obolibrary.org/obo/NCIT_C182288 score=0.80
#
# Query: gut
# no matches
# Query: blood
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12434
#
# Query: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
# Query: brainstem
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C182288
#
# Query: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
# Query: brainstem
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C182288
#
# Query: gut
# no matches
# Query: hippocampus
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12444
#
# Query: brainstem
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C182288
#
# Query: intestine
#   • Intestine                                URI=http://purl.obolibrary.org/obo/NCIT_C12736 score=1.00
#
# Query: lungs
# no matches
# Query: brain
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C12439

# %% [markdown]
# <h1>INGEST GENE</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint

GENE_BASE = "http://purl.obolibrary.org/obo/"
GENE_CLASS = URIRef("https://w3id.org/brainteaser/ontology/schema/Gene")
GENE_CONCEPT_SCHEME = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Gene")

def load_gene_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = GENE_BASE + term_id
            rows.append((label, uri))
    return rows

GENE_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncit_full_taxonomy.txt"
gene_rows = load_gene_labels(GENE_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in gene_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in gene_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

def top_cosine(term, k=5, thr=0.75):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = gene_rows[i]
        out.append((lbl, uri, sc[i]))
    return out
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "gene":
            text_span = entity.get("text_span", "").strip()
            cleaned_text = create_uri_fragment(text_span)
            cleaned_text_span = normalize_to_ascii(cleaned_text)
            term_raw = cleaned_text_span.lower()
            term = preprocess(term_raw)
            
            print(f"Query: {term}")
            
            if term_raw in created:
                entity_uri = created[term_raw]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                continue

            ex = exact_ix.get(term, [])
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, GENE_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, GENE_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            cos = top_cosine(term)
            if cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, GENE_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, GENE_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAIN[term_raw])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAIN[f"title_{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAIN[f"abstract_{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip().lower()
        else:
            continue

        if label != "gene":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAIN[cleaned_text_span])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_gene_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))
# Out:
# Query: skin lipid metabolism-related genes
# no matches
# Query: ppar-
#   • PPAR Pathway                             URI=http://purl.obolibrary.org/obo/NCIT_C39199 score=0.87
#
# Query: srebp-1c
# no matches
# Query: acc
# no matches
# Query: fasn
#   • FASN Gene                                URI=http://purl.obolibrary.org/obo/NCIT_C26564 score=0.95
#
# Query: ppar-
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C39199
#
# Query: acox1
#   • ACOX1 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C191889 score=0.95
#
# Query: hsl
# no matches
# Query: atgl
# no matches
# Query: skin lipid metabolism-related genes
# no matches
# Query: ppar-
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C39199
#
# Query: srebp-1c
# no matches
# Query: fasn
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26564
#
# Query: atgl
# no matches
# Query: trem2
#   • TREM2 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C125468 score=0.94
#
# Query: c3
#   • C3 Gene                                  URI=http://purl.obolibrary.org/obo/NCIT_C21521 score=0.92
#
# Query: c3ar1
#   • C3AR1 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C182144 score=0.95
#
# Query: tnfa
# no matches
# Query: nf-kb
#   • NF-kB                                    URI=http://purl.obolibrary.org/obo/NCIT_C17380
#   • NF-kB                                    URI=http://purl.obolibrary.org/obo/NCIT_C17380 score=1.00
#
# Query: tgfb1 2
#   • TGFB1 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C24856 score=0.94
#
# Query: sirt1 6
#   • SIRT1 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C80113 score=0.95
#
# Query: hmgb1
#   • HMGB1 Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C20578 score=0.94
#
# Query: sting
#   • STING Agonist                            URI=http://purl.obolibrary.org/obo/NCIT_C176586 score=0.77
#
# Query: pwy-7328
# no matches
# Query: trehalose
#   • Trehalose                                URI=http://purl.obolibrary.org/obo/NCIT_C87705
#   • Trehalose                                URI=http://purl.obolibrary.org/obo/NCIT_C87705 score=1.00
#
# Query: maltose hydrolase
#   • Maltose                                  URI=http://purl.obolibrary.org/obo/NCIT_C68478 score=0.78
#
# Query: cog1554
# no matches
# Query: fucose permease
# no matches
# Query: cog0738
# no matches
# Query: urease accessory proteins uree
# no matches
# Query: cog2371
# no matches
# Query: camkiid
# no matches
# Query: k00658
# no matches
# Query: k00837
# no matches
# Query: k01696
# no matches
# Query: k00382
# no matches
# Query: k00626
# no matches
# Query: k01667
# no matches
# Query: k03781
# no matches
# Query: hba1
#   • HBA1 Gene                                URI=http://purl.obolibrary.org/obo/NCIT_C75429 score=0.95
#
# Query: 16s ribosomal rna gene
#   • 16S Mitochondrial Ribosomal RNA          URI=http://purl.obolibrary.org/obo/NCIT_C131261 score=0.88
#
# Query: differential expressed genes
# no matches
# Query: degs
# no matches
# Query: gut microbe-related degs
# no matches
# Query: creb3l3
#   • CREB3L3 Gene                             URI=http://purl.obolibrary.org/obo/NCIT_C95485 score=0.95
#
# Query: ccdc173
# no matches
# Query: bacterial 16s rrna gene
# no matches
# Query: htr1a
#   • HTR1A Gene                               URI=http://purl.obolibrary.org/obo/NCIT_C105868 score=0.95
#
# Query: htr1a
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C105868
#
# Query: htr1a
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C105868
#
# Query: apolipoprotein b
#   • Apolipoprotein M                         URI=http://purl.obolibrary.org/obo/NCIT_C178705 score=1.00
#
# Query: 16s rrna gene
# no matches
# Query: microglia activation-related genes
# no matches
# Query: fatty acid transport genes
# no matches
# Query: abhd5
# no matches
# Query: adipogenesis
#   • Adipogenesis                             URI=http://purl.obolibrary.org/obo/NCIT_C20906
#   • Adipogenesis                             URI=http://purl.obolibrary.org/obo/NCIT_C20906 score=1.00
#
# Query: me1
#   • ME1 Gene                                 URI=http://purl.obolibrary.org/obo/NCIT_C127139 score=0.94
#
# Query: fasn
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C26564
#
# Query: pnpla3
# no matches
# Query: elovl6
# no matches
# Query: peroxisome proliferator-activated receptor gamma  pparg  genes
#   • Peroxisome Proliferator-Activated Receptor Gamma URI=http://purl.obolibrary.org/obo/NCIT_C34077 score=0.78
#
# Query: 5-ht receptor htr2a
# no matches
# Query: 16s rrna gene
# no matches
# Query: tight junction protein claudin-5
#   • Tight Junction                           URI=http://purl.obolibrary.org/obo/NCIT_C13333 score=0.77

# %% [markdown]
# <h1>INGEST DDF</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint

DDF_BASE = "http://purl.obolibrary.org/obo/"
DDF_CLASS = URIRef("https://w3id.org/brainteaser/ontology/schema/DiseaseDisorderOrFinding")
DDF_CONCEPT_SCHEME = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/DiseaseDisorderOrFindingConceptScheme")

def load_ddf_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = DDF_BASE + term_id
            rows.append((label, uri))
    return rows

created = {}
OMIT_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\omit_full_taxonomy.txt"
DDF_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncit_full_taxonomy.txt"
ddf_rows = load_ddf_labels(DDF_LABELS_FILE)
omit_rows = load_ddf_labels(OMIT_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in ddf_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

exact_ix1 = defaultdict(list)
for lbl, uri in omit_rows:
    exact_ix1[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in ddf_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

labels_only1 = [preprocess(lbl) for lbl, _ in omit_rows]
vec1 = TfidfVectorizer(stop_words="english")
mat1 = vec1.fit_transform(labels_only1)

manual_created = {
    "deficiency": URIRef("https://uts.nlm.nih.gov/uts/umls/vocabulary/SNOMEDCT_US/246199000"),
    "neuropsychiatric_disorders" : URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/resource/Chemical"),
    
}

created = dict(manual_created)

for key, uri in manual_created.items():
    g.add((uri, RDF.type,      DDF_CLASS))
    g.add((uri, RDF.type,      SKOS.Concept))
    g.add((uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
    label = key.replace("_", " ").capitalize()
    g.add((uri, RDFS.label, Literal(label, datatype=XSD.string)))


regex_map = [
    (r"\bdepressive_symptoms\b", "major_depressive_disorder"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))migraine_headache\b","migraine"),
    (r"t1d","Type_1_Diabetes_Mellitus"),
    (r"long-term_acetate_deficiency","deficiency"),
    (r"cognitive_decline","mental_deterioration"),
    (r"systemic_inflammation","inflammation"),
    
    
]

def top_cosine(term, k=5, thr=0.85):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = ddf_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

def top_cosine_omit(term, k=5, thr=0.85):
    v  = vec1.transform([term])
    sc = cosine_similarity(v, mat1).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = omit_rows[i]
        out.append((lbl, uri, sc[i]))
    return out
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "DDF":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            #lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            #print(lookup_key)
            
            if lookup_key in created:
                entity_uri = created[lookup_key]
                for lookup_key in manual_created:
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type,        MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,      Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri

            ex = exact_ix.get(term, [])
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, DDF_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            cos = top_cosine(term)
            cos1 = top_cosine_omit(term)
            if cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DDF_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DDF_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DDF_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAIN[term_raw])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAIN[f"title_{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAIN[f"abstract_{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip()
        else:
            continue

        if label != "DDF":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAIN[cleaned_text_span])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_ddf_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

output_file = os.path.join(save_path, "gutbrain_entities.ttl")
ttl_output = g.serialize(format="turtle")
with open(output_file, "w", encoding="utf-8") as f_out:
    f_out.write(ttl_output)

print(f"The RDF graph has been saved in {output_file}")
# Out:
# Query: major depressive disorder
#   • Depressive Disorder, Major               URI=http://purl.obolibrary.org/obo/OMIT_0005141 score=1.00
# Query: mental deterioration
# no matches
# Query: mood disorders
#   • Mood Disorders                           URI=http://purl.obolibrary.org/obo/OMIT_0019924 score=1.00
# Query: major depressive disorder
#   • Depressive Disorder, Major               URI=http://purl.obolibrary.org/obo/OMIT_0005141 score=1.00
# Query: antimicrobial resistance
#   • Antimicrobial Resistance Result          URI=http://purl.obolibrary.org/obo/NCIT_C85562 score=0.91
# Query: inflammation
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137 score=1.00
# Query: psychosis
#   • Psychosis                                URI=http://purl.obolibrary.org/obo/NCIT_C78576
#   • Psychosis                                URI=http://purl.obolibrary.org/obo/NCIT_C78576 score=1.00
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: psychosis
#   • Psychosis                                URI=http://purl.obolibrary.org/obo/NCIT_C78576
#   • Psychosis                                URI=http://purl.obolibrary.org/obo/NCIT_C78576 score=1.00
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: psychosis
#   • Psychosis                                URI=http://purl.obolibrary.org/obo/NCIT_C78576
#   • Psychosis                                URI=http://purl.obolibrary.org/obo/NCIT_C78576 score=1.00
# Query: psychosis
#   • Psychosis                                URI=http://purl.obolibrary.org/obo/NCIT_C78576
#   • Psychosis                                URI=http://purl.obolibrary.org/obo/NCIT_C78576 score=1.00
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: psychosis
#   • Psychosis                                URI=http://purl.obolibrary.org/obo/NCIT_C78576
#   • Psychosis                                URI=http://purl.obolibrary.org/obo/NCIT_C78576 score=1.00
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: psychosis
#   • Psychosis                                URI=http://purl.obolibrary.org/obo/NCIT_C78576
#   • Psychosis                                URI=http://purl.obolibrary.org/obo/NCIT_C78576 score=1.00
# Query: psychosis
#   • Psychosis                                URI=http://purl.obolibrary.org/obo/NCIT_C78576
#   • Psychosis                                URI=http://purl.obolibrary.org/obo/NCIT_C78576 score=1.00
# Query: migraine
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715 score=1.00
# Query: migraine
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715 score=1.00
# Query: gastrointestinal diseases
#   • Gastrointestinal Diseases                URI=http://purl.obolibrary.org/obo/OMIT_0006966 score=1.00
# Query: headaches
#   • Get Headaches                            URI=http://purl.obolibrary.org/obo/NCIT_C111065 score=1.00
# Query: gastrointestinal disorders
#   • Gastrointestinal Disorders, CTCAE        URI=http://purl.obolibrary.org/obo/NCIT_C146630 score=0.93
# Query: migraine
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715 score=1.00
# Query: gastrointestinal disorders
#   • Gastrointestinal Disorders, CTCAE        URI=http://purl.obolibrary.org/obo/NCIT_C146630 score=0.93
# Query: migraine
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715 score=1.00
# Query: gastrointestinal diseases
#   • Gastrointestinal Diseases                URI=http://purl.obolibrary.org/obo/OMIT_0006966 score=1.00
# Query: inflammation
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137 score=1.00
# Query: migraine
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715 score=1.00
# Query: migraine
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715 score=1.00
# Query: migraine
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715 score=1.00
# Query: migraine
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715 score=1.00
# Query: migraine
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715 score=1.00
# Query: migraine
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715 score=1.00
# Query: migraine
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715 score=1.00
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: anxiety
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696 score=1.00
# Query: inflammation
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137 score=1.00
# Query: migraine
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715 score=1.00
# Query: migraine
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715
#   • Migraine                                 URI=http://purl.obolibrary.org/obo/NCIT_C89715 score=1.00
# Query: cognitive impairment
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921 score=1.00
# Query: type 1 diabetes mellitus
#   • Type 1 Diabetes Mellitus                 URI=http://purl.obolibrary.org/obo/NCIT_C2986
#   • Type 1 Diabetes Mellitus                 URI=http://purl.obolibrary.org/obo/NCIT_C2986 score=1.00
# Query: t1d
# no matches
# Query: t1d
# no matches
# Query: cognitive impairment
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921 score=1.00
# Query: long-term acetate deficiency
# no matches
# Query: learning and memory impairments
# no matches
# Query: long-term acetate deficiency
# no matches
# Query: cognitive decline
# no matches
# Query: neuropsychiatric disorders
# no matches
# Query: neuropsychiatric disorders
# no matches
# Query: psychiatric and neurodegenerative disorders
# no matches
# Query: neuropsychiatric disorders
# no matches
# Query: periodontitis
#   • Periodontitis                            URI=http://purl.obolibrary.org/obo/NCIT_C34918
#   • Periodontitis                            URI=http://purl.obolibrary.org/obo/NCIT_C34918 score=1.00
# Query: neuropsychiatric disorders
# no matches
# Query: alzheimer s disease
#   • Alzheimer's Disease                      URI=http://purl.obolibrary.org/obo/NCIT_C2866 score=1.00
# Query: neuropsychiatric disorders
# no matches
# Query: autoimmune diseases
#   • Autoimmune Diseases                      URI=http://purl.obolibrary.org/obo/OMIT_0002707 score=1.00
# Query: autoimmune  ai  diseases
#   • Autoimmune Diseases                      URI=http://purl.obolibrary.org/obo/OMIT_0002707 score=1.00
# Query: gut dysbiosis
#   • Dysbiosis                                URI=http://purl.obolibrary.org/obo/OMIT_0028544 score=1.00
# Query: gut dysbiosis
#   • Dysbiosis                                URI=http://purl.obolibrary.org/obo/OMIT_0028544 score=1.00
# Query: ai
#   • AI Regimen                               URI=http://purl.obolibrary.org/obo/NCIT_C63686 score=0.90
# Query: systemic inflammation
# no matches
# Query: arthropathy
#   • Arthropathy                              URI=http://purl.obolibrary.org/obo/NCIT_C35760
#   • Arthropathy                              URI=http://purl.obolibrary.org/obo/NCIT_C35760 score=1.00
# Query: gut dysbiosis
#   • Dysbiosis                                URI=http://purl.obolibrary.org/obo/OMIT_0028544 score=1.00
# Query: chronic inflammation
#   • Chronic Inflammation                     URI=http://purl.obolibrary.org/obo/NCIT_C174450
#   • Chronic Inflammation                     URI=http://purl.obolibrary.org/obo/NCIT_C174450 score=1.00
# Query: ai
#   • AI Regimen                               URI=http://purl.obolibrary.org/obo/NCIT_C63686 score=0.90
# Query: psoriatic arthritis
#   • Psoriatic Arthritis                      URI=http://purl.obolibrary.org/obo/NCIT_C61277
#   • Psoriatic Arthritis                      URI=http://purl.obolibrary.org/obo/NCIT_C61277 score=1.00
# Query: systemic lupus erythematosus
#   • Systemic Lupus Erythematosus             URI=http://purl.obolibrary.org/obo/NCIT_C3201
#   • Systemic Lupus Erythematosus             URI=http://purl.obolibrary.org/obo/NCIT_C3201 score=1.00
# Query: irritable bowel disease
# no matches
# Query: rheumatoid arthritis
#   • Rheumatoid Arthritis                     URI=http://purl.obolibrary.org/obo/NCIT_C2884
#   • Rheumatoid Arthritis                     URI=http://purl.obolibrary.org/obo/NCIT_C2884 score=1.00
# Query: ai
#   • AI Regimen                               URI=http://purl.obolibrary.org/obo/NCIT_C63686 score=0.90
# Query: reduced systemic inflammation
# no matches
# Query: inflammation
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137 score=1.00
# Query: ai-related musculoskeletal pathology
# no matches
# Query: oleic acid-induced acne
# no matches
# Query: acne pathogenesis
# no matches
# Query: acne vulgaris
#   • Acne Vulgaris                            URI=http://purl.obolibrary.org/obo/OMIT_0001590 score=1.00
# Query: inflammatory disease
# no matches
# Query: oleic acid-induced acne
# no matches
# Query: skin inflammation
#   • Skin Inflammation                        URI=http://purl.obolibrary.org/obo/NCIT_C50742
#   • Skin Inflammation                        URI=http://purl.obolibrary.org/obo/NCIT_C50742 score=1.00
# Query: skin inflammation
#   • Skin Inflammation                        URI=http://purl.obolibrary.org/obo/NCIT_C50742
#   • Skin Inflammation                        URI=http://purl.obolibrary.org/obo/NCIT_C50742 score=1.00
# Query: serum hormone secretion
# no matches
# Query: acne
#   • Acne                                     URI=http://purl.obolibrary.org/obo/NCIT_C27195
#   • Acne                                     URI=http://purl.obolibrary.org/obo/NCIT_C27195 score=1.00
# Query: skin inflammation
#   • Skin Inflammation                        URI=http://purl.obolibrary.org/obo/NCIT_C50742
#   • Skin Inflammation                        URI=http://purl.obolibrary.org/obo/NCIT_C50742 score=1.00
# Query: neurodegenerative diseases
#   • Neurodegenerative Diseases               URI=http://purl.obolibrary.org/obo/OMIT_0019646 score=1.00
# Query: age-associated diseases
# no matches
# Query: neurodegenerative  inflammatory  metabolic  and cardiovascular diseases
# no matches
# Query: cancer
#   • Cancer Other                             URI=http://purl.obolibrary.org/obo/NCIT_C50477 score=1.00
# Query: senescence
#   • Senescence                               URI=http://purl.obolibrary.org/obo/NCIT_C17467
#   • Senescence                               URI=http://purl.obolibrary.org/obo/NCIT_C17467 score=1.00
# Query: neurodegeneration
# no matches
# Query: age-associated brain diseases
# no matches
# Query: alzheimer s and parkinson s diseases
# no matches
# Query: age-associated molecular dysfunctions
# no matches
# Query: dysregulation of microglia genes
# no matches
# Query: neuroinflammation
# no matches
# Query: telomere attrition
# no matches
# Query: neuronal stem cell degradation
# no matches
# Query: vascular system dysfunction
# no matches
# Query: loss of chromosome x inactivation
# no matches
# Query: gut microbiome dysbiosis
# no matches
# Query: neurodegeneration
# no matches
# Query: age-related brain diseases
# no matches
# Query: neurodegenerative diseases
#   • Neurodegenerative Diseases               URI=http://purl.obolibrary.org/obo/OMIT_0019646 score=1.00
# Query: parkinson s
#   • Parkinson Disease                        URI=http://purl.obolibrary.org/obo/NCIT_C26845 score=0.85
# Query: alzheimer s
#   • Other Alzheimer's Disease                URI=http://purl.obolibrary.org/obo/NCIT_C195947 score=0.86
# Query: lewy body dementia
#   • Lewy Body Dementia                       URI=http://purl.obolibrary.org/obo/NCIT_C84826
#   • Lewy Body Dementia                       URI=http://purl.obolibrary.org/obo/NCIT_C84826 score=1.00
# Query: alzheimer s disease
#   • Alzheimer's Disease                      URI=http://purl.obolibrary.org/obo/NCIT_C2866 score=1.00
# Query: ad
#   • AD Regimen                               URI=http://purl.obolibrary.org/obo/NCIT_C63516 score=0.88
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: pd
# no matches
# Query: lewy body dementia
#   • Lewy Body Dementia                       URI=http://purl.obolibrary.org/obo/NCIT_C84826
#   • Lewy Body Dementia                       URI=http://purl.obolibrary.org/obo/NCIT_C84826 score=1.00
# Query: lbd
# no matches
# Query: vitiligo
#   • Vitiligo                                 URI=http://purl.obolibrary.org/obo/NCIT_C26915
#   • Vitiligo                                 URI=http://purl.obolibrary.org/obo/NCIT_C26915 score=1.00
# Query: ad
#   • AD Regimen                               URI=http://purl.obolibrary.org/obo/NCIT_C63516 score=0.88
# Query: pd
# no matches
# Query: lbd
# no matches
# Query: vitiligo
#   • Vitiligo                                 URI=http://purl.obolibrary.org/obo/NCIT_C26915
#   • Vitiligo                                 URI=http://purl.obolibrary.org/obo/NCIT_C26915 score=1.00
# Query: apoptosis
#   • Apoptosis                                URI=http://purl.obolibrary.org/obo/NCIT_C17557
#   • Apoptosis                                URI=http://purl.obolibrary.org/obo/NCIT_C17557 score=1.00
# Query: gut dysbiosis
#   • Dysbiosis                                URI=http://purl.obolibrary.org/obo/OMIT_0028544 score=1.00
# Query: inflammation
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137 score=1.00
# Query: gut dysbiosis
#   • Dysbiosis                                URI=http://purl.obolibrary.org/obo/OMIT_0028544 score=1.00
# Query: inflammation
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137 score=1.00
# Query: ad
#   • AD Regimen                               URI=http://purl.obolibrary.org/obo/NCIT_C63516 score=0.88
# Query: pd
# no matches
# Query: lbd
# no matches
# Query: neurodegenerative diseases
#   • Neurodegenerative Diseases               URI=http://purl.obolibrary.org/obo/OMIT_0019646 score=1.00
# Query: inflammation
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137 score=1.00
# Query: melanomas
# no matches
# Query: vitiligo
#   • Vitiligo                                 URI=http://purl.obolibrary.org/obo/NCIT_C26915
#   • Vitiligo                                 URI=http://purl.obolibrary.org/obo/NCIT_C26915 score=1.00
# Query: cums-induced depressive disorder
# no matches
# Query: major depressive disorders
# no matches
# Query: chronic unpredictable mild stress  cums -induced depressive-like symptoms
# no matches
# Query: major depressive disorder
#   • Depressive Disorder, Major               URI=http://purl.obolibrary.org/obo/OMIT_0005141 score=1.00
# Query: depressive behaviors
# no matches
# Query: major depressive disorders
# no matches
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: human stress
# no matches
# Query: anxiety symptoms
# no matches
# Query: stress
#   • Stress                                   URI=http://purl.obolibrary.org/obo/NCIT_C35041
#   • Stress                                   URI=http://purl.obolibrary.org/obo/NCIT_C35041 score=1.00
# Query: mental health problems
# no matches
# Query: anxiety
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696 score=1.00
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: stress
#   • Stress                                   URI=http://purl.obolibrary.org/obo/NCIT_C35041
#   • Stress                                   URI=http://purl.obolibrary.org/obo/NCIT_C35041 score=1.00
# Query: anxiety
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696 score=1.00
# Query: stress-related symptoms
# no matches
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: altered gut microbiome
# no matches
# Query: intestinal inflammation
# no matches
# Query: gastric disturbances
# no matches
# Query: microbiome alteration
# no matches
# Query: pd-like pathology
# no matches
# Query: colitis
#   • Colitis                                  URI=http://purl.obolibrary.org/obo/NCIT_C26723
#   • Colitis                                  URI=http://purl.obolibrary.org/obo/NCIT_C26723 score=1.00
# Query: gut inflammation
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/OMIT_0008376 score=1.00
# Query: lps paraquat-induced weight loss
# no matches
# Query: inflamed gut
# no matches
# Query: brain-gut changes
# no matches
# Query: pd
# no matches
# Query: human neurological disorders
# no matches
# Query: imbalance in the gut microflora
# no matches
# Query: dysbiosis
#   • Dysbiosis                                URI=http://purl.obolibrary.org/obo/OMIT_0028544 score=1.00
# Query: neurological disorders
# no matches
# Query: neurological conditions
# no matches
# Query: autism spectrum disorders
# no matches
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: multiple sclerosis
#   • Multiple Sclerosis                       URI=http://purl.obolibrary.org/obo/NCIT_C3243
#   • Multiple Sclerosis                       URI=http://purl.obolibrary.org/obo/NCIT_C3243 score=1.00
# Query: alzheimer s disease
#   • Alzheimer's Disease                      URI=http://purl.obolibrary.org/obo/NCIT_C2866 score=1.00
# Query: epilepsy
#   • Epilepsy                                 URI=http://purl.obolibrary.org/obo/OMIT_0006064 score=1.00
# Query: stroke
#   • Stroke                                   URI=http://purl.obolibrary.org/obo/NCIT_C3390
#   • Stroke                                   URI=http://purl.obolibrary.org/obo/NCIT_C3390 score=1.00
# Query: neurological disorders
# no matches
# Query: neurological disorders
# no matches
# Query: depressive disorder
#   • Depressive Disorder                      URI=http://purl.obolibrary.org/obo/OMIT_0005142 score=1.00
# Query: depressive disorder
#   • Depressive Disorder                      URI=http://purl.obolibrary.org/obo/OMIT_0005142 score=1.00
# Query: dd
#   • DD                                       URI=http://purl.obolibrary.org/obo/NCIT_C14767
#   • DD                                       URI=http://purl.obolibrary.org/obo/NCIT_C14767 score=1.00
# Query: hpa axis dysfunction
# no matches
# Query: chronic mild stress
# no matches
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: stress-related disorders
# no matches
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: cms
# no matches
# Query: anxiety- and depressive-like behaviors
# no matches
# Query: cms-induced anxiety- and depressive-like behaviors
# no matches
# Query: dysbiosis
#   • Dysbiosis                                URI=http://purl.obolibrary.org/obo/OMIT_0028544 score=1.00
# Query: inflammatory bowel disease
#   • Inflammatory Bowel Disease               URI=http://purl.obolibrary.org/obo/NCIT_C3138
#   • Inflammatory Bowel Disease               URI=http://purl.obolibrary.org/obo/NCIT_C3138 score=1.00
# Query: obesity
#   • Obesity                                  URI=http://purl.obolibrary.org/obo/NCIT_C3283
#   • Obesity                                  URI=http://purl.obolibrary.org/obo/NCIT_C3283 score=1.00
# Query: neurological conditions
# no matches
# Query: gastrointestinal disorders
#   • Gastrointestinal Disorders, CTCAE        URI=http://purl.obolibrary.org/obo/NCIT_C146630 score=0.93
# Query: chronic enteropathy
# no matches
# Query: inflammatory bowel disease
#   • Inflammatory Bowel Disease               URI=http://purl.obolibrary.org/obo/NCIT_C3138
#   • Inflammatory Bowel Disease               URI=http://purl.obolibrary.org/obo/NCIT_C3138 score=1.00
# Query: food allergies
#   • Food                                     URI=http://purl.obolibrary.org/obo/NCIT_C62695 score=1.00
# Query: ulcerative histiocytic colitis
# no matches
# Query: irritable bowel syndrome
#   • Irritable Bowel Syndrome                 URI=http://purl.obolibrary.org/obo/NCIT_C82343
#   • Irritable Bowel Syndrome                 URI=http://purl.obolibrary.org/obo/NCIT_C82343 score=1.00
# Query: depression patients
# no matches
# Query: irritable bowel syndrome
#   • Irritable Bowel Syndrome                 URI=http://purl.obolibrary.org/obo/NCIT_C82343
#   • Irritable Bowel Syndrome                 URI=http://purl.obolibrary.org/obo/NCIT_C82343 score=1.00
# Query: ibs
# no matches
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: diarrhea-predominant ibs
#   • Diarrhea                                 URI=http://purl.obolibrary.org/obo/OMIT_0005240 score=1.00
# Query: ibs-d
# no matches
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: ibs-d
# no matches
# Query: ibs-d
# no matches
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: ibs-d
# no matches
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: ibs-d
# no matches
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: neurodegenerative diseases
#   • Neurodegenerative Diseases               URI=http://purl.obolibrary.org/obo/OMIT_0019646 score=1.00
# Query: neurodegenerative diseases
#   • Neurodegenerative Diseases               URI=http://purl.obolibrary.org/obo/OMIT_0019646 score=1.00
# Query: nds
# no matches
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: pd
# no matches
# Query: neurodegenerative disease
#   • Neurodegenerative Disease Gene           URI=http://purl.obolibrary.org/obo/NCIT_C20856 score=0.95
# Query: pd
# no matches
# Query: nds
# no matches
# Query: alzheimer s disease
#   • Alzheimer's Disease                      URI=http://purl.obolibrary.org/obo/NCIT_C2866 score=1.00
# Query: ad
#   • AD Regimen                               URI=http://purl.obolibrary.org/obo/NCIT_C63516 score=0.88
# Query: multiple system atrophy
#   • Multiple System Atrophy                  URI=http://purl.obolibrary.org/obo/NCIT_C84909
#   • Multiple System Atrophy                  URI=http://purl.obolibrary.org/obo/NCIT_C84909 score=1.00
# Query: msa
# no matches
# Query: multiple sclerosis
#   • Multiple Sclerosis                       URI=http://purl.obolibrary.org/obo/NCIT_C3243
#   • Multiple Sclerosis                       URI=http://purl.obolibrary.org/obo/NCIT_C3243 score=1.00
# Query: ms
#   • Ms                                       URI=http://purl.obolibrary.org/obo/NCIT_C69169
#   • Ms                                       URI=http://purl.obolibrary.org/obo/NCIT_C69169 score=1.00
# Query: neuromyelitis optica
#   • Neuromyelitis Optica                     URI=http://purl.obolibrary.org/obo/NCIT_C84934
#   • Neuromyelitis Optica                     URI=http://purl.obolibrary.org/obo/NCIT_C84934 score=1.00
# Query: nmo
# no matches
# Query: amyotrophic lateral sclerosis
#   • Amyotrophic Lateral Sclerosis            URI=http://purl.obolibrary.org/obo/NCIT_C34373
#   • Amyotrophic Lateral Sclerosis 1          URI=http://purl.obolibrary.org/obo/NCIT_C168749 score=1.00
# Query: als
# no matches
# Query: pd
# no matches
# Query: pd
# no matches
# Query: pd
# no matches
# Query: msa
# no matches
# Query: alpha synucleinopathies
#   • Alpha                                    URI=http://purl.obolibrary.org/obo/NCIT_C86942 score=1.00
# Query: cognitive impairment
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921 score=1.00
# Query: hippocampal microglia-mediated synaptic loss
# no matches
# Query: cognitive impairment
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921 score=1.00
# Query: neurodegenerative diseases
#   • Neurodegenerative Diseases               URI=http://purl.obolibrary.org/obo/OMIT_0019646 score=1.00
# Query: cognitive impairment
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921 score=1.00
# Query: impaired cognition
# no matches
# Query: gut microbiota dysbiosis
# no matches
# Query: cognitive impairment
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921 score=1.00
# Query: cognitive impairment
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921 score=1.00
# Query: cognitive impairment
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921
#   • Cognitive Impairment                     URI=http://purl.obolibrary.org/obo/NCIT_C116921 score=1.00
# Query: neurodegenerative diseases
#   • Neurodegenerative Diseases               URI=http://purl.obolibrary.org/obo/OMIT_0019646 score=1.00
# Query: inflammatory gut milieu
# no matches
# Query: posttraumatic stress disorder
#   • Acute Stress Disorder                    URI=http://purl.obolibrary.org/obo/NCIT_C92621 score=0.88
# Query: ptsd
# no matches
# Query: ptsd
# no matches
# Query: ptsd
# no matches
# Query: ptsd
# no matches
# Query: gut dysbiosis and inflammation
# no matches
# Query: ptsd
# no matches
# Query: microbiota dysbiosis
# no matches
# Query: dysregulation of gut barrier functions
# no matches
# Query: transepithelial electrical resistance
# no matches
# Query: mucin homeostasis
# no matches
# Query: antimicrobial responses
# no matches
# Query: traumatic stress
#   • Stress Disorders, Traumatic              URI=http://purl.obolibrary.org/obo/OMIT_0023016 score=0.88
# Query: dysregulation of gut barrier functions
# no matches
# Query: proinflammatory gut milieu
# no matches
# Query: ptsd
# no matches
# Query: helicobacter pylori-related hyperhomocysteinemia
# no matches
# Query: neurodegeneration
# no matches
# Query: helicobacter pylori infection
#   • Helicobacter Pylori Infection            URI=http://purl.obolibrary.org/obo/NCIT_C39293
#   • Helicobacter Pylori Infection            URI=http://purl.obolibrary.org/obo/NCIT_C39293 score=1.00
# Query: substantiated local gastric pathologies
# no matches
# Query: peptic ulcers
# no matches
# Query: gastric cancer
# no matches
# Query: neurodegenerative disorders
#   • Neurodegenerative Disorders Pathway      URI=http://purl.obolibrary.org/obo/NCIT_C39737 score=0.91
# Query: hyperhomocysteinemia-related brain cortical thinning
# no matches
# Query: bct
# no matches
# Query: bct
# no matches
# Query: neurodegenerative central nervous system disorders
# no matches
# Query: alzheimer s disease
#   • Alzheimer's Disease                      URI=http://purl.obolibrary.org/obo/NCIT_C2866 score=1.00
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: multiple sclerosis
#   • Multiple Sclerosis                       URI=http://purl.obolibrary.org/obo/NCIT_C3243
#   • Multiple Sclerosis                       URI=http://purl.obolibrary.org/obo/NCIT_C3243 score=1.00
# Query: glaucoma
#   • Glaucoma                                 URI=http://purl.obolibrary.org/obo/NCIT_C26782
#   • Glaucoma                                 URI=http://purl.obolibrary.org/obo/NCIT_C26782 score=1.00
# Query: ocular alzheimer s disease
# no matches
# Query: neurodegeneration
# no matches
# Query: neurodegenerative diseases
#   • Neurodegenerative Diseases               URI=http://purl.obolibrary.org/obo/OMIT_0019646 score=1.00
# Query: alzheimer s disease
#   • Alzheimer's Disease                      URI=http://purl.obolibrary.org/obo/NCIT_C2866 score=1.00
# Query: helicobacter pylori-related hyperhomocysteinemia
# no matches
# Query: neurodegenerative disorders
#   • Neurodegenerative Disorders Pathway      URI=http://purl.obolibrary.org/obo/NCIT_C39737 score=0.91
# Query: bipolar disorder
#   • Bipolar Disorder                         URI=http://purl.obolibrary.org/obo/NCIT_C34423
#   • Other Bipolar Disorder                   URI=http://purl.obolibrary.org/obo/NCIT_C195891 score=1.00
# Query: bipolar disorder
#   • Bipolar Disorder                         URI=http://purl.obolibrary.org/obo/NCIT_C34423
#   • Other Bipolar Disorder                   URI=http://purl.obolibrary.org/obo/NCIT_C195891 score=1.00
# Query: major depressive episode
# no matches
# Query: bpd
# no matches
# Query: bpd
# no matches
# Query: bpd
# no matches
# Query: bpd
# no matches
# Query: bpd
# no matches
# Query: bpd
# no matches
# Query: bpd
# no matches
# Query: bipolar disorders
# no matches
# Query: bpd
# no matches
# Query: bpd
# no matches
# Query: mild metabolic disorders
# no matches
# Query: secondary metabolic disturbances
# no matches
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: bipolar disorder
#   • Bipolar Disorder                         URI=http://purl.obolibrary.org/obo/NCIT_C34423
#   • Other Bipolar Disorder                   URI=http://purl.obolibrary.org/obo/NCIT_C195891 score=1.00
# Query: mild metabolic disorders
# no matches
# Query: metabolic syndrome
#   • Metabolic Syndrome                       URI=http://purl.obolibrary.org/obo/NCIT_C84442
#   • Metabolic Syndrome                       URI=http://purl.obolibrary.org/obo/NCIT_C84442 score=1.00
# Query: mild metabolic disorders
# no matches
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: bipolar disorder
#   • Bipolar Disorder                         URI=http://purl.obolibrary.org/obo/NCIT_C34423
#   • Other Bipolar Disorder                   URI=http://purl.obolibrary.org/obo/NCIT_C195891 score=1.00
# Query: schizoaffective psychosis
# no matches
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: bipolar disorder
#   • Bipolar Disorder                         URI=http://purl.obolibrary.org/obo/NCIT_C34423
#   • Other Bipolar Disorder                   URI=http://purl.obolibrary.org/obo/NCIT_C195891 score=1.00
# Query: mild metabolic disturbances
# no matches
# Query: autoimmune diseases
#   • Autoimmune Diseases                      URI=http://purl.obolibrary.org/obo/OMIT_0002707 score=1.00
# Query: gastrointestinal disorders
#   • Gastrointestinal Disorders, CTCAE        URI=http://purl.obolibrary.org/obo/NCIT_C146630 score=0.93
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: autoimmunity
#   • Autoimmunity                             URI=http://purl.obolibrary.org/obo/OMIT_0016272 score=1.00
# Query: gastrointestinal  gi  disorders
# no matches
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: autoimmune disorders
# no matches
# Query: enteropathic celiac disease
#   • Celiac Disease                           URI=http://purl.obolibrary.org/obo/OMIT_0003776 score=1.00
# Query: non-celiac food sensitivities
# no matches
# Query: co-morbid gi inflammation
# no matches
# Query: humoral immunity
#   • Humoral Immunity                         URI=http://purl.obolibrary.org/obo/NCIT_C16712
#   • Humoral Immunity                         URI=http://purl.obolibrary.org/obo/NCIT_C16712 score=1.00
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: antipsychotic-generated motility effects
# no matches
# Query: inflammation
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137 score=1.00
# Query: infection
#   • Infection                                URI=http://purl.obolibrary.org/obo/NCIT_C128320
#   • Co-infection                             URI=http://purl.obolibrary.org/obo/NCIT_C173511 score=1.00
# Query: inflammation
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137 score=1.00
# Query: inefficient gluten digestion
# no matches
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: autoimmunity
#   • Autoimmunity                             URI=http://purl.obolibrary.org/obo/OMIT_0016272 score=1.00
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: polygenic brain disorders
# no matches
# Query: autism spectrum disorder
#   • Autism Spectrum Disorder                 URI=http://purl.obolibrary.org/obo/NCIT_C88412
#   • Autism Spectrum Disorder                 URI=http://purl.obolibrary.org/obo/NCIT_C88412 score=1.00
# Query: maternal immune activation
# no matches
# Query: mia
#   • MIA Gene                                 URI=http://purl.obolibrary.org/obo/NCIT_C98124 score=0.95
# Query: autism spectrum disorder
#   • Autism Spectrum Disorder                 URI=http://purl.obolibrary.org/obo/NCIT_C88412
#   • Autism Spectrum Disorder                 URI=http://purl.obolibrary.org/obo/NCIT_C88412 score=1.00
# Query: asd
# no matches
# Query: mia
#   • MIA Gene                                 URI=http://purl.obolibrary.org/obo/NCIT_C98124 score=0.95
# Query: mia
#   • MIA Gene                                 URI=http://purl.obolibrary.org/obo/NCIT_C98124 score=0.95
# Query: asd
# no matches
# Query: fever
#   • Fever                                    URI=http://purl.obolibrary.org/obo/NCIT_C3038
#   • Q Fever                                  URI=http://purl.obolibrary.org/obo/NCIT_C34970 score=1.00
# Query: genitourinary infection
#   • Genitourinary System Infection           URI=http://purl.obolibrary.org/obo/NCIT_C35719 score=1.00
# Query: asd
# no matches
# Query: flu
# no matches
# Query: asd
# no matches
# Query: flu
# no matches
# Query: asd
# no matches
# Query: flu
# no matches
# Query: asd
# no matches
# Query: mia
#   • MIA Gene                                 URI=http://purl.obolibrary.org/obo/NCIT_C98124 score=0.95
# Query: autism spectrum disorder
#   • Autism Spectrum Disorder                 URI=http://purl.obolibrary.org/obo/NCIT_C88412
#   • Autism Spectrum Disorder                 URI=http://purl.obolibrary.org/obo/NCIT_C88412 score=1.00
# Query: asd
# no matches
# Query: asd
# no matches
# Query: asd
# no matches
# Query: flu
# no matches
# Query: asd
# no matches
# Query: neuropsychiatric disorders
# no matches
# Query: psychiatric disorders
#   • Psychiatric Disorders, CTCAE             URI=http://purl.obolibrary.org/obo/NCIT_C143187 score=0.94
# Query: psychiatric disorders
#   • Psychiatric Disorders, CTCAE             URI=http://purl.obolibrary.org/obo/NCIT_C143187 score=0.94
# Query: mental health disorders
#   • Mental Disorders                         URI=http://purl.obolibrary.org/obo/OMIT_0002893 score=0.86
# Query: psychiatric disorders
#   • Psychiatric Disorders, CTCAE             URI=http://purl.obolibrary.org/obo/NCIT_C143187 score=0.94
# Query: autism spectrum disorder
#   • Autism Spectrum Disorder                 URI=http://purl.obolibrary.org/obo/NCIT_C88412
#   • Autism Spectrum Disorder                 URI=http://purl.obolibrary.org/obo/NCIT_C88412 score=1.00
# Query: asd
# no matches
# Query: attention deficit hyperactivity disorder
#   • Attention Deficit Hyperactivity Disorder URI=http://purl.obolibrary.org/obo/NCIT_C97160
#   • Attention Deficit Hyperactivity Disorder URI=http://purl.obolibrary.org/obo/NCIT_C97160 score=1.00
# Query: adhd
# no matches
# Query: asd
# no matches
# Query: psychiatric disorders
#   • Psychiatric Disorders, CTCAE             URI=http://purl.obolibrary.org/obo/NCIT_C143187 score=0.94
# Query: gut dysbiosis
#   • Dysbiosis                                URI=http://purl.obolibrary.org/obo/OMIT_0028544 score=1.00
# Query: mental disorders
#   • Mental Disorders                         URI=http://purl.obolibrary.org/obo/OMIT_0002893 score=1.00
# Query: gut dysbiosis
#   • Dysbiosis                                URI=http://purl.obolibrary.org/obo/OMIT_0028544 score=1.00
# Query: mental disorders
#   • Mental Disorders                         URI=http://purl.obolibrary.org/obo/OMIT_0002893 score=1.00
# Query: neuropsychiatric disorders
# no matches
# Query: neuropsychiatric disorders
# no matches
# Query: type 2 diabetes mellitus
#   • Type 2 Diabetes Mellitus                 URI=http://purl.obolibrary.org/obo/NCIT_C26747
#   • Type 1 Diabetes Mellitus                 URI=http://purl.obolibrary.org/obo/NCIT_C2986 score=1.00
# Query: t2dm
# no matches
# Query: fecal microbiota dysbiosis
#   • Fecal Microbiota Transplantation         URI=http://purl.obolibrary.org/obo/NCIT_C118643 score=0.87
# Query: psychiatric comorbidities
#   • Psychiatric Finding                      URI=http://purl.obolibrary.org/obo/NCIT_C168404 score=0.88
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: anxiety
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696 score=1.00
# Query: t2dm
# no matches
# Query: t2dm
# no matches
# Query: systemic inflammation
# no matches
# Query: psychiatric comorbidities
#   • Psychiatric Finding                      URI=http://purl.obolibrary.org/obo/NCIT_C168404 score=0.88
# Query: intestinal microbiota alterations
# no matches
# Query: t2dm
# no matches
# Query: alcohol use disorder
# no matches
# Query: substance use disorder
# no matches
# Query: healthy eating index
# no matches
# Query: depression-like behavior
# no matches
# Query: chronic and unpredictable mild stress
# no matches
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: chronic mental illness
# no matches
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: anxiety
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696 score=1.00
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: stress-induced depression
# no matches
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: depression-like behaviors
# no matches
# Query: chronic restraint stress-induced neurobehavioral and gut barrier deficits
# no matches
# Query: depression-like behaviors
# no matches
# Query: dysbiosis
#   • Dysbiosis                                URI=http://purl.obolibrary.org/obo/OMIT_0028544 score=1.00
# Query: cancers of the esophagus and stomach
# no matches
# Query: dysbiosis of the gastrointestinal tract
#   • Gastrointestinal Tract                   URI=http://purl.obolibrary.org/obo/NCIT_C34082 score=1.00
# Query: nonalcoholic fatty liver disease
#   • Nonalcoholic Fatty Liver Disease         URI=http://purl.obolibrary.org/obo/NCIT_C84444
#   • Nonalcoholic Fatty Liver Disease         URI=http://purl.obolibrary.org/obo/NCIT_C84444 score=1.00
# Query: cardiovascular disease
# no matches
# Query: obesity
#   • Obesity                                  URI=http://purl.obolibrary.org/obo/NCIT_C3283
# ...
#   • Toll-Like Receptor 3                     URI=http://purl.obolibrary.org/obo/NCIT_C30104 score=0.95
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: microbial dysbiosis
# no matches
# Query: chronic gut dysfunction
# no matches
# Query: anxiety
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696 score=1.00
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: anxiety
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696 score=1.00
# Query: depressive behaviour
# no matches
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: anxiety disorders
#   • Anxiety Disorders                        URI=http://purl.obolibrary.org/obo/OMIT_0002402 score=1.00
# Query: mental illnesses
# no matches
# Query: cognitive or motor dysfunction
# no matches
# Query: anxiety
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696
#   • Anxiety                                  URI=http://purl.obolibrary.org/obo/NCIT_C26696 score=1.00
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: mental health
#   • Mental Health                            URI=http://purl.obolibrary.org/obo/NCIT_C93187
#   • Mental Health                            URI=http://purl.obolibrary.org/obo/NCIT_C93187 score=1.00
# Query: major depressive disorder
#   • Depressive Disorder, Major               URI=http://purl.obolibrary.org/obo/OMIT_0005141 score=1.00
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: gut microbiota disorder
# no matches
# Query: major depressive disorder
#   • Depressive Disorder, Major               URI=http://purl.obolibrary.org/obo/OMIT_0005141 score=1.00
# Query: mdd
# no matches
# Query: mdd
# no matches
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: depression
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C124639
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982
#   • Depression                               URI=http://purl.obolibrary.org/obo/NCIT_C2982 score=1.00
# Query: age-related neurodegeneration
# no matches
# Query: neurodegenerative diseases
#   • Neurodegenerative Diseases               URI=http://purl.obolibrary.org/obo/OMIT_0019646 score=1.00
# Query: ndds
# no matches
# Query: neurodegenerative diseases
#   • Neurodegenerative Diseases               URI=http://purl.obolibrary.org/obo/OMIT_0019646 score=1.00
# Query: alzheimer s
#   • Other Alzheimer's Disease                URI=http://purl.obolibrary.org/obo/NCIT_C195947 score=0.86
# Query: ad
#   • AD Regimen                               URI=http://purl.obolibrary.org/obo/NCIT_C63516 score=0.88
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: multiple sclerosis
#   • Multiple Sclerosis                       URI=http://purl.obolibrary.org/obo/NCIT_C3243
#   • Multiple Sclerosis                       URI=http://purl.obolibrary.org/obo/NCIT_C3243 score=1.00
# Query: amyotrophic lateral sclerosis
#   • Amyotrophic Lateral Sclerosis            URI=http://purl.obolibrary.org/obo/NCIT_C34373
#   • Amyotrophic Lateral Sclerosis 1          URI=http://purl.obolibrary.org/obo/NCIT_C168749 score=1.00
# Query: traumatic brain injury
# no matches
# Query: ndd
# no matches
# Query: ndd
# no matches
# Query: malfunctioning of neurons
#   • Murine Neurons                           URI=http://purl.obolibrary.org/obo/NCIT_C23557 score=0.86
# Query: dementia
#   • Dementia                                 URI=http://purl.obolibrary.org/obo/NCIT_C4786
#   • Dementia                                 URI=http://purl.obolibrary.org/obo/NCIT_C4786 score=1.00
# Query: death
#   • Death                                    URI=http://purl.obolibrary.org/obo/OMIT_0004926 score=1.00
# Query: ndd
# no matches
# Query: mitochondrial dysfunction
# no matches
# Query: ndd
# no matches
# Query: low-grade inflammation and anomalies
# no matches
# Query: ndd
# no matches
# Query: dementia
#   • Dementia                                 URI=http://purl.obolibrary.org/obo/NCIT_C4786
#   • Dementia                                 URI=http://purl.obolibrary.org/obo/NCIT_C4786 score=1.00
# Query: ad
#   • AD Regimen                               URI=http://purl.obolibrary.org/obo/NCIT_C63516 score=0.88
# Query: ndd
# no matches
# Query: ndd
# no matches
# Query: ndd
# no matches
# Query: ndd
# no matches
# Query: type 2 diabetes mellitus
#   • Type 2 Diabetes Mellitus                 URI=http://purl.obolibrary.org/obo/NCIT_C26747
#   • Type 1 Diabetes Mellitus                 URI=http://purl.obolibrary.org/obo/NCIT_C2986 score=1.00
# Query: type 2 diabetes mellitus
#   • Type 2 Diabetes Mellitus                 URI=http://purl.obolibrary.org/obo/NCIT_C26747
#   • Type 1 Diabetes Mellitus                 URI=http://purl.obolibrary.org/obo/NCIT_C2986 score=1.00
# Query: dementia
#   • Dementia                                 URI=http://purl.obolibrary.org/obo/NCIT_C4786
#   • Dementia                                 URI=http://purl.obolibrary.org/obo/NCIT_C4786 score=1.00
# Query: diabetes
#   • Have Diabetes                            URI=http://purl.obolibrary.org/obo/NCIT_C113407 score=1.00
# Query: nonalcoholic fatty liver
#   • Nonalcoholic Fatty Liver Disease         URI=http://purl.obolibrary.org/obo/NCIT_C84444 score=0.94
# Query: diabetes
#   • Have Diabetes                            URI=http://purl.obolibrary.org/obo/NCIT_C113407 score=1.00
# Query: diabetes
#   • Have Diabetes                            URI=http://purl.obolibrary.org/obo/NCIT_C113407 score=1.00
# Query: metabolic syndrome
#   • Metabolic Syndrome                       URI=http://purl.obolibrary.org/obo/NCIT_C84442
#   • Metabolic Syndrome                       URI=http://purl.obolibrary.org/obo/NCIT_C84442 score=1.00
# Query: clostridium difficile infection
#   • Clostridium difficile Infection          URI=http://purl.obolibrary.org/obo/NCIT_C180523
#   • Clostridium difficile Infection          URI=http://purl.obolibrary.org/obo/NCIT_C180523 score=1.00
# Query: traumatic stress
#   • Stress Disorders, Traumatic              URI=http://purl.obolibrary.org/obo/OMIT_0023016 score=0.88
# Query: mood disorders
#   • Mood Disorders                           URI=http://purl.obolibrary.org/obo/OMIT_0019924 score=1.00
# Query: stress
#   • Stress                                   URI=http://purl.obolibrary.org/obo/NCIT_C35041
#   • Stress                                   URI=http://purl.obolibrary.org/obo/NCIT_C35041 score=1.00
# Query: stress-induced psychopathologies
#   • Stress-Induced Protein                   URI=http://purl.obolibrary.org/obo/NCIT_C29736 score=0.92
# Query: affective disorders
# no matches
# Query: post-traumatic stress disorder
#   • Post-Traumatic Stress Disorder           URI=http://purl.obolibrary.org/obo/NCIT_C3389
#   • Post-Traumatic Stress Disorder           URI=http://purl.obolibrary.org/obo/NCIT_C3389 score=1.00
# Query: stress-related disorders
# no matches
# Query: traumatic stress
#   • Stress Disorders, Traumatic              URI=http://purl.obolibrary.org/obo/OMIT_0023016 score=0.88
# Query: neurological diseases
# no matches
# Query: viral respiratory infections
# no matches
# Query: neuroinflammatory disorders
# no matches
# Query: inflammation
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137 score=1.00
# Query: tissue damage
#   • Tissue Damage                            URI=http://purl.obolibrary.org/obo/NCIT_C50773
#   • Tissue Damage                            URI=http://purl.obolibrary.org/obo/NCIT_C50773 score=1.00
# Query: immune dysfunction
# no matches
# Query: inflammatory conditions
# no matches
# Query: inflammation
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137
#   • Inflammation                             URI=http://purl.obolibrary.org/obo/NCIT_C3137 score=1.00
# Query: respiratory infections
# no matches
# Query: neuroinflammatory disorders
# no matches
# Query: viral respiratory infections
# no matches
# Query: covid-19 disease
#   • COVID-19 Disease Severity 6              URI=http://purl.obolibrary.org/obo/NCIT_C179016 score=0.86
# Query: influenza virus infection
#   • Influenza A Virus                        URI=http://purl.obolibrary.org/obo/NCIT_C53454 score=0.88
# Query: neurological disorders
# no matches
# Query: multiple sclerosis
#   • Multiple Sclerosis                       URI=http://purl.obolibrary.org/obo/NCIT_C3243
#   • Multiple Sclerosis                       URI=http://purl.obolibrary.org/obo/NCIT_C3243 score=1.00
# Query: mental illnesses
# no matches
# Query: prediabetes
#   • Prediabetes                              URI=http://purl.obolibrary.org/obo/NCIT_C122685
#   • Prediabetes                              URI=http://purl.obolibrary.org/obo/NCIT_C122685 score=1.00
# Query: prediabetes
#   • Prediabetes                              URI=http://purl.obolibrary.org/obo/NCIT_C122685
#   • Prediabetes                              URI=http://purl.obolibrary.org/obo/NCIT_C122685 score=1.00
# Query: prediabetes
#   • Prediabetes                              URI=http://purl.obolibrary.org/obo/NCIT_C122685
#   • Prediabetes                              URI=http://purl.obolibrary.org/obo/NCIT_C122685 score=1.00
# Query: neurological and mental disorders
# no matches
# Query: neurological and mental disorders
# no matches
# Query: neurological and mental disorders
# no matches
# Query: neurological and mental disorders
# no matches
# Query: neurological and mental disorders
# no matches
# Query: cardiovascular diseases
#   • Cardiovascular Diseases                  URI=http://purl.obolibrary.org/obo/OMIT_0003653 score=1.00
# Query: neoplasms
#   • Neoplasms                                URI=http://purl.obolibrary.org/obo/OMIT_0010397 score=1.00
# Query: diabetes mellitus
#   • Diabetes Mellitus                        URI=http://purl.obolibrary.org/obo/NCIT_C2985
#   • Diabetes Mellitus                        URI=http://purl.obolibrary.org/obo/NCIT_C2985 score=1.00
# Query: depressive disorders
#   • Other Recurrent Depressive Disorders     URI=http://purl.obolibrary.org/obo/NCIT_C195907 score=0.89
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: alzheimer s disease
#   • Alzheimer's Disease                      URI=http://purl.obolibrary.org/obo/NCIT_C2866 score=1.00
# Query: dementias
# no matches
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: headache disorders
#   • Headache Disorders                       URI=http://purl.obolibrary.org/obo/OMIT_0020618 score=1.00
# Query: anxiety disorders
#   • Anxiety Disorders                        URI=http://purl.obolibrary.org/obo/OMIT_0002402 score=1.00
# Query: conduct disorders
# no matches
# Query: autism spectrum disorders
# no matches
# Query: eating disorders
# no matches
# Query: diabetes mellitus
#   • Diabetes Mellitus                        URI=http://purl.obolibrary.org/obo/NCIT_C2985
#   • Diabetes Mellitus                        URI=http://purl.obolibrary.org/obo/NCIT_C2985 score=1.00
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: schizophrenia
#   • Schizophrenia                            URI=http://purl.obolibrary.org/obo/NCIT_C3362
#   • Other Schizophrenia                      URI=http://purl.obolibrary.org/obo/NCIT_C195854 score=1.00
# Query: cardiovascular diseases
#   • Cardiovascular Diseases                  URI=http://purl.obolibrary.org/obo/OMIT_0003653 score=1.00
# Query: neoplasms
#   • Neoplasms                                URI=http://purl.obolibrary.org/obo/OMIT_0010397 score=1.00
# Query: neurological and mental disorders
# no matches
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: pd
# no matches
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: tremors
# no matches
# Query: postural instability
# no matches
# Query: microbiome and specific bacterial changes
# no matches
# Query: parkinson s disease
#   • Parkinson Disease 9                      URI=http://purl.obolibrary.org/obo/NCIT_C203534 score=1.00
# Query: fear of cancer recurrence
#   • Fear of Cancer Recurrence Questionnaire  URI=http://purl.obolibrary.org/obo/NCIT_C176830 score=0.91
# Query: fcr
#   • FCR Regimen                              URI=http://purl.obolibrary.org/obo/NCIT_C63755 score=0.90
# Query: depressive and anxiety disorders
# no matches
# Query: chemotherapy-associated psychological distress
# no matches
# Query: fcr
#   • FCR Regimen                              URI=http://purl.obolibrary.org/obo/NCIT_C63755 score=0.90
# Query: invasive breast cancer
# no matches
# Query: stage i disease
# no matches
# Query: fcr
#   • FCR Regimen                              URI=http://purl.obolibrary.org/obo/NCIT_C63755 score=0.90
# Query: fcr
#   • FCR Regimen                              URI=http://purl.obolibrary.org/obo/NCIT_C63755 score=0.90
# Query: fcr
#   • FCR Regimen                              URI=http://purl.obolibrary.org/obo/NCIT_C63755 score=0.90
# Query: fcr
#   • FCR Regimen                              URI=http://purl.obolibrary.org/obo/NCIT_C63755 score=0.90
# Query: fcr
#   • FCR Regimen                              URI=http://purl.obolibrary.org/obo/NCIT_C63755 score=0.90
# Query: first-episode depression
# no matches
# Query: first-episode depression
# no matches
# Query: major depressive disorder
#   • Depressive Disorder, Major               URI=http://purl.obolibrary.org/obo/OMIT_0005141 score=1.00
# Query: mdd
# no matches
# Query: first-episode depression
# no matches
# Query: mdd
# no matches
# The RDF graph has been saved in C:\Users\samue\OneDrive\Desktop\ThesisPiron\rdf\gutbrain_entities.ttl

# %% [markdown]
# <h1>INGEST ANIMAL</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint

ANIMAL_BASE = "http://purl.obolibrary.org/obo/"
ANIMAL_CLASS = URIRef("https://w3id.org/brainteaser/ontology/schema/Animal")
ANIMAL_CONCEPT_SCHEME = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/AnimalConceptScheme")

def load_animal_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = ANIMAL_BASE + term_id
            rows.append((label, uri))
    return rows

ANIMAL_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncbitaxon_full_taxonomy.txt"
NCIT_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncit_full_taxonomy.txt"
animal_rows = load_animal_labels(ANIMAL_LABELS_FILE)
ncit_rows = load_animal_labels(NCIT_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in animal_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

exact_ix1 = defaultdict(list)
for lbl, uri in ncit_rows:
    exact_ix1[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in animal_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

labels_only1 = [preprocess(lbl) for lbl, _ in ncit_rows]
vec1 = TfidfVectorizer(stop_words="english")
mat1 = vec1.fit_transform(labels_only1)

def top_cosine(term, k=5, thr=0.78):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = animal_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

def top_cosine_ncit(term, k=5, thr=0.80):
    v  = vec1.transform([term])
    sc = cosine_similarity(v, mat1).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = ncit_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

def singularize(term):
    if term.endswith("ies"):
        return term[:-3] + "y"
    elif term.endswith("s") and not term.endswith("ss"):
        return term[:-1]
    return term

created["animal"] = URIRef("http://purl.obolibrary.org/obo/NCIT_C14182")

special_map = {
                "mouse":           "mus_musculus",
                "skin lipid":      "skin",
                "mice":            "mus_musculus",
                "rat":             "mus_musculus",
                "dogs":            "Canis lupus familiaris",
                "children":        "offspring",
                "pig":             "sus",
                "bird":            "aves",
                "rodent":          "rodentia",
                "6-ohda":          "mus_musculus",
                "sps-susceptible male": "mus_musculus",
                "sps-susceptible female": "mus_musculus",
                "SPS-resilient females": "mus_musculus",
                "SPS-resilient males": "mus_musculus",
                "sps resilient females": "mus_musculus",
                "sps-s males": "mus_musculus",
                "female": "animal",
                "male": "animal",
                "females": "animal",
                "males": "animal",
        }
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "animal":
            text_span = entity.get("text_span", "").strip()
            #cleaned_text = create_uri_fragment(text_span)
            #cleaned_text_span = normalize_to_ascii(cleaned_text)
            #term_raw = cleaned_text_span.lower()
            #term = preprocess(term_raw)
            # mappature speciali
            
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for key, val in special_map.items():
                if key in lookup_key:
                    lookup_key = val
                    break
            
            term = preprocess(lookup_key)

            #print(f"Query: {term}")
            print(f"Original span: {term_raw!r}; Lookup term: {term!r}")
            
            if lookup_key in created:
                entity_uri = created[lookup_key]
                print(f"  → Reusing existing URI: {entity_uri}\n")
                continue

            ex = exact_ix.get(term, [])
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, ANIMAL_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            cos = top_cosine(term)
            cos1 = top_cosine_ncit(term)
            if cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, ANIMAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, ANIMAL_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, ANIMAL_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAIN[term_raw])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAIN[f"title_{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAIN[f"abstract_{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip()
        else:
            continue

        if label != "animal":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAIN[cleaned_text_span])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_animal_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))
# Out:
# Original span: 'birds'; Lookup term: 'aves'
#   • Aves                                     URI=http://purl.obolibrary.org/obo/NCBITaxon_8782
#   • Aves                                     URI=http://purl.obolibrary.org/obo/NCBITaxon_8782 score=1.00
#
# Original span: 'bird'; Lookup term: 'aves'
#   • Aves                                     URI=http://purl.obolibrary.org/obo/NCBITaxon_8782
#   • Aves                                     URI=http://purl.obolibrary.org/obo/NCBITaxon_8782 score=1.00
#
# Original span: 'animals'; Lookup term: 'animal'
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# Original span: 'diabetic_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'streptozotocin__stz_-induced_t1d_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 't1d_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 't1d_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 't1d_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'acne_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'acne_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'acne_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'depressive_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'offspring'; Lookup term: 'offspring'
#   • Offspring                                URI=http://purl.obolibrary.org/obo/NCIT_C42708 score=1.00
#
# Original span: 'mothers'; Lookup term: 'mother'
#   • Mother                                   URI=http://purl.obolibrary.org/obo/NCIT_C25189 score=1.00
#
# Original span: 'children'; Lookup term: 'offspring'
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C42708
#
# Original span: 'mothers'; Lookup term: 'mother'
#   • Mother                                   URI=http://purl.obolibrary.org/obo/NCIT_C25189 score=1.00
#
# Original span: 'children'; Lookup term: 'offspring'
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C42708
#
# Original span: 'rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'dogs'; Lookup term: 'dog'
#   • Dog                                      URI=http://purl.obolibrary.org/obo/NCIT_C14201 score=1.00
#
# Original span: 'dogs'; Lookup term: 'dog'
#   • Dog                                      URI=http://purl.obolibrary.org/obo/NCIT_C14201 score=1.00
#
# Original span: 'dogs'; Lookup term: 'dog'
#   • Dog                                      URI=http://purl.obolibrary.org/obo/NCIT_C14201 score=1.00
#
# Original span: 'dogs'; Lookup term: 'dog'
#   • Dog                                      URI=http://purl.obolibrary.org/obo/NCIT_C14201 score=1.00
#
# Original span: 'dogs'; Lookup term: 'dog'
#   • Dog                                      URI=http://purl.obolibrary.org/obo/NCIT_C14201 score=1.00
#
# Original span: 'fd_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'fd_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'fd_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'fd_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mice_with_a_short-term_fd_diet__7_days_'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'scfa_receptor_knockout_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mouse_model'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'rsds_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'rsds_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'rsds_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'depressed_rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'cums_model_rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'cums_rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'depressed_rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'aged_rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'adult_rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'experimental_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'healthy_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'stressed_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'stress-naive_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'cus_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'gastrointestinal__gi__tract'; Lookup term: 'gastrointestinal  gi  tract'
# no matches
# Original span: 'cpz-treated_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'cpz-treated_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'cpz-treated_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'cpz-treated_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'cpz-treated_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: '-synuclein_overexpressing_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: '-synuclein_overexpressing__aso__mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'aso_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'aso_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'aso_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'aso_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: '6-ohda'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'singly-housed_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'c57bl_6n_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'males'; Lookup term: 'animal'
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# Original span: 'females'; Lookup term: 'animal'
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# Original span: 'diet-induced_high-fat_mesocricetus_auratus'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mesocricetus_auratus'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'm__auratus'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'chronic_unpredictable_mild_stress__cums__model_rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'c57bl_6j_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'humanized_gnotobiotic_mice'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'male_and_female_sprague-dawley_rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'sps-s_males'; Lookup term: 'animal'
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# Original span: 'sps-r_females'; Lookup term: 'animal'
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# Original span: 'sps-susceptible_males'; Lookup term: 'animal'
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# Original span: 'sps-susceptible_females'; Lookup term: 'animal'
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# Original span: 'male_and_female_rats'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'male_and_female_rodents'; Lookup term: 'rodentia'
#   • Rodentia                                 URI=http://purl.obolibrary.org/obo/NCBITaxon_9989
#   • Rodentia                                 URI=http://purl.obolibrary.org/obo/NCBITaxon_9989 score=1.00
#
# Original span: 'sps-resilient_females'; Lookup term: 'animal'
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# Original span: 'juvenile_rat'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'sps-resilient_males'; Lookup term: 'animal'
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# Original span: 'sps-resilient_males'; Lookup term: 'animal'
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# Original span: 'sps-susceptible_females'; Lookup term: 'animal'
#   → Reusing existing URI: http://purl.obolibrary.org/obo/NCIT_C14182
#
# Original span: 'mouse_model'; Lookup term: 'mus musculus'
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090
#   • Mus musculus                             URI=http://purl.obolibrary.org/obo/NCBITaxon_10090 score=1.00
#
# Original span: 'pigs'; Lookup term: 'sus'
#   • Sus                                      URI=http://purl.obolibrary.org/obo/NCBITaxon_9822
#   • Sus                                      URI=http://purl.obolibrary.org/obo/NCBITaxon_9822 score=1.00

# %% [markdown]
# <h1>INGEST DIETARY SUPPLEMENT</h1>

# %%
import re
import json
import numpy as np
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import unicodedata
from pathlib import Path
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL
from pprint import pprint
from nltk.stem import WordNetLemmatizer

DIETARYSUPPLEMENT_BASE = "http://purl.obolibrary.org/obo/"
DIETARYSUPPLEMENT_CLASS = URIRef("https://w3id.org/brainteaser/ontology/schema/DietarySupplement")
DIETARYSUPPLEMENT_CONCEPT_SCHEME = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/DietarySupplement")

lemmatizer = WordNetLemmatizer()

created = {}

# 1.1) keep only your hand-picked seeds here
manual_created = {
    "dietary_supplementation": URIRef("https://www.ncbi.nlm.nih.gov/mesh/68019587"),
    "egcg":                     URIRef("http://purl.obolibrary.org/obo/XCO_0001093"),
    "hippophae_rhamnoide":      URIRef("http://purl.obolibrary.org/obo/NCBITaxon_193516"),
    "prebiotic":                URIRef("http://purl.obolibrary.org/obo/OMIT_0026689"),
    "acacetin":                 URIRef("http://purl.obolibrary.org/obo/CHEBI_15335"),
    "gluten":                   URIRef("http://purl.obolibrary.org/obo/FOODON_03420177"),
    "lactobacillus":            URIRef("https://www.ncbi.nlm.nih.gov/mesh/D052200"),
    "triphala":                 URIRef("https://www.ncbi.nlm.nih.gov/mesh/67520904"),
    "lacticaseibacillus_rhamnosus":
                                URIRef("http://purl.obolibrary.org/obo/NCBITaxon_47715"),
}

created = dict(manual_created)

for key, uri in manual_created.items():
    g.add((uri, RDF.type,      DIETARYSUPPLEMENT_CLASS))
    g.add((uri, RDF.type,      SKOS.Concept))
    g.add((uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
    label = key.replace("_", " ").capitalize()
    g.add((uri, RDFS.label, Literal(label, datatype=XSD.string)))


regex_map = [
    (r"\bprobiot(?:ic|ics|ic_supplementation)\b", "probiotic"),
    (r"feed_additive",       "feed"),
    (r"next-generation_feed_additive", "feed"),
    (r"seabuckthorn","hippophae_rhamnoide"),
    (r"vsl__3","prebiotic"),
    (r"vsl_3","prebiotic"),
    ("sbf","hippophae_rhamnoide"),
    ("fwg","fermented_wheat_germ"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))probiotic\w*\b", "probiotic"),
    (r"postbiotic","metabolite"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))scfa\w*\b","short-chain_fatty_acid"),
    (r"prebiotic_supplementation","synbiotic_supplement"),
    (r"(?:(?<=^)|(?<=[^A-Za-z0-9]))starch\w*\b","Starch"),
    (r"nvp-1704_treatment", "probiotic"),
    (r"danggui_buxue_decoction","medication"),
    (r"\bdbd\w*\b","medication"),
    (r"f4_consumption","lactobacillus"),
    (r"f4_supplementation","lactobacillus"),
    (r"medicinal_herb", "medication"),
    (r"\bprebiotic\w*\b","prebiotic"),
    (r"b__licheniformi","bacillus"),
    (r"plant_polysaccharide","plant"),
    (r"zhe_busong_decoction","triphala"),
    (r"\blacticaseibacillus_rhamnosus\w*\b", "lacticaseibacillus_rhamnosus"),
    (r"high-cholesterol_diet", "diet"),
    
]

def load_dietary_labels(path):
    pattern = re.compile(r'^\s*(.*?)\s*[\(\[]([A-Za-z0-9_]+)[\)\]]')
    rows = []
    with open(path, encoding="utf-8") as fh:
        for ln in fh:
            m = pattern.match(ln)
            if not m:
                continue
            label, term_id = m.group(1), m.group(2)
            uri = DIETARYSUPPLEMENT_BASE + term_id
            rows.append((label, uri))
    return rows

def load_chebi_labels(path):
    rows = []
    with open(path, encoding="utf-8") as fh:
        next(fh) 
        for ln in fh:
            uri, label = ln.rstrip("\n").split("\t", 1)
            rows.append((label, uri))
    return rows

CHEBI_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\chebi_labels.txt"
DIETARYSUPPLEMENT_LABELS_FILE = r"C:\Users\samue\OneDrive\Desktop\ThesisPiron\parsedOntologies\ncit_full_taxonomy.txt"
dietary_rows = load_dietary_labels(DIETARYSUPPLEMENT_LABELS_FILE)
chebi_rows = load_chebi_labels(CHEBI_LABELS_FILE)

exact_ix = defaultdict(list)
for lbl, uri in dietary_rows:
    exact_ix[lbl.lower()].append((lbl, uri))

exact_ix1 = defaultdict(list)
for lbl, uri in chebi_rows:
    exact_ix1[lbl.lower()].append((lbl, uri))

labels_only = [preprocess(lbl) for lbl, _ in dietary_rows]
vec = TfidfVectorizer(stop_words="english")
mat = vec.fit_transform(labels_only)

labels_only1 = [preprocess(lbl) for lbl, _ in chebi_rows]
vec1 = TfidfVectorizer(stop_words="english")
mat1 = vec1.fit_transform(labels_only1)

def top_cosine(term, k=5, thr=0.80):
    v  = vec.transform([term])
    sc = cosine_similarity(v, mat).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = dietary_rows[i]
        out.append((lbl, uri, sc[i]))
    return out

def top_cosine_chebi(term, k=5, thr=0.80):
    v  = vec1.transform([term])
    sc = cosine_similarity(v, mat1).ravel()
    idx = np.argsort(sc)[::-1]
    out = []
    for i in idx[:k]:
        if sc[i] < thr:
            break
        lbl, uri = chebi_rows[i]
        out.append((lbl, uri, sc[i]))
    return out
    
for paper_id, paper_data in data.items():
    
    entities = paper_data.get("entities", [])
    
    for i, entity in enumerate(entities):
        raw_label = entity.get("label", "").strip()
        
        text_span = entity.get("text_span", "").strip()
        
        if raw_label == "dietary supplement":
            text_span = entity.get("text_span", "").strip()
            cleaned_text_span = normalize_to_ascii(create_uri_fragment(text_span)).lower()
            term_raw = cleaned_text_span
            lookup_key = term_raw
            lookup_key = singularize(lookup_key)
            
            for pattern, replacement in regex_map:
                if re.search(pattern, lookup_key, flags=re.IGNORECASE):
                    lookup_key = replacement
                    break
                    
            term = preprocess(lookup_key)
            
            print(f"Query: {term}")
            #print(lookup_key)
            
            if lookup_key in created:
                entity_uri = created[lookup_key]
                for lookup_key in manual_created:
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type,        MENTION_CLASS))
                    g.add((mention_uri, RDFS.label,      Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri

            ex = exact_ix.get(term, [])
            if ex:
                for lbl, uri in ex:
                    print(f"  • {lbl:40s} URI={uri}")
                    entity_uri = URIRef(f"{uri}")
                    created[term_raw] = entity_uri
                    g.add((entity_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                    g.add((entity_uri, RDF.type, SKOS.Concept))
                    g.add((entity_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((entity_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((entity_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print(); 
                    
            cos = top_cosine(term)
            cos1 = top_cosine_chebi(term)
            if cos:
                for lbl, uri, score in cos[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
            elif cos1:
                for lbl, uri, score in cos1[:1]:
                    print(f"  • {lbl:40s} URI={uri:40s} score={score:.2f}")
                    name_uri = URIRef(f"{uri}")
                    created[term_raw] = name_uri
                    g.add((name_uri, RDF.type, DIETARYSUPPLEMENT_CLASS))
                    g.add((name_uri, RDF.type, SKOS.Concept))
                    g.add((name_uri, RDFS.label, Literal(lbl, datatype=XSD.string)))
                    g.add((name_uri, SKOS.inScheme, DIETARYSUPPLEMENT_CONCEPT_SCHEME))
                    mention_uri = URIRef(GUTBRAIN[term_raw])
                    g.add((mention_uri, RDF.type, MENTION_CLASS))
                    g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                    g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                    g.add((name_uri, GUTPROP.containedIn, mention_uri))
                    tokenized_mentions[term_raw] = mention_uri
                    continue
                    print()
                    
            else:
                mention_uri = URIRef(GUTBRAIN[term_raw])
                g.add((mention_uri, RDF.type, MENTION_CLASS))
                g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{term_raw}", datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.hasMentionText, Literal(term_raw, datatype=XSD.string)))
                g.add((mention_uri, GUTPROP.taggedAs, Literal(raw_label, datatype=XSD.string)))
                tokenized_mentions[term_raw] = mention_uri
                print("no matches")
                continue

        else:
            pass

with open(tokenized_file, "r", encoding="utf-8") as f_sent:
    tokenized_data = json.load(f_sent)

for entry in tokenized_data:
    pmid         = entry["pmid"]
    sent_id      = entry["sent_id"]
    sentence_txt = entry["sentence"].strip()
    entities     = entry["entities"]

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])

    sent_uri = URIRef(GUTBRAIN[f"sentence_{pmid}_{sent_id}"])
    g.add((sent_uri, RDF.type, SENTENCE))
    g.add((sent_uri, GUTPROP.hasSentenceText, Literal(sentence_txt, datatype=XSD.string)))

    if sent_id == 0:
        parent_uri = URIRef(GUTBRAIN[f"title_{pmid}"])
    else:
        parent_uri = URIRef(GUTBRAIN[f"abstract_{pmid}"])
    g.add((sent_uri,      GUTPROP.partOf,  parent_uri))
    g.add((parent_uri,    GUTPROP.composedOf, sent_uri))
        
    for ent in entities:
        if isinstance(ent, dict):
            text_span = ent.get("text_span", "").strip()
            label     = ent.get("label",    "").strip()
        else:
            continue

        if label != "dietary supplement":
            continue
        canonical = create_uri_fragment(text_span)
        cleaned_text_span = normalize_to_ascii(canonical).lower()
        
        if cleaned_text_span not in tokenized_mentions:
            mention_uri = URIRef(GUTBRAIN[cleaned_text_span])
            tokenized_mentions[cleaned_text_span] = mention_uri

            g.add((mention_uri, RDF.type, MENTION_CLASS))
            g.add((mention_uri, RDFS.label, Literal(f"mention_dietarysupplement_{cleaned_text_span}", datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.hasMentionText, Literal(text_span, datatype=XSD.string)))
            g.add((mention_uri, GUTPROP.taggedAs, Literal(label, datatype=XSD.string)))
            
            
        else:
            mention_uri = tokenized_mentions[cleaned_text_span]
            
        g.add((mention_uri, GUTPROP.locatedIn, sent_uri))

output_file = os.path.join(save_path, "gutbrain_entities.ttl")
ttl_output = g.serialize(format="turtle")
with open(output_file, "w", encoding="utf-8") as f_out:
    f_out.write(ttl_output)

print(f"The RDF graph has been saved in {output_file}")
# Out:
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: dietary supplementation
# no matches
# Query: feed
#   • Feed                                     URI=http://purl.obolibrary.org/obo/NCIT_C69427
#   • Feed                                     URI=http://purl.obolibrary.org/obo/NCIT_C69427 score=1.00
# Query: feed
#   • Feed                                     URI=http://purl.obolibrary.org/obo/NCIT_C69427
#   • Feed                                     URI=http://purl.obolibrary.org/obo/NCIT_C69427 score=1.00
# Query: feed
#   • Feed                                     URI=http://purl.obolibrary.org/obo/NCIT_C69427
#   • Feed                                     URI=http://purl.obolibrary.org/obo/NCIT_C69427 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: phytochemical
#   • Phytochemical                            URI=http://purl.obolibrary.org/obo/NCIT_C28269
#   • Phytochemical                            URI=http://purl.obolibrary.org/obo/NCIT_C28269 score=1.00
# Query: nutrient
#   • Nutrient                                 URI=http://purl.obolibrary.org/obo/NCIT_C1814
#   • Nutrient                                 URI=http://purl.obolibrary.org/obo/NCIT_C1814 score=1.00
# Query: phytochemical
#   • Phytochemical                            URI=http://purl.obolibrary.org/obo/NCIT_C28269
#   • Phytochemical                            URI=http://purl.obolibrary.org/obo/NCIT_C28269 score=1.00
# Query: phytochemical
#   • Phytochemical                            URI=http://purl.obolibrary.org/obo/NCIT_C28269
#   • Phytochemical                            URI=http://purl.obolibrary.org/obo/NCIT_C28269 score=1.00
# Query: curcumin
#   • Curcumin                                 URI=http://purl.obolibrary.org/obo/NCIT_C401
#   • Curcumin                                 URI=http://purl.obolibrary.org/obo/NCIT_C401 score=1.00
# Query: egcg
# no matches
# Query: fucoidan
#   • fucoidan                                 URI=http://purl.obolibrary.org/obo/CHEBI_5181 score=1.00
# Query: galangin
#   • galangin                                 URI=http://purl.obolibrary.org/obo/CHEBI_5262 score=1.00
# Query: astin c
#   • Astin I                                  URI=http://purl.obolibrary.org/obo/CHEBI_192105 score=1.00
# Query: apigenin
#   • Apigenin                                 URI=http://purl.obolibrary.org/obo/NCIT_C68466
#   • Apigenin                                 URI=http://purl.obolibrary.org/obo/NCIT_C68466 score=1.00
# Query: resveratrol
#   • Resveratrol                              URI=http://purl.obolibrary.org/obo/NCIT_C1215
#   • Resveratrol                              URI=http://purl.obolibrary.org/obo/NCIT_C1215 score=1.00
# Query: phytic acid
#   • Phytic Acid                              URI=http://purl.obolibrary.org/obo/NCIT_C87652
#   • Phytic Acid                              URI=http://purl.obolibrary.org/obo/NCIT_C87652 score=1.00
# Query: acacetin
# no matches
# Query: daucosterol
#   • daucosterol                              URI=http://purl.obolibrary.org/obo/CHEBI_67554 score=1.00
# Query: silibinin
#   • Silibinin                                URI=http://purl.obolibrary.org/obo/NCIT_C152359
#   • Silibinin                                URI=http://purl.obolibrary.org/obo/NCIT_C152359 score=1.00
# Query: sulforaphane
#   • Sulforaphane                             URI=http://purl.obolibrary.org/obo/NCIT_C1424
#   • Sulforaphane                             URI=http://purl.obolibrary.org/obo/NCIT_C1424 score=1.00
# Query: withaferin a
#   • withaferin A                             URI=http://purl.obolibrary.org/obo/CHEBI_69120 score=1.00
# Query: betulinic acid
#   • Betulinic Acid                           URI=http://purl.obolibrary.org/obo/NCIT_C38126
#   • Betulinic Acid                           URI=http://purl.obolibrary.org/obo/NCIT_C38126 score=1.00
# Query: phytochemical
#   • Phytochemical                            URI=http://purl.obolibrary.org/obo/NCIT_C28269
#   • Phytochemical                            URI=http://purl.obolibrary.org/obo/NCIT_C28269 score=1.00
# Query: hippophae rhamnoide
# no matches
# Query: hippophae rhamnoide
# no matches
# Query: hippophae rhamnoide
# no matches
# Query: hippophae rhamnoide
# no matches
# Query: hippophae rhamnoide
# no matches
# Query: hippophae rhamnoide
# no matches
# Query: hippophae rhamnoide
# no matches
# Query: hippophae rhamnoide
# no matches
# Query: hippophae rhamnoide
# no matches
# Query: fermented food
#   • food                                     URI=http://purl.obolibrary.org/obo/CHEBI_33290 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: prebiotic
# no matches
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: prebiotic
# no matches
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: prebiotic
# no matches
# Query: prebiotic
# no matches
# Query: prebiotic
# no matches
# Query: prebiotic
# no matches
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: prebiotic
# no matches
# Query: metabolite
#   • Metabolite                               URI=http://purl.obolibrary.org/obo/NCIT_C61154
#   • Metabolite                               URI=http://purl.obolibrary.org/obo/NCIT_C61154 score=1.00
# Query: synbiotic
#   • Synbiotic Supplement                     URI=http://purl.obolibrary.org/obo/NCIT_C99230 score=0.83
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: short-chain fatty acid
#   • Short Chain Fatty Acid                   URI=http://purl.obolibrary.org/obo/NCIT_C68424 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: berberine
#   • Berberine                                URI=http://purl.obolibrary.org/obo/NCIT_C83551
#   • Berberine                                URI=http://purl.obolibrary.org/obo/NCIT_C83551 score=1.00
# Query: berberine
#   • Berberine                                URI=http://purl.obolibrary.org/obo/NCIT_C83551
#   • Berberine                                URI=http://purl.obolibrary.org/obo/NCIT_C83551 score=1.00
# Query: berberine
#   • Berberine                                URI=http://purl.obolibrary.org/obo/NCIT_C83551
#   • Berberine                                URI=http://purl.obolibrary.org/obo/NCIT_C83551 score=1.00
# Query: berberine
#   • Berberine                                URI=http://purl.obolibrary.org/obo/NCIT_C83551
#   • Berberine                                URI=http://purl.obolibrary.org/obo/NCIT_C83551 score=1.00
# Query: berberine
#   • Berberine                                URI=http://purl.obolibrary.org/obo/NCIT_C83551
#   • Berberine                                URI=http://purl.obolibrary.org/obo/NCIT_C83551 score=1.00
# Query: berberine
#   • Berberine                                URI=http://purl.obolibrary.org/obo/NCIT_C83551
#   • Berberine                                URI=http://purl.obolibrary.org/obo/NCIT_C83551 score=1.00
# Query: berberine
#   • Berberine                                URI=http://purl.obolibrary.org/obo/NCIT_C83551
#   • Berberine                                URI=http://purl.obolibrary.org/obo/NCIT_C83551 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: synbiotic supplement
#   • Synbiotic Supplement                     URI=http://purl.obolibrary.org/obo/NCIT_C99230
#   • Synbiotic Supplement                     URI=http://purl.obolibrary.org/obo/NCIT_C99230 score=1.00
# Query: synbiotic supplement
#   • Synbiotic Supplement                     URI=http://purl.obolibrary.org/obo/NCIT_C99230
#   • Synbiotic Supplement                     URI=http://purl.obolibrary.org/obo/NCIT_C99230 score=1.00
# Query: prebiotic
# no matches
# Query: micronutrient treatment
#   • Micronutrient                            URI=http://purl.obolibrary.org/obo/NCIT_C68549 score=0.88
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: fermented wheat germ
#   • Fermented Wheat Germ Extract             URI=http://purl.obolibrary.org/obo/NCIT_C64763 score=0.90
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: fermented wheat germ
#   • Fermented Wheat Germ Extract             URI=http://purl.obolibrary.org/obo/NCIT_C64763 score=0.90
# Query: fermented wheat germ
#   • Fermented Wheat Germ Extract             URI=http://purl.obolibrary.org/obo/NCIT_C64763 score=0.90
# Query: fermented wheat germ
#   • Fermented Wheat Germ Extract             URI=http://purl.obolibrary.org/obo/NCIT_C64763 score=0.90
# Query: fermented wheat germ
#   • Fermented Wheat Germ Extract             URI=http://purl.obolibrary.org/obo/NCIT_C64763 score=0.90
# Query: fermented wheat germ
#   • Fermented Wheat Germ Extract             URI=http://purl.obolibrary.org/obo/NCIT_C64763 score=0.90
# Query: fermented wheat germ
#   • Fermented Wheat Germ Extract             URI=http://purl.obolibrary.org/obo/NCIT_C64763 score=0.90
# Query: fermented wheat germ
#   • Fermented Wheat Germ Extract             URI=http://purl.obolibrary.org/obo/NCIT_C64763 score=0.90
# Query: fermented wheat germ
#   • Fermented Wheat Germ Extract             URI=http://purl.obolibrary.org/obo/NCIT_C64763 score=0.90
# Query: fermented wheat germ
#   • Fermented Wheat Germ Extract             URI=http://purl.obolibrary.org/obo/NCIT_C64763 score=0.90
# Query: starch
#   • Starch                                   URI=http://purl.obolibrary.org/obo/NCIT_C68488
#   • Starch                                   URI=http://purl.obolibrary.org/obo/NCIT_C68488 score=1.00
# Query: short-chain fatty acid
#   • Short Chain Fatty Acid                   URI=http://purl.obolibrary.org/obo/NCIT_C68424 score=1.00
# Query: starch
#   • Starch                                   URI=http://purl.obolibrary.org/obo/NCIT_C68488
#   • Starch                                   URI=http://purl.obolibrary.org/obo/NCIT_C68488 score=1.00
# Query: starch
#   • Starch                                   URI=http://purl.obolibrary.org/obo/NCIT_C68488
#   • Starch                                   URI=http://purl.obolibrary.org/obo/NCIT_C68488 score=1.00
# Query: standard diet
#   • Standard Diet                            URI=http://purl.obolibrary.org/obo/NCIT_C165169
#   • Standard Diet                            URI=http://purl.obolibrary.org/obo/NCIT_C165169 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: prebiotic
# no matches
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: prebiotic
# no matches
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: prebiotic
# no matches
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: prebiotic
# no matches
# Query: gluten
# no matches
# Query: casein
#   • Casein                                   URI=http://purl.obolibrary.org/obo/NCIT_C73337
#   • Casein                                   URI=http://purl.obolibrary.org/obo/NCIT_C73337 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: prebiotic
# no matches
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: nvp-1704
#   • NVP-2                                    URI=http://purl.obolibrary.org/obo/CHEBI_230487 score=1.00
# Query: nvp-1704
#   • NVP-2                                    URI=http://purl.obolibrary.org/obo/CHEBI_230487 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: nvp-1704
#   • NVP-2                                    URI=http://purl.obolibrary.org/obo/CHEBI_230487 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: medication
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459 score=1.00
# Query: medication
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459 score=1.00
# Query: medication
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459 score=1.00
# Query: medication
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459 score=1.00
# Query: medication
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459 score=1.00
# Query: medication
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459 score=1.00
# Query: lactobacillus
#   • Lactobacillus                            URI=http://purl.obolibrary.org/obo/NCIT_C76352
#   • Lactobacillus                            URI=http://purl.obolibrary.org/obo/NCIT_C76352 score=1.00
# Query: lactobacillus
#   • Lactobacillus                            URI=http://purl.obolibrary.org/obo/NCIT_C76352
#   • Lactobacillus                            URI=http://purl.obolibrary.org/obo/NCIT_C76352 score=1.00
# Query: lactobacillus
#   • Lactobacillus                            URI=http://purl.obolibrary.org/obo/NCIT_C76352
#   • Lactobacillus                            URI=http://purl.obolibrary.org/obo/NCIT_C76352 score=1.00
# Query: medication
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459
#   • Medication                               URI=http://purl.obolibrary.org/obo/NCIT_C459 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: micronutrient supplementation
#   • micronutrient                            URI=http://purl.obolibrary.org/obo/CHEBI_27027 score=1.00
# Query: prebiotic
# no matches
# Query: prebiotic
# no matches
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: prebiotic
# no matches
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: bacillus licheniformi
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202 score=1.00
# Query: bacillus licheniformi
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: bacillus licheniformi
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202 score=1.00
# Query: bacillus
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202 score=1.00
# Query: bacillus
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202 score=1.00
# Query: bacillus
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202 score=1.00
# Query: bacillus
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202 score=1.00
# Query: bacillus
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202 score=1.00
# Query: bacillus
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202
#   • Bacillus                                 URI=http://purl.obolibrary.org/obo/NCIT_C76202 score=1.00
# Query: diet
#   • Diet                                     URI=http://purl.obolibrary.org/obo/NCIT_C15222
#   • Diet                                     URI=http://purl.obolibrary.org/obo/NCIT_C15222 score=1.00
# Query: prebiotic
# no matches
# Query: prebiotic
# no matches
# Query: plant
#   • Plant                                    URI=http://purl.obolibrary.org/obo/NCIT_C14258
#   • Plant, Whole                             URI=http://purl.obolibrary.org/obo/NCIT_C79659 score=1.00
# Query: plant
#   • Plant                                    URI=http://purl.obolibrary.org/obo/NCIT_C14258
#   • Plant, Whole                             URI=http://purl.obolibrary.org/obo/NCIT_C79659 score=1.00
# Query: plant
#   • Plant                                    URI=http://purl.obolibrary.org/obo/NCIT_C14258
#   • Plant, Whole                             URI=http://purl.obolibrary.org/obo/NCIT_C79659 score=1.00
# Query: plant
#   • Plant                                    URI=http://purl.obolibrary.org/obo/NCIT_C14258
#   • Plant, Whole                             URI=http://purl.obolibrary.org/obo/NCIT_C79659 score=1.00
# Query: plant
#   • Plant                                    URI=http://purl.obolibrary.org/obo/NCIT_C14258
#   • Plant, Whole                             URI=http://purl.obolibrary.org/obo/NCIT_C79659 score=1.00
# Query: plant
#   • Plant                                    URI=http://purl.obolibrary.org/obo/NCIT_C14258
#   • Plant, Whole                             URI=http://purl.obolibrary.org/obo/NCIT_C79659 score=1.00
# Query: triphala polyphenol
#   • Polyphenol                               URI=http://purl.obolibrary.org/obo/NCIT_C28203 score=1.00
# Query: polyphenol
#   • Polyphenol                               URI=http://purl.obolibrary.org/obo/NCIT_C28203
#   • Polyphenol                               URI=http://purl.obolibrary.org/obo/NCIT_C28203 score=1.00
# Query: triphala
# no matches
# Query: triphala
# no matches
# Query: triphala polyphenol
#   • Polyphenol                               URI=http://purl.obolibrary.org/obo/NCIT_C28203 score=1.00
# Query: triphala polyphenol
#   • Polyphenol                               URI=http://purl.obolibrary.org/obo/NCIT_C28203 score=1.00
# Query: triphala polyphenol
#   • Polyphenol                               URI=http://purl.obolibrary.org/obo/NCIT_C28203 score=1.00
# Query: triphala polyphenol
#   • Polyphenol                               URI=http://purl.obolibrary.org/obo/NCIT_C28203 score=1.00
# Query: triphala polyphenol
#   • Polyphenol                               URI=http://purl.obolibrary.org/obo/NCIT_C28203 score=1.00
# Query: triphala polyphenol
#   • Polyphenol                               URI=http://purl.obolibrary.org/obo/NCIT_C28203 score=1.00
# Query: triphala polyphenol
#   • Polyphenol                               URI=http://purl.obolibrary.org/obo/NCIT_C28203 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: metabolite
#   • Metabolite                               URI=http://purl.obolibrary.org/obo/NCIT_C61154
#   • Metabolite                               URI=http://purl.obolibrary.org/obo/NCIT_C61154 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: metabolite
#   • Metabolite                               URI=http://purl.obolibrary.org/obo/NCIT_C61154
#   • Metabolite                               URI=http://purl.obolibrary.org/obo/NCIT_C61154 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: lacticaseibacillus rhamnosus
# no matches
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# Query: probiotic
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144
#   • Probiotic                                URI=http://purl.obolibrary.org/obo/NCIT_C93144 score=1.00
# The RDF graph has been saved in C:\Users\samue\OneDrive\Desktop\ThesisPiron\rdf\gutbrain_entities.ttl
