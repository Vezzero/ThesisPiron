# %%
#!/usr/bin/env python3
import os
import csv
import re
from pathlib import Path
import pandas as pd
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL

# -----------------------------------------------------------------------------
# 1. Setup dei percorsi e dei namespace
# -----------------------------------------------------------------------------
path = str(Path(os.path.abspath(os.getcwd())).absolute())
csv_file = os.path.join(path, "train_platinum_entities.csv")  # Assicurati che il file sia in questo percorso
save_path = os.path.join(path, "rdf")
os.makedirs(save_path, exist_ok=True)

# Namespace per gli individuali creati dal CSV
GUTBRAIN = Namespace("https://hereditary.dei.unipd.it/ontology/gutbrain/resource/")
GUTPROP = Namespace("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/")

PAPER_CLASS   = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Paper")
MENTION_CLASS = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Mention")

# -----------------------------------------------------------------------------
# 2. Lettura del CSV con rilevamento automatico del delimitatore
# -----------------------------------------------------------------------------
with open(csv_file, "r", encoding="utf-8") as f:
    sample = f.read(1024)
    f.seek(0)
    try:
        dialect = csv.Sniffer().sniff(sample)
        delimiter = dialect.delimiter
        print(f"Rilevato delimitatore: '{delimiter}'")
    except csv.Error:
        delimiter = ","  # fallback
        print("Impossibile rilevare il delimitatore, uso la virgola ','.")

df = pd.read_csv(csv_file, delimiter=delimiter)
df.columns = [col.strip() for col in df.columns]
print("Colonne lette dal CSV:", df.columns.tolist())

# -----------------------------------------------------------------------------
# 3. Dizionari di mapping (le chiavi sono in formato Title)
# -----------------------------------------------------------------------------
# Mapping per le label che associano la label (formattata come Title) all'URI della classe
label_mapping = {
    "Anatomical Location":   URIRef("https://w3id.org/brainteaser/ontology/schema/AnatomicalSite"),
    "Animal":                URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Animal"),
    "Biomedical Technique":  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/BiomedicalTechnique"),
    "Bacteria":              URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Species"),
    "Chemical":              URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Chemical"),
    "Dietary Supplement":    URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/DietarySupplement"),
    "Ddf":                   URIRef("https://w3id.org/brainteaser/ontology/schema/DiseaseDisorderOrFinding"),
    "Drug":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Drug"),
    "Food":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Food"),
    "Gene":                  URIRef("https://w3id.org/brainteaser/ontology/schema/Gene"),
    "Human":                 URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Human"),
    "Microbiome":            URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Microbiome"),
    "Statistical Technique": URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/StatisticalTechnique")
}

# Mapping per i concept scheme: le chiavi devono essere in formato Title.
concept_scheme_mapping = {
    "Anatomical Location":   URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/AnatomicSite"),
    "Animal":                URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Animal"),
    "Human":                 URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Human"),
    "Drug":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Drug"),
    "Gene":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Gene"),
    "Dietary Supplement":    URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/dietarySupplement"),
    "Ddf":                   URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/diseaseDisorderOrFindingTaxonomy"),
    "Metabolite":            URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Metabolite"),
    "Species":               URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Species"),
    "Food":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Food"),
    "Chemical":              URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Chemical"),
    "Biomedical Technique":  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/BiomedicalTechnique"),
    "Microbiome":            URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Microbiome"),
    "Statistical Technique": URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/StatisticalTechnique")
}

# Dizionario alias: per mappare eventuali termini alternativi alla chiave di concept scheme
alias_mapping = {
    "Bacteria": "Species"
}

# -----------------------------------------------------------------------------
# 4. Inizializza il grafo RDF e imposta il binding dei namespace
# -----------------------------------------------------------------------------
g = Graph()
g.bind("gutbrain", GUTBRAIN)
g.bind("rdfs", RDFS)
g.bind("xsd", XSD)
g.bind("skos", SKOS)
g.bind("owl", OWL)
g.bind("gutprop", GUTPROP)

# -----------------------------------------------------------------------------
# 4.a: Dichiarazione di skos:inScheme come ObjectProperty (OWL)
# -----------------------------------------------------------------------------
g.add((SKOS.inScheme, RDF.type, OWL.ObjectProperty))

# -----------------------------------------------------------------------------
# 4.b: Crea gli individuali per i Concept Scheme
# -----------------------------------------------------------------------------
for scheme_uri in set(concept_scheme_mapping.values()):
    # Trova tutte le chiavi che mappano a questo URI
    keys = [k for k, v in concept_scheme_mapping.items() if v == scheme_uri]
    # Costruisci l'etichetta: usa .title() per capitalizzare
    label_text = ", ".join(k.title() for k in keys) + " Concept Scheme"
    g.add((scheme_uri, RDF.type, SKOS.ConceptScheme))
    g.add((scheme_uri, RDFS.label, Literal(label_text, datatype=XSD.string)))

def create_uri_fragment(text):
    # Rimuovi spazi e virgole
    return re.sub(r'[ ,]', '', text)
    
# -----------------------------------------------------------------------------
# 5. Itera su ogni riga del CSV per creare le istanze e associarle al Concept Scheme
# -----------------------------------------------------------------------------
for idx, row in df.iterrows():
    pmid      = str(row["pmid"]).strip()
    annotator = str(row["annotator"]).strip()
    start_idx = str(row["start_idx"]).strip()
    end_idx   = str(row["end_idx"]).strip()
    location  = str(row["location"]).strip()
    text_span = str(row["text_span"]).strip()
    raw_label = str(row["label"]).strip()

    # Converti la label in formato Title per uniformarla (es. "bacteria" -> "Bacteria")
    label_title = raw_label.title()

    # Rimuove eventuali tag HTML dal campo text_span
    cleaned_text_span = re.sub(r'<[^>]*>', '', text_span).strip()

    # Crea o riferisci l'istanza del paper associato
    paper_uri = URIRef(GUTBRAIN[f"paper_{pmid}"])
    g.add((paper_uri, RDF.type, PAPER_CLASS))
    
    if label_title in label_mapping:
        class_uri = label_mapping[label_title]
        instance_name = cleaned_text_span.replace(" ", "_")
        instance_uri = URIRef(GUTBRAIN[instance_name])
        
        g.add((instance_uri, RDF.type, class_uri))
        g.add((instance_uri, RDF.type, SKOS.Concept))
        g.add((instance_uri, RDFS.label, Literal(cleaned_text_span, datatype=XSD.string)))
        
        # Determina la chiave da usare per il Concept Scheme: usa l'alias se esiste
        scheme_key = label_title
        if label_title in alias_mapping:
            scheme_key = alias_mapping[label_title]
        
        if scheme_key in concept_scheme_mapping:
            scheme_uri = concept_scheme_mapping[scheme_key]
            g.add((instance_uri, SKOS.inScheme, scheme_uri))
        
        #g.add((paper_uri, GUTPROP.containedIn, instance_uri))
    else:
        # Gestione come una Mention per le annotazioni non mappate
        mention_uri = URIRef(GUTBRAIN[f"mention_{pmid}"])
        g.add((mention_uri, RDF.type, MENTION_CLASS))
        g.add((mention_uri, RDF.type, SKOS.Concept))
        g.add((mention_uri, GUTBRAIN.annotator, Literal(annotator, datatype=XSD.string)))
        g.add((mention_uri, GUTBRAIN.location, Literal(location, datatype=XSD.string)))
        g.add((mention_uri, GUTBRAIN.text_span, Literal(cleaned_text_span, datatype=XSD.string)))
        g.add((mention_uri, GUTBRAIN.label, Literal(label_title, datatype=XSD.string)))
        g.add((mention_uri, GUTBRAIN.start_idx, Literal(int(start_idx), datatype=XSD.integer)))
        g.add((mention_uri, GUTBRAIN.end_idx, Literal(int(end_idx), datatype=XSD.integer)))
        g.add((paper_uri, GUTBRAIN.hasMention, mention_uri))

# -----------------------------------------------------------------------------
# 6. Serializza il grafo RDF in formato Turtle e salva su file
# -----------------------------------------------------------------------------
output_file = os.path.join(save_path, "gutbrain_entities.ttl")
g.serialize(destination=output_file, format="turtle")
print(f"Il grafo RDF è stato salvato in {output_file}")
# Out:
# Rilevato delimitatore: '|'
# Colonne lette dal CSV: ['pmid', 'annotator', 'start_idx', 'end_idx', 'location', 'text_span', 'label']
# Il grafo RDF è stato salvato in C:\Users\samue\OneDrive\Desktop\ThesisPiron\rdf\gutbrain_entities.ttl

# %%
#!/usr/bin/env python3
import os
import csv
import re
from pathlib import Path
import pandas as pd
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD, SKOS, OWL

# -----------------------------------------------------------------------------
# 1. Setup dei percorsi e dei namespace
# -----------------------------------------------------------------------------
path = str(Path(os.path.abspath(os.getcwd())).absolute())
csv_file = os.path.join(path, "train_platinum_entities.csv")  # File delle entità
relations_csv = os.path.join(path, "train_platinum_relations.csv")  # File delle relazioni
save_path = os.path.join(path, "rdf")
os.makedirs(save_path, exist_ok=True)

# Namespace per gli individuali creati dal CSV
GUTBRAIN = Namespace("https://hereditary.dei.unipd.it/ontology/gutbrain/resource/")
# Namespace per le proprietà e per i tipi (schema)
GUTPROP = Namespace("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/")

PAPER_CLASS   = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Paper")
MENTION_CLASS = URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Mention")

# -----------------------------------------------------------------------------
# 2. Lettura del CSV delle entità con rilevamento automatico del delimitatore
# -----------------------------------------------------------------------------
with open(csv_file, "r", encoding="utf-8") as f:
    sample = f.read(1024)
    f.seek(0)
    try:
        dialect = csv.Sniffer().sniff(sample)
        delimiter = dialect.delimiter
        print(f"Rilevato delimitatore per entità: '{delimiter}'")
    except csv.Error:
        delimiter = ","  
        print("Impossibile rilevare il delimitatore per entità, uso la virgola ','.")

df = pd.read_csv(csv_file, delimiter=delimiter)
df.columns = [col.strip() for col in df.columns]
print("Colonne lette dal CSV delle entità:", df.columns.tolist())

# -----------------------------------------------------------------------------
# 3. Dizionari di mapping (le chiavi sono in formato Title)
# -----------------------------------------------------------------------------
label_mapping = {
    "Anatomical Location":   URIRef("https://w3id.org/brainteaser/ontology/schema/AnatomicalSite"),
    "Animal":                URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Animal"),
    "Biomedical Technique":  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/BiomedicalTechnique"),
    "Bacteria":              URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Species"),
    "Chemical":              URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Chemical"),
    "Dietary Supplement":    URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/DietarySupplement"),
    "DDF":                   URIRef("https://w3id.org/brainteaser/ontology/schema/DiseaseDisorderOrFinding"),
    "Drug":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Drug"),
    "Food":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Food"),
    "Gene":                  URIRef("https://w3id.org/brainteaser/ontology/schema/Gene"),
    "Human":                 URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Human"),
    "Microbiome":            URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/Microbiome"),
    "Statistical Technique": URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/StatisticalTechnique")
}

concept_scheme_mapping = {
    "Anatomical Location":   URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/AnatomicSite"),
    "Animal":                URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Animal"),
    "Human":                 URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Human"),
    "Drug":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Drug"),
    "Gene":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Gene"),
    "Dietary Supplement":    URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/dietarySupplement"),
    "DDF":                   URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/diseaseDisorderOrFindingTaxonomy"),
    "Metabolite":            URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Metabolite"),
    "Species":               URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Species"),
    "Food":                  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Food"),
    "Chemical":              URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Chemical"),
    "Biomedical Technique":  URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/BiomedicalTechnique"),
    "Microbiome":            URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/Microbiome"),
    "Statistical Technique": URIRef("https://hereditary.dei.unipd.it/ontology/gutbrain/schema/conceptScheme/StatisticalTechnique")
}

alias_mapping = {
    "Bacteria": "Species"
}

# -----------------------------------------------------------------------------
# 4. Inizializza il grafo RDF e imposta il binding dei namespace
# -----------------------------------------------------------------------------
g = Graph()
g.bind("gutbrain", GUTBRAIN)
g.bind("rdfs", RDFS)
g.bind("xsd", XSD)
g.bind("skos", SKOS)
g.bind("owl", OWL)
g.bind("gutprop", GUTPROP)

# -----------------------------------------------------------------------------
# 4.a: Dichiarazione di skos:inScheme come ObjectProperty (OWL)
# -----------------------------------------------------------------------------
g.add((SKOS.inScheme, RDF.type, OWL.ObjectProperty))

# -----------------------------------------------------------------------------
# 4.b: Crea gli individuali per i Concept Scheme
# -----------------------------------------------------------------------------
for scheme_uri in set(concept_scheme_mapping.values()):
    keys = [k for k, v in concept_scheme_mapping.items() if v == scheme_uri]
    label_text = ", ".join(k.title() for k in keys) + " Concept Scheme"
    g.add((scheme_uri, RDF.type, SKOS.ConceptScheme))
    g.add((scheme_uri, RDFS.label, Literal(label_text, datatype=XSD.string)))

# Funzione per creare un frammento URI senza spazi, virgole e parentesi
def create_uri_fragment(text):
    # Rimuove i tag HTML, se presenti
    cleaned = re.sub(r'<[^>]*>', '', text)
    # Sostituisce / rimuove caratteri non validi (ad es. backslash, parentesi, virgole, spazi)
    # Es.: sostituisci tutti i caratteri NON a-zA-Z0-9_- con underscore
    cleaned = re.sub(r'[^a-zA-Z0-9_-]', '_', cleaned)
    return cleaned


# Definizione della funzione per convertire una stringa in camelCase
def to_camel_case(s):
    parts = re.split(r'\s+', s.strip())
    if not parts:
        return ""
    return parts[0].lower() + ''.join(word.title() for word in parts[1:])

# -----------------------------------------------------------------------------
# 5. Itera sul CSV delle entità per creare le istanze e associarle al Concept Scheme
# -----------------------------------------------------------------------------
for idx, row in df.iterrows():
    pmid      = str(row["pmid"]).strip()
    annotator = str(row["annotator"]).strip()
    start_idx = str(row["start_idx"]).strip()
    end_idx   = str(row["end_idx"]).strip()
    location  = str(row["location"]).strip()
    text_span = str(row["text_span"]).strip()
    raw_label = str(row["label"]).strip()

    if raw_label.lower() == "ddf":
        label_title = "DDF"
    else:
        label_title = raw_label.title()
    
    cleaned_text_span = re.sub(r'<[^>]*>', '', text_span).strip()
    cleaned_text_span = cleaned_text_span.replace('\\', '\\\\') 

    paper_uri = URIRef(GUTBRAIN[f"paper_{pmid}"])
    g.add((paper_uri, RDF.type, PAPER_CLASS))
    
    if label_title in label_mapping:
        class_uri = label_mapping[label_title]
        instance_fragment = create_uri_fragment(cleaned_text_span)
        instance_uri = URIRef(GUTBRAIN[instance_fragment])
        
        g.add((instance_uri, RDF.type, class_uri))
        g.add((instance_uri, RDF.type, SKOS.Concept))
        g.add((instance_uri, RDFS.label, Literal(cleaned_text_span, datatype=XSD.string)))
        
        scheme_key = label_title
        if label_title in alias_mapping:
            scheme_key = alias_mapping[label_title]
        
        if scheme_key in concept_scheme_mapping:
            scheme_uri = concept_scheme_mapping[scheme_key]
            g.add((instance_uri, SKOS.inScheme, scheme_uri))
        
        #g.add((paper_uri, GUTPROP.containedIn, instance_uri))
    else:
        mention_uri = URIRef(GUTBRAIN[f"mention_{pmid}"])
        g.add((mention_uri, RDF.type, MENTION_CLASS))
        g.add((mention_uri, RDF.type, SKOS.Concept))
        g.add((mention_uri, GUTPROP.annotator, Literal(annotator, datatype=XSD.string)))
        g.add((mention_uri, GUTPROP.location, Literal(location, datatype=XSD.string)))
        g.add((mention_uri, GUTPROP.text_span, Literal(cleaned_text_span, datatype=XSD.string)))
        g.add((mention_uri, GUTPROP.label, Literal(label_title, datatype=XSD.string)))
        g.add((mention_uri, GUTPROP.start_idx, Literal(int(start_idx), datatype=XSD.integer)))
        g.add((mention_uri, GUTPROP.end_idx, Literal(int(end_idx), datatype=XSD.integer)))
        g.add((paper_uri, GUTPROP.hasMention, mention_uri))

# -----------------------------------------------------------------------------
# 6. Lettura del CSV delle relazioni e integrazione nel grafo RDF
# -----------------------------------------------------------------------------
df_rel = pd.read_csv(relations_csv, delimiter="|")
df_rel.columns = [col.strip() for col in df_rel.columns]
print("Colonne lette dal CSV delle relazioni:", df_rel.columns.tolist())

df_rel.rename(columns={'object_label,,': 'object_label'}, inplace=True)
print("Colonne lette dal CSV delle relazioni:", df_rel.columns.tolist())

for idx, row in df_rel.iterrows():
    # Per il soggetto:
    subj_text = str(row["subject_text_span"]).strip()
    cleaned_subj_text = re.sub(r'<[^>]*>', '', subj_text).strip()
    subj_fragment = create_uri_fragment(cleaned_subj_text)
    subj_uri = URIRef(GUTBRAIN[subj_fragment])
    
    # Per l'oggetto:
    obj_text = str(row["object_text_span"]).strip()
    cleaned_obj_text = re.sub(r'<[^>]*>', '', obj_text).strip()
    obj_fragment = create_uri_fragment(cleaned_obj_text)
    print(obj_fragment)
    obj_uri = URIRef(GUTBRAIN[obj_fragment])
    
    # Per il predicato:
    pred_text = str(row["predicate"]).strip()
    pred_text_clean = to_camel_case(pred_text)
    pred_uri = URIRef(GUTPROP[pred_text_clean])
    
    g.add((subj_uri, pred_uri, obj_uri))

output_file = os.path.join(save_path, "gutbrain_entities.ttl")
g.serialize(destination=output_file, format="turtle")
print(f"Il grafo RDF è stato salvato in {output_file}")
# Out:
# Rilevato delimitatore per entità: '|'
# Colonne lette dal CSV delle entità: ['pmid', 'annotator', 'start_idx', 'end_idx', 'location', 'text_span', 'label']
# Colonne lette dal CSV delle relazioni: ['pmid', 'annotator', 'subject_start_idx', 'subject_end_idx', 'subject_location', 'subject_text_span', 'subject_label', 'predicate', 'object_start_idx', 'object_end_idx', 'object_location', 'object_text_span', 'object_label,,']
# Colonne lette dal CSV delle relazioni: ['pmid', 'annotator', 'subject_start_idx', 'subject_end_idx', 'subject_location', 'subject_text_span', 'subject_label', 'predicate', 'object_start_idx', 'object_end_idx', 'object_location', 'object_text_span', 'object_label']
# patients
# people
# bariatric_patients
# gut_microbiome
# inflammation
# poultry_gut_microbiome
# gut_microbiome
# inflammation
# gut_microbiome
# inflammation
# poultry_gut_microbiome
# Birds
# bird
# patients
# patients
# patients
# psychosis
# schizophrenia
# patients
# patients
# patients
# healthy_controls
# patients
# patients
# Human_Migraine_Headache
# gastrointestinal_diseases
# patients
# patients
# headaches
# gastrointestinal_disorders
# gut_microbiota
# gut_microbiota
# gastrointestinal_diseases
# inflammation
# inflammation
# gut_microbiota
# migraine_headache
# migraine_headache
# patients
# migraine_headache
# patients
# migraine_headache
# patients
# depression
# anxiety
# migraine_headache
# migraine_headache
# patients
# cognitive_impairment
# type_1_diabetes_mellitus
# T1D
# T1D
# gut_microbiota
# streptozotocin__STZ_-induced_T1D_mice
# T1D_mice
# Long-term_acetate_deficiency
# learning_and_memory_impairments
# long-term_acetate_deficiency
# cognitive_decline
# neuropsychiatric_disorders
# microbiota
# neuropsychiatric_disorders
# oral_cavity
# nasal_passages
# lungs
# gut
# skin
# bladder
# vagina
# gastrointestinal_tract
# psychiatric_and_neurodegenerative_disorders
# neuropsychiatric_disorders
# neuropsychiatric_disorders
# patients
# neuropsychiatric_disorders
# AI
# systemic_inflammation
# AI
# arthropathy
# gut_dysbiosis
# AI
# arthropathy
# gut_dysbiosis
# AI
# arthropathy
# gut_dysbiosis
# AI
# psoriatic_arthritis
# systemic_lupus_erythematosus
# irritable_bowel_disease
# rheumatoid_arthritis
# AI
# reduced_systemic_inflammation
# inflammation
# AI-related_musculoskeletal_pathology
# oleic_acid-induced_acne
# acne_pathogenesis
# inflammatory_disease
# patients
# patients
# oleic_acid-induced_acne
# skin_inflammation
# serum_hormone
# insulin
# testosterone
# acne_mice
# skin_lipids
# triglycerides
# non-esterified_free_fatty_acids
# skin_lipid_metabolism-related_genes
# skin_triglycerides
# skin_lipid_metabolism-related_genes
# PPAR-__
# SREBP-1c
# FASN
# ATGL
# acne_mice
# acne_mice
# gut_microbiota
# Staphylococcus
# acne_mice
# gut_microbiota
# acne
# skin_inflammation
# acne
# skin_inflammation
# Neurodegenerative_Diseases
# age-associated_diseases
# age-associated_diseases
# Alzheimer_s_and_Parkinson_s_diseases
# Alzheimer_s_and_Parkinson_s_diseases
# neurodegeneration
# age-associated_molecular_dysfunctions
# age-associated_molecular_dysfunctions
# neurodegeneration
# neurodegeneration
# neurodegeneration
# neurodegeneration
# neurodegeneration
# females
# neurodegeneration
# TREM2
# C3
# C3aR1
# TNFA
# NF-kb
# TGFB1_2
# SIRT1_6
# HMGB1
# STING
# TREM2
# C3
# TREM2
# TREM2
# TREM2
# TREM2
# TREM2
# TREM2
# TREM2
# TREM2
# TREM2
# TREM2
# TREM2
# TREM2
# TREM2
# age-related_brain_diseases
# humans
# brain
# heart
# arteries
# ovaries
# AD
# PD
# LBD
# vitiligo
# apoptosis
# gut_dysbiosis
# inflammation
# gut_dysbiosis
# inflammation
# melanin
# melanin
# CUMS-induced_depressive_disorder
# gut_microbiota
# CUMS-induced_depressive_disorder
# gut_microbiota
# mice
# depressive_behaviors
# gut_microbiota
# major_depressive_disorders
# mothers
# children
# 16S_rRNA_amplicon_sequencing
# colon
# patients
# schizophrenia
# schizophrenia_patients
# healthy_controls
# 16S_rRNA_sequencing
# 16S_rRNA_sequencing
# schizophrenia
# schizophrenia_patients
# healthy_controls
# PICRUSt_analysis
# PICRUSt_analysis
# schizophrenia_patients
# healthy_controls
# human_stress
# anxiety_symptoms
# Stress
# mental_health_problems
# anxiety
# depression
# stress
# anxiety
# stress
# anxiety
# stress
# stress
# anxiety
# stressed_adults
# stressed_adults
# placebo_group
# fecal_metagenomes
# fecal_metagenomes
# fecal_metagenomes
# probiotic_group
# fecal_metagenomes
# fecal_metagenomes
# Bifidobacterium_adolescentis
# Bifidobacterium_longum
# Fecalibacterium_prausnitzii
# Roseburia_faecis
# Fusicatenibacter_saccharivorans
# Parkinson_s_disease__PD__patients
# Parkinson_s_disease__PD__patients
# Parkinson_s_disease__PD__patients
# PD_patients
# gut_inflammation
# LPS_paraquat-induced_weight_loss
# Bacteroidaceae_and_Porphyromonadaceae_families
# Rikencellaceae
# S24-7
# Human_Neurological_Disorders
# human_microbiome
# human_body
# neurological_disorders
# neurological_disorders
# neurological_disorders
# neurological_conditions
# autism_spectrum_disorders
# Parkinson_s_disease
# schizophrenia
# multiple_sclerosis
# Alzheimer_s_disease
# epilepsy
# stroke
# neurological_disorders
# neurological_disorders
# neurological_disorders
# neurological_disorders
# neurological_disorders
# depressive_disorder
# patients
# patients
# patients
# rats
# Chronic_Mild_Stress
# Mice
# depression
# stress-related_disorders
# Lactobacillus_helveticus_R0052
# Lactobacillus_plantarum_R1012
# Bifidobacterium_longum_R0175
# Lactobacillus
# mice
# anxiety-_and_depressive-like_behaviors
# CMS-induced_anxiety-_and_depressive-like_behaviors
# humans
# dogs
# individuals
# Dysbiosis
# humans
# dogs
# humans
# Dysbiosis
# Dysbiosis
# Dysbiosis
# Dysbiosis
# gastrointestinal_disorders
# chronic_enteropathy
# inflammatory_bowel_disease
# food_allergies
# ulcerative_histiocytic_colitis
# dogs
# humans
# dogs
# depression
# depression
# depression_gut_microbiota
# multiomics_study
# fecal_metagenome-wide_sequencing
# serum_metabolomics_profiling
# individuals
# individuals
# multiomics_study
# fecal_metagenome-wide_sequencing
# serum_metabolomics_profiling
# multiomics_study
# fecal_metagenome-wide_sequencing
# serum_metabolomics_profiling
# Escherichia_coli
# Enterobacter_cloacae
# Escherichia_coli
# Enterobacter_cloacae
# IBS-D
# microbiota_of_neonatal_gut_and_nose
# microbiota_of_infant_gut_and_nose
# 16S_rRNA_sequencing
# 16S_rRNA_sequencing
# qPCR
# 16S_rRNA_sequencing
# qPCR
# infant_faecal_microbiota
# infant_microbiota
# infant_stool_microbiota
# infant_stool_microbiota
# vaginally_delivered__fully_breastfed_infants
# gut_microbiota
# maternal_microbiota
# PD
# NDs
# Alzheimer_s_disease
# AD
# multiple_system_atrophy
# MSA
# multiple_sclerosis
# MS
# neuromyelitis_optica
# NMO
# amyotrophic_lateral_sclerosis
# ALS
# Lactobacillus
# Bifidobacterium
# Verrucomicrobiaceae
# Akkermansia
# Faecalibacterium
# Coprococcus
# Blautia
# Prevotella
# Prevotellaceae
# neurodegenerative_diseases
# FD_mice
# FD_mice
# FD_mice
# FD_mice
# FD_mice
# hippocampal_proteomic_analysis
# FD_mice
# Bacteroidetes
# Proteobacteria
# cognitive_impairment
# SCFA_receptor_knockout_mice
# cognitive_impairment
# SCFA_receptor_knockout_mice
# altered_gut_microbiota
# PTSD
# repeated_social_defeat_stress
# RSDS
# RSDS_mice
# RSDS_mice
# RSDS_mice
# RSDS_mice
# RSDS_mice
# dysregulation_of_gut_barrier_functions
# proinflammatory_gut_milieu
# world_s_population
# substantiated_local_gastric_pathologies
# neurodegenerative_disorders
# hyperhomocysteinemia-related_brain_cortical_thinning
# BCT
# neurodegeneration
# substantiated_local_gastric_pathologies
# substantiated_local_gastric_pathologies
# neurodegenerative_central_nervous_system_disorders
# neurodegenerative_central_nervous_system_disorders
# neurodegenerative_central_nervous_system_disorders
# neurodegenerative_central_nervous_system_disorders
# neurodegenerative_central_nervous_system_disorders
# neurodegenerative_central_nervous_system_disorders
# neurodegenerative_central_nervous_system_disorders
# glaucoma
# Helicobacter_pylori_infection
# non-commensal_gut_microbiome
# neurodegenerative_diseases
# Alzheimer_s_disease
# neurodegenerative_diseases
# Alzheimer_s_disease
# neurodegenerative_diseases
# neurodegenerative_diseases
# neurodegenerative_diseases
# neurodegenerative_diseases
# neurodegenerative_disorders
# Shotgun_metagenomics
# major_depressive_episode_patients
# Bacteroidetes
# Actinobacteria
# Firmicutes
# microbes
# Gut_Microbiota
# Patients
# Mild_Metabolic_Disorders
# Gut_Microbiota
# Mild_Metabolic_Disorders
# patients
# patients
# patients
# Secondary_metabolic_disturbances
# metabolic_syndrome
# intestinal_flora
# patients
# mild_metabolic_disorders
# patients
# mild_metabolic_disorders
# patients
# patients
# patients
# patients
# patients
# patients
# FPG
# FPI
# HOMA-IR
# firmicutes
# coliform
# patients
# patients
# patients
# bacteroides
# firmicutes
# bacteroides
# patients
# firmicutes
# intestinal_flora
# patients
# patients
# patients
# patients
# mild_metabolic_disturbances
# schizophrenia
# schizophrenia
# gastrointestinal__GI__disorders
# schizophrenia
# Autoimmunity
# schizophrenia
# Autoimmunity
# gastrointestinal__GI__disorders
# autoimmune_disorders
# enteropathic_celiac_disease
# non-celiac_food_sensitivities
# non-celiac_food_sensitivities
# individuals
# humoral_immunity
# gut_bacteria
# inflammation
# schizophrenia
# autism_spectrum_disorder
# autism_spectrum_disorder
# ASD
# women
# women
# ASD
# children
# ASD
# gut_microbiota
# psychiatric_disorders
# pediatric_population
# child_and_adolescent_population__0-18__years_old_
# mental_health_disorders
# child_and_adolescent_population__0-18__years_old_
# youth
# psychiatric_disorders
# youth
# Lachnospiraceae_family
# bifidobacterial_populations
# ASD_and_healthy_controls
# Attention_Deficit_Hyperactivity_Disorder
# ADHD
# ASD
# gut_Bifidobacterium
# psychiatric_disorders
# children
# adolescents
# children
# adolescents
# mental_disorders
# mental_disorders
# gut_microbiota
# type_2_diabetes_patients
# patients
# patients
# patients
# patients
# patients
# patients
# patients
# patients
# gut_microbiota
# participants
# Lactobacillus
# Bifidobacterium
# Akkermansias
# intestinal_microbiota_alterations
# T2DM
# patients
# veterans
# Depression-like_Behavior
# Rats
# Rats
# depression
# anxiety
# depression
# depression
# stress-induced_depression
# stress-induced_depression
# chronic_unpredictable_mild_stress__CUMS__model
# depression
# depression-like_behaviors
# CUMS_model_rats
# gut_microbiota
# CUMS_rats
# depressed_rats
# Chronic_Restraint_Stress-Induced_Neurobehavioral_and_Gut_Barrier_Deficits
# Gut_Microbiota
# depression-like_behaviors
# mice
# nonalcoholic_fatty_liver_disease
# cardiovascular_disease
# obesity
# diabetes
# depression
# Parkinson_s_disease
# autism
# gastrointestinal_cancers
# Gastric_and_esophageal_cancer
# gut_microbiome
# rats
# idiopathic_Parkinson_s_disease
# individuals
# Parkinson_s_disease
# PD
# aged_rats
# gut_microbiome
# gut_microbiome
# gut_microbiome
# Parkinsonian_pathology
# neuroinflammation
# endolysosomal_deficits
# Parkinsonian_pathology
# neuroinflammation
# endolysosomal_deficits
# aged_rats
# PD-related_neurodegeneration
# gut_microbiome
# persons
# gut_microbiome
# persons
# whole_genome_shotgun_sequencing
# nigrostriatal_neurodegeneration
# adult_rats
# whole_genome_shotgun_sequencing
# individuals
# gut_microbiome
# Blautia
# gut_microbiome
# Bifidobacteria
# gut_microbiome
# idiopathic_PD
# hospitalized_older_adults
# geriatric_populations
# disease-related_malnutrition
# geriatric_populations
# malnutrition
# hospitalized_acutely_ill_older_adults
# 16S_rRNA_gene-sequenced_gut_microbiota_data
# patients
# Patients
# Patients
# malnutrition
# malnutrition
# malnutrition
# malnutrition
# malnutrition
# malnutrition
# patients
# Older_adults
# patients
# disability
# brain
# gut
# Patients
# Depressive_Episode
# patients
# patients
# 16S_rRNA_sequencing
# patients
# patients
# patients
# patients
# PD
# patients
# Lactobacillus_fermentum_PS150
# hypnotic_psychobiotic_strain
# hypnotic_effects
# sleep_disturbances
# hypnotic_effects
# sleep_disturbances
# hypnotic_effects
# sleep_disturbances
# pentobarbital-induced_sleep_test
# hypnotic_effects
# hypnotic_effects
# hypnotic_effects
# hypnotic_effects
# hypnotic_effect
# anxiety_symptoms
# mental_diseases
# physical_disorders
# stress
# anxiety
# anxiety
# anxiety_symptoms
# intestinal_microbiota
# intestinal_microbiota
# intestinal_microbiota
# intestinal_flora
# IRIF
# anxiety_symptoms
# anxiety_symptoms
# anxiety_symptoms
# intestinal_microbiota
# anxiety_symptoms
# anxiety_symptoms
# PCOS_Patients
# PCOS
# depression
# metagenomic_sequencing
# transcriptome_sequencing
# RNA-seq
# depressed_women
# depressed_women
# patients
# neurodegenerative_diseases
# neurodegenerative_diseases
# PCOS_patients
# Parkinson_s_Disease
# Parkinson_s_Disease
# Parkinson_s_disease
# Parkinson_s_disease
# Parkinson_s_disease
# Parkinson_s_disease
# Parkinson_s_disease
# Parkinson_s_disease
# Patients
# GI_symptoms
# children
# ASD
# ASD
# GI_symptoms
# children
# gastrointestinal_symptoms
# children
# children
# ASD
# typically_developing__TD__children
# 16S_rRNA
# untargeted_metabolomics
# children
# children
# GI_symptoms
# GI_symptoms
# GI_symptoms
# GI_symptoms
# GI_symptoms
# GI_symptoms
# GI_symptoms
# GI_symptoms
# ASD_children
# GI_symptoms
# GI_symptoms
# children
# children
# Shotgun_metagenomics
# Shotgun_metagenomics
# major_depressive_disorder
# MDD
# MDD_patients
# shotgun_metagenomic_sequencing
# shotgun_metagenomic_sequencing
# shotgun_metagenomic_sequencing
# MDD
# Bifidobacterium
# MDD
# MDD_patients
# HCs
# MDD
# MDD_patients
# HCs
# gut_microbiota
# MDD_group
# gut_microbiota
# MDD_group
# gut_microbiota
# MDD_group
# gut_microbiota
# MDD_group
# MDD_group
# Healthy_Adults
# stress
# depression
# anxiety
# sleep_disturbances
# healthy_adults
# healthy_adults
# healthy_adults
# healthy_adults
# healthy_adults
# NVP-1704_group
# placebo_group
# NVP-1704_group
# placebo_group
# Bifidobacteriaceae
# Lactobacillacea
# Enterobacteriaceae
# colon_cancer
# colon_cancer
# CCRA
# Colon_cancer-related_anemia
# CCRA
# Colon_cancer-related_anemia
# CCRA
# Colon_cancer-related_anemia
# CCRA
# Colon_cancer-related_anemia
# Lachnospiraceae
# Odoribacter
# cancer-related_bacteria
# Helicobacter
# Lactococcus
# Alloprevotella
# imbalance-inducing_bacteria
# Escherichia-Shigella
# Parabacteroides
# butyrate-producing_bacteria
# Ruminococcaceae_UCG-014
# Lachnospiraceae
# Odoribacter
# cancer-related_bacteria
# Helicobacter
# Lactococcus
# Alloprevotella
# imbalance-inducing_bacteria
# Escherichia-Shigella
# Parabacteroides
# butyrate-producing_bacteria
# Ruminococcaceae_UCG-014
# Lachnospiraceae
# Odoribacter
# Lachnospiraceae
# Odoribacter
# Lachnospiraceae
# Odoribacter
# cancer-related_bacteria
# imbalance-inducing_bacteria
# butyrate-producing_bacteria
# CCRA
# CCRA
# CCRA
# Chronic_Stress-induced_Anhedonia
# patients
# major_depressive_disorder
# MDD
# patients
# patients
# neuropsychiatric_disorders
# neurometabolic_alterations
# neurometabolic_alterations
# healthy_mice
# depressive-like_behavior
# anhedonia
# anhedonia
# MDD
# CUS-induced_anhedonic_behaviors
# brain
# brain
# medial_prefrontal_cortex
# mPFC
# stressed_mice
# stressed_mice
# CUS_mice
# depressive_symptoms
# CUS-induced_depressive-like_behaviors
# individuals
# Parkinson_s_disease
# neuronal_disorders
# depression
# autism_spectrum_disorder
# Parkinson_s_disease
# Alzheimer_s_disease
# multiple_sclerosis
# anxiety_disorders
# anxiety_disorders
# subdiaphragmatic_vagus_nerve
# cuprizone-treated_mouse_brain
# demyelination
# demyelination
# vagus_nerve
# demyelination
# demyelination
# demyelination
# brain
# CPZ-treated_mice
# abnormal_blood_levels
# brain
# brain
# demyelination
# brain
# colorectal_cancer
# multiple_sclerosis
# individuals
# 16s_rRNA_sequencing_technique
# individuals
# individuals
# individuals
# individuals
# reproductive-aged_women
# reproductive-aged_women
# psychiatric_disorders
# depression
# anxiety
# patients
# psychiatric_symptoms
# psychiatric_symptoms
# PCOS_patients
# psychotic_and_affective_disorders
# mental_disorders
# patients
# psychotic_disorders
# bipolar_disorder
# depression
# healthy_controls
# patients
# psychotic_disorders
# bipolar_disorder
# depression
# healthy_controls
# Actinobacteria
# Firmicutes
# Actinobacteria
# Firmicutes
# Actinobacteria
# Firmicutes
# Actinobacteria
# Firmicutes
# Lachnospiraceae
# Faecalibacterium
# brain
# brain
# 13C-D-xylose_breath_tests
# 13C-D-xylose_breath_tests
# 13C-D-xylose_breath_testing
# patients
# patients
# patients
# patients
# patients
# patients
# patients
# chronic_alcohol_overconsumption
# __-synuclein_overexpressing_mice
# peripheral_tissues
# gastrointestinal__GI__tract
# brain
# peripheral_tissues
# gastrointestinal__GI__tract
# brain
# Parkinson_s_disease
# PD
# Parkinson_s_disease__
# PD__
# Parkinson_s_disease
# PD
# peripheral_tissues
# gastrointestinal__GI__tract
# brain
# PD
# motor_and_GI_symptoms
# gut_microbiome
# __-synuclein_overexpressing__ASO__mice
# substantia_nigra
# mice
# __-synuclein_overexpressing__ASO__mice
# ASO_mice
# gut_microbiome
# microglial_activation
# ASO_mice
# ASO_mice
# Single-cell_RNA-seq_analysis
# ASO_mice
# mice
# mental_and_neurological_disorders
# mental_illnesses
# autism
# depression
# anxiety
# neurodegenerative_disorders
# Alzheimer_s_and_Parkinson_s_diseases
# Patients
# Acute_and_Chronic_Insomnia
# Patients
# insomnia
# insomnia
# systemic_disorders
# insomnia
# insomnia
# insomnia
# insomnia
# insomnia
# insomnia
# insomnia
# depression
# depressive_behavior
# depressive_behavior
# depressive_behavior
# depressive_behavior
# depressive_behavior
# depressive_behavior
# depressive_behavior
# cell_danger_response
# cell_danger_response
# cell_danger_response
# cell_danger_response
# cell_danger_response
# cell_danger_response
# gut_microbiome
# major_depressive_disorder
# major_depressive_disorder
# MDD
# MDD
# patients
# MDD
# 16S_rRNA_gene_sequencing
# shotgun_metagenomic_sequencing
# patients
# patients
# patients
# Bifidobacterium
# Blautia
# patients
# MDD
# 16S_rRNA_gene_sequencing
# 16S_rRNA_gene_sequencing
# 16S_rRNA_gene_sequencing
# Phylogenetic_Investigation_of_Communities_by_Reconstruction_of_Unobserved_States__PICRUSt__analysis
# gastrointestinal_tract
# Mental_health_disorders
# functional_gastrointestinal_disorders
# functional_gastrointestinal_disorders
# irritable_bowel_syndrome
# IBS
# females
# females
# controls
# participants
# Gut_Microbiome
# Parkinson_s_disease
# PD
# Illumina_sequencing
# Illumina_sequencing
# Illumina_sequencing
# Illumina_sequencing
# gut_microbiota
# gut_microbiota
# gut_microbiota
# gut_microbiota
# gut_microbiota
# gut_microbiota
# gut_microbiota
# southern_hemisphere_PD_population
# gut_microbiota
# psychiatric_disorders
# dysbiosis
# gut_microbiota
# Prevotella_species
# Clostridium_difficile_colitis
# LC-MS_MS
# LC-MS_MS
# 6-OHDA
# NAPEs
# PD
# Bipolar_disorder
# bipolar_disorder
# bipolar_disorder
# bipolar_disorder
# bipolar_disorder
# bipolar_disorder
# bipolar_disorder
# Depression
# gut_microbiota
# gut_microbiota
# neurological_and_psychiatric_disorders
# rodent_gut
# V4_16S_rRNA_gene_sequencing
# microbiome_profiling
# Parkinson_s_Disease
# Occidental_Patients
# Occidental_Patients
# Occidental_Patients
# gut_microbiota_dysbiosis
# PD_patients
# Occidental_Patients
# Parkinson_s_disease
# gut_microbiota_dysbiosis
# PD
# populations
# PD_patients
# non-PD_controls
# PD_patients
# voluntary_wheel_running
# Blood_Lipid
# serum_total_cholesterol
# triglycerides
# low-density_lipoprotein_cholesterol
# Muribaculaceae
# Faecalibaculum
# colon
# liver
# fatty_acid_transport_genes
# Abhd5
# adipogenesis
# Me1
# Fasn
# Pnpla3
# Elovl6
# fatty_acid_transport_genes
# Abhd5
# adipogenesis
# Me1
# Fasn
# Pnpla3
# Elovl6
# CD36
# Acacb
# peroxisome_proliferator-activated_receptor_gamma__PPARg___genes
# gut_microbiota
# schizophrenia
# schizophrenia
# untargeted_liquid_chromatography-mass_spectrometry-based_metabolic_profiling_approach
# psychiatric_clinical_symptoms
# schizophrenia
# Flavonifractor
# Christensenellaceae
# gut_microbiota
# gut_microbiota
# gut_Flavonifractor_genus
# gut_Christensenellaceae_family
# patients
# gut_Christensenellaceae_family
# patients
# gut_microbiota
# gut_microbiota
# patients
# 16S_rRNA_gene_amplicon_sequencing
# 16S_rRNA_gene_amplicon_sequencing
# patients
# unaffected_first-degree_relatives
# healthy_controls
# 16S_rRNA_gene_amplicon_sequencing
# AD
# AD
# patients
# smokers
# patients
# patients
# smokers
# patients
# non-smoking_patients
# patients
# Christensenellaceae
# Flavonifractor
# enhanced_oxidative_stress
# systemic_low-grade_inflammation
# enhanced_oxidative_stress
# systemic_low-grade_inflammation
# AD
# states_of_dysmetabolism
# Prader-Willi_Syndrome
# obesity
# metabolic_disorders
# mental_health_symptoms
# Prader-Willi_syndrome
# Prader-Willi_syndrome
# Prader-Willi_syndrome
# Prader-Willi_syndrome
# disability
# patients
# Major_depression
# mental_d__
# mental_disorders
# mental_disorders
# depression
# affective_disorders
# Major_Depressive_Disorder
# MDD
# participants
# participants
# depression
# Obstructive_Sleep_Apnea
# obstructive_sleep_apnea
# OSA
# obstructive_sleep_apnea
# OSA
# OSA
# gut_microbiota
# OSA_onset
# gut_microbiota
# OSA_onset
# gut_microbiota
# OSA_onset
# gut_microbiota
# gut_microbiota
# gut_microbiota
# gut_microbiota
# gut_microbiota
# OSA
# OSA
# OSA
# obstructive_sleep_apnea
# OSA
# children
# children
# VVS_patients
# children
# VVS_patients
# children
# VVS
# VVS_children
# matched_controls
# children
# 16S_rRNA_gene_sequencing
# 16S_rRNA_gene_sequencing
# clinical_symptoms
# VVS_children
# controls
# syncope
# VVS_patients
# VVS_patients
# VVS_patients
# head-up_tilt_test
# HUTT
# VVS
# VVS
# gut_microbiota
# VVS
# patients
# patients
# 16S_rRNA_sequencing
# quantitative_fluorescence_in_situ_hybridization
# high-sensitivity_C-reactive_protein
# 16S_rRNA_sequencing
# quantitative_fluorescence_in_situ_hybridization
# high-sensitivity_C-reactive_protein
# gut_microbiota
# MDD
# MDD
# gut_microbiota
# MDD
# anxiety-like_and_depression-like_behaviours
# mental_disorders
# gut_diseases
# gut_microbiome
# depressive-like_and_anxiety-like_behaviours
# rats
# gut_microbiota
# colon
# colon
# brain
# brain
# brain
# brain
# brain
# SCFAs
# SCFAs
# SCFAs
# SCFAs
# depressive-like_behaviours
# depressive-like_and_anxiety-like_behaviours
# colon
# depressive-like_and_anxiety-like_behaviours
# chronic_unpredictable_mild_stress
# brain
# depressive-like_and_anxiety-like_behaviours
# depression-_and_anxiety-like_behaviors
# neuroinflammation
# mice
# Akkermansia_muciniphila
# hippocampus
# depression-_and_anxiety-like_behaviors
# Humanized_Gnotobiotic_Mice
# multi-omics_approach
# multi-omics_approach
# patients
# patients
# patients
# patients
# Lactobacillus
# gut_microbiota
# children
# children
# children
# children
# children
# children
# ASD
# gut_microbiota
# ASD
# gut_microbiota
# ASD_children
# typically_developing__TD__children
# blast_shotgun_metagenomic_sequencing
# blast_shotgun_metagenomic_sequencing
# ASD_children
# MEs
# gut_IgA_level
# gut_microbiota
# autoimmune_disease
# ASD
# gap_junction_alpha-1
# GJA1
# paired_box_protein_Pax-3
# PAX3
# eyes_absent_homolog_1_isoform_4
# EYA1
# Listeria_monocytogenes
# ASD_children
# TD_children
# children
# children
# children
# ASD
# gut_IgA_levels
# gut_microbiota
# children
# ASD
# ASD_children
# Gut_Microbiota
# Schizophrenia
# 16S_rRNA_sequencing
# schizophrenia
# schizophrenia
# criteria-acute_group__patients_with_acute_schizophrenia_
# remission_group__patients_with_schizophrenia_in_remission_
# 16S_rRNA_sequencing
# 16S_rRNA_sequencing
# 16S_rRNA_sequencing
# 16S_rRNA_sequencing
# criteria-acute_group__patients_with_acute_schizophrenia_
# depression
# participants
# criteria-acute_group__patients_with_acute_schizophrenia_
# remission_group__patients_with_schizophrenia_in_remission_
# control_group__healthy_controls_
# 16S_rRNA_sequencing
# schizophrenia
# patients
# patients
# patients
# postinfection_disorders_of_gut-brain_interaction
# DGBI
# Patients
# Patients
# mental_disorders
# mental_disorders
# gut_microbiota
# mental_disorders
# central_and_peripheral_inflammation
# gut_microbiota
# gut_microbiota
# mental_disorders
# people
# Parkinson_s_disease
# PD
# PD
# PD
# PD
# PD
# psychological_changes
# age-related_diseases
# Alzheimer_s_disease
# Parkinson_s_disease
# older_subjects
# duodenal_aspirates
# stress-induced_depression
# cognitive_impairment
# neuropsychiatric_disorders
# depression
# cognitive_impairment
# at-risk_groups
# stress-induced_mental_health_problems
# stress-induced_mental_health_problems
# stress-induced_mental_health_problems
# stress-induced_mental_health_problems
# stress-induced_mental_health_problems
# stress-induced_mental_health_problems
# stress-induced_mental_health_problems
# Parkinson_s_disease
# Parkinson_s_disease
# Parkinson_s_disease_patients
# Parkinson_s_disease_patients
# depressive_behaviour
# mental_health
# gut_microbiota
# patients
# patients
# patients
# patients
# patients
# gut_microbiota_disorder
# intestinal_barrier
# patients
# major_depressive_disorder
# MDD
# patients
# patients
# 16S_rRNA_sequencing
# bioinformatics_analysis
# patients
# 16S_rRNA_sequencing
# bioinformatics_analysis
# 16S_rRNA_sequencing
# bioinformatics_analysis
# patients
# depression
# gut_microbiota
# depression
# short-chain_fatty_acids
# depression
# Type_2_Diabetes_Mellitus
# Dementia
# Colon_microbiota
# Colon_microbiota
# nonalcoholic_fatty_liver
# diabetes
# diabetes
# metabolic_syndrome
# healthy_persons
# Clostridium_difficile_infection
# stool_biobank
# women
# men
# SPS
# Male_and_female_Sprague-Dawley_rats
# Male_and_female_Sprague-Dawley_rats
# male_and_female_rodents
# taxon-function_analysis
# Viral_Respiratory_Infections
# Neuroinflammatory_Disorders
# tissue_damage
# immune_dysfunction
# inflammatory_conditions
# intestine
# lungs
# brain
# inflammation
# inflammation
# respiratory_infections
# neuroinflammatory_disorders
# viral_respiratory_infections
# COVID-19_disease
# influenza_virus_infection
# neurological_disorders
# multiple_sclerosis
# mental_illnesses
# People
# gut_microbiota
# prediabetes
# individuals
# Parkinson_s_disease
# schizophrenia
# cardiovascular_diseases
# neoplasms
# Egyptian_patients
# Parkinson_s_Disease
# Egyptian_patients
# Parkinson_s_disease
# Parkinson_s_disease
# PD
# Parkinson_s_disease
# Quantitative_SYBR_Green_Real-Time_PCR
# patients
# Bacteroides
# Firmicutes
# Bifidobacteria
# Prevotella
# Quantitative_SYBR_Green_Real-Time_PCR
# PD_patients
# Bifidobacteria
# Bifidobacteria
# Parkinson_s_disease_patients
# healthy_controls
# Parkinson_s_disease
# breast_cancer_survivors
# cancer_survivors
# cancer_survivors
# depressive_and_anxiety_disorders
# chemotherapy-associated_psychological_distress
# FCR
# cancer_survivors
# cancer_survivors
# women
# participants
# gut_microbiota
# FCR
# Firmicutes
# Bacteroidetes
# Bacteroides
# Lachnospiraceae_g
# Ruminococcus
# gut_microbiota
# gut_microbiota
# gut_microbiota
# gut_microbiota
# FCR
# FCR
# patients
# patients
# patients
# patients
# 16S_RNA_method
# ELISA_kit
# patients
# 16S_RNA_method
# ELISA_kit
# gut_microbiota
# gut_microbiota
# gut_microbiota
# gut_microbiota
# gut_microbiota
# gut_microbiota
# gut_microbiota
# gut_microbiota
# gut_microbiota
# gut_microbiota
# MDD_group
# MDD
# Il grafo RDF è stato salvato in C:\Users\samue\OneDrive\Desktop\ThesisPiron\rdf\gutbrain_entities.ttl
